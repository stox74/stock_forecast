# %%
from kita_trade_collector import KITATradeCollector

# URL 디코딩된 키 사용 (% 인코딩 제거)
collector = KITATradeCollector(
    service_key="2o6NG3ixxDgGQ9S4dWUgsMac9WlxfX46+JvFRsAlsXQ6xVi6CZewvNJvbHd4S7exkWwt3YWoKSdwvUNb46kSTQ=="
)

df = collector.get_trade_data("202101", "202112")
# Out:
# 조회 중: 202101 ~ 202112... ✅ 13행 수집

# %%
from kita_long_term_collector_fixed import collect_long_term_trade_data, analyze_trade_data, save_trade_data

# API 키
SERVICE_KEY = "2o6NG3ixxDgGQ9S4dWUgsMac9WlxfX46+JvFRsAlsXQ6xVi6CZewvNJvbHd4S7exkWwt3YWoKSdwvUNb46kSTQ=="

# 데이터 수집
df = collect_long_term_trade_data(
    service_key=SERVICE_KEY,
    start_year=2010,
    end_year=2025
)

# 분석
analyze_trade_data(df)

# 저장
save_trade_data(df, 2010, 2025)
# Out:
# ...
# 무역통계 데이터 수집: 2010년 ~ 2025년
# ...
#
# 2010년 데이터 수집 중... ✅ 13개월
#
# 2011년 데이터 수집 중... ✅ 13개월
#
# 2012년 데이터 수집 중... ✅ 13개월
#
# 2013년 데이터 수집 중... ✅ 13개월
#
# 2014년 데이터 수집 중... ✅ 13개월
#
# 2015년 데이터 수집 중... ✅ 13개월
#
# 2016년 데이터 수집 중... ✅ 13개월
#
# 2017년 데이터 수집 중... ✅ 13개월
#
# 2018년 데이터 수집 중... ✅ 13개월
#
# 2019년 데이터 수집 중... ✅ 13개월
#
# 2020년 데이터 수집 중... ✅ 13개월
#
# 2021년 데이터 수집 중... ✅ 13개월
#
# 2022년 데이터 수집 중... ✅ 13개월
#
# 2023년 데이터 수집 중... ✅ 13개월
#
# 2024년 데이터 수집 중... ✅ 13개월
#
# 2025년 데이터 수집 중... ✅ 13개월
#
# ...
# 데이터 처리 중...
# ...
# ✅ 총 208개월 데이터 수집 완료
#
# ...
# 데이터 분석
# ...
#
# 📋 컬럼: balPayments, expCnt, expDlr, impCnt, impDlr, year
#
# 📊 수출액 통계 (단위: 천 달러)
#    평균: $89,523,641,030
#    최대: $709,406,808,165
#    최소: $30,735,415,239
#    합계: $18,620,917,334,316
#
# 📋 최근 12개월:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[18], line 14
#       7 df = collect_long_term_trade_data(
# ...
