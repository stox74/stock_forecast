# %% [markdown]
# # US Revenue Forecast v10.2 — UPSERT + NaN cleanup 패치
#
# **v10 대비 변경**:
# 1. `save_to_db` 를 INSERT-only → UPSERT 로 교체 (Override 자동 갱신)
# 2. `to_dict('records')` 이후 NaN/NaT → None 직접 치환 (pymysql 호환)
#
# 분기 매출 시계열 예측 파이프라인 (FMP API + 시계열 앙상블 + DB 저장).
#
# ## 흐름 요약
#
# | Phase | 셀 | 역할 |
# |-------|----|------|
# | Setup | Cell 1~4 | 환경, 모듈, 파라미터, DB |
# | Data  | Cell 5 | **매출 Quality 검증 + Override 통합 함수** |
# | Inspect | Cell 6 | 단일 ticker 데이터 정제 결과 확인 |
# | Forecast Lib | Cell 7 | 예측 함수 정의 (모델 + index) |
# | Storage Lib | Cell 8 | Long-format 변환 + DB 저장 함수 |
# | Single Run | Cell 9 | 단일 ticker end-to-end (Quality → 예측 → 저장) |
# | Batch | Cell 10 | 전체 배치 (Override 종목 처리 옵션) |
# | Monitor | Cell 11 | 저장 결과 조회 |
# | Utility | Cell 12 | 오염 데이터 삭제 |
#
# ## v8 대비 변경 사항 (v9)
#
# - ❌ v8.1 → v8.2 wrapper chain 제거
# - ✅ 단일 `fetch_financial_series` 안에 FPI safety + Override 일체화
# - ✅ `MANUAL_REVENUE_OVERRIDES` 운영 dict 한 곳에 집중
# - ✅ `OVERRIDE_TICKERS` 자동 도출 + 배치 모드 (all / exclude / only)
# - ✅ Cell 5 에서 verification 테스트 분리 → Cell 6 으로 이동

# %% [markdown]
# ## Cell 1 · 환경 설정 & 경로 자동 감지

# %%
import sys, os, warnings
from pathlib import Path
warnings.filterwarnings("ignore")

# ── 후보 프로젝트 루트 (노트북 / 데스크탑) ───────────────────────
_CANDIDATE_ROOTS = [
    r"C:\Users\Hoyoung_Park\PyCharmMiscProject\stock_forecast",
    r"C:\Users\82108\OneDrive\바탕 화면\investment\investment_strategy",
]


def _setup_path() -> str:
    try:
        start = Path(__file__).resolve().parent
    except NameError:
        start = Path.cwd()

    for p in [start] + list(start.parents):
        if (p / "DATA").is_dir():
            root = str(p)
            if root not in sys.path:
                sys.path.insert(0, root)
            print(f"[PATH] root 자동 감지 : {root}")
            return root

    for candidate in _CANDIDATE_ROOTS:
        if os.path.isdir(candidate) and os.path.isdir(os.path.join(candidate, "DATA")):
            if candidate not in sys.path:
                sys.path.insert(0, candidate)
            print(f"[PATH] root 후보 경로 : {candidate}")
            return candidate

    raise EnvironmentError("DATA 폴더를 찾을 수 없습니다.")


_ROOT = _setup_path()
print(f"[확인] 프로젝트 루트  : {_ROOT}")
print(f"[확인] DATA 경로     : {os.path.join(_ROOT, 'DATA')}")
# Out:
# [PATH] root 자동 감지 : C:\Users\82108\OneDrive\바탕 화면\investment\investment_strategy
# [확인] 프로젝트 루트  : C:\Users\82108\OneDrive\바탕 화면\investment\investment_strategy
# [확인] DATA 경로     : C:\Users\82108\OneDrive\바탕 화면\investment\investment_strategy\DATA

# %% [markdown]
# ## Cell 2 · 모듈 Import

# %%
# ── 내부 모듈 (DATA 폴더) ─────────────────────────────────────
from DATA.config import get_db_info, get_engine
from DATA.us_target_ticker_list_2000 import ticker_list as DEFAULT_TICKER_LIST
from DATA.universal_ts_forecast_function_v2 import (
    forecast_sarima, forecast_ets, forecast_prophet,
    forecast_lstm, forecast_theta,
    infer_freq_alias, seasonal_periods_from_freq, clear_memory,
)

# ── 외부 라이브러리 ───────────────────────────────────────────
import gc
import time as _time
import traceback
import requests as _requests
from typing import Optional, List, Dict
from datetime import datetime

import numpy as np
import pandas as pd
from sqlalchemy import text
from IPython.display import display

# ── 로그 유틸 ─────────────────────────────────────────────────
try:
    from DATA.config import log
except ImportError:
    def log(tag: str, msg: str):
        ts = datetime.now().strftime("%H:%M:%S")
        print(f"[{ts}][{tag}] {msg}")


print(f"[OK] 모듈 Import 완료")
print(f"[OK] DEFAULT_TICKER_LIST 길이: {len(DEFAULT_TICKER_LIST):,}개")
# Out:
# [OK] 모듈 Import 완료
# [OK] DEFAULT_TICKER_LIST 길이: 2,000개

# %% [markdown]
# ## Cell 3 · 파라미터 설정
#
# 필요 시 이 셀만 수정하세요.

# %%
# ════════════════════════════════════════════════════════════
#  ★ 파라미터 — 필요에 따라 이 셀만 수정 ★
# ════════════════════════════════════════════════════════════

# ── FMP API ──────────────────────────────────────────────
FMP_API_KEY    = "hT0gAk87j9xZx4PlBApvBqfVL5IahvgV"
FMP_BASE_URL   = "https://financialmodelingprep.com/api/v3"
FMP_MAX_RETRY  = 3
FMP_SLEEP_SEC  = 0.35

# ── DB 테이블 ────────────────────────────────────────────
DEST_TABLE = "us_revenue_forecast_data"

# ── 재무 항목 ────────────────────────────────────────────
ITEM       = "sale"

# ── 예측 설정 ────────────────────────────────────────────
HORIZON    = 8     # 예측 분기 수 (8 = 2년)
MIN_OBS    = 28    # 최소 관측 분기 (28 = 7년)

# ── 모델 ─────────────────────────────────────────────────
ALL_MODELS      = ["SARIMA", "ETS", "Prophet", "LSTM", "Theta"]
ENSEMBLE_MODELS = ["SARIMA", "ETS", "Theta"]

# ── 예측 실행일 ──────────────────────────────────────────
FORECAST_DATE = datetime.now().strftime("%Y-%m-%d")

print("[파라미터 확인]")
print(f"  DEST_TABLE   = {DEST_TABLE}")
print(f"  ITEM         = {ITEM}")
print(f"  HORIZON      = {HORIZON}분기")
print(f"  MIN_OBS      = {MIN_OBS}개")
print(f"  ENSEMBLE     = {ENSEMBLE_MODELS}")
print(f"  FORECAST_DATE= {FORECAST_DATE}")
# Out:
# [파라미터 확인]
#   DEST_TABLE   = us_revenue_forecast_data
#   ITEM         = sale
#   HORIZON      = 8분기
#   MIN_OBS      = 28개
#   ENSEMBLE     = ['SARIMA', 'ETS', 'Theta']
#   FORECAST_DATE= 2026-09-05

# %% [markdown]
# ## Cell 4 · DB 연결 테스트

# %%
db_info = get_db_info()
engine  = get_engine(db_info)

try:
    with engine.connect() as conn:
        conn.execute(text("SELECT 1"))
    print("[OK] DB 연결 성공")
    print(f"     host={db_info.get('host')}  port={db_info.get('port')}  db={db_info.get('database')}")
except Exception as e:
    print(f"[FAIL] DB 연결 실패: {e}")
# Out:
# [FAIL] DB 연결 실패: (pymysql.err.OperationalError) (2003, "Can't connect to MySQL server on '192.168.0.230' ([WinError 10061] 대상 컴퓨터에서 연결을 거부했으므로 연결하지 못했습니다)")
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %% [markdown]
# ## Cell 5 · 매출 데이터 Quality 검증 + Manual Override (통합)
#
# **v9 정리**: 이전 v8.1 / v8.2 wrapper chain 을 모두 단일 셀로 통합했습니다.
#
# ### 5-1. Helper 함수
# - `_fmp_fetch_income` — FMP /income-statement 1차 조회
# - `_fmp_fetch_income_as_reported` — XBRL 백업 endpoint
# - `_fmp_fetch_profile` — country/isAdr 으로 FPI 식별
# - `_clean_series` — 중복 제거 정제
# - `_detect_duplicate_value_anomaly` — 마지막 분기 ≡ 직전 분기 패턴 탐지
# - `_apply_manual_overrides` — 알려진 정답 주입
#
# ### 5-2. `MANUAL_REVENUE_OVERRIDES`
# 1차 출처(SEC 6-K 등)에서 직접 확인한 정답 분기 매출 등록.
# **FMP 가 정상화되면 verbose 로그에 "제거 가능" 알림이 뜸**.
#
# ### 5-3. `fetch_financial_series` (단일 통합 함수)
# 파이프라인:
# 1. FMP primary 조회
# 2. 음수 매출 검사
# 3. 중복값 의심 탐지 → 의심 시 as-reported XBRL fallback → 그래도 의심이면 strict drop
# 4. Manual override 적용 (drop 된 분기 복원 또는 잘못된 값 갱신)
# 5. 최종 min_obs 검증
#
# ### 5-4. Override 종목 조회 도구
# `OVERRIDE_TICKERS` (set), `get_override_summary()` (df 형태).

# %%
# ════════════════════════════════════════════════════════════════════
# 5-1. Helper 함수 정의
# ════════════════════════════════════════════════════════════════════

def _fmp_fetch_income(ticker: str, limit: int = 40,
                      period: str = "quarter") -> pd.DataFrame:
    """FMP /income-statement → 표준 columns DataFrame.
    columns = [date, report_date, period, date_month, value]
    """
    url = f"{FMP_BASE_URL}/income-statement/{ticker}"
    params = {"period": period, "limit": limit, "apikey": FMP_API_KEY}

    for k in range(FMP_MAX_RETRY):
        try:
            r = _requests.get(url, params=params, timeout=30)
            if r.status_code == 429:
                _time.sleep(1.5 + k); continue
            r.raise_for_status()
            data = r.json()
            if isinstance(data, dict) and "Error Message" in data:
                raise ValueError(data["Error Message"])
            break
        except Exception as e:
            if k == FMP_MAX_RETRY - 1:
                raise RuntimeError(f"FMP 조회 실패 ({ticker}): {e}")
            _time.sleep(FMP_SLEEP_SEC + k * 0.5)

    if not data or not isinstance(data, list):
        return pd.DataFrame()

    df = pd.DataFrame(data)
    if df.empty or "revenue" not in df.columns:
        return pd.DataFrame()

    df["date"]        = pd.to_datetime(df["date"], errors="coerce")
    df["report_date"] = pd.to_datetime(
        df.get("fillingDate", df.get("acceptedDate", pd.NaT)), errors="coerce")
    df["period"]      = df.get("period", pd.NA)
    df["date_month"]  = df["date"].dt.to_period("M").dt.to_timestamp()
    df["value"]       = pd.to_numeric(df["revenue"], errors="coerce")

    return (df[["date","report_date","period","date_month","value"]]
                .dropna(subset=["date","value"])
                .sort_values("date")
                .reset_index(drop=True))


def _fmp_fetch_income_as_reported(ticker: str, limit: int = 40,
                                    period: str = "quarter") -> pd.DataFrame:
    """FMP /income-statement-as-reported (XBRL) — fallback 전용."""
    url = f"{FMP_BASE_URL}/income-statement-as-reported/{ticker}"
    params = {"period": period, "limit": limit, "apikey": FMP_API_KEY}

    for k in range(FMP_MAX_RETRY):
        try:
            r = _requests.get(url, params=params, timeout=30)
            if r.status_code == 429:
                _time.sleep(1.5 + k); continue
            r.raise_for_status()
            data = r.json()
            if isinstance(data, dict) and "Error Message" in data:
                return pd.DataFrame()
            break
        except Exception:
            if k == FMP_MAX_RETRY - 1:
                return pd.DataFrame()
            _time.sleep(FMP_SLEEP_SEC + k * 0.5)

    if not data or not isinstance(data, list):
        return pd.DataFrame()

    df = pd.DataFrame(data)
    if df.empty:
        return pd.DataFrame()

    REVENUE_TAGS = [
        "revenues",
        "revenuefromcontractwithcustomerexcludingassessedtax",
        "revenuefromcontractwithcustomerincludingassessedtax",
        "salesrevenuenet", "salesrevenuegoodsnet", "revenue",
    ]
    rev_col = next((tag for tag in REVENUE_TAGS if tag in df.columns), None)
    if rev_col is None:
        return pd.DataFrame()

    df["date"]        = pd.to_datetime(df.get("date"), errors="coerce")
    df["report_date"] = pd.to_datetime(
        df.get("fillingDate", df.get("acceptedDate", pd.NaT)), errors="coerce")
    df["period"]      = df.get("period", pd.NA)
    df["date_month"]  = df["date"].dt.to_period("M").dt.to_timestamp()
    df["value"]       = pd.to_numeric(df[rev_col], errors="coerce")

    return (df[["date","report_date","period","date_month","value"]]
                .dropna(subset=["date","value"])
                .sort_values("date")
                .reset_index(drop=True))


def _fmp_fetch_profile(ticker: str) -> Dict:
    """FMP /profile → country, isAdr, is_fpi (heuristic)."""
    url = f"{FMP_BASE_URL}/profile/{ticker}"
    try:
        r = _requests.get(url, params={"apikey": FMP_API_KEY}, timeout=15)
        r.raise_for_status()
        data = r.json()
        if isinstance(data, list) and data:
            p = data[0]
            country = (p.get("country") or "").upper()
            is_adr  = bool(p.get("isAdr", False))
            is_fpi  = is_adr or (country not in ("US", ""))
            return {"country": country, "is_adr": is_adr, "is_fpi": is_fpi,
                    "industry": p.get("industry", "") or ""}
    except Exception:
        pass
    return {"country": "", "is_adr": False, "is_fpi": False, "industry": ""}


def _clean_series(df: pd.DataFrame) -> pd.DataFrame:
    """date 중복 제거 (마지막 행 유지)."""
    df = df.copy()
    df["value"] = pd.to_numeric(df["value"], errors="coerce")
    df = df.dropna(subset=["date","value"]).sort_values("date").reset_index(drop=True)
    return df.groupby("date", sort=True).last().reset_index()


def _detect_duplicate_value_anomaly(df: pd.DataFrame,
                                     rel_tol: float = 1e-6,
                                     abs_tol: float = 1.0) -> Dict:
    """마지막 분기 == 직전 분기 → 의심 신호 (FMP carry-forward 패턴)."""
    if df is None or len(df) < 2:
        return {"anomaly": False, "reason": "데이터 부족"}

    last, prev = df.iloc[-1], df.iloc[-2]
    lv, pv = float(last["value"]), float(prev["value"])

    if pv == 0:
        return {"anomaly": False, "reason": "직전값=0"}

    diff_abs = abs(lv - pv)
    diff_rel = diff_abs / max(abs(pv), 1)
    is_dup   = (diff_abs <= abs_tol) and (diff_rel <= rel_tol)

    return {
        "anomaly":    is_dup,
        "last_date":  str(last["date"].date()) if pd.notna(last["date"]) else None,
        "prev_date":  str(prev["date"].date()) if pd.notna(prev["date"]) else None,
        "last_value": lv, "prev_value": pv,
        "reason":     f"마지막={lv:,.0f} ≡ 직전={pv:,.0f}" if is_dup
                      else f"Δ={diff_abs:,.0f} ({diff_rel:.4%})",
    }


# ════════════════════════════════════════════════════════════════════
# 5-2. MANUAL_REVENUE_OVERRIDES — 1차 출처 정답 등록
# ════════════════════════════════════════════════════════════════════
#
# 형식: ticker → {"YYYY-MM-DD" (분기말): value (USD)}
#
# 등록 기준:
#   · SEC 6-K, 20-F, 회사 IR 페이지 등 1차 출처에서 직접 확인한 값만
#   · 분기말 날짜는 calendar Q-end (3/31, 6/30, 9/30, 12/31)
#   · 값은 USD 정수 (예: 342_100_000)
#
# 정리 시점:
#   · FMP 가 데이터 수정 후 verbose 로그에 "제거 가능 ✓" 알림 → 그때 dict 에서 제거
# ════════════════════════════════════════════════════════════════════

MANUAL_REVENUE_OVERRIDES: Dict[str, Dict[str, float]] = {
    "SIMO": {
        "2026-03-31": 342_100_000,   # Q1 2026, 출처: 4/28 6-K (filing 2026-04-29)
                                     # FMP 가 Q4 2025 값 ($278.5M) 으로 carry-forward
    },
    # ── 신규 문제 종목 추가 시 여기에 ──────────────────────────────
    # "TICKER": {"YYYY-MM-DD": value_in_usd},
}


def _apply_manual_overrides(df: pd.DataFrame, ticker: str,
                             verbose: bool = False) -> pd.DataFrame:
    """알려진 정답 값으로 override / drop 된 분기 보강."""
    overrides = MANUAL_REVENUE_OVERRIDES.get(ticker.upper())
    if not overrides:
        return df

    df = df.copy()
    for date_str, true_value in overrides.items():
        target_date = pd.Timestamp(date_str)
        mask = df["date"] == target_date

        if mask.any():
            current  = float(df.loc[mask, "value"].iloc[0])
            rel_diff = abs(current - true_value) / max(abs(true_value), 1)
            if rel_diff > 0.01:
                df.loc[mask, "value"] = float(true_value)
                if verbose:
                    print(f"  [override] {ticker} {date_str}: "
                          f"{current:,.0f} → {true_value:,.0f}")
            else:
                if verbose:
                    print(f"  [override-match] {ticker} {date_str}: "
                          f"FMP 값과 일치 ({true_value:,.0f}) "
                          f"— MANUAL_REVENUE_OVERRIDES 에서 제거 가능 ✓")
        else:
            new_row = pd.DataFrame([{
                "date":        target_date,
                "report_date": pd.NaT,
                "period":      f"Q{target_date.quarter}",
                "date_month":  target_date.to_period("M").to_timestamp(),
                "value":       float(true_value),
            }])
            df = pd.concat([df, new_row], ignore_index=True)
            df = df.sort_values("date").reset_index(drop=True)
            if verbose:
                print(f"  [override-add] {ticker} {date_str}: "
                      f"+ {true_value:,.0f} (drop 분기 복원)")

    return df


# ════════════════════════════════════════════════════════════════════
# 5-3. fetch_financial_series — 통합 함수 (Quality + Override)
# ════════════════════════════════════════════════════════════════════

def fetch_financial_series(
    engine,
    ticker: str,
    item: str = "sale",
    min_obs: int = 28,
    *,
    strict_dup_check: bool        = True,
    fallback_to_as_reported: bool = True,
    verbose: bool                 = False,
) -> pd.DataFrame:
    """FMP 분기 매출 시계열 추출 (v9 통합).

    Pipeline:
      1) FMP primary 조회
      2) 음수 매출 검사
      3) 중복값 의심 탐지 → fallback (XBRL) 시도
      4) Strict drop (의심값 제거)
      5) Manual override 적용 (정답 주입)
      6) 최종 min_obs 검증

    Args:
        strict_dup_check : 의심값 fallback 도 실패 시 drop 여부
        fallback_to_as_reported : XBRL endpoint 시도 여부
        verbose : 진단 로그 출력
    """
    # ── Step 1: Primary fetch ───────────────────────────────────
    df = _fmp_fetch_income(ticker, limit=max(min_obs + 10, 40))
    if df.empty:
        raise ValueError(f"[{ticker}] FMP 1차 조회 결과 없음")
    _time.sleep(FMP_SLEEP_SEC)
    df = _clean_series(df)

    # ── Step 2: 음수 매출 검사 ──────────────────────────────────
    if (df["value"] < 0).any():
        neg_dates = df.loc[df["value"] < 0, "date"].dt.date.tolist()
        raise ValueError(f"[{ticker}] 음수 매출 → 예측 제외 ({neg_dates})")

    # ── Step 3+4: 중복값 의심 → Fallback → Strict drop ─────────
    diag = _detect_duplicate_value_anomaly(df)
    if diag["anomaly"]:
        prof = _fmp_fetch_profile(ticker)
        _time.sleep(FMP_SLEEP_SEC)

        if verbose:
            fpi_tag = " [FPI]" if prof["is_fpi"] else ""
            print(f"  ⚠ [{ticker}]{fpi_tag} 중복값 의심: "
                  f"{diag['prev_date']}={diag['prev_value']:,.0f} ≡ "
                  f"{diag['last_date']}={diag['last_value']:,.0f} "
                  f"(country={prof['country']}, isAdr={prof['is_adr']})")

        used_fallback = False
        if fallback_to_as_reported:
            df_ar = _fmp_fetch_income_as_reported(ticker, limit=max(min_obs + 10, 40))
            _time.sleep(FMP_SLEEP_SEC)
            if not df_ar.empty:
                df_ar = _clean_series(df_ar)
                diag_ar = _detect_duplicate_value_anomaly(df_ar)
                if not diag_ar["anomaly"] and len(df_ar) >= len(df) - 1:
                    if verbose:
                        last = df_ar.iloc[-1]
                        print(f"  ✓ [{ticker}] as-reported (XBRL) fallback 성공: "
                              f"{last['date'].date()}={last['value']:,.0f}")
                    df = df_ar
                    used_fallback = True
                elif verbose:
                    print(f"  ✗ [{ticker}] as-reported 도 의심: {diag_ar['reason']}")

        if (not used_fallback) and strict_dup_check:
            dropped = df.iloc[-1]
            df = df.iloc[:-1].reset_index(drop=True)
            if verbose:
                print(f"  → [{ticker}] strict drop "
                      f"({dropped['date'].date()}={dropped['value']:,.0f}) "
                      f"→ 잔여 {len(df)}분기")

    # ── Step 5: Manual override 적용 ────────────────────────────
    df = _apply_manual_overrides(df, ticker, verbose=verbose)

    # ── Step 6: 최종 min_obs 검증 ───────────────────────────────
    if len(df) < min_obs:
        raise ValueError(f"[{ticker}] 관측치 부족: {len(df)} < {min_obs}")

    return df


# ════════════════════════════════════════════════════════════════════
# 5-4. Override 종목 조회 도구
# ════════════════════════════════════════════════════════════════════

# 자동으로 도출되는 override 종목 set (대문자 정규화)
OVERRIDE_TICKERS = {tk.upper() for tk in MANUAL_REVENUE_OVERRIDES.keys()}


def get_override_summary() -> pd.DataFrame:
    """MANUAL_REVENUE_OVERRIDES 를 DataFrame 으로 보기 좋게 출력.

    Columns: ticker, quarter_end, override_value, override_value_M
    """
    rows = []
    for tk, qs in MANUAL_REVENUE_OVERRIDES.items():
        for d, v in qs.items():
            rows.append({
                "ticker":           tk,
                "quarter_end":      d,
                "override_value":   v,
                "override_value_M": f"${v/1e6:,.1f}M",
            })
    if not rows:
        return pd.DataFrame(columns=["ticker","quarter_end","override_value","override_value_M"])
    return pd.DataFrame(rows).sort_values(["ticker","quarter_end"]).reset_index(drop=True)


# ════════════════════════════════════════════════════════════════════
# 5-5. sync_overrides_to_db — DB 의 actual 값을 override 정답으로 강제 동기화
# ════════════════════════════════════════════════════════════════════
#
# 사용 시나리오:
#   override 추가 후, 이미 DB 에 옛 값(예: $278.5M)이 저장된 상태에서
#   해당 ticker 를 재예측 했지만 unique key 충돌로 갱신이 안 된 경우.
#   이 함수를 한 번 호출하면 모든 override 항목을 DB 에 강제 반영함.
#
# 사용:
#   sync_overrides_to_db(engine)
#
# 운영 워크플로우:
#   1. MANUAL_REVENUE_OVERRIDES 에 항목 추가
#   2. Cell 5 재실행 (dict 갱신)
#   3. sync_overrides_to_db(engine) 한 번 실행
#   4. FCFF / Relative_Valuation 등 downstream 노트북 재실행
# ════════════════════════════════════════════════════════════════════

def sync_overrides_to_db(engine):
    """MANUAL_REVENUE_OVERRIDES 의 모든 값을 DB 의 actual 행에 강제 반영.

    각 (ticker, date) 의 모든 forecast_date 에 걸쳐 value 를 갱신.
    DB 에 해당 행이 없으면 갱신 없음 (해당 ticker 매출 예측을 먼저 실행 필요).

    Returns:
        int : 총 갱신된 행 수
    """
    if not MANUAL_REVENUE_OVERRIDES:
        print("[INFO] MANUAL_REVENUE_OVERRIDES 가 비어있음 — 갱신 없음")
        return 0

    total_updated = 0
    with engine.begin() as conn:
        for ticker, qs in MANUAL_REVENUE_OVERRIDES.items():
            for date_str, value in qs.items():
                r = conn.execute(text(f"""
                    UPDATE `{DEST_TABLE}`
                    SET    value = :v
                    WHERE  ticker = :tk
                      AND  item = 'sale'
                      AND  data_type = 'actual'
                      AND  date = :d
                """), {"v": int(value), "tk": ticker, "d": date_str})
                n = r.rowcount or 0
                total_updated += n
                if n == 0:
                    print(f"  [SKIP]   {ticker} {date_str} → DB 에 해당 행 없음 "
                          f"(매출 예측 먼저 실행 필요)")
                else:
                    print(f"  [UPDATE] {ticker} {date_str} → ${value/1e6:,.1f}M  ({n}행 갱신)")

    print(f"\n[OK] 총 {total_updated}행 갱신")
    return total_updated


# ════════════════════════════════════════════════════════════════════
# 적용 확인
# ════════════════════════════════════════════════════════════════════
print("[OK] Cell 5 — fetch_financial_series + Override 통합 (v9)")
print(f"     · 등록된 OVERRIDE_TICKERS: {len(OVERRIDE_TICKERS)}개 → {sorted(OVERRIDE_TICKERS)}")
print(f"     · Pipeline: FMP → as-reported → strict drop → override → min_obs check")
# Out:
# [OK] Cell 5 — fetch_financial_series + Override 통합 (v9)
#      · 등록된 OVERRIDE_TICKERS: 1개 → ['SIMO']
#      · Pipeline: FMP → as-reported → strict drop → override → min_obs check

# %% [markdown]
# ## Cell 6 · 단일 Ticker 매출 데이터 Quality 검증
#
# `TEST_TICKER` 만 수정해서 사용. 다음을 확인합니다:
#
# 1. FMP raw 데이터에서 **중복값 의심** 자동 탐지 여부
# 2. **Override 적용**된 최종 분기 (해당 종목이 등록되어 있을 경우)
# 3. 최종 정제된 시계열 (예측 입력으로 그대로 사용 가능)

# %%
# ─── 단일 ticker 입력 ────────────────────────────────────────
TEST_TICKER = "LLY"     # ← 검증할 ticker (다른 종목으로 변경 가능)

print(f"{'='*72}")
print(f"[Quality Check] {TEST_TICKER}")
print(f"{'='*72}")

# Override 등록 여부 표시
if TEST_TICKER.upper() in OVERRIDE_TICKERS:
    overrides = MANUAL_REVENUE_OVERRIDES[TEST_TICKER.upper()]
    print(f"  ※ 이 ticker 는 override 등록되어 있음:")
    for d, v in overrides.items():
        print(f"     - {d}: ${v/1e6:,.1f}M")
    print()

# 통합 fetch 호출 (verbose 로 진단 로그 표시)
try:
    src_df = fetch_financial_series(
        engine, TEST_TICKER, item=ITEM, min_obs=MIN_OBS,
        strict_dup_check=True, fallback_to_as_reported=True, verbose=True,
    )

    print(f"\n[OK] {TEST_TICKER} 정제 완료: {len(src_df)}분기")
    print(f"     기간: {src_df['date'].iloc[0].date()} ~ {src_df['date'].iloc[-1].date()}")
    print(f"\n[정제된 매출 시계열] 마지막 8분기:")
    display(src_df.tail(8))

except Exception as e:
    print(f"\n[FAIL] {e}")
    src_df = None

# ─── Override 종목 전체 목록 표시 (참조용) ────────────────────
print(f"\n[현재 등록된 Override 종목]")
display(get_override_summary())
# Out:
# ========================================================================
# [Quality Check] LLY
# ========================================================================
#
# [OK] LLY 정제 완료: 40분기
#      기간: 2016-09-30 ~ 2026-06-30
#
# [정제된 매출 시계열] 마지막 8분기:
#          date report_date period date_month        value
# 32 2024-09-30  2024-10-30     Q3 2024-09-01  11439100000
# 33 2024-12-31  2025-02-19     Q4 2024-12-01  13532800000
# 34 2025-03-31  2025-05-01     Q1 2025-03-01  12728500000
# 35 2025-06-30  2025-08-07     Q2 2025-06-01  15557700000
# 36 2025-09-30  2025-10-30     Q3 2025-09-01  17600800000
# 37 2025-12-31  2026-02-12     Q4 2025-12-01  19292000000
# 38 2026-03-31  2026-04-30     Q1 2026-03-01  19799000000
# 39 2026-06-30  2026-08-05     Q2 2026-06-01  22974000000
# [현재 등록된 Override 종목]
#   ticker quarter_end  override_value override_value_M
# 0   SIMO  2026-03-31       342100000          $342.1M

# %% [markdown]
# ## Cell 7 · 예측 함수 정의
#
# - `forecast_one_ticker` — SARIMA / ETS / Prophet / LSTM / Theta 호출
# - `make_forecast_index_v5` — 분기 예측 인덱스 생성 (단순 +3 month, fiscal calendar 호환)

# %%
def forecast_one_ticker(
    y: pd.Series,
    ticker: str,
    horizon: int,
    models: list,
) -> dict:
    """단일 ticker 시계열 → 지정 모델로 예측."""
    import psutil, os
    proc = psutil.Process(os.getpid())

    def _mem_mb():
        return proc.memory_info().rss / 1024 / 1024

    freq    = infer_freq_alias(y.index)
    sp      = seasonal_periods_from_freq(freq)
    results = {}

    def _call(model_name):
        if model_name == "SARIMA":
            return forecast_sarima(y, horizon, seasonal_period=sp)
        elif model_name == "ETS":
            return forecast_ets(y, horizon, m=sp)
        elif model_name == "Prophet":
            return forecast_prophet(y, horizon, m=sp)
        elif model_name == "LSTM":
            return forecast_lstm(y, horizon)
        elif model_name == "Theta":
            return forecast_theta(y, horizon, m=sp)
        else:
            raise ValueError(f"알 수 없는 모델: {model_name}")

    for model_name in models:
        log(ticker, f"  [{model_name}] 시작  (메모리: {_mem_mb():.1f} MB)")
        try:
            res = _call(model_name)
            results[model_name] = res
            fc_arr = np.asarray(res.get("forecast", []))
            if len(fc_arr) > 0:
                log(ticker, f"  [{model_name}] 완료  첫값={fc_arr[0]:.2e} 마지막={fc_arr[-1]:.2e}")
            else:
                log(ticker, f"  [{model_name}] 완료 (forecast 비어있음)")
        except Exception as e:
            log(ticker, f"  [{model_name}] 실패: {type(e).__name__}: {str(e)[:80]}")
            results[model_name] = {"error": f"{type(e).__name__}: {e}"}

    return results


# ════════════════════════════════════════════════════════════════════
# 분기 예측 인덱스 — calendar month-end +3
# ════════════════════════════════════════════════════════════════════
def make_forecast_index_v5(last_date, horizon, freq=None):
    """last_date 의 month + 3 부터 calendar month-end 까지 horizon 개.

    fiscal calendar 변형 (1월/2월/8월/9월 fiscal year, 13W 등) 모두 자연 처리.
    """
    dates = []
    m, y = last_date.month, last_date.year
    for _ in range(horizon):
        m += 3
        if m > 12:
            m -= 12
            y += 1
        dates.append(pd.Timestamp(y, m, 1) + pd.offsets.MonthEnd(0))
    return pd.DatetimeIndex(dates)


def infer_freq_alias_v5(index):
    return "QE"  # placeholder for compatibility


# 모듈 + 노트북 namespace 둘 다 patch
import DATA.universal_ts_forecast_function_v2 as _ufm
_ufm.infer_freq_alias    = infer_freq_alias_v5
_ufm.make_forecast_index = make_forecast_index_v5
infer_freq_alias    = infer_freq_alias_v5
make_forecast_index = make_forecast_index_v5

print("[OK] Cell 7 — forecast_one_ticker + make_forecast_index 정의")
# Out:
# [OK] Cell 7 — forecast_one_ticker + make_forecast_index 정의

# %% [markdown]
# ## Cell 8 · Long-format 변환 + DB 저장 함수
#
# - `build_long_df` — actual + 모델별 forecast + Ensemble → long 포맷
# - `ensure_table` — 저장 테이블 생성 (최초 1회)
# - `save_to_db` — `(ticker,item,date,model,forecast_date)` 중복 키 기준 신규만 INSERT

# %%
def build_long_df(
    ticker: str,
    item: str,
    src_df: pd.DataFrame,
    forecast_results: dict,
    forecast_index: pd.DatetimeIndex,
    forecast_date: str,
    ensemble_models: list = None,
) -> pd.DataFrame:
    """actual + forecast (모델별) + Ensemble → long-format DataFrame."""
    if ensemble_models is None:
        ensemble_models = ENSEMBLE_MODELS

    now_str = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
    rows = []

    # actual 행
    for _, row in src_df.iterrows():
        rows.append({
            "ticker": ticker, "item": item,
            "date":   row["date"].strftime("%Y-%m-%d"),
            "period": row.get("period"),
            "date_month": (row["date_month"].strftime("%Y-%m-%d")
                            if pd.notna(row.get("date_month")) else None),
            "data_type": "actual", "model": "actual",
            "value": round(float(row["value"]), 6),
            "forecast_date": forecast_date,
            "sarima_order": None, "sarima_seasonal_order": None,
            "sarima_ic_value": None, "created_at": now_str,
        })

    # forecast 행
    ensemble_bucket = {}
    for model_name, res in forecast_results.items():
        if "error" in res or "forecast" not in res:
            continue
        fc_arr = np.asarray(res["forecast"])
        spec   = res.get("spec", {})

        sarima_order, sarima_seasonal, sarima_ic = None, None, None
        if model_name == "SARIMA":
            sarima_order    = str(spec.get("order", ""))
            sarima_seasonal = str(spec.get("seasonal_order", ""))
            raw_ic = spec.get("ic_value")
            if raw_ic is not None:
                try:
                    v = float(raw_ic)
                    sarima_ic = round(v, 4) if np.isfinite(v) else None
                except (TypeError, ValueError):
                    pass

        for i, dt in enumerate(forecast_index):
            if i >= len(fc_arr):
                break
            val    = float(fc_arr[i])
            dt_str = dt.strftime("%Y-%m-%d")
            rows.append({
                "ticker": ticker, "item": item, "date": dt_str,
                "period": None, "date_month": None,
                "data_type": "forecast", "model": model_name,
                "value": round(val, 6), "forecast_date": forecast_date,
                "sarima_order": sarima_order,
                "sarima_seasonal_order": sarima_seasonal,
                "sarima_ic_value": sarima_ic, "created_at": now_str,
            })
            if model_name in ensemble_models:
                ensemble_bucket.setdefault(dt_str, []).append(val)

    # Ensemble 행
    for dt_str, vals in ensemble_bucket.items():
        rows.append({
            "ticker": ticker, "item": item, "date": dt_str,
            "period": None, "date_month": None,
            "data_type": "forecast", "model": "Ensemble",
            "value": round(float(np.mean(vals)), 6),
            "forecast_date": forecast_date,
            "sarima_order": None, "sarima_seasonal_order": None,
            "sarima_ic_value": None, "created_at": now_str,
        })

    return pd.DataFrame(rows)


# ════════════════════════════════════════════════════════════════════
# DB 테이블 + 저장
# ════════════════════════════════════════════════════════════════════
CREATE_TABLE_SQL = f"""
CREATE TABLE IF NOT EXISTS `{DEST_TABLE}` (
    id                    BIGINT       NOT NULL AUTO_INCREMENT,
    ticker                VARCHAR(20)  NOT NULL,
    item                  VARCHAR(30)  NOT NULL,
    date                  DATE         NOT NULL,
    period                VARCHAR(10)  DEFAULT NULL,
    date_month            DATE         DEFAULT NULL,
    data_type             VARCHAR(10)  NOT NULL COMMENT 'actual / forecast',
    model                 VARCHAR(20)  NOT NULL,
    value                 DOUBLE       DEFAULT NULL,
    forecast_date         DATE         NOT NULL,
    sarima_order          VARCHAR(30)  DEFAULT NULL,
    sarima_seasonal_order VARCHAR(30)  DEFAULT NULL,
    sarima_ic_value       DOUBLE       DEFAULT NULL,
    created_at            DATETIME     DEFAULT CURRENT_TIMESTAMP,
    PRIMARY KEY (id),
    UNIQUE KEY uq_main (ticker, item, date, model, forecast_date),
    INDEX idx_ticker      (ticker),
    INDEX idx_forecast_dt (forecast_date),
    INDEX idx_model       (model)
) ENGINE=InnoDB DEFAULT CHARSET=utf8mb4;
"""


def ensure_table(engine):
    with engine.begin() as conn:
        conn.execute(text(CREATE_TABLE_SQL))


def save_to_db(engine, long_df: pd.DataFrame, dest_table: str = DEST_TABLE) -> int:
    """UPSERT 로 저장.

    동작 (v10.1):
      · 새 unique key (ticker,item,date,model,forecast_date) → INSERT
      · 기존 unique key 존재 → value, sarima_*, created_at 갱신
      · override 적용으로 같은 key 의 값이 변경된 경우에도 자동 반영

    Returns:
        affected rows (MySQL: INSERT=1, UPDATE=2, no-change=0 의 합)
    """
    if long_df is None or long_df.empty:
        return 0

    upsert_sql = text(f"""
        INSERT INTO `{dest_table}`
            (ticker, item, date, period, date_month, data_type, model, value,
             forecast_date, sarima_order, sarima_seasonal_order, sarima_ic_value,
             created_at)
        VALUES
            (:ticker, :item, :date, :period, :date_month, :data_type, :model, :value,
             :forecast_date, :sarima_order, :sarima_seasonal_order, :sarima_ic_value,
             :created_at)
        ON DUPLICATE KEY UPDATE
            value                 = VALUES(value),
            period                = VALUES(period),
            date_month            = VALUES(date_month),
            sarima_order          = VALUES(sarima_order),
            sarima_seasonal_order = VALUES(sarima_seasonal_order),
            sarima_ic_value       = VALUES(sarima_ic_value),
            created_at            = VALUES(created_at)
    """)

    # NaN / NaT → None 변환 (record-level, pymysql 호환)
    # pandas 의 float64 컬럼에 None 을 할당하면 NaN 으로 되돌아가는 함정을
    # 피하기 위해 to_dict("records") 이후 dict 단위로 직접 치환.
    records = long_df.to_dict("records")
    for r in records:
        for k, v in list(r.items()):
            if pd.isna(v):
                r[k] = None

    with engine.begin() as conn:
        result = conn.execute(upsert_sql, records)
        affected = result.rowcount or 0

    return affected


print("[OK] Cell 8 — build_long_df / ensure_table / save_to_db 정의")
# Out:
# [OK] Cell 8 — build_long_df / ensure_table / save_to_db 정의

# %% [markdown]
# ## Cell 9 · 단일 Ticker 매출 예측 → DB 저장 (end-to-end)
#
# 호영님 요청 4·6 — 한 셀에서 데이터 정제 → 예측 → DB 저장까지 일괄 수행.
#
# `SINGLE_TICKER` 만 수정하시면 됩니다.

# %%
# ─── 입력 ────────────────────────────────────────────────────
SINGLE_TICKER = "LLY"           # ← 실행할 ticker
SINGLE_MODELS = ALL_MODELS       # ← 또는 ["SARIMA","ETS","Theta"] (빠른 실행)
SAVE_TO_DB    = True             # ← False 로 두면 dry-run

print(f"{'='*72}")
print(f"[Single Ticker End-to-End] {SINGLE_TICKER}")
print(f"  Models: {SINGLE_MODELS}")
print(f"  Save to DB: {SAVE_TO_DB}")
print(f"{'='*72}\n")

# ─── Step 1: 매출 데이터 정제 (Quality + Override 통합) ──────
print("[Step 1] 매출 데이터 정제 ...")
src_df = fetch_financial_series(
    engine, SINGLE_TICKER, item=ITEM, min_obs=MIN_OBS,
    strict_dup_check=True, fallback_to_as_reported=True, verbose=True,
)
print(f"  → {len(src_df)} 분기 정제 완료\n")

# ─── Step 2: 시계열 변환 ─────────────────────────────────────
y = src_df.set_index("date")["value"].copy()
y.index = pd.DatetimeIndex(y.index)
y.name  = ITEM

# ─── Step 3: 예측 ────────────────────────────────────────────
print(f"[Step 2] 예측 ({SINGLE_MODELS}) ...")
fc_results = forecast_one_ticker(y, SINGLE_TICKER, HORIZON, SINGLE_MODELS)

# ─── Step 4: 예측 인덱스 ─────────────────────────────────────
fc_index = make_forecast_index(y.index[-1], HORIZON)

print(f"\n[예측 결과 요약]")
for m, res in fc_results.items():
    if "error" in res:
        print(f"  {m:<10}: ERROR → {res['error'][:80]}")
    else:
        fc = np.asarray(res["forecast"])
        print(f"  {m:<10}: 첫값={fc[0]/1e6:.1f}M  마지막={fc[-1]/1e6:.1f}M")

# ─── Step 5: Long-format 변환 ────────────────────────────────
long_df = build_long_df(
    ticker=SINGLE_TICKER, item=ITEM, src_df=src_df,
    forecast_results=fc_results, forecast_index=fc_index,
    forecast_date=FORECAST_DATE,
)
print(f"\n[Step 3] Long-format: {len(long_df)} 행 (actual + forecast + Ensemble)")

# ─── Step 6: DB 저장 ─────────────────────────────────────────
if SAVE_TO_DB:
    ensure_table(engine)
    affected = save_to_db(engine, long_df)
    print(f"\n[Step 4] DB 저장 완료 — affected rows: {affected} (input: {len(long_df)})")
    print(f"     ※ MySQL: INSERT=1, UPDATE=2, no-change=0 의 합. >0 이면 DB 변경 발생.")
else:
    print(f"\n[Step 4] dry-run mode — DB 저장 스킵")

# ─── 검증 표시 ───────────────────────────────────────────────
print(f"\n{'='*72}")
print(f"[검증] 마지막 actual 분기 + 첫 forecast 분기")
print(f"{'='*72}")
sample = long_df[long_df["model"].isin(["actual","Ensemble","SARIMA"])].tail(20)
display(sample[["date","data_type","model","value"]])
# Out:
# ========================================================================
# [Single Ticker End-to-End] LLY
#   Models: ['SARIMA', 'ETS', 'Prophet', 'LSTM', 'Theta']
#   Save to DB: True
# ========================================================================
#
# [Step 1] 매출 데이터 정제 ...
#   → 40 분기 정제 완료
#
# [Step 2] 예측 (['SARIMA', 'ETS', 'Prophet', 'LSTM', 'Theta']) ...
# [LLY]   [SARIMA] 시작  (메모리: 1469.8 MB)
# [메모리] forecast_sarima 실행 전: 1469.79 MB
# [메모리] find_best_sarima_params 실행 전: 1469.79 MB
# [메모리] find_best_sarima_params 실행 후: 1476.63 MB (변화: +6.84 MB)
# [메모리] forecast_sarima 실행 후: 1476.63 MB (변화: +6.84 MB)
# [LLY]   [SARIMA] 완료  첫값=2.28e+10 마지막=3.03e+10
# [LLY]   [ETS] 시작  (메모리: 1476.6 MB)
# [메모리] forecast_ets 실행 전: 1476.63 MB
# [메모리] forecast_ets 실행 후: 1476.63 MB (변화: +0.00 MB)
# [LLY]   [ETS] 완료  첫값=2.68e+10 마지막=5.51e+10
# [LLY]   [Prophet] 시작  (메모리: 1476.6 MB)
# [메모리] forecast_prophet 실행 전: 1476.63 MB
# 08:08:00 - cmdstanpy - INFO - Chain [1] start processing
# 08:08:00 - cmdstanpy - INFO - Chain [1] done processing
# [메모리] forecast_prophet 실행 후: 1478.21 MB (변화: +1.59 MB)
# [LLY]   [Prophet] 완료  첫값=2.38e+10 마지막=3.36e+10
# [LLY]   [LSTM] 시작  (메모리: 1478.2 MB)
# [메모리] forecast_lstm 실행 전: 1478.21 MB
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# [메모리] forecast_lstm 실행 후: 1484.56 MB (변화: +6.34 MB)
# [LLY]   [LSTM] 완료  첫값=3.00e+10 마지막=2.51e+12
# [LLY]   [Theta] 시작  (메모리: 1484.6 MB)
# [메모리] forecast_theta 실행 전: 1484.56 MB
# [메모리] forecast_theta 실행 후: 1484.56 MB (변화: +0.00 MB)
# [LLY]   [Theta] 완료  첫값=2.27e+10 마지막=2.54e+10
#
# [예측 결과 요약]
#   SARIMA    : 첫값=22841.4M  마지막=30272.5M
#   ETS       : 첫값=26802.1M  마지막=55056.7M
#   Prophet   : 첫값=23836.9M  마지막=33647.8M
#   LSTM      : 첫값=30031.1M  마지막=2505764.2M
#   Theta     : 첫값=22702.7M  마지막=25397.4M
#
# [Step 3] Long-format: 88 행 (actual + forecast + Ensemble)
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pymysql\connections.py:616, in Connection.connect(self, sock)
#     615 try:
# --> 616     sock = socket.create_connection(
#     617         (self.host, self.port), self.connect_timeout, **kwargs
#     618     )
#     619     break
#
# File ~\AppData\Local\Programs\Python\Python39\lib\socket.py:844, in create_connection(address, timeout, source_address)
#     843 try:
# --> 844     raise err
#     845 finally:
#     846     # Break explicitly a reference cycle
#
# File ~\AppData\Local\Programs\Python\Python39\lib\socket.py:832, in create_connection(address, timeout, source_address)
#     831     sock.bind(source_address)
# --> 832 sock.connect(sa)
#     833 # Break explicitly a reference cycle
#
# ConnectionRefusedError: [WinError 10061] 대상 컴퓨터에서 연결을 거부했으므로 연결하지 못했습니다
#
# During handling of the above exception, another exception occurred:
#
# OperationalError                          Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\sqlalchemy\engine\base.py:145, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     144 try:
# --> 145     self._dbapi_connection = engine.raw_connection()
#     146 except dialect.loaded_dbapi.Error as err:
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\sqlalchemy\engine\base.py:3293, in Engine.raw_connection(self)
#    3272 """Return a "raw" DBAPI connection from the connection pool.
#    3273
#    3274 The returned object is a proxied version of the DBAPI
#    (...)
#    3291
#    3292 """
# -> 3293 return self.pool.connect()
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\sqlalchemy\pool\base.py:452, in Pool.connect(self)
#     445 """Return a DBAPI connection from the pool.
#     446
#     447 The connection is instrumented such that when its
#    (...)
#     450
#     451 """
# --> 452 return _ConnectionFairy._checkout(self)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\sqlalchemy\pool\base.py:1268, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#    1267 if not fairy:
# -> 1268     fairy = _ConnectionRecord.checkout(pool)
#    1270     if threadconns is not None:
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\sqlalchemy\pool\base.py:716, in _ConnectionRecord.checkout(cls, pool)
#     715 else:
# --> 716     rec = pool._do_get()
#     718 try:
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\sqlalchemy\pool\impl.py:169, in QueuePool._do_get(self)
#     168 with util.safe_reraise():
# --> 169     self._dec_overflow()
#     170 raise
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\sqlalchemy\util\langhelpers.py:147, in safe_reraise.__exit__(self, type_, value, traceback)
#     146     self._exc_info = None  # remove potential circular references
# --> 147     raise exc_value.with_traceback(exc_tb)
#     148 else:
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\sqlalchemy\pool\impl.py:166, in QueuePool._do_get(self)
#     165 try:
# --> 166     return self._create_connection()
#     167 except:
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\sqlalchemy\pool\base.py:393, in Pool._create_connection(self)
#     391 """Called by subclasses to create a new ConnectionRecord."""
# --> 393 return _ConnectionRecord(self)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\sqlalchemy\pool\base.py:678, in _ConnectionRecord.__init__(self, pool, connect)
#     677 if connect:
# --> 678     self.__connect()
#     679 self.finalize_callback = deque()
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\sqlalchemy\pool\base.py:903, in _ConnectionRecord.__connect(self)
#     902     with util.safe_reraise():
# --> 903         pool.logger.debug("Error on connect(): %s", e)
#     904 else:
#     905     # in SQLAlchemy 1.4 the first_connect event is not used by
#     906     # the engine, so this will usually not be set
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\sqlalchemy\util\langhelpers.py:147, in safe_reraise.__exit__(self, type_, value, traceback)
#     146     self._exc_info = None  # remove potential circular references
# --> 147     raise exc_value.with_traceback(exc_tb)
#     148 else:
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\sqlalchemy\pool\base.py:898, in _ConnectionRecord.__connect(self)
#     897 self.starttime = time.time()
# --> 898 self.dbapi_connection = connection = pool._invoke_creator(self)
#     899 pool.logger.debug("Created new connection %r", connection)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\sqlalchemy\engine\create.py:637, in create_engine.<locals>.connect(connection_record)
#     635             return connection
# --> 637 return dialect.connect(*cargs, **cparams)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\sqlalchemy\engine\default.py:616, in DefaultDialect.connect(self, *cargs, **cparams)
#     614 def connect(self, *cargs, **cparams):
#     615     # inherits the docstring from interfaces.Dialect.connect
# --> 616     return self.loaded_dbapi.connect(*cargs, **cparams)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pymysql\connections.py:352, in Connection.__init__(self, user, password, host, database, unix_socket, port, charset, sql_mode, read_default_file, conv, use_unicode, client_flag, cursorclass, init_command, connect_timeout, read_default_group, autocommit, local_infile, max_allowed_packet, defer_connect, auth_plugin_map, read_timeout, write_timeout, bind_address, binary_prefix, program_name, server_public_key, ssl, ssl_ca, ssl_cert, ssl_disabled, ssl_key, ssl_verify_cert, ssl_verify_identity, compress, named_pipe, passwd, db)
#     351 else:
# --> 352     self.connect()
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pymysql\connections.py:668, in Connection.connect(self, sock)
#     667         print(exc.traceback)
# --> 668     raise exc
#     670 # If e is neither DatabaseError or IOError, It's a bug.
#     671 # But raising AssertionError hides original error.
#     672 # So just reraise it.
#
# OperationalError: (2003, "Can't connect to MySQL server on '192.168.0.230' ([WinError 10061] 대상 컴퓨터에서 연결을 거부했으므로 연결하지 못했습니다)")
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# Cell In[10], line 50
#      48 # ─── Step 6: DB 저장 ─────────────────────────────────────────
#      49 if SAVE_TO_DB:
# ---> 50     ensure_table(engine)
#      51     affected = save_to_db(engine, long_df)
#      52     print(f"\n[Step 4] DB 저장 완료 — affected rows: {affected} (input: {len(long_df)})")
#
# Cell In[8], line 113, in ensure_table(engine)
#     112 def ensure_table(engine):
# --> 113     with engine.begin() as conn:
#     114         conn.execute(text(CREATE_TABLE_SQL))
#
# File ~\AppData\Local\Programs\Python\Python39\lib\contextlib.py:119, in _GeneratorContextManager.__enter__(self)
#     117 del self.args, self.kwds, self.func
#     118 try:
# --> 119     return next(self.gen)
#     120 except StopIteration:
#     121     raise RuntimeError("generator didn't yield") from None
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\sqlalchemy\engine\base.py:3233, in Engine.begin(self)
#    3206 @contextlib.contextmanager
#    3207 def begin(self) -> Iterator[Connection]:
#    3208     """Return a context manager delivering a :class:`_engine.Connection`
#    3209     with a :class:`.Transaction` established.
#    3210
#    (...)
#    3231
#    3232     """
# -> 3233     with self.connect() as conn:
#    3234         with conn.begin():
#    3235             yield conn
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\sqlalchemy\engine\base.py:3269, in Engine.connect(self)
#    3246 def connect(self) -> Connection:
#    3247     """Return a new :class:`_engine.Connection` object.
#    3248
#    3249     The :class:`_engine.Connection` acts as a Python context manager, so
#    (...)
#    3266
#    3267     """
# -> 3269     return self._connection_cls(self)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\sqlalchemy\engine\base.py:147, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     145         self._dbapi_connection = engine.raw_connection()
#     146     except dialect.loaded_dbapi.Error as err:
# --> 147         Connection._handle_dbapi_exception_noconnection(
#     148             err, dialect, engine
#     149         )
#     150         raise
#     151 else:
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\sqlalchemy\engine\base.py:2431, in Connection._handle_dbapi_exception_noconnection(cls, e, dialect, engine, is_disconnect, invalidate_pool_on_disconnect, is_pre_ping)
#    2429 elif should_wrap:
#    2430     assert sqlalchemy_exception is not None
# -> 2431     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2432 else:
#    2433     assert exc_info[1] is not None
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\sqlalchemy\engine\base.py:145, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     143 if connection is None:
#     144     try:
# --> 145         self._dbapi_connection = engine.raw_connection()
#     146     except dialect.loaded_dbapi.Error as err:
#     147         Connection._handle_dbapi_exception_noconnection(
#     148             err, dialect, engine
#     149         )
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\sqlalchemy\engine\base.py:3293, in Engine.raw_connection(self)
#    3271 def raw_connection(self) -> PoolProxiedConnection:
#    3272     """Return a "raw" DBAPI connection from the connection pool.
#    3273
#    3274     The returned object is a proxied version of the DBAPI
#    (...)
#    3291
#    3292     """
# -> 3293     return self.pool.connect()
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\sqlalchemy\pool\base.py:452, in Pool.connect(self)
#     444 def connect(self) -> PoolProxiedConnection:
#     445     """Return a DBAPI connection from the pool.
#     446
#     447     The connection is instrumented such that when its
#    (...)
#     450
#     451     """
# --> 452     return _ConnectionFairy._checkout(self)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\sqlalchemy\pool\base.py:1268, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#    1259 @classmethod
#    1260 def _checkout(
#    1261     cls,
#    (...)
#    1264     fairy: Optional[_ConnectionFairy] = None,
#    1265 ) -> _ConnectionFairy:
#    1267     if not fairy:
# -> 1268         fairy = _ConnectionRecord.checkout(pool)
#    1270         if threadconns is not None:
#    1271             threadconns.current = weakref.ref(fairy)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\sqlalchemy\pool\base.py:716, in _ConnectionRecord.checkout(cls, pool)
#     714     rec = cast(_ConnectionRecord, pool._do_get())
#     715 else:
# --> 716     rec = pool._do_get()
#     718 try:
#     719     dbapi_connection = rec.get_connection()
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\sqlalchemy\pool\impl.py:169, in QueuePool._do_get(self)
#     167     except:
#     168         with util.safe_reraise():
# --> 169             self._dec_overflow()
#     170         raise
#     171 else:
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\sqlalchemy\util\langhelpers.py:147, in safe_reraise.__exit__(self, type_, value, traceback)
#     145     assert exc_value is not None
#     146     self._exc_info = None  # remove potential circular references
# --> 147     raise exc_value.with_traceback(exc_tb)
#     148 else:
#     149     self._exc_info = None  # remove potential circular references
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\sqlalchemy\pool\impl.py:166, in QueuePool._do_get(self)
#     164 if self._inc_overflow():
#     165     try:
# --> 166         return self._create_connection()
#     167     except:
#     168         with util.safe_reraise():
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\sqlalchemy\pool\base.py:393, in Pool._create_connection(self)
#     390 def _create_connection(self) -> ConnectionPoolEntry:
#     391     """Called by subclasses to create a new ConnectionRecord."""
# --> 393     return _ConnectionRecord(self)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\sqlalchemy\pool\base.py:678, in _ConnectionRecord.__init__(self, pool, connect)
#     676 self.__pool = pool
#     677 if connect:
# --> 678     self.__connect()
#     679 self.finalize_callback = deque()
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\sqlalchemy\pool\base.py:903, in _ConnectionRecord.__connect(self)
#     901 except BaseException as e:
#     902     with util.safe_reraise():
# --> 903         pool.logger.debug("Error on connect(): %s", e)
#     904 else:
#     905     # in SQLAlchemy 1.4 the first_connect event is not used by
#     906     # the engine, so this will usually not be set
#     907     if pool.dispatch.first_connect:
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\sqlalchemy\util\langhelpers.py:147, in safe_reraise.__exit__(self, type_, value, traceback)
#     145     assert exc_value is not None
#     146     self._exc_info = None  # remove potential circular references
# --> 147     raise exc_value.with_traceback(exc_tb)
#     148 else:
#     149     self._exc_info = None  # remove potential circular references
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\sqlalchemy\pool\base.py:898, in _ConnectionRecord.__connect(self)
#     896 try:
#     897     self.starttime = time.time()
# --> 898     self.dbapi_connection = connection = pool._invoke_creator(self)
#     899     pool.logger.debug("Created new connection %r", connection)
#     900     self.fresh = True
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\sqlalchemy\engine\create.py:637, in create_engine.<locals>.connect(connection_record)
#     634         if connection is not None:
#     635             return connection
# --> 637 return dialect.connect(*cargs, **cparams)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\sqlalchemy\engine\default.py:616, in DefaultDialect.connect(self, *cargs, **cparams)
#     614 def connect(self, *cargs, **cparams):
#     615     # inherits the docstring from interfaces.Dialect.connect
# --> 616     return self.loaded_dbapi.connect(*cargs, **cparams)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pymysql\connections.py:352, in Connection.__init__(self, user, password, host, database, unix_socket, port, charset, sql_mode, read_default_file, conv, use_unicode, client_flag, cursorclass, init_command, connect_timeout, read_default_group, autocommit, local_infile, max_allowed_packet, defer_connect, auth_plugin_map, read_timeout, write_timeout, bind_address, binary_prefix, program_name, server_public_key, ssl, ssl_ca, ssl_cert, ssl_disabled, ssl_key, ssl_verify_cert, ssl_verify_identity, compress, named_pipe, passwd, db)
#     350     self._sock = None
#     351 else:
# --> 352     self.connect()
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pymysql\connections.py:668, in Connection.connect(self, sock)
#     666     if DEBUG:
#     667         print(exc.traceback)
# --> 668     raise exc
#     670 # If e is neither DatabaseError or IOError, It's a bug.
#     671 # But raising AssertionError hides original error.
#     672 # So just reraise it.
#     673 raise
#
# OperationalError: (pymysql.err.OperationalError) (2003, "Can't connect to MySQL server on '192.168.0.230' ([WinError 10061] 대상 컴퓨터에서 연결을 거부했으므로 연결하지 못했습니다)")
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %% [markdown]
# ## Cell 10 · 전체 배치 실행 (Override 종목 처리 옵션)
#
# **호영님 요청 5** — Override 종목을 batch 에서 어떻게 다룰지 옵션 선택:
#
# | `BATCH_MODE` | 동작 |
# |---|---|
# | `"all"` | Override 종목 포함 전체 실행 (override 적용된 데이터로 예측) |
# | `"exclude_overrides"` | **Override 종목 제외** — 기본값. Override 종목은 별도로 Cell 9 에서 검토·실행 권장 |
# | `"overrides_only"` | Override 종목만 별도 배치 실행 |
#
# `RUN_TICKERS` 가 지정되면 그 안에서 모드 적용. None 이면 `DEFAULT_TICKER_LIST[TICKER_START:TICKER_END]` 사용.

# %%
# ════════════════════════════════════════════════════════════
#  배치 설정 — 여기를 수정
# ════════════════════════════════════════════════════════════

# ── Override 종목 처리 모드 ───────────────────────────────────
BATCH_MODE = "exclude_overrides"   # "all" / "exclude_overrides" / "overrides_only"

# ── 특정 티커 지정 (None 이면 아래 구간/전체 사용) ────────────
RUN_TICKERS  = None                # type: Optional[list]
# RUN_TICKERS = ["STRL", "APH", "FIX"]

# ── 전체 리스트 구간 (RUN_TICKERS=None 일 때) ─────────────────
TICKER_START = 0
TICKER_END   = 2000

# ── 모델 / 항목 / 예측 기간 ───────────────────────────────────
RUN_MODELS  = ["SARIMA", "ETS", "Theta"]    # 또는 ALL_MODELS
RUN_ITEM    = ITEM
RUN_HORIZON = HORIZON
RUN_MIN_OBS = MIN_OBS

# ════════════════════════════════════════════════════════════
#  실행 대상 티커 목록 결정
# ════════════════════════════════════════════════════════════
if RUN_TICKERS is not None:
    base_tickers = RUN_TICKERS
    print(f"[모드] 특정 티커 지정 (총 {len(base_tickers)}개)")
else:
    base_tickers = DEFAULT_TICKER_LIST[TICKER_START:TICKER_END]
    print(f"[모드] 구간 실행: index {TICKER_START} ~ {TICKER_END-1} ({len(base_tickers)}개)")

# Override 처리 모드 적용
if BATCH_MODE == "exclude_overrides":
    tickers  = [t for t in base_tickers if t.upper() not in OVERRIDE_TICKERS]
    excluded = [t for t in base_tickers if t.upper() in OVERRIDE_TICKERS]
    print(f"[Override 처리] EXCLUDE — {len(excluded)} 종목 제외, {len(tickers)} 종목 실행")
    if excluded:
        print(f"   제외된 override 종목: {excluded}")
        print(f"   → Cell 9 에서 개별 실행 권장")
elif BATCH_MODE == "overrides_only":
    tickers = [t for t in base_tickers if t.upper() in OVERRIDE_TICKERS]
    print(f"[Override 처리] OVERRIDES_ONLY — override {len(tickers)} 종목만 실행")
elif BATCH_MODE == "all":
    tickers = base_tickers
    print(f"[Override 처리] ALL — 전체 {len(tickers)} 종목 실행 (override 적용)")
else:
    raise ValueError(f"알 수 없는 BATCH_MODE: {BATCH_MODE}")

total = len(tickers)
if total == 0:
    print("\n[INFO] 실행할 ticker 없음. 종료.")
else:
    # ════════════════════════════════════════════════════════════
    #  배치 실행
    # ════════════════════════════════════════════════════════════
    ensure_table(engine)

    success, skipped, errored, neg_skipped = 0, 0, 0, 0
    skip_list, error_list, neg_skip_list   = [], [], []

    log("BATCH", "=" * 70)
    log("BATCH", f"시작 | {total}개 | mode={BATCH_MODE} | 항목={RUN_ITEM} | 예측={RUN_HORIZON}분기")
    log("BATCH", f"모델 : {RUN_MODELS}  |  예측일: {FORECAST_DATE}  |  min_obs: {RUN_MIN_OBS}")
    log("BATCH", "=" * 70)

    for i, ticker in enumerate(tickers, 1):
        pct = i / total * 100
        log("PROGRESS", f"[{i:>4}/{total}] ({pct:5.1f}%)  >>  {ticker}")

        # Step 1: 데이터 추출 (override 자동 적용)
        try:
            _src_df = fetch_financial_series(engine, ticker, RUN_ITEM, RUN_MIN_OBS)
        except ValueError as e:
            err_msg = str(e)
            if "음수 매출" in err_msg:
                log(ticker, f"[NEG-SKIP] {err_msg}")
                neg_skipped += 1; neg_skip_list.append(ticker)
            else:
                log(ticker, f"[SKIP] {err_msg}")
                skipped += 1; skip_list.append(ticker)
            continue
        except Exception as e:
            log(ticker, f"[SKIP] {e}")
            skipped += 1; skip_list.append(ticker)
            continue

        _y = _src_df.set_index("date")["value"].copy()
        _y.index = pd.DatetimeIndex(_y.index); _y.name = RUN_ITEM
        log(ticker, f"  {len(_y)}분기 | {_y.index[0].date()} ~ {_y.index[-1].date()}")

        # Step 2: 예측
        try:
            _fc_results = forecast_one_ticker(_y, ticker, RUN_HORIZON, RUN_MODELS)
        except Exception as e:
            log(ticker, f"[ERROR] 예측: {e}")
            errored += 1; error_list.append(ticker)
            del _src_df, _y; clear_memory(); continue

        # Step 3: 예측 인덱스
        _fc_index = make_forecast_index(_y.index[-1], RUN_HORIZON)

        # Step 4: Long-format
        try:
            _ldf = build_long_df(
                ticker=ticker, item=RUN_ITEM, src_df=_src_df,
                forecast_results=_fc_results, forecast_index=_fc_index,
                forecast_date=FORECAST_DATE,
            )
        except Exception as e:
            log(ticker, f"[ERROR] Long-format: {e}")
            errored += 1; error_list.append(ticker)
            del _src_df, _y, _fc_results; clear_memory(); continue

        # Step 5: DB 저장
        try:
            save_to_db(engine, _ldf)
            success += 1
        except Exception as e:
            log(ticker, f"[ERROR] DB 저장: {e}")
            errored += 1; error_list.append(ticker)

        del _src_df, _y, _fc_results, _ldf
        clear_memory()

    # ── 요약 ──────────────────────────────────────────────────
    log("BATCH", "=" * 70)
    log("BATCH", f"완료 | 성공: {success}  데이터스킵: {skipped}  음수제외: {neg_skipped}  오류: {errored}  합계: {total}")
    if skip_list:     log("BATCH", f"데이터스킵  : {skip_list[:30]}{'...' if len(skip_list)>30 else ''}")
    if neg_skip_list: log("BATCH", f"음수제외   : {neg_skip_list}")
    if error_list:    log("BATCH", f"오류       : {error_list[:30]}{'...' if len(error_list)>30 else ''}")
    log("BATCH", "=" * 70)

    if BATCH_MODE == "exclude_overrides" and excluded:
        log("BATCH", f"※ 다음 override 종목은 본 배치에서 제외됨 — Cell 9 에서 개별 처리 필요:")
        log("BATCH", f"   {excluded}")
# Out:
# [모드] 구간 실행: index 0 ~ 1999 (2000개)
# [Override 처리] EXCLUDE — 1 종목 제외, 1999 종목 실행
#    제외된 override 종목: ['SIMO']
#    → Cell 9 에서 개별 실행 권장
# [BATCH] ======================================================================
# [BATCH] 시작 | 1999개 | mode=exclude_overrides | 항목=sale | 예측=8분기
# [BATCH] 모델 : ['SARIMA', 'ETS', 'Theta']  |  예측일: 2026-09-05  |  min_obs: 28
# [BATCH] ======================================================================
# [PROGRESS] [   1/1999] (  0.1%)  >>  NVDA
# [NVDA]   40분기 | 2016-10-30 ~ 2026-07-26
# [NVDA]   [SARIMA] 시작  (메모리: 1485.7 MB)
# [메모리] forecast_sarima 실행 전: 1485.70 MB
# [메모리] find_best_sarima_params 실행 전: 1485.70 MB
# [메모리] find_best_sarima_params 실행 후: 1496.93 MB (변화: +11.23 MB)
# [메모리] forecast_sarima 실행 후: 1496.93 MB (변화: +11.23 MB)
# [NVDA]   [SARIMA] 완료  첫값=1.09e+11 마지막=2.38e+11
# [NVDA]   [ETS] 시작  (메모리: 1496.9 MB)
# [메모리] forecast_ets 실행 전: 1496.93 MB
# [메모리] forecast_ets 실행 후: 1496.93 MB (변화: +0.00 MB)
# [NVDA]   [ETS] 완료  첫값=1.28e+11 마지막=2.83e+11
# [NVDA]   [Theta] 시작  (메모리: 1496.9 MB)
# [메모리] forecast_theta 실행 전: 1496.93 MB
# [메모리] forecast_theta 실행 후: 1496.93 MB (변화: +0.00 MB)
# [NVDA]   [Theta] 완료  첫값=1.01e+11 마지막=1.42e+11
# [PROGRESS] [   2/1999] (  0.1%)  >>  GOOG
# [GOOG]   40분기 | 2016-09-30 ~ 2026-06-30
# [GOOG]   [SARIMA] 시작  (메모리: 1496.9 MB)
# [메모리] forecast_sarima 실행 전: 1496.95 MB
# [메모리] find_best_sarima_params 실행 전: 1496.95 MB
# [메모리] find_best_sarima_params 실행 후: 1496.95 MB (변화: +0.00 MB)
# [메모리] forecast_sarima 실행 후: 1496.95 MB (변화: +0.00 MB)
# [GOOG]   [SARIMA] 완료  첫값=1.18e+11 마지막=1.71e+11
# [GOOG]   [ETS] 시작  (메모리: 1496.9 MB)
# [메모리] forecast_ets 실행 전: 1496.95 MB
# [메모리] forecast_ets 실행 후: 1496.95 MB (변화: +0.00 MB)
# [GOOG]   [ETS] 완료  첫값=1.32e+11 마지막=1.82e+11
# [GOOG]   [Theta] 시작  (메모리: 1496.9 MB)
# [메모리] forecast_theta 실행 전: 1496.95 MB
# [메모리] forecast_theta 실행 후: 1496.95 MB (변화: +0.00 MB)
# [GOOG]   [Theta] 완료  첫값=1.22e+11 마지막=1.41e+11
# [PROGRESS] [   3/1999] (  0.2%)  >>  AAPL
# [AAPL]   40분기 | 2016-09-24 ~ 2026-06-27
# [AAPL]   [SARIMA] 시작  (메모리: 1496.9 MB)
# [메모리] forecast_sarima 실행 전: 1496.95 MB
# [메모리] find_best_sarima_params 실행 전: 1496.95 MB
# [메모리] find_best_sarima_params 실행 후: 1497.30 MB (변화: +0.36 MB)
# [메모리] forecast_sarima 실행 후: 1497.30 MB (변화: +0.36 MB)
# [AAPL]   [SARIMA] 완료  첫값=1.18e+11 마지막=1.30e+11
# [AAPL]   [ETS] 시작  (메모리: 1497.3 MB)
# [메모리] forecast_ets 실행 전: 1497.30 MB
# [메모리] forecast_ets 실행 후: 1497.30 MB (변화: +0.00 MB)
# [AAPL]   [ETS] 완료  첫값=1.16e+11 마지막=1.29e+11
# [AAPL]   [Theta] 시작  (메모리: 1497.3 MB)
# [메모리] forecast_theta 실행 전: 1497.30 MB
# [메모리] forecast_theta 실행 후: 1497.30 MB (변화: +0.00 MB)
# [AAPL]   [Theta] 완료  첫값=1.14e+11 마지막=1.22e+11
# [PROGRESS] [   4/1999] (  0.2%)  >>  MSFT
# [MSFT]   40분기 | 2016-09-30 ~ 2026-06-30
# [MSFT]   [SARIMA] 시작  (메모리: 1497.3 MB)
# [메모리] forecast_sarima 실행 전: 1497.30 MB
# [메모리] find_best_sarima_params 실행 전: 1497.30 MB
# [메모리] find_best_sarima_params 실행 후: 1497.30 MB (변화: +0.00 MB)
# [메모리] forecast_sarima 실행 후: 1497.30 MB (변화: +0.00 MB)
# [MSFT]   [SARIMA] 완료  첫값=9.10e+10 마지막=1.19e+11
# [MSFT]   [ETS] 시작  (메모리: 1497.3 MB)
# [메모리] forecast_ets 실행 전: 1497.30 MB
# [메모리] forecast_ets 실행 후: 1497.30 MB (변화: +0.00 MB)
# [MSFT]   [ETS] 완료  첫값=8.64e+10 마지막=1.19e+11
# [MSFT]   [Theta] 시작  (메모리: 1497.3 MB)
# [메모리] forecast_theta 실행 전: 1497.30 MB
# [메모리] forecast_theta 실행 후: 1497.30 MB (변화: +0.00 MB)
# [MSFT]   [Theta] 완료  첫값=9.03e+10 마지막=1.02e+11
# [PROGRESS] [   5/1999] (  0.3%)  >>  AMZN
# [AMZN]   40분기 | 2016-09-30 ~ 2026-06-30
# [AMZN]   [SARIMA] 시작  (메모리: 1497.3 MB)
# [메모리] forecast_sarima 실행 전: 1497.31 MB
# [메모리] find_best_sarima_params 실행 전: 1497.31 MB
# [메모리] find_best_sarima_params 실행 후: 1497.31 MB (변화: +0.00 MB)
# [메모리] forecast_sarima 실행 후: 1497.31 MB (변화: +0.00 MB)
# [AMZN]   [SARIMA] 완료  첫값=2.12e+11 마지막=2.34e+11
# [AMZN]   [ETS] 시작  (메모리: 1497.3 MB)
# [메모리] forecast_ets 실행 전: 1497.31 MB
# [메모리] forecast_ets 실행 후: 1497.31 MB (변화: +0.00 MB)
# [AMZN]   [ETS] 완료  첫값=2.17e+11 마지막=2.66e+11
# [AMZN]   [Theta] 시작  (메모리: 1497.3 MB)
# [메모리] forecast_theta 실행 전: 1497.31 MB
# [메모리] forecast_theta 실행 후: 1497.31 MB (변화: +0.00 MB)
# [AMZN]   [Theta] 완료  첫값=2.03e+11 마지막=2.36e+11
# [PROGRESS] [   6/1999] (  0.3%)  >>  TSM
# [TSM]   40분기 | 2016-09-30 ~ 2026-06-30
# [TSM]   [SARIMA] 시작  (메모리: 1497.3 MB)
# [메모리] forecast_sarima 실행 전: 1497.31 MB
# [메모리] find_best_sarima_params 실행 전: 1497.31 MB
# [메모리] find_best_sarima_params 실행 후: 1497.31 MB (변화: +0.00 MB)
# [메모리] forecast_sarima 실행 후: 1497.31 MB (변화: +0.00 MB)
# [TSM]   [SARIMA] 완료  첫값=1.32e+12 마지막=1.28e+12
# [TSM]   [ETS] 시작  (메모리: 1497.3 MB)
# [메모리] forecast_ets 실행 전: 1497.31 MB
# [메모리] forecast_ets 실행 후: 1497.31 MB (변화: +0.00 MB)
# [TSM]   [ETS] 완료  첫값=1.51e+12 마지막=2.40e+12
# [TSM]   [Theta] 시작  (메모리: 1497.3 MB)
# [메모리] forecast_theta 실행 전: 1497.31 MB
# [메모리] forecast_theta 실행 후: 1497.31 MB (변화: +0.00 MB)
# [TSM]   [Theta] 완료  첫값=1.30e+12 마지막=1.51e+12
# [PROGRESS] [   7/1999] (  0.4%)  >>  META
# [META]   40분기 | 2016-09-30 ~ 2026-06-30
# [META]   [SARIMA] 시작  (메모리: 1497.3 MB)
# [메모리] forecast_sarima 실행 전: 1497.31 MB
# [메모리] find_best_sarima_params 실행 전: 1497.31 MB
# [메모리] find_best_sarima_params 실행 후: 1497.32 MB (변화: +0.00 MB)
# [메모리] forecast_sarima 실행 후: 1497.32 MB (변화: +0.00 MB)
# [META]   [SARIMA] 완료  첫값=6.58e+10 마지막=8.87e+10
# [META]   [ETS] 시작  (메모리: 1497.3 MB)
# [메모리] forecast_ets 실행 전: 1497.32 MB
# [메모리] forecast_ets 실행 후: 1497.32 MB (변화: +0.00 MB)
# [META]   [ETS] 완료  첫값=6.79e+10 마지막=1.06e+11
# [META]   [Theta] 시작  (메모리: 1497.3 MB)
# [메모리] forecast_theta 실행 전: 1497.32 MB
# [메모리] forecast_theta 실행 후: 1497.32 MB (변화: +0.00 MB)
# [META]   [Theta] 완료  첫값=6.19e+10 마지막=7.35e+10
# [PROGRESS] [   8/1999] (  0.4%)  >>  AVGO
# [AVGO]   40분기 | 2016-10-31 ~ 2026-08-02
# [AVGO]   [SARIMA] 시작  (메모리: 1497.3 MB)
# [메모리] forecast_sarima 실행 전: 1497.32 MB
# [메모리] find_best_sarima_params 실행 전: 1497.32 MB
# [메모리] find_best_sarima_params 실행 후: 1497.32 MB (변화: +0.00 MB)
# [메모리] forecast_sarima 실행 후: 1497.32 MB (변화: +0.00 MB)
# [AVGO]   [SARIMA] 완료  첫값=3.12e+10 마지막=4.57e+10
# [AVGO]   [ETS] 시작  (메모리: 1497.3 MB)
# [메모리] forecast_ets 실행 전: 1497.32 MB
# [메모리] forecast_ets 실행 후: 1497.32 MB (변화: +0.00 MB)
# [AVGO]   [ETS] 완료  첫값=3.86e+10 마지막=1.72e+11
# [AVGO]   [Theta] 시작  (메모리: 1497.3 MB)
# [메모리] forecast_theta 실행 전: 1497.32 MB
# [메모리] forecast_theta 실행 후: 1497.32 MB (변화: +0.00 MB)
# [AVGO]   [Theta] 완료  첫값=3.02e+10 마지막=3.50e+10
# [PROGRESS] [   9/1999] (  0.5%)  >>  TSLA
# [TSLA]   40분기 | 2016-09-30 ~ 2026-06-30
# [TSLA]   [SARIMA] 시작  (메모리: 1497.3 MB)
# [메모리] forecast_sarima 실행 전: 1497.32 MB
# [메모리] find_best_sarima_params 실행 전: 1497.32 MB
# [메모리] find_best_sarima_params 실행 후: 1497.32 MB (변화: +0.00 MB)
# [메모리] forecast_sarima 실행 후: 1497.32 MB (변화: +0.00 MB)
# [TSLA]   [SARIMA] 완료  첫값=3.01e+10 마지막=4.79e+10
# [TSLA]   [ETS] 시작  (메모리: 1497.3 MB)
# [메모리] forecast_ets 실행 전: 1497.32 MB
# [메모리] forecast_ets 실행 후: 1497.32 MB (변화: +0.00 MB)
# [TSLA]   [ETS] 완료  첫값=3.07e+10 마지막=4.86e+10
# [TSLA]   [Theta] 시작  (메모리: 1497.3 MB)
# [메모리] forecast_theta 실행 전: 1497.32 MB
# [메모리] forecast_theta 실행 후: 1497.32 MB (변화: +0.00 MB)
# [TSLA]   [Theta] 완료  첫값=2.89e+10 마지막=3.67e+10
# [PROGRESS] [  10/1999] (  0.5%)  >>  LLY
# [LLY]   40분기 | 2016-09-30 ~ 2026-06-30
# [LLY]   [SARIMA] 시작  (메모리: 1497.3 MB)
# [메모리] forecast_sarima 실행 전: 1497.32 MB
# [메모리] find_best_sarima_params 실행 전: 1497.32 MB
# [메모리] find_best_sarima_params 실행 후: 1497.32 MB (변화: +0.00 MB)
# [메모리] forecast_sarima 실행 후: 1497.32 MB (변화: +0.00 MB)
# [LLY]   [SARIMA] 완료  첫값=2.28e+10 마지막=3.03e+10
# [LLY]   [ETS] 시작  (메모리: 1497.3 MB)
# [메모리] forecast_ets 실행 전: 1497.32 MB
# [메모리] forecast_ets 실행 후: 1497.32 MB (변화: +0.00 MB)
# [LLY]   [ETS] 완료  첫값=2.68e+10 마지막=5.51e+10
# [LLY]   [Theta] 시작  (메모리: 1497.3 MB)
# [메모리] forecast_theta 실행 전: 1497.32 MB
# [메모리] forecast_theta 실행 후: 1497.32 MB (변화: +0.00 MB)
# [LLY]   [Theta] 완료  첫값=2.27e+10 마지막=2.54e+10
# [PROGRESS] [  11/1999] (  0.6%)  >>  WMT
# [WMT]   40분기 | 2016-10-31 ~ 2026-07-31
# [WMT]   [SARIMA] 시작  (메모리: 1497.3 MB)
# [메모리] forecast_sarima 실행 전: 1497.32 MB
# [메모리] find_best_sarima_params 실행 전: 1497.32 MB
# [메모리] find_best_sarima_params 실행 후: 1497.32 MB (변화: +0.00 MB)
# [메모리] forecast_sarima 실행 후: 1497.32 MB (변화: +0.00 MB)
# [WMT]   [SARIMA] 완료  첫값=1.91e+11 마지막=2.14e+11
# [WMT]   [ETS] 시작  (메모리: 1497.3 MB)
# [메모리] forecast_ets 실행 전: 1497.32 MB
# [메모리] forecast_ets 실행 후: 1497.32 MB (변화: +0.00 MB)
# [WMT]   [ETS] 완료  첫값=1.85e+11 마지막=2.03e+11
# [WMT]   [Theta] 시작  (메모리: 1497.3 MB)
# [메모리] forecast_theta 실행 전: 1497.32 MB
# [메모리] forecast_theta 실행 후: 1497.32 MB (변화: +0.00 MB)
# [WMT]   [Theta] 완료  첫값=1.86e+11 마지막=1.94e+11
# [PROGRESS] [  12/1999] (  0.6%)  >>  XOM
# [XOM]   40분기 | 2016-09-30 ~ 2026-06-30
# [XOM]   [SARIMA] 시작  (메모리: 1497.3 MB)
# [메모리] forecast_sarima 실행 전: 1497.32 MB
# [메모리] find_best_sarima_params 실행 전: 1497.32 MB
# [메모리] find_best_sarima_params 실행 후: 1497.32 MB (변화: +0.00 MB)
# [메모리] forecast_sarima 실행 후: 1497.32 MB (변화: +0.00 MB)
# [XOM]   [SARIMA] 완료  첫값=1.17e+11 마지막=1.32e+11
# [XOM]   [ETS] 시작  (메모리: 1497.3 MB)
# [메모리] forecast_ets 실행 전: 1497.32 MB
# [메모리] forecast_ets 실행 후: 1497.32 MB (변화: +0.00 MB)
# [XOM]   [ETS] 완료  첫값=1.35e+11 마지막=1.83e+11
# [XOM]   [Theta] 시작  (메모리: 1497.3 MB)
# [메모리] forecast_theta 실행 전: 1497.32 MB
# [메모리] forecast_theta 실행 후: 1497.32 MB (변화: +0.00 MB)
# [XOM]   [Theta] 완료  첫값=1.13e+11 마지막=1.19e+11
# [PROGRESS] [  13/1999] (  0.7%)  >>  ASML
# [ASML]   40분기 | 2016-09-30 ~ 2026-06-30
# [ASML]   [SARIMA] 시작  (메모리: 1497.3 MB)
# [메모리] forecast_sarima 실행 전: 1497.32 MB
# [메모리] find_best_sarima_params 실행 전: 1497.32 MB
# [메모리] find_best_sarima_params 실행 후: 1497.32 MB (변화: +0.00 MB)
# [메모리] forecast_sarima 실행 후: 1497.32 MB (변화: +0.00 MB)
# [ASML]   [SARIMA] 완료  첫값=1.04e+10 마지막=1.42e+10
# [ASML]   [ETS] 시작  (메모리: 1497.3 MB)
# [메모리] forecast_ets 실행 전: 1497.32 MB
# [메모리] forecast_ets 실행 후: 1497.32 MB (변화: +0.00 MB)
# [ASML]   [ETS] 완료  첫값=1.13e+10 마지막=1.34e+10
# [ASML]   [Theta] 시작  (메모리: 1497.3 MB)
# [메모리] forecast_theta 실행 전: 1497.32 MB
# [메모리] forecast_theta 실행 후: 1497.32 MB (변화: +0.00 MB)
# [ASML]   [Theta] 완료  첫값=9.43e+09 마지막=1.09e+10
# [PROGRESS] [  14/1999] (  0.7%)  >>  JNJ
# [JNJ]   40분기 | 2016-10-02 ~ 2026-06-28
# [JNJ]   [SARIMA] 시작  (메모리: 1497.3 MB)
# [메모리] forecast_sarima 실행 전: 1497.32 MB
# [메모리] find_best_sarima_params 실행 전: 1497.32 MB
# [메모리] find_best_sarima_params 실행 후: 1497.34 MB (변화: +0.02 MB)
# [메모리] forecast_sarima 실행 후: 1497.34 MB (변화: +0.02 MB)
# [JNJ]   [SARIMA] 완료  첫값=2.49e+10 마지막=2.67e+10
# [JNJ]   [ETS] 시작  (메모리: 1497.3 MB)
# [메모리] forecast_ets 실행 전: 1497.34 MB
# [메모리] forecast_ets 실행 후: 1497.34 MB (변화: +0.00 MB)
# [JNJ]   [ETS] 완료  첫값=2.60e+10 마지막=2.85e+10
# [JNJ]   [Theta] 시작  (메모리: 1497.3 MB)
# [메모리] forecast_theta 실행 전: 1497.34 MB
# [메모리] forecast_theta 실행 후: 1497.34 MB (변화: +0.00 MB)
# [JNJ]   [Theta] 완료  첫값=2.49e+10 마지막=2.55e+10
# [PROGRESS] [  15/1999] (  0.8%)  >>  ORCL
# [ORCL]   40분기 | 2016-08-31 ~ 2026-05-31
# [ORCL]   [SARIMA] 시작  (메모리: 1497.3 MB)
# [메모리] forecast_sarima 실행 전: 1497.34 MB
# [메모리] find_best_sarima_params 실행 전: 1497.34 MB
# [메모리] find_best_sarima_params 실행 후: 1497.34 MB (변화: +0.00 MB)
# [메모리] forecast_sarima 실행 후: 1497.34 MB (변화: +0.00 MB)
# [ORCL]   [SARIMA] 완료  첫값=1.87e+10 마지막=2.58e+10
# [ORCL]   [ETS] 시작  (메모리: 1497.3 MB)
# [메모리] forecast_ets 실행 전: 1497.34 MB
# [메모리] forecast_ets 실행 후: 1497.34 MB (변화: +0.00 MB)
# [ORCL]   [ETS] 완료  첫값=1.73e+10 마지막=2.53e+10
# [ORCL]   [Theta] 시작  (메모리: 1497.3 MB)
# [메모리] forecast_theta 실행 전: 1497.34 MB
# [메모리] forecast_theta 실행 후: 1497.34 MB (변화: +0.00 MB)
# [ORCL]   [Theta] 완료  첫값=1.82e+10 마지막=1.93e+10
# [PROGRESS] [  16/1999] (  0.8%)  >>  MU
# [MU]   40분기 | 2016-09-01 ~ 2026-05-28
# [MU]   [SARIMA] 시작  (메모리: 1497.3 MB)
# [메모리] forecast_sarima 실행 전: 1497.34 MB
# [메모리] find_best_sarima_params 실행 전: 1497.34 MB
# [메모리] find_best_sarima_params 실행 후: 1497.36 MB (변화: +0.02 MB)
# [메모리] forecast_sarima 실행 후: 1497.36 MB (변화: +0.02 MB)
# [MU]   [SARIMA] 완료  첫값=5.17e+10 마지막=8.56e+10
# [MU]   [ETS] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_ets 실행 전: 1497.36 MB
# [메모리] forecast_ets 실행 후: 1497.36 MB (변화: +0.00 MB)
# [MU]   [ETS] 완료  첫값=7.11e+10 마지막=2.01e+12
# [MU]   [Theta] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_theta 실행 전: 1497.36 MB
# [메모리] forecast_theta 실행 후: 1497.36 MB (변화: +0.00 MB)
# [MU]   [Theta] 완료  첫값=4.19e+10 마지막=4.51e+10
# [PROGRESS] [  17/1999] (  0.9%)  >>  COST
# [COST]   40분기 | 2016-08-31 ~ 2026-05-10
# [COST]   [SARIMA] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_sarima 실행 전: 1497.36 MB
# [메모리] find_best_sarima_params 실행 전: 1497.36 MB
# [메모리] find_best_sarima_params 실행 후: 1497.36 MB (변화: +0.00 MB)
# [메모리] forecast_sarima 실행 후: 1497.36 MB (변화: +0.00 MB)
# [COST]   [SARIMA] 완료  첫값=1.04e+11 마지막=8.89e+10
# [COST]   [ETS] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_ets 실행 전: 1497.36 MB
# [메모리] forecast_ets 실행 후: 1497.36 MB (변화: +0.00 MB)
# [COST]   [ETS] 완료  첫값=1.03e+11 마지막=8.89e+10
# [COST]   [Theta] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_theta 실행 전: 1497.36 MB
# [메모리] forecast_theta 실행 후: 1497.36 MB (변화: +0.00 MB)
# [COST]   [Theta] 완료  첫값=7.24e+10 마지막=7.87e+10
# [PROGRESS] [  18/1999] (  0.9%)  >>  AMD
# [AMD]   40분기 | 2016-09-24 ~ 2026-06-27
# [AMD]   [SARIMA] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_sarima 실행 전: 1497.36 MB
# [메모리] find_best_sarima_params 실행 전: 1497.36 MB
# [메모리] find_best_sarima_params 실행 후: 1497.37 MB (변화: +0.00 MB)
# [메모리] forecast_sarima 실행 후: 1497.37 MB (변화: +0.00 MB)
# [AMD]   [SARIMA] 완료  첫값=1.22e+10 마지막=1.86e+10
# [AMD]   [ETS] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_ets 실행 전: 1497.37 MB
# [메모리] forecast_ets 실행 후: 1497.37 MB (변화: +0.00 MB)
# [AMD]   [ETS] 완료  첫값=1.49e+10 마지막=2.15e+10
# [AMD]   [Theta] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_theta 실행 전: 1497.37 MB
# [메모리] forecast_theta 실행 후: 1497.37 MB (변화: +0.00 MB)
# [AMD]   [Theta] 완료  첫값=1.19e+10 마지막=1.47e+10
# [PROGRESS] [  19/1999] (  1.0%)  >>  BABA
# [BABA]   40분기 | 2016-09-30 ~ 2026-06-30
# [BABA]   [SARIMA] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_sarima 실행 전: 1497.37 MB
# [메모리] find_best_sarima_params 실행 전: 1497.37 MB
# [메모리] find_best_sarima_params 실행 후: 1497.37 MB (변화: +0.00 MB)
# [메모리] forecast_sarima 실행 후: 1497.37 MB (변화: +0.00 MB)
# [BABA]   [SARIMA] 완료  첫값=2.64e+11 마지막=2.53e+11
# [BABA]   [ETS] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_ets 실행 전: 1497.37 MB
# [메모리] forecast_ets 실행 후: 1497.37 MB (변화: +0.00 MB)
# [BABA]   [ETS] 완료  첫값=2.68e+11 마지막=3.25e+11
# [BABA]   [Theta] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_theta 실행 전: 1497.37 MB
# [메모리] forecast_theta 실행 후: 1497.37 MB (변화: +0.00 MB)
# [BABA]   [Theta] 완료  첫값=2.72e+11 마지막=3.21e+11
# [PROGRESS] [  20/1999] (  1.0%)  >>  NFLX
# [NFLX]   40분기 | 2016-09-30 ~ 2026-06-30
# [NFLX]   [SARIMA] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_sarima 실행 전: 1497.37 MB
# [메모리] find_best_sarima_params 실행 전: 1497.37 MB
# [메모리] find_best_sarima_params 실행 후: 1497.37 MB (변화: +0.00 MB)
# [메모리] forecast_sarima 실행 후: 1497.37 MB (변화: +0.00 MB)
# [NFLX]   [SARIMA] 완료  첫값=1.30e+10 마지막=1.72e+10
# [NFLX]   [ETS] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_ets 실행 전: 1497.37 MB
# [메모리] forecast_ets 실행 후: 1497.37 MB (변화: +0.00 MB)
# [NFLX]   [ETS] 완료  첫값=1.31e+10 마지막=1.69e+10
# [NFLX]   [Theta] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_theta 실행 전: 1497.37 MB
# [메모리] forecast_theta 실행 후: 1497.37 MB (변화: +0.00 MB)
# [NFLX]   [Theta] 완료  첫값=1.28e+10 마지막=1.48e+10
# [PROGRESS] [  21/1999] (  1.1%)  >>  ABBV
# [ABBV]   40분기 | 2016-09-30 ~ 2026-06-30
# [ABBV]   [SARIMA] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_sarima 실행 전: 1497.37 MB
# [메모리] find_best_sarima_params 실행 전: 1497.37 MB
# [메모리] find_best_sarima_params 실행 후: 1497.37 MB (변화: +0.00 MB)
# [메모리] forecast_sarima 실행 후: 1497.37 MB (변화: +0.00 MB)
# [ABBV]   [SARIMA] 완료  첫값=1.70e+10 마지막=2.15e+10
# [ABBV]   [ETS] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_ets 실행 전: 1497.37 MB
# [메모리] forecast_ets 실행 후: 1497.37 MB (변화: +0.00 MB)
# [ABBV]   [ETS] 완료  첫값=1.83e+10 마지막=2.09e+10
# [ABBV]   [Theta] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_theta 실행 전: 1497.37 MB
# [메모리] forecast_theta 실행 후: 1497.37 MB (변화: +0.00 MB)
# [ABBV]   [Theta] 완료  첫값=1.70e+10 마지막=1.85e+10
# [PROGRESS] [  22/1999] (  1.1%)  >>  HD
# [HD]   40분기 | 2016-10-30 ~ 2026-08-02
# [HD]   [SARIMA] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_sarima 실행 전: 1497.37 MB
# [메모리] find_best_sarima_params 실행 전: 1497.37 MB
# [메모리] find_best_sarima_params 실행 후: 1497.37 MB (변화: +0.00 MB)
# [메모리] forecast_sarima 실행 후: 1497.37 MB (변화: +0.00 MB)
# [HD]   [SARIMA] 완료  첫값=4.48e+10 마지막=4.76e+10
# [HD]   [ETS] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_ets 실행 전: 1497.37 MB
# [메모리] forecast_ets 실행 후: 1497.37 MB (변화: +0.00 MB)
# [HD]   [ETS] 완료  첫값=4.26e+10 마지막=5.31e+10
# [HD]   [Theta] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_theta 실행 전: 1497.37 MB
# [메모리] forecast_theta 실행 후: 1497.37 MB (변화: +0.00 MB)
# [HD]   [Theta] 완료  첫값=4.48e+10 마지막=4.75e+10
# [PROGRESS] [  23/1999] (  1.2%)  >>  PG
# [PG]   40분기 | 2016-09-30 ~ 2026-06-30
# [PG]   [SARIMA] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_sarima 실행 전: 1497.37 MB
# [메모리] find_best_sarima_params 실행 전: 1497.37 MB
# [메모리] find_best_sarima_params 실행 후: 1497.37 MB (변화: +0.00 MB)
# [메모리] forecast_sarima 실행 후: 1497.37 MB (변화: +0.00 MB)
# [PG]   [SARIMA] 완료  첫값=2.26e+10 마지막=2.13e+10
# [PG]   [ETS] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_ets 실행 전: 1497.37 MB
# [메모리] forecast_ets 실행 후: 1497.37 MB (변화: +0.00 MB)
# [PG]   [ETS] 완료  첫값=2.28e+10 마지막=2.27e+10
# [PG]   [Theta] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_theta 실행 전: 1497.37 MB
# [메모리] forecast_theta 실행 후: 1497.37 MB (변화: +0.00 MB)
# [PG]   [Theta] 완료  첫값=2.16e+10 마지막=2.22e+10
# [PROGRESS] [  24/1999] (  1.2%)  >>  CVX
# [CVX]   40분기 | 2016-09-30 ~ 2026-06-30
# [CVX]   [SARIMA] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_sarima 실행 전: 1497.37 MB
# [메모리] find_best_sarima_params 실행 전: 1497.37 MB
# [메모리] find_best_sarima_params 실행 후: 1497.37 MB (변화: +0.00 MB)
# [메모리] forecast_sarima 실행 후: 1497.37 MB (변화: +0.00 MB)
# [CVX]   [SARIMA] 완료  첫값=6.87e+10 마지막=7.98e+10
# [CVX]   [ETS] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_ets 실행 전: 1497.37 MB
# [메모리] forecast_ets 실행 후: 1497.37 MB (변화: +0.00 MB)
# [CVX]   [ETS] 완료  첫값=8.03e+10 마지막=1.09e+11
# [CVX]   [Theta] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_theta 실행 전: 1497.37 MB
# [메모리] forecast_theta 실행 후: 1497.37 MB (변화: +0.00 MB)
# [CVX]   [Theta] 완료  첫값=6.75e+10 마지막=7.12e+10
# [PROGRESS] [  25/1999] (  1.3%)  >>  UNH
# [UNH]   40분기 | 2016-09-30 ~ 2026-06-30
# [UNH]   [SARIMA] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_sarima 실행 전: 1497.37 MB
# [메모리] find_best_sarima_params 실행 전: 1497.37 MB
# [메모리] find_best_sarima_params 실행 후: 1497.37 MB (변화: +0.00 MB)
# [메모리] forecast_sarima 실행 후: 1497.37 MB (변화: +0.00 MB)
# [UNH]   [SARIMA] 완료  첫값=1.15e+11 마지막=1.35e+11
# [UNH]   [ETS] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_ets 실행 전: 1497.37 MB
# [메모리] forecast_ets 실행 후: 1497.37 MB (변화: +0.00 MB)
# [UNH]   [ETS] 완료  첫값=1.14e+11 마지막=1.38e+11
# [UNH]   [Theta] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_theta 실행 전: 1497.37 MB
# [메모리] forecast_theta 실행 후: 1497.37 MB (변화: +0.00 MB)
# [UNH]   [Theta] 완료  첫값=1.13e+11 마지막=1.23e+11
# [PROGRESS] [  26/1999] (  1.3%)  >>  KO
# [KO]   40분기 | 2016-09-30 ~ 2026-07-03
# [KO]   [SARIMA] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_sarima 실행 전: 1497.38 MB
# [메모리] find_best_sarima_params 실행 전: 1497.38 MB
# [메모리] find_best_sarima_params 실행 후: 1497.39 MB (변화: +0.00 MB)
# [메모리] forecast_sarima 실행 후: 1497.39 MB (변화: +0.00 MB)
# [KO]   [SARIMA] 완료  첫값=1.28e+10 마지막=1.28e+10
# [KO]   [ETS] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_ets 실행 전: 1497.39 MB
# [메모리] forecast_ets 실행 후: 1497.39 MB (변화: +0.00 MB)
# [KO]   [ETS] 완료  첫값=1.36e+10 마지막=1.56e+10
# [KO]   [Theta] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_theta 실행 전: 1497.39 MB
# [메모리] forecast_theta 실행 후: 1497.39 MB (변화: +0.00 MB)
# [KO]   [Theta] 완료  첫값=1.30e+10 마지막=1.35e+10
# [PROGRESS] [  27/1999] (  1.4%)  >>  GE
# [GE]   40분기 | 2016-09-30 ~ 2026-06-30
# [GE]   [SARIMA] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_sarima 실행 전: 1497.39 MB
# [메모리] find_best_sarima_params 실행 전: 1497.39 MB
# [메모리] find_best_sarima_params 실행 후: 1497.39 MB (변화: +0.00 MB)
# [메모리] forecast_sarima 실행 후: 1497.39 MB (변화: +0.00 MB)
# [GE]   [SARIMA] 완료  첫값=9.27e+09 마지막=7.47e+09
# [GE]   [ETS] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_ets 실행 전: 1497.39 MB
# [메모리] forecast_ets 실행 후: 1497.39 MB (변화: +0.00 MB)
# [GE]   [ETS] 완료  첫값=1.15e+10 마지막=1.02e+10
# [GE]   [Theta] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_theta 실행 전: 1497.39 MB
# [메모리] forecast_theta 실행 후: 1497.39 MB (변화: +0.00 MB)
# [GE]   [Theta] 완료  첫값=1.20e+10 마지막=1.08e+10
# [PROGRESS] [  28/1999] (  1.4%)  >>  CSCO
# [CSCO]   40분기 | 2016-10-29 ~ 2026-07-25
# [CSCO]   [SARIMA] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_sarima 실행 전: 1497.39 MB
# [메모리] find_best_sarima_params 실행 전: 1497.39 MB
# [메모리] find_best_sarima_params 실행 후: 1497.39 MB (변화: +0.00 MB)
# [메모리] forecast_sarima 실행 후: 1497.39 MB (변화: +0.00 MB)
# [CSCO]   [SARIMA] 완료  첫값=1.79e+10 마지막=1.94e+10
# [CSCO]   [ETS] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_ets 실행 전: 1497.39 MB
# [메모리] forecast_ets 실행 후: 1497.39 MB (변화: +0.00 MB)
# [CSCO]   [ETS] 완료  첫값=1.69e+10 마지막=1.81e+10
# [CSCO]   [Theta] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_theta 실행 전: 1497.39 MB
# [메모리] forecast_theta 실행 후: 1497.39 MB (변화: +0.00 MB)
# [CSCO]   [Theta] 완료  첫값=1.73e+10 마지막=1.77e+10
# [PROGRESS] [  29/1999] (  1.5%)  >>  CAT
# [CAT]   40분기 | 2016-09-30 ~ 2026-06-30
# [CAT]   [SARIMA] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_sarima 실행 전: 1497.39 MB
# [메모리] find_best_sarima_params 실행 전: 1497.39 MB
# [메모리] find_best_sarima_params 실행 후: 1497.39 MB (변화: +0.00 MB)
# [메모리] forecast_sarima 실행 후: 1497.39 MB (변화: +0.00 MB)
# [CAT]   [SARIMA] 완료  첫값=2.06e+10 마지막=2.59e+10
# [CAT]   [ETS] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_ets 실행 전: 1497.39 MB
# [메모리] forecast_ets 실행 후: 1497.39 MB (변화: +0.00 MB)
# [CAT]   [ETS] 완료  첫값=2.03e+10 마지막=2.47e+10
# [CAT]   [Theta] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_theta 실행 전: 1497.39 MB
# [메모리] forecast_theta 실행 후: 1497.39 MB (변화: +0.00 MB)
# [CAT]   [Theta] 완료  첫값=2.04e+10 마지막=2.14e+10
# [PROGRESS] [  30/1999] (  1.5%)  >>  TM
# [TM]   40분기 | 2016-09-30 ~ 2026-06-30
# [TM]   [SARIMA] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_sarima 실행 전: 1497.39 MB
# [메모리] find_best_sarima_params 실행 전: 1497.39 MB
# [메모리] find_best_sarima_params 실행 후: 1497.39 MB (변화: +0.00 MB)
# [메모리] forecast_sarima 실행 후: 1497.39 MB (변화: +0.00 MB)
# [TM]   [SARIMA] 완료  첫값=1.40e+13 마지막=1.60e+13
# [TM]   [ETS] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_ets 실행 전: 1497.39 MB
# [메모리] forecast_ets 실행 후: 1497.39 MB (변화: +0.00 MB)
# [TM]   [ETS] 완료  첫값=1.53e+13 마지막=1.73e+13
# [TM]   [Theta] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_theta 실행 전: 1497.39 MB
# [메모리] forecast_theta 실행 후: 1497.39 MB (변화: +0.00 MB)
# [TM]   [Theta] 완료  첫값=1.37e+13 마지막=1.46e+13
# [PROGRESS] [  31/1999] (  1.6%)  >>  AZN
# [AZN]   40분기 | 2016-09-30 ~ 2026-06-30
# [AZN]   [SARIMA] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_sarima 실행 전: 1497.39 MB
# [메모리] find_best_sarima_params 실행 전: 1497.39 MB
# [메모리] find_best_sarima_params 실행 후: 1497.43 MB (변화: +0.04 MB)
# [메모리] forecast_sarima 실행 후: 1497.43 MB (변화: +0.04 MB)
# [AZN]   [SARIMA] 완료  첫값=1.58e+10 마지막=1.90e+10
# [AZN]   [ETS] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_ets 실행 전: 1497.43 MB
# [메모리] forecast_ets 실행 후: 1497.43 MB (변화: +0.00 MB)
# [AZN]   [ETS] 완료  첫값=1.68e+10 마지막=2.09e+10
# [AZN]   [Theta] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_theta 실행 전: 1497.43 MB
# [메모리] forecast_theta 실행 후: 1497.43 MB (변화: +0.00 MB)
# [AZN]   [Theta] 완료  첫값=1.56e+10 마지막=1.75e+10
# [PROGRESS] [  32/1999] (  1.6%)  >>  NVS
# [NVS]   40분기 | 2016-09-30 ~ 2026-06-30
# [NVS]   [SARIMA] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_sarima 실행 전: 1497.43 MB
# [메모리] find_best_sarima_params 실행 전: 1497.43 MB
# [메모리] find_best_sarima_params 실행 후: 1497.43 MB (변화: +0.00 MB)
# [메모리] forecast_sarima 실행 후: 1497.43 MB (변화: +0.00 MB)
# [NVS]   [SARIMA] 완료  첫값=1.39e+10 마지막=1.41e+10
# [NVS]   [ETS] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_ets 실행 전: 1497.43 MB
# [메모리] forecast_ets 실행 후: 1497.43 MB (변화: +0.00 MB)
# [NVS]   [ETS] 완료  첫값=1.44e+10 마지막=1.54e+10
# [NVS]   [Theta] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_theta 실행 전: 1497.43 MB
# [메모리] forecast_theta 실행 후: 1497.43 MB (변화: +0.00 MB)
# [NVS]   [Theta] 완료  첫값=1.40e+10 마지막=1.41e+10
# [PROGRESS] [  33/1999] (  1.7%)  >>  NVO
# [NVO]   40분기 | 2016-09-30 ~ 2026-06-30
# [NVO]   [SARIMA] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_sarima 실행 전: 1497.43 MB
# [메모리] find_best_sarima_params 실행 전: 1497.43 MB
# [메모리] find_best_sarima_params 실행 후: 1497.43 MB (변화: +0.00 MB)
# [메모리] forecast_sarima 실행 후: 1497.43 MB (변화: +0.00 MB)
# [NVO]   [SARIMA] 완료  첫값=8.07e+10 마지막=9.79e+10
# [NVO]   [ETS] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_ets 실행 전: 1497.43 MB
# [메모리] forecast_ets 실행 후: 1497.43 MB (변화: +0.00 MB)
# [NVO]   [ETS] 완료  첫값=8.20e+10 마지막=9.17e+10
# [NVO]   [Theta] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_theta 실행 전: 1497.43 MB
# [메모리] forecast_theta 실행 후: 1497.43 MB (변화: +0.00 MB)
# [NVO]   [Theta] 완료  첫값=8.12e+10 마지막=9.14e+10
# [PROGRESS] [  34/1999] (  1.7%)  >>  LRCX
# [LRCX]   40분기 | 2016-09-25 ~ 2026-06-28
# [LRCX]   [SARIMA] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_sarima 실행 전: 1497.43 MB
# [메모리] find_best_sarima_params 실행 전: 1497.43 MB
# [메모리] find_best_sarima_params 실행 후: 1497.43 MB (변화: +0.00 MB)
# [메모리] forecast_sarima 실행 후: 1497.43 MB (변화: +0.00 MB)
# [LRCX]   [SARIMA] 완료  첫값=6.98e+09 마지막=9.06e+09
# [LRCX]   [ETS] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_ets 실행 전: 1497.43 MB
# [메모리] forecast_ets 실행 후: 1497.43 MB (변화: +0.00 MB)
# [LRCX]   [ETS] 완료  첫값=7.35e+09 마지막=9.36e+09
# [LRCX]   [Theta] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_theta 실행 전: 1497.43 MB
# [메모리] forecast_theta 실행 후: 1497.43 MB (변화: +0.00 MB)
# [LRCX]   [Theta] 완료  첫값=6.81e+09 마지막=7.46e+09
# [PROGRESS] [  35/1999] (  1.8%)  >>  SAP
# [SAP]   40분기 | 2016-09-30 ~ 2026-06-30
# [SAP]   [SARIMA] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_sarima 실행 전: 1497.43 MB
# [메모리] find_best_sarima_params 실행 전: 1497.43 MB
# [메모리] find_best_sarima_params 실행 후: 1497.44 MB (변화: +0.01 MB)
# [메모리] forecast_sarima 실행 후: 1497.44 MB (변화: +0.01 MB)
# [SAP]   [SARIMA] 완료  첫값=9.89e+09 마지막=1.11e+10
# [SAP]   [ETS] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_ets 실행 전: 1497.44 MB
# [메모리] forecast_ets 실행 후: 1497.44 MB (변화: +0.00 MB)
# [SAP]   [ETS] 완료  첫값=9.33e+09 마지막=1.07e+10
# [SAP]   [Theta] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_theta 실행 전: 1497.44 MB
# [메모리] forecast_theta 실행 후: 1497.44 MB (변화: +0.00 MB)
# [SAP]   [Theta] 완료  첫값=9.72e+09 마지막=1.02e+10
# [PROGRESS] [  36/1999] (  1.8%)  >>  IBM
# [IBM]   40분기 | 2016-09-30 ~ 2026-06-30
# [IBM]   [SARIMA] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_sarima 실행 전: 1497.44 MB
# [메모리] find_best_sarima_params 실행 전: 1497.44 MB
# [메모리] find_best_sarima_params 실행 후: 1497.44 MB (변화: +0.00 MB)
# [메모리] forecast_sarima 실행 후: 1497.44 MB (변화: +0.00 MB)
# [IBM]   [SARIMA] 완료  첫값=1.49e+10 마지막=1.63e+10
# [IBM]   [ETS] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_ets 실행 전: 1497.44 MB
# [메모리] forecast_ets 실행 후: 1497.44 MB (변화: +0.00 MB)
# [IBM]   [ETS] 완료  첫값=1.67e+10 마지막=1.68e+10
# [IBM]   [Theta] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_theta 실행 전: 1497.44 MB
# [메모리] forecast_theta 실행 후: 1497.44 MB (변화: +0.00 MB)
# [IBM]   [Theta] 완료  첫값=1.67e+10 마지막=1.63e+10
# [PROGRESS] [  37/1999] (  1.9%)  >>  PM
# [PM]   40분기 | 2016-09-30 ~ 2026-06-30
# [PM]   [SARIMA] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_sarima 실행 전: 1497.44 MB
# [메모리] find_best_sarima_params 실행 전: 1497.44 MB
# [메모리] find_best_sarima_params 실행 후: 1497.44 MB (변화: +0.00 MB)
# [메모리] forecast_sarima 실행 후: 1497.44 MB (변화: +0.00 MB)
# [PM]   [SARIMA] 완료  첫값=1.11e+10 마지막=1.20e+10
# [PM]   [ETS] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_ets 실행 전: 1497.44 MB
# [메모리] forecast_ets 실행 후: 1497.44 MB (변화: +0.00 MB)
# [PM]   [ETS] 완료  첫값=1.18e+10 마지막=1.35e+10
# [PM]   [Theta] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_theta 실행 전: 1497.44 MB
# [메모리] forecast_theta 실행 후: 1497.44 MB (변화: +0.00 MB)
# [PM]   [Theta] 완료  첫값=1.08e+10 마지막=1.13e+10
# [PROGRESS] [  38/1999] (  1.9%)  >>  MRK
# [MRK]   40분기 | 2016-09-30 ~ 2026-06-30
# [MRK]   [SARIMA] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_sarima 실행 전: 1497.44 MB
# [메모리] find_best_sarima_params 실행 전: 1497.44 MB
# [메모리] find_best_sarima_params 실행 후: 1497.44 MB (변화: +0.00 MB)
# [메모리] forecast_sarima 실행 후: 1497.44 MB (변화: +0.00 MB)
# [MRK]   [SARIMA] 완료  첫값=1.70e+10 마지막=1.88e+10
# [MRK]   [ETS] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_ets 실행 전: 1497.44 MB
# [메모리] forecast_ets 실행 후: 1497.44 MB (변화: +0.00 MB)
# [MRK]   [ETS] 완료  첫값=1.72e+10 마지막=1.98e+10
# [MRK]   [Theta] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_theta 실행 전: 1497.44 MB
# [메모리] forecast_theta 실행 후: 1497.44 MB (변화: +0.00 MB)
# [MRK]   [Theta] 완료  첫값=1.67e+10 마지막=1.76e+10
# [PROGRESS] [  39/1999] (  2.0%)  >>  RTX
# [RTX]   40분기 | 2016-09-30 ~ 2026-06-30
# [RTX]   [SARIMA] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_sarima 실행 전: 1497.44 MB
# [메모리] find_best_sarima_params 실행 전: 1497.44 MB
# [메모리] find_best_sarima_params 실행 후: 1497.43 MB (변화: -0.02 MB)
# [메모리] forecast_sarima 실행 후: 1497.43 MB (변화: -0.02 MB)
# [RTX]   [SARIMA] 완료  첫값=2.23e+10 마지막=2.77e+10
# [RTX]   [ETS] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_ets 실행 전: 1497.43 MB
# [메모리] forecast_ets 실행 후: 1497.43 MB (변화: +0.00 MB)
# [RTX]   [ETS] 완료  첫값=2.25e+10 마지막=2.87e+10
# [RTX]   [Theta] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_theta 실행 전: 1497.43 MB
# [메모리] forecast_theta 실행 후: 1497.43 MB (변화: +0.00 MB)
# [RTX]   [Theta] 완료  첫값=2.33e+10 마지막=2.43e+10
# [PROGRESS] [  40/1999] (  2.0%)  >>  AMAT
# [AMAT]   40분기 | 2016-10-30 ~ 2026-07-26
# [AMAT]   [SARIMA] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_sarima 실행 전: 1497.43 MB
# [메모리] find_best_sarima_params 실행 전: 1497.43 MB
# [메모리] find_best_sarima_params 실행 후: 1497.43 MB (변화: +0.01 MB)
# [메모리] forecast_sarima 실행 후: 1497.43 MB (변화: +0.01 MB)
# [AMAT]   [SARIMA] 완료  첫값=9.36e+09 마지막=1.13e+10
# [AMAT]   [ETS] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_ets 실행 전: 1497.43 MB
# [메모리] forecast_ets 실행 후: 1497.43 MB (변화: +0.00 MB)
# [AMAT]   [ETS] 완료  첫값=9.64e+09 마지막=1.07e+10
# [AMAT]   [Theta] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_theta 실행 전: 1497.43 MB
# [메모리] forecast_theta 실행 후: 1497.43 MB (변화: +0.00 MB)
# [AMAT]   [Theta] 완료  첫값=9.22e+09 마지막=1.00e+10
# [PROGRESS] [  41/1999] (  2.1%)  >>  VZA
# [VZA]   40분기 | 2016-09-30 ~ 2026-06-30
# [VZA]   [SARIMA] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_sarima 실행 전: 1497.43 MB
# [메모리] find_best_sarima_params 실행 전: 1497.43 MB
# [메모리] find_best_sarima_params 실행 후: 1497.43 MB (변화: +0.00 MB)
# [메모리] forecast_sarima 실행 후: 1497.43 MB (변화: +0.00 MB)
# [VZA]   [SARIMA] 완료  첫값=3.44e+10 마지막=3.44e+10
# [VZA]   [ETS] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_ets 실행 전: 1497.43 MB
# [메모리] forecast_ets 실행 후: 1497.43 MB (변화: +0.00 MB)
# [VZA]   [ETS] 완료  첫값=3.54e+10 마지막=3.67e+10
# [VZA]   [Theta] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_theta 실행 전: 1497.43 MB
# [메모리] forecast_theta 실행 후: 1497.43 MB (변화: +0.00 MB)
# [VZA]   [Theta] 완료  첫값=3.52e+10 마지막=3.63e+10
# [PROGRESS] [  42/1999] (  2.1%)  >>  TMO
# [TMO]   40분기 | 2016-10-01 ~ 2026-06-27
# [TMO]   [SARIMA] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_sarima 실행 전: 1497.43 MB
# [메모리] find_best_sarima_params 실행 전: 1497.43 MB
# [메모리] find_best_sarima_params 실행 후: 1497.43 MB (변화: +0.00 MB)
# [메모리] forecast_sarima 실행 후: 1497.43 MB (변화: +0.00 MB)
# [TMO]   [SARIMA] 완료  첫값=1.19e+10 마지막=1.51e+10
# [TMO]   [ETS] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_ets 실행 전: 1497.43 MB
# [메모리] forecast_ets 실행 후: 1497.43 MB (변화: +0.00 MB)
# [TMO]   [ETS] 완료  첫값=1.29e+10 마지막=1.52e+10
# [TMO]   [Theta] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_theta 실행 전: 1497.43 MB
# [메모리] forecast_theta 실행 후: 1497.43 MB (변화: +0.00 MB)
# [TMO]   [Theta] 완료  첫값=1.21e+10 마지막=1.32e+10
# [PROGRESS] [  43/1999] (  2.2%)  >>  MCD
# [MCD]   40분기 | 2016-09-30 ~ 2026-06-30
# [MCD]   [SARIMA] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_sarima 실행 전: 1497.43 MB
# [메모리] find_best_sarima_params 실행 전: 1497.43 MB
# [메모리] find_best_sarima_params 실행 후: 1497.43 MB (변화: +0.00 MB)
# [메모리] forecast_sarima 실행 후: 1497.43 MB (변화: +0.00 MB)
# [MCD]   [SARIMA] 완료  첫값=7.15e+09 마지막=6.99e+09
# [MCD]   [ETS] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_ets 실행 전: 1497.43 MB
# [메모리] forecast_ets 실행 후: 1497.43 MB (변화: +0.00 MB)
# [MCD]   [ETS] 완료  첫값=7.71e+09 마지막=7.74e+09
# [MCD]   [Theta] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_theta 실행 전: 1497.43 MB
# [메모리] forecast_theta 실행 후: 1497.43 MB (변화: +0.00 MB)
# [MCD]   [Theta] 완료  첫값=6.96e+09 마지막=7.11e+09
# [PROGRESS] [  44/1999] (  2.2%)  >>  CRM
# [CRM]   40분기 | 2016-10-31 ~ 2026-07-31
# [CRM]   [SARIMA] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_sarima 실행 전: 1497.43 MB
# [메모리] find_best_sarima_params 실행 전: 1497.43 MB
# [메모리] find_best_sarima_params 실행 후: 1497.43 MB (변화: +0.00 MB)
# [메모리] forecast_sarima 실행 후: 1497.43 MB (변화: +0.00 MB)
# [CRM]   [SARIMA] 완료  첫값=1.13e+10 마지막=1.34e+10
# [CRM]   [ETS] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_ets 실행 전: 1497.43 MB
# [메모리] forecast_ets 실행 후: 1497.43 MB (변화: +0.00 MB)
# [CRM]   [ETS] 완료  첫값=1.15e+10 마지막=1.38e+10
# [CRM]   [Theta] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_theta 실행 전: 1497.43 MB
# [메모리] forecast_theta 실행 후: 1497.43 MB (변화: +0.00 MB)
# [CRM]   [Theta] 완료  첫값=1.16e+10 마지막=1.35e+10
# [PROGRESS] [  45/1999] (  2.3%)  >>  SHEL
# [SHEL]   40분기 | 2016-09-30 ~ 2026-06-30
# [SHEL]   [SARIMA] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_sarima 실행 전: 1497.43 MB
# [메모리] find_best_sarima_params 실행 전: 1497.43 MB
# [메모리] find_best_sarima_params 실행 후: 1497.43 MB (변화: +0.00 MB)
# [메모리] forecast_sarima 실행 후: 1497.43 MB (변화: +0.00 MB)
# [SHEL]   [SARIMA] 완료  첫값=9.47e+10 마지막=9.47e+10
# [SHEL]   [ETS] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_ets 실행 전: 1497.43 MB
# [메모리] forecast_ets 실행 후: 1497.43 MB (변화: +0.00 MB)
# [SHEL]   [ETS] 완료  첫값=1.07e+11 마지막=1.42e+11
# [SHEL]   [Theta] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_theta 실행 전: 1497.43 MB
# [메모리] forecast_theta 실행 후: 1497.43 MB (변화: +0.00 MB)
# [SHEL]   [Theta] 완료  첫값=9.46e+10 마지막=9.44e+10
# [PROGRESS] [  46/1999] (  2.3%)  >>  LIN
# [LIN]   40분기 | 2016-09-30 ~ 2026-06-30
# [LIN]   [SARIMA] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_sarima 실행 전: 1497.43 MB
# [메모리] find_best_sarima_params 실행 전: 1497.43 MB
# [메모리] find_best_sarima_params 실행 후: 1497.43 MB (변화: +0.00 MB)
# [메모리] forecast_sarima 실행 후: 1497.43 MB (변화: +0.00 MB)
# [LIN]   [SARIMA] 완료  첫값=9.28e+09 마지막=9.32e+09
# [LIN]   [ETS] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_ets 실행 전: 1497.43 MB
# [메모리] forecast_ets 실행 후: 1497.43 MB (변화: +0.00 MB)
# [LIN]   [ETS] 완료  첫값=9.59e+09 마지막=1.41e+10
# [LIN]   [Theta] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_theta 실행 전: 1497.43 MB
# [메모리] forecast_theta 실행 후: 1497.43 MB (변화: +0.00 MB)
# [LIN]   [Theta] 완료  첫값=9.43e+09 마지막=1.05e+10
# [PROGRESS] [  47/1999] (  2.4%)  >>  INTC
# [INTC]   40분기 | 2016-10-01 ~ 2026-06-27
# [INTC]   [SARIMA] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_sarima 실행 전: 1497.43 MB
# [메모리] find_best_sarima_params 실행 전: 1497.43 MB
# [메모리] find_best_sarima_params 실행 후: 1497.43 MB (변화: +0.00 MB)
# [메모리] forecast_sarima 실행 후: 1497.43 MB (변화: +0.00 MB)
# [INTC]   [SARIMA] 완료  첫값=1.61e+10 마지막=1.62e+10
# [INTC]   [ETS] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_ets 실행 전: 1497.43 MB
# [메모리] forecast_ets 실행 후: 1497.43 MB (변화: +0.00 MB)
# [INTC]   [ETS] 완료  첫값=1.67e+10 마지막=1.53e+10
# [INTC]   [Theta] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_theta 실행 전: 1497.43 MB
# [메모리] forecast_theta 실행 후: 1497.43 MB (변화: +0.00 MB)
# [INTC]   [Theta] 완료  첫값=1.61e+10 마지막=1.57e+10
# [PROGRESS] [  48/1999] (  2.4%)  >>  TMUS
# [TMUS]   40분기 | 2016-09-30 ~ 2026-06-30
# [TMUS]   [SARIMA] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_sarima 실행 전: 1497.43 MB
# [메모리] find_best_sarima_params 실행 전: 1497.43 MB
# [메모리] find_best_sarima_params 실행 후: 1497.43 MB (변화: +0.00 MB)
# [메모리] forecast_sarima 실행 후: 1497.43 MB (변화: +0.00 MB)
# [TMUS]   [SARIMA] 완료  첫값=2.26e+10 마지막=2.26e+10
# [TMUS]   [ETS] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_ets 실행 전: 1497.43 MB
# [메모리] forecast_ets 실행 후: 1497.43 MB (변화: +0.00 MB)
# [TMUS]   [ETS] 완료  첫값=2.33e+10 마지막=2.50e+10
# [TMUS]   [Theta] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_theta 실행 전: 1497.43 MB
# [메모리] forecast_theta 실행 후: 1497.43 MB (변화: +0.00 MB)
# [TMUS]   [Theta] 완료  첫값=2.31e+10 마지막=2.52e+10
# [PROGRESS] [  49/1999] (  2.5%)  >>  KLAC
# [KLAC]   40분기 | 2016-09-30 ~ 2026-06-30
# [KLAC]   [SARIMA] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_sarima 실행 전: 1497.43 MB
# [메모리] find_best_sarima_params 실행 전: 1497.43 MB
# [메모리] find_best_sarima_params 실행 후: 1497.43 MB (변화: +0.00 MB)
# [메모리] forecast_sarima 실행 후: 1497.43 MB (변화: +0.00 MB)
# [KLAC]   [SARIMA] 완료  첫값=3.81e+09 마지막=5.12e+09
# [KLAC]   [ETS] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_ets 실행 전: 1497.43 MB
# [메모리] forecast_ets 실행 후: 1497.43 MB (변화: +0.00 MB)
# [KLAC]   [ETS] 완료  첫값=3.79e+09 마지막=5.32e+09
# [KLAC]   [Theta] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_theta 실행 전: 1497.43 MB
# [메모리] forecast_theta 실행 후: 1497.43 MB (변화: +0.00 MB)
# [KLAC]   [Theta] 완료  첫값=3.73e+09 마지막=4.28e+09
# [PROGRESS] [  50/1999] (  2.5%)  >>  PEP
# [PEP]   40분기 | 2016-09-03 ~ 2026-06-13
# [PEP]   [SARIMA] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_sarima 실행 전: 1497.43 MB
# [메모리] find_best_sarima_params 실행 전: 1497.43 MB
# [메모리] find_best_sarima_params 실행 후: 1497.43 MB (변화: +0.00 MB)
# [메모리] forecast_sarima 실행 후: 1497.43 MB (변화: +0.00 MB)
# [PEP]   [SARIMA] 완료  첫값=2.59e+10 마지막=2.67e+10
# [PEP]   [ETS] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_ets 실행 전: 1497.43 MB
# [메모리] forecast_ets 실행 후: 1497.43 MB (변화: +0.00 MB)
# [PEP]   [ETS] 완료  첫값=2.58e+10 마지막=2.66e+10
# [PEP]   [Theta] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_theta 실행 전: 1497.43 MB
# [메모리] forecast_theta 실행 후: 1497.43 MB (변화: +0.00 MB)
# [PEP]   [Theta] 완료  첫값=2.61e+10 마지막=2.61e+10
# [PROGRESS] [  51/1999] (  2.6%)  >>  DIS
# [DIS]   40분기 | 2016-09-30 ~ 2026-06-27
# [DIS]   [SARIMA] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_sarima 실행 전: 1497.43 MB
# [메모리] find_best_sarima_params 실행 전: 1497.43 MB
# [메모리] find_best_sarima_params 실행 후: 1497.43 MB (변화: +0.00 MB)
# [메모리] forecast_sarima 실행 후: 1497.43 MB (변화: +0.00 MB)
# [DIS]   [SARIMA] 완료  첫값=2.64e+10 마지막=3.01e+10
# [DIS]   [ETS] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_ets 실행 전: 1497.43 MB
# [메모리] forecast_ets 실행 후: 1497.43 MB (변화: +0.00 MB)
# [DIS]   [ETS] 완료  첫값=2.46e+10 마지막=3.38e+10
# [DIS]   [Theta] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_theta 실행 전: 1497.43 MB
# [메모리] forecast_theta 실행 후: 1497.43 MB (변화: +0.00 MB)
# [DIS]   [Theta] 완료  첫값=2.55e+10 마지막=2.71e+10
# [PROGRESS] [  52/1999] (  2.6%)  >>  BA
# [BA]   40분기 | 2016-09-30 ~ 2026-06-30
# [BA]   [SARIMA] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_sarima 실행 전: 1497.43 MB
# [메모리] find_best_sarima_params 실행 전: 1497.43 MB
# [메모리] find_best_sarima_params 실행 후: 1497.43 MB (변화: +0.00 MB)
# [메모리] forecast_sarima 실행 후: 1497.43 MB (변화: +0.00 MB)
# [BA]   [SARIMA] 완료  첫값=2.38e+10 마지막=2.40e+10
# [BA]   [ETS] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_ets 실행 전: 1497.43 MB
# [메모리] forecast_ets 실행 후: 1497.43 MB (변화: +0.00 MB)
# [BA]   [ETS] 완료  첫값=2.46e+10 마지막=2.43e+10
# [BA]   [Theta] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_theta 실행 전: 1497.43 MB
# [메모리] forecast_theta 실행 후: 1497.43 MB (변화: +0.00 MB)
# [BA]   [Theta] 완료  첫값=2.38e+10 마지막=2.35e+10
# [PROGRESS] [  53/1999] (  2.7%)  >>  APH
# [APH]   40분기 | 2016-09-30 ~ 2026-06-30
# [APH]   [SARIMA] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_sarima 실행 전: 1497.43 MB
# [메모리] find_best_sarima_params 실행 전: 1497.43 MB
# [메모리] find_best_sarima_params 실행 후: 1497.43 MB (변화: +0.00 MB)
# [메모리] forecast_sarima 실행 후: 1497.43 MB (변화: +0.00 MB)
# [APH]   [SARIMA] 완료  첫값=9.17e+09 마지막=1.27e+10
# [APH]   [ETS] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_ets 실행 전: 1497.43 MB
# [메모리] forecast_ets 실행 후: 1497.43 MB (변화: +0.00 MB)
# [APH]   [ETS] 완료  첫값=1.08e+10 마지막=2.90e+10
# [APH]   [Theta] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_theta 실행 전: 1497.43 MB
# [메모리] forecast_theta 실행 후: 1497.43 MB (변화: +0.00 MB)
# [APH]   [Theta] 완료  첫값=8.91e+09 마지막=1.01e+10
# [PROGRESS] [  54/1999] (  2.7%)  >>  ISRG
# [ISRG]   40분기 | 2016-09-30 ~ 2026-06-30
# [ISRG]   [SARIMA] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_sarima 실행 전: 1497.43 MB
# [메모리] find_best_sarima_params 실행 전: 1497.43 MB
# [메모리] find_best_sarima_params 실행 후: 1497.43 MB (변화: +0.00 MB)
# [메모리] forecast_sarima 실행 후: 1497.43 MB (변화: +0.00 MB)
# [ISRG]   [SARIMA] 완료  첫값=2.89e+09 마지막=3.74e+09
# [ISRG]   [ETS] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_ets 실행 전: 1497.43 MB
# [메모리] forecast_ets 실행 후: 1497.43 MB (변화: +0.00 MB)
# [ISRG]   [ETS] 완료  첫값=3.08e+09 마지막=4.28e+09
# [ISRG]   [Theta] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_theta 실행 전: 1497.43 MB
# [메모리] forecast_theta 실행 후: 1497.43 MB (변화: +0.00 MB)
# [ISRG]   [Theta] 완료  첫값=2.94e+09 마지막=3.33e+09
# [PROGRESS] [  55/1999] (  2.8%)  >>  ABT
# [ABT]   40분기 | 2016-09-30 ~ 2026-06-30
# [ABT]   [SARIMA] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_sarima 실행 전: 1497.43 MB
# [메모리] find_best_sarima_params 실행 전: 1497.43 MB
# [메모리] find_best_sarima_params 실행 후: 1497.43 MB (변화: +0.00 MB)
# [메모리] forecast_sarima 실행 후: 1497.43 MB (변화: +0.00 MB)
# [ABT]   [SARIMA] 완료  첫값=1.29e+10 마지막=1.51e+10
# [ABT]   [ETS] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_ets 실행 전: 1497.43 MB
# [메모리] forecast_ets 실행 후: 1497.43 MB (변화: +0.00 MB)
# [ABT]   [ETS] 완료  첫값=1.36e+10 마지막=1.60e+10
# [ABT]   [Theta] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_theta 실행 전: 1497.43 MB
# [메모리] forecast_theta 실행 후: 1497.43 MB (변화: +0.00 MB)
# [ABT]   [Theta] 완료  첫값=1.27e+10 마지막=1.35e+10
# [PROGRESS] [  56/1999] (  2.8%)  >>  AMGN
# [AMGN]   40분기 | 2016-09-30 ~ 2026-06-30
# [AMGN]   [SARIMA] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_sarima 실행 전: 1497.43 MB
# [메모리] find_best_sarima_params 실행 전: 1497.43 MB
# [메모리] find_best_sarima_params 실행 후: 1497.43 MB (변화: +0.00 MB)
# [메모리] forecast_sarima 실행 후: 1497.43 MB (변화: +0.00 MB)
# [AMGN]   [SARIMA] 완료  첫값=9.21e+09 마지막=1.01e+10
# [AMGN]   [ETS] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_ets 실행 전: 1497.43 MB
# [메모리] forecast_ets 실행 후: 1497.43 MB (변화: +0.00 MB)
# [AMGN]   [ETS] 완료  첫값=1.01e+10 마지막=1.22e+10
# [AMGN]   [Theta] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_theta 실행 전: 1497.43 MB
# [메모리] forecast_theta 실행 후: 1497.43 MB (변화: +0.00 MB)
# [AMGN]   [Theta] 완료  첫값=9.70e+09 마지막=1.02e+10
# [PROGRESS] [  57/1999] (  2.9%)  >>  ANET
# [ANET]   40분기 | 2016-09-30 ~ 2026-06-30
# [ANET]   [SARIMA] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_sarima 실행 전: 1497.43 MB
# [메모리] find_best_sarima_params 실행 전: 1497.43 MB
# [메모리] find_best_sarima_params 실행 후: 1497.43 MB (변화: +0.00 MB)
# [메모리] forecast_sarima 실행 후: 1497.43 MB (변화: +0.00 MB)
# [ANET]   [SARIMA] 완료  첫값=3.24e+09 마지막=5.09e+09
# [ANET]   [ETS] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_ets 실행 전: 1497.43 MB
# [메모리] forecast_ets 실행 후: 1497.43 MB (변화: +0.00 MB)
# [ANET]   [ETS] 완료  첫값=3.37e+09 마지막=6.49e+09
# [ANET]   [Theta] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_theta 실행 전: 1497.43 MB
# [메모리] forecast_theta 실행 후: 1497.43 MB (변화: +0.00 MB)
# [ANET]   [Theta] 완료  첫값=3.12e+09 마지막=3.78e+09
# [PROGRESS] [  58/1999] (  2.9%)  >>  TXN
# [TXN]   40분기 | 2016-09-30 ~ 2026-06-30
# [TXN]   [SARIMA] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_sarima 실행 전: 1497.43 MB
# [메모리] find_best_sarima_params 실행 전: 1497.43 MB
# [메모리] find_best_sarima_params 실행 후: 1497.43 MB (변화: +0.00 MB)
# [메모리] forecast_sarima 실행 후: 1497.43 MB (변화: +0.00 MB)
# [TXN]   [SARIMA] 완료  첫값=5.67e+09 마지막=5.52e+09
# [TXN]   [ETS] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_ets 실행 전: 1497.43 MB
# [메모리] forecast_ets 실행 후: 1497.43 MB (변화: +0.00 MB)
# [TXN]   [ETS] 완료  첫값=6.47e+09 마지막=1.14e+10
# [TXN]   [Theta] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_theta 실행 전: 1497.43 MB
# [메모리] forecast_theta 실행 후: 1497.43 MB (변화: +0.00 MB)
# [TXN]   [Theta] 완료  첫값=5.48e+09 마지막=5.62e+09
# [PROGRESS] [  59/1999] (  3.0%)  >>  SHOP
# [SHOP]   40분기 | 2016-09-30 ~ 2026-06-30
# [SHOP]   [SARIMA] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_sarima 실행 전: 1497.43 MB
# [메모리] find_best_sarima_params 실행 전: 1497.43 MB
# [메모리] find_best_sarima_params 실행 후: 1497.43 MB (변화: +0.00 MB)
# [메모리] forecast_sarima 실행 후: 1497.43 MB (변화: +0.00 MB)
# [SHOP]   [SARIMA] 완료  첫값=3.51e+09 마지막=7.66e+09
# [SHOP]   [ETS] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_ets 실행 전: 1497.43 MB
# [메모리] forecast_ets 실행 후: 1497.43 MB (변화: +0.00 MB)
# [SHOP]   [ETS] 완료  첫값=3.68e+09 마지막=5.15e+09
# [SHOP]   [Theta] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_theta 실행 전: 1497.43 MB
# [메모리] forecast_theta 실행 후: 1497.43 MB (변화: +0.00 MB)
# [SHOP]   [Theta] 완료  첫값=3.73e+09 마지막=5.11e+09
# [PROGRESS] [  60/1999] (  3.0%)  >>  ACN
# [ACN]   40분기 | 2016-08-31 ~ 2026-05-31
# [ACN]   [SARIMA] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_sarima 실행 전: 1497.43 MB
# [메모리] find_best_sarima_params 실행 전: 1497.43 MB
# [메모리] find_best_sarima_params 실행 후: 1497.43 MB (변화: +0.00 MB)
# [메모리] forecast_sarima 실행 후: 1497.43 MB (변화: +0.00 MB)
# [ACN]   [SARIMA] 완료  첫값=1.83e+10 마지막=2.17e+10
# [ACN]   [ETS] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_ets 실행 전: 1497.43 MB
# [메모리] forecast_ets 실행 후: 1497.43 MB (변화: +0.00 MB)
# [ACN]   [ETS] 완료  첫값=1.86e+10 마지막=2.30e+10
# [ACN]   [Theta] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_theta 실행 전: 1497.43 MB
# [메모리] forecast_theta 실행 후: 1497.43 MB (변화: +0.00 MB)
# [ACN]   [Theta] 완료  첫값=1.89e+10 마지막=2.03e+10
# [PROGRESS] [  61/1999] (  3.1%)  >>  BHP
# [BHP]   40분기 | 2006-12-31 ~ 2026-06-30
# [BHP]   [SARIMA] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_sarima 실행 전: 1497.43 MB
# [메모리] find_best_sarima_params 실행 전: 1497.43 MB
# [메모리] find_best_sarima_params 실행 후: 1497.43 MB (변화: +0.00 MB)
# [메모리] forecast_sarima 실행 후: 1497.43 MB (변화: +0.00 MB)
# [BHP]   [SARIMA] 완료  첫값=3.13e+10 마지막=3.28e+10
# [BHP]   [ETS] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_ets 실행 전: 1497.43 MB
# [메모리] forecast_ets 실행 후: 1497.43 MB (변화: +0.00 MB)
# [BHP]   [ETS] 완료  첫값=3.42e+10 마지막=2.98e+10
# [BHP]   [Theta] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_theta 실행 전: 1497.43 MB
# [메모리] forecast_theta 실행 후: 1497.43 MB (변화: +0.00 MB)
# [BHP]   [Theta] 완료  첫값=4.08e+10 마지막=3.08e+10
# [PROGRESS] [  62/1999] (  3.1%)  >>  GILD
# [GILD]   40분기 | 2016-09-30 ~ 2026-06-30
# [GILD]   [SARIMA] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_sarima 실행 전: 1497.43 MB
# [메모리] find_best_sarima_params 실행 전: 1497.43 MB
# [메모리] find_best_sarima_params 실행 후: 1497.43 MB (변화: +0.00 MB)
# [메모리] forecast_sarima 실행 후: 1497.43 MB (변화: +0.00 MB)
# [GILD]   [SARIMA] 완료  첫값=8.31e+09 마지막=7.66e+09
# [GILD]   [ETS] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_ets 실행 전: 1497.43 MB
# [메모리] forecast_ets 실행 후: 1497.43 MB (변화: +0.00 MB)
# [GILD]   [ETS] 완료  첫값=8.22e+09 마지막=7.74e+09
# [GILD]   [Theta] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_theta 실행 전: 1497.43 MB
# [메모리] forecast_theta 실행 후: 1497.43 MB (변화: +0.00 MB)
# [GILD]   [Theta] 완료  첫값=7.60e+09 마지막=7.75e+09
# [PROGRESS] [  63/1999] (  3.2%)  >>  DHR
# [DHR]   40분기 | 2016-09-30 ~ 2026-06-26
# [DHR]   [SARIMA] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_sarima 실행 전: 1497.43 MB
# [메모리] find_best_sarima_params 실행 전: 1497.43 MB
# [메모리] find_best_sarima_params 실행 후: 1497.43 MB (변화: +0.00 MB)
# [메모리] forecast_sarima 실행 후: 1497.43 MB (변화: +0.00 MB)
# [DHR]   [SARIMA] 완료  첫값=5.86e+09 마지막=6.73e+09
# [DHR]   [ETS] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_ets 실행 전: 1497.43 MB
# [메모리] forecast_ets 실행 후: 1497.43 MB (변화: +0.00 MB)
# [DHR]   [ETS] 완료  첫값=5.99e+09 마지막=6.65e+09
# [DHR]   [Theta] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_theta 실행 전: 1497.43 MB
# [메모리] forecast_theta 실행 후: 1497.43 MB (변화: +0.00 MB)
# [DHR]   [Theta] 완료  첫값=6.27e+09 마지막=6.53e+09
# [PROGRESS] [  64/1999] (  3.2%)  >>  VZ
# [VZ]   40분기 | 2016-09-30 ~ 2026-06-30
# [VZ]   [SARIMA] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_sarima 실행 전: 1497.43 MB
# [메모리] find_best_sarima_params 실행 전: 1497.43 MB
# [메모리] find_best_sarima_params 실행 후: 1497.43 MB (변화: +0.00 MB)
# [메모리] forecast_sarima 실행 후: 1497.43 MB (변화: +0.00 MB)
# [VZ]   [SARIMA] 완료  첫값=3.44e+10 마지막=3.44e+10
# [VZ]   [ETS] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_ets 실행 전: 1497.43 MB
# [메모리] forecast_ets 실행 후: 1497.43 MB (변화: +0.00 MB)
# [VZ]   [ETS] 완료  첫값=3.54e+10 마지막=3.67e+10
# [VZ]   [Theta] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_theta 실행 전: 1497.43 MB
# [메모리] forecast_theta 실행 후: 1497.43 MB (변화: +0.00 MB)
# [VZ]   [Theta] 완료  첫값=3.52e+10 마지막=3.63e+10
# [PROGRESS] [  65/1999] (  3.3%)  >>  TJX
# [TJX]   40분기 | 2016-10-29 ~ 2026-08-01
# [TJX]   [SARIMA] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_sarima 실행 전: 1497.43 MB
# [메모리] find_best_sarima_params 실행 전: 1497.43 MB
# [메모리] find_best_sarima_params 실행 후: 1497.43 MB (변화: +0.00 MB)
# [메모리] forecast_sarima 실행 후: 1497.43 MB (변화: +0.00 MB)
# [TJX]   [SARIMA] 완료  첫값=1.64e+10 마지막=1.73e+10
# [TJX]   [ETS] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_ets 실행 전: 1497.43 MB
# [메모리] forecast_ets 실행 후: 1497.43 MB (변화: +0.00 MB)
# [TJX]   [ETS] 완료  첫값=1.77e+10 마지막=1.99e+10
# [TJX]   [Theta] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_theta 실행 전: 1497.43 MB
# [메모리] forecast_theta 실행 후: 1497.43 MB (변화: +0.00 MB)
# [TJX]   [Theta] 완료  첫값=1.55e+10 마지막=1.65e+10
# [PROGRESS] [  66/1999] (  3.3%)  >>  T
# [T]   40분기 | 2016-09-30 ~ 2026-06-30
# [T]   [SARIMA] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_sarima 실행 전: 1497.43 MB
# [메모리] find_best_sarima_params 실행 전: 1497.43 MB
# [메모리] find_best_sarima_params 실행 후: 1497.43 MB (변화: +0.00 MB)
# [메모리] forecast_sarima 실행 후: 1497.43 MB (변화: +0.00 MB)
# [T]   [SARIMA] 완료  첫값=3.13e+10 마지막=2.99e+10
# [T]   [ETS] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_ets 실행 전: 1497.43 MB
# [메모리] forecast_ets 실행 후: 1497.43 MB (변화: +0.00 MB)
# [T]   [ETS] 완료  첫값=3.20e+10 마지막=2.98e+10
# [T]   [Theta] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_theta 실행 전: 1497.43 MB
# [메모리] forecast_theta 실행 후: 1497.43 MB (변화: +0.00 MB)
# [T]   [Theta] 완료  첫값=3.14e+10 마지막=3.02e+10
# [PROGRESS] [  67/1999] (  3.4%)  >>  QCOM
# [QCOM]   40분기 | 2016-09-30 ~ 2026-06-28
# [QCOM]   [SARIMA] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_sarima 실행 전: 1497.43 MB
# [메모리] find_best_sarima_params 실행 전: 1497.43 MB
# [메모리] find_best_sarima_params 실행 후: 1497.43 MB (변화: +0.00 MB)
# [메모리] forecast_sarima 실행 후: 1497.43 MB (변화: +0.00 MB)
# [QCOM]   [SARIMA] 완료  첫값=9.95e+09 마지막=9.97e+09
# [QCOM]   [ETS] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_ets 실행 전: 1497.43 MB
# [메모리] forecast_ets 실행 후: 1497.43 MB (변화: +0.00 MB)
# [QCOM]   [ETS] 완료  첫값=1.24e+10 마지막=1.70e+10
# [QCOM]   [Theta] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_theta 실행 전: 1497.43 MB
# [메모리] forecast_theta 실행 후: 1497.43 MB (변화: +0.00 MB)
# [QCOM]   [Theta] 완료  첫값=1.07e+10 마지막=1.16e+10
# [PROGRESS] [  68/1999] (  3.4%)  >>  BKNG
# [BKNG]   40분기 | 2016-09-30 ~ 2026-06-30
# [BKNG]   [SARIMA] 시작  (메모리: 1497.4 MB)
# [메모리] forecast_sarima 실행 전: 1497.43 MB
# [메모리] find_best_sarima_params 실행 전: 1497.43 MB
# [메모리] find_best_sarima_params 실행 후: 1497.44 MB (변화: +0.01 MB)
# ...
# [BYRN]   [SARIMA] 완료  첫값=4.44e+06 마지막=1.77e+07
# [BYRN]   [ETS] 시작  (메모리: 1503.9 MB)
# [메모리] forecast_ets 실행 전: 1503.91 MB
# [메모리] forecast_ets 실행 후: 1503.91 MB (변화: +0.00 MB)
# [BYRN]   [ETS] 완료  첫값=1.91e+07 마지막=4.87e+07
# [BYRN]   [Theta] 시작  (메모리: 1503.9 MB)
# [메모리] forecast_theta 실행 전: 1503.91 MB
# [메모리] forecast_theta 실행 후: 1503.91 MB (변화: +0.00 MB)
# [BYRN]   [Theta] 완료  첫값=1.99e+07 마지막=4.11e+07
# [PROGRESS] [1979/1999] ( 99.0%)  >>  INS
# [INS]   40분기 | 2012-12-31 ~ 2025-06-30
# [INS]   [SARIMA] 시작  (메모리: 1503.9 MB)
# [메모리] forecast_sarima 실행 전: 1503.91 MB
# [메모리] find_best_sarima_params 실행 전: 1503.91 MB
# [메모리] find_best_sarima_params 실행 후: 1503.91 MB (변화: +0.00 MB)
# [메모리] forecast_sarima 실행 후: 1503.91 MB (변화: +0.00 MB)
# [INS]   [SARIMA] 완료  첫값=2.59e+07 마지막=2.54e+07
# [INS]   [ETS] 시작  (메모리: 1503.9 MB)
# [메모리] forecast_ets 실행 전: 1503.91 MB
# [메모리] forecast_ets 실행 후: 1503.91 MB (변화: +0.00 MB)
# [INS]   [ETS] 완료  첫값=1.62e+07 마지막=1.64e+07
# [INS]   [Theta] 시작  (메모리: 1503.9 MB)
# [메모리] forecast_theta 실행 전: 1503.91 MB
# [메모리] forecast_theta 실행 후: 1503.91 MB (변화: +0.00 MB)
# [INS]   [Theta] 완료  첫값=1.80e+07 마지막=2.15e+07
# [PROGRESS] [1980/1999] ( 99.0%)  >>  MTLS
# [MTLS]   40분기 | 2016-09-30 ~ 2026-06-30
# [MTLS]   [SARIMA] 시작  (메모리: 1503.9 MB)
# [메모리] forecast_sarima 실행 전: 1503.91 MB
# [메모리] find_best_sarima_params 실행 전: 1503.91 MB
# [메모리] find_best_sarima_params 실행 후: 1503.91 MB (변화: +0.00 MB)
# [메모리] forecast_sarima 실행 후: 1503.91 MB (변화: +0.00 MB)
# [MTLS]   [SARIMA] 완료  첫값=7.29e+07 마지막=8.59e+07
# [MTLS]   [ETS] 시작  (메모리: 1503.9 MB)
# [메모리] forecast_ets 실행 전: 1503.91 MB
# [메모리] forecast_ets 실행 후: 1503.91 MB (변화: +0.00 MB)
# [MTLS]   [ETS] 완료  첫값=6.82e+07 마지막=9.01e+07
# [MTLS]   [Theta] 시작  (메모리: 1503.9 MB)
# [메모리] forecast_theta 실행 전: 1503.91 MB
# [메모리] forecast_theta 실행 후: 1503.91 MB (변화: +0.00 MB)
# [MTLS]   [Theta] 완료  첫값=7.14e+07 마지막=7.65e+07
# [PROGRESS] [1981/1999] ( 99.1%)  >>  SNMP
# [SNMP]   40분기 | 2013-12-31 ~ 2023-09-30
# [SNMP]   [SARIMA] 시작  (메모리: 1503.9 MB)
# [메모리] forecast_sarima 실행 전: 1503.91 MB
# [메모리] find_best_sarima_params 실행 전: 1503.91 MB
# [메모리] find_best_sarima_params 실행 후: 1503.91 MB (변화: +0.00 MB)
# [메모리] forecast_sarima 실행 후: 1503.91 MB (변화: +0.00 MB)
# [SNMP]   [SARIMA] 완료  첫값=7.40e+06 마지막=5.39e+06
# [SNMP]   [ETS] 시작  (메모리: 1503.9 MB)
# [메모리] forecast_ets 실행 전: 1503.91 MB
# [메모리] forecast_ets 실행 후: 1503.91 MB (변화: +0.00 MB)
# [SNMP]   [ETS] 완료  첫값=6.69e+06 마지막=2.77e+06
# [SNMP]   [Theta] 시작  (메모리: 1503.9 MB)
# [메모리] forecast_theta 실행 전: 1503.91 MB
# [메모리] forecast_theta 실행 후: 1503.91 MB (변화: +0.00 MB)
# [SNMP]   [Theta] 완료  첫값=6.43e+06 마지막=6.00e+06
# [PROGRESS] [1982/1999] ( 99.1%)  >>  OFLX
# [OFLX]   40분기 | 2016-09-30 ~ 2026-06-30
# [OFLX]   [SARIMA] 시작  (메모리: 1503.9 MB)
# [메모리] forecast_sarima 실행 전: 1503.91 MB
# [메모리] find_best_sarima_params 실행 전: 1503.91 MB
# [메모리] find_best_sarima_params 실행 후: 1503.91 MB (변화: +0.00 MB)
# [메모리] forecast_sarima 실행 후: 1503.91 MB (변화: +0.00 MB)
# [OFLX]   [SARIMA] 완료  첫값=2.41e+07 마지막=2.40e+07
# [OFLX]   [ETS] 시작  (메모리: 1503.9 MB)
# [메모리] forecast_ets 실행 전: 1503.91 MB
# [메모리] forecast_ets 실행 후: 1503.91 MB (변화: +0.00 MB)
# [OFLX]   [ETS] 완료  첫값=2.68e+07 마지막=2.82e+07
# [OFLX]   [Theta] 시작  (메모리: 1503.9 MB)
# [메모리] forecast_theta 실행 전: 1503.91 MB
# [메모리] forecast_theta 실행 후: 1503.91 MB (변화: +0.00 MB)
# [OFLX]   [Theta] 완료  첫값=2.39e+07 마지막=2.39e+07
# [PROGRESS] [1983/1999] ( 99.2%)  >>  RMNI
# [RMNI]   40분기 | 2016-09-30 ~ 2026-06-30
# [RMNI]   [SARIMA] 시작  (메모리: 1503.9 MB)
# [메모리] forecast_sarima 실행 전: 1503.91 MB
# [메모리] find_best_sarima_params 실행 전: 1503.91 MB
# [메모리] find_best_sarima_params 실행 후: 1503.91 MB (변화: +0.00 MB)
# [메모리] forecast_sarima 실행 후: 1503.91 MB (변화: +0.00 MB)
# [RMNI]   [SARIMA] 완료  첫값=1.08e+08 마지막=1.14e+08
# [RMNI]   [ETS] 시작  (메모리: 1503.9 MB)
# [메모리] forecast_ets 실행 전: 1503.91 MB
# [메모리] forecast_ets 실행 후: 1503.91 MB (변화: +0.00 MB)
# [RMNI]   [ETS] 완료  첫값=1.12e+08 마지막=1.16e+08
# [RMNI]   [Theta] 시작  (메모리: 1503.9 MB)
# [메모리] forecast_theta 실행 전: 1503.91 MB
# [메모리] forecast_theta 실행 후: 1503.91 MB (변화: +0.00 MB)
# [RMNI]   [Theta] 완료  첫값=1.12e+08 마지막=1.22e+08
# [PROGRESS] [1984/1999] ( 99.2%)  >>  LWAY
# [LWAY]   40분기 | 2016-09-30 ~ 2026-06-30
# [LWAY]   [SARIMA] 시작  (메모리: 1503.9 MB)
# [메모리] forecast_sarima 실행 전: 1503.91 MB
# [메모리] find_best_sarima_params 실행 전: 1503.91 MB
# [메모리] find_best_sarima_params 실행 후: 1503.91 MB (변화: +0.00 MB)
# [메모리] forecast_sarima 실행 후: 1503.91 MB (변화: +0.00 MB)
# [LWAY]   [SARIMA] 완료  첫값=6.84e+07 마지막=7.96e+07
# [LWAY]   [ETS] 시작  (메모리: 1503.9 MB)
# [메모리] forecast_ets 실행 전: 1503.91 MB
# [메모리] forecast_ets 실행 후: 1503.91 MB (변화: +0.00 MB)
# [LWAY]   [ETS] 완료  첫값=6.84e+07 마지막=9.63e+07
# [LWAY]   [Theta] 시작  (메모리: 1503.9 MB)
# [메모리] forecast_theta 실행 전: 1503.91 MB
# [메모리] forecast_theta 실행 후: 1503.91 MB (변화: +0.00 MB)
# [LWAY]   [Theta] 완료  첫값=6.76e+07 마지막=7.30e+07
# [PROGRESS] [1985/1999] ( 99.3%)  >>  SVC
# [SVC]   40분기 | 2016-09-30 ~ 2026-06-30
# [SVC]   [SARIMA] 시작  (메모리: 1503.9 MB)
# [메모리] forecast_sarima 실행 전: 1503.91 MB
# [메모리] find_best_sarima_params 실행 전: 1503.91 MB
# [메모리] find_best_sarima_params 실행 후: 1503.91 MB (변화: +0.00 MB)
# [메모리] forecast_sarima 실행 후: 1503.91 MB (변화: +0.00 MB)
# [SVC]   [SARIMA] 완료  첫값=4.21e+08 마지막=4.21e+08
# [SVC]   [ETS] 시작  (메모리: 1503.9 MB)
# [메모리] forecast_ets 실행 전: 1503.91 MB
# [메모리] forecast_ets 실행 후: 1503.91 MB (변화: +0.00 MB)
# [SVC]   [ETS] 완료  첫값=4.48e+08 마지막=5.51e+08
# [SVC]   [Theta] 시작  (메모리: 1503.9 MB)
# [메모리] forecast_theta 실행 전: 1503.91 MB
# [메모리] forecast_theta 실행 후: 1503.91 MB (변화: +0.00 MB)
# [SVC]   [Theta] 완료  첫값=4.11e+08 마지막=4.03e+08
# [PROGRESS] [1986/1999] ( 99.3%)  >>  EVI
# [EVI]   40분기 | 2016-06-30 ~ 2026-03-31
# [EVI]   [SARIMA] 시작  (메모리: 1503.9 MB)
# [메모리] forecast_sarima 실행 전: 1503.91 MB
# [메모리] find_best_sarima_params 실행 전: 1503.91 MB
# [메모리] find_best_sarima_params 실행 후: 1503.91 MB (변화: +0.00 MB)
# [메모리] forecast_sarima 실행 후: 1503.91 MB (변화: +0.00 MB)
# [EVI]   [SARIMA] 완료  첫값=1.01e+08 마지막=1.01e+08
# [EVI]   [ETS] 시작  (메모리: 1503.9 MB)
# [메모리] forecast_ets 실행 전: 1503.91 MB
# [메모리] forecast_ets 실행 후: 1503.91 MB (변화: +0.00 MB)
# [EVI]   [ETS] 완료  첫값=1.01e+08 마지막=1.37e+08
# [EVI]   [Theta] 시작  (메모리: 1503.9 MB)
# [메모리] forecast_theta 실행 전: 1503.91 MB
# [메모리] forecast_theta 실행 후: 1503.91 MB (변화: +0.00 MB)
# [EVI]   [Theta] 완료  첫값=1.05e+08 마지막=1.22e+08
# [PROGRESS] [1987/1999] ( 99.4%)  >>  OOMA
# [OOMA]   40분기 | 2016-10-31 ~ 2026-07-31
# [OOMA]   [SARIMA] 시작  (메모리: 1503.9 MB)
# [메모리] forecast_sarima 실행 전: 1503.91 MB
# [메모리] find_best_sarima_params 실행 전: 1503.91 MB
# [메모리] find_best_sarima_params 실행 후: 1503.91 MB (변화: +0.00 MB)
# [메모리] forecast_sarima 실행 후: 1503.91 MB (변화: +0.00 MB)
# [OOMA]   [SARIMA] 완료  첫값=8.57e+07 마지막=1.06e+08
# [OOMA]   [ETS] 시작  (메모리: 1503.9 MB)
# [메모리] forecast_ets 실행 전: 1503.91 MB
# [메모리] forecast_ets 실행 후: 1503.91 MB (변화: +0.00 MB)
# [OOMA]   [ETS] 완료  첫값=8.53e+07 마지막=1.03e+08
# [OOMA]   [Theta] 시작  (메모리: 1503.9 MB)
# [메모리] forecast_theta 실행 전: 1503.91 MB
# [메모리] forecast_theta 실행 후: 1503.91 MB (변화: +0.00 MB)
# [OOMA]   [Theta] 완료  첫값=8.44e+07 마지막=9.32e+07
# [PROGRESS] [1988/1999] ( 99.4%)  >>  MLP
# [MLP]   40분기 | 2016-09-30 ~ 2026-06-30
# [MLP]   [SARIMA] 시작  (메모리: 1503.9 MB)
# [메모리] forecast_sarima 실행 전: 1503.91 MB
# [메모리] find_best_sarima_params 실행 전: 1503.91 MB
# [메모리] find_best_sarima_params 실행 후: 1503.91 MB (변화: +0.00 MB)
# [메모리] forecast_sarima 실행 후: 1503.91 MB (변화: +0.00 MB)
# [MLP]   [SARIMA] 완료  첫값=2.17e+06 마지막=1.36e+07
# [MLP]   [ETS] 시작  (메모리: 1503.9 MB)
# [메모리] forecast_ets 실행 전: 1503.91 MB
# [메모리] forecast_ets 실행 후: 1503.91 MB (변화: +0.00 MB)
# [MLP]   [ETS] 완료  첫값=2.17e+06 마지막=5.86e+06
# [MLP]   [Theta] 시작  (메모리: 1503.9 MB)
# [메모리] forecast_theta 실행 전: 1503.91 MB
# [메모리] forecast_theta 실행 후: 1503.91 MB (변화: +0.00 MB)
# [MLP]   [Theta] 완료  첫값=3.78e+06 마지막=3.67e+06
# [PROGRESS] [1989/1999] ( 99.5%)  >>  STRT
# [STRT]   40분기 | 2016-10-02 ~ 2026-06-28
# [STRT]   [SARIMA] 시작  (메모리: 1503.9 MB)
# [메모리] forecast_sarima 실행 전: 1503.91 MB
# [메모리] find_best_sarima_params 실행 전: 1503.91 MB
# [메모리] find_best_sarima_params 실행 후: 1503.91 MB (변화: +0.00 MB)
# [메모리] forecast_sarima 실행 후: 1503.91 MB (변화: +0.00 MB)
# [STRT]   [SARIMA] 완료  첫값=1.68e+08 마지막=1.81e+08
# [STRT]   [ETS] 시작  (메모리: 1503.9 MB)
# [메모리] forecast_ets 실행 전: 1503.91 MB
# [메모리] forecast_ets 실행 후: 1503.91 MB (변화: +0.00 MB)
# [STRT]   [ETS] 완료  첫값=1.63e+08 마지막=1.97e+08
# [STRT]   [Theta] 시작  (메모리: 1503.9 MB)
# [메모리] forecast_theta 실행 전: 1503.91 MB
# [메모리] forecast_theta 실행 후: 1503.91 MB (변화: +0.00 MB)
# [STRT]   [Theta] 완료  첫값=1.44e+08 마지막=1.49e+08
# [PROGRESS] [1990/1999] ( 99.5%)  >>  LFCR
# [LFCR]   39분기 | 2016-08-31 ~ 2026-06-30
# [LFCR]   [SARIMA] 시작  (메모리: 1503.9 MB)
# [메모리] forecast_sarima 실행 전: 1503.91 MB
# [메모리] find_best_sarima_params 실행 전: 1503.91 MB
# [메모리] find_best_sarima_params 실행 후: 1503.91 MB (변화: +0.00 MB)
# [메모리] forecast_sarima 실행 후: 1503.91 MB (변화: +0.00 MB)
# [LFCR]   [SARIMA] 완료  첫값=3.54e+07 마지막=1.39e+07
# [LFCR]   [ETS] 시작  (메모리: 1503.9 MB)
# [메모리] forecast_ets 실행 전: 1503.91 MB
# [메모리] forecast_ets 실행 후: 1503.91 MB (변화: +0.00 MB)
# [LFCR]   [ETS] 완료  첫값=3.21e+07 마지막=2.75e+07
# [LFCR]   [Theta] 시작  (메모리: 1503.9 MB)
# [메모리] forecast_theta 실행 전: 1503.91 MB
# [메모리] forecast_theta 실행 후: 1503.91 MB (변화: +0.00 MB)
# [LFCR]   [Theta] 완료  첫값=2.92e+07 마지막=2.39e+07
# [PROGRESS] [1991/1999] ( 99.6%)  >>  PKOH
# [PKOH]   40분기 | 2016-09-30 ~ 2026-06-30
# [PKOH]   [SARIMA] 시작  (메모리: 1503.9 MB)
# [메모리] forecast_sarima 실행 전: 1503.91 MB
# [메모리] find_best_sarima_params 실행 전: 1503.91 MB
# [메모리] find_best_sarima_params 실행 후: 1503.91 MB (변화: +0.00 MB)
# [메모리] forecast_sarima 실행 후: 1503.91 MB (변화: +0.00 MB)
# [PKOH]   [SARIMA] 완료  첫값=4.13e+08 마지막=4.13e+08
# [PKOH]   [ETS] 시작  (메모리: 1503.9 MB)
# [메모리] forecast_ets 실행 전: 1503.91 MB
# [메모리] forecast_ets 실행 후: 1503.91 MB (변화: +0.00 MB)
# [PKOH]   [ETS] 완료  첫값=4.03e+08 마지막=4.32e+08
# [PKOH]   [Theta] 시작  (메모리: 1503.9 MB)
# [메모리] forecast_theta 실행 전: 1503.91 MB
# [메모리] forecast_theta 실행 후: 1503.91 MB (변화: +0.00 MB)
# [PKOH]   [Theta] 완료  첫값=4.19e+08 마지막=4.25e+08
# [PROGRESS] [1992/1999] ( 99.6%)  >>  PBYI
# [PBYI]   40분기 | 2016-09-30 ~ 2026-06-30
# [PBYI]   [SARIMA] 시작  (메모리: 1503.9 MB)
# [메모리] forecast_sarima 실행 전: 1503.91 MB
# [메모리] find_best_sarima_params 실행 전: 1503.91 MB
# [메모리] find_best_sarima_params 실행 후: 1503.91 MB (변화: +0.00 MB)
# [메모리] forecast_sarima 실행 후: 1503.91 MB (변화: +0.00 MB)
# [PBYI]   [SARIMA] 완료 (forecast 비어있음)
# [PBYI]   [ETS] 시작  (메모리: 1503.9 MB)
# [메모리] forecast_ets 실행 전: 1503.91 MB
# [메모리] forecast_ets 실행 후: 1503.91 MB (변화: +0.00 MB)
# [PBYI]   [ETS] 완료  첫값=5.26e+07 마지막=6.40e+07
# [PBYI]   [Theta] 시작  (메모리: 1503.9 MB)
# [메모리] forecast_theta 실행 전: 1503.91 MB
# [메모리] forecast_theta 실행 후: 1503.91 MB (변화: +0.00 MB)
# [PBYI]   [Theta] 완료  첫값=5.64e+07 마지막=5.95e+07
# [PROGRESS] [1993/1999] ( 99.7%)  >>  MPX
# [MPX]   40분기 | 2016-06-30 ~ 2026-03-31
# [MPX]   [SARIMA] 시작  (메모리: 1503.9 MB)
# [메모리] forecast_sarima 실행 전: 1503.91 MB
# [메모리] find_best_sarima_params 실행 전: 1503.91 MB
# [메모리] find_best_sarima_params 실행 후: 1503.91 MB (변화: +0.00 MB)
# [메모리] forecast_sarima 실행 후: 1503.91 MB (변화: +0.00 MB)
# [MPX]   [SARIMA] 완료  첫값=6.65e+07 마지막=6.65e+07
# [MPX]   [ETS] 시작  (메모리: 1503.9 MB)
# [메모리] forecast_ets 실행 전: 1503.91 MB
# [메모리] forecast_ets 실행 후: 1503.91 MB (변화: +0.00 MB)
# [MPX]   [ETS] 완료  첫값=5.95e+07 마지막=6.15e+07
# [MPX]   [Theta] 시작  (메모리: 1503.9 MB)
# [메모리] forecast_theta 실행 전: 1503.91 MB
# [메모리] forecast_theta 실행 후: 1503.91 MB (변화: +0.00 MB)
# [MPX]   [Theta] 완료  첫값=6.55e+07 마지막=6.57e+07
# [PROGRESS] [1994/1999] ( 99.7%)  >>  MIXT
# [MIXT]   40분기 | 2014-03-31 ~ 2023-12-31
# [MIXT]   [SARIMA] 시작  (메모리: 1503.9 MB)
# [메모리] forecast_sarima 실행 전: 1503.91 MB
# [메모리] find_best_sarima_params 실행 전: 1503.91 MB
# [메모리] find_best_sarima_params 실행 후: 1503.91 MB (변화: +0.00 MB)
# [메모리] forecast_sarima 실행 후: 1503.91 MB (변화: +0.00 MB)
# [MIXT]   [SARIMA] 완료  첫값=3.87e+07 마지막=4.05e+07
# [MIXT]   [ETS] 시작  (메모리: 1503.9 MB)
# [메모리] forecast_ets 실행 전: 1503.91 MB
# [메모리] forecast_ets 실행 후: 1503.91 MB (변화: +0.00 MB)
# [MIXT]   [ETS] 완료  첫값=4.10e+07 마지막=4.14e+07
# [MIXT]   [Theta] 시작  (메모리: 1503.9 MB)
# [메모리] forecast_theta 실행 전: 1503.91 MB
# [메모리] forecast_theta 실행 후: 1503.91 MB (변화: +0.00 MB)
# [MIXT]   [Theta] 완료  첫값=3.86e+07 마지막=3.98e+07
# [PROGRESS] [1995/1999] ( 99.8%)  >>  DENN
# [DENN]   40분기 | 2015-12-31 ~ 2025-09-24
# [DENN]   [SARIMA] 시작  (메모리: 1503.9 MB)
# [메모리] forecast_sarima 실행 전: 1503.91 MB
# [메모리] find_best_sarima_params 실행 전: 1503.91 MB
# [메모리] find_best_sarima_params 실행 후: 1503.91 MB (변화: +0.00 MB)
# [메모리] forecast_sarima 실행 후: 1503.91 MB (변화: +0.00 MB)
# [DENN]   [SARIMA] 완료  첫값=1.14e+08 마지막=1.11e+08
# [DENN]   [ETS] 시작  (메모리: 1503.9 MB)
# [메모리] forecast_ets 실행 전: 1503.91 MB
# [메모리] forecast_ets 실행 후: 1503.91 MB (변화: +0.00 MB)
# [DENN]   [ETS] 완료  첫값=1.11e+08 마지막=1.12e+08
# [DENN]   [Theta] 시작  (메모리: 1503.9 MB)
# [메모리] forecast_theta 실행 전: 1503.91 MB
# [메모리] forecast_theta 실행 후: 1503.91 MB (변화: +0.00 MB)
# [DENN]   [Theta] 완료  첫값=1.14e+08 마지막=1.11e+08
# [PROGRESS] [1996/1999] ( 99.8%)  >>  NEO
# [NEO]   40분기 | 2016-09-30 ~ 2026-06-30
# [NEO]   [SARIMA] 시작  (메모리: 1503.9 MB)
# [메모리] forecast_sarima 실행 전: 1503.91 MB
# [메모리] find_best_sarima_params 실행 전: 1503.91 MB
# [메모리] find_best_sarima_params 실행 후: 1503.91 MB (변화: +0.00 MB)
# [메모리] forecast_sarima 실행 후: 1503.91 MB (변화: +0.00 MB)
# [NEO]   [SARIMA] 완료  첫값=2.08e+08 마지막=2.60e+08
# [NEO]   [ETS] 시작  (메모리: 1503.9 MB)
# [메모리] forecast_ets 실행 전: 1503.91 MB
# [메모리] forecast_ets 실행 후: 1503.91 MB (변화: +0.00 MB)
# [NEO]   [ETS] 완료  첫값=2.23e+08 마지막=2.77e+08
# [NEO]   [Theta] 시작  (메모리: 1503.9 MB)
# [메모리] forecast_theta 실행 전: 1503.91 MB
# [메모리] forecast_theta 실행 후: 1503.91 MB (변화: +0.00 MB)
# [NEO]   [Theta] 완료  첫값=2.03e+08 마지막=2.27e+08
# [PROGRESS] [1997/1999] ( 99.9%)  >>  AMRN
# [AMRN]   40분기 | 2016-09-30 ~ 2026-06-30
# [AMRN]   [SARIMA] 시작  (메모리: 1503.9 MB)
# [메모리] forecast_sarima 실행 전: 1503.91 MB
# [메모리] find_best_sarima_params 실행 전: 1503.91 MB
# [메모리] find_best_sarima_params 실행 후: 1503.91 MB (변화: +0.00 MB)
# [메모리] forecast_sarima 실행 후: 1503.91 MB (변화: +0.00 MB)
# [AMRN]   [SARIMA] 완료  첫값=4.12e+07 마지막=3.92e+07
# [AMRN]   [ETS] 시작  (메모리: 1503.9 MB)
# [메모리] forecast_ets 실행 전: 1503.91 MB
# [메모리] forecast_ets 실행 후: 1503.91 MB (변화: +0.00 MB)
# [AMRN]   [ETS] 완료  첫값=3.84e+07 마지막=2.49e+07
# [AMRN]   [Theta] 시작  (메모리: 1503.9 MB)
# [메모리] forecast_theta 실행 전: 1503.91 MB
# [메모리] forecast_theta 실행 후: 1503.91 MB (변화: +0.00 MB)
# [AMRN]   [Theta] 완료  첫값=4.33e+07 마지막=4.34e+07
# [PROGRESS] [1998/1999] ( 99.9%)  >>  LOCO
# [LOCO]   40분기 | 2016-09-28 ~ 2026-07-01
# [LOCO]   [SARIMA] 시작  (메모리: 1503.9 MB)
# [메모리] forecast_sarima 실행 전: 1503.91 MB
# [메모리] find_best_sarima_params 실행 전: 1503.91 MB
# [메모리] find_best_sarima_params 실행 후: 1503.91 MB (변화: +0.00 MB)
# [메모리] forecast_sarima 실행 후: 1503.91 MB (변화: +0.00 MB)
# [LOCO]   [SARIMA] 완료  첫값=1.28e+08 마지막=1.31e+08
# [LOCO]   [ETS] 시작  (메모리: 1503.9 MB)
# [메모리] forecast_ets 실행 전: 1503.91 MB
# [메모리] forecast_ets 실행 후: 1503.91 MB (변화: +0.00 MB)
# [LOCO]   [ETS] 완료  첫값=1.30e+08 마지막=1.42e+08
# [LOCO]   [Theta] 시작  (메모리: 1503.9 MB)
# [메모리] forecast_theta 실행 전: 1503.91 MB
# [메모리] forecast_theta 실행 후: 1503.91 MB (변화: +0.00 MB)
# [LOCO]   [Theta] 완료  첫값=1.27e+08 마지막=1.30e+08
# [PROGRESS] [1999/1999] (100.0%)  >>  BNTC
# [BNTC] [NEG-SKIP] [BNTC] 음수 매출 → 예측 제외 ([datetime.date(2020, 6, 30), datetime.date(2024, 6, 30)])
# [BATCH] ======================================================================
# [BATCH] 완료 | 성공: 1857  데이터스킵: 48  음수제외: 94  오류: 0  합계: 1999
# [BATCH] 데이터스킵  : ['RIO', 'SNDK', 'VIK', 'FLUT', 'ULS', 'CNHI', 'PSKY', 'PARA', 'OS', 'LGN', 'LIF', 'TGS', 'WPP', 'INDV', 'DJT', 'VRN', 'CXT', 'CAM', 'CON', 'CMBT', 'PINC', 'EACQ', 'BWLP', 'TVPT', 'GOGL', 'NVRI', 'VIVO', 'ASTH', 'NNE', 'CCEC']...
# [BATCH] 음수제외   : ['EMR', 'CRH', 'RCL', 'FER', 'NETE', 'XPO', 'NLY', 'J', 'AGNC', 'IAG', 'DOC', 'CREE', 'UEC', 'FBHS', 'BRKS', 'CYTK', 'MSGS', 'RITM', 'USM', 'CNX', 'NRZ', 'IEP', 'SBRA', 'TWNK', 'DAN', 'COMM', 'WSC', 'DNN', 'SLG', 'MPW', 'COTY', 'BTE', 'WVE', 'PLUG', 'VGR', 'GLPG', 'NOG', 'DX', 'ARR', 'SEM', 'CLI', 'STGW', 'NVAX', 'WRE', 'ALEX', 'ABR', 'VYX', 'SBET', 'TWO', 'ARI', 'IRS', 'LAC', 'SYX', 'EFC', 'BTCM', 'LAR', 'ORC', 'BLFS', 'VVI', 'PMT', 'CIM', 'CMP', 'GLYC', 'MFA', 'PRSU', 'ALBO', 'LIND', 'VERB', 'OMER', 'GAU', 'NEWP', 'ABUS', 'MTA', 'RWT', 'RZLV', 'GYRE', 'STAR', 'NYMT', 'NR', 'IVR', 'TBN', 'STKL', 'DBVT', 'OCGN', 'IMMP', 'CD', 'DMAC', 'LAAC', 'PTSI', 'PTN', 'NBY', 'RC', 'QIWI', 'BNTC']
# [BATCH] ======================================================================
# [BATCH] ※ 다음 override 종목은 본 배치에서 제외됨 — Cell 9 에서 개별 처리 필요:
# [BATCH]    ['SIMO']

# %% [markdown]
# ## Cell 11 · 저장 결과 조회

# %%
# ── 오늘 예측된 ticker × 모델별 요약 ───────────────────────
with engine.connect() as conn:
    today_summary = pd.read_sql(
        text(f"""
            SELECT model, COUNT(DISTINCT ticker) AS n_tickers, COUNT(*) AS n_rows
            FROM   `{DEST_TABLE}`
            WHERE  forecast_date = :fd AND data_type = 'forecast'
            GROUP  BY model
            ORDER  BY model
        """),
        conn, params={"fd": FORECAST_DATE},
    )

print(f"[오늘({FORECAST_DATE}) 예측 요약]")
display(today_summary)

# ── 전체 DB 저장 통계 ──────────────────────────────────────
with engine.connect() as conn:
    total_stats = pd.read_sql(
        text(f"""
            SELECT forecast_date,
                   COUNT(DISTINCT ticker) AS n_tickers,
                   COUNT(*) AS n_rows
            FROM   `{DEST_TABLE}`
            GROUP  BY forecast_date
            ORDER  BY forecast_date DESC
            LIMIT  10
        """), conn,
    )

print(f"\n[최근 10일 forecast_date 별 통계]")
display(total_stats)
# Out:
# [오늘(2026-09-05) 예측 요약]
#       model  n_tickers  n_rows
# 0  Ensemble       1857   14856
# 1       ETS       1857   14856
# 2    SARIMA       1810   14480
# 3     Theta       1857   14856
# [최근 10일 forecast_date 별 통계]
#   forecast_date  n_tickers  n_rows
# 0    2026-09-05       1857  133260
# 1    2026-08-20          1      88
# 2    2026-08-03       1859  133420
# 3    2026-06-25       1865  133849
# 4    2026-05-28       1865  133840
# 5    2026-05-07          4     336
# 6    2026-05-02        902   64567
# 7    2026-05-01        864   62129
# 8    2026-04-30        497   23262
# 9    2026-04-24          1      40

# %% [markdown]
# ## Cell 12 · 오염 데이터 삭제 & 재예측 (utility)
#
# 특정 ticker / 특정 forecast_date 의 잘못된 데이터를 지울 때 사용.
# **삭제는 되돌릴 수 없으므로 신중히** 사용하세요. 기본은 dry-run.

# %%
# ─── 삭제 대상 지정 ──────────────────────────────────────────
DELETE_TICKERS       = ["DY"]           # 삭제할 ticker (예: ["STRL"])
DELETE_FORECAST_DATE = FORECAST_DATE      # 삭제할 forecast_date
DRY_RUN              = True               # True 면 실제 삭제 안 함

print(f"[삭제 대상]")
print(f"  ticker(s)     : {DELETE_TICKERS}")
print(f"  forecast_date : {DELETE_FORECAST_DATE}")
print(f"  dry_run       : {DRY_RUN}")

with engine.connect() as conn:
    cnt = pd.read_sql(
        text(f"""
            SELECT ticker, COUNT(*) AS rows_to_delete
            FROM   `{DEST_TABLE}`
            WHERE  ticker IN :tk AND forecast_date = :fd
            GROUP  BY ticker
        """),
        conn,
        params={"tk": tuple(DELETE_TICKERS) if len(DELETE_TICKERS) > 1
                                            else (DELETE_TICKERS[0], DELETE_TICKERS[0]),
                "fd": DELETE_FORECAST_DATE},
    )

print(f"\n[현재 DB 의 해당 행 수]")
display(cnt)

if not DRY_RUN and not cnt.empty:
    with engine.begin() as conn:
        conn.execute(
            text(f"""
                DELETE FROM `{DEST_TABLE}`
                WHERE  ticker IN :tk AND forecast_date = :fd
            """),
            {"tk": tuple(DELETE_TICKERS) if len(DELETE_TICKERS) > 1
                                          else (DELETE_TICKERS[0], DELETE_TICKERS[0]),
             "fd": DELETE_FORECAST_DATE},
        )
    print(f"\n[삭제 완료] 위 행들이 DB 에서 제거됨. Cell 9 또는 Cell 10 으로 재예측하세요.")
elif DRY_RUN:
    print(f"\n[dry-run] DRY_RUN=False 로 변경 후 다시 실행하면 실제 삭제됨.")
else:
    print(f"\n[INFO] 삭제할 행 없음.")
# Out:
# [삭제 대상]
#   ticker(s)     : ['DY']
#   forecast_date : 2026-08-03
#   dry_run       : True
#
# [현재 DB 의 해당 행 수]
#   ticker  rows_to_delete
# 0     DY              72
# [dry-run] DRY_RUN=False 로 변경 후 다시 실행하면 실제 삭제됨.
