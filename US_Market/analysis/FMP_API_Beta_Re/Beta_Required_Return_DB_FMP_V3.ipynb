# %% [markdown]
# # US Beta / Required Return — Batch Runner V3
#
# **저장 테이블** : `us_required_return_result`
# **저장 형태**   : `date · ticker · indicator · value` (long-format)
# **저장 방법**   : `INSERT ... ON DUPLICATE KEY UPDATE` (upsert)
# **PRIMARY KEY** : `(date, ticker, indicator)`
#
# ---
#
# | 셀 | 단계 |
# |----|------|
# | 1  | 환경 설정 & 경로 자동 감지 (노트북/데스크탑 자동 판별) |
# | 2  | 모듈 Import & 설정 상수 |
# | 3  | DB 연결 함수 / 조회 함수 |
# | 4  | FMP / FDR 가격 fetch 함수 |
# | 5  | RF(국채금리) fetch 함수 |
# | 6  | Beta · Required Return 계산 함수 |
# | 7  | MySQL 저장 함수 (sanitize + upsert) |
# | 8  | 가격 확보 함수 (ensure_price_series) |
# | 9  | 티커 1개 업데이트 함수 (update_one_ticker) |
# | 10 | SPY / RF 공통 데이터 준비 |
# | 11 | 배치 실행 (구간 지정 · 체크포인트 · 실패 재시도) |
# | 12 | DB 조회 유틸 (pivot 조회) |
# | 13 | 결과 조회 테스트 |
#
# ---
# ### 개선 사항 (V2 → V3)
# - **경로 자동 감지**: 노트북/데스크탑 환경 자동 판별, `config.py` 경유 DB 접속
# - **Python 3.9 호환**: `X | Y` 타입 힌트 제거 → `Optional[X]` 방식 통일
# - **구간 실행**: `TICKER_START` / `TICKER_END` 로 2000개 티커를 단계적으로 처리
# - **진행률 표시**: `[idx/total] (pct%)  ticker` 형태로 실시간 출력
# - **메모리 관리**: 1개 티커 처리 후 즉시 저장 + `gc.collect()` (배치 누적 방지)
# - **로그 통일**: `[HH:MM:SS][TAG] msg` 형태
# - **FDR fallback 강화**: FMP 실패 시 FDR 자동 전환

# %% [markdown]
# ## Cell 1 · 환경 설정 & 경로 자동 감지

# %%
import sys, os, gc, warnings
from pathlib import Path
warnings.filterwarnings("ignore")

# ── 후보 프로젝트 루트 (노트북 / 데스크탑) ───────────────────
_CANDIDATE_ROOTS = [
    r"C:\Users\Hoyoung_Park\PyCharmMiscProject\stock_forecast",         # 노트북
    r"C:\Users\82108\OneDrive\바탕 화면\investment\investment_strategy",  # 데스크탑
]

def _setup_path() -> str:
    """
    DATA/ 폴더를 포함하는 프로젝트 루트를 탐색해 sys.path 에 추가합니다.
    탐색 순서:
      1) cwd / __file__ 상위 경로 중 DATA/ 를 포함하는 첫 번째 경로
      2) _CANDIDATE_ROOTS 에서 DATA/ 가 있는 첫 번째 경로
    """
    try:
        start = Path(__file__).resolve().parent
    except NameError:
        start = Path.cwd()

    for p in [start] + list(start.parents):
        if (p / "DATA").is_dir():
            root = str(p)
            if root not in sys.path:
                sys.path.insert(0, root)
            print(f"[PATH] root 자동 감지 : {root}")
            return root

    for candidate in _CANDIDATE_ROOTS:
        if os.path.isdir(candidate) and os.path.isdir(os.path.join(candidate, "DATA")):
            if candidate not in sys.path:
                sys.path.insert(0, candidate)
            print(f"[PATH] root 후보 경로 : {candidate}")
            return candidate

    raise EnvironmentError(
        "DATA 폴더를 찾을 수 없습니다.\n"
        "_CANDIDATE_ROOTS 를 현재 환경에 맞게 수정하거나 "
        "노트북을 프로젝트 루트 아래에서 실행하세요."
    )

_ROOT = _setup_path()
print(f"[확인] 프로젝트 루트 : {_ROOT}")
print(f"[확인] DATA 경로    : {os.path.join(_ROOT, 'DATA')}")
# Out:
# [PATH] root 자동 감지 : C:\Users\82108\OneDrive\바탕 화면\investment\investment_strategy
# [확인] 프로젝트 루트 : C:\Users\82108\OneDrive\바탕 화면\investment\investment_strategy
# [확인] DATA 경로    : C:\Users\82108\OneDrive\바탕 화면\investment\investment_strategy\DATA

# %% [markdown]
# ## Cell 2 · 모듈 Import & 설정 상수

# %%
# ── 표준 라이브러리 ───────────────────────────────────────────
import math
import time
import requests
from datetime import datetime
from typing import Optional, Dict, Any, List, Tuple
from pandas.tseries.offsets import BDay

# ── 외부 라이브러리 ───────────────────────────────────────────
import numpy as np
import pandas as pd
import pymysql
import FinanceDataReader as fdr
from IPython.display import display

# ── 내부 모듈 ─────────────────────────────────────────────────
from DATA.config import get_db_info, get_engine
from DATA.us_target_ticker_list_2000 import ticker_list as DEFAULT_TICKER_LIST

# ── 로그 유틸 ─────────────────────────────────────────────────
def log(tag: str, msg: str):
    ts = datetime.now().strftime("%H:%M:%S")
    print(f"[{ts}][{tag}] {msg}")

# ══════════════════════════════════════════════════════════════
#  설정 상수 — 여기만 수정하세요
# ══════════════════════════════════════════════════════════════
DB_NAME       = "investar"
TABLE_RESULT  = "us_required_return_result"
DEFAULT_PORT  = 3307
MARKET_TICKER = "SPY"

# FMP API
API_KEY            = "hT0gAk87j9xZx4PlBApvBqfVL5IahvgV"   # ← 필요시 변경
MAX_RETRY          = 5
SLEEP_BETWEEN_CALLS = 0.35
MIN_START_DATE     = "2015-01-01"

# Beta 윈도우
BETA_WINDOWS         = [252, 750, 1250]   # beta_252, beta_750, beta_1250
MAX_ROLLING_WINDOW   = max(BETA_WINDOWS)  # 1250
ROLLING_WARMUP_BDAYS = MAX_ROLLING_WINDOW + 80

# 저장 모드: "minimal" (Re + beta) / "full" (모든 중간값 포함)
STORE_MODE = "minimal"

# 체크포인트
CHECKPOINT_DIR    = "_batch_checkpoint"
os.makedirs(CHECKPOINT_DIR, exist_ok=True)
DEFAULT_DONE_PATH = os.path.join(CHECKPOINT_DIR, "done_tickers.txt")
DEFAULT_FAIL_PATH = os.path.join(CHECKPOINT_DIR, "failed_tickers.txt")

# ══════════════════════════════════════════════════════════════
print(f"[OK] Import 완료")
print(f"[OK] DEFAULT_TICKER_LIST: {len(DEFAULT_TICKER_LIST):,}개")
print(f"[설정] TABLE={TABLE_RESULT}  STORE_MODE={STORE_MODE}")
print(f"[설정] BETA_WINDOWS={BETA_WINDOWS}")
print(f"[설정] MIN_START_DATE={MIN_START_DATE}")
# Out:
# [OK] Import 완료
# [OK] DEFAULT_TICKER_LIST: 2,000개
# [설정] TABLE=us_required_return_result  STORE_MODE=minimal
# [설정] BETA_WINDOWS=[252, 750, 1250]
# [설정] MIN_START_DATE=2015-01-01

# %% [markdown]
# ## Cell 3 · DB 연결 함수 / 조회 함수

# %%
# ── DB 접속 정보 ──────────────────────────────────────────────
db_info = get_db_info()   # config.py 의 get_db_info()


def get_conn(db_info: Dict[str, Any]):
    """pymysql 연결 생성"""
    return pymysql.connect(
        host        = db_info["host"],
        port        = db_info.get("port", DEFAULT_PORT),
        user        = db_info["user"],
        password    = db_info["password"],
        db          = db_info.get("database", DB_NAME),
        charset     = "utf8mb4",
        autocommit  = False,
        cursorclass = pymysql.cursors.DictCursor,
    )


def get_minmax_date_in_db(
    db_info: Dict[str, Any],
    ticker: str,
    indicator: str,
) -> Tuple[Optional[pd.Timestamp], Optional[pd.Timestamp]]:
    """MIN/MAX 날짜를 1회 쿼리로 조회 (커넥션 수 최소화)"""
    sql = f"""
        SELECT MIN(date) AS first_date, MAX(date) AS last_date
        FROM   {TABLE_RESULT}
        WHERE  ticker=%s AND indicator=%s;
    """
    conn = get_conn(db_info)
    try:
        with conn.cursor() as cur:
            cur.execute(sql, (ticker, indicator))
            row = cur.fetchone()
            first_dt = row["first_date"] if row else None
            last_dt  = row["last_date"]  if row else None
    finally:
        conn.close()

    first_dt = pd.to_datetime(first_dt) if first_dt is not None else None
    last_dt  = pd.to_datetime(last_dt)  if last_dt  is not None else None
    return first_dt, last_dt


def read_indicator_series(
    db_info: Dict[str, Any],
    ticker: str,
    indicator: str,
    start_date: Optional[str] = None,
    end_date: Optional[str]   = None,
) -> pd.DataFrame:
    """DB에서 (date, value) 시리즈를 필요 구간만 읽어 반환"""
    where  = ["ticker=%s", "indicator=%s"]
    params = [ticker, indicator]
    if start_date is not None:
        where.append("date >= %s")
        params.append(start_date)
    if end_date is not None:
        where.append("date <= %s")
        params.append(end_date)

    sql = f"""
        SELECT date, value
        FROM   {TABLE_RESULT}
        WHERE  {" AND ".join(where)}
        ORDER  BY date;
    """
    conn = get_conn(db_info)
    try:
        df = pd.read_sql(sql, conn, params=params)
    finally:
        conn.close()

    if df.empty:
        return pd.DataFrame(columns=["date", "value"])

    df["date"]  = pd.to_datetime(df["date"], errors="coerce")
    df["value"] = pd.to_numeric(df["value"], errors="coerce")
    df = df.dropna(subset=["date"]).drop_duplicates("date").sort_values("date")
    return df


# ── 연결 테스트 ───────────────────────────────────────────────
try:
    _c = get_conn(db_info)
    with _c.cursor() as _cur:
        _cur.execute("SELECT 1")
    _c.close()
    log("DB", f"연결 성공  host={db_info.get('host')}  port={db_info.get('port')}  db={db_info.get('database')}")
except Exception as _e:
    log("DB", f"연결 실패: {_e}")
# Out:
# [20:31:54][DB] 연결 성공  host=192.168.0.230  port=3307  db=investar

# %% [markdown]
# ## Cell 4 · FMP / FDR 가격 fetch 함수

# %%
def _get_json(url: str, params: Dict[str, Any]) -> Any:
    """FMP API 호출 (재시도 포함)"""
    last_err = None
    for k in range(MAX_RETRY):
        try:
            r = requests.get(url, params=params, timeout=30)
            if r.status_code == 429:
                time.sleep(1.0 + 0.7 * k)
                continue
            r.raise_for_status()
            return r.json()
        except Exception as e:
            last_err = e
            time.sleep(0.7 + 0.7 * k)
    raise RuntimeError(f"FMP 요청 실패 (재시도 {MAX_RETRY}회): {last_err}")


def fetch_fmp_price(
    symbol: str,
    api_key: str,
    start_date: str,
    end_date: Optional[str]   = None,
    min_start_date: str       = MIN_START_DATE,
) -> pd.DataFrame:
    """
    FMP에서 adjClose 우선으로 가격 fetch.
    start_date 가 min_start_date 보다 최근이면 min_start_date 로 당김.
    반환: columns [date, price]
    """
    if pd.to_datetime(start_date) > pd.to_datetime(min_start_date):
        start_date = min_start_date

    url    = f"https://financialmodelingprep.com/api/v3/historical-price-full/{symbol}"
    params = {"from": start_date, "apikey": api_key}
    if end_date is not None:
        params["to"] = end_date

    try:
        js   = _get_json(url, params=params)
        hist = js.get("historical", []) if isinstance(js, dict) else []
    except Exception:
        return pd.DataFrame(columns=["date", "price"])

    if not hist:
        return pd.DataFrame(columns=["date", "price"])

    df = pd.DataFrame(hist)
    df["date"] = pd.to_datetime(df["date"], errors="coerce")
    df = df.dropna(subset=["date"])
    price_col = "adjClose" if "adjClose" in df.columns else "close"
    df[price_col] = pd.to_numeric(df[price_col], errors="coerce")
    df = (
        df[["date", price_col]]
        .rename(columns={price_col: "price"})
        .dropna(subset=["price"])
        .drop_duplicates("date")
        .sort_values("date")
    )
    return df


def fetch_fdr_price(
    symbol: str,
    start_date: str,
    end_date: str,
) -> pd.DataFrame:
    """FinanceDataReader fallback. 반환: columns [date, price]"""
    try:
        df = fdr.DataReader(symbol, start_date, end_date)
    except Exception:
        return pd.DataFrame(columns=["date", "price"])

    if df is None or df.empty:
        return pd.DataFrame(columns=["date", "price"])

    df = df.copy().reset_index()
    # 날짜 컬럼 통일
    date_col = next((c for c in df.columns if c.lower() in ("date", "index")), df.columns[0])
    df = df.rename(columns={date_col: "date"})

    # 가격 컬럼 우선순위
    for pc in ("Adj Close", "adj close", "Close", "close"):
        if pc in df.columns:
            price_col = pc
            break
    else:
        num_cols = df.select_dtypes(include=[np.number]).columns.tolist()
        if not num_cols:
            return pd.DataFrame(columns=["date", "price"])
        price_col = num_cols[0]

    out = df[["date", price_col]].rename(columns={price_col: "price"})
    out["date"]  = pd.to_datetime(out["date"], errors="coerce")
    out["price"] = pd.to_numeric(out["price"], errors="coerce")
    out = out.dropna(subset=["date", "price"]).drop_duplicates("date").sort_values("date")
    return out


print("[OK] fetch_fmp_price / fetch_fdr_price 함수 정의 완료")
# Out:
# [OK] fetch_fmp_price / fetch_fdr_price 함수 정의 완료

# %% [markdown]
# ## Cell 5 · RF(국채금리) fetch 함수

# %%
def fetch_us_treasury_yields(
    start_date: str,
    end_date: Optional[str] = None,
) -> pd.DataFrame:
    """
    1y / 3y / 5y 미국 국채 수익률을 FRED 또는 Yahoo 로 fetch.
    반환: index=date, columns=[rf_1y, rf_3y, rf_5y]  (소수 단위, 예: 0.045)
    """
    if end_date is None:
        end_date = pd.Timestamp.today().strftime("%Y-%m-%d")

    # 1순위: FRED
    try:
        y1 = fdr.DataReader("FRED:DGS1", start_date, end_date)
        y3 = fdr.DataReader("FRED:DGS3", start_date, end_date)
        y5 = fdr.DataReader("FRED:DGS5", start_date, end_date)
        idx = y1.index.union(y3.index).union(y5.index)
        out = pd.DataFrame(index=idx).sort_index()
        out["rf_1y"] = pd.to_numeric(y1.iloc[:, 0], errors="coerce") / 100.0
        out["rf_3y"] = pd.to_numeric(y3.iloc[:, 0], errors="coerce") / 100.0
        out["rf_5y"] = pd.to_numeric(y5.iloc[:, 0], errors="coerce") / 100.0
        log("RF", f"FRED 로드 성공: {len(out)}행")
        return out
    except Exception:
        pass

    # 2순위: Yahoo (^IRX, ^FVX)
    try:
        y1 = fdr.DataReader("^IRX", start_date, end_date)
        y5 = fdr.DataReader("^FVX", start_date, end_date)
        idx = y1.index.union(y5.index)
        out = pd.DataFrame(index=idx).sort_index()
        out["rf_1y"] = pd.to_numeric(y1["Close"], errors="coerce") / 100.0
        out["rf_5y"] = pd.to_numeric(y5["Close"], errors="coerce") / 100.0
        out["rf_3y"] = out["rf_1y"] + (out["rf_5y"] - out["rf_1y"]) * (3 - 1) / (5 - 1)
        log("RF", f"Yahoo fallback 로드 성공: {len(out)}행")
        return out
    except Exception as e:
        log("RF", f"[WARN] 국채 금리 로드 실패: {e}")
        return pd.DataFrame(columns=["rf_1y", "rf_3y", "rf_5y"])


print("[OK] fetch_us_treasury_yields 함수 정의 완료")
# Out:
# [OK] fetch_us_treasury_yields 함수 정의 완료

# %% [markdown]
# ## Cell 6 · Beta · Required Return 계산 함수

# %%
def rolling_beta(
    ret_stock: pd.Series,
    ret_mkt: pd.Series,
    window: int,
) -> pd.Series:
    """Rolling Beta = Cov(ret_stock, ret_mkt) / Var(ret_mkt)"""
    cov = ret_stock.rolling(window).cov(ret_mkt)
    var = ret_mkt.rolling(window).var()
    return cov / var


def build_features(
    price_stock_df: pd.DataFrame,   # columns: [date, price_stock]
    price_mkt_df: pd.DataFrame,     # columns: [date, price_mkt]
    rf_df: pd.DataFrame,            # index=date, columns=[rf_1y, rf_3y, rf_5y]
) -> pd.DataFrame:
    """
    Beta 및 Required Return (CAPM) 계산.

    저장 지표:
      minimal : beta_252 / beta_750 / beta_1250 / Re_1y / Re_3y / Re_5y
      full    : 위 + price_mkt / ret_stock / ret_mkt / rf_* / E_Rm_*
    """
    df = pd.merge(price_stock_df, price_mkt_df, on="date", how="inner")
    df = df.sort_values("date").drop_duplicates("date").reset_index(drop=True)

    df["price_stock"] = pd.to_numeric(df["price_stock"], errors="coerce")
    df["price_mkt"]   = pd.to_numeric(df["price_mkt"],   errors="coerce")
    df = df.dropna(subset=["price_stock", "price_mkt"])

    df["ret_stock"] = df["price_stock"].pct_change()
    df["ret_mkt"]   = df["price_mkt"].pct_change()

    # Rolling Beta
    for w in BETA_WINDOWS:
        df[f"beta_{w}"] = rolling_beta(df["ret_stock"], df["ret_mkt"], w)

    # RF 조인
    if rf_df is None or rf_df.empty:
        df["rf_1y"] = np.nan
        df["rf_3y"] = np.nan
        df["rf_5y"] = np.nan
    else:
        rf2 = rf_df.copy().sort_index()
        rf2 = rf2.reindex(pd.to_datetime(df["date"])).ffill()
        df["rf_1y"] = rf2["rf_1y"].values
        df["rf_3y"] = rf2["rf_3y"].values
        df["rf_5y"] = rf2["rf_5y"].values

    # 기대 시장 수익률 (연환산)
    df["E_Rm_1y"] = df["ret_mkt"].rolling(252).mean()  * 252
    df["E_Rm_3y"] = df["ret_mkt"].rolling(750).mean()  * 252
    df["E_Rm_5y"] = df["ret_mkt"].rolling(1250).mean() * 252

    # CAPM Required Return
    df["Re_1y"] = df["rf_1y"] + df["beta_252"]  * (df["E_Rm_1y"] - df["rf_1y"])
    df["Re_3y"] = df["rf_3y"] + df["beta_750"]  * (df["E_Rm_3y"] - df["rf_3y"])
    df["Re_5y"] = df["rf_5y"] + df["beta_1250"] * (df["E_Rm_5y"] - df["rf_5y"])

    return df


print("[OK] rolling_beta / build_features 함수 정의 완료")
print(f"     BETA_WINDOWS = {BETA_WINDOWS}")
print(f"     저장 지표 (minimal): beta_252/750/1250, Re_1y/3y/5y")
# Out:
# [OK] rolling_beta / build_features 함수 정의 완료
#      BETA_WINDOWS = [252, 750, 1250]
#      저장 지표 (minimal): beta_252/750/1250, Re_1y/3y/5y

# %% [markdown]
# ## Cell 7 · MySQL 저장 함수 (sanitize + upsert)
#
# - NaN / inf → `None` 변환 후 저장
# - `INSERT ... ON DUPLICATE KEY UPDATE value = VALUES(value)`
# - ticker 단위로 커넥션 분리 → 메모리/커넥션 부담 최소화

# %%
def _to_mysql_float(x: Any) -> Optional[float]:
    """NaN / inf → None, 그 외 float 반환"""
    if x is None:
        return None
    try:
        v = float(x)
    except Exception:
        return None
    return None if (math.isnan(v) or math.isinf(v)) else v


def sanitize_long_for_mysql(df: pd.DataFrame) -> pd.DataFrame:
    """저장 전 데이터 정제"""
    out = df.copy()
    out["date"]      = pd.to_datetime(out["date"], errors="coerce")
    out = out[out["date"].notna()]
    out["date"]      = out["date"].dt.date
    out["ticker"]    = out["ticker"].astype(str)
    out["indicator"] = out["indicator"].astype(str)
    out = out[~out["ticker"].str.lower().isin(["nan", "none"])]
    out = out[~out["indicator"].str.lower().isin(["nan", "none"])]
    out["value"]     = pd.to_numeric(out["value"], errors="coerce")
    out["value"]     = out["value"].apply(_to_mysql_float)
    out = out.drop_duplicates(subset=["date", "ticker", "indicator"])
    return out


def upsert_long_df(
    db_info: Dict[str, Any],
    long_df: pd.DataFrame,
    batch_size_rows: int   = 50_000,
    batch_size_ticker: int = 50,
    drop_null_values: bool = True,
) -> int:
    """
    long_df → DB upsert.
    PK (date, ticker, indicator) 중복 시 value 업데이트.
    Returns: 저장 행 수
    """
    if long_df is None or long_df.empty:
        return 0

    df = sanitize_long_for_mysql(long_df)
    if drop_null_values:
        df = df.dropna(subset=["value"])
    if df.empty:
        return 0

    tickers = sorted(df["ticker"].unique())
    total_saved = 0

    insert_sql = f"""
        INSERT INTO {TABLE_RESULT} (date, ticker, indicator, value)
        VALUES (%s, %s, %s, %s)
        ON DUPLICATE KEY UPDATE
            value = VALUES(value);
    """

    for i in range(0, len(tickers), batch_size_ticker):
        batch_tickers = tickers[i : i + batch_size_ticker]
        batch = (
            df[df["ticker"].isin(batch_tickers)]
            .sort_values(["ticker", "date", "indicator"])
        )
        rows = list(batch[["date", "ticker", "indicator", "value"]].itertuples(index=False, name=None))

        conn = get_conn(db_info)
        try:
            with conn.cursor() as cur:
                for j in range(0, len(rows), batch_size_rows):
                    chunk = rows[j : j + batch_size_rows]
                    # NaN/inf 샘플 검사
                    for _r in chunk[:10]:
                        vv = _r[3]
                        if isinstance(vv, float) and (math.isnan(vv) or math.isinf(vv)):
                            raise ValueError(f"NaN/inf 발견: {_r}")
                    cur.executemany(insert_sql, chunk)
            conn.commit()
            log("DB", f"batch {i//batch_size_ticker+1}: tickers={len(batch_tickers)}, rows={len(rows):,}")
            total_saved += len(rows)
        except Exception:
            conn.rollback()
            raise
        finally:
            conn.close()

    return total_saved


# ── 체크포인트 유틸 ───────────────────────────────────────────
def _load_set(path: str) -> set:
    if not os.path.exists(path):
        return set()
    with open(path, "r", encoding="utf-8") as f:
        return {line.strip() for line in f if line.strip()}

def _append_line(path: str, line: str) -> None:
    with open(path, "a", encoding="utf-8") as f:
        f.write(line.strip() + "\n")


print("[OK] sanitize_long_for_mysql / upsert_long_df 함수 정의 완료")
# Out:
# [OK] sanitize_long_for_mysql / upsert_long_df 함수 정의 완료

# %% [markdown]
# ## Cell 8 · 가격 확보 함수 (ensure_price_series)
#
# - DB에 있는 구간 확인 → **부족분만** FMP 또는 FDR 호출
# - backfill (과거) / forward (최신) 각각 필요한 구간만 요청
# - FMP 실패 시 FDR 자동 fallback

# %%
def ensure_price_series(
    db_info: Dict[str, Any],
    ticker: str,
    api_key: str,
    indicator_name: str       = "price_stock",
    today_iso: Optional[str]  = None,
    min_start_date: str       = MIN_START_DATE,
    return_start_date: Optional[str] = None,
) -> pd.DataFrame:
    """
    DB에서 가격을 확인하고 부족분만 FMP/FDR 로 fetch 후 저장.

    Returns
    -------
    DataFrame  columns: [date, {indicator_name}]
    """
    if today_iso is None:
        today_iso = datetime.utcnow().date().isoformat()

    first_dt, last_dt = get_minmax_date_in_db(db_info, ticker, indicator_name)

    def _fetch(start: str, end: Optional[str]) -> pd.DataFrame:
        """FMP 먼저, 실패 시 FDR fallback"""
        df = fetch_fmp_price(ticker, api_key, start, end, min_start_date)
        time.sleep(SLEEP_BETWEEN_CALLS)
        if df.empty:
            df = fetch_fdr_price(ticker, start, end or today_iso)
        return df

    def _store(df_price: pd.DataFrame):
        if df_price is None or df_price.empty:
            return
        df2 = df_price.rename(columns={"price": indicator_name}).copy()
        long_new = df2.assign(ticker=ticker).melt(
            id_vars=["date", "ticker"],
            value_vars=[indicator_name],
            var_name="indicator",
            value_name="value",
        )
        upsert_long_df(db_info, long_new, drop_null_values=True)

    # (A) DB에 데이터 없음 → 전 구간 fetch
    if last_dt is None:
        df_new = _fetch(min_start_date, today_iso)
        if not df_new.empty:
            _store(df_new)
        out = df_new.rename(columns={"price": indicator_name}).drop_duplicates("date").sort_values("date")
        if return_start_date:
            out = out[out["date"] >= pd.to_datetime(return_start_date)]
        return out

    # (B) 과거 backfill — min_start_date 보다 늦게 시작한 경우
    if first_dt is not None and first_dt.date().isoformat() > min_start_date:
        back_end = (first_dt - pd.Timedelta(days=1)).date().isoformat()
        df_back  = _fetch(min_start_date, back_end)
        if not df_back.empty:
            _store(df_back)

    # (C) 최신 forward
    start_missing = (last_dt + pd.Timedelta(days=1)).date().isoformat()
    if start_missing <= today_iso:
        df_fwd = _fetch(start_missing, today_iso)
        if not df_fwd.empty:
            _store(df_fwd)

    # (D) 필요 구간만 DB에서 읽어 반환
    df_db = read_indicator_series(
        db_info, ticker, indicator_name,
        start_date=return_start_date, end_date=today_iso,
    ).rename(columns={"value": indicator_name})
    df_db["date"] = pd.to_datetime(df_db["date"], errors="coerce")
    df_db = df_db.dropna(subset=["date"]).drop_duplicates("date").sort_values("date")
    return df_db


print("[OK] ensure_price_series 함수 정의 완료")
# Out:
# [OK] ensure_price_series 함수 정의 완료

# %% [markdown]
# ## Cell 9 · 티커 1개 업데이트 함수 (update_one_ticker)
#
# - `last_saved_date` 이후 데이터만 저장 (중복 저장 방지)
# - `price_stock` 은 `ensure_price_series` 에서 이미 저장 → 재저장 금지

# %%
def _pick_ref_indicator(store_mode: str) -> str:
    """저장 여부 판단 기준 지표 (Re_5y 가 가장 보수적)"""
    return "Re_5y"


def update_one_ticker(
    db_info: Dict[str, Any],
    ticker: str,
    api_key: str,
    spy_price_df: pd.DataFrame,   # columns: [date, price_mkt]
    rf_df: pd.DataFrame,          # index=date, columns=[rf_1y, rf_3y, rf_5y]
    today_iso: Optional[str]  = None,
    min_start_date: str       = MIN_START_DATE,
    store_mode: str           = "minimal",
) -> Tuple[bool, str]:
    """
    티커 1개에 대해 가격 확보 → 계산 → DB 저장 수행.

    Returns
    -------
    (True, 성공 메시지) or (False, 실패 메시지)
    """
    if today_iso is None:
        today_iso = datetime.utcnow().date().isoformat()

    if spy_price_df is None or spy_price_df.empty:
        return (False, "SPY price df 없음")

    # 0) 마지막 저장일 확인 → 중복 계산/저장 방지
    ref_ind          = _pick_ref_indicator(store_mode)
    _, last_saved    = get_minmax_date_in_db(db_info, ticker, ref_ind)

    if last_saved is not None:
        calc_start_dt = (pd.to_datetime(last_saved) - BDay(ROLLING_WARMUP_BDAYS)).date().isoformat()
        save_after_dt = pd.to_datetime(last_saved).date()
    else:
        calc_start_dt = min_start_date
        save_after_dt = None

    # 1) 종목 가격 확보 (필요 구간만 FMP fetch) + DB 저장
    px_stock = ensure_price_series(
        db_info           = db_info,
        ticker            = ticker,
        api_key           = api_key,
        indicator_name    = "price_stock",
        today_iso         = today_iso,
        min_start_date    = min_start_date,
        return_start_date = calc_start_dt,
    )
    if px_stock.empty:
        return (False, f"{ticker}: price_stock empty")

    # 2) SPY 가격을 calc_start_dt 이후 구간만 슬라이싱
    spy2 = spy_price_df.copy()
    spy2["date"] = pd.to_datetime(spy2["date"], errors="coerce")
    spy2 = spy2.dropna(subset=["date", "price_mkt"])
    spy2 = spy2[spy2["date"] >= pd.to_datetime(calc_start_dt)]
    if spy2.empty:
        return (False, f"{ticker}: SPY slice empty from {calc_start_dt}")

    # 3) 계산
    feat = build_features(
        price_stock_df = px_stock[["date", "price_stock"]],
        price_mkt_df   = spy2[["date", "price_mkt"]],
        rf_df          = rf_df,
    )
    if feat.empty:
        return (False, f"{ticker}: feature df empty")

    feat["ticker"] = ticker

    # 4) 저장 컬럼 선택
    if store_mode == "full":
        keep_cols = [
            # price_stock 은 ensure_price_series 에서 이미 저장 → 제외
            "price_mkt", "ret_stock", "ret_mkt",
            "beta_252", "beta_750", "beta_1250",
            "rf_1y", "rf_3y", "rf_5y",
            "E_Rm_1y", "E_Rm_3y", "E_Rm_5y",
            "Re_1y", "Re_3y", "Re_5y",
        ]
    else:  # minimal
        keep_cols = [
            "beta_252", "beta_750", "beta_1250",
            "Re_1y", "Re_3y", "Re_5y",
        ]
    keep_cols = [c for c in keep_cols if c in feat.columns]

    # 5) last_saved 이후만 저장 → 중복 upsert 방지
    if save_after_dt is not None:
        feat = feat[pd.to_datetime(feat["date"]).dt.date > save_after_dt]
        if feat.empty:
            return (True, f"{ticker}: up-to-date (no new rows after {save_after_dt})")

    # 6) wide → long melt
    long_df = feat[["date", "ticker"] + keep_cols].melt(
        id_vars    = ["date", "ticker"],
        value_vars = keep_cols,
        var_name   = "indicator",
        value_name = "value",
    )
    long_df["value"] = pd.to_numeric(long_df["value"], errors="coerce")
    long_df = long_df.replace([np.inf, -np.inf], np.nan).dropna(subset=["value"])

    if long_df.empty:
        return (False, f"{ticker}: 모든 값 NaN")

    # 7) DB 저장
    n_saved = upsert_long_df(db_info, long_df, drop_null_values=True)
    return (True, f"{ticker}: saved {n_saved:,}행 ({store_mode}) from {calc_start_dt}")


print("[OK] update_one_ticker 함수 정의 완료")
# Out:
# [OK] update_one_ticker 함수 정의 완료

# %% [markdown]
# ## Cell 10 · SPY / RF 공통 데이터 준비
#
# SPY 가격과 RF(국채금리)는 배치 전 1회만 fetch해서 모든 티커에 재사용합니다.

# %%
def prepare_spy_and_rf(
    db_info: Dict[str, Any],
    api_key: str,
    today_iso: str,
    min_start_date: str = MIN_START_DATE,
) -> Tuple[pd.DataFrame, pd.DataFrame]:
    """
    SPY 가격 + RF 를 1회 fetch 후 반환.
    SPY 가격은 DB에도 저장 (ensure_price_series 경유).

    Returns
    -------
    (spy_price_df, rf_df)
      spy_price_df : columns [date, price_mkt]
      rf_df        : index=date, columns=[rf_1y, rf_3y, rf_5y]
    """
    log("PREP", "SPY 가격 확보 시작")
    spy_px = ensure_price_series(
        db_info           = db_info,
        ticker            = MARKET_TICKER,
        api_key           = api_key,
        indicator_name    = "price_stock",
        today_iso         = today_iso,
        min_start_date    = min_start_date,
        return_start_date = min_start_date,
    )

    # FDR 최종 안전망
    if spy_px.empty:
        log("PREP", "[WARN] SPY ensure 실패 → FDR 직접 fallback")
        df_fdr = fetch_fdr_price(MARKET_TICKER, min_start_date, today_iso)
        if not df_fdr.empty:
            df2 = df_fdr.rename(columns={"price": "price_stock"})
            long_new = df2.assign(ticker=MARKET_TICKER).melt(
                id_vars=["date", "ticker"], value_vars=["price_stock"],
                var_name="indicator", value_name="value",
            )
            upsert_long_df(db_info, long_new, drop_null_values=True)
            spy_px = df2[["date", "price_stock"]].copy()

    if spy_px.empty:
        raise RuntimeError("SPY 가격 확보 실패. API_KEY / 네트워크 / FDR 상태를 확인하세요.")

    spy_price_df = (
        spy_px
        .rename(columns={"price_stock": "price_mkt"})
        [["date", "price_mkt"]]
        .copy()
    )
    spy_price_df["date"]      = pd.to_datetime(spy_price_df["date"])
    spy_price_df["price_mkt"] = pd.to_numeric(spy_price_df["price_mkt"], errors="coerce")
    spy_price_df = (
        spy_price_df
        .dropna(subset=["date", "price_mkt"])
        .drop_duplicates("date")
        .sort_values("date")
    )
    log("PREP", f"SPY 가격: {len(spy_price_df)}행  ({spy_price_df['date'].iloc[0].date()} ~ {spy_price_df['date'].iloc[-1].date()})")

    # RF
    start_for_rf = spy_price_df["date"].min().date().isoformat()
    end_for_rf   = spy_price_df["date"].max().date().isoformat()
    log("PREP", f"RF 로드 중: {start_for_rf} ~ {end_for_rf}")
    rf_df = fetch_us_treasury_yields(start_for_rf, end_for_rf)
    if rf_df is None or rf_df.empty:
        log("PREP", "[WARN] RF 로드 실패 → Required Return 이 NaN 이 될 수 있습니다.")

    return spy_price_df, rf_df


print("[OK] prepare_spy_and_rf 함수 정의 완료")
# Out:
# [OK] prepare_spy_and_rf 함수 정의 완료

# %% [markdown]
# ## Cell 11 · 배치 실행
#
# ### 실행 모드
# | 변수 | 설명 |
# |------|------|
# | `RUN_TICKERS` | `None` → 구간/전체 실행 / 리스트 → 해당 티커만 |
# | `TICKER_START` | 리스트 슬라이싱 시작 인덱스 (0부터) |
# | `TICKER_END` | 슬라이싱 끝 인덱스 (None = 끝까지) |
# | `SKIP_DONE` | True → 체크포인트에 있는 티커 건너뜀 |
# | `RETRY_FAILED` | True → 실패 티커 1회 재시도 |
#
# ### 구간 예시
# ```python
# TICKER_START, TICKER_END = 0,    500   # 0~499번째
# TICKER_START, TICKER_END = 500,  1000  # 500~999번째
# TICKER_START, TICKER_END = None, None  # 전체
# ```
#
# ### 메모리 전략
# > 1개 처리 → 즉시 저장 → `gc.collect()` → 다음 티커
# > 완료 티커는 `done_tickers.txt` 에 기록 → 재시작 시 중복 처리 방지

# %%
# ══════════════════════════════════════════════════════════════
#  배치 설정 — 여기를 수정하세요
# ══════════════════════════════════════════════════════════════

RUN_TICKERS  = None          # type: Optional[List[str]]
# RUN_TICKERS = ["AAPL", "MSFT", "NVDA"]   # 특정 티커만

TICKER_START = 10             # type: Optional[int]
TICKER_END   = 2000           # type: Optional[int]
# 전체: TICKER_START = None, TICKER_END = None

RUN_STORE_MODE   = STORE_MODE   # "minimal" or "full"
SKIP_DONE        = True          # True: 체크포인트 티커 스킵
RETRY_FAILED     = True          # True: 실패 티커 1회 재시도

DONE_PATH = DEFAULT_DONE_PATH
FAIL_PATH = DEFAULT_FAIL_PATH

# ══════════════════════════════════════════════════════════════
#  실행 대상 결정
# ══════════════════════════════════════════════════════════════
if RUN_TICKERS is not None:
    tickers = RUN_TICKERS
    log("BATCH", f"모드: 특정 티커 지정  {tickers}")
else:
    tickers = DEFAULT_TICKER_LIST[TICKER_START:TICKER_END]
    _s = TICKER_START if TICKER_START is not None else 0
    _e = TICKER_END   if TICKER_END   is not None else len(DEFAULT_TICKER_LIST)
    log("BATCH", f"모드: 구간 실행  index {_s} ~ {_e-1}  ({len(tickers)}개)")

total     = len(tickers)
today_iso = datetime.utcnow().date().isoformat()
done_set  = _load_set(DONE_PATH) if SKIP_DONE else set()
fail_set  = set()

# ── SPY / RF 공통 데이터 준비 (배치 전 1회) ──────────────────
spy_price_df, rf_df = prepare_spy_and_rf(
    db_info        = db_info,
    api_key        = API_KEY,
    today_iso      = today_iso,
    min_start_date = MIN_START_DATE,
)

success, skipped, errored = 0, 0, 0

log("BATCH", "=" * 70)
log("BATCH", f"시작  | {total}개 티커 | store_mode={RUN_STORE_MODE}")
log("BATCH", f"skip_done={SKIP_DONE}  retry_failed={RETRY_FAILED}")
log("BATCH", f"체크포인트 완료: {len(done_set)}개")
log("BATCH", "=" * 70)


def _run_one(ticker: str) -> Tuple[bool, str]:
    """티커 1개 처리. (True, msg) or (False, msg) 반환."""
    try:
        ok, msg = update_one_ticker(
            db_info        = db_info,
            ticker         = ticker,
            api_key        = API_KEY,
            spy_price_df   = spy_price_df,
            rf_df          = rf_df,
            today_iso      = today_iso,
            min_start_date = MIN_START_DATE,
            store_mode     = RUN_STORE_MODE,
        )
    except Exception as e:
        return (False, f"{ticker}: 예외 발생 → {e}")
    finally:
        gc.collect()
    return ok, msg


# ── 메인 루프 ─────────────────────────────────────────────────
for idx, ticker in enumerate(tickers, 1):
    ticker = str(ticker).strip()
    if not ticker:
        continue

    pct = idx / total * 100
    log("PROGRESS", f"[{idx:>4}/{total}] ({pct:5.1f}%)  >>  {ticker}")

    if SKIP_DONE and ticker in done_set:
        log(ticker, "[SKIP] 이미 완료 (체크포인트)")
        skipped += 1
        continue

    ok, msg = _run_one(ticker)
    if ok:
        log(ticker, f"[OK] {msg}")
        _append_line(DONE_PATH, ticker)
        done_set.add(ticker)
        success += 1
    else:
        log(ticker, f"[FAIL] {msg}")
        _append_line(FAIL_PATH, ticker)
        fail_set.add(ticker)
        errored += 1

# ── 실패 티커 재시도 ──────────────────────────────────────────
if RETRY_FAILED and fail_set:
    log("RETRY", f"실패 티커 {len(fail_set)}개 재시도")
    still_fail = set()
    for ticker in sorted(fail_set):
        ok, msg = _run_one(ticker)
        if ok:
            log(ticker, f"[RETRY-OK] {msg}")
            _append_line(DONE_PATH, ticker)
            done_set.add(ticker)
            success += 1
            errored -= 1
        else:
            log(ticker, f"[RETRY-FAIL] {msg}")
            still_fail.add(ticker)
    log("RETRY", f"재시도 완료. 최종 실패: {len(still_fail)}개")

# ── 배치 요약 ─────────────────────────────────────────────────
log("BATCH", "=" * 70)
log("BATCH", f"완료 | 성공={success}  스킵={skipped}  실패={errored}  합계={total}")
log("BATCH", f"체크포인트: {DONE_PATH}")
log("BATCH", "=" * 70)
# Out:
# [20:40:20][BATCH] 모드: 구간 실행  index 10 ~ 1999  (1990개)
# [20:40:20][PREP] SPY 가격 확보 시작
# [20:40:38][DB] batch 1: tickers=1, rows=2,829
# [20:40:58][PREP] [WARN] SPY ensure 실패 → FDR 직접 fallback
# [20:41:00][DB] batch 1: tickers=1, rows=2,830
# [20:41:00][PREP] SPY 가격: 2830행  (2014-12-31 ~ 2026-04-02)
# [20:41:00][PREP] RF 로드 중: 2014-12-31 ~ 2026-04-02
# [20:41:01][RF] Yahoo fallback 로드 성공: 2937행
# [20:41:01][BATCH] ======================================================================
# [20:41:01][BATCH] 시작  | 1990개 티커 | store_mode=minimal
# [20:41:01][BATCH] skip_done=True  retry_failed=True
# [20:41:01][BATCH] 체크포인트 완료: 3575개
# [20:41:01][BATCH] ======================================================================
# [20:41:01][PROGRESS] [   1/1990] (  0.1%)  >>  WMT
# [20:41:01][WMT] [SKIP] 이미 완료 (체크포인트)
# [20:41:01][PROGRESS] [   2/1990] (  0.1%)  >>  XOM
# [20:41:01][XOM] [SKIP] 이미 완료 (체크포인트)
# [20:41:01][PROGRESS] [   3/1990] (  0.2%)  >>  ASML
# [20:41:01][ASML] [SKIP] 이미 완료 (체크포인트)
# [20:41:01][PROGRESS] [   4/1990] (  0.2%)  >>  JNJ
# [20:41:01][JNJ] [SKIP] 이미 완료 (체크포인트)
# [20:41:01][PROGRESS] [   5/1990] (  0.3%)  >>  ORCL
# [20:41:01][ORCL] [SKIP] 이미 완료 (체크포인트)
# [20:41:01][PROGRESS] [   6/1990] (  0.3%)  >>  MU
# [20:41:01][MU] [SKIP] 이미 완료 (체크포인트)
# [20:41:01][PROGRESS] [   7/1990] (  0.4%)  >>  COST
# [20:41:01][COST] [SKIP] 이미 완료 (체크포인트)
# [20:41:01][PROGRESS] [   8/1990] (  0.4%)  >>  AMD
# [20:41:33][DB] batch 1: tickers=1, rows=2,829
# [20:41:43][AMD] [FAIL] AMD: price_stock empty
# [20:41:43][PROGRESS] [   9/1990] (  0.5%)  >>  BABA
# [20:41:43][BABA] [SKIP] 이미 완료 (체크포인트)
# [20:41:43][PROGRESS] [  10/1990] (  0.5%)  >>  NFLX
# [20:41:43][NFLX] [SKIP] 이미 완료 (체크포인트)
# [20:41:43][PROGRESS] [  11/1990] (  0.6%)  >>  ABBV
# [20:41:43][ABBV] [SKIP] 이미 완료 (체크포인트)
# [20:41:43][PROGRESS] [  12/1990] (  0.6%)  >>  HD
# [20:41:43][HD] [SKIP] 이미 완료 (체크포인트)
# [20:41:43][PROGRESS] [  13/1990] (  0.7%)  >>  PG
# [20:41:43][PG] [SKIP] 이미 완료 (체크포인트)
# [20:41:43][PROGRESS] [  14/1990] (  0.7%)  >>  CVX
# [20:41:43][CVX] [SKIP] 이미 완료 (체크포인트)
# [20:41:43][PROGRESS] [  15/1990] (  0.8%)  >>  UNH
# [20:41:43][UNH] [SKIP] 이미 완료 (체크포인트)
# [20:41:43][PROGRESS] [  16/1990] (  0.8%)  >>  KO
# [20:41:43][KO] [SKIP] 이미 완료 (체크포인트)
# [20:41:43][PROGRESS] [  17/1990] (  0.9%)  >>  GE
# [20:41:43][GE] [SKIP] 이미 완료 (체크포인트)
# [20:41:43][PROGRESS] [  18/1990] (  0.9%)  >>  CSCO
# [20:41:43][CSCO] [SKIP] 이미 완료 (체크포인트)
# [20:41:43][PROGRESS] [  19/1990] (  1.0%)  >>  CAT
# [20:41:43][CAT] [SKIP] 이미 완료 (체크포인트)
# [20:41:43][PROGRESS] [  20/1990] (  1.0%)  >>  TM
# [20:41:43][TM] [SKIP] 이미 완료 (체크포인트)
# [20:41:43][PROGRESS] [  21/1990] (  1.1%)  >>  AZN
# [20:41:43][AZN] [SKIP] 이미 완료 (체크포인트)
# [20:41:43][PROGRESS] [  22/1990] (  1.1%)  >>  NVS
# [20:41:43][NVS] [SKIP] 이미 완료 (체크포인트)
# [20:41:43][PROGRESS] [  23/1990] (  1.2%)  >>  NVO
# [20:41:43][NVO] [SKIP] 이미 완료 (체크포인트)
# [20:41:43][PROGRESS] [  24/1990] (  1.2%)  >>  LRCX
# [20:41:43][LRCX] [SKIP] 이미 완료 (체크포인트)
# [20:41:43][PROGRESS] [  25/1990] (  1.3%)  >>  SAP
# [20:41:43][SAP] [SKIP] 이미 완료 (체크포인트)
# [20:41:43][PROGRESS] [  26/1990] (  1.3%)  >>  IBM
# [20:41:43][IBM] [SKIP] 이미 완료 (체크포인트)
# [20:41:43][PROGRESS] [  27/1990] (  1.4%)  >>  PM
# [20:41:43][PM] [SKIP] 이미 완료 (체크포인트)
# [20:41:43][PROGRESS] [  28/1990] (  1.4%)  >>  MRK
# [20:41:43][MRK] [SKIP] 이미 완료 (체크포인트)
# [20:41:43][PROGRESS] [  29/1990] (  1.5%)  >>  RTX
# [20:41:43][RTX] [SKIP] 이미 완료 (체크포인트)
# [20:41:43][PROGRESS] [  30/1990] (  1.5%)  >>  AMAT
# [20:41:43][AMAT] [SKIP] 이미 완료 (체크포인트)
# [20:41:43][PROGRESS] [  31/1990] (  1.6%)  >>  VZA
# [20:41:43][VZA] [SKIP] 이미 완료 (체크포인트)
# [20:41:43][PROGRESS] [  32/1990] (  1.6%)  >>  TMO
# [20:41:43][TMO] [SKIP] 이미 완료 (체크포인트)
# [20:41:43][PROGRESS] [  33/1990] (  1.7%)  >>  MCD
# [20:41:43][MCD] [SKIP] 이미 완료 (체크포인트)
# [20:41:43][PROGRESS] [  34/1990] (  1.7%)  >>  CRM
# [20:41:43][CRM] [SKIP] 이미 완료 (체크포인트)
# [20:41:43][PROGRESS] [  35/1990] (  1.8%)  >>  SHEL
# [20:41:43][SHEL] [SKIP] 이미 완료 (체크포인트)
# [20:41:43][PROGRESS] [  36/1990] (  1.8%)  >>  LIN
# [20:41:43][LIN] [SKIP] 이미 완료 (체크포인트)
# [20:41:43][PROGRESS] [  37/1990] (  1.9%)  >>  INTC
# [20:41:43][INTC] [SKIP] 이미 완료 (체크포인트)
# [20:41:43][PROGRESS] [  38/1990] (  1.9%)  >>  TMUS
# [20:41:43][TMUS] [SKIP] 이미 완료 (체크포인트)
# [20:41:43][PROGRESS] [  39/1990] (  2.0%)  >>  KLAC
# [20:41:43][KLAC] [SKIP] 이미 완료 (체크포인트)
# [20:41:43][PROGRESS] [  40/1990] (  2.0%)  >>  PEP
# [20:41:43][PEP] [SKIP] 이미 완료 (체크포인트)
# [20:41:43][PROGRESS] [  41/1990] (  2.1%)  >>  DIS
# [20:41:43][DIS] [SKIP] 이미 완료 (체크포인트)
# [20:41:43][PROGRESS] [  42/1990] (  2.1%)  >>  BA
# [20:41:43][BA] [SKIP] 이미 완료 (체크포인트)
# [20:41:43][PROGRESS] [  43/1990] (  2.2%)  >>  APH
# [20:41:43][APH] [SKIP] 이미 완료 (체크포인트)
# [20:41:43][PROGRESS] [  44/1990] (  2.2%)  >>  ISRG
# [20:41:43][ISRG] [SKIP] 이미 완료 (체크포인트)
# [20:41:43][PROGRESS] [  45/1990] (  2.3%)  >>  ABT
# [20:41:43][ABT] [SKIP] 이미 완료 (체크포인트)
# [20:41:43][PROGRESS] [  46/1990] (  2.3%)  >>  AMGN
# [20:41:43][AMGN] [SKIP] 이미 완료 (체크포인트)
# [20:41:43][PROGRESS] [  47/1990] (  2.4%)  >>  ANET
# [20:41:43][ANET] [SKIP] 이미 완료 (체크포인트)
# [20:41:43][PROGRESS] [  48/1990] (  2.4%)  >>  TXN
# [20:41:43][TXN] [SKIP] 이미 완료 (체크포인트)
# [20:41:43][PROGRESS] [  49/1990] (  2.5%)  >>  SHOP
# [20:41:43][SHOP] [SKIP] 이미 완료 (체크포인트)
# [20:41:43][PROGRESS] [  50/1990] (  2.5%)  >>  ACN
# [20:41:43][ACN] [SKIP] 이미 완료 (체크포인트)
# [20:41:43][PROGRESS] [  51/1990] (  2.6%)  >>  BHP
# [20:41:43][BHP] [SKIP] 이미 완료 (체크포인트)
# [20:41:43][PROGRESS] [  52/1990] (  2.6%)  >>  GILD
# [20:41:43][GILD] [SKIP] 이미 완료 (체크포인트)
# [20:41:43][PROGRESS] [  53/1990] (  2.7%)  >>  DHR
# [20:41:43][DHR] [SKIP] 이미 완료 (체크포인트)
# [20:41:43][PROGRESS] [  54/1990] (  2.7%)  >>  VZ
# [20:41:43][VZ] [SKIP] 이미 완료 (체크포인트)
# [20:41:43][PROGRESS] [  55/1990] (  2.8%)  >>  TJX
# [20:41:43][TJX] [SKIP] 이미 완료 (체크포인트)
# [20:41:43][PROGRESS] [  56/1990] (  2.8%)  >>  T
# [20:41:43][T] [SKIP] 이미 완료 (체크포인트)
# [20:41:43][PROGRESS] [  57/1990] (  2.9%)  >>  QCOM
# [20:41:43][QCOM] [SKIP] 이미 완료 (체크포인트)
# [20:41:43][PROGRESS] [  58/1990] (  2.9%)  >>  BKNG
# [20:41:43][BKNG] [SKIP] 이미 완료 (체크포인트)
# [20:41:43][PROGRESS] [  59/1990] (  3.0%)  >>  TTE
# [20:41:43][TTE] [SKIP] 이미 완료 (체크포인트)
# [20:41:43][PROGRESS] [  60/1990] (  3.0%)  >>  INTU
# [20:41:43][INTU] [SKIP] 이미 완료 (체크포인트)
# [20:41:43][PROGRESS] [  61/1990] (  3.1%)  >>  LOW
# [20:41:43][LOW] [SKIP] 이미 완료 (체크포인트)
# [20:41:43][PROGRESS] [  62/1990] (  3.1%)  >>  SCCO
# [20:41:43][SCCO] [SKIP] 이미 완료 (체크포인트)
# [20:41:43][PROGRESS] [  63/1990] (  3.2%)  >>  ADI
# [20:41:43][ADI] [SKIP] 이미 완료 (체크포인트)
# [20:41:43][PROGRESS] [  64/1990] (  3.2%)  >>  PFE
# [20:41:43][PFE] [SKIP] 이미 완료 (체크포인트)
# [20:41:43][PROGRESS] [  65/1990] (  3.3%)  >>  RIO
# [20:41:43][RIO] [SKIP] 이미 완료 (체크포인트)
# [20:41:43][PROGRESS] [  66/1990] (  3.3%)  >>  UL
# [20:41:43][UL] [SKIP] 이미 완료 (체크포인트)
# [20:41:43][PROGRESS] [  67/1990] (  3.4%)  >>  NOW
# [20:41:43][NOW] [SKIP] 이미 완료 (체크포인트)
# [20:41:43][PROGRESS] [  68/1990] (  3.4%)  >>  HON
# [20:41:43][HON] [SKIP] 이미 완료 (체크포인트)
# [20:41:43][PROGRESS] [  69/1990] (  3.5%)  >>  DE
# [20:41:43][DE] [SKIP] 이미 완료 (체크포인트)
# [20:41:43][PROGRESS] [  70/1990] (  3.5%)  >>  BSX
# [20:41:43][BSX] [SKIP] 이미 완료 (체크포인트)
# [20:41:43][PROGRESS] [  71/1990] (  3.6%)  >>  NEM
# [20:41:43][NEM] [SKIP] 이미 완료 (체크포인트)
# [20:41:43][PROGRESS] [  72/1990] (  3.6%)  >>  SONY
# [20:41:43][SONY] [SKIP] 이미 완료 (체크포인트)
# [20:41:43][PROGRESS] [  73/1990] (  3.7%)  >>  UNP
# [20:41:43][UNP] [SKIP] 이미 완료 (체크포인트)
# [20:41:43][PROGRESS] [  74/1990] (  3.7%)  >>  SYK
# [20:41:43][SYK] [SKIP] 이미 완료 (체크포인트)
# [20:41:43][PROGRESS] [  75/1990] (  3.8%)  >>  LMT
# [20:41:43][LMT] [SKIP] 이미 완료 (체크포인트)
# [20:41:43][PROGRESS] [  76/1990] (  3.8%)  >>  BUD
# [20:41:43][BUD] [SKIP] 이미 완료 (체크포인트)
# [20:41:43][PROGRESS] [  77/1990] (  3.9%)  >>  MDT
# [20:41:43][MDT] [SKIP] 이미 완료 (체크포인트)
# [20:41:43][PROGRESS] [  78/1990] (  3.9%)  >>  ETN
# [20:41:43][ETN] [SKIP] 이미 완료 (체크포인트)
# [20:41:43][PROGRESS] [  79/1990] (  4.0%)  >>  BTI
# [20:41:43][BTI] [SKIP] 이미 완료 (체크포인트)
# [20:41:43][PROGRESS] [  80/1990] (  4.0%)  >>  ADBE
# [20:41:43][ADBE] [SKIP] 이미 완료 (체크포인트)
# [20:41:43][PROGRESS] [  81/1990] (  4.1%)  >>  WELL
# [20:41:43][WELL] [SKIP] 이미 완료 (체크포인트)
# [20:41:43][PROGRESS] [  82/1990] (  4.1%)  >>  PANW
# [20:41:43][PANW] [SKIP] 이미 완료 (체크포인트)
# [20:41:43][PROGRESS] [  83/1990] (  4.2%)  >>  COP
# [20:41:43][COP] [SKIP] 이미 완료 (체크포인트)
# [20:41:43][PROGRESS] [  84/1990] (  4.2%)  >>  VRTX
# [20:41:43][VRTX] [SKIP] 이미 완료 (체크포인트)
# [20:41:43][PROGRESS] [  85/1990] (  4.3%)  >>  PH
# [20:41:43][PH] [SKIP] 이미 완료 (체크포인트)
# [20:41:43][PROGRESS] [  86/1990] (  4.3%)  >>  PLD
# [20:41:43][PLD] [SKIP] 이미 완료 (체크포인트)
# [20:41:43][PROGRESS] [  87/1990] (  4.4%)  >>  SNY
# [20:41:43][SNY] [SKIP] 이미 완료 (체크포인트)
# [20:41:43][PROGRESS] [  88/1990] (  4.4%)  >>  ANTM
# [20:41:43][ANTM] [SKIP] 이미 완료 (체크포인트)
# [20:41:43][PROGRESS] [  89/1990] (  4.5%)  >>  MELI
# [20:41:43][MELI] [SKIP] 이미 완료 (체크포인트)
# [20:41:43][PROGRESS] [  90/1990] (  4.5%)  >>  BMY
# [20:41:43][BMY] [SKIP] 이미 완료 (체크포인트)
# [20:41:43][PROGRESS] [  91/1990] (  4.6%)  >>  SBUX
# [20:41:43][SBUX] [SKIP] 이미 완료 (체크포인트)
# [20:41:43][PROGRESS] [  92/1990] (  4.6%)  >>  AEM
# [20:41:43][AEM] [SKIP] 이미 완료 (체크포인트)
# [20:41:43][PROGRESS] [  93/1990] (  4.7%)  >>  HCA
# [20:41:43][HCA] [SKIP] 이미 완료 (체크포인트)
# [20:41:43][PROGRESS] [  94/1990] (  4.7%)  >>  CVS
# [20:41:43][CVS] [SKIP] 이미 완료 (체크포인트)
# [20:41:43][PROGRESS] [  95/1990] (  4.8%)  >>  MO
# [20:41:43][MO] [SKIP] 이미 완료 (체크포인트)
# [20:41:43][PROGRESS] [  96/1990] (  4.8%)  >>  ENB
# [20:41:43][ENB] [SKIP] 이미 완료 (체크포인트)
# [20:41:43][PROGRESS] [  97/1990] (  4.9%)  >>  ADP
# [20:41:43][ADP] [SKIP] 이미 완료 (체크포인트)
# [20:41:43][PROGRESS] [  98/1990] (  4.9%)  >>  MCK
# [20:41:43][MCK] [SKIP] 이미 완료 (체크포인트)
# [20:41:43][PROGRESS] [  99/1990] (  5.0%)  >>  GSK
# [20:41:43][GSK] [SKIP] 이미 완료 (체크포인트)
# [20:41:43][PROGRESS] [ 100/1990] (  5.0%)  >>  GD
# [20:41:43][GD] [SKIP] 이미 완료 (체크포인트)
# [20:41:43][PROGRESS] [ 101/1990] (  5.1%)  >>  BP
# [20:41:43][BP] [SKIP] 이미 완료 (체크포인트)
# [20:41:43][PROGRESS] [ 102/1990] (  5.1%)  >>  SNPS
# [20:41:43][SNPS] [SKIP] 이미 완료 (체크포인트)
# [20:41:43][PROGRESS] [ 103/1990] (  5.2%)  >>  NKE
# [20:41:43][NKE] [SKIP] 이미 완료 (체크포인트)
# [20:41:43][PROGRESS] [ 104/1990] (  5.2%)  >>  NOC
# [20:41:43][NOC] [SKIP] 이미 완료 (체크포인트)
# [20:41:43][PROGRESS] [ 105/1990] (  5.3%)  >>  WM
# [20:41:43][WM] [SKIP] 이미 완료 (체크포인트)
# [20:41:43][PROGRESS] [ 106/1990] (  5.3%)  >>  PBR
# [20:41:43][PBR] [SKIP] 이미 완료 (체크포인트)
# [20:41:43][PROGRESS] [ 107/1990] (  5.4%)  >>  UPS
# [20:41:43][UPS] [SKIP] 이미 완료 (체크포인트)
# [20:41:43][PROGRESS] [ 108/1990] (  5.4%)  >>  FCX
# [20:41:43][FCX] [SKIP] 이미 완료 (체크포인트)
# [20:41:43][PROGRESS] [ 109/1990] (  5.5%)  >>  B
# [20:41:43][B] [SKIP] 이미 완료 (체크포인트)
# [20:41:43][PROGRESS] [ 110/1990] (  5.5%)  >>  CDNS
# [20:41:43][CDNS] [SKIP] 이미 완료 (체크포인트)
# [20:41:43][PROGRESS] [ 111/1990] (  5.6%)  >>  TT
# [20:41:43][TT] [SKIP] 이미 완료 (체크포인트)
# [20:41:43][PROGRESS] [ 112/1990] (  5.6%)  >>  SHW
# [20:41:43][SHW] [SKIP] 이미 완료 (체크포인트)
# [20:41:43][PROGRESS] [ 113/1990] (  5.7%)  >>  MAR
# [20:41:43][MAR] [SKIP] 이미 완료 (체크포인트)
# [20:41:43][PROGRESS] [ 114/1990] (  5.7%)  >>  ORLY
# [20:41:43][ORLY] [SKIP] 이미 완료 (체크포인트)
# [20:41:43][PROGRESS] [ 115/1990] (  5.8%)  >>  MMM
# [20:41:43][MMM] [SKIP] 이미 완료 (체크포인트)
# [20:41:43][PROGRESS] [ 116/1990] (  5.8%)  >>  NTES
# [20:41:43][NTES] [SKIP] 이미 완료 (체크포인트)
# [20:41:43][PROGRESS] [ 117/1990] (  5.9%)  >>  AMT
# [20:41:43][AMT] [SKIP] 이미 완료 (체크포인트)
# [20:41:43][PROGRESS] [ 118/1990] (  5.9%)  >>  EMR
# [20:41:43][EMR] [SKIP] 이미 완료 (체크포인트)
# [20:41:43][PROGRESS] [ 119/1990] (  6.0%)  >>  ELV
# [20:41:43][ELV] [SKIP] 이미 완료 (체크포인트)
# [20:41:43][PROGRESS] [ 120/1990] (  6.0%)  >>  WDC
# [20:41:43][WDC] [SKIP] 이미 완료 (체크포인트)
# [20:41:43][PROGRESS] [ 121/1990] (  6.1%)  >>  CRH
# [20:41:43][CRH] [SKIP] 이미 완료 (체크포인트)
# [20:41:43][PROGRESS] [ 122/1990] (  6.1%)  >>  GLW
# [20:41:43][GLW] [SKIP] 이미 완료 (체크포인트)
# [20:41:43][PROGRESS] [ 123/1990] (  6.2%)  >>  TDG
# [20:41:43][TDG] [SKIP] 이미 완료 (체크포인트)
# [20:41:43][PROGRESS] [ 124/1990] (  6.2%)  >>  ECL
# [20:41:43][ECL] [SKIP] 이미 완료 (체크포인트)
# [20:41:43][PROGRESS] [ 125/1990] (  6.3%)  >>  RCL
# [20:41:43][RCL] [SKIP] 이미 완료 (체크포인트)
# [20:41:43][PROGRESS] [ 126/1990] (  6.3%)  >>  MNST
# [20:41:43][MNST] [SKIP] 이미 완료 (체크포인트)
# [20:41:43][PROGRESS] [ 127/1990] (  6.4%)  >>  EQIX
# [20:41:43][EQIX] [SKIP] 이미 완료 (체크포인트)
# [20:41:43][PROGRESS] [ 128/1990] (  6.4%)  >>  REGN
# [20:41:43][REGN] [SKIP] 이미 완료 (체크포인트)
# [20:41:43][PROGRESS] [ 129/1990] (  6.5%)  >>  CMI
# [20:41:43][CMI] [SKIP] 이미 완료 (체크포인트)
# [20:41:43][PROGRESS] [ 130/1990] (  6.5%)  >>  WMB
# [20:41:43][WMB] [SKIP] 이미 완료 (체크포인트)
# [20:41:43][PROGRESS] [ 131/1990] (  6.6%)  >>  CTAS
# [20:41:43][CTAS] [SKIP] 이미 완료 (체크포인트)
# [20:41:43][PROGRESS] [ 132/1990] (  6.6%)  >>  INFY
# [20:41:43][INFY] [SKIP] 이미 완료 (체크포인트)
# [20:41:43][PROGRESS] [ 133/1990] (  6.7%)  >>  STX
# [20:41:43][STX] [SKIP] 이미 완료 (체크포인트)
# [20:41:43][PROGRESS] [ 134/1990] (  6.7%)  >>  ITW
# [20:41:43][ITW] [SKIP] 이미 완료 (체크포인트)
# [20:41:43][PROGRESS] [ 135/1990] (  6.8%)  >>  MDLZ
# [20:41:43][MDLZ] [SKIP] 이미 완료 (체크포인트)
# [20:41:43][PROGRESS] [ 136/1990] (  6.8%)  >>  CNQ
# [20:41:43][CNQ] [SKIP] 이미 완료 (체크포인트)
# [20:41:43][PROGRESS] [ 137/1990] (  6.9%)  >>  CI
# [20:41:43][CI] [SKIP] 이미 완료 (체크포인트)
# [20:41:43][PROGRESS] [ 138/1990] (  6.9%)  >>  ATVI
# [20:41:43][ATVI] [SKIP] 이미 완료 (체크포인트)
# [20:41:43][PROGRESS] [ 139/1990] (  7.0%)  >>  SLB
# [20:41:43][SLB] [SKIP] 이미 완료 (체크포인트)
# [20:41:43][PROGRESS] [ 140/1990] (  7.0%)  >>  GM
# [20:41:43][GM] [SKIP] 이미 완료 (체크포인트)
# [20:41:43][PROGRESS] [ 141/1990] (  7.1%)  >>  FDX
# [20:41:43][FDX] [SKIP] 이미 완료 (체크포인트)
# [20:41:43][PROGRESS] [ 142/1990] (  7.1%)  >>  RELX
# [20:41:43][RELX] [SKIP] 이미 완료 (체크포인트)
# [20:41:43][PROGRESS] [ 143/1990] (  7.2%)  >>  EPD
# [20:41:43][EPD] [SKIP] 이미 완료 (체크포인트)
# [20:41:43][PROGRESS] [ 144/1990] (  7.2%)  >>  MRVL
# [20:41:43][MRVL] [SKIP] 이미 완료 (체크포인트)
# [20:41:43][PROGRESS] [ 145/1990] (  7.3%)  >>  JCI
# [20:41:43][JCI] [SKIP] 이미 완료 (체크포인트)
# [20:41:43][PROGRESS] [ 146/1990] (  7.3%)  >>  PWR
# [20:41:43][PWR] [SKIP] 이미 완료 (체크포인트)
# [20:41:43][PROGRESS] [ 147/1990] (  7.4%)  >>  WBD
# [20:41:43][WBD] [SKIP] 이미 완료 (체크포인트)
# [20:41:43][PROGRESS] [ 148/1990] (  7.4%)  >>  CSX
# [20:41:43][CSX] [SKIP] 이미 완료 (체크포인트)
# [20:41:43][PROGRESS] [ 149/1990] (  7.5%)  >>  HLT
# [20:41:43][HLT] [SKIP] 이미 완료 (체크포인트)
# [20:41:43][PROGRESS] [ 150/1990] (  7.5%)  >>  ABB
# [20:41:43][ABB] [SKIP] 이미 완료 (체크포인트)
# [20:41:43][PROGRESS] [ 151/1990] (  7.6%)  >>  SNDK
# [20:42:15][DB] batch 1: tickers=1, rows=285
# [20:42:32][SNDK] [FAIL] SNDK: price_stock empty
# [20:42:32][PROGRESS] [ 152/1990] (  7.6%)  >>  COR
# [20:42:32][COR] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 153/1990] (  7.7%)  >>  CL
# [20:42:32][CL] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 154/1990] (  7.7%)  >>  RSG
# [20:42:32][RSG] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 155/1990] (  7.8%)  >>  WPM
# [20:42:32][WPM] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 156/1990] (  7.8%)  >>  VALE
# [20:42:32][VALE] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 157/1990] (  7.9%)  >>  MSI
# [20:42:32][MSI] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 158/1990] (  7.9%)  >>  CP
# [20:42:32][CP] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 159/1990] (  8.0%)  >>  TEL
# [20:42:32][TEL] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 160/1990] (  8.0%)  >>  LHX
# [20:42:32][LHX] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 161/1990] (  8.1%)  >>  AMOV
# [20:42:32][AMOV] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 162/1990] (  8.1%)  >>  KMI
# [20:42:32][KMI] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 163/1990] (  8.2%)  >>  EQNR
# [20:42:32][EQNR] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 164/1990] (  8.2%)  >>  NSC
# [20:42:32][NSC] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 165/1990] (  8.3%)  >>  PCAR
# [20:42:32][PCAR] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 166/1990] (  8.3%)  >>  FTNT
# [20:42:32][FTNT] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 167/1990] (  8.4%)  >>  PXD
# [20:42:32][PXD] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 168/1990] (  8.4%)  >>  AZO
# [20:42:32][AZO] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 169/1990] (  8.5%)  >>  CNI
# [20:42:32][CNI] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 170/1990] (  8.5%)  >>  AMX
# [20:42:32][AMX] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 171/1990] (  8.6%)  >>  ET
# [20:42:32][ET] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 172/1990] (  8.6%)  >>  VMW
# [20:42:32][VMW] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 173/1990] (  8.7%)  >>  SU
# [20:42:32][SU] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 174/1990] (  8.7%)  >>  ROST
# [20:42:32][ROST] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 175/1990] (  8.8%)  >>  RACE
# [20:42:32][RACE] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 176/1990] (  8.8%)  >>  SPG
# [20:42:32][SPG] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 177/1990] (  8.9%)  >>  E
# [20:42:32][E] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 178/1990] (  8.9%)  >>  EOG
# [20:42:32][EOG] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 179/1990] (  9.0%)  >>  URI
# [20:42:32][URI] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 180/1990] (  9.0%)  >>  TRP
# [20:42:32][TRP] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 181/1990] (  9.1%)  >>  APD
# [20:42:32][APD] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 182/1990] (  9.1%)  >>  NXPI
# [20:42:32][NXPI] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 183/1990] (  9.2%)  >>  BDX
# [20:42:32][BDX] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 184/1990] (  9.2%)  >>  ADSK
# [20:42:32][ADSK] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 185/1990] (  9.3%)  >>  VLO
# [20:42:32][VLO] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 186/1990] (  9.3%)  >>  PSX
# [20:42:32][PSX] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 187/1990] (  9.4%)  >>  MPLX
# [20:42:32][MPLX] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 188/1990] (  9.4%)  >>  TRI
# [20:42:32][TRI] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 189/1990] (  9.5%)  >>  IDXX
# [20:42:32][IDXX] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 190/1990] (  9.5%)  >>  O
# [20:42:32][O] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 191/1990] (  9.6%)  >>  BKR
# [20:42:32][BKR] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 192/1990] (  9.6%)  >>  DLR
# [20:42:32][DLR] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 193/1990] (  9.7%)  >>  ZTS
# [20:42:32][ZTS] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 194/1990] (  9.7%)  >>  AU
# [20:42:32][AU] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 195/1990] (  9.8%)  >>  CMG
# [20:42:32][CMG] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 196/1990] (  9.8%)  >>  BIDU
# [20:42:32][BIDU] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 197/1990] (  9.9%)  >>  CCJ
# [20:42:32][CCJ] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 198/1990] (  9.9%)  >>  F
# [20:42:32][F] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 199/1990] ( 10.0%)  >>  TAK
# [20:42:32][TAK] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 200/1990] ( 10.1%)  >>  MPC
# [20:42:32][MPC] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 201/1990] ( 10.1%)  >>  SQ
# [20:42:32][SQ] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 202/1990] ( 10.2%)  >>  IMO
# [20:42:32][IMO] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 203/1990] ( 10.2%)  >>  MPWR
# [20:42:32][MPWR] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 204/1990] ( 10.3%)  >>  EA
# [20:42:32][EA] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 205/1990] ( 10.3%)  >>  WDAY
# [20:42:32][WDAY] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 206/1990] ( 10.4%)  >>  AME
# [20:42:32][AME] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 207/1990] ( 10.4%)  >>  CBRE
# [20:42:32][CBRE] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 208/1990] ( 10.5%)  >>  FAST
# [20:42:32][FAST] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 209/1990] ( 10.5%)  >>  CAH
# [20:42:32][CAH] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 210/1990] ( 10.6%)  >>  FNV
# [20:42:32][FNV] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 211/1990] ( 10.6%)  >>  GWW
# [20:42:32][GWW] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 212/1990] ( 10.7%)  >>  DEO
# [20:42:32][DEO] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 213/1990] ( 10.7%)  >>  FERG
# [20:42:32][FERG] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 214/1990] ( 10.8%)  >>  EW
# [20:42:32][EW] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 215/1990] ( 10.8%)  >>  GFI
# [20:42:32][GFI] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 216/1990] ( 10.9%)  >>  PSA
# [20:42:32][PSA] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 217/1990] ( 10.9%)  >>  FER
# [20:42:32][FER] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 218/1990] ( 11.0%)  >>  OKE
# [20:42:32][OKE] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 219/1990] ( 11.0%)  >>  AXON
# [20:42:32][AXON] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 220/1990] ( 11.1%)  >>  ALNY
# [20:42:32][ALNY] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 221/1990] ( 11.1%)  >>  ERJ
# [20:42:32][ERJ] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 222/1990] ( 11.2%)  >>  ROK
# [20:42:32][ROK] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 223/1990] ( 11.2%)  >>  TGT
# [20:42:32][TGT] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 224/1990] ( 11.3%)  >>  HEI
# [20:42:32][HEI] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 225/1990] ( 11.3%)  >>  MSTR
# [20:42:32][MSTR] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 226/1990] ( 11.4%)  >>  KGC
# [20:42:32][KGC] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 227/1990] ( 11.4%)  >>  HES
# [20:42:32][HES] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 228/1990] ( 11.5%)  >>  TTWO
# [20:42:32][TTWO] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 229/1990] ( 11.5%)  >>  LNG
# [20:42:32][LNG] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 230/1990] ( 11.6%)  >>  FANG
# [20:42:32][FANG] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 231/1990] ( 11.6%)  >>  DAL
# [20:42:32][DAL] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 232/1990] ( 11.7%)  >>  WCN
# [20:42:32][WCN] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 233/1990] ( 11.7%)  >>  ROP
# [20:42:32][ROP] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 234/1990] ( 11.8%)  >>  ABEV
# [20:42:32][ABEV] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 235/1990] ( 11.8%)  >>  DHI
# [20:42:32][DHI] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 236/1990] ( 11.9%)  >>  OXY
# [20:42:32][OXY] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 237/1990] ( 11.9%)  >>  ASX
# [20:42:32][ASX] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 238/1990] ( 12.0%)  >>  SGEN
# [20:42:32][SGEN] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 239/1990] ( 12.0%)  >>  EBAY
# [20:42:32][EBAY] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 240/1990] ( 12.1%)  >>  YUM
# [20:42:32][YUM] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 241/1990] ( 12.1%)  >>  JD
# [20:42:32][JD] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 242/1990] ( 12.2%)  >>  KR
# [20:42:32][KR] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 243/1990] ( 12.2%)  >>  EL
# [20:42:32][EL] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 244/1990] ( 12.3%)  >>  CTSH
# [20:42:32][CTSH] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 245/1990] ( 12.3%)  >>  TCOM
# [20:42:32][TCOM] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 246/1990] ( 12.4%)  >>  TRGP
# [20:42:32][TRGP] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 247/1990] ( 12.4%)  >>  LVS
# [20:42:32][LVS] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 248/1990] ( 12.5%)  >>  TWTR
# [20:42:32][TWTR] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 249/1990] ( 12.5%)  >>  CCEP
# [20:42:32][CCEP] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 250/1990] ( 12.6%)  >>  MT
# [20:42:32][MT] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 251/1990] ( 12.6%)  >>  IQV
# [20:42:32][IQV] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 252/1990] ( 12.7%)  >>  NUE
# [20:42:32][NUE] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 253/1990] ( 12.7%)  >>  MCHP
# [20:42:32][MCHP] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 254/1990] ( 12.8%)  >>  CPRT
# [20:42:32][CPRT] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 255/1990] ( 12.8%)  >>  XYZ
# [20:42:32][XYZ] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 256/1990] ( 12.9%)  >>  GRMN
# [20:42:32][GRMN] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 257/1990] ( 12.9%)  >>  FIX
# [20:42:32][FIX] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 258/1990] ( 13.0%)  >>  VMC
# [20:42:32][VMC] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 259/1990] ( 13.0%)  >>  WAB
# [20:42:32][WAB] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 260/1990] ( 13.1%)  >>  MLM
# [20:42:32][MLM] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 261/1990] ( 13.1%)  >>  HMC
# [20:42:32][HMC] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 262/1990] ( 13.2%)  >>  HSY
# [20:42:32][HSY] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 263/1990] ( 13.2%)  >>  A
# [20:42:32][A] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 264/1990] ( 13.3%)  >>  PAYX
# [20:42:32][PAYX] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 265/1990] ( 13.3%)  >>  CCI
# [20:42:32][CCI] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 266/1990] ( 13.4%)  >>  KDP
# [20:42:32][KDP] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 267/1990] ( 13.4%)  >>  CCL
# [20:42:32][CCL] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 268/1990] ( 13.5%)  >>  CUK
# [20:42:32][CUK] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 269/1990] ( 13.5%)  >>  NOK
# [20:42:32][NOK] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 270/1990] ( 13.6%)  >>  RMD
# [20:42:32][RMD] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 271/1990] ( 13.6%)  >>  FICO
# [20:42:32][FICO] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 272/1990] ( 13.7%)  >>  TER
# [20:42:32][TER] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 273/1990] ( 13.7%)  >>  TEVA
# [20:42:32][TEVA] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 274/1990] ( 13.8%)  >>  VEEV
# [20:42:32][VEEV] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 275/1990] ( 13.8%)  >>  KEYS
# [20:42:32][KEYS] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 276/1990] ( 13.9%)  >>  FISV
# [20:42:32][FISV] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 277/1990] ( 13.9%)  >>  ODFL
# [20:42:32][ODFL] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 278/1990] ( 14.0%)  >>  TEAM
# [20:42:32][TEAM] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 279/1990] ( 14.0%)  >>  SYY
# [20:42:32][SYY] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 280/1990] ( 14.1%)  >>  ABC
# [20:42:32][ABC] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 281/1990] ( 14.1%)  >>  VTR
# [20:42:32][VTR] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 282/1990] ( 14.2%)  >>  CVE
# [20:42:32][CVE] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 283/1990] ( 14.2%)  >>  ERIC
# [20:42:32][ERIC] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 284/1990] ( 14.3%)  >>  CLS
# [20:42:32][CLS] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 285/1990] ( 14.3%)  >>  EQT
# [20:42:32][EQT] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 286/1990] ( 14.4%)  >>  XYL
# [20:42:32][XYL] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 287/1990] ( 14.4%)  >>  UAL
# [20:42:32][UAL] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 288/1990] ( 14.5%)  >>  VOD
# [20:42:32][VOD] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 289/1990] ( 14.5%)  >>  SATS
# [20:42:32][SATS] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 290/1990] ( 14.6%)  >>  LYV
# [20:42:32][LYV] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 291/1990] ( 14.6%)  >>  FI
# [20:42:32][FI] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 292/1990] ( 14.7%)  >>  INSM
# [20:42:32][INSM] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 293/1990] ( 14.7%)  >>  KMB
# [20:42:32][KMB] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 294/1990] ( 14.8%)  >>  NTRA
# [20:42:32][NTRA] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 295/1990] ( 14.8%)  >>  UI
# [20:42:32][UI] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 296/1990] ( 14.9%)  >>  CHT
# [20:42:32][CHT] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 297/1990] ( 14.9%)  >>  DG
# [20:42:32][DG] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 298/1990] ( 15.0%)  >>  ESLT
# [20:42:32][ESLT] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 299/1990] ( 15.0%)  >>  ANSS
# [20:42:32][ANSS] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 300/1990] ( 15.1%)  >>  CIEN
# [20:42:32][CIEN] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 301/1990] ( 15.1%)  >>  ADM
# [20:42:32][ADM] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 302/1990] ( 15.2%)  >>  WDS
# [20:42:32][WDS] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 303/1990] ( 15.2%)  >>  HUM
# [20:42:32][HUM] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 304/1990] ( 15.3%)  >>  EME
# [20:42:32][EME] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 305/1990] ( 15.3%)  >>  EXPE
# [20:42:32][EXPE] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 306/1990] ( 15.4%)  >>  COHR
# [20:42:32][COHR] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 307/1990] ( 15.4%)  >>  VIK
# [20:42:32][VIK] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 308/1990] ( 15.5%)  >>  ROL
# [20:42:32][ROL] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 309/1990] ( 15.5%)  >>  VRSK
# [20:42:32][VRSK] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 310/1990] ( 15.6%)  >>  FLUT
# [20:42:32][FLUT] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 311/1990] ( 15.6%)  >>  FIS
# [20:42:32][FIS] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 312/1990] ( 15.7%)  >>  EXR
# [20:42:32][EXR] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 313/1990] ( 15.7%)  >>  ULTA
# [20:42:32][ULTA] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 314/1990] ( 15.8%)  >>  ORAN
# [20:42:32][ORAN] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 315/1990] ( 15.8%)  >>  FTAI
# [20:42:32][FTAI] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 316/1990] ( 15.9%)  >>  TSCO
# [20:42:32][TSCO] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 317/1990] ( 15.9%)  >>  HAL
# [20:42:32][HAL] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 318/1990] ( 16.0%)  >>  MTD
# [20:42:32][MTD] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 319/1990] ( 16.0%)  >>  K
# [20:42:32][K] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 320/1990] ( 16.1%)  >>  DXCM
# [20:42:32][DXCM] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 321/1990] ( 16.1%)  >>  TDY
# [20:42:32][TDY] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 322/1990] ( 16.2%)  >>  HPE
# [20:42:32][HPE] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 323/1990] ( 16.2%)  >>  DOV
# [20:42:32][DOV] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 324/1990] ( 16.3%)  >>  UMC
# [20:42:32][UMC] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 325/1990] ( 16.3%)  >>  STZ
# [20:42:32][STZ] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 326/1990] ( 16.4%)  >>  STLA
# [20:42:32][STLA] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 327/1990] ( 16.4%)  >>  KHC
# [20:42:32][KHC] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 328/1990] ( 16.5%)  >>  LEN
# [20:42:32][LEN] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 329/1990] ( 16.5%)  >>  CSGP
# [20:42:32][CSGP] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 330/1990] ( 16.6%)  >>  NETE
# [20:42:32][NETE] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 331/1990] ( 16.6%)  >>  PHG
# [20:42:32][PHG] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 332/1990] ( 16.7%)  >>  IRM
# [20:42:32][IRM] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 333/1990] ( 16.7%)  >>  CQP
# [20:42:32][CQP] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 334/1990] ( 16.8%)  >>  WIT
# [20:42:32][WIT] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 335/1990] ( 16.8%)  >>  HZNP
# [20:42:32][HZNP] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 336/1990] ( 16.9%)  >>  CHTR
# [20:42:32][CHTR] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 337/1990] ( 16.9%)  >>  SPLK
# [20:42:32][SPLK] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 338/1990] ( 17.0%)  >>  EFX
# [20:42:32][EFX] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 339/1990] ( 17.0%)  >>  TECK
# [20:42:32][TECK] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 340/1990] ( 17.1%)  >>  TPR
# [20:42:32][TPR] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 341/1990] ( 17.1%)  >>  SHLM
# [20:42:32][SHLM] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 342/1990] ( 17.2%)  >>  FSLR
# [20:42:32][FSLR] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 343/1990] ( 17.2%)  >>  EC
# [20:42:32][EC] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 344/1990] ( 17.3%)  >>  STE
# [20:42:32][STE] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 345/1990] ( 17.3%)  >>  HUBB
# [20:42:32][HUBB] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 346/1990] ( 17.4%)  >>  JBL
# [20:42:32][JBL] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 347/1990] ( 17.4%)  >>  DLTR
# [20:42:32][DLTR] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 348/1990] ( 17.5%)  >>  STM
# [20:42:32][STM] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 349/1990] ( 17.5%)  >>  BIIB
# [20:42:32][BIIB] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 350/1990] ( 17.6%)  >>  AER
# [20:42:32][AER] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 351/1990] ( 17.6%)  >>  AVB
# [20:42:32][AVB] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 352/1990] ( 17.7%)  >>  STLD
# [20:42:32][STLD] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 353/1990] ( 17.7%)  >>  PPG
# [20:42:32][PPG] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 354/1990] ( 17.8%)  >>  ON
# [20:42:32][ON] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 355/1990] ( 17.8%)  >>  DVN
# [20:42:32][DVN] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 356/1990] ( 17.9%)  >>  CW
# [20:42:32][CW] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 357/1990] ( 17.9%)  >>  WSM
# [20:42:32][WSM] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 358/1990] ( 18.0%)  >>  BR
# [20:42:32][BR] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 359/1990] ( 18.0%)  >>  PHM
# [20:42:32][PHM] [SKIP] 이미 완료 (체크포인트)
# [20:42:32][PROGRESS] [ 360/1990] ( 18.1%)  >>  STRK
# [20:43:04][DB] batch 1: tickers=1, rows=294
# [20:43:22][STRK] [FAIL] STRK: price_stock empty
# [20:43:22][PROGRESS] [ 361/1990] ( 18.1%)  >>  LDOS
# [20:43:22][LDOS] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 362/1990] ( 18.2%)  >>  PSTG
# [20:43:22][PSTG] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 363/1990] ( 18.2%)  >>  SQM
# [20:43:22][SQM] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 364/1990] ( 18.3%)  >>  GIS
# [20:43:22][GIS] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 365/1990] ( 18.3%)  >>  PAAS
# [20:43:22][PAAS] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 366/1990] ( 18.4%)  >>  EQR
# [20:43:22][EQR] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 367/1990] ( 18.4%)  >>  TS
# [20:43:22][TS] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 368/1990] ( 18.5%)  >>  PBA
# [20:43:22][PBA] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 369/1990] ( 18.5%)  >>  LITE
# [20:43:22][LITE] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 370/1990] ( 18.6%)  >>  FLEX
# [20:43:22][FLEX] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 371/1990] ( 18.6%)  >>  TPL
# [20:43:22][TPL] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 372/1990] ( 18.7%)  >>  BCE
# [20:43:22][BCE] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 373/1990] ( 18.7%)  >>  ILMN
# [20:43:22][ILMN] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 374/1990] ( 18.8%)  >>  VRSN
# [20:43:22][VRSN] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 375/1990] ( 18.8%)  >>  WAT
# [20:43:22][WAT] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 376/1990] ( 18.9%)  >>  CASY
# [20:43:22][CASY] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 377/1990] ( 18.9%)  >>  DRI
# [20:43:22][DRI] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 378/1990] ( 19.0%)  >>  TSN
# [20:43:22][TSN] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 379/1990] ( 19.0%)  >>  CNC
# [20:43:22][CNC] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 380/1990] ( 19.1%)  >>  IP
# [20:43:22][IP] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 381/1990] ( 19.1%)  >>  CPAY
# [20:43:22][CPAY] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 382/1990] ( 19.2%)  >>  TLK
# [20:43:22][TLK] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 383/1990] ( 19.2%)  >>  CYBR
# [20:43:22][CYBR] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 384/1990] ( 19.3%)  >>  FTI
# [20:43:22][FTI] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 385/1990] ( 19.3%)  >>  CHD
# [20:43:22][CHD] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 386/1990] ( 19.4%)  >>  VIV
# [20:43:22][VIV] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 387/1990] ( 19.4%)  >>  ALB
# [20:43:22][ALB] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 388/1990] ( 19.5%)  >>  KOF
# [20:43:22][KOF] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 389/1990] ( 19.5%)  >>  LH
# [20:43:22][LH] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 390/1990] ( 19.6%)  >>  FMX
# [20:43:22][FMX] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 391/1990] ( 19.6%)  >>  BG
# [20:43:22][BG] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 392/1990] ( 19.7%)  >>  QSR
# [20:43:22][QSR] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 393/1990] ( 19.7%)  >>  CAJ
# [20:43:22][CAJ] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 394/1990] ( 19.8%)  >>  RL
# [20:43:22][RL] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 395/1990] ( 19.8%)  >>  BLL
# [20:43:22][BLL] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 396/1990] ( 19.9%)  >>  NVR
# [20:43:22][NVR] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 397/1990] ( 19.9%)  >>  FLT
# [20:43:22][FLT] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 398/1990] ( 20.0%)  >>  LUV
# [20:43:22][LUV] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 399/1990] ( 20.1%)  >>  RBA
# [20:43:22][RBA] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 400/1990] ( 20.1%)  >>  LULU
# [20:43:22][LULU] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 401/1990] ( 20.2%)  >>  EXPD
# [20:43:22][EXPD] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 402/1990] ( 20.2%)  >>  TU
# [20:43:22][TU] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 403/1990] ( 20.3%)  >>  TEF
# [20:43:22][TEF] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 404/1990] ( 20.3%)  >>  UTHR
# [20:43:22][UTHR] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 405/1990] ( 20.4%)  >>  CHRW
# [20:43:22][CHRW] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 406/1990] ( 20.4%)  >>  SSNC
# [20:43:22][SSNC] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 407/1990] ( 20.5%)  >>  CTRA
# [20:43:22][CTRA] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 408/1990] ( 20.5%)  >>  GMAB
# [20:43:22][GMAB] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 409/1990] ( 20.6%)  >>  AMCR
# [20:43:22][AMCR] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 410/1990] ( 20.6%)  >>  IHG
# [20:43:22][IHG] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 411/1990] ( 20.7%)  >>  DGX
# [20:43:22][DGX] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 412/1990] ( 20.7%)  >>  INCY
# [20:43:22][INCY] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 413/1990] ( 20.8%)  >>  HL
# [20:43:22][HL] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 414/1990] ( 20.8%)  >>  SBAC
# [20:43:22][SBAC] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 415/1990] ( 20.9%)  >>  PKG
# [20:43:22][PKG] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 416/1990] ( 20.9%)  >>  WWD
# [20:43:22][WWD] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 417/1990] ( 21.0%)  >>  GIB
# [20:43:22][GIB] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 418/1990] ( 21.0%)  >>  CHKP
# [20:43:22][CHKP] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 419/1990] ( 21.1%)  >>  PTC
# [20:43:22][PTC] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 420/1990] ( 21.1%)  >>  NTAP
# [20:43:22][NTAP] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 421/1990] ( 21.2%)  >>  RCI
# [20:43:22][RCI] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 422/1990] ( 21.2%)  >>  JBHT
# [20:43:22][JBHT] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 423/1990] ( 21.3%)  >>  EXAS
# [20:43:22][EXAS] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 424/1990] ( 21.3%)  >>  VIAC
# [20:43:22][VIAC] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 425/1990] ( 21.4%)  >>  GPC
# [20:43:22][GPC] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 426/1990] ( 21.4%)  >>  MTZ
# [20:43:22][MTZ] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 427/1990] ( 21.5%)  >>  WY
# [20:43:22][WY] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 428/1990] ( 21.5%)  >>  PODD
# [20:43:22][PODD] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 429/1990] ( 21.6%)  >>  RGLD
# [20:43:22][RGLD] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 430/1990] ( 21.6%)  >>  IFF
# [20:43:22][IFF] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 431/1990] ( 21.7%)  >>  TYL
# [20:43:22][TYL] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 432/1990] ( 21.7%)  >>  PKX
# [20:43:22][PKX] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 433/1990] ( 21.8%)  >>  BWXT
# [20:43:22][BWXT] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 434/1990] ( 21.8%)  >>  KTOS
# [20:43:22][KTOS] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 435/1990] ( 21.9%)  >>  DD
# [20:43:22][DD] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 436/1990] ( 21.9%)  >>  CX
# [20:43:22][CX] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 437/1990] ( 22.0%)  >>  BURL
# [20:43:22][BURL] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 438/1990] ( 22.0%)  >>  SMCI
# [20:43:22][SMCI] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 439/1990] ( 22.1%)  >>  HPQ
# [20:43:22][HPQ] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 440/1990] ( 22.1%)  >>  LII
# [20:43:22][LII] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 441/1990] ( 22.2%)  >>  IT
# [20:43:22][IT] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 442/1990] ( 22.2%)  >>  AGI
# [20:43:22][AGI] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 443/1990] ( 22.3%)  >>  GPN
# [20:43:22][GPN] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 444/1990] ( 22.3%)  >>  PNR
# [20:43:22][PNR] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 445/1990] ( 22.4%)  >>  ENTG
# [20:43:22][ENTG] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 446/1990] ( 22.4%)  >>  XPO
# [20:43:22][XPO] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 447/1990] ( 22.5%)  >>  WST
# [20:43:22][WST] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 448/1990] ( 22.5%)  >>  CRS
# [20:43:22][CRS] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 449/1990] ( 22.6%)  >>  ZBH
# [20:43:22][ZBH] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 450/1990] ( 22.6%)  >>  NWS
# [20:43:22][NWS] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 451/1990] ( 22.7%)  >>  HUBS
# [20:43:22][HUBS] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 452/1990] ( 22.7%)  >>  ABMD
# [20:43:22][ABMD] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 453/1990] ( 22.8%)  >>  COG
# [20:43:22][COG] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 454/1990] ( 22.8%)  >>  RS
# [20:43:22][RS] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 455/1990] ( 22.9%)  >>  FN
# [20:43:22][FN] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 456/1990] ( 22.9%)  >>  TRMB
# [20:43:22][TRMB] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 457/1990] ( 23.0%)  >>  JLL
# [20:43:22][JLL] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 458/1990] ( 23.0%)  >>  QXO
# [20:43:22][QXO] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 459/1990] ( 23.1%)  >>  Z
# [20:43:22][Z] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 460/1990] ( 23.1%)  >>  HOLX
# [20:43:22][HOLX] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 461/1990] ( 23.2%)  >>  ATI
# [20:43:22][ATI] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 462/1990] ( 23.2%)  >>  AZPN
# [20:43:22][AZPN] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 463/1990] ( 23.3%)  >>  THC
# [20:43:22][THC] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 464/1990] ( 23.3%)  >>  TXT
# [20:43:22][TXT] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 465/1990] ( 23.4%)  >>  APTV
# [20:43:22][APTV] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 466/1990] ( 23.4%)  >>  RTO
# [20:43:22][RTO] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 467/1990] ( 23.5%)  >>  CDW
# [20:43:22][CDW] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 468/1990] ( 23.5%)  >>  WES
# [20:43:22][WES] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 469/1990] ( 23.6%)  >>  TRU
# [20:43:22][TRU] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 470/1990] ( 23.6%)  >>  ZG
# [20:43:22][ZG] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 471/1990] ( 23.7%)  >>  DKS
# [20:43:22][DKS] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 472/1990] ( 23.7%)  >>  MTSI
# [20:43:22][MTSI] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 473/1990] ( 23.8%)  >>  LYB
# [20:43:22][LYB] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 474/1990] ( 23.8%)  >>  MKC
# [20:43:22][MKC] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 475/1990] ( 23.9%)  >>  CDE
# [20:43:22][CDE] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 476/1990] ( 23.9%)  >>  NLY
# [20:43:22][NLY] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 477/1990] ( 24.0%)  >>  ESS
# [20:43:22][ESS] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 478/1990] ( 24.0%)  >>  J
# [20:43:22][J] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 479/1990] ( 24.1%)  >>  HII
# [20:43:22][HII] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 480/1990] ( 24.1%)  >>  COO
# [20:43:22][COO] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 481/1990] ( 24.2%)  >>  MRO
# [20:43:22][MRO] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 482/1990] ( 24.2%)  >>  RBC
# [20:43:22][RBC] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 483/1990] ( 24.3%)  >>  CEA
# [20:43:22][CEA] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 484/1990] ( 24.3%)  >>  ITT
# [20:43:22][ITT] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 485/1990] ( 24.4%)  >>  GEN
# [20:43:22][GEN] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 486/1990] ( 24.4%)  >>  MAA
# [20:43:22][MAA] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 487/1990] ( 24.5%)  >>  WSO
# [20:43:22][WSO] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 488/1990] ( 24.5%)  >>  FFIV
# [20:43:22][FFIV] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 489/1990] ( 24.6%)  >>  OMC
# [20:43:22][OMC] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 490/1990] ( 24.6%)  >>  SUI
# [20:43:22][SUI] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 491/1990] ( 24.7%)  >>  HTHT
# [20:43:22][HTHT] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 492/1990] ( 24.7%)  >>  H
# [20:43:22][H] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 493/1990] ( 24.8%)  >>  BALL
# [20:43:22][BALL] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 494/1990] ( 24.8%)  >>  NWSA
# [20:43:22][NWSA] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 495/1990] ( 24.9%)  >>  VTRS
# [20:43:22][VTRS] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 496/1990] ( 24.9%)  >>  NDSN
# [20:43:22][NDSN] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 497/1990] ( 25.0%)  >>  YNDX
# [20:43:22][YNDX] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 498/1990] ( 25.0%)  >>  AVAV
# [20:43:22][AVAV] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 499/1990] ( 25.1%)  >>  WPC
# [20:43:22][WPC] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 500/1990] ( 25.1%)  >>  DECK
# [20:43:22][DECK] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 501/1990] ( 25.2%)  >>  MGA
# [20:43:22][MGA] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 502/1990] ( 25.2%)  >>  CSL
# [20:43:22][CSL] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 503/1990] ( 25.3%)  >>  SJR
# [20:43:22][SJR] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 504/1990] ( 25.3%)  >>  MLI
# [20:43:22][MLI] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 505/1990] ( 25.4%)  >>  CF
# [20:43:22][CF] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 506/1990] ( 25.4%)  >>  SNN
# [20:43:22][SNN] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 507/1990] ( 25.5%)  >>  HMY
# [20:43:22][HMY] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 508/1990] ( 25.5%)  >>  PFGC
# [20:43:22][PFGC] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 509/1990] ( 25.6%)  >>  IEX
# [20:43:22][IEX] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 510/1990] ( 25.6%)  >>  ULS
# [20:43:22][ULS] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 511/1990] ( 25.7%)  >>  MKSI
# [20:43:22][MKSI] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 512/1990] ( 25.7%)  >>  GDDY
# [20:43:22][GDDY] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 513/1990] ( 25.8%)  >>  AVY
# [20:43:22][AVY] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 514/1990] ( 25.8%)  >>  PKI
# [20:43:22][PKI] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 515/1990] ( 25.9%)  >>  CNHI
# [20:43:22][CNHI] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 516/1990] ( 25.9%)  >>  GGG
# [20:43:22][GGG] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 517/1990] ( 26.0%)  >>  ALLE
# [20:43:22][ALLE] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 518/1990] ( 26.0%)  >>  W
# [20:43:22][W] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 519/1990] ( 26.1%)  >>  YPF
# [20:43:22][YPF] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 520/1990] ( 26.1%)  >>  NLOK
# [20:43:22][NLOK] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 521/1990] ( 26.2%)  >>  ICLR
# [20:43:22][ICLR] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 522/1990] ( 26.2%)  >>  ASND
# [20:43:22][ASND] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 523/1990] ( 26.3%)  >>  MAS
# [20:43:22][MAS] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 524/1990] ( 26.3%)  >>  TSEM
# [20:43:22][TSEM] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 525/1990] ( 26.4%)  >>  AKAM
# [20:43:22][AKAM] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 526/1990] ( 26.4%)  >>  CACI
# [20:43:22][CACI] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 527/1990] ( 26.5%)  >>  PAC
# [20:43:22][PAC] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 528/1990] ( 26.5%)  >>  LECO
# [20:43:22][LECO] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 529/1990] ( 26.6%)  >>  KIM
# [20:43:22][KIM] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 530/1990] ( 26.6%)  >>  JHX
# [20:43:22][JHX] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 531/1990] ( 26.7%)  >>  PEN
# [20:43:22][PEN] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 532/1990] ( 26.7%)  >>  CELH
# [20:43:22][CELH] [SKIP] 이미 완료 (체크포인트)
# [20:43:22][PROGRESS] [ 533/1990] ( 26.8%)  >>  ITCI
# [20:43:22][ITCI] [SKIP] 이미 완료 (체크포인트)
# ...
# [20:46:38][PROGRESS] [1825/1990] ( 91.7%)  >>  NAGE
# [20:46:38][NAGE] [SKIP] 이미 완료 (체크포인트)
# [20:46:38][PROGRESS] [1826/1990] ( 91.8%)  >>  DIN
# [20:46:38][DIN] [SKIP] 이미 완료 (체크포인트)
# [20:46:38][PROGRESS] [1827/1990] ( 91.8%)  >>  KMDA
# [20:46:38][KMDA] [SKIP] 이미 완료 (체크포인트)
# [20:46:38][PROGRESS] [1828/1990] ( 91.9%)  >>  EGY
# [20:46:38][EGY] [SKIP] 이미 완료 (체크포인트)
# [20:46:38][PROGRESS] [1829/1990] ( 91.9%)  >>  EBF
# [20:46:38][EBF] [SKIP] 이미 완료 (체크포인트)
# [20:46:38][PROGRESS] [1830/1990] ( 92.0%)  >>  FPI
# [20:46:38][FPI] [SKIP] 이미 완료 (체크포인트)
# [20:46:38][PROGRESS] [1831/1990] ( 92.0%)  >>  PWFL
# [20:46:38][PWFL] [SKIP] 이미 완료 (체크포인트)
# [20:46:38][PROGRESS] [1832/1990] ( 92.1%)  >>  MAGN
# [20:46:38][MAGN] [SKIP] 이미 완료 (체크포인트)
# [20:46:38][PROGRESS] [1833/1990] ( 92.1%)  >>  RMR
# [20:46:38][RMR] [SKIP] 이미 완료 (체크포인트)
# [20:46:38][PROGRESS] [1834/1990] ( 92.2%)  >>  HPP
# [20:46:38][HPP] [SKIP] 이미 완료 (체크포인트)
# [20:46:38][PROGRESS] [1835/1990] ( 92.2%)  >>  GEVO
# [20:46:38][GEVO] [SKIP] 이미 완료 (체크포인트)
# [20:46:38][PROGRESS] [1836/1990] ( 92.3%)  >>  SIGA
# [20:46:38][SIGA] [SKIP] 이미 완료 (체크포인트)
# [20:46:38][PROGRESS] [1837/1990] ( 92.3%)  >>  CHCT
# [20:46:38][CHCT] [SKIP] 이미 완료 (체크포인트)
# [20:46:38][PROGRESS] [1838/1990] ( 92.4%)  >>  HT
# [20:46:38][HT] [SKIP] 이미 완료 (체크포인트)
# [20:46:38][PROGRESS] [1839/1990] ( 92.4%)  >>  CLNE
# [20:46:38][CLNE] [SKIP] 이미 완료 (체크포인트)
# [20:46:38][PROGRESS] [1840/1990] ( 92.5%)  >>  MITK
# [20:46:38][MITK] [SKIP] 이미 완료 (체크포인트)
# [20:46:38][PROGRESS] [1841/1990] ( 92.5%)  >>  ORN
# [20:46:38][ORN] [SKIP] 이미 완료 (체크포인트)
# [20:46:38][PROGRESS] [1842/1990] ( 92.6%)  >>  ASC
# [20:46:38][ASC] [SKIP] 이미 완료 (체크포인트)
# [20:46:38][PROGRESS] [1843/1990] ( 92.6%)  >>  PKE
# [20:46:38][PKE] [SKIP] 이미 완료 (체크포인트)
# [20:46:38][PROGRESS] [1844/1990] ( 92.7%)  >>  JOUT
# [20:46:38][JOUT] [SKIP] 이미 완료 (체크포인트)
# [20:46:38][PROGRESS] [1845/1990] ( 92.7%)  >>  MCS
# [20:46:38][MCS] [SKIP] 이미 완료 (체크포인트)
# [20:46:38][PROGRESS] [1846/1990] ( 92.8%)  >>  CODI
# [20:46:38][CODI] [SKIP] 이미 완료 (체크포인트)
# [20:46:38][PROGRESS] [1847/1990] ( 92.8%)  >>  CERS
# [20:46:38][CERS] [SKIP] 이미 완료 (체크포인트)
# [20:46:38][PROGRESS] [1848/1990] ( 92.9%)  >>  NRC
# [20:46:38][NRC] [SKIP] 이미 완료 (체크포인트)
# [20:46:38][PROGRESS] [1849/1990] ( 92.9%)  >>  BBBY
# [20:46:38][BBBY] [SKIP] 이미 완료 (체크포인트)
# [20:46:38][PROGRESS] [1850/1990] ( 93.0%)  >>  IMMP
# [20:46:38][IMMP] [SKIP] 이미 완료 (체크포인트)
# [20:46:38][PROGRESS] [1851/1990] ( 93.0%)  >>  MTW
# [20:46:38][MTW] [SKIP] 이미 완료 (체크포인트)
# [20:46:38][PROGRESS] [1852/1990] ( 93.1%)  >>  KOPN
# [20:46:38][KOPN] [SKIP] 이미 완료 (체크포인트)
# [20:46:38][PROGRESS] [1853/1990] ( 93.1%)  >>  SVA
# [20:47:09][DB] batch 1: tickers=1, rows=75
# [20:47:27][SVA] [FAIL] SVA: price_stock empty
# [20:47:27][PROGRESS] [1854/1990] ( 93.2%)  >>  MLR
# [20:47:27][MLR] [SKIP] 이미 완료 (체크포인트)
# [20:47:27][PROGRESS] [1855/1990] ( 93.2%)  >>  OSPN
# [20:47:27][OSPN] [SKIP] 이미 완료 (체크포인트)
# [20:47:27][PROGRESS] [1856/1990] ( 93.3%)  >>  VNDA
# [20:47:27][VNDA] [SKIP] 이미 완료 (체크포인트)
# [20:47:27][PROGRESS] [1857/1990] ( 93.3%)  >>  CD
# [20:47:27][CD] [SKIP] 이미 완료 (체크포인트)
# [20:47:27][PROGRESS] [1858/1990] ( 93.4%)  >>  TCI
# [20:47:27][TCI] [SKIP] 이미 완료 (체크포인트)
# [20:47:27][PROGRESS] [1859/1990] ( 93.4%)  >>  EMX
# [20:47:27][EMX] [SKIP] 이미 완료 (체크포인트)
# [20:47:27][PROGRESS] [1860/1990] ( 93.5%)  >>  OLP
# [20:47:27][OLP] [SKIP] 이미 완료 (체크포인트)
# [20:47:27][PROGRESS] [1861/1990] ( 93.5%)  >>  OBE
# [20:47:27][OBE] [SKIP] 이미 완료 (체크포인트)
# [20:47:27][PROGRESS] [1862/1990] ( 93.6%)  >>  SLS
# [20:47:27][SLS] [SKIP] 이미 완료 (체크포인트)
# [20:47:27][PROGRESS] [1863/1990] ( 93.6%)  >>  GSS
# [20:47:27][GSS] [SKIP] 이미 완료 (체크포인트)
# [20:47:27][PROGRESS] [1864/1990] ( 93.7%)  >>  MLAB
# [20:47:27][MLAB] [SKIP] 이미 완료 (체크포인트)
# [20:47:27][PROGRESS] [1865/1990] ( 93.7%)  >>  WOLF
# [20:47:27][WOLF] [SKIP] 이미 완료 (체크포인트)
# [20:47:27][PROGRESS] [1866/1990] ( 93.8%)  >>  MG
# [20:47:27][MG] [SKIP] 이미 완료 (체크포인트)
# [20:47:27][PROGRESS] [1867/1990] ( 93.8%)  >>  GLDG
# [20:47:27][GLDG] [SKIP] 이미 완료 (체크포인트)
# [20:47:27][PROGRESS] [1868/1990] ( 93.9%)  >>  AVXL
# [20:47:27][AVXL] [SKIP] 이미 완료 (체크포인트)
# [20:47:27][PROGRESS] [1869/1990] ( 93.9%)  >>  CVGW
# [20:47:27][CVGW] [SKIP] 이미 완료 (체크포인트)
# [20:47:27][PROGRESS] [1870/1990] ( 94.0%)  >>  GRVY
# [20:47:27][GRVY] [SKIP] 이미 완료 (체크포인트)
# [20:47:27][PROGRESS] [1871/1990] ( 94.0%)  >>  FRPH
# [20:47:27][FRPH] [SKIP] 이미 완료 (체크포인트)
# [20:47:27][PROGRESS] [1872/1990] ( 94.1%)  >>  IPI
# [20:47:27][IPI] [SKIP] 이미 완료 (체크포인트)
# [20:47:27][PROGRESS] [1873/1990] ( 94.1%)  >>  CABO
# [20:47:27][CABO] [SKIP] 이미 완료 (체크포인트)
# [20:47:27][PROGRESS] [1874/1990] ( 94.2%)  >>  DMAC
# [20:47:27][DMAC] [SKIP] 이미 완료 (체크포인트)
# [20:47:27][PROGRESS] [1875/1990] ( 94.2%)  >>  LAAC
# [20:47:27][LAAC] [SKIP] 이미 완료 (체크포인트)
# [20:47:27][PROGRESS] [1876/1990] ( 94.3%)  >>  CYH
# [20:47:27][CYH] [SKIP] 이미 완료 (체크포인트)
# [20:47:27][PROGRESS] [1877/1990] ( 94.3%)  >>  ATEX
# [20:47:27][ATEX] [SKIP] 이미 완료 (체크포인트)
# [20:47:27][PROGRESS] [1878/1990] ( 94.4%)  >>  SHYF
# [20:47:27][SHYF] [SKIP] 이미 완료 (체크포인트)
# [20:47:27][PROGRESS] [1879/1990] ( 94.4%)  >>  NETI
# [20:47:27][NETI] [SKIP] 이미 완료 (체크포인트)
# [20:47:27][PROGRESS] [1880/1990] ( 94.5%)  >>  NOA
# [20:47:27][NOA] [SKIP] 이미 완료 (체크포인트)
# [20:47:27][PROGRESS] [1881/1990] ( 94.5%)  >>  NGS
# [20:47:27][NGS] [SKIP] 이미 완료 (체크포인트)
# [20:47:27][PROGRESS] [1882/1990] ( 94.6%)  >>  TRC
# [20:47:27][TRC] [SKIP] 이미 완료 (체크포인트)
# [20:47:27][PROGRESS] [1883/1990] ( 94.6%)  >>  FCEL
# [20:47:27][FCEL] [SKIP] 이미 완료 (체크포인트)
# [20:47:27][PROGRESS] [1884/1990] ( 94.7%)  >>  ALLT
# [20:47:27][ALLT] [SKIP] 이미 완료 (체크포인트)
# [20:47:27][PROGRESS] [1885/1990] ( 94.7%)  >>  CLFD
# [20:47:27][CLFD] [SKIP] 이미 완료 (체크포인트)
# [20:47:27][PROGRESS] [1886/1990] ( 94.8%)  >>  EVH
# [20:47:27][EVH] [SKIP] 이미 완료 (체크포인트)
# [20:47:27][PROGRESS] [1887/1990] ( 94.8%)  >>  CAL
# [20:47:27][CAL] [SKIP] 이미 완료 (체크포인트)
# [20:47:27][PROGRESS] [1888/1990] ( 94.9%)  >>  PTSI
# [20:47:27][PTSI] [SKIP] 이미 완료 (체크포인트)
# [20:47:27][PROGRESS] [1889/1990] ( 94.9%)  >>  NATR
# [20:47:27][NATR] [SKIP] 이미 완료 (체크포인트)
# [20:47:27][PROGRESS] [1890/1990] ( 95.0%)  >>  LPTH
# [20:47:27][LPTH] [SKIP] 이미 완료 (체크포인트)
# [20:47:27][PROGRESS] [1891/1990] ( 95.0%)  >>  ULH
# [20:47:27][ULH] [SKIP] 이미 완료 (체크포인트)
# [20:47:27][PROGRESS] [1892/1990] ( 95.1%)  >>  HVT
# [20:47:27][HVT] [SKIP] 이미 완료 (체크포인트)
# [20:47:27][PROGRESS] [1893/1990] ( 95.1%)  >>  ANGO
# [20:47:27][ANGO] [SKIP] 이미 완료 (체크포인트)
# [20:47:27][PROGRESS] [1894/1990] ( 95.2%)  >>  ZUMZ
# [20:47:27][ZUMZ] [SKIP] 이미 완료 (체크포인트)
# [20:47:27][PROGRESS] [1895/1990] ( 95.2%)  >>  PTN
# [20:47:27][PTN] [SKIP] 이미 완료 (체크포인트)
# [20:47:27][PROGRESS] [1896/1990] ( 95.3%)  >>  USAP
# [20:47:27][USAP] [SKIP] 이미 완료 (체크포인트)
# [20:47:27][PROGRESS] [1897/1990] ( 95.3%)  >>  CLPT
# [20:47:27][CLPT] [SKIP] 이미 완료 (체크포인트)
# [20:47:27][PROGRESS] [1898/1990] ( 95.4%)  >>  TSAT
# [20:47:27][TSAT] [SKIP] 이미 완료 (체크포인트)
# [20:47:27][PROGRESS] [1899/1990] ( 95.4%)  >>  SGU
# [20:47:27][SGU] [SKIP] 이미 완료 (체크포인트)
# [20:47:27][PROGRESS] [1900/1990] ( 95.5%)  >>  VHI
# [20:47:27][VHI] [SKIP] 이미 완료 (체크포인트)
# [20:47:27][PROGRESS] [1901/1990] ( 95.5%)  >>  PLG
# [20:47:27][PLG] [SKIP] 이미 완료 (체크포인트)
# [20:47:27][PROGRESS] [1902/1990] ( 95.6%)  >>  KOR
# [20:47:27][KOR] [SKIP] 이미 완료 (체크포인트)
# [20:47:27][PROGRESS] [1903/1990] ( 95.6%)  >>  GPRK
# [20:47:27][GPRK] [SKIP] 이미 완료 (체크포인트)
# [20:47:27][PROGRESS] [1904/1990] ( 95.7%)  >>  NATH
# [20:47:27][NATH] [SKIP] 이미 완료 (체크포인트)
# [20:47:27][PROGRESS] [1905/1990] ( 95.7%)  >>  PERI
# [20:47:27][PERI] [SKIP] 이미 완료 (체크포인트)
# [20:47:27][PROGRESS] [1906/1990] ( 95.8%)  >>  LTBR
# [20:47:27][LTBR] [SKIP] 이미 완료 (체크포인트)
# [20:47:27][PROGRESS] [1907/1990] ( 95.8%)  >>  ACRS
# [20:47:27][ACRS] [SKIP] 이미 완료 (체크포인트)
# [20:47:27][PROGRESS] [1908/1990] ( 95.9%)  >>  LND
# [20:47:27][LND] [SKIP] 이미 완료 (체크포인트)
# [20:47:27][PROGRESS] [1909/1990] ( 95.9%)  >>  HELE
# [20:47:27][HELE] [SKIP] 이미 완료 (체크포인트)
# [20:47:27][PROGRESS] [1910/1990] ( 96.0%)  >>  CLLS
# [20:47:27][CLLS] [SKIP] 이미 완료 (체크포인트)
# [20:47:27][PROGRESS] [1911/1990] ( 96.0%)  >>  PLM
# [20:47:27][PLM] [SKIP] 이미 완료 (체크포인트)
# [20:47:27][PROGRESS] [1912/1990] ( 96.1%)  >>  WNC
# [20:47:27][WNC] [SKIP] 이미 완료 (체크포인트)
# [20:47:27][PROGRESS] [1913/1990] ( 96.1%)  >>  USNA
# [20:47:27][USNA] [SKIP] 이미 완료 (체크포인트)
# [20:47:27][PROGRESS] [1914/1990] ( 96.2%)  >>  JACK
# [20:47:27][JACK] [SKIP] 이미 완료 (체크포인트)
# [20:47:27][PROGRESS] [1915/1990] ( 96.2%)  >>  ELVA
# [20:47:27][ELVA] [SKIP] 이미 완료 (체크포인트)
# [20:47:27][PROGRESS] [1916/1990] ( 96.3%)  >>  SMLP
# [20:47:27][SMLP] [SKIP] 이미 완료 (체크포인트)
# [20:47:27][PROGRESS] [1917/1990] ( 96.3%)  >>  SLP
# [20:47:27][SLP] [SKIP] 이미 완료 (체크포인트)
# [20:47:27][PROGRESS] [1918/1990] ( 96.4%)  >>  LXFR
# [20:47:27][LXFR] [SKIP] 이미 완료 (체크포인트)
# [20:47:27][PROGRESS] [1919/1990] ( 96.4%)  >>  TROO
# [20:47:27][TROO] [SKIP] 이미 완료 (체크포인트)
# [20:47:27][PROGRESS] [1920/1990] ( 96.5%)  >>  CINR
# [20:47:27][CINR] [SKIP] 이미 완료 (체크포인트)
# [20:47:27][PROGRESS] [1921/1990] ( 96.5%)  >>  GTN
# [20:47:27][GTN] [SKIP] 이미 완료 (체크포인트)
# [20:47:27][PROGRESS] [1922/1990] ( 96.6%)  >>  CECE
# [20:47:27][CECE] [SKIP] 이미 완료 (체크포인트)
# [20:47:27][PROGRESS] [1923/1990] ( 96.6%)  >>  WILC
# [20:47:27][WILC] [SKIP] 이미 완료 (체크포인트)
# [20:47:27][PROGRESS] [1924/1990] ( 96.7%)  >>  CO
# [20:47:27][CO] [SKIP] 이미 완료 (체크포인트)
# [20:47:27][PROGRESS] [1925/1990] ( 96.7%)  >>  TRX
# [20:47:27][TRX] [SKIP] 이미 완료 (체크포인트)
# [20:47:27][PROGRESS] [1926/1990] ( 96.8%)  >>  QUOT
# [20:47:27][QUOT] [SKIP] 이미 완료 (체크포인트)
# [20:47:27][PROGRESS] [1927/1990] ( 96.8%)  >>  SSP
# [20:47:27][SSP] [SKIP] 이미 완료 (체크포인트)
# [20:47:27][PROGRESS] [1928/1990] ( 96.9%)  >>  NBY
# [20:47:27][NBY] [SKIP] 이미 완료 (체크포인트)
# [20:47:27][PROGRESS] [1929/1990] ( 96.9%)  >>  TTGT
# [20:47:27][TTGT] [SKIP] 이미 완료 (체크포인트)
# [20:47:27][PROGRESS] [1930/1990] ( 97.0%)  >>  RCKT
# [20:47:27][RCKT] [SKIP] 이미 완료 (체크포인트)
# [20:47:27][PROGRESS] [1931/1990] ( 97.0%)  >>  MTRX
# [20:47:27][MTRX] [SKIP] 이미 완료 (체크포인트)
# [20:47:27][PROGRESS] [1932/1990] ( 97.1%)  >>  DSKE
# [20:47:27][DSKE] [SKIP] 이미 완료 (체크포인트)
# [20:47:27][PROGRESS] [1933/1990] ( 97.1%)  >>  LSAK
# [20:47:27][LSAK] [SKIP] 이미 완료 (체크포인트)
# [20:47:27][PROGRESS] [1934/1990] ( 97.2%)  >>  KFS
# [20:47:27][KFS] [SKIP] 이미 완료 (체크포인트)
# [20:47:27][PROGRESS] [1935/1990] ( 97.2%)  >>  CTGO
# [20:47:27][CTGO] [SKIP] 이미 완료 (체크포인트)
# [20:47:27][PROGRESS] [1936/1990] ( 97.3%)  >>  TITN
# [20:47:27][TITN] [SKIP] 이미 완료 (체크포인트)
# [20:47:27][PROGRESS] [1937/1990] ( 97.3%)  >>  ESEA
# [20:47:27][ESEA] [SKIP] 이미 완료 (체크포인트)
# [20:47:27][PROGRESS] [1938/1990] ( 97.4%)  >>  RVNC
# [20:47:27][RVNC] [SKIP] 이미 완료 (체크포인트)
# [20:47:27][PROGRESS] [1939/1990] ( 97.4%)  >>  ACTG
# [20:47:27][ACTG] [SKIP] 이미 완료 (체크포인트)
# [20:47:27][PROGRESS] [1940/1990] ( 97.5%)  >>  AKBA
# [20:47:27][AKBA] [SKIP] 이미 완료 (체크포인트)
# [20:47:27][PROGRESS] [1941/1990] ( 97.5%)  >>  VSTM
# [20:47:27][VSTM] [SKIP] 이미 완료 (체크포인트)
# [20:47:27][PROGRESS] [1942/1990] ( 97.6%)  >>  RC
# [20:47:27][RC] [SKIP] 이미 완료 (체크포인트)
# [20:47:27][PROGRESS] [1943/1990] ( 97.6%)  >>  DBI
# [20:47:27][DBI] [SKIP] 이미 완료 (체크포인트)
# [20:47:27][PROGRESS] [1944/1990] ( 97.7%)  >>  LCTX
# [20:47:27][LCTX] [SKIP] 이미 완료 (체크포인트)
# [20:47:27][PROGRESS] [1945/1990] ( 97.7%)  >>  ISSC
# [20:47:27][ISSC] [SKIP] 이미 완료 (체크포인트)
# [20:47:27][PROGRESS] [1946/1990] ( 97.8%)  >>  NC
# [20:47:27][NC] [SKIP] 이미 완료 (체크포인트)
# [20:47:27][PROGRESS] [1947/1990] ( 97.8%)  >>  JKS
# [20:47:27][JKS] [SKIP] 이미 완료 (체크포인트)
# [20:47:27][PROGRESS] [1948/1990] ( 97.9%)  >>  NVEC
# [20:47:27][NVEC] [SKIP] 이미 완료 (체크포인트)
# [20:47:27][PROGRESS] [1949/1990] ( 97.9%)  >>  LAND
# [20:47:27][LAND] [SKIP] 이미 완료 (체크포인트)
# [20:47:27][PROGRESS] [1950/1990] ( 98.0%)  >>  HEAR
# [20:47:27][HEAR] [SKIP] 이미 완료 (체크포인트)
# [20:47:27][PROGRESS] [1951/1990] ( 98.0%)  >>  ACCO
# [20:47:27][ACCO] [SKIP] 이미 완료 (체크포인트)
# [20:47:27][PROGRESS] [1952/1990] ( 98.1%)  >>  ELA
# [20:47:27][ELA] [SKIP] 이미 완료 (체크포인트)
# [20:47:27][PROGRESS] [1953/1990] ( 98.1%)  >>  QIWI
# [20:47:27][QIWI] [SKIP] 이미 완료 (체크포인트)
# [20:47:27][PROGRESS] [1954/1990] ( 98.2%)  >>  KNOP
# [20:47:27][KNOP] [SKIP] 이미 완료 (체크포인트)
# [20:47:27][PROGRESS] [1955/1990] ( 98.2%)  >>  OEC
# [20:47:27][OEC] [SKIP] 이미 완료 (체크포인트)
# [20:47:27][PROGRESS] [1956/1990] ( 98.3%)  >>  GCO
# [20:47:27][GCO] [SKIP] 이미 완료 (체크포인트)
# [20:47:27][PROGRESS] [1957/1990] ( 98.3%)  >>  MCFT
# [20:47:27][MCFT] [SKIP] 이미 완료 (체크포인트)
# [20:47:27][PROGRESS] [1958/1990] ( 98.4%)  >>  MOV
# [20:47:27][MOV] [SKIP] 이미 완료 (체크포인트)
# [20:47:27][PROGRESS] [1959/1990] ( 98.4%)  >>  CTRN
# [20:47:27][CTRN] [SKIP] 이미 완료 (체크포인트)
# [20:47:27][PROGRESS] [1960/1990] ( 98.5%)  >>  FVR
# [20:47:27][FVR] [SKIP] 이미 완료 (체크포인트)
# [20:47:27][PROGRESS] [1961/1990] ( 98.5%)  >>  BGS
# [20:47:27][BGS] [SKIP] 이미 완료 (체크포인트)
# [20:47:27][PROGRESS] [1962/1990] ( 98.6%)  >>  NCMI
# [20:47:27][NCMI] [SKIP] 이미 완료 (체크포인트)
# [20:47:27][PROGRESS] [1963/1990] ( 98.6%)  >>  VGZ
# [20:47:27][VGZ] [SKIP] 이미 완료 (체크포인트)
# [20:47:27][PROGRESS] [1964/1990] ( 98.7%)  >>  CCLP
# [20:47:27][CCLP] [SKIP] 이미 완료 (체크포인트)
# [20:47:27][PROGRESS] [1965/1990] ( 98.7%)  >>  ATNI
# [20:47:27][ATNI] [SKIP] 이미 완료 (체크포인트)
# [20:47:27][PROGRESS] [1966/1990] ( 98.8%)  >>  SMC
# [20:47:27][SMC] [SKIP] 이미 완료 (체크포인트)
# [20:47:27][PROGRESS] [1967/1990] ( 98.8%)  >>  CLDT
# [20:47:27][CLDT] [SKIP] 이미 완료 (체크포인트)
# [20:47:27][PROGRESS] [1968/1990] ( 98.9%)  >>  AMCX
# [20:47:27][AMCX] [SKIP] 이미 완료 (체크포인트)
# [20:47:27][PROGRESS] [1969/1990] ( 98.9%)  >>  BYRN
# [20:47:27][BYRN] [SKIP] 이미 완료 (체크포인트)
# [20:47:27][PROGRESS] [1970/1990] ( 99.0%)  >>  INS
# [20:47:27][INS] [SKIP] 이미 완료 (체크포인트)
# [20:47:27][PROGRESS] [1971/1990] ( 99.0%)  >>  MTLS
# [20:47:27][MTLS] [SKIP] 이미 완료 (체크포인트)
# [20:47:27][PROGRESS] [1972/1990] ( 99.1%)  >>  SNMP
# [20:47:27][SNMP] [SKIP] 이미 완료 (체크포인트)
# [20:47:27][PROGRESS] [1973/1990] ( 99.1%)  >>  OFLX
# [20:47:27][OFLX] [SKIP] 이미 완료 (체크포인트)
# [20:47:27][PROGRESS] [1974/1990] ( 99.2%)  >>  RMNI
# [20:47:27][RMNI] [SKIP] 이미 완료 (체크포인트)
# [20:47:27][PROGRESS] [1975/1990] ( 99.2%)  >>  LWAY
# [20:47:27][LWAY] [SKIP] 이미 완료 (체크포인트)
# [20:47:27][PROGRESS] [1976/1990] ( 99.3%)  >>  SVC
# [20:47:27][SVC] [SKIP] 이미 완료 (체크포인트)
# [20:47:27][PROGRESS] [1977/1990] ( 99.3%)  >>  EVI
# [20:47:27][EVI] [SKIP] 이미 완료 (체크포인트)
# [20:47:27][PROGRESS] [1978/1990] ( 99.4%)  >>  OOMA
# [20:47:27][OOMA] [SKIP] 이미 완료 (체크포인트)
# [20:47:27][PROGRESS] [1979/1990] ( 99.4%)  >>  MLP
# [20:47:27][MLP] [SKIP] 이미 완료 (체크포인트)
# [20:47:27][PROGRESS] [1980/1990] ( 99.5%)  >>  STRT
# [20:47:27][STRT] [SKIP] 이미 완료 (체크포인트)
# [20:47:27][PROGRESS] [1981/1990] ( 99.5%)  >>  LFCR
# [20:47:27][LFCR] [SKIP] 이미 완료 (체크포인트)
# [20:47:27][PROGRESS] [1982/1990] ( 99.6%)  >>  PKOH
# [20:47:27][PKOH] [SKIP] 이미 완료 (체크포인트)
# [20:47:27][PROGRESS] [1983/1990] ( 99.6%)  >>  PBYI
# [20:47:27][PBYI] [SKIP] 이미 완료 (체크포인트)
# [20:47:27][PROGRESS] [1984/1990] ( 99.7%)  >>  MPX
# [20:47:27][MPX] [SKIP] 이미 완료 (체크포인트)
# [20:47:27][PROGRESS] [1985/1990] ( 99.7%)  >>  MIXT
# [20:47:27][MIXT] [SKIP] 이미 완료 (체크포인트)
# [20:47:27][PROGRESS] [1986/1990] ( 99.8%)  >>  DENN
# [20:47:27][DENN] [SKIP] 이미 완료 (체크포인트)
# [20:47:27][PROGRESS] [1987/1990] ( 99.8%)  >>  NEO
# [20:47:27][NEO] [SKIP] 이미 완료 (체크포인트)
# [20:47:27][PROGRESS] [1988/1990] ( 99.9%)  >>  AMRN
# [20:47:27][AMRN] [SKIP] 이미 완료 (체크포인트)
# [20:47:27][PROGRESS] [1989/1990] ( 99.9%)  >>  LOCO
# [20:47:27][LOCO] [SKIP] 이미 완료 (체크포인트)
# [20:47:27][PROGRESS] [1990/1990] (100.0%)  >>  BNTC
# [20:47:27][BNTC] [SKIP] 이미 완료 (체크포인트)
# [20:47:27][RETRY] 실패 티커 8개 재시도
# [20:47:58][DB] batch 1: tickers=1, rows=2,829
# [20:48:09][AMD] [RETRY-FAIL] AMD: price_stock empty
# [20:48:41][DB] batch 1: tickers=1, rows=109
# [20:48:58][ELE] [RETRY-FAIL] ELE: price_stock empty
# [20:49:30][DB] batch 1: tickers=1, rows=140
# [20:49:48][LGN] [RETRY-FAIL] LGN: price_stock empty
# [20:50:18][DB] batch 1: tickers=1, rows=69
# [20:50:36][SCZM] [RETRY-FAIL] SCZM: price_stock empty
# [20:51:08][DB] batch 1: tickers=1, rows=285
# [20:51:25][SNDK] [RETRY-FAIL] SNDK: price_stock empty
# [20:51:57][DB] batch 1: tickers=1, rows=294
# [20:52:15][STRK] [RETRY-FAIL] STRK: price_stock empty
# [20:52:45][DB] batch 1: tickers=1, rows=75
# [20:53:03][SVA] [RETRY-FAIL] SVA: price_stock empty
# [20:53:35][DB] batch 1: tickers=1, rows=137
# [20:53:52][WBI] [RETRY-FAIL] WBI: price_stock empty
# [20:53:52][RETRY] 재시도 완료. 최종 실패: 8개
# [20:53:52][BATCH] ======================================================================
# [20:53:52][BATCH] 완료 | 성공=0  스킵=1982  실패=8  합계=1990
# [20:53:52][BATCH] 체크포인트: _batch_checkpoint\done_tickers.txt
# [20:53:52][BATCH] ======================================================================

# %% [markdown]
# ## Cell 12 · DB 조회 유틸 (pivot 조회)
#
# long-format → pivot 형태로 변환해 반환합니다.

# %%
def fetch_required_return_pivot_from_db(
    db_info: Dict[str, Any],
    table_name: str               = TABLE_RESULT,
    indicators: Optional[List[str]] = None,
    start_date: Optional[str]     = None,
    end_date: Optional[str]       = None,
    tickers: Optional[List[str]]  = None,
) -> pd.DataFrame:
    """
    DB long-format → pivot DataFrame.
    반환 컬럼: date, ticker, [indicator 컬럼들...]

    수정 포인트:
      CASE WHEN 의 indicator 값은 직접 SQL 문자열에 삽입 (이스케이프 처리).
      WHERE 절 조건값만 %s 바인딩 사용.
      → pymysql 파라미터 순서 꼬임 문제 완전 해결.
    """
    if indicators is None:
        indicators = ["Re_1y", "Re_3y", "Re_5y",
                      "beta_252", "beta_750", "beta_1250"]

    # ── CASE WHEN: indicator 값을 SQL 문자열에 직접 삽입 (이스케이프) ──
    # %s 파라미터 바인딩 사용 시 WHERE 절 params 와 순서가 꼬이므로
    # indicator 명은 따옴표 이스케이프 후 SQL 리터럴로 직접 삽입
    case_parts = []
    for ind in indicators:
        ind_escaped = ind.replace("'", "''")
        col_name    = ind.replace("'", "''").replace("`", "``")
        case_parts.append(
            f"MAX(CASE WHEN indicator = '{ind_escaped}' THEN value END) AS `{col_name}`"
        )
    case_sql = ",\n                ".join(case_parts)

    # ── WHERE 절: 조건값만 %s 바인딩 ────────────────────────────
    where_clauses = []
    params        = []

    if start_date:
        where_clauses.append("date >= %s")
        params.append(start_date)
    if end_date:
        where_clauses.append("date <= %s")
        params.append(end_date)
    if tickers:
        placeholders = ", ".join(["%s"] * len(tickers))
        where_clauses.append(f"ticker IN ({placeholders})")
        params.extend(tickers)

    where_sql = ("WHERE " + " AND ".join(where_clauses)) if where_clauses else ""

    query = f"""
        SELECT
            date,
            ticker,
            {case_sql}
        FROM   {table_name}
        {where_sql}
        GROUP  BY date, ticker
        ORDER  BY date, ticker;
    """

    # params 에는 WHERE 절 조건값만 포함 (CASE WHEN 값 제외)
    conn = get_conn(db_info)
    try:
        df_pivot = pd.read_sql(query, conn, params=params if params else None)
        df_pivot["date"] = pd.to_datetime(df_pivot["date"], errors="coerce")
        df_pivot = df_pivot.dropna(subset=["date"]).reset_index(drop=True)
        return df_pivot
    finally:
        conn.close()


print("[OK] fetch_required_return_pivot_from_db 함수 정의 완료")
print("     수정: CASE WHEN indicator 값을 SQL 리터럴로 직접 삽입")
print("           WHERE 조건값만 %s 바인딩 → 파라미터 순서 꼬임 해결")
# Out:
# [OK] fetch_required_return_pivot_from_db 함수 정의 완료
#      수정: CASE WHEN indicator 값을 SQL 리터럴로 직접 삽입
#            WHERE 조건값만 %s 바인딩 → 파라미터 순서 꼬임 해결

# %%
# 테이블 전체 row 수와 ticker 종류 확인
conn = get_conn(db_info)
try:
    df_check  = pd.read_sql(f"SELECT COUNT(*) AS cnt FROM {TABLE_RESULT}", conn)
    df_ticker = pd.read_sql(f"SELECT DISTINCT ticker FROM {TABLE_RESULT} LIMIT 10", conn)
finally:
    conn.close()

cnt = int(df_check['cnt'].iloc[0])
print(f"전체 row 수: {cnt:,}")
print(f"저장된 ticker 샘플:\n{df_ticker}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 9
#       6 finally:
#       7     conn.close()
# ----> 9 cnt = int(df_check['cnt'].iloc[0])
#      10 print(f"전체 row 수: {cnt:,}")
#      11 print(f"저장된 ticker 샘플:\n{df_ticker}")
#
# ValueError: invalid literal for int() with base 10: 'cnt'

# %%
conn = get_conn(db_info)
try:
    df_raw = pd.read_sql(
        f"SELECT * FROM {TABLE_RESULT} WHERE ticker = 'AAPL' LIMIT 10",
        conn
    )
finally:
    conn.close()

print(f"AAPL raw 데이터: {len(df_raw)}행")
print(df_raw)
# Out:
# AAPL raw 데이터: 10행
#    date  ticker  indicator  value
# 0  date  ticker  indicator  value
# 1  date  ticker  indicator  value
# 2  date  ticker  indicator  value
# 3  date  ticker  indicator  value
# 4  date  ticker  indicator  value
# 5  date  ticker  indicator  value
# 6  date  ticker  indicator  value
# 7  date  ticker  indicator  value
# 8  date  ticker  indicator  value
# 9  date  ticker  indicator  value

# %%
# python# DB에 실제로 어떤 indicator 이름으로 저장됐는지 확인
conn = get_conn(db_info)
try:
    df_ind = pd.read_sql(
        f"SELECT DISTINCT indicator FROM {TABLE_RESULT} LIMIT 20",
        conn
    )
finally:
    conn.close()

print("저장된 indicator 목록:")
print(df_ind)
# Out:
# 저장된 indicator 목록:
#     indicator
# 0   indicator
# 1   indicator
# 2   indicator
# 3   indicator
# 4   indicator
# 5   indicator
# 6   indicator
# 7   indicator
# 8   indicator
# 9   indicator
# 10  indicator
# 11  indicator
# 12  indicator
# 13  indicator
# 14  indicator
# 15  indicator

# %%
# pymysql 커서로 직접 조회 (pd.read_sql 우회)
conn = get_conn(db_info)
try:
    with conn.cursor() as cur:
        # 오염 행 수 확인
        cur.execute(f"SELECT COUNT(*) AS cnt FROM {TABLE_RESULT} WHERE date = 'date'")
        row = cur.fetchone()
        print(f"오염된 행 수: {row['cnt']}")

        # 정상 행 수 확인
        cur.execute(f"SELECT COUNT(*) AS cnt FROM {TABLE_RESULT} WHERE date != 'date'")
        row2 = cur.fetchone()
        print(f"정상 행 수  : {row2['cnt']}")

        # 저장된 ticker 샘플
        cur.execute(f"SELECT DISTINCT ticker FROM {TABLE_RESULT} WHERE date != 'date' LIMIT 10")
        tickers = cur.fetchall()
        print(f"ticker 샘플 : {[r['ticker'] for r in tickers]}")

        # 저장된 indicator 샘플
        cur.execute(f"SELECT DISTINCT indicator FROM {TABLE_RESULT} WHERE date != 'date' LIMIT 10")
        inds = cur.fetchall()
        print(f"indicator 샘플: {[r['indicator'] for r in inds]}")
finally:
    conn.close()
# Out:
# 오염된 행 수: 0
# 정상 행 수  : 45039872
# ticker 샘플 : ['AAL', 'AAON', 'AAPL', 'ABUS', 'ACAD', 'ACHC', 'ACLS', 'ADBE', 'ADEA', 'ADI']
# indicator 샘플: ['beta_252', 'Re_1y', 'beta_750', 'Re_3y', 'beta_1250', 'Re_5y', 'price_stock', 'price_mkt', 'rf_1y', 'rf_3y']

# %% [markdown]
# ## Cell 13 · 결과 조회 테스트

# %%
# ── 단일 티커 조회 테스트 ─────────────────────────────────────
TEST_TICKER = "AAPL"   # ← 변경 가능

re_df = fetch_required_return_pivot_from_db(
    db_info    = db_info,
    table_name = TABLE_RESULT,
    indicators = ["Re_1y", "Re_3y", "Re_5y", "beta_252", "beta_750", "beta_1250"],
    start_date = "2020-01-01",
    end_date   = None,
    tickers    = [TEST_TICKER],
)

print(f"[조회] {TEST_TICKER}  총 {len(re_df)}행")
print("\n--- 앞 5행 ---")
display(re_df.head())
print("\n--- 뒤 5행 ---")
display(re_df.tail())
# Out:
# [조회] AAPL  총 0행
#
# --- 앞 5행 ---
# Empty DataFrame
# Columns: [date, ticker, Re_1y, Re_3y, Re_5y, beta_252, beta_750, beta_1250]
# Index: []
# --- 뒤 5행 ---
# Empty DataFrame
# Columns: [date, ticker, Re_1y, Re_3y, Re_5y, beta_252, beta_750, beta_1250]
# Index: []

# %%
# ── 전체 저장 현황 요약 ───────────────────────────────────────
sql_summary = f"""
    SELECT
        indicator,
        COUNT(DISTINCT ticker) AS ticker_cnt,
        COUNT(*)               AS total_rows,
        MIN(date)              AS date_from,
        MAX(date)              AS date_to
    FROM   {TABLE_RESULT}
    GROUP  BY indicator
    ORDER  BY indicator;
"""

conn = get_conn(db_info)
try:
    summary_df = pd.read_sql(sql_summary, conn)
finally:
    conn.close()

print(f"[전체 저장 현황]  {TABLE_RESULT}")
display(summary_df)
