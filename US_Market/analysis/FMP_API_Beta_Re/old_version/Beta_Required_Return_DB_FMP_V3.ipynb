# %% [markdown]
# # US Beta / Required Return — Batch Runner V3
#
# **저장 테이블** : `us_required_return_result`
# **저장 형태**   : `date · ticker · indicator · value` (long-format)
# **저장 방법**   : `INSERT ... ON DUPLICATE KEY UPDATE` (upsert)
# **PRIMARY KEY** : `(date, ticker, indicator)`
#
# ---
#
# | 셀 | 단계 |
# |----|------|
# | 1  | 환경 설정 & 경로 자동 감지 (노트북/데스크탑 자동 판별) |
# | 2  | 모듈 Import & 설정 상수 |
# | 3  | DB 연결 함수 / 조회 함수 |
# | 4  | FMP / FDR 가격 fetch 함수 |
# | 5  | RF(국채금리) fetch 함수 |
# | 6  | Beta · Required Return 계산 함수 |
# | 7  | MySQL 저장 함수 (sanitize + upsert) |
# | 8  | 가격 확보 함수 (ensure_price_series) |
# | 9  | 티커 1개 업데이트 함수 (update_one_ticker) |
# | 10 | SPY / RF 공통 데이터 준비 |
# | 11 | 배치 실행 (구간 지정 · 체크포인트 · 실패 재시도) |
# | 12 | DB 조회 유틸 (pivot 조회) |
# | 13 | 결과 조회 테스트 |
#
# ---
# ### 개선 사항 (V2 → V3)
# - **경로 자동 감지**: 노트북/데스크탑 환경 자동 판별, `config.py` 경유 DB 접속
# - **Python 3.9 호환**: `X | Y` 타입 힌트 제거 → `Optional[X]` 방식 통일
# - **구간 실행**: `TICKER_START` / `TICKER_END` 로 2000개 티커를 단계적으로 처리
# - **진행률 표시**: `[idx/total] (pct%)  ticker` 형태로 실시간 출력
# - **메모리 관리**: 1개 티커 처리 후 즉시 저장 + `gc.collect()` (배치 누적 방지)
# - **로그 통일**: `[HH:MM:SS][TAG] msg` 형태
# - **FDR fallback 강화**: FMP 실패 시 FDR 자동 전환

# %% [markdown]
# ## Cell 1 · 환경 설정 & 경로 자동 감지

# %%
import sys, os, gc, warnings
from pathlib import Path
warnings.filterwarnings("ignore")

# ── 후보 프로젝트 루트 (노트북 / 데스크탑) ───────────────────
_CANDIDATE_ROOTS = [
    r"C:\Users\Hoyoung_Park\PyCharmMiscProject\stock_forecast",         # 노트북
    r"C:\Users\82108\OneDrive\바탕 화면\investment\investment_strategy",  # 데스크탑
]

def _setup_path() -> str:
    """
    DATA/ 폴더를 포함하는 프로젝트 루트를 탐색해 sys.path 에 추가합니다.
    탐색 순서:
      1) cwd / __file__ 상위 경로 중 DATA/ 를 포함하는 첫 번째 경로
      2) _CANDIDATE_ROOTS 에서 DATA/ 가 있는 첫 번째 경로
    """
    try:
        start = Path(__file__).resolve().parent
    except NameError:
        start = Path.cwd()

    for p in [start] + list(start.parents):
        if (p / "DATA").is_dir():
            root = str(p)
            if root not in sys.path:
                sys.path.insert(0, root)
            print(f"[PATH] root 자동 감지 : {root}")
            return root

    for candidate in _CANDIDATE_ROOTS:
        if os.path.isdir(candidate) and os.path.isdir(os.path.join(candidate, "DATA")):
            if candidate not in sys.path:
                sys.path.insert(0, candidate)
            print(f"[PATH] root 후보 경로 : {candidate}")
            return candidate

    raise EnvironmentError(
        "DATA 폴더를 찾을 수 없습니다.\n"
        "_CANDIDATE_ROOTS 를 현재 환경에 맞게 수정하거나 "
        "노트북을 프로젝트 루트 아래에서 실행하세요."
    )

_ROOT = _setup_path()
print(f"[확인] 프로젝트 루트 : {_ROOT}")
print(f"[확인] DATA 경로    : {os.path.join(_ROOT, 'DATA')}")
# Out:
# [PATH] root 자동 감지 : C:\Users\82108\OneDrive\바탕 화면\investment\investment_strategy
# [확인] 프로젝트 루트 : C:\Users\82108\OneDrive\바탕 화면\investment\investment_strategy
# [확인] DATA 경로    : C:\Users\82108\OneDrive\바탕 화면\investment\investment_strategy\DATA

# %% [markdown]
# ## Cell 2 · 모듈 Import & 설정 상수

# %%
# ── 표준 라이브러리 ───────────────────────────────────────────
import math
import time
import requests
from datetime import datetime
from typing import Optional, Dict, Any, List, Tuple
from pandas.tseries.offsets import BDay

# ── 외부 라이브러리 ───────────────────────────────────────────
import numpy as np
import pandas as pd
import pymysql
import FinanceDataReader as fdr
from IPython.display import display

# ── 내부 모듈 ─────────────────────────────────────────────────
from DATA.config import get_db_info, get_engine
from DATA.us_target_ticker_list_2000 import ticker_list as DEFAULT_TICKER_LIST

# ── 로그 유틸 ─────────────────────────────────────────────────
def log(tag: str, msg: str):
    ts = datetime.now().strftime("%H:%M:%S")
    print(f"[{ts}][{tag}] {msg}")

# ══════════════════════════════════════════════════════════════
#  설정 상수 — 여기만 수정하세요
# ══════════════════════════════════════════════════════════════
DB_NAME       = "investar"
TABLE_RESULT  = "us_required_return_result"
DEFAULT_PORT  = 3307
MARKET_TICKER = "SPY"

# FMP API
API_KEY            = "hT0gAk87j9xZx4PlBApvBqfVL5IahvgV"   # ← 필요시 변경
MAX_RETRY          = 5
SLEEP_BETWEEN_CALLS = 0.35
MIN_START_DATE     = "2015-01-01"

# Beta 윈도우
BETA_WINDOWS         = [252, 750, 1250]   # beta_252, beta_750, beta_1250
MAX_ROLLING_WINDOW   = max(BETA_WINDOWS)  # 1250
ROLLING_WARMUP_BDAYS = MAX_ROLLING_WINDOW + 80

# 저장 모드: "minimal" (Re + beta) / "full" (모든 중간값 포함)
STORE_MODE = "minimal"

# 체크포인트
CHECKPOINT_DIR    = "../_batch_checkpoint"
os.makedirs(CHECKPOINT_DIR, exist_ok=True)
DEFAULT_DONE_PATH = os.path.join(CHECKPOINT_DIR, "done_tickers.txt")
DEFAULT_FAIL_PATH = os.path.join(CHECKPOINT_DIR, "failed_tickers.txt")

# ══════════════════════════════════════════════════════════════
print(f"[OK] Import 완료")
print(f"[OK] DEFAULT_TICKER_LIST: {len(DEFAULT_TICKER_LIST):,}개")
print(f"[설정] TABLE={TABLE_RESULT}  STORE_MODE={STORE_MODE}")
print(f"[설정] BETA_WINDOWS={BETA_WINDOWS}")
print(f"[설정] MIN_START_DATE={MIN_START_DATE}")
# Out:
# [OK] Import 완료
# [OK] DEFAULT_TICKER_LIST: 2,000개
# [설정] TABLE=us_required_return_result  STORE_MODE=minimal
# [설정] BETA_WINDOWS=[252, 750, 1250]
# [설정] MIN_START_DATE=2015-01-01

# %% [markdown]
# ## Cell 3 · DB 연결 함수 / 조회 함수

# %%
# ── DB 접속 정보 ──────────────────────────────────────────────
db_info = get_db_info()   # config.py 의 get_db_info()


def get_conn(db_info: Dict[str, Any]):
    """pymysql 연결 생성"""
    return pymysql.connect(
        host        = db_info["host"],
        port        = db_info.get("port", DEFAULT_PORT),
        user        = db_info["user"],
        password    = db_info["password"],
        db          = db_info.get("database", DB_NAME),
        charset     = "utf8mb4",
        autocommit  = False,
        cursorclass = pymysql.cursors.DictCursor,
    )


def get_minmax_date_in_db(
    db_info: Dict[str, Any],
    ticker: str,
    indicator: str,
) -> Tuple[Optional[pd.Timestamp], Optional[pd.Timestamp]]:
    """MIN/MAX 날짜를 1회 쿼리로 조회 (커넥션 수 최소화)"""
    sql = f"""
        SELECT MIN(date) AS first_date, MAX(date) AS last_date
        FROM   {TABLE_RESULT}
        WHERE  ticker=%s AND indicator=%s;
    """
    conn = get_conn(db_info)
    try:
        with conn.cursor() as cur:
            cur.execute(sql, (ticker, indicator))
            row = cur.fetchone()
            first_dt = row["first_date"] if row else None
            last_dt  = row["last_date"]  if row else None
    finally:
        conn.close()

    first_dt = pd.to_datetime(first_dt) if first_dt is not None else None
    last_dt  = pd.to_datetime(last_dt)  if last_dt  is not None else None
    return first_dt, last_dt


def read_indicator_series(
    db_info, ticker, indicator, start_date=None, end_date=None
) -> pd.DataFrame:
    where  = ["ticker=%s", "indicator=%s"]
    params = [ticker, indicator]
    if start_date:
        where.append("date >= %s"); params.append(start_date)
    if end_date:
        where.append("date <= %s"); params.append(end_date)

    sql = f"""
        SELECT date, value FROM {TABLE_RESULT}
        WHERE  {" AND ".join(where)}
        ORDER  BY date;
    """
    conn = get_conn(db_info)
    try:
        with conn.cursor() as cur:
            cur.execute(sql, params)
            rows = cur.fetchall()
            df = pd.DataFrame(rows)
    finally:
        conn.close()

    if df.empty:
        return pd.DataFrame(columns=["date", "value"])

    df["date"]  = pd.to_datetime(df["date"], errors="coerce")
    df["value"] = pd.to_numeric(df["value"], errors="coerce")
    df = df.dropna(subset=["date"]).drop_duplicates("date").sort_values("date")
    return df


# ── 연결 테스트 ───────────────────────────────────────────────
try:
    _c = get_conn(db_info)
    with _c.cursor() as _cur:
        _cur.execute("SELECT 1")
    _c.close()
    log("DB", f"연결 성공  host={db_info.get('host')}  port={db_info.get('port')}  db={db_info.get('database')}")
except Exception as _e:
    log("DB", f"연결 실패: {_e}")
# Out:
# [15:12:37][DB] 연결 성공  host=192.168.0.230  port=3307  db=investar

# %% [markdown]
# ## Cell 4 · FMP / FDR 가격 fetch 함수

# %%
def _get_json(url: str, params: Dict[str, Any]) -> Any:
    """FMP API 호출 (재시도 포함)"""
    last_err = None
    for k in range(MAX_RETRY):
        try:
            r = requests.get(url, params=params, timeout=30)
            if r.status_code == 429:
                time.sleep(1.0 + 0.7 * k)
                continue
            r.raise_for_status()
            return r.json()
        except Exception as e:
            last_err = e
            time.sleep(0.7 + 0.7 * k)
    raise RuntimeError(f"FMP 요청 실패 (재시도 {MAX_RETRY}회): {last_err}")


def fetch_fmp_price(
    symbol: str,
    api_key: str,
    start_date: str,
    end_date: Optional[str]   = None,
    min_start_date: str       = MIN_START_DATE,
) -> pd.DataFrame:
    """
    FMP에서 adjClose 우선으로 가격 fetch.
    start_date 가 min_start_date 보다 최근이면 min_start_date 로 당김.
    반환: columns [date, price]
    """
    if pd.to_datetime(start_date) > pd.to_datetime(min_start_date):
        start_date = min_start_date

    url    = f"https://financialmodelingprep.com/api/v3/historical-price-full/{symbol}"
    params = {"from": start_date, "apikey": api_key}
    if end_date is not None:
        params["to"] = end_date

    try:
        js   = _get_json(url, params=params)
        hist = js.get("historical", []) if isinstance(js, dict) else []
    except Exception:
        return pd.DataFrame(columns=["date", "price"])

    if not hist:
        return pd.DataFrame(columns=["date", "price"])

    df = pd.DataFrame(hist)
    df["date"] = pd.to_datetime(df["date"], errors="coerce")
    df = df.dropna(subset=["date"])
    price_col = "adjClose" if "adjClose" in df.columns else "close"
    df[price_col] = pd.to_numeric(df[price_col], errors="coerce")
    df = (
        df[["date", price_col]]
        .rename(columns={price_col: "price"})
        .dropna(subset=["price"])
        .drop_duplicates("date")
        .sort_values("date")
    )
    return df


def fetch_fdr_price(
    symbol: str,
    start_date: str,
    end_date: str,
) -> pd.DataFrame:
    """FinanceDataReader fallback. 반환: columns [date, price]"""
    try:
        df = fdr.DataReader(symbol, start_date, end_date)
    except Exception:
        return pd.DataFrame(columns=["date", "price"])

    if df is None or df.empty:
        return pd.DataFrame(columns=["date", "price"])

    df = df.copy().reset_index()
    # 날짜 컬럼 통일
    date_col = next((c for c in df.columns if c.lower() in ("date", "index")), df.columns[0])
    df = df.rename(columns={date_col: "date"})

    # 가격 컬럼 우선순위
    for pc in ("Adj Close", "adj close", "Close", "close"):
        if pc in df.columns:
            price_col = pc
            break
    else:
        num_cols = df.select_dtypes(include=[np.number]).columns.tolist()
        if not num_cols:
            return pd.DataFrame(columns=["date", "price"])
        price_col = num_cols[0]

    out = df[["date", price_col]].rename(columns={price_col: "price"})
    out["date"]  = pd.to_datetime(out["date"], errors="coerce")
    out["price"] = pd.to_numeric(out["price"], errors="coerce")
    out = out.dropna(subset=["date", "price"]).drop_duplicates("date").sort_values("date")
    return out


print("[OK] fetch_fmp_price / fetch_fdr_price 함수 정의 완료")
# Out:
# [OK] fetch_fmp_price / fetch_fdr_price 함수 정의 완료

# %% [markdown]
# ## Cell 5 · RF(국채금리) fetch 함수

# %%
def fetch_us_treasury_yields(
    start_date: str,
    end_date: Optional[str] = None,
) -> pd.DataFrame:
    """
    1y / 3y / 5y 미국 국채 수익률을 FRED 또는 Yahoo 로 fetch.
    반환: index=date, columns=[rf_1y, rf_3y, rf_5y]  (소수 단위, 예: 0.045)
    """
    if end_date is None:
        end_date = pd.Timestamp.today().strftime("%Y-%m-%d")

    # 1순위: FRED
    try:
        y1 = fdr.DataReader("FRED:DGS1", start_date, end_date)
        y3 = fdr.DataReader("FRED:DGS3", start_date, end_date)
        y5 = fdr.DataReader("FRED:DGS5", start_date, end_date)
        idx = y1.index.union(y3.index).union(y5.index)
        out = pd.DataFrame(index=idx).sort_index()
        out["rf_1y"] = pd.to_numeric(y1.iloc[:, 0], errors="coerce") / 100.0
        out["rf_3y"] = pd.to_numeric(y3.iloc[:, 0], errors="coerce") / 100.0
        out["rf_5y"] = pd.to_numeric(y5.iloc[:, 0], errors="coerce") / 100.0
        log("RF", f"FRED 로드 성공: {len(out)}행")
        return out
    except Exception:
        pass

    # 2순위: Yahoo (^IRX, ^FVX)
    try:
        y1 = fdr.DataReader("^IRX", start_date, end_date)
        y5 = fdr.DataReader("^FVX", start_date, end_date)
        idx = y1.index.union(y5.index)
        out = pd.DataFrame(index=idx).sort_index()
        out["rf_1y"] = pd.to_numeric(y1["Close"], errors="coerce") / 100.0
        out["rf_5y"] = pd.to_numeric(y5["Close"], errors="coerce") / 100.0
        out["rf_3y"] = out["rf_1y"] + (out["rf_5y"] - out["rf_1y"]) * (3 - 1) / (5 - 1)
        log("RF", f"Yahoo fallback 로드 성공: {len(out)}행")
        return out
    except Exception as e:
        log("RF", f"[WARN] 국채 금리 로드 실패: {e}")
        return pd.DataFrame(columns=["rf_1y", "rf_3y", "rf_5y"])


print("[OK] fetch_us_treasury_yields 함수 정의 완료")
# Out:
# [OK] fetch_us_treasury_yields 함수 정의 완료

# %% [markdown]
# ## Cell 6 · Beta · Required Return 계산 함수

# %%
def rolling_beta(
    ret_stock: pd.Series,
    ret_mkt: pd.Series,
    window: int,
) -> pd.Series:
    """Rolling Beta = Cov(ret_stock, ret_mkt) / Var(ret_mkt)"""
    cov = ret_stock.rolling(window).cov(ret_mkt)
    var = ret_mkt.rolling(window).var()
    return cov / var


def build_features(
    price_stock_df: pd.DataFrame,
    price_mkt_df: pd.DataFrame,
    rf_df: pd.DataFrame,
) -> pd.DataFrame:

    df = pd.merge(price_stock_df, price_mkt_df, on="date", how="inner")
    df = df.sort_values("date").drop_duplicates("date").reset_index(drop=True)

    df["price_stock"] = pd.to_numeric(df["price_stock"], errors="coerce")
    df["price_mkt"]   = pd.to_numeric(df["price_mkt"],   errors="coerce")
    df = df.dropna(subset=["price_stock", "price_mkt"])

    df["ret_stock"] = df["price_stock"].pct_change()
    df["ret_mkt"]   = df["price_mkt"].pct_change()

    # Rolling Beta
    for w in BETA_WINDOWS:
        df[f"beta_{w}"] = rolling_beta(df["ret_stock"], df["ret_mkt"], w)

    # ── RF 조인 (수정본) ─────────────────────────────────────────
    if rf_df is None or rf_df.empty:
        df["rf_1y"] = np.nan
        df["rf_3y"] = np.nan
        df["rf_5y"] = np.nan
    else:
        # ★ 1) 인덱스 → 컬럼으로 꺼내고 타입을 date로 통일
        rf2 = rf_df.copy().reset_index()
        rf2.columns = ["date", "rf_1y", "rf_3y", "rf_5y"]
        rf2["date"] = pd.to_datetime(rf2["date"]).dt.normalize().dt.tz_localize(None)
        rf2 = rf2.dropna(subset=["rf_1y", "rf_3y", "rf_5y"], how="all")
        rf2 = rf2.sort_values("date")

        df["date"] = pd.to_datetime(df["date"]).dt.normalize()

        # ★ 2) merge_asof: RF 없는 날짜는 가장 가까운 과거값으로 자동 채움
        df = pd.merge_asof(
            df.sort_values("date"),
            rf2[["date", "rf_1y", "rf_3y", "rf_5y"]],
            on="date",
            direction="backward",
        )

    # 기대 시장 수익률 (연환산)
    df["E_Rm_1y"] = df["ret_mkt"].rolling(252).mean()  * 252
    df["E_Rm_3y"] = df["ret_mkt"].rolling(750).mean()  * 252
    df["E_Rm_5y"] = df["ret_mkt"].rolling(1250).mean() * 252

    # CAPM Required Return
    df["Re_1y"] = df["rf_1y"] + df["beta_252"]  * (df["E_Rm_1y"] - df["rf_1y"])
    df["Re_3y"] = df["rf_3y"] + df["beta_750"]  * (df["E_Rm_3y"] - df["rf_3y"])
    df["Re_5y"] = df["rf_5y"] + df["beta_1250"] * (df["E_Rm_5y"] - df["rf_5y"])

    return df


print("[OK] rolling_beta / build_features 함수 정의 완료")
print(f"     BETA_WINDOWS = {BETA_WINDOWS}")
print(f"     저장 지표 (minimal): beta_252/750/1250, Re_1y/3y/5y")
# Out:
# [OK] rolling_beta / build_features 함수 정의 완료
#      BETA_WINDOWS = [252, 750, 1250]
#      저장 지표 (minimal): beta_252/750/1250, Re_1y/3y/5y

# %% [markdown]
# ## Cell 7 · MySQL 저장 함수 (sanitize + upsert)
#
# - NaN / inf → `None` 변환 후 저장
# - `INSERT ... ON DUPLICATE KEY UPDATE value = VALUES(value)`
# - ticker 단위로 커넥션 분리 → 메모리/커넥션 부담 최소화

# %%
def _to_mysql_float(x: Any) -> Optional[float]:
    """NaN / inf → None, 그 외 float 반환"""
    if x is None:
        return None
    try:
        v = float(x)
    except Exception:
        return None
    return None if (math.isnan(v) or math.isinf(v)) else v


def sanitize_long_for_mysql(df: pd.DataFrame) -> pd.DataFrame:
    """저장 전 데이터 정제"""
    out = df.copy()
    out["date"]      = pd.to_datetime(out["date"], errors="coerce")
    out = out[out["date"].notna()]
    out["date"]      = out["date"].dt.date
    out["ticker"]    = out["ticker"].astype(str)
    out["indicator"] = out["indicator"].astype(str)
    out = out[~out["ticker"].str.lower().isin(["nan", "none"])]
    out = out[~out["indicator"].str.lower().isin(["nan", "none"])]
    out["value"]     = pd.to_numeric(out["value"], errors="coerce")
    out["value"]     = out["value"].apply(_to_mysql_float)
    out = out.drop_duplicates(subset=["date", "ticker", "indicator"])
    return out


def upsert_long_df(
    db_info: Dict[str, Any],
    long_df: pd.DataFrame,
    batch_size_rows: int   = 50_000,
    batch_size_ticker: int = 50,
    drop_null_values: bool = True,
) -> int:
    """
    long_df → DB upsert.
    PK (date, ticker, indicator) 중복 시 value 업데이트.
    Returns: 저장 행 수
    """
    if long_df is None or long_df.empty:
        return 0

    df = sanitize_long_for_mysql(long_df)
    if drop_null_values:
        df = df.dropna(subset=["value"])
    if df.empty:
        return 0

    tickers = sorted(df["ticker"].unique())
    total_saved = 0

    insert_sql = f"""
        INSERT INTO {TABLE_RESULT} (date, ticker, indicator, value)
        VALUES (%s, %s, %s, %s)
        ON DUPLICATE KEY UPDATE
            value = VALUES(value);
    """

    for i in range(0, len(tickers), batch_size_ticker):
        batch_tickers = tickers[i : i + batch_size_ticker]
        batch = (
            df[df["ticker"].isin(batch_tickers)]
            .sort_values(["ticker", "date", "indicator"])
        )
        rows = list(batch[["date", "ticker", "indicator", "value"]].itertuples(index=False, name=None))

        conn = get_conn(db_info)
        try:
            with conn.cursor() as cur:
                for j in range(0, len(rows), batch_size_rows):
                    chunk = rows[j : j + batch_size_rows]
                    # NaN/inf 샘플 검사
                    for _r in chunk[:10]:
                        vv = _r[3]
                        if isinstance(vv, float) and (math.isnan(vv) or math.isinf(vv)):
                            raise ValueError(f"NaN/inf 발견: {_r}")
                    cur.executemany(insert_sql, chunk)
            conn.commit()
            log("DB", f"batch {i//batch_size_ticker+1}: tickers={len(batch_tickers)}, rows={len(rows):,}")
            total_saved += len(rows)
        except Exception:
            conn.rollback()
            raise
        finally:
            conn.close()

    return total_saved


# ── 체크포인트 유틸 ───────────────────────────────────────────
def _load_set(path: str) -> set:
    if not os.path.exists(path):
        return set()
    with open(path, "r", encoding="utf-8") as f:
        return {line.strip() for line in f if line.strip()}

def _append_line(path: str, line: str) -> None:
    with open(path, "a", encoding="utf-8") as f:
        f.write(line.strip() + "\n")


print("[OK] sanitize_long_for_mysql / upsert_long_df 함수 정의 완료")
# Out:
# [OK] sanitize_long_for_mysql / upsert_long_df 함수 정의 완료

# %% [markdown]
# ## Cell 8 · 가격 확보 함수 (ensure_price_series)
#
# - DB에 있는 구간 확인 → **부족분만** FMP 또는 FDR 호출
# - backfill (과거) / forward (최신) 각각 필요한 구간만 요청
# - FMP 실패 시 FDR 자동 fallback

# %%
def ensure_price_series(
    db_info: Dict[str, Any],
    ticker: str,
    api_key: str,
    indicator_name: str       = "price_stock",
    today_iso: Optional[str]  = None,
    min_start_date: str       = MIN_START_DATE,
    return_start_date: Optional[str] = None,
) -> pd.DataFrame:
    """
    DB에서 가격을 확인하고 부족분만 FMP/FDR 로 fetch 후 저장.

    Returns
    -------
    DataFrame  columns: [date, {indicator_name}]
    """
    if today_iso is None:
        today_iso = datetime.utcnow().date().isoformat()

    first_dt, last_dt = get_minmax_date_in_db(db_info, ticker, indicator_name)

    def _fetch(start: str, end: Optional[str]) -> pd.DataFrame:
        """FMP 먼저, 실패 시 FDR fallback"""
        df = fetch_fmp_price(ticker, api_key, start, end, min_start_date)
        time.sleep(SLEEP_BETWEEN_CALLS)
        if df.empty:
            df = fetch_fdr_price(ticker, start, end or today_iso)
        return df

    def _store(df_price: pd.DataFrame):
        if df_price is None or df_price.empty:
            return
        df2 = df_price.rename(columns={"price": indicator_name}).copy()
        long_new = df2.assign(ticker=ticker).melt(
            id_vars=["date", "ticker"],
            value_vars=[indicator_name],
            var_name="indicator",
            value_name="value",
        )
        upsert_long_df(db_info, long_new, drop_null_values=True)

    # (A) DB에 데이터 없음 → 전 구간 fetch
    if last_dt is None:
        df_new = _fetch(min_start_date, today_iso)
        if not df_new.empty:
            _store(df_new)
        out = df_new.rename(columns={"price": indicator_name}).drop_duplicates("date").sort_values("date")
        if return_start_date:
            out = out[out["date"] >= pd.to_datetime(return_start_date)]
        return out

    # (B) 과거 backfill — min_start_date 보다 늦게 시작한 경우
    if first_dt is not None and first_dt.date().isoformat() > min_start_date:
        back_end = (first_dt - pd.Timedelta(days=1)).date().isoformat()
        df_back  = _fetch(min_start_date, back_end)
        if not df_back.empty:
            _store(df_back)

    # (C) 최신 forward
    start_missing = (last_dt + pd.Timedelta(days=1)).date().isoformat()
    if start_missing <= today_iso:
        df_fwd = _fetch(start_missing, today_iso)
        if not df_fwd.empty:
            _store(df_fwd)

    # (D) 필요 구간만 DB에서 읽어 반환
    df_db = read_indicator_series(
        db_info, ticker, indicator_name,
        start_date=return_start_date, end_date=today_iso,
    ).rename(columns={"value": indicator_name})
    df_db["date"] = pd.to_datetime(df_db["date"], errors="coerce")
    df_db = df_db.dropna(subset=["date"]).drop_duplicates("date").sort_values("date")
    return df_db


print("[OK] ensure_price_series 함수 정의 완료")
# Out:
# [OK] ensure_price_series 함수 정의 완료

# %% [markdown]
# ## Cell 9 · 티커 1개 업데이트 함수 (update_one_ticker)
#
# - `last_saved_date` 이후 데이터만 저장 (중복 저장 방지)
# - `price_stock` 은 `ensure_price_series` 에서 이미 저장 → 재저장 금지

# %%
def _pick_ref_indicator(store_mode: str) -> str:
    """저장 여부 판단 기준 지표 (Re_5y 가 가장 보수적)"""
    return "Re_5y"


def update_one_ticker(
    db_info: Dict[str, Any],
    ticker: str,
    api_key: str,
    spy_price_df: pd.DataFrame,   # columns: [date, price_mkt]
    rf_df: pd.DataFrame,          # index=date, columns=[rf_1y, rf_3y, rf_5y]
    today_iso: Optional[str]  = None,
    min_start_date: str       = MIN_START_DATE,
    store_mode: str           = "minimal",
) -> Tuple[bool, str]:
    """
    티커 1개에 대해 가격 확보 → 계산 → DB 저장 수행.

    Returns
    -------
    (True, 성공 메시지) or (False, 실패 메시지)
    """
    if today_iso is None:
        today_iso = datetime.utcnow().date().isoformat()

    if spy_price_df is None or spy_price_df.empty:
        return (False, "SPY price df 없음")

    # 0) 마지막 저장일 확인 → 중복 계산/저장 방지
    ref_ind          = _pick_ref_indicator(store_mode)
    _, last_saved    = get_minmax_date_in_db(db_info, ticker, ref_ind)

    if last_saved is not None:
        calc_start_dt = (pd.to_datetime(last_saved) - BDay(ROLLING_WARMUP_BDAYS)).date().isoformat()
        save_after_dt = pd.to_datetime(last_saved).date()
    else:
        calc_start_dt = min_start_date
        save_after_dt = None

    # 1) 종목 가격 확보 (필요 구간만 FMP fetch) + DB 저장
    px_stock = ensure_price_series(
        db_info           = db_info,
        ticker            = ticker,
        api_key           = api_key,
        indicator_name    = "price_stock",
        today_iso         = today_iso,
        min_start_date    = min_start_date,
        return_start_date = calc_start_dt,
    )
    if px_stock.empty:
        return (False, f"{ticker}: price_stock empty")

    # 2) SPY 가격을 calc_start_dt 이후 구간만 슬라이싱
    spy2 = spy_price_df.copy()
    spy2["date"] = pd.to_datetime(spy2["date"], errors="coerce")
    spy2 = spy2.dropna(subset=["date", "price_mkt"])
    spy2 = spy2[spy2["date"] >= pd.to_datetime(calc_start_dt)]
    if spy2.empty:
        return (False, f"{ticker}: SPY slice empty from {calc_start_dt}")

    # 3) 계산
    feat = build_features(
        price_stock_df = px_stock[["date", "price_stock"]],
        price_mkt_df   = spy2[["date", "price_mkt"]],
        rf_df          = rf_df,
    )
    if feat.empty:
        return (False, f"{ticker}: feature df empty")

    feat["ticker"] = ticker

    # 4) 저장 컬럼 선택
    if store_mode == "full":
        keep_cols = [
            # price_stock 은 ensure_price_series 에서 이미 저장 → 제외
            "price_mkt", "ret_stock", "ret_mkt",
            "beta_252", "beta_750", "beta_1250",
            "rf_1y", "rf_3y", "rf_5y",
            "E_Rm_1y", "E_Rm_3y", "E_Rm_5y",
            "Re_1y", "Re_3y", "Re_5y",
        ]
    else:  # minimal
        keep_cols = [
            "beta_252", "beta_750", "beta_1250",
            "Re_1y", "Re_3y", "Re_5y",
        ]
    keep_cols = [c for c in keep_cols if c in feat.columns]

    # 5) last_saved 이후만 저장 → 중복 upsert 방지
    if save_after_dt is not None:
        feat = feat[pd.to_datetime(feat["date"]).dt.date > save_after_dt]
        if feat.empty:
            return (True, f"{ticker}: up-to-date (no new rows after {save_after_dt})")

    # 6) wide → long melt
    long_df = feat[["date", "ticker"] + keep_cols].melt(
        id_vars    = ["date", "ticker"],
        value_vars = keep_cols,
        var_name   = "indicator",
        value_name = "value",
    )
    long_df["value"] = pd.to_numeric(long_df["value"], errors="coerce")
    long_df = long_df.replace([np.inf, -np.inf], np.nan).dropna(subset=["value"])

    if long_df.empty:
        return (False, f"{ticker}: 모든 값 NaN")

    # 7) DB 저장
    n_saved = upsert_long_df(db_info, long_df, drop_null_values=True)
    return (True, f"{ticker}: saved {n_saved:,}행 ({store_mode}) from {calc_start_dt}")


print("[OK] update_one_ticker 함수 정의 완료")
# Out:
# [OK] update_one_ticker 함수 정의 완료

# %% [markdown]
# ## Cell 10 · SPY / RF 공통 데이터 준비
#
# SPY 가격과 RF(국채금리)는 배치 전 1회만 fetch해서 모든 티커에 재사용합니다.

# %%
def prepare_spy_and_rf(
    db_info: Dict[str, Any],
    api_key: str,
    today_iso: str,
    min_start_date: str = MIN_START_DATE,
) -> Tuple[pd.DataFrame, pd.DataFrame]:
    """
    SPY 가격 + RF 를 1회 fetch 후 반환.
    SPY 가격은 DB에도 저장 (ensure_price_series 경유).

    Returns
    -------
    (spy_price_df, rf_df)
      spy_price_df : columns [date, price_mkt]
      rf_df        : index=date, columns=[rf_1y, rf_3y, rf_5y]
    """
    log("PREP", "SPY 가격 확보 시작")
    spy_px = ensure_price_series(
        db_info           = db_info,
        ticker            = MARKET_TICKER,
        api_key           = api_key,
        indicator_name    = "price_stock",
        today_iso         = today_iso,
        min_start_date    = min_start_date,
        return_start_date = min_start_date,
    )

    # FDR 최종 안전망
    if spy_px.empty:
        log("PREP", "[WARN] SPY ensure 실패 → FDR 직접 fallback")
        df_fdr = fetch_fdr_price(MARKET_TICKER, min_start_date, today_iso)
        if not df_fdr.empty:
            df2 = df_fdr.rename(columns={"price": "price_stock"})
            long_new = df2.assign(ticker=MARKET_TICKER).melt(
                id_vars=["date", "ticker"], value_vars=["price_stock"],
                var_name="indicator", value_name="value",
            )
            upsert_long_df(db_info, long_new, drop_null_values=True)
            spy_px = df2[["date", "price_stock"]].copy()

    if spy_px.empty:
        raise RuntimeError("SPY 가격 확보 실패. API_KEY / 네트워크 / FDR 상태를 확인하세요.")

    spy_price_df = (
        spy_px
        .rename(columns={"price_stock": "price_mkt"})
        [["date", "price_mkt"]]
        .copy()
    )
    spy_price_df["date"]      = pd.to_datetime(spy_price_df["date"])
    spy_price_df["price_mkt"] = pd.to_numeric(spy_price_df["price_mkt"], errors="coerce")
    spy_price_df = (
        spy_price_df
        .dropna(subset=["date", "price_mkt"])
        .drop_duplicates("date")
        .sort_values("date")
    )
    log("PREP", f"SPY 가격: {len(spy_price_df)}행  ({spy_price_df['date'].iloc[0].date()} ~ {spy_price_df['date'].iloc[-1].date()})")

    # RF
    start_for_rf = spy_price_df["date"].min().date().isoformat()
    end_for_rf   = spy_price_df["date"].max().date().isoformat()
    log("PREP", f"RF 로드 중: {start_for_rf} ~ {end_for_rf}")
    rf_df = fetch_us_treasury_yields(start_for_rf, end_for_rf)
    if rf_df is None or rf_df.empty:
        log("PREP", "[WARN] RF 로드 실패 → Required Return 이 NaN 이 될 수 있습니다.")

    return spy_price_df, rf_df


print("[OK] prepare_spy_and_rf 함수 정의 완료")
# Out:
# [OK] prepare_spy_and_rf 함수 정의 완료

# %% [markdown]
# ## Cell 11 · 배치 실행
#
# ### 실행 모드
# | 변수 | 설명 |
# |------|------|
# | `RUN_TICKERS` | `None` → 구간/전체 실행 / 리스트 → 해당 티커만 |
# | `TICKER_START` | 리스트 슬라이싱 시작 인덱스 (0부터) |
# | `TICKER_END` | 슬라이싱 끝 인덱스 (None = 끝까지) |
# | `SKIP_DONE` | True → 체크포인트에 있는 티커 건너뜀 |
# | `RETRY_FAILED` | True → 실패 티커 1회 재시도 |
#
# ### 구간 예시
# ```python
# TICKER_START, TICKER_END = 0,    500   # 0~499번째
# TICKER_START, TICKER_END = 500,  1000  # 500~999번째
# TICKER_START, TICKER_END = None, None  # 전체
# ```
#
# ### 메모리 전략
# > 1개 처리 → 즉시 저장 → `gc.collect()` → 다음 티커
# > 완료 티커는 `done_tickers.txt` 에 기록 → 재시작 시 중복 처리 방지

# %%
# ══════════════════════════════════════════════════════════════
#  배치 설정 — 여기를 수정하세요
# ══════════════════════════════════════════════════════════════

RUN_TICKERS  = None          # type: Optional[List[str]]
# RUN_TICKERS = ["AAPL", "MSFT", "NVDA"]   # 특정 티커만

TICKER_START = 10             # type: Optional[int]
TICKER_END   = 2000           # type: Optional[int]
# 전체: TICKER_START = None, TICKER_END = None

RUN_STORE_MODE   = STORE_MODE   # "minimal" or "full"
SKIP_DONE        = True          # True: 체크포인트 티커 스킵
RETRY_FAILED     = True          # True: 실패 티커 1회 재시도

DONE_PATH = DEFAULT_DONE_PATH
FAIL_PATH = DEFAULT_FAIL_PATH

# ══════════════════════════════════════════════════════════════
#  실행 대상 결정
# ══════════════════════════════════════════════════════════════
if RUN_TICKERS is not None:
    tickers = RUN_TICKERS
    log("BATCH", f"모드: 특정 티커 지정  {tickers}")
else:
    tickers = DEFAULT_TICKER_LIST[TICKER_START:TICKER_END]
    _s = TICKER_START if TICKER_START is not None else 0
    _e = TICKER_END   if TICKER_END   is not None else len(DEFAULT_TICKER_LIST)
    log("BATCH", f"모드: 구간 실행  index {_s} ~ {_e-1}  ({len(tickers)}개)")

total     = len(tickers)
today_iso = datetime.utcnow().date().isoformat()
done_set  = _load_set(DONE_PATH) if SKIP_DONE else set()
fail_set  = set()

# ── SPY / RF 공통 데이터 준비 (배치 전 1회) ──────────────────
spy_price_df, rf_df = prepare_spy_and_rf(
    db_info        = db_info,
    api_key        = API_KEY,
    today_iso      = today_iso,
    min_start_date = MIN_START_DATE,
)

success, skipped, errored = 0, 0, 0

log("BATCH", "=" * 70)
log("BATCH", f"시작  | {total}개 티커 | store_mode={RUN_STORE_MODE}")
log("BATCH", f"skip_done={SKIP_DONE}  retry_failed={RETRY_FAILED}")
log("BATCH", f"체크포인트 완료: {len(done_set)}개")
log("BATCH", "=" * 70)


def _run_one(ticker: str) -> Tuple[bool, str]:
    """티커 1개 처리. (True, msg) or (False, msg) 반환."""
    try:
        ok, msg = update_one_ticker(
            db_info        = db_info,
            ticker         = ticker,
            api_key        = API_KEY,
            spy_price_df   = spy_price_df,
            rf_df          = rf_df,
            today_iso      = today_iso,
            min_start_date = MIN_START_DATE,
            store_mode     = RUN_STORE_MODE,
        )
    except Exception as e:
        return (False, f"{ticker}: 예외 발생 → {e}")
    finally:
        gc.collect()
    return ok, msg


# ── 메인 루프 ─────────────────────────────────────────────────
for idx, ticker in enumerate(tickers, 1):
    ticker = str(ticker).strip()
    if not ticker:
        continue

    pct = idx / total * 100
    log("PROGRESS", f"[{idx:>4}/{total}] ({pct:5.1f}%)  >>  {ticker}")

    if SKIP_DONE and ticker in done_set:
        log(ticker, "[SKIP] 이미 완료 (체크포인트)")
        skipped += 1
        continue

    ok, msg = _run_one(ticker)
    if ok:
        log(ticker, f"[OK] {msg}")
        _append_line(DONE_PATH, ticker)
        done_set.add(ticker)
        success += 1
    else:
        log(ticker, f"[FAIL] {msg}")
        _append_line(FAIL_PATH, ticker)
        fail_set.add(ticker)
        errored += 1

# ── 실패 티커 재시도 ──────────────────────────────────────────
if RETRY_FAILED and fail_set:
    log("RETRY", f"실패 티커 {len(fail_set)}개 재시도")
    still_fail = set()
    for ticker in sorted(fail_set):
        ok, msg = _run_one(ticker)
        if ok:
            log(ticker, f"[RETRY-OK] {msg}")
            _append_line(DONE_PATH, ticker)
            done_set.add(ticker)
            success += 1
            errored -= 1
        else:
            log(ticker, f"[RETRY-FAIL] {msg}")
            still_fail.add(ticker)
    log("RETRY", f"재시도 완료. 최종 실패: {len(still_fail)}개")

# ── 배치 요약 ─────────────────────────────────────────────────
log("BATCH", "=" * 70)
log("BATCH", f"완료 | 성공={success}  스킵={skipped}  실패={errored}  합계={total}")
log("BATCH", f"체크포인트: {DONE_PATH}")
log("BATCH", "=" * 70)
# Out:
# [15:12:40][BATCH] 모드: 구간 실행  index 10 ~ 1999  (1990개)
# [15:12:40][PREP] SPY 가격 확보 시작
# [15:12:59][DB] batch 1: tickers=1, rows=2,830
# [15:13:18][PREP] [WARN] SPY ensure 실패 → FDR 직접 fallback
# [15:13:20][DB] batch 1: tickers=1, rows=2,831
# [15:13:20][PREP] SPY 가격: 2831행  (2014-12-31 ~ 2026-04-06)
# [15:13:20][PREP] RF 로드 중: 2014-12-31 ~ 2026-04-06
# [15:13:23][RF] Yahoo fallback 로드 성공: 2939행
# [15:13:23][BATCH] ======================================================================
# [15:13:23][BATCH] 시작  | 1990개 티커 | store_mode=minimal
# [15:13:23][BATCH] skip_done=True  retry_failed=True
# [15:13:23][BATCH] 체크포인트 완료: 3575개
# [15:13:23][BATCH] ======================================================================
# [15:13:23][PROGRESS] [   1/1990] (  0.1%)  >>  WMT
# [15:13:23][WMT] [SKIP] 이미 완료 (체크포인트)
# [15:13:23][PROGRESS] [   2/1990] (  0.1%)  >>  XOM
# [15:13:23][XOM] [SKIP] 이미 완료 (체크포인트)
# [15:13:23][PROGRESS] [   3/1990] (  0.2%)  >>  ASML
# [15:13:23][ASML] [SKIP] 이미 완료 (체크포인트)
# [15:13:23][PROGRESS] [   4/1990] (  0.2%)  >>  JNJ
# [15:13:23][JNJ] [SKIP] 이미 완료 (체크포인트)
# [15:13:23][PROGRESS] [   5/1990] (  0.3%)  >>  ORCL
# [15:13:23][ORCL] [SKIP] 이미 완료 (체크포인트)
# [15:13:23][PROGRESS] [   6/1990] (  0.3%)  >>  MU
# [15:13:23][MU] [SKIP] 이미 완료 (체크포인트)
# [15:13:23][PROGRESS] [   7/1990] (  0.4%)  >>  COST
# [15:13:23][COST] [SKIP] 이미 완료 (체크포인트)
# [15:13:23][PROGRESS] [   8/1990] (  0.4%)  >>  AMD
# [15:13:55][DB] batch 1: tickers=1, rows=2,830
# [15:14:05][AMD] [FAIL] AMD: price_stock empty
# [15:14:05][PROGRESS] [   9/1990] (  0.5%)  >>  BABA
# [15:14:05][BABA] [SKIP] 이미 완료 (체크포인트)
# [15:14:05][PROGRESS] [  10/1990] (  0.5%)  >>  NFLX
# [15:14:05][NFLX] [SKIP] 이미 완료 (체크포인트)
# [15:14:05][PROGRESS] [  11/1990] (  0.6%)  >>  ABBV
# [15:14:05][ABBV] [SKIP] 이미 완료 (체크포인트)
# [15:14:05][PROGRESS] [  12/1990] (  0.6%)  >>  HD
# [15:14:05][HD] [SKIP] 이미 완료 (체크포인트)
# [15:14:05][PROGRESS] [  13/1990] (  0.7%)  >>  PG
# [15:14:05][PG] [SKIP] 이미 완료 (체크포인트)
# [15:14:05][PROGRESS] [  14/1990] (  0.7%)  >>  CVX
# [15:14:05][CVX] [SKIP] 이미 완료 (체크포인트)
# [15:14:05][PROGRESS] [  15/1990] (  0.8%)  >>  UNH
# [15:14:05][UNH] [SKIP] 이미 완료 (체크포인트)
# [15:14:05][PROGRESS] [  16/1990] (  0.8%)  >>  KO
# [15:14:05][KO] [SKIP] 이미 완료 (체크포인트)
# [15:14:05][PROGRESS] [  17/1990] (  0.9%)  >>  GE
# [15:14:05][GE] [SKIP] 이미 완료 (체크포인트)
# [15:14:05][PROGRESS] [  18/1990] (  0.9%)  >>  CSCO
# [15:14:05][CSCO] [SKIP] 이미 완료 (체크포인트)
# [15:14:05][PROGRESS] [  19/1990] (  1.0%)  >>  CAT
# [15:14:05][CAT] [SKIP] 이미 완료 (체크포인트)
# [15:14:05][PROGRESS] [  20/1990] (  1.0%)  >>  TM
# [15:14:05][TM] [SKIP] 이미 완료 (체크포인트)
# [15:14:05][PROGRESS] [  21/1990] (  1.1%)  >>  AZN
# [15:14:05][AZN] [SKIP] 이미 완료 (체크포인트)
# [15:14:05][PROGRESS] [  22/1990] (  1.1%)  >>  NVS
# [15:14:05][NVS] [SKIP] 이미 완료 (체크포인트)
# [15:14:05][PROGRESS] [  23/1990] (  1.2%)  >>  NVO
# [15:14:05][NVO] [SKIP] 이미 완료 (체크포인트)
# [15:14:05][PROGRESS] [  24/1990] (  1.2%)  >>  LRCX
# [15:14:05][LRCX] [SKIP] 이미 완료 (체크포인트)
# [15:14:05][PROGRESS] [  25/1990] (  1.3%)  >>  SAP
# [15:14:05][SAP] [SKIP] 이미 완료 (체크포인트)
# [15:14:05][PROGRESS] [  26/1990] (  1.3%)  >>  IBM
# [15:14:05][IBM] [SKIP] 이미 완료 (체크포인트)
# [15:14:05][PROGRESS] [  27/1990] (  1.4%)  >>  PM
# [15:14:05][PM] [SKIP] 이미 완료 (체크포인트)
# [15:14:05][PROGRESS] [  28/1990] (  1.4%)  >>  MRK
# [15:14:05][MRK] [SKIP] 이미 완료 (체크포인트)
# [15:14:05][PROGRESS] [  29/1990] (  1.5%)  >>  RTX
# [15:14:05][RTX] [SKIP] 이미 완료 (체크포인트)
# [15:14:05][PROGRESS] [  30/1990] (  1.5%)  >>  AMAT
# [15:14:05][AMAT] [SKIP] 이미 완료 (체크포인트)
# [15:14:05][PROGRESS] [  31/1990] (  1.6%)  >>  VZA
# [15:14:05][VZA] [SKIP] 이미 완료 (체크포인트)
# [15:14:05][PROGRESS] [  32/1990] (  1.6%)  >>  TMO
# [15:14:05][TMO] [SKIP] 이미 완료 (체크포인트)
# [15:14:05][PROGRESS] [  33/1990] (  1.7%)  >>  MCD
# [15:14:05][MCD] [SKIP] 이미 완료 (체크포인트)
# [15:14:05][PROGRESS] [  34/1990] (  1.7%)  >>  CRM
# [15:14:05][CRM] [SKIP] 이미 완료 (체크포인트)
# [15:14:05][PROGRESS] [  35/1990] (  1.8%)  >>  SHEL
# [15:14:05][SHEL] [SKIP] 이미 완료 (체크포인트)
# [15:14:05][PROGRESS] [  36/1990] (  1.8%)  >>  LIN
# [15:14:05][LIN] [SKIP] 이미 완료 (체크포인트)
# [15:14:05][PROGRESS] [  37/1990] (  1.9%)  >>  INTC
# [15:14:05][INTC] [SKIP] 이미 완료 (체크포인트)
# [15:14:05][PROGRESS] [  38/1990] (  1.9%)  >>  TMUS
# [15:14:05][TMUS] [SKIP] 이미 완료 (체크포인트)
# [15:14:05][PROGRESS] [  39/1990] (  2.0%)  >>  KLAC
# [15:14:05][KLAC] [SKIP] 이미 완료 (체크포인트)
# [15:14:05][PROGRESS] [  40/1990] (  2.0%)  >>  PEP
# [15:14:05][PEP] [SKIP] 이미 완료 (체크포인트)
# [15:14:05][PROGRESS] [  41/1990] (  2.1%)  >>  DIS
# [15:14:05][DIS] [SKIP] 이미 완료 (체크포인트)
# [15:14:05][PROGRESS] [  42/1990] (  2.1%)  >>  BA
# [15:14:05][BA] [SKIP] 이미 완료 (체크포인트)
# [15:14:05][PROGRESS] [  43/1990] (  2.2%)  >>  APH
# [15:14:05][APH] [SKIP] 이미 완료 (체크포인트)
# [15:14:05][PROGRESS] [  44/1990] (  2.2%)  >>  ISRG
# [15:14:05][ISRG] [SKIP] 이미 완료 (체크포인트)
# [15:14:05][PROGRESS] [  45/1990] (  2.3%)  >>  ABT
# [15:14:05][ABT] [SKIP] 이미 완료 (체크포인트)
# [15:14:05][PROGRESS] [  46/1990] (  2.3%)  >>  AMGN
# [15:14:05][AMGN] [SKIP] 이미 완료 (체크포인트)
# [15:14:05][PROGRESS] [  47/1990] (  2.4%)  >>  ANET
# [15:14:05][ANET] [SKIP] 이미 완료 (체크포인트)
# [15:14:05][PROGRESS] [  48/1990] (  2.4%)  >>  TXN
# [15:14:05][TXN] [SKIP] 이미 완료 (체크포인트)
# [15:14:05][PROGRESS] [  49/1990] (  2.5%)  >>  SHOP
# [15:14:05][SHOP] [SKIP] 이미 완료 (체크포인트)
# [15:14:05][PROGRESS] [  50/1990] (  2.5%)  >>  ACN
# [15:14:05][ACN] [SKIP] 이미 완료 (체크포인트)
# [15:14:05][PROGRESS] [  51/1990] (  2.6%)  >>  BHP
# [15:14:05][BHP] [SKIP] 이미 완료 (체크포인트)
# [15:14:05][PROGRESS] [  52/1990] (  2.6%)  >>  GILD
# [15:14:05][GILD] [SKIP] 이미 완료 (체크포인트)
# [15:14:05][PROGRESS] [  53/1990] (  2.7%)  >>  DHR
# [15:14:05][DHR] [SKIP] 이미 완료 (체크포인트)
# [15:14:05][PROGRESS] [  54/1990] (  2.7%)  >>  VZ
# [15:14:05][VZ] [SKIP] 이미 완료 (체크포인트)
# [15:14:05][PROGRESS] [  55/1990] (  2.8%)  >>  TJX
# [15:14:05][TJX] [SKIP] 이미 완료 (체크포인트)
# [15:14:05][PROGRESS] [  56/1990] (  2.8%)  >>  T
# [15:14:05][T] [SKIP] 이미 완료 (체크포인트)
# [15:14:05][PROGRESS] [  57/1990] (  2.9%)  >>  QCOM
# [15:14:05][QCOM] [SKIP] 이미 완료 (체크포인트)
# [15:14:05][PROGRESS] [  58/1990] (  2.9%)  >>  BKNG
# [15:14:05][BKNG] [SKIP] 이미 완료 (체크포인트)
# [15:14:05][PROGRESS] [  59/1990] (  3.0%)  >>  TTE
# [15:14:05][TTE] [SKIP] 이미 완료 (체크포인트)
# [15:14:05][PROGRESS] [  60/1990] (  3.0%)  >>  INTU
# [15:14:05][INTU] [SKIP] 이미 완료 (체크포인트)
# [15:14:05][PROGRESS] [  61/1990] (  3.1%)  >>  LOW
# [15:14:05][LOW] [SKIP] 이미 완료 (체크포인트)
# [15:14:05][PROGRESS] [  62/1990] (  3.1%)  >>  SCCO
# [15:14:05][SCCO] [SKIP] 이미 완료 (체크포인트)
# [15:14:05][PROGRESS] [  63/1990] (  3.2%)  >>  ADI
# [15:14:05][ADI] [SKIP] 이미 완료 (체크포인트)
# [15:14:05][PROGRESS] [  64/1990] (  3.2%)  >>  PFE
# [15:14:05][PFE] [SKIP] 이미 완료 (체크포인트)
# [15:14:05][PROGRESS] [  65/1990] (  3.3%)  >>  RIO
# [15:14:05][RIO] [SKIP] 이미 완료 (체크포인트)
# [15:14:05][PROGRESS] [  66/1990] (  3.3%)  >>  UL
# [15:14:05][UL] [SKIP] 이미 완료 (체크포인트)
# [15:14:05][PROGRESS] [  67/1990] (  3.4%)  >>  NOW
# [15:14:05][NOW] [SKIP] 이미 완료 (체크포인트)
# [15:14:05][PROGRESS] [  68/1990] (  3.4%)  >>  HON
# [15:14:05][HON] [SKIP] 이미 완료 (체크포인트)
# [15:14:05][PROGRESS] [  69/1990] (  3.5%)  >>  DE
# [15:14:05][DE] [SKIP] 이미 완료 (체크포인트)
# [15:14:05][PROGRESS] [  70/1990] (  3.5%)  >>  BSX
# [15:14:05][BSX] [SKIP] 이미 완료 (체크포인트)
# [15:14:05][PROGRESS] [  71/1990] (  3.6%)  >>  NEM
# [15:14:05][NEM] [SKIP] 이미 완료 (체크포인트)
# [15:14:05][PROGRESS] [  72/1990] (  3.6%)  >>  SONY
# [15:14:05][SONY] [SKIP] 이미 완료 (체크포인트)
# [15:14:05][PROGRESS] [  73/1990] (  3.7%)  >>  UNP
# [15:14:05][UNP] [SKIP] 이미 완료 (체크포인트)
# [15:14:05][PROGRESS] [  74/1990] (  3.7%)  >>  SYK
# [15:14:05][SYK] [SKIP] 이미 완료 (체크포인트)
# [15:14:05][PROGRESS] [  75/1990] (  3.8%)  >>  LMT
# [15:14:05][LMT] [SKIP] 이미 완료 (체크포인트)
# [15:14:05][PROGRESS] [  76/1990] (  3.8%)  >>  BUD
# [15:14:05][BUD] [SKIP] 이미 완료 (체크포인트)
# [15:14:05][PROGRESS] [  77/1990] (  3.9%)  >>  MDT
# [15:14:05][MDT] [SKIP] 이미 완료 (체크포인트)
# [15:14:05][PROGRESS] [  78/1990] (  3.9%)  >>  ETN
# [15:14:05][ETN] [SKIP] 이미 완료 (체크포인트)
# [15:14:05][PROGRESS] [  79/1990] (  4.0%)  >>  BTI
# [15:14:05][BTI] [SKIP] 이미 완료 (체크포인트)
# [15:14:05][PROGRESS] [  80/1990] (  4.0%)  >>  ADBE
# [15:14:05][ADBE] [SKIP] 이미 완료 (체크포인트)
# [15:14:05][PROGRESS] [  81/1990] (  4.1%)  >>  WELL
# [15:14:05][WELL] [SKIP] 이미 완료 (체크포인트)
# [15:14:05][PROGRESS] [  82/1990] (  4.1%)  >>  PANW
# [15:14:05][PANW] [SKIP] 이미 완료 (체크포인트)
# [15:14:05][PROGRESS] [  83/1990] (  4.2%)  >>  COP
# [15:14:05][COP] [SKIP] 이미 완료 (체크포인트)
# [15:14:05][PROGRESS] [  84/1990] (  4.2%)  >>  VRTX
# [15:14:05][VRTX] [SKIP] 이미 완료 (체크포인트)
# [15:14:05][PROGRESS] [  85/1990] (  4.3%)  >>  PH
# [15:14:05][PH] [SKIP] 이미 완료 (체크포인트)
# [15:14:05][PROGRESS] [  86/1990] (  4.3%)  >>  PLD
# [15:14:05][PLD] [SKIP] 이미 완료 (체크포인트)
# [15:14:05][PROGRESS] [  87/1990] (  4.4%)  >>  SNY
# [15:14:05][SNY] [SKIP] 이미 완료 (체크포인트)
# [15:14:05][PROGRESS] [  88/1990] (  4.4%)  >>  ANTM
# [15:14:05][ANTM] [SKIP] 이미 완료 (체크포인트)
# [15:14:05][PROGRESS] [  89/1990] (  4.5%)  >>  MELI
# [15:14:05][MELI] [SKIP] 이미 완료 (체크포인트)
# [15:14:05][PROGRESS] [  90/1990] (  4.5%)  >>  BMY
# [15:14:05][BMY] [SKIP] 이미 완료 (체크포인트)
# [15:14:05][PROGRESS] [  91/1990] (  4.6%)  >>  SBUX
# [15:14:05][SBUX] [SKIP] 이미 완료 (체크포인트)
# [15:14:05][PROGRESS] [  92/1990] (  4.6%)  >>  AEM
# [15:14:05][AEM] [SKIP] 이미 완료 (체크포인트)
# [15:14:05][PROGRESS] [  93/1990] (  4.7%)  >>  HCA
# [15:14:05][HCA] [SKIP] 이미 완료 (체크포인트)
# [15:14:05][PROGRESS] [  94/1990] (  4.7%)  >>  CVS
# [15:14:05][CVS] [SKIP] 이미 완료 (체크포인트)
# [15:14:05][PROGRESS] [  95/1990] (  4.8%)  >>  MO
# [15:14:05][MO] [SKIP] 이미 완료 (체크포인트)
# [15:14:05][PROGRESS] [  96/1990] (  4.8%)  >>  ENB
# [15:14:05][ENB] [SKIP] 이미 완료 (체크포인트)
# [15:14:05][PROGRESS] [  97/1990] (  4.9%)  >>  ADP
# [15:14:05][ADP] [SKIP] 이미 완료 (체크포인트)
# [15:14:05][PROGRESS] [  98/1990] (  4.9%)  >>  MCK
# [15:14:05][MCK] [SKIP] 이미 완료 (체크포인트)
# [15:14:05][PROGRESS] [  99/1990] (  5.0%)  >>  GSK
# [15:14:05][GSK] [SKIP] 이미 완료 (체크포인트)
# [15:14:05][PROGRESS] [ 100/1990] (  5.0%)  >>  GD
# [15:14:05][GD] [SKIP] 이미 완료 (체크포인트)
# [15:14:05][PROGRESS] [ 101/1990] (  5.1%)  >>  BP
# [15:14:05][BP] [SKIP] 이미 완료 (체크포인트)
# [15:14:05][PROGRESS] [ 102/1990] (  5.1%)  >>  SNPS
# [15:14:05][SNPS] [SKIP] 이미 완료 (체크포인트)
# [15:14:05][PROGRESS] [ 103/1990] (  5.2%)  >>  NKE
# [15:14:05][NKE] [SKIP] 이미 완료 (체크포인트)
# [15:14:05][PROGRESS] [ 104/1990] (  5.2%)  >>  NOC
# [15:14:05][NOC] [SKIP] 이미 완료 (체크포인트)
# [15:14:05][PROGRESS] [ 105/1990] (  5.3%)  >>  WM
# [15:14:05][WM] [SKIP] 이미 완료 (체크포인트)
# [15:14:05][PROGRESS] [ 106/1990] (  5.3%)  >>  PBR
# [15:14:05][PBR] [SKIP] 이미 완료 (체크포인트)
# [15:14:05][PROGRESS] [ 107/1990] (  5.4%)  >>  UPS
# [15:14:05][UPS] [SKIP] 이미 완료 (체크포인트)
# [15:14:05][PROGRESS] [ 108/1990] (  5.4%)  >>  FCX
# [15:14:05][FCX] [SKIP] 이미 완료 (체크포인트)
# [15:14:05][PROGRESS] [ 109/1990] (  5.5%)  >>  B
# [15:14:05][B] [SKIP] 이미 완료 (체크포인트)
# [15:14:05][PROGRESS] [ 110/1990] (  5.5%)  >>  CDNS
# [15:14:05][CDNS] [SKIP] 이미 완료 (체크포인트)
# [15:14:05][PROGRESS] [ 111/1990] (  5.6%)  >>  TT
# [15:14:05][TT] [SKIP] 이미 완료 (체크포인트)
# [15:14:05][PROGRESS] [ 112/1990] (  5.6%)  >>  SHW
# [15:14:05][SHW] [SKIP] 이미 완료 (체크포인트)
# [15:14:05][PROGRESS] [ 113/1990] (  5.7%)  >>  MAR
# [15:14:05][MAR] [SKIP] 이미 완료 (체크포인트)
# [15:14:05][PROGRESS] [ 114/1990] (  5.7%)  >>  ORLY
# [15:14:05][ORLY] [SKIP] 이미 완료 (체크포인트)
# [15:14:05][PROGRESS] [ 115/1990] (  5.8%)  >>  MMM
# [15:14:05][MMM] [SKIP] 이미 완료 (체크포인트)
# [15:14:05][PROGRESS] [ 116/1990] (  5.8%)  >>  NTES
# [15:14:05][NTES] [SKIP] 이미 완료 (체크포인트)
# [15:14:05][PROGRESS] [ 117/1990] (  5.9%)  >>  AMT
# [15:14:05][AMT] [SKIP] 이미 완료 (체크포인트)
# [15:14:05][PROGRESS] [ 118/1990] (  5.9%)  >>  EMR
# [15:14:05][EMR] [SKIP] 이미 완료 (체크포인트)
# [15:14:05][PROGRESS] [ 119/1990] (  6.0%)  >>  ELV
# [15:14:05][ELV] [SKIP] 이미 완료 (체크포인트)
# [15:14:05][PROGRESS] [ 120/1990] (  6.0%)  >>  WDC
# [15:14:05][WDC] [SKIP] 이미 완료 (체크포인트)
# [15:14:05][PROGRESS] [ 121/1990] (  6.1%)  >>  CRH
# [15:14:05][CRH] [SKIP] 이미 완료 (체크포인트)
# [15:14:05][PROGRESS] [ 122/1990] (  6.1%)  >>  GLW
# [15:14:05][GLW] [SKIP] 이미 완료 (체크포인트)
# [15:14:05][PROGRESS] [ 123/1990] (  6.2%)  >>  TDG
# [15:14:05][TDG] [SKIP] 이미 완료 (체크포인트)
# [15:14:05][PROGRESS] [ 124/1990] (  6.2%)  >>  ECL
# [15:14:05][ECL] [SKIP] 이미 완료 (체크포인트)
# [15:14:05][PROGRESS] [ 125/1990] (  6.3%)  >>  RCL
# [15:14:05][RCL] [SKIP] 이미 완료 (체크포인트)
# [15:14:05][PROGRESS] [ 126/1990] (  6.3%)  >>  MNST
# [15:14:05][MNST] [SKIP] 이미 완료 (체크포인트)
# [15:14:05][PROGRESS] [ 127/1990] (  6.4%)  >>  EQIX
# [15:14:05][EQIX] [SKIP] 이미 완료 (체크포인트)
# [15:14:05][PROGRESS] [ 128/1990] (  6.4%)  >>  REGN
# [15:14:05][REGN] [SKIP] 이미 완료 (체크포인트)
# [15:14:05][PROGRESS] [ 129/1990] (  6.5%)  >>  CMI
# [15:14:05][CMI] [SKIP] 이미 완료 (체크포인트)
# [15:14:05][PROGRESS] [ 130/1990] (  6.5%)  >>  WMB
# [15:14:05][WMB] [SKIP] 이미 완료 (체크포인트)
# [15:14:05][PROGRESS] [ 131/1990] (  6.6%)  >>  CTAS
# [15:14:05][CTAS] [SKIP] 이미 완료 (체크포인트)
# [15:14:05][PROGRESS] [ 132/1990] (  6.6%)  >>  INFY
# [15:14:05][INFY] [SKIP] 이미 완료 (체크포인트)
# [15:14:05][PROGRESS] [ 133/1990] (  6.7%)  >>  STX
# [15:14:05][STX] [SKIP] 이미 완료 (체크포인트)
# [15:14:05][PROGRESS] [ 134/1990] (  6.7%)  >>  ITW
# [15:14:05][ITW] [SKIP] 이미 완료 (체크포인트)
# [15:14:05][PROGRESS] [ 135/1990] (  6.8%)  >>  MDLZ
# [15:14:05][MDLZ] [SKIP] 이미 완료 (체크포인트)
# [15:14:05][PROGRESS] [ 136/1990] (  6.8%)  >>  CNQ
# [15:14:05][CNQ] [SKIP] 이미 완료 (체크포인트)
# [15:14:05][PROGRESS] [ 137/1990] (  6.9%)  >>  CI
# [15:14:05][CI] [SKIP] 이미 완료 (체크포인트)
# [15:14:05][PROGRESS] [ 138/1990] (  6.9%)  >>  ATVI
# [15:14:05][ATVI] [SKIP] 이미 완료 (체크포인트)
# [15:14:05][PROGRESS] [ 139/1990] (  7.0%)  >>  SLB
# [15:14:05][SLB] [SKIP] 이미 완료 (체크포인트)
# [15:14:05][PROGRESS] [ 140/1990] (  7.0%)  >>  GM
# [15:14:05][GM] [SKIP] 이미 완료 (체크포인트)
# [15:14:05][PROGRESS] [ 141/1990] (  7.1%)  >>  FDX
# [15:14:05][FDX] [SKIP] 이미 완료 (체크포인트)
# [15:14:05][PROGRESS] [ 142/1990] (  7.1%)  >>  RELX
# [15:14:05][RELX] [SKIP] 이미 완료 (체크포인트)
# [15:14:05][PROGRESS] [ 143/1990] (  7.2%)  >>  EPD
# [15:14:05][EPD] [SKIP] 이미 완료 (체크포인트)
# [15:14:05][PROGRESS] [ 144/1990] (  7.2%)  >>  MRVL
# [15:14:05][MRVL] [SKIP] 이미 완료 (체크포인트)
# [15:14:05][PROGRESS] [ 145/1990] (  7.3%)  >>  JCI
# [15:14:05][JCI] [SKIP] 이미 완료 (체크포인트)
# [15:14:05][PROGRESS] [ 146/1990] (  7.3%)  >>  PWR
# [15:14:05][PWR] [SKIP] 이미 완료 (체크포인트)
# [15:14:05][PROGRESS] [ 147/1990] (  7.4%)  >>  WBD
# [15:14:05][WBD] [SKIP] 이미 완료 (체크포인트)
# [15:14:05][PROGRESS] [ 148/1990] (  7.4%)  >>  CSX
# [15:14:05][CSX] [SKIP] 이미 완료 (체크포인트)
# [15:14:05][PROGRESS] [ 149/1990] (  7.5%)  >>  HLT
# [15:14:05][HLT] [SKIP] 이미 완료 (체크포인트)
# [15:14:05][PROGRESS] [ 150/1990] (  7.5%)  >>  ABB
# [15:14:05][ABB] [SKIP] 이미 완료 (체크포인트)
# [15:14:05][PROGRESS] [ 151/1990] (  7.6%)  >>  SNDK
# [15:14:38][DB] batch 1: tickers=1, rows=286
# [15:14:55][SNDK] [FAIL] SNDK: price_stock empty
# [15:14:55][PROGRESS] [ 152/1990] (  7.6%)  >>  COR
# [15:14:55][COR] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 153/1990] (  7.7%)  >>  CL
# [15:14:55][CL] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 154/1990] (  7.7%)  >>  RSG
# [15:14:55][RSG] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 155/1990] (  7.8%)  >>  WPM
# [15:14:55][WPM] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 156/1990] (  7.8%)  >>  VALE
# [15:14:55][VALE] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 157/1990] (  7.9%)  >>  MSI
# [15:14:55][MSI] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 158/1990] (  7.9%)  >>  CP
# [15:14:55][CP] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 159/1990] (  8.0%)  >>  TEL
# [15:14:55][TEL] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 160/1990] (  8.0%)  >>  LHX
# [15:14:55][LHX] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 161/1990] (  8.1%)  >>  AMOV
# [15:14:55][AMOV] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 162/1990] (  8.1%)  >>  KMI
# [15:14:55][KMI] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 163/1990] (  8.2%)  >>  EQNR
# [15:14:55][EQNR] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 164/1990] (  8.2%)  >>  NSC
# [15:14:55][NSC] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 165/1990] (  8.3%)  >>  PCAR
# [15:14:55][PCAR] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 166/1990] (  8.3%)  >>  FTNT
# [15:14:55][FTNT] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 167/1990] (  8.4%)  >>  PXD
# [15:14:55][PXD] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 168/1990] (  8.4%)  >>  AZO
# [15:14:55][AZO] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 169/1990] (  8.5%)  >>  CNI
# [15:14:55][CNI] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 170/1990] (  8.5%)  >>  AMX
# [15:14:55][AMX] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 171/1990] (  8.6%)  >>  ET
# [15:14:55][ET] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 172/1990] (  8.6%)  >>  VMW
# [15:14:55][VMW] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 173/1990] (  8.7%)  >>  SU
# [15:14:55][SU] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 174/1990] (  8.7%)  >>  ROST
# [15:14:55][ROST] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 175/1990] (  8.8%)  >>  RACE
# [15:14:55][RACE] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 176/1990] (  8.8%)  >>  SPG
# [15:14:55][SPG] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 177/1990] (  8.9%)  >>  E
# [15:14:55][E] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 178/1990] (  8.9%)  >>  EOG
# [15:14:55][EOG] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 179/1990] (  9.0%)  >>  URI
# [15:14:55][URI] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 180/1990] (  9.0%)  >>  TRP
# [15:14:55][TRP] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 181/1990] (  9.1%)  >>  APD
# [15:14:55][APD] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 182/1990] (  9.1%)  >>  NXPI
# [15:14:55][NXPI] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 183/1990] (  9.2%)  >>  BDX
# [15:14:55][BDX] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 184/1990] (  9.2%)  >>  ADSK
# [15:14:55][ADSK] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 185/1990] (  9.3%)  >>  VLO
# [15:14:55][VLO] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 186/1990] (  9.3%)  >>  PSX
# [15:14:55][PSX] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 187/1990] (  9.4%)  >>  MPLX
# [15:14:55][MPLX] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 188/1990] (  9.4%)  >>  TRI
# [15:14:55][TRI] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 189/1990] (  9.5%)  >>  IDXX
# [15:14:55][IDXX] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 190/1990] (  9.5%)  >>  O
# [15:14:55][O] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 191/1990] (  9.6%)  >>  BKR
# [15:14:55][BKR] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 192/1990] (  9.6%)  >>  DLR
# [15:14:55][DLR] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 193/1990] (  9.7%)  >>  ZTS
# [15:14:55][ZTS] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 194/1990] (  9.7%)  >>  AU
# [15:14:55][AU] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 195/1990] (  9.8%)  >>  CMG
# [15:14:55][CMG] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 196/1990] (  9.8%)  >>  BIDU
# [15:14:55][BIDU] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 197/1990] (  9.9%)  >>  CCJ
# [15:14:55][CCJ] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 198/1990] (  9.9%)  >>  F
# [15:14:55][F] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 199/1990] ( 10.0%)  >>  TAK
# [15:14:55][TAK] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 200/1990] ( 10.1%)  >>  MPC
# [15:14:55][MPC] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 201/1990] ( 10.1%)  >>  SQ
# [15:14:55][SQ] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 202/1990] ( 10.2%)  >>  IMO
# [15:14:55][IMO] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 203/1990] ( 10.2%)  >>  MPWR
# [15:14:55][MPWR] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 204/1990] ( 10.3%)  >>  EA
# [15:14:55][EA] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 205/1990] ( 10.3%)  >>  WDAY
# [15:14:55][WDAY] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 206/1990] ( 10.4%)  >>  AME
# [15:14:55][AME] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 207/1990] ( 10.4%)  >>  CBRE
# [15:14:55][CBRE] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 208/1990] ( 10.5%)  >>  FAST
# [15:14:55][FAST] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 209/1990] ( 10.5%)  >>  CAH
# [15:14:55][CAH] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 210/1990] ( 10.6%)  >>  FNV
# [15:14:55][FNV] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 211/1990] ( 10.6%)  >>  GWW
# [15:14:55][GWW] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 212/1990] ( 10.7%)  >>  DEO
# [15:14:55][DEO] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 213/1990] ( 10.7%)  >>  FERG
# [15:14:55][FERG] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 214/1990] ( 10.8%)  >>  EW
# [15:14:55][EW] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 215/1990] ( 10.8%)  >>  GFI
# [15:14:55][GFI] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 216/1990] ( 10.9%)  >>  PSA
# [15:14:55][PSA] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 217/1990] ( 10.9%)  >>  FER
# [15:14:55][FER] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 218/1990] ( 11.0%)  >>  OKE
# [15:14:55][OKE] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 219/1990] ( 11.0%)  >>  AXON
# [15:14:55][AXON] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 220/1990] ( 11.1%)  >>  ALNY
# [15:14:55][ALNY] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 221/1990] ( 11.1%)  >>  ERJ
# [15:14:55][ERJ] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 222/1990] ( 11.2%)  >>  ROK
# [15:14:55][ROK] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 223/1990] ( 11.2%)  >>  TGT
# [15:14:55][TGT] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 224/1990] ( 11.3%)  >>  HEI
# [15:14:55][HEI] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 225/1990] ( 11.3%)  >>  MSTR
# [15:14:55][MSTR] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 226/1990] ( 11.4%)  >>  KGC
# [15:14:55][KGC] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 227/1990] ( 11.4%)  >>  HES
# [15:14:55][HES] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 228/1990] ( 11.5%)  >>  TTWO
# [15:14:55][TTWO] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 229/1990] ( 11.5%)  >>  LNG
# [15:14:55][LNG] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 230/1990] ( 11.6%)  >>  FANG
# [15:14:55][FANG] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 231/1990] ( 11.6%)  >>  DAL
# [15:14:55][DAL] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 232/1990] ( 11.7%)  >>  WCN
# [15:14:55][WCN] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 233/1990] ( 11.7%)  >>  ROP
# [15:14:55][ROP] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 234/1990] ( 11.8%)  >>  ABEV
# [15:14:55][ABEV] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 235/1990] ( 11.8%)  >>  DHI
# [15:14:55][DHI] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 236/1990] ( 11.9%)  >>  OXY
# [15:14:55][OXY] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 237/1990] ( 11.9%)  >>  ASX
# [15:14:55][ASX] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 238/1990] ( 12.0%)  >>  SGEN
# [15:14:55][SGEN] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 239/1990] ( 12.0%)  >>  EBAY
# [15:14:55][EBAY] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 240/1990] ( 12.1%)  >>  YUM
# [15:14:55][YUM] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 241/1990] ( 12.1%)  >>  JD
# [15:14:55][JD] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 242/1990] ( 12.2%)  >>  KR
# [15:14:55][KR] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 243/1990] ( 12.2%)  >>  EL
# [15:14:55][EL] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 244/1990] ( 12.3%)  >>  CTSH
# [15:14:55][CTSH] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 245/1990] ( 12.3%)  >>  TCOM
# [15:14:55][TCOM] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 246/1990] ( 12.4%)  >>  TRGP
# [15:14:55][TRGP] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 247/1990] ( 12.4%)  >>  LVS
# [15:14:55][LVS] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 248/1990] ( 12.5%)  >>  TWTR
# [15:14:55][TWTR] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 249/1990] ( 12.5%)  >>  CCEP
# [15:14:55][CCEP] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 250/1990] ( 12.6%)  >>  MT
# [15:14:55][MT] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 251/1990] ( 12.6%)  >>  IQV
# [15:14:55][IQV] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 252/1990] ( 12.7%)  >>  NUE
# [15:14:55][NUE] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 253/1990] ( 12.7%)  >>  MCHP
# [15:14:55][MCHP] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 254/1990] ( 12.8%)  >>  CPRT
# [15:14:55][CPRT] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 255/1990] ( 12.8%)  >>  XYZ
# [15:14:55][XYZ] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 256/1990] ( 12.9%)  >>  GRMN
# [15:14:55][GRMN] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 257/1990] ( 12.9%)  >>  FIX
# [15:14:55][FIX] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 258/1990] ( 13.0%)  >>  VMC
# [15:14:55][VMC] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 259/1990] ( 13.0%)  >>  WAB
# [15:14:55][WAB] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 260/1990] ( 13.1%)  >>  MLM
# [15:14:55][MLM] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 261/1990] ( 13.1%)  >>  HMC
# [15:14:55][HMC] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 262/1990] ( 13.2%)  >>  HSY
# [15:14:55][HSY] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 263/1990] ( 13.2%)  >>  A
# [15:14:55][A] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 264/1990] ( 13.3%)  >>  PAYX
# [15:14:55][PAYX] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 265/1990] ( 13.3%)  >>  CCI
# [15:14:55][CCI] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 266/1990] ( 13.4%)  >>  KDP
# [15:14:55][KDP] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 267/1990] ( 13.4%)  >>  CCL
# [15:14:55][CCL] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 268/1990] ( 13.5%)  >>  CUK
# [15:14:55][CUK] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 269/1990] ( 13.5%)  >>  NOK
# [15:14:55][NOK] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 270/1990] ( 13.6%)  >>  RMD
# [15:14:55][RMD] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 271/1990] ( 13.6%)  >>  FICO
# [15:14:55][FICO] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 272/1990] ( 13.7%)  >>  TER
# [15:14:55][TER] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 273/1990] ( 13.7%)  >>  TEVA
# [15:14:55][TEVA] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 274/1990] ( 13.8%)  >>  VEEV
# [15:14:55][VEEV] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 275/1990] ( 13.8%)  >>  KEYS
# [15:14:55][KEYS] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 276/1990] ( 13.9%)  >>  FISV
# [15:14:55][FISV] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 277/1990] ( 13.9%)  >>  ODFL
# [15:14:55][ODFL] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 278/1990] ( 14.0%)  >>  TEAM
# [15:14:55][TEAM] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 279/1990] ( 14.0%)  >>  SYY
# [15:14:55][SYY] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 280/1990] ( 14.1%)  >>  ABC
# [15:14:55][ABC] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 281/1990] ( 14.1%)  >>  VTR
# [15:14:55][VTR] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 282/1990] ( 14.2%)  >>  CVE
# [15:14:55][CVE] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 283/1990] ( 14.2%)  >>  ERIC
# [15:14:55][ERIC] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 284/1990] ( 14.3%)  >>  CLS
# [15:14:55][CLS] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 285/1990] ( 14.3%)  >>  EQT
# [15:14:55][EQT] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 286/1990] ( 14.4%)  >>  XYL
# [15:14:55][XYL] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 287/1990] ( 14.4%)  >>  UAL
# [15:14:55][UAL] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 288/1990] ( 14.5%)  >>  VOD
# [15:14:55][VOD] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 289/1990] ( 14.5%)  >>  SATS
# [15:14:55][SATS] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 290/1990] ( 14.6%)  >>  LYV
# [15:14:55][LYV] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 291/1990] ( 14.6%)  >>  FI
# [15:14:55][FI] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 292/1990] ( 14.7%)  >>  INSM
# [15:14:55][INSM] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 293/1990] ( 14.7%)  >>  KMB
# [15:14:55][KMB] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 294/1990] ( 14.8%)  >>  NTRA
# [15:14:55][NTRA] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 295/1990] ( 14.8%)  >>  UI
# [15:14:55][UI] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 296/1990] ( 14.9%)  >>  CHT
# [15:14:55][CHT] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 297/1990] ( 14.9%)  >>  DG
# [15:14:55][DG] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 298/1990] ( 15.0%)  >>  ESLT
# [15:14:55][ESLT] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 299/1990] ( 15.0%)  >>  ANSS
# [15:14:55][ANSS] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 300/1990] ( 15.1%)  >>  CIEN
# [15:14:55][CIEN] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 301/1990] ( 15.1%)  >>  ADM
# [15:14:55][ADM] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 302/1990] ( 15.2%)  >>  WDS
# [15:14:55][WDS] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 303/1990] ( 15.2%)  >>  HUM
# [15:14:55][HUM] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 304/1990] ( 15.3%)  >>  EME
# [15:14:55][EME] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 305/1990] ( 15.3%)  >>  EXPE
# [15:14:55][EXPE] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 306/1990] ( 15.4%)  >>  COHR
# [15:14:55][COHR] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 307/1990] ( 15.4%)  >>  VIK
# [15:14:55][VIK] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 308/1990] ( 15.5%)  >>  ROL
# [15:14:55][ROL] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 309/1990] ( 15.5%)  >>  VRSK
# [15:14:55][VRSK] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 310/1990] ( 15.6%)  >>  FLUT
# [15:14:55][FLUT] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 311/1990] ( 15.6%)  >>  FIS
# [15:14:55][FIS] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 312/1990] ( 15.7%)  >>  EXR
# [15:14:55][EXR] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 313/1990] ( 15.7%)  >>  ULTA
# [15:14:55][ULTA] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 314/1990] ( 15.8%)  >>  ORAN
# [15:14:55][ORAN] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 315/1990] ( 15.8%)  >>  FTAI
# [15:14:55][FTAI] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 316/1990] ( 15.9%)  >>  TSCO
# [15:14:55][TSCO] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 317/1990] ( 15.9%)  >>  HAL
# [15:14:55][HAL] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 318/1990] ( 16.0%)  >>  MTD
# [15:14:55][MTD] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 319/1990] ( 16.0%)  >>  K
# [15:14:55][K] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 320/1990] ( 16.1%)  >>  DXCM
# [15:14:55][DXCM] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 321/1990] ( 16.1%)  >>  TDY
# [15:14:55][TDY] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 322/1990] ( 16.2%)  >>  HPE
# [15:14:55][HPE] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 323/1990] ( 16.2%)  >>  DOV
# [15:14:55][DOV] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 324/1990] ( 16.3%)  >>  UMC
# [15:14:55][UMC] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 325/1990] ( 16.3%)  >>  STZ
# [15:14:55][STZ] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 326/1990] ( 16.4%)  >>  STLA
# [15:14:55][STLA] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 327/1990] ( 16.4%)  >>  KHC
# [15:14:55][KHC] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 328/1990] ( 16.5%)  >>  LEN
# [15:14:55][LEN] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 329/1990] ( 16.5%)  >>  CSGP
# [15:14:55][CSGP] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 330/1990] ( 16.6%)  >>  NETE
# [15:14:55][NETE] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 331/1990] ( 16.6%)  >>  PHG
# [15:14:55][PHG] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 332/1990] ( 16.7%)  >>  IRM
# [15:14:55][IRM] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 333/1990] ( 16.7%)  >>  CQP
# [15:14:55][CQP] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 334/1990] ( 16.8%)  >>  WIT
# [15:14:55][WIT] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 335/1990] ( 16.8%)  >>  HZNP
# [15:14:55][HZNP] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 336/1990] ( 16.9%)  >>  CHTR
# [15:14:55][CHTR] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 337/1990] ( 16.9%)  >>  SPLK
# [15:14:55][SPLK] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 338/1990] ( 17.0%)  >>  EFX
# [15:14:55][EFX] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 339/1990] ( 17.0%)  >>  TECK
# [15:14:55][TECK] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 340/1990] ( 17.1%)  >>  TPR
# [15:14:55][TPR] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 341/1990] ( 17.1%)  >>  SHLM
# [15:14:55][SHLM] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 342/1990] ( 17.2%)  >>  FSLR
# [15:14:55][FSLR] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 343/1990] ( 17.2%)  >>  EC
# [15:14:55][EC] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 344/1990] ( 17.3%)  >>  STE
# [15:14:55][STE] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 345/1990] ( 17.3%)  >>  HUBB
# [15:14:55][HUBB] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 346/1990] ( 17.4%)  >>  JBL
# [15:14:55][JBL] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 347/1990] ( 17.4%)  >>  DLTR
# [15:14:55][DLTR] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 348/1990] ( 17.5%)  >>  STM
# [15:14:55][STM] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 349/1990] ( 17.5%)  >>  BIIB
# [15:14:55][BIIB] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 350/1990] ( 17.6%)  >>  AER
# [15:14:55][AER] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 351/1990] ( 17.6%)  >>  AVB
# [15:14:55][AVB] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 352/1990] ( 17.7%)  >>  STLD
# [15:14:55][STLD] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 353/1990] ( 17.7%)  >>  PPG
# [15:14:55][PPG] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 354/1990] ( 17.8%)  >>  ON
# [15:14:55][ON] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 355/1990] ( 17.8%)  >>  DVN
# [15:14:55][DVN] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 356/1990] ( 17.9%)  >>  CW
# [15:14:55][CW] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 357/1990] ( 17.9%)  >>  WSM
# [15:14:55][WSM] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 358/1990] ( 18.0%)  >>  BR
# [15:14:55][BR] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 359/1990] ( 18.0%)  >>  PHM
# [15:14:55][PHM] [SKIP] 이미 완료 (체크포인트)
# [15:14:55][PROGRESS] [ 360/1990] ( 18.1%)  >>  STRK
# [15:15:28][DB] batch 1: tickers=1, rows=295
# [15:15:45][STRK] [FAIL] STRK: price_stock empty
# [15:15:45][PROGRESS] [ 361/1990] ( 18.1%)  >>  LDOS
# [15:15:45][LDOS] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 362/1990] ( 18.2%)  >>  PSTG
# [15:15:45][PSTG] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 363/1990] ( 18.2%)  >>  SQM
# [15:15:45][SQM] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 364/1990] ( 18.3%)  >>  GIS
# [15:15:45][GIS] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 365/1990] ( 18.3%)  >>  PAAS
# [15:15:45][PAAS] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 366/1990] ( 18.4%)  >>  EQR
# [15:15:45][EQR] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 367/1990] ( 18.4%)  >>  TS
# [15:15:45][TS] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 368/1990] ( 18.5%)  >>  PBA
# [15:15:45][PBA] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 369/1990] ( 18.5%)  >>  LITE
# [15:15:45][LITE] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 370/1990] ( 18.6%)  >>  FLEX
# [15:15:45][FLEX] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 371/1990] ( 18.6%)  >>  TPL
# [15:15:45][TPL] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 372/1990] ( 18.7%)  >>  BCE
# [15:15:45][BCE] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 373/1990] ( 18.7%)  >>  ILMN
# [15:15:45][ILMN] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 374/1990] ( 18.8%)  >>  VRSN
# [15:15:45][VRSN] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 375/1990] ( 18.8%)  >>  WAT
# [15:15:45][WAT] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 376/1990] ( 18.9%)  >>  CASY
# [15:15:45][CASY] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 377/1990] ( 18.9%)  >>  DRI
# [15:15:45][DRI] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 378/1990] ( 19.0%)  >>  TSN
# [15:15:45][TSN] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 379/1990] ( 19.0%)  >>  CNC
# [15:15:45][CNC] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 380/1990] ( 19.1%)  >>  IP
# [15:15:45][IP] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 381/1990] ( 19.1%)  >>  CPAY
# [15:15:45][CPAY] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 382/1990] ( 19.2%)  >>  TLK
# [15:15:45][TLK] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 383/1990] ( 19.2%)  >>  CYBR
# [15:15:45][CYBR] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 384/1990] ( 19.3%)  >>  FTI
# [15:15:45][FTI] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 385/1990] ( 19.3%)  >>  CHD
# [15:15:45][CHD] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 386/1990] ( 19.4%)  >>  VIV
# [15:15:45][VIV] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 387/1990] ( 19.4%)  >>  ALB
# [15:15:45][ALB] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 388/1990] ( 19.5%)  >>  KOF
# [15:15:45][KOF] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 389/1990] ( 19.5%)  >>  LH
# [15:15:45][LH] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 390/1990] ( 19.6%)  >>  FMX
# [15:15:45][FMX] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 391/1990] ( 19.6%)  >>  BG
# [15:15:45][BG] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 392/1990] ( 19.7%)  >>  QSR
# [15:15:45][QSR] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 393/1990] ( 19.7%)  >>  CAJ
# [15:15:45][CAJ] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 394/1990] ( 19.8%)  >>  RL
# [15:15:45][RL] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 395/1990] ( 19.8%)  >>  BLL
# [15:15:45][BLL] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 396/1990] ( 19.9%)  >>  NVR
# [15:15:45][NVR] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 397/1990] ( 19.9%)  >>  FLT
# [15:15:45][FLT] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 398/1990] ( 20.0%)  >>  LUV
# [15:15:45][LUV] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 399/1990] ( 20.1%)  >>  RBA
# [15:15:45][RBA] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 400/1990] ( 20.1%)  >>  LULU
# [15:15:45][LULU] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 401/1990] ( 20.2%)  >>  EXPD
# [15:15:45][EXPD] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 402/1990] ( 20.2%)  >>  TU
# [15:15:45][TU] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 403/1990] ( 20.3%)  >>  TEF
# [15:15:45][TEF] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 404/1990] ( 20.3%)  >>  UTHR
# [15:15:45][UTHR] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 405/1990] ( 20.4%)  >>  CHRW
# [15:15:45][CHRW] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 406/1990] ( 20.4%)  >>  SSNC
# [15:15:45][SSNC] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 407/1990] ( 20.5%)  >>  CTRA
# [15:15:45][CTRA] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 408/1990] ( 20.5%)  >>  GMAB
# [15:15:45][GMAB] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 409/1990] ( 20.6%)  >>  AMCR
# [15:15:45][AMCR] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 410/1990] ( 20.6%)  >>  IHG
# [15:15:45][IHG] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 411/1990] ( 20.7%)  >>  DGX
# [15:15:45][DGX] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 412/1990] ( 20.7%)  >>  INCY
# [15:15:45][INCY] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 413/1990] ( 20.8%)  >>  HL
# [15:15:45][HL] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 414/1990] ( 20.8%)  >>  SBAC
# [15:15:45][SBAC] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 415/1990] ( 20.9%)  >>  PKG
# [15:15:45][PKG] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 416/1990] ( 20.9%)  >>  WWD
# [15:15:45][WWD] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 417/1990] ( 21.0%)  >>  GIB
# [15:15:45][GIB] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 418/1990] ( 21.0%)  >>  CHKP
# [15:15:45][CHKP] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 419/1990] ( 21.1%)  >>  PTC
# [15:15:45][PTC] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 420/1990] ( 21.1%)  >>  NTAP
# [15:15:45][NTAP] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 421/1990] ( 21.2%)  >>  RCI
# [15:15:45][RCI] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 422/1990] ( 21.2%)  >>  JBHT
# [15:15:45][JBHT] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 423/1990] ( 21.3%)  >>  EXAS
# [15:15:45][EXAS] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 424/1990] ( 21.3%)  >>  VIAC
# [15:15:45][VIAC] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 425/1990] ( 21.4%)  >>  GPC
# [15:15:45][GPC] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 426/1990] ( 21.4%)  >>  MTZ
# [15:15:45][MTZ] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 427/1990] ( 21.5%)  >>  WY
# [15:15:45][WY] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 428/1990] ( 21.5%)  >>  PODD
# [15:15:45][PODD] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 429/1990] ( 21.6%)  >>  RGLD
# [15:15:45][RGLD] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 430/1990] ( 21.6%)  >>  IFF
# [15:15:45][IFF] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 431/1990] ( 21.7%)  >>  TYL
# [15:15:45][TYL] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 432/1990] ( 21.7%)  >>  PKX
# [15:15:45][PKX] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 433/1990] ( 21.8%)  >>  BWXT
# [15:15:45][BWXT] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 434/1990] ( 21.8%)  >>  KTOS
# [15:15:45][KTOS] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 435/1990] ( 21.9%)  >>  DD
# [15:15:45][DD] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 436/1990] ( 21.9%)  >>  CX
# [15:15:45][CX] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 437/1990] ( 22.0%)  >>  BURL
# [15:15:45][BURL] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 438/1990] ( 22.0%)  >>  SMCI
# [15:15:45][SMCI] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 439/1990] ( 22.1%)  >>  HPQ
# [15:15:45][HPQ] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 440/1990] ( 22.1%)  >>  LII
# [15:15:45][LII] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 441/1990] ( 22.2%)  >>  IT
# [15:15:45][IT] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 442/1990] ( 22.2%)  >>  AGI
# [15:15:45][AGI] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 443/1990] ( 22.3%)  >>  GPN
# [15:15:45][GPN] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 444/1990] ( 22.3%)  >>  PNR
# [15:15:45][PNR] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 445/1990] ( 22.4%)  >>  ENTG
# [15:15:45][ENTG] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 446/1990] ( 22.4%)  >>  XPO
# [15:15:45][XPO] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 447/1990] ( 22.5%)  >>  WST
# [15:15:45][WST] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 448/1990] ( 22.5%)  >>  CRS
# [15:15:45][CRS] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 449/1990] ( 22.6%)  >>  ZBH
# [15:15:45][ZBH] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 450/1990] ( 22.6%)  >>  NWS
# [15:15:45][NWS] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 451/1990] ( 22.7%)  >>  HUBS
# [15:15:45][HUBS] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 452/1990] ( 22.7%)  >>  ABMD
# [15:15:45][ABMD] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 453/1990] ( 22.8%)  >>  COG
# [15:15:45][COG] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 454/1990] ( 22.8%)  >>  RS
# [15:15:45][RS] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 455/1990] ( 22.9%)  >>  FN
# [15:15:45][FN] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 456/1990] ( 22.9%)  >>  TRMB
# [15:15:45][TRMB] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 457/1990] ( 23.0%)  >>  JLL
# [15:15:45][JLL] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 458/1990] ( 23.0%)  >>  QXO
# [15:15:45][QXO] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 459/1990] ( 23.1%)  >>  Z
# [15:15:45][Z] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 460/1990] ( 23.1%)  >>  HOLX
# [15:15:45][HOLX] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 461/1990] ( 23.2%)  >>  ATI
# [15:15:45][ATI] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 462/1990] ( 23.2%)  >>  AZPN
# [15:15:45][AZPN] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 463/1990] ( 23.3%)  >>  THC
# [15:15:45][THC] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 464/1990] ( 23.3%)  >>  TXT
# [15:15:45][TXT] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 465/1990] ( 23.4%)  >>  APTV
# [15:15:45][APTV] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 466/1990] ( 23.4%)  >>  RTO
# [15:15:45][RTO] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 467/1990] ( 23.5%)  >>  CDW
# [15:15:45][CDW] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 468/1990] ( 23.5%)  >>  WES
# [15:15:45][WES] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 469/1990] ( 23.6%)  >>  TRU
# [15:15:45][TRU] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 470/1990] ( 23.6%)  >>  ZG
# [15:15:45][ZG] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 471/1990] ( 23.7%)  >>  DKS
# [15:15:45][DKS] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 472/1990] ( 23.7%)  >>  MTSI
# [15:15:45][MTSI] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 473/1990] ( 23.8%)  >>  LYB
# [15:15:45][LYB] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 474/1990] ( 23.8%)  >>  MKC
# [15:15:45][MKC] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 475/1990] ( 23.9%)  >>  CDE
# [15:15:45][CDE] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 476/1990] ( 23.9%)  >>  NLY
# [15:15:45][NLY] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 477/1990] ( 24.0%)  >>  ESS
# [15:15:45][ESS] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 478/1990] ( 24.0%)  >>  J
# [15:15:45][J] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 479/1990] ( 24.1%)  >>  HII
# [15:15:45][HII] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 480/1990] ( 24.1%)  >>  COO
# [15:15:45][COO] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 481/1990] ( 24.2%)  >>  MRO
# [15:15:45][MRO] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 482/1990] ( 24.2%)  >>  RBC
# [15:15:45][RBC] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 483/1990] ( 24.3%)  >>  CEA
# [15:15:45][CEA] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 484/1990] ( 24.3%)  >>  ITT
# [15:15:45][ITT] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 485/1990] ( 24.4%)  >>  GEN
# [15:15:45][GEN] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 486/1990] ( 24.4%)  >>  MAA
# [15:15:45][MAA] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 487/1990] ( 24.5%)  >>  WSO
# [15:15:45][WSO] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 488/1990] ( 24.5%)  >>  FFIV
# [15:15:45][FFIV] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 489/1990] ( 24.6%)  >>  OMC
# [15:15:45][OMC] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 490/1990] ( 24.6%)  >>  SUI
# [15:15:45][SUI] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 491/1990] ( 24.7%)  >>  HTHT
# [15:15:45][HTHT] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 492/1990] ( 24.7%)  >>  H
# [15:15:45][H] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 493/1990] ( 24.8%)  >>  BALL
# [15:15:45][BALL] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 494/1990] ( 24.8%)  >>  NWSA
# [15:15:45][NWSA] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 495/1990] ( 24.9%)  >>  VTRS
# [15:15:45][VTRS] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 496/1990] ( 24.9%)  >>  NDSN
# [15:15:45][NDSN] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 497/1990] ( 25.0%)  >>  YNDX
# [15:15:45][YNDX] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 498/1990] ( 25.0%)  >>  AVAV
# [15:15:45][AVAV] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 499/1990] ( 25.1%)  >>  WPC
# [15:15:45][WPC] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 500/1990] ( 25.1%)  >>  DECK
# [15:15:45][DECK] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 501/1990] ( 25.2%)  >>  MGA
# [15:15:45][MGA] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 502/1990] ( 25.2%)  >>  CSL
# [15:15:45][CSL] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 503/1990] ( 25.3%)  >>  SJR
# [15:15:45][SJR] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 504/1990] ( 25.3%)  >>  MLI
# [15:15:45][MLI] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 505/1990] ( 25.4%)  >>  CF
# [15:15:45][CF] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 506/1990] ( 25.4%)  >>  SNN
# [15:15:45][SNN] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 507/1990] ( 25.5%)  >>  HMY
# [15:15:45][HMY] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 508/1990] ( 25.5%)  >>  PFGC
# [15:15:45][PFGC] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 509/1990] ( 25.6%)  >>  IEX
# [15:15:45][IEX] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 510/1990] ( 25.6%)  >>  ULS
# [15:15:45][ULS] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 511/1990] ( 25.7%)  >>  MKSI
# [15:15:45][MKSI] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 512/1990] ( 25.7%)  >>  GDDY
# [15:15:45][GDDY] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 513/1990] ( 25.8%)  >>  AVY
# [15:15:45][AVY] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 514/1990] ( 25.8%)  >>  PKI
# [15:15:45][PKI] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 515/1990] ( 25.9%)  >>  CNHI
# [15:15:45][CNHI] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 516/1990] ( 25.9%)  >>  GGG
# [15:15:45][GGG] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 517/1990] ( 26.0%)  >>  ALLE
# [15:15:45][ALLE] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 518/1990] ( 26.0%)  >>  W
# [15:15:45][W] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 519/1990] ( 26.1%)  >>  YPF
# [15:15:45][YPF] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 520/1990] ( 26.1%)  >>  NLOK
# [15:15:45][NLOK] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 521/1990] ( 26.2%)  >>  ICLR
# [15:15:45][ICLR] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 522/1990] ( 26.2%)  >>  ASND
# [15:15:45][ASND] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 523/1990] ( 26.3%)  >>  MAS
# [15:15:45][MAS] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 524/1990] ( 26.3%)  >>  TSEM
# [15:15:45][TSEM] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 525/1990] ( 26.4%)  >>  AKAM
# [15:15:45][AKAM] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 526/1990] ( 26.4%)  >>  CACI
# [15:15:45][CACI] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 527/1990] ( 26.5%)  >>  PAC
# [15:15:45][PAC] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 528/1990] ( 26.5%)  >>  LECO
# [15:15:45][LECO] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 529/1990] ( 26.6%)  >>  KIM
# [15:15:45][KIM] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 530/1990] ( 26.6%)  >>  JHX
# [15:15:45][JHX] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 531/1990] ( 26.7%)  >>  PEN
# [15:15:45][PEN] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 532/1990] ( 26.7%)  >>  CELH
# [15:15:45][CELH] [SKIP] 이미 완료 (체크포인트)
# [15:15:45][PROGRESS] [ 533/1990] ( 26.8%)  >>  ITCI
# [15:15:45][ITCI] [SKIP] 이미 완료 (체크포인트)
# ...
# [15:19:04][PROGRESS] [1825/1990] ( 91.7%)  >>  NAGE
# [15:19:04][NAGE] [SKIP] 이미 완료 (체크포인트)
# [15:19:04][PROGRESS] [1826/1990] ( 91.8%)  >>  DIN
# [15:19:04][DIN] [SKIP] 이미 완료 (체크포인트)
# [15:19:04][PROGRESS] [1827/1990] ( 91.8%)  >>  KMDA
# [15:19:04][KMDA] [SKIP] 이미 완료 (체크포인트)
# [15:19:04][PROGRESS] [1828/1990] ( 91.9%)  >>  EGY
# [15:19:04][EGY] [SKIP] 이미 완료 (체크포인트)
# [15:19:04][PROGRESS] [1829/1990] ( 91.9%)  >>  EBF
# [15:19:04][EBF] [SKIP] 이미 완료 (체크포인트)
# [15:19:04][PROGRESS] [1830/1990] ( 92.0%)  >>  FPI
# [15:19:04][FPI] [SKIP] 이미 완료 (체크포인트)
# [15:19:04][PROGRESS] [1831/1990] ( 92.0%)  >>  PWFL
# [15:19:04][PWFL] [SKIP] 이미 완료 (체크포인트)
# [15:19:04][PROGRESS] [1832/1990] ( 92.1%)  >>  MAGN
# [15:19:04][MAGN] [SKIP] 이미 완료 (체크포인트)
# [15:19:04][PROGRESS] [1833/1990] ( 92.1%)  >>  RMR
# [15:19:04][RMR] [SKIP] 이미 완료 (체크포인트)
# [15:19:04][PROGRESS] [1834/1990] ( 92.2%)  >>  HPP
# [15:19:04][HPP] [SKIP] 이미 완료 (체크포인트)
# [15:19:04][PROGRESS] [1835/1990] ( 92.2%)  >>  GEVO
# [15:19:04][GEVO] [SKIP] 이미 완료 (체크포인트)
# [15:19:04][PROGRESS] [1836/1990] ( 92.3%)  >>  SIGA
# [15:19:04][SIGA] [SKIP] 이미 완료 (체크포인트)
# [15:19:04][PROGRESS] [1837/1990] ( 92.3%)  >>  CHCT
# [15:19:04][CHCT] [SKIP] 이미 완료 (체크포인트)
# [15:19:04][PROGRESS] [1838/1990] ( 92.4%)  >>  HT
# [15:19:04][HT] [SKIP] 이미 완료 (체크포인트)
# [15:19:04][PROGRESS] [1839/1990] ( 92.4%)  >>  CLNE
# [15:19:04][CLNE] [SKIP] 이미 완료 (체크포인트)
# [15:19:04][PROGRESS] [1840/1990] ( 92.5%)  >>  MITK
# [15:19:04][MITK] [SKIP] 이미 완료 (체크포인트)
# [15:19:04][PROGRESS] [1841/1990] ( 92.5%)  >>  ORN
# [15:19:04][ORN] [SKIP] 이미 완료 (체크포인트)
# [15:19:04][PROGRESS] [1842/1990] ( 92.6%)  >>  ASC
# [15:19:04][ASC] [SKIP] 이미 완료 (체크포인트)
# [15:19:04][PROGRESS] [1843/1990] ( 92.6%)  >>  PKE
# [15:19:04][PKE] [SKIP] 이미 완료 (체크포인트)
# [15:19:04][PROGRESS] [1844/1990] ( 92.7%)  >>  JOUT
# [15:19:04][JOUT] [SKIP] 이미 완료 (체크포인트)
# [15:19:04][PROGRESS] [1845/1990] ( 92.7%)  >>  MCS
# [15:19:04][MCS] [SKIP] 이미 완료 (체크포인트)
# [15:19:04][PROGRESS] [1846/1990] ( 92.8%)  >>  CODI
# [15:19:04][CODI] [SKIP] 이미 완료 (체크포인트)
# [15:19:04][PROGRESS] [1847/1990] ( 92.8%)  >>  CERS
# [15:19:04][CERS] [SKIP] 이미 완료 (체크포인트)
# [15:19:04][PROGRESS] [1848/1990] ( 92.9%)  >>  NRC
# [15:19:04][NRC] [SKIP] 이미 완료 (체크포인트)
# [15:19:04][PROGRESS] [1849/1990] ( 92.9%)  >>  BBBY
# [15:19:04][BBBY] [SKIP] 이미 완료 (체크포인트)
# [15:19:04][PROGRESS] [1850/1990] ( 93.0%)  >>  IMMP
# [15:19:04][IMMP] [SKIP] 이미 완료 (체크포인트)
# [15:19:04][PROGRESS] [1851/1990] ( 93.0%)  >>  MTW
# [15:19:04][MTW] [SKIP] 이미 완료 (체크포인트)
# [15:19:04][PROGRESS] [1852/1990] ( 93.1%)  >>  KOPN
# [15:19:04][KOPN] [SKIP] 이미 완료 (체크포인트)
# [15:19:04][PROGRESS] [1853/1990] ( 93.1%)  >>  SVA
# [15:19:35][DB] batch 1: tickers=1, rows=75
# [15:19:52][SVA] [FAIL] SVA: price_stock empty
# [15:19:52][PROGRESS] [1854/1990] ( 93.2%)  >>  MLR
# [15:19:52][MLR] [SKIP] 이미 완료 (체크포인트)
# [15:19:52][PROGRESS] [1855/1990] ( 93.2%)  >>  OSPN
# [15:19:52][OSPN] [SKIP] 이미 완료 (체크포인트)
# [15:19:52][PROGRESS] [1856/1990] ( 93.3%)  >>  VNDA
# [15:19:52][VNDA] [SKIP] 이미 완료 (체크포인트)
# [15:19:52][PROGRESS] [1857/1990] ( 93.3%)  >>  CD
# [15:19:52][CD] [SKIP] 이미 완료 (체크포인트)
# [15:19:52][PROGRESS] [1858/1990] ( 93.4%)  >>  TCI
# [15:19:52][TCI] [SKIP] 이미 완료 (체크포인트)
# [15:19:52][PROGRESS] [1859/1990] ( 93.4%)  >>  EMX
# [15:19:52][EMX] [SKIP] 이미 완료 (체크포인트)
# [15:19:52][PROGRESS] [1860/1990] ( 93.5%)  >>  OLP
# [15:19:52][OLP] [SKIP] 이미 완료 (체크포인트)
# [15:19:52][PROGRESS] [1861/1990] ( 93.5%)  >>  OBE
# [15:19:52][OBE] [SKIP] 이미 완료 (체크포인트)
# [15:19:52][PROGRESS] [1862/1990] ( 93.6%)  >>  SLS
# [15:19:52][SLS] [SKIP] 이미 완료 (체크포인트)
# [15:19:52][PROGRESS] [1863/1990] ( 93.6%)  >>  GSS
# [15:19:52][GSS] [SKIP] 이미 완료 (체크포인트)
# [15:19:52][PROGRESS] [1864/1990] ( 93.7%)  >>  MLAB
# [15:19:52][MLAB] [SKIP] 이미 완료 (체크포인트)
# [15:19:52][PROGRESS] [1865/1990] ( 93.7%)  >>  WOLF
# [15:19:52][WOLF] [SKIP] 이미 완료 (체크포인트)
# [15:19:52][PROGRESS] [1866/1990] ( 93.8%)  >>  MG
# [15:19:52][MG] [SKIP] 이미 완료 (체크포인트)
# [15:19:52][PROGRESS] [1867/1990] ( 93.8%)  >>  GLDG
# [15:19:52][GLDG] [SKIP] 이미 완료 (체크포인트)
# [15:19:52][PROGRESS] [1868/1990] ( 93.9%)  >>  AVXL
# [15:19:52][AVXL] [SKIP] 이미 완료 (체크포인트)
# [15:19:52][PROGRESS] [1869/1990] ( 93.9%)  >>  CVGW
# [15:19:52][CVGW] [SKIP] 이미 완료 (체크포인트)
# [15:19:52][PROGRESS] [1870/1990] ( 94.0%)  >>  GRVY
# [15:19:52][GRVY] [SKIP] 이미 완료 (체크포인트)
# [15:19:52][PROGRESS] [1871/1990] ( 94.0%)  >>  FRPH
# [15:19:52][FRPH] [SKIP] 이미 완료 (체크포인트)
# [15:19:52][PROGRESS] [1872/1990] ( 94.1%)  >>  IPI
# [15:19:52][IPI] [SKIP] 이미 완료 (체크포인트)
# [15:19:52][PROGRESS] [1873/1990] ( 94.1%)  >>  CABO
# [15:19:52][CABO] [SKIP] 이미 완료 (체크포인트)
# [15:19:52][PROGRESS] [1874/1990] ( 94.2%)  >>  DMAC
# [15:19:52][DMAC] [SKIP] 이미 완료 (체크포인트)
# [15:19:52][PROGRESS] [1875/1990] ( 94.2%)  >>  LAAC
# [15:19:52][LAAC] [SKIP] 이미 완료 (체크포인트)
# [15:19:52][PROGRESS] [1876/1990] ( 94.3%)  >>  CYH
# [15:19:52][CYH] [SKIP] 이미 완료 (체크포인트)
# [15:19:52][PROGRESS] [1877/1990] ( 94.3%)  >>  ATEX
# [15:19:52][ATEX] [SKIP] 이미 완료 (체크포인트)
# [15:19:52][PROGRESS] [1878/1990] ( 94.4%)  >>  SHYF
# [15:19:52][SHYF] [SKIP] 이미 완료 (체크포인트)
# [15:19:52][PROGRESS] [1879/1990] ( 94.4%)  >>  NETI
# [15:19:52][NETI] [SKIP] 이미 완료 (체크포인트)
# [15:19:52][PROGRESS] [1880/1990] ( 94.5%)  >>  NOA
# [15:19:52][NOA] [SKIP] 이미 완료 (체크포인트)
# [15:19:52][PROGRESS] [1881/1990] ( 94.5%)  >>  NGS
# [15:19:52][NGS] [SKIP] 이미 완료 (체크포인트)
# [15:19:52][PROGRESS] [1882/1990] ( 94.6%)  >>  TRC
# [15:19:52][TRC] [SKIP] 이미 완료 (체크포인트)
# [15:19:52][PROGRESS] [1883/1990] ( 94.6%)  >>  FCEL
# [15:19:52][FCEL] [SKIP] 이미 완료 (체크포인트)
# [15:19:52][PROGRESS] [1884/1990] ( 94.7%)  >>  ALLT
# [15:19:52][ALLT] [SKIP] 이미 완료 (체크포인트)
# [15:19:52][PROGRESS] [1885/1990] ( 94.7%)  >>  CLFD
# [15:19:52][CLFD] [SKIP] 이미 완료 (체크포인트)
# [15:19:52][PROGRESS] [1886/1990] ( 94.8%)  >>  EVH
# [15:19:52][EVH] [SKIP] 이미 완료 (체크포인트)
# [15:19:52][PROGRESS] [1887/1990] ( 94.8%)  >>  CAL
# [15:19:52][CAL] [SKIP] 이미 완료 (체크포인트)
# [15:19:52][PROGRESS] [1888/1990] ( 94.9%)  >>  PTSI
# [15:19:52][PTSI] [SKIP] 이미 완료 (체크포인트)
# [15:19:52][PROGRESS] [1889/1990] ( 94.9%)  >>  NATR
# [15:19:52][NATR] [SKIP] 이미 완료 (체크포인트)
# [15:19:52][PROGRESS] [1890/1990] ( 95.0%)  >>  LPTH
# [15:19:52][LPTH] [SKIP] 이미 완료 (체크포인트)
# [15:19:52][PROGRESS] [1891/1990] ( 95.0%)  >>  ULH
# [15:19:52][ULH] [SKIP] 이미 완료 (체크포인트)
# [15:19:52][PROGRESS] [1892/1990] ( 95.1%)  >>  HVT
# [15:19:52][HVT] [SKIP] 이미 완료 (체크포인트)
# [15:19:52][PROGRESS] [1893/1990] ( 95.1%)  >>  ANGO
# [15:19:52][ANGO] [SKIP] 이미 완료 (체크포인트)
# [15:19:52][PROGRESS] [1894/1990] ( 95.2%)  >>  ZUMZ
# [15:19:52][ZUMZ] [SKIP] 이미 완료 (체크포인트)
# [15:19:52][PROGRESS] [1895/1990] ( 95.2%)  >>  PTN
# [15:19:52][PTN] [SKIP] 이미 완료 (체크포인트)
# [15:19:52][PROGRESS] [1896/1990] ( 95.3%)  >>  USAP
# [15:19:52][USAP] [SKIP] 이미 완료 (체크포인트)
# [15:19:52][PROGRESS] [1897/1990] ( 95.3%)  >>  CLPT
# [15:19:52][CLPT] [SKIP] 이미 완료 (체크포인트)
# [15:19:52][PROGRESS] [1898/1990] ( 95.4%)  >>  TSAT
# [15:19:52][TSAT] [SKIP] 이미 완료 (체크포인트)
# [15:19:52][PROGRESS] [1899/1990] ( 95.4%)  >>  SGU
# [15:19:52][SGU] [SKIP] 이미 완료 (체크포인트)
# [15:19:52][PROGRESS] [1900/1990] ( 95.5%)  >>  VHI
# [15:19:52][VHI] [SKIP] 이미 완료 (체크포인트)
# [15:19:52][PROGRESS] [1901/1990] ( 95.5%)  >>  PLG
# [15:19:52][PLG] [SKIP] 이미 완료 (체크포인트)
# [15:19:52][PROGRESS] [1902/1990] ( 95.6%)  >>  KOR
# [15:19:52][KOR] [SKIP] 이미 완료 (체크포인트)
# [15:19:52][PROGRESS] [1903/1990] ( 95.6%)  >>  GPRK
# [15:19:52][GPRK] [SKIP] 이미 완료 (체크포인트)
# [15:19:52][PROGRESS] [1904/1990] ( 95.7%)  >>  NATH
# [15:19:52][NATH] [SKIP] 이미 완료 (체크포인트)
# [15:19:52][PROGRESS] [1905/1990] ( 95.7%)  >>  PERI
# [15:19:52][PERI] [SKIP] 이미 완료 (체크포인트)
# [15:19:52][PROGRESS] [1906/1990] ( 95.8%)  >>  LTBR
# [15:19:52][LTBR] [SKIP] 이미 완료 (체크포인트)
# [15:19:52][PROGRESS] [1907/1990] ( 95.8%)  >>  ACRS
# [15:19:52][ACRS] [SKIP] 이미 완료 (체크포인트)
# [15:19:52][PROGRESS] [1908/1990] ( 95.9%)  >>  LND
# [15:19:52][LND] [SKIP] 이미 완료 (체크포인트)
# [15:19:52][PROGRESS] [1909/1990] ( 95.9%)  >>  HELE
# [15:19:52][HELE] [SKIP] 이미 완료 (체크포인트)
# [15:19:52][PROGRESS] [1910/1990] ( 96.0%)  >>  CLLS
# [15:19:52][CLLS] [SKIP] 이미 완료 (체크포인트)
# [15:19:52][PROGRESS] [1911/1990] ( 96.0%)  >>  PLM
# [15:19:52][PLM] [SKIP] 이미 완료 (체크포인트)
# [15:19:52][PROGRESS] [1912/1990] ( 96.1%)  >>  WNC
# [15:19:52][WNC] [SKIP] 이미 완료 (체크포인트)
# [15:19:52][PROGRESS] [1913/1990] ( 96.1%)  >>  USNA
# [15:19:52][USNA] [SKIP] 이미 완료 (체크포인트)
# [15:19:52][PROGRESS] [1914/1990] ( 96.2%)  >>  JACK
# [15:19:52][JACK] [SKIP] 이미 완료 (체크포인트)
# [15:19:52][PROGRESS] [1915/1990] ( 96.2%)  >>  ELVA
# [15:19:52][ELVA] [SKIP] 이미 완료 (체크포인트)
# [15:19:52][PROGRESS] [1916/1990] ( 96.3%)  >>  SMLP
# [15:19:52][SMLP] [SKIP] 이미 완료 (체크포인트)
# [15:19:52][PROGRESS] [1917/1990] ( 96.3%)  >>  SLP
# [15:19:52][SLP] [SKIP] 이미 완료 (체크포인트)
# [15:19:52][PROGRESS] [1918/1990] ( 96.4%)  >>  LXFR
# [15:19:52][LXFR] [SKIP] 이미 완료 (체크포인트)
# [15:19:52][PROGRESS] [1919/1990] ( 96.4%)  >>  TROO
# [15:19:52][TROO] [SKIP] 이미 완료 (체크포인트)
# [15:19:52][PROGRESS] [1920/1990] ( 96.5%)  >>  CINR
# [15:19:52][CINR] [SKIP] 이미 완료 (체크포인트)
# [15:19:52][PROGRESS] [1921/1990] ( 96.5%)  >>  GTN
# [15:19:52][GTN] [SKIP] 이미 완료 (체크포인트)
# [15:19:52][PROGRESS] [1922/1990] ( 96.6%)  >>  CECE
# [15:19:52][CECE] [SKIP] 이미 완료 (체크포인트)
# [15:19:52][PROGRESS] [1923/1990] ( 96.6%)  >>  WILC
# [15:19:52][WILC] [SKIP] 이미 완료 (체크포인트)
# [15:19:52][PROGRESS] [1924/1990] ( 96.7%)  >>  CO
# [15:19:52][CO] [SKIP] 이미 완료 (체크포인트)
# [15:19:52][PROGRESS] [1925/1990] ( 96.7%)  >>  TRX
# [15:19:52][TRX] [SKIP] 이미 완료 (체크포인트)
# [15:19:52][PROGRESS] [1926/1990] ( 96.8%)  >>  QUOT
# [15:19:52][QUOT] [SKIP] 이미 완료 (체크포인트)
# [15:19:52][PROGRESS] [1927/1990] ( 96.8%)  >>  SSP
# [15:19:52][SSP] [SKIP] 이미 완료 (체크포인트)
# [15:19:52][PROGRESS] [1928/1990] ( 96.9%)  >>  NBY
# [15:19:52][NBY] [SKIP] 이미 완료 (체크포인트)
# [15:19:52][PROGRESS] [1929/1990] ( 96.9%)  >>  TTGT
# [15:19:52][TTGT] [SKIP] 이미 완료 (체크포인트)
# [15:19:52][PROGRESS] [1930/1990] ( 97.0%)  >>  RCKT
# [15:19:52][RCKT] [SKIP] 이미 완료 (체크포인트)
# [15:19:52][PROGRESS] [1931/1990] ( 97.0%)  >>  MTRX
# [15:19:52][MTRX] [SKIP] 이미 완료 (체크포인트)
# [15:19:52][PROGRESS] [1932/1990] ( 97.1%)  >>  DSKE
# [15:19:52][DSKE] [SKIP] 이미 완료 (체크포인트)
# [15:19:52][PROGRESS] [1933/1990] ( 97.1%)  >>  LSAK
# [15:19:52][LSAK] [SKIP] 이미 완료 (체크포인트)
# [15:19:52][PROGRESS] [1934/1990] ( 97.2%)  >>  KFS
# [15:19:52][KFS] [SKIP] 이미 완료 (체크포인트)
# [15:19:52][PROGRESS] [1935/1990] ( 97.2%)  >>  CTGO
# [15:19:52][CTGO] [SKIP] 이미 완료 (체크포인트)
# [15:19:52][PROGRESS] [1936/1990] ( 97.3%)  >>  TITN
# [15:19:52][TITN] [SKIP] 이미 완료 (체크포인트)
# [15:19:52][PROGRESS] [1937/1990] ( 97.3%)  >>  ESEA
# [15:19:52][ESEA] [SKIP] 이미 완료 (체크포인트)
# [15:19:52][PROGRESS] [1938/1990] ( 97.4%)  >>  RVNC
# [15:19:52][RVNC] [SKIP] 이미 완료 (체크포인트)
# [15:19:52][PROGRESS] [1939/1990] ( 97.4%)  >>  ACTG
# [15:19:52][ACTG] [SKIP] 이미 완료 (체크포인트)
# [15:19:52][PROGRESS] [1940/1990] ( 97.5%)  >>  AKBA
# [15:19:52][AKBA] [SKIP] 이미 완료 (체크포인트)
# [15:19:52][PROGRESS] [1941/1990] ( 97.5%)  >>  VSTM
# [15:19:52][VSTM] [SKIP] 이미 완료 (체크포인트)
# [15:19:52][PROGRESS] [1942/1990] ( 97.6%)  >>  RC
# [15:19:52][RC] [SKIP] 이미 완료 (체크포인트)
# [15:19:52][PROGRESS] [1943/1990] ( 97.6%)  >>  DBI
# [15:19:52][DBI] [SKIP] 이미 완료 (체크포인트)
# [15:19:52][PROGRESS] [1944/1990] ( 97.7%)  >>  LCTX
# [15:19:52][LCTX] [SKIP] 이미 완료 (체크포인트)
# [15:19:52][PROGRESS] [1945/1990] ( 97.7%)  >>  ISSC
# [15:19:52][ISSC] [SKIP] 이미 완료 (체크포인트)
# [15:19:52][PROGRESS] [1946/1990] ( 97.8%)  >>  NC
# [15:19:52][NC] [SKIP] 이미 완료 (체크포인트)
# [15:19:52][PROGRESS] [1947/1990] ( 97.8%)  >>  JKS
# [15:19:52][JKS] [SKIP] 이미 완료 (체크포인트)
# [15:19:52][PROGRESS] [1948/1990] ( 97.9%)  >>  NVEC
# [15:19:52][NVEC] [SKIP] 이미 완료 (체크포인트)
# [15:19:52][PROGRESS] [1949/1990] ( 97.9%)  >>  LAND
# [15:19:52][LAND] [SKIP] 이미 완료 (체크포인트)
# [15:19:52][PROGRESS] [1950/1990] ( 98.0%)  >>  HEAR
# [15:19:52][HEAR] [SKIP] 이미 완료 (체크포인트)
# [15:19:52][PROGRESS] [1951/1990] ( 98.0%)  >>  ACCO
# [15:19:52][ACCO] [SKIP] 이미 완료 (체크포인트)
# [15:19:52][PROGRESS] [1952/1990] ( 98.1%)  >>  ELA
# [15:19:52][ELA] [SKIP] 이미 완료 (체크포인트)
# [15:19:52][PROGRESS] [1953/1990] ( 98.1%)  >>  QIWI
# [15:19:52][QIWI] [SKIP] 이미 완료 (체크포인트)
# [15:19:52][PROGRESS] [1954/1990] ( 98.2%)  >>  KNOP
# [15:19:52][KNOP] [SKIP] 이미 완료 (체크포인트)
# [15:19:52][PROGRESS] [1955/1990] ( 98.2%)  >>  OEC
# [15:19:52][OEC] [SKIP] 이미 완료 (체크포인트)
# [15:19:52][PROGRESS] [1956/1990] ( 98.3%)  >>  GCO
# [15:19:52][GCO] [SKIP] 이미 완료 (체크포인트)
# [15:19:52][PROGRESS] [1957/1990] ( 98.3%)  >>  MCFT
# [15:19:52][MCFT] [SKIP] 이미 완료 (체크포인트)
# [15:19:52][PROGRESS] [1958/1990] ( 98.4%)  >>  MOV
# [15:19:52][MOV] [SKIP] 이미 완료 (체크포인트)
# [15:19:52][PROGRESS] [1959/1990] ( 98.4%)  >>  CTRN
# [15:19:52][CTRN] [SKIP] 이미 완료 (체크포인트)
# [15:19:52][PROGRESS] [1960/1990] ( 98.5%)  >>  FVR
# [15:19:52][FVR] [SKIP] 이미 완료 (체크포인트)
# [15:19:52][PROGRESS] [1961/1990] ( 98.5%)  >>  BGS
# [15:19:52][BGS] [SKIP] 이미 완료 (체크포인트)
# [15:19:52][PROGRESS] [1962/1990] ( 98.6%)  >>  NCMI
# [15:19:52][NCMI] [SKIP] 이미 완료 (체크포인트)
# [15:19:52][PROGRESS] [1963/1990] ( 98.6%)  >>  VGZ
# [15:19:52][VGZ] [SKIP] 이미 완료 (체크포인트)
# [15:19:52][PROGRESS] [1964/1990] ( 98.7%)  >>  CCLP
# [15:19:52][CCLP] [SKIP] 이미 완료 (체크포인트)
# [15:19:52][PROGRESS] [1965/1990] ( 98.7%)  >>  ATNI
# [15:19:52][ATNI] [SKIP] 이미 완료 (체크포인트)
# [15:19:52][PROGRESS] [1966/1990] ( 98.8%)  >>  SMC
# [15:19:52][SMC] [SKIP] 이미 완료 (체크포인트)
# [15:19:52][PROGRESS] [1967/1990] ( 98.8%)  >>  CLDT
# [15:19:52][CLDT] [SKIP] 이미 완료 (체크포인트)
# [15:19:52][PROGRESS] [1968/1990] ( 98.9%)  >>  AMCX
# [15:19:52][AMCX] [SKIP] 이미 완료 (체크포인트)
# [15:19:52][PROGRESS] [1969/1990] ( 98.9%)  >>  BYRN
# [15:19:52][BYRN] [SKIP] 이미 완료 (체크포인트)
# [15:19:52][PROGRESS] [1970/1990] ( 99.0%)  >>  INS
# [15:19:52][INS] [SKIP] 이미 완료 (체크포인트)
# [15:19:52][PROGRESS] [1971/1990] ( 99.0%)  >>  MTLS
# [15:19:52][MTLS] [SKIP] 이미 완료 (체크포인트)
# [15:19:52][PROGRESS] [1972/1990] ( 99.1%)  >>  SNMP
# [15:19:52][SNMP] [SKIP] 이미 완료 (체크포인트)
# [15:19:52][PROGRESS] [1973/1990] ( 99.1%)  >>  OFLX
# [15:19:52][OFLX] [SKIP] 이미 완료 (체크포인트)
# [15:19:52][PROGRESS] [1974/1990] ( 99.2%)  >>  RMNI
# [15:19:52][RMNI] [SKIP] 이미 완료 (체크포인트)
# [15:19:52][PROGRESS] [1975/1990] ( 99.2%)  >>  LWAY
# [15:19:52][LWAY] [SKIP] 이미 완료 (체크포인트)
# [15:19:52][PROGRESS] [1976/1990] ( 99.3%)  >>  SVC
# [15:19:52][SVC] [SKIP] 이미 완료 (체크포인트)
# [15:19:52][PROGRESS] [1977/1990] ( 99.3%)  >>  EVI
# [15:19:52][EVI] [SKIP] 이미 완료 (체크포인트)
# [15:19:52][PROGRESS] [1978/1990] ( 99.4%)  >>  OOMA
# [15:19:52][OOMA] [SKIP] 이미 완료 (체크포인트)
# [15:19:52][PROGRESS] [1979/1990] ( 99.4%)  >>  MLP
# [15:19:52][MLP] [SKIP] 이미 완료 (체크포인트)
# [15:19:52][PROGRESS] [1980/1990] ( 99.5%)  >>  STRT
# [15:19:52][STRT] [SKIP] 이미 완료 (체크포인트)
# [15:19:52][PROGRESS] [1981/1990] ( 99.5%)  >>  LFCR
# [15:19:52][LFCR] [SKIP] 이미 완료 (체크포인트)
# [15:19:52][PROGRESS] [1982/1990] ( 99.6%)  >>  PKOH
# [15:19:52][PKOH] [SKIP] 이미 완료 (체크포인트)
# [15:19:52][PROGRESS] [1983/1990] ( 99.6%)  >>  PBYI
# [15:19:52][PBYI] [SKIP] 이미 완료 (체크포인트)
# [15:19:52][PROGRESS] [1984/1990] ( 99.7%)  >>  MPX
# [15:19:52][MPX] [SKIP] 이미 완료 (체크포인트)
# [15:19:52][PROGRESS] [1985/1990] ( 99.7%)  >>  MIXT
# [15:19:52][MIXT] [SKIP] 이미 완료 (체크포인트)
# [15:19:52][PROGRESS] [1986/1990] ( 99.8%)  >>  DENN
# [15:19:52][DENN] [SKIP] 이미 완료 (체크포인트)
# [15:19:52][PROGRESS] [1987/1990] ( 99.8%)  >>  NEO
# [15:19:52][NEO] [SKIP] 이미 완료 (체크포인트)
# [15:19:52][PROGRESS] [1988/1990] ( 99.9%)  >>  AMRN
# [15:19:52][AMRN] [SKIP] 이미 완료 (체크포인트)
# [15:19:52][PROGRESS] [1989/1990] ( 99.9%)  >>  LOCO
# [15:19:52][LOCO] [SKIP] 이미 완료 (체크포인트)
# [15:19:52][PROGRESS] [1990/1990] (100.0%)  >>  BNTC
# [15:19:52][BNTC] [SKIP] 이미 완료 (체크포인트)
# [15:19:52][RETRY] 실패 티커 8개 재시도
# [15:20:24][DB] batch 1: tickers=1, rows=2,830
# [15:20:35][AMD] [RETRY-FAIL] AMD: price_stock empty
# [15:21:07][DB] batch 1: tickers=1, rows=110
# [15:21:25][ELE] [RETRY-FAIL] ELE: price_stock empty
# [15:21:57][DB] batch 1: tickers=1, rows=141
# [15:22:15][LGN] [RETRY-FAIL] LGN: price_stock empty
# [15:22:46][DB] batch 1: tickers=1, rows=70
# [15:23:04][SCZM] [RETRY-FAIL] SCZM: price_stock empty
# [15:23:36][DB] batch 1: tickers=1, rows=286
# [15:23:54][SNDK] [RETRY-FAIL] SNDK: price_stock empty
# [15:24:26][DB] batch 1: tickers=1, rows=295
# [15:24:43][STRK] [RETRY-FAIL] STRK: price_stock empty
# [15:25:15][DB] batch 1: tickers=1, rows=75
# [15:25:32][SVA] [RETRY-FAIL] SVA: price_stock empty
# [15:26:05][DB] batch 1: tickers=1, rows=138
# [15:26:23][WBI] [RETRY-FAIL] WBI: price_stock empty
# [15:26:23][RETRY] 재시도 완료. 최종 실패: 8개
# [15:26:23][BATCH] ======================================================================
# [15:26:23][BATCH] 완료 | 성공=0  스킵=1982  실패=8  합계=1990
# [15:26:23][BATCH] 체크포인트: _batch_checkpoint\done_tickers.txt
# [15:26:23][BATCH] ======================================================================

# %% [markdown]
# ## Cell 12 · DB 조회 유틸 (pivot 조회)
#
# long-format → pivot 형태로 변환해 반환합니다.

# %%
def fetch_required_return_pivot_from_db(
    db_info: Dict[str, Any],
    table_name: str               = TABLE_RESULT,
    indicators: Optional[List[str]] = None,
    start_date: Optional[str]     = None,
    end_date: Optional[str]       = None,
    tickers: Optional[List[str]]  = None,
) -> pd.DataFrame:
    """
    DB long-format → pivot DataFrame.
    반환 컬럼: date, ticker, [indicator 컬럼들...]

    수정 포인트:
      CASE WHEN 의 indicator 값은 직접 SQL 문자열에 삽입 (이스케이프 처리).
      WHERE 절 조건값만 %s 바인딩 사용.
      → pymysql 파라미터 순서 꼬임 문제 완전 해결.
    """
    if indicators is None:
        indicators = ["Re_1y", "Re_3y", "Re_5y",
                      "beta_252", "beta_750", "beta_1250"]

    # ── CASE WHEN: indicator 값을 SQL 문자열에 직접 삽입 (이스케이프) ──
    # %s 파라미터 바인딩 사용 시 WHERE 절 params 와 순서가 꼬이므로
    # indicator 명은 따옴표 이스케이프 후 SQL 리터럴로 직접 삽입
    case_parts = []
    for ind in indicators:
        ind_escaped = ind.replace("'", "''")
        col_name    = ind.replace("'", "''").replace("`", "``")
        case_parts.append(
            f"MAX(CASE WHEN indicator = '{ind_escaped}' THEN value END) AS `{col_name}`"
        )
    case_sql = ",\n                ".join(case_parts)

    # ── WHERE 절: 조건값만 %s 바인딩 ────────────────────────────
    where_clauses = []
    params        = []

    if start_date:
        where_clauses.append("date >= %s")
        params.append(start_date)
    if end_date:
        where_clauses.append("date <= %s")
        params.append(end_date)
    if tickers:
        placeholders = ", ".join(["%s"] * len(tickers))
        where_clauses.append(f"ticker IN ({placeholders})")
        params.extend(tickers)

    where_sql = ("WHERE " + " AND ".join(where_clauses)) if where_clauses else ""

    query = f"""
        SELECT
            date,
            ticker,
            {case_sql}
        FROM   {table_name}
        {where_sql}
        GROUP  BY date, ticker
        ORDER  BY date, ticker;
    """

    # params 에는 WHERE 절 조건값만 포함 (CASE WHEN 값 제외)
    conn = get_conn(db_info)
    try:
        df_pivot = pd.read_sql(query, conn, params=params if params else None)
        df_pivot["date"] = pd.to_datetime(df_pivot["date"], errors="coerce")
        df_pivot = df_pivot.dropna(subset=["date"]).reset_index(drop=True)
        return df_pivot
    finally:
        conn.close()


print("[OK] fetch_required_return_pivot_from_db 함수 정의 완료")
print("     수정: CASE WHEN indicator 값을 SQL 리터럴로 직접 삽입")
print("           WHERE 조건값만 %s 바인딩 → 파라미터 순서 꼬임 해결")
# Out:
# [OK] fetch_required_return_pivot_from_db 함수 정의 완료
#      수정: CASE WHEN indicator 값을 SQL 리터럴로 직접 삽입
#            WHERE 조건값만 %s 바인딩 → 파라미터 순서 꼬임 해결

# %%
conn = get_conn(db_info)
try:
    with conn.cursor() as cur:
        # 전체 row 수
        cur.execute(f"SELECT COUNT(*) AS cnt FROM {TABLE_RESULT}")
        row = cur.fetchone()
        cnt = int(row['cnt'])

        # ticker 샘플
        cur.execute(f"SELECT DISTINCT ticker FROM {TABLE_RESULT} LIMIT 10")
        rows = cur.fetchall()
        df_ticker = pd.DataFrame(rows)
finally:
    conn.close()

print(f"전체 row 수: {cnt:,}")
print(f"저장된 ticker 샘플:\n{df_ticker}")
# Out:
# 전체 row 수: 45,039,952
# 저장된 ticker 샘플:
#   ticker
# 0    AAL
# 1   AAON
# 2   AAPL
# 3   ABUS
# 4   ACAD
# 5   ACHC
# 6   ACLS
# 7   ADBE
# 8   ADEA
# 9    ADI

# %%
conn = get_conn(db_info)
try:
    with conn.cursor() as cur:
        cur.execute(f"SELECT * FROM {TABLE_RESULT} WHERE ticker = 'AAPL' LIMIT 10")
        rows = cur.fetchall()
        df_raw = pd.DataFrame(rows)
finally:
    conn.close()

print(f"AAPL raw 데이터: {len(df_raw)}행")
print(df_raw)
# Out:
# AAPL raw 데이터: 10행
#          date ticker indicator     value
# 0  2011-01-03   AAPL  beta_252  1.057188
# 1  2011-01-03   AAPL     Re_1y  0.139306
# 2  2011-01-04   AAPL  beta_252  1.057057
# 3  2011-01-04   AAPL     Re_1y  0.134599
# 4  2011-01-05   AAPL  beta_252  1.057323
# 5  2011-01-05   AAPL     Re_1y  0.139350
# 6  2011-01-06   AAPL  beta_252  1.058079
# 7  2011-01-06   AAPL     Re_1y  0.132966
# 8  2011-01-07   AAPL  beta_252  1.057400
# 9  2011-01-07   AAPL     Re_1y  0.127886

# %%
# pymysql 커서로 직접 조회 (pd.read_sql 우회)
conn = get_conn(db_info)
try:
    with conn.cursor() as cur:
        # 오염 행 수 확인
        cur.execute(f"SELECT COUNT(*) AS cnt FROM {TABLE_RESULT} WHERE date = 'date'")
        row = cur.fetchone()
        print(f"오염된 행 수: {row['cnt']}")

        # 정상 행 수 확인
        cur.execute(f"SELECT COUNT(*) AS cnt FROM {TABLE_RESULT} WHERE date != 'date'")
        row2 = cur.fetchone()
        print(f"정상 행 수  : {row2['cnt']}")

        # 저장된 ticker 샘플
        cur.execute(f"SELECT DISTINCT ticker FROM {TABLE_RESULT} WHERE date != 'date' LIMIT 10")
        tickers = cur.fetchall()
        print(f"ticker 샘플 : {[r['ticker'] for r in tickers]}")

        # 저장된 indicator 샘플
        cur.execute(f"SELECT DISTINCT indicator FROM {TABLE_RESULT} WHERE date != 'date' LIMIT 10")
        inds = cur.fetchall()
        print(f"indicator 샘플: {[r['indicator'] for r in inds]}")
finally:
    conn.close()
# Out:
# 오염된 행 수: 0
# 정상 행 수  : 45039952
# ticker 샘플 : ['AAL', 'AAON', 'AAPL', 'ABUS', 'ACAD', 'ACHC', 'ACLS', 'ADBE', 'ADEA', 'ADI']
# indicator 샘플: ['beta_252', 'Re_1y', 'beta_750', 'Re_3y', 'beta_1250', 'Re_5y', 'price_stock', 'price_mkt', 'rf_1y', 'rf_3y']

# %% [markdown]
# ## Cell 13 · 결과 조회 테스트

# %%
def fetch_required_return_pivot_from_db(
    db_info: Dict[str, Any],
    table_name: str               = TABLE_RESULT,
    indicators: Optional[List[str]] = None,
    start_date: Optional[str]     = None,
    end_date: Optional[str]       = None,
    tickers: Optional[List[str]]  = None,
) -> pd.DataFrame:
    """
    DB long-format → pivot DataFrame.
    반환 컬럼: date, ticker, [indicator 컬럼들...]
    """
    if indicators is None:
        indicators = ["Re_1y", "Re_3y", "Re_5y",
                      "beta_252", "beta_750", "beta_1250"]

    # CASE WHEN: indicator 값을 SQL 문자열에 직접 삽입 (이스케이프)
    case_parts = []
    for ind in indicators:
        ind_escaped = ind.replace("'", "''")
        col_name    = ind.replace("'", "''").replace("`", "``")
        case_parts.append(
            f"MAX(CASE WHEN indicator = '{ind_escaped}' THEN value END) AS `{col_name}`"
        )
    case_sql = ",\n                ".join(case_parts)

    # WHERE 절: 조건값만 %s 바인딩
    where_clauses = []
    params        = []

    if start_date:
        where_clauses.append("date >= %s")
        params.append(start_date)
    if end_date:
        where_clauses.append("date <= %s")
        params.append(end_date)
    if tickers:
        placeholders = ", ".join(["%s"] * len(tickers))
        where_clauses.append(f"ticker IN ({placeholders})")
        params.extend(tickers)

    where_sql = ("WHERE " + " AND ".join(where_clauses)) if where_clauses else ""

    query = f"""
        SELECT
            date,
            ticker,
            {case_sql}
        FROM   {table_name}
        {where_sql}
        GROUP  BY date, ticker
        ORDER  BY date, ticker;
    """

    # ★ pd.read_sql 대신 커서 직접 실행
    conn = get_conn(db_info)
    try:
        with conn.cursor() as cur:
            cur.execute(query, params if params else None)
            rows = cur.fetchall()
            df_pivot = pd.DataFrame(rows)
    finally:
        conn.close()

    if df_pivot.empty:
        return pd.DataFrame(columns=["date", "ticker"] + indicators)

    df_pivot["date"] = pd.to_datetime(df_pivot["date"], errors="coerce")
    df_pivot = df_pivot.dropna(subset=["date"]).reset_index(drop=True)
    return df_pivot


print("[OK] fetch_required_return_pivot_from_db 함수 정의 완료")
# Out:
# [OK] fetch_required_return_pivot_from_db 함수 정의 완료

# %%
# 단일 티커, 특정 기간
df = fetch_required_return_pivot_from_db(
    db_info    = db_info,
    table_name = TABLE_RESULT,
    indicators = ["Re_1y", "Re_3y", "Re_5y", "beta_252", "beta_750", "beta_1250"],
    start_date = "2020-01-01",
    end_date   = None,          # None이면 최신까지
    tickers    = ["MU"],
)

# %%
df.tail(100)
# Out:
#            date ticker     Re_1y     Re_3y     Re_5y  beta_252  beta_750  \
# 1436 2025-09-19     MU  0.351208  0.340218  0.234257  2.133294  1.797909
# 1437 2025-09-22     MU  0.366961  0.354967  0.237507  2.132211  1.806895
# 1438 2025-09-23     MU  0.319568  0.357557  0.233374  2.136039  1.804421
# 1439 2025-09-24     MU  0.318015  0.357374  0.230376  2.140039  1.806925
# 1440 2025-09-25     MU  0.301244  0.343426  0.231539  2.142103  1.815057
# ...         ...    ...       ...       ...       ...       ...       ...
# 1531 2026-02-05     MU       NaN       NaN       NaN       NaN       NaN
# 1532 2026-02-06     MU       NaN       NaN       NaN       NaN       NaN
# 1533 2026-02-09     MU       NaN       NaN       NaN       NaN       NaN
# 1534 2026-02-10     MU       NaN       NaN       NaN       NaN       NaN
# 1535 2026-02-11     MU       NaN       NaN       NaN       NaN       NaN
#
#       beta_1250
# 1436   1.695594
# 1437   1.696724
# 1438   1.700522
# 1439   1.700730
# 1440   1.700692
# ...         ...
# 1531        NaN
# 1532        NaN
# 1533        NaN
# 1534        NaN
# 1535        NaN
#
# [100 rows x 8 columns]

# %%
# ── 전체 저장 현황 요약 ───────────────────────────────────────
sql_summary = f"""
    SELECT
        indicator,
        COUNT(DISTINCT ticker) AS ticker_cnt,
        COUNT(*)               AS total_rows,
        MIN(date)              AS date_from,
        MAX(date)              AS date_to
    FROM   {TABLE_RESULT}
    GROUP  BY indicator
    ORDER  BY indicator;
"""

conn = get_conn(db_info)
try:
    summary_df = pd.read_sql(sql_summary, conn)
finally:
    conn.close()

print(f"[전체 저장 현황]  {TABLE_RESULT}")
display(summary_df)

# %%
# RF 데이터 마지막 날짜 확인
print("rf_df 마지막 날짜:", rf_df.index.max())
print("rf_df 인덱스 타입:", type(rf_df.index[0]))
print("rf_df tail:\n", rf_df.tail())

# 주가 날짜와 RF 인덱스 타입 비교
conn = get_conn(db_info)
with conn.cursor() as cur:
    cur.execute(
        f"SELECT DISTINCT date FROM {TABLE_RESULT} "
        f"WHERE ticker='AAPL' ORDER BY date DESC LIMIT 5"
    )
    rows = cur.fetchall()
conn.close()
print("\nDB AAPL 최근 날짜:", [r['date'] for r in rows])
# Out:
# rf_df 마지막 날짜: 2026-04-03 00:00:00
# rf_df 인덱스 타입: <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# rf_df tail:
#                rf_1y    rf_5y     rf_3y
# 2026-03-30  0.03598  0.03979  0.037885
# 2026-03-31  0.03600  0.03945  0.037725
# 2026-04-01  0.03605  0.03955  0.037800
# 2026-04-02  0.03607  0.03948  0.037775
# 2026-04-03      NaN      NaN       NaN
#
# DB AAPL 최근 날짜: [datetime.date(2026, 4, 2), datetime.date(2026, 4, 1), datetime.date(2026, 3, 31), datetime.date(2026, 3, 30), datetime.date(2026, 3, 27)]
