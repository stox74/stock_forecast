# %%
# 로깅 설정
import logging
import asyncio
import aiohttp
import ssl
import certifi
import json
import pandas as pd
import numpy as np
import time
import random
import seaborn as sns
import sqlite3
import mysql.connector
from urllib.request import urlopen
from datetime import datetime, timedelta
import matplotlib.pyplot as plt
from DATA.stock_invest_function import *

# matplotlib.rc('font', family='Malgun Gothic')
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False
# warnings.filterwarnings("ignore")

# %%
# DB 접속 정보 설정
db_info = {
    'user': 'stox7412',         # 예: 'root'
    'password': 'Apt106503!~', # 예: '1234'
    # 'host': '192.168.0.230',
    'host': get_db_host(),         # 예: 'localhost' 또는 IP
    'port': '3307',              # 기본 포트는 보통 3306
    'database': 'investar'        # 예: 'trade_data'
}

# API 키 설정
api_key = "hT0gAk87j9xZx4PlBApvBqfVL5IahvgV"

# %% [markdown]
# #### 0. 제무데이터 호출

# %% [markdown]
# #### 1. SARIMAX 를 이용한 매출 예측

# %% [markdown]
# #### 2.  LSTM을 이용한 매출 예측

# %% [markdown]
# #### 3. Exponential Smoothing을 이용한 매출 예측

# %% [markdown]
# #### 4. Prophet을 이용한 매출 예측

# %% [markdown]
# #### 5. 트랜스포머
