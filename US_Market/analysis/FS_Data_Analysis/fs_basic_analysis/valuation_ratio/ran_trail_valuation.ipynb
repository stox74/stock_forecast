# %%
from trail_per_pbr_calculator import TrailValuationCalculator

# API 키 설정
API_KEY =  'hT0gAk87j9xZx4PlBApvBqfVL5IahvgV'

# Calculator 인스턴스 생성
calculator = TrailValuationCalculator(
    api_key=API_KEY,
    output_folder='./results'  # 결과 저장 폴더
)

# 일별 데이터 분석
daily_df = calculator.analyze(
    symbol="STRL",              # 종목 코드
    start_date="2023-01-01",    # 시작일
    end_date="2025-12-31",      # 종료일
    frequency='monthly'           # 'daily' 또는 'monthly'
)
# Out:
# ======================================================================
# Trail Valuation 분석 시작
#   종목: STRL
#   기간: 2023-01-01 ~ 2025-12-31
#   주기: monthly
# ======================================================================
#
# STRL 주가 데이터 수집 중... (2023-01-01 ~ 2025-12-31)
#   - 752개의 일별 데이터 수집 완료
#
# STRL Trail PER/PBR 계산 중...
#
# STRL 분기별 재무제표 수집 중...
#   - 손익계산서: 60개 수집
#   - 재무상태표: 60개 수집 및 병합 완료
#   - 최종 60개의 분기 재무제표 준비 완료
#   - 주요 컬럼 확인: ['totalStockholdersEquity', 'totalEquity']
#   - 분기별 재무제표 컬럼: ['date', 'symbol', 'reportedCurrency', 'cik', 'fillingDate', 'acceptedDate', 'calendarYear', 'period', 'revenue', 'costOfRevenue']...
#   - 752개의 유효한 Trail PER 계산 완료
#   - 752개의 유효한 Trail PBR 계산 완료
#
# 월말 데이터 추출 완료: 36개
#
# 시각화 생성 중... (monthly)
#   - Trail PER 유효 데이터: 36개
#   - Trail PBR 유효 데이터: 36개
#   - Trail PSR 유효 데이터: 36개
#   - 차트 저장: results\STRL_trail_valuation_monthly.png
# Excel 파일 저장 중... (monthly)
#   - Excel 파일 저장: results\STRL_trail_valuation_monthly_20260119_231635.xlsx
#
# ======================================================================
# 분석 완료 요약
# ======================================================================
# 전체 데이터 수: 36
# 유효 Trail PER: 36
# 유효 Trail PBR: 36
# 유효 Trail PSR: 36
#
# 평균 Trail PER: 21.38
#   - 최소: 10.64
#   - 최대: 37.05
#
# 평균 Trail PBR: 5.71
#   - 최소: 2.30
#   - 최대: 11.13
#
# 평균 Trail PSR: 2.13
#   - 최소: 0.69
#   - 최대: 5.24
#
# 결과 파일:
#   - results\STRL_trail_valuation_monthly_20260119_231635.xlsx
# ======================================================================
