# %%
import wrds
import warnings
import pandas as pd
import numpy as np
import time
from tqdm import tqdm
import os
# import statsmodels.formula.api as smf
import datetime
from pandas.tseries.offsets import MonthEndp
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[18], line 10
#       8 # import statsmodels.formula.api as smf
#       9 import datetime
# ---> 10 from pandas.tseries.offsets import MonthEndp
#
# ImportError: cannot import name 'MonthEndp' from 'pandas.tseries.offsets' (C:\Users\Hoyoung_Park\PyCharmMiscProject\.venv1\lib\site-packages\pandas\tseries\offsets.py)

# %%
# functions in /fire_pytools/utils

def pk_integrity(df, primary_key):

    """Check that df columns in primary_key consist no missing values or duplicates."""

    assert df[primary_key].notna().all().all(), 'Null values detected in primary key.'
    assert not df[primary_key].duplicated().any(), 'Duplicate values detected in primary key.'

    pass



def monthly_date(date):
    """
    Get year and month from a datestamp as a integer
    """
    mdate = date.year*100+date.month

    return mdate


def create_crsp_calendar(db):
    """"
    Create CRSP daily calender.
    Input:
        db: WRDS connection
    Return:
        tdays: pandas costume business days calendar
    """

    #db = wrds.Connection(wrds_username='lmota')

    # Erroneous dates: on these dates there are only 1 or 22 (2012-10-29) stock observations, all missing returns
    # seem to be erroneous holidays/weekenddays
    err_dates = pd.to_datetime(['1952-09-27', '1962-08-12', '1972-12-25', '1972-12-28',
                 '1973-01-25', '1973-09-09', '1976-08-29', '1977-01-15', '1977-07-14',
                 '1978-11-26', '1981-11-01', '1985-09-27', '1987-04-19', '1992-10-24',
                 '1995-09-30', '1996-02-19', '2001-09-11', '2012-10-29', '2017-09-30'])

    # Create dist_prc variable - count number of valid days since last
    sql = "SELECT DISTINCT date FROM crspq.dsf"
    dates = db.raw_sql(sql, date_cols=['date'])
    dates = dates.sort_values(['date']).reset_index().date

    # Notice that we are marking weekend as holidays because in the begging of the sample saturdays were trading days.
    all_days = pd.date_range(min(dates), max(dates))
    holidays = all_days[np.logical_not(all_days.isin(dates))]
    holidays = holidays.append(err_dates)
    holidays = holidays.unique()

    # Define CRSP's trading days calendar
    tdays = np.busdaycalendar(weekmask=[1, 1, 1, 1, 1, 1, 1], holidays=holidays.tolist())

    # Test
    # np.busday_count(min(dates), max(dates), busdaycal=TDays) == len(dates) - 1

    return tdays


def post_event_nan(df, event, vars, id_vars=['permno', 'date']):

    event_dt = df[event][id_vars]
    event_dt.rename(columns={id_vars[1]: 'event_date'}, inplace=True)
    pk_integrity(event_dt, id_vars[0])

    df = pd.merge(df, event_dt, on=id_vars[0], how='left')
    df.loc[df[id_vars[1]] > df['event_date'], vars] = np.nan
    df.drop(columns={'event_date'}, inplace=True)

    return df

TABLE = {'cusip': 'all',
         'permco': 'all',
         'issuno': 'all',
         'hexcd': 'all',
         'hsiccd': 'all',
         'shrout': 'all',
         'bidlo': 'sf',
         'askhi': 'sf',
         'prc': 'sf',
         'vol': 'sf',
         'ret': 'sf',
         'bid': 'sf',
         'ask': 'sf',
         'cfacpr': 'sf',
         'cfacshr': 'sf',
         'retx': 'sf',
         'altprc': 'msf',
         'spread': 'msf',
         'altprcdt': 'msf',
         'openprc': 'dsf',
         'numtrd': 'dsf',
         'comnam': 'seall',
         'dclrdt': 'seall',
         'dlamt': 'seall',
         'dlpdt': 'seall',
         'dlstcd': 'seall',
         'ncusip': 'seall',
         'nextdt': 'seall',
         'paydt': 'seall',
         'rcrddt': 'seall',
         'shrcls': 'seall',
         'shrflg': 'seall',
         'ticker': 'seall',
         'hsicmg': 'seall',
         'hsicig': 'seall',
         'nameendt': 'seall',
         'shrcd': 'seall',
         'exchcd': 'seall',
         'siccd': 'seall',
         'tsymbol': 'seall',
         'naics': 'seall',
         'primexch': 'seall',
         'trdstat': 'seall',
         'secstat': 'seall',
         'distcd': 'seall',
         'divamt': 'seall',
         'facpr': 'seall',
         'facshr': 'seall',
         'acperm': 'seall',
         'accomp': 'seall',
         'shrenddt': 'seall',
         'nwperm': 'seall',
         'nwcomp': 'seall',
         'dlretx': 'seall',
         'dlprc': 'seall',
         'dlret': 'seall',
         'trtscd': 'seall',
         'trtsendt': 'seall',
         'nmsind': 'seall',
         'mmcnt': 'seall',
         'nsdinx': 'seall',
         'year': 'mseall',
         'month': 'mseall'}

# MSEPAD is used when creating CRSP
# When merging mse and sf tables and for vars in MSEPAD we should copy information from
# event observations to succeeding non-event observations.
MSEPAD = ["ticker", "comnam", "ncusip", "shrout", "siccd", "exchcd",
          "shrcls", "shrcd",  "shrflg", "trtscd", "nmsind", "mmcnt",
          "naics", "nsdinx"]


# %% Function Definition


def crsp_sf(varlist, start_date, end_date, freq, permno_list=None, shrcd_list=None, exchcd_list=None, db=None):


    start_time = time.time()
    if db is None:
        db = wrds.Connection() # make sure to configure wrds connector before hand.

    assert freq in ['daily', 'monthly'], "freq must be either 'daily' or 'monthly'."

    if freq == 'daily' and len(varlist) > 1:
        warnings.warn('''Querying multiple variables from daily tables may take a long time if limited RAM is available (16GB or less).
                         WRDS connection may time out causing an error.''')

    prefix = 'd' if freq == 'daily' else 'm'

    sfvars = ['permno', 'date']
    sfvars += [i for i in varlist if TABLE[i] in ['{}sf'.format(prefix), 'sf']]
    sfvars += [i + ' AS {}_sf'.format(i) for i in varlist if TABLE[i] == 'all']

    seallvars = ['permno', 'date']

    if ('divamt' in set(varlist)) & ('facpr' not in set(varlist)):
        seallvars += ['facpr']
    if ('divamt' in set(varlist)) & ('distcd' not in set(varlist)):
        seallvars += ['distcd']

    seallvars += [i for i in varlist if TABLE[i] in ['{}seall'.format(prefix), 'seall']]
    seallvars += [i + ' AS {}_seall'.format(i) for i in varlist if TABLE[i] == 'all']

    permnos = 'AND permno IN ({})'.format(", ".join(map(str, permno_list))) if permno_list else ''

    sql = '''
          SELECT {}
          FROM crsp.{}sf
          WHERE date >= DATE '{}'
          AND date <= DATE '{}'
          {}
          '''.format(', '.join(sfvars), prefix, start_date, end_date, permnos)

    df = db.raw_sql(sql, date_cols=['date'])

    sql = '''
          SELECT {}
          FROM crsp.{}seall
          WHERE date >= DATE '{}'
          AND date <= DATE '{}'
          {}
          '''.format(', '.join(seallvars), prefix, start_date, end_date, permnos)

    df2 = db.raw_sql(sql, date_cols=['date'])

    # There are some duplicates in mseall that differ in variables related to cash distributions and acquisitions.
    # Cumulate if possible, or remove arbitrary row. Raise warning if any relevant variable was queried.
    nonunique_cols = ['rcrddt', 'dclrdt', 'acperm', 'accomp', 'paydt', 'distcd', 'facpr', 'facshr']

    if set(varlist).intersection(set(nonunique_cols)):
        warnings.warn('''Duplicate permno-date observations were deleted arbitrarily.
                             {} percent of the observations.
                             Please resolve manually the affected columns:
                             {}
                             '''.format(str((df2.duplicated(subset=['permno', 'date']).sum() / df2.shape[0]) * 100),
                                        ', '.join(nonunique_cols)))

    # Duplicated happens when there is two distribution types at the same day.
    # We need to have permno/date as primary key
    # df2.duplicated(subset=['permno', 'date', 'distcd', 'paydt']).sum() # TODO: why isn't this primary key?
    # We start with  52665 duplicated permno/date. 1867 non zero facpr (monthly).

    if 'divamt' in set(varlist):
        # Calculate (TOTAL) DIVAMT:
        # "If the Distribution code is 6225, a nonzero amount represents an offer price given to a certain amount of
        # shares. For these cases, the dollar value per share is actually DIVAMT multiplied by the percent of shares
        # accepted by the offer, where the percent of shares accepted can be derived by multiplying FACPR by negative
        # one. See FACPR." (WRDS)
        # print(df2[df2.distcd == 6225].to_string())

        df2.set_index(['permno', 'date'], inplace=True)

        div = df2[['distcd', 'divamt', 'facpr']].copy()
        div.reset_index(inplace=True)
        div.loc[div.distcd == 6225, 'divamt'] = div['facpr']*(-1)*div['divamt']

        div = div.groupby(['permno', 'date'])['divamt'].sum(min_count=1).to_frame('divamt')

        df2.reset_index(inplace=True)
        df2.drop(columns=['divamt'], inplace=True)

    # For all other entries keep last
    df2 = df2[~df2.duplicated(subset=['permno', 'date'], keep='last')].copy()
    pk_integrity(df2, ['date', 'permno'])

    # Merge tables.
    df['permno'] = df['permno'].astype('int')
    df2['permno'] = df2['permno'].astype('int')

    # Merge tables with following logic: for each sf observation, merge most recent seall observation with same permno.
    # If particular permno-date combination does not exist in sf but does in seall, include that observation.
    df.sort_values(['date', 'permno'], inplace=True)
    df2.sort_values(['date', 'permno'], inplace=True)

    df = pd.merge_asof(df, df2, on='date', by='permno', direction='backward')

    df2 = df2[(df2['date'] >= start_date) & (df2['date'] <= end_date)]
    df = df.merge(df2, on=['permno', 'date'], how='outer', validate='1:1', suffixes=('', '_y'), indicator=True)

    for i in df2.columns.tolist()[2:]:
        df.loc[df['_merge'] == 'right_only', i] = df[i + '_y']
    df.drop([s + '_y' for s in df2.columns.tolist()[2:]] + ['_merge'], axis=1, inplace=True)
    del df2

    # Make sure that downloaded columns that exist in both tables agree and keep union of them.
    for i in [j for j in varlist if TABLE[j] == 'all']:
        mask = df[[i + '_sf', i + '_seall']].notnull().all(axis=1)
        assert (df.loc[mask, i + '_sf'] == df.loc[mask, i + '_seall']).all(), \
            'sf and seall had conflicting values for {}.'.format(i)
        df.rename(columns={i + '_sf': i}, inplace=True)
        df.loc[df[i].isnull(), i] = df[i + '_seall']
        df.drop(i + '_seall', axis=1, inplace=True)

    # Add total divamt
    if 'divamt' in set(varlist):
        df = df.merge(div, on=['permno', 'date'], how='left')

    # delete wanted rows
    if exchcd_list:
        df = df[df.exchcd.isin(exchcd_list)]
    if shrcd_list:
        df = df[df.shrcd.isin(shrcd_list)]
    df = df[(df['date'] >= start_date) & (df['date'] <= end_date)]

    df = df[['permno', 'date']+varlist]

    pk_integrity(df, ['permno', 'date'])

    df.sort_values(['permno', 'date'], inplace=True)

    print("CRSP data was successfully downloaded in %s seconds." % str(time.time() - start_time))

    return df

def calculate_melag_weight(mdata):
    required_cols = ['lag_me', 'lag_dlret']

    set(required_cols).issubset(mdata.columns), "Required columns: {}.".format(', '.join(required_cols))

    df = mdata[required_cols].copy()
    df['melag'] = df.groupby('permno').lag_me.fillna(method='pad')
    df.reset_index(inplace=True)

    # Fill na after delisting
    df = post_event_nan(df=df, event=df.lag_dlret.notnull(), vars=['melag'], id_vars=['permno', 'date'])

    df.set_index(['permno', 'date'], inplace=True)

    return df[['melag']]

def get_adata_quarter(adata, data_name):

    data = adata.pivot_table(index='date', columns='permno', values= data_name).astype('float')
    # data = data.fillna(method='ffill', limit=2)
    data = data.loc[[x for x in data.index if x.month % 3 == 2]].reindex(data.index).ffill(limit=2).dropna(how='all')

    return data

def which_quantile(data_scalar, nyse_criteria_list):
  if np.isinf(data_scalar):
    return np.nan

  for q in range(1, len(nyse_criteria_list) - 1):
    if nyse_criteria_list[q-1] <= data_scalar < nyse_criteria_list[q]:
      return q

  return len(nyse_criteria_list) - 1


def get_quantile(data_series, nyse_bool, q=5):
    # NaN 값 처리
    data_series = data_series.dropna()

    if len(data_series) == 0:
        return np.nan

    # nyse_bool에서 NaN 값을 False로 변환
    tmp_nyse_bool = nyse_bool.loc[data_series.name].fillna(False)
    nyse_data_series = data_series[tmp_nyse_bool]

    nyse_criteria = [np.nanpercentile(nyse_data_series, x) for x in range(0, 100+int(100/q), int(100/q))]

    return data_series.apply(lambda x: which_quantile(x, nyse_criteria))



def get_port_rtn(ret_df, wl1_df):
  return (ret_df * wl1_df).sum(axis=1).replace(0, np.nan).dropna()


def get_quantile_rtn(ret_df, me_df, quantile_df):
  q = np.unique(quantile_df.values.flatten())
  q = int(max(q[~np.isnan(q)]))

  port_rtn = pd.DataFrame(index=ret_df.index, columns=range(1, q+1), dtype=float)

  for i in range(1, q+1):
    tmp_me = me_df[quantile_df == i]
    tmp_wl1 = tmp_me.divide(tmp_me.sum(axis=1), axis=0).shift(1).dropna(how='all')

    port_rtn[i] = get_port_rtn(ret_df, tmp_wl1)

  port_rtn[f'{q}-1'] = port_rtn[q] - port_rtn[1]
  return port_rtn.dropna(how='all')

def calculate_annual_volatility_and_sharpe_ratio(df, risk_free_rate=0.02):
    """
    월간 수익률 데이터프레임에서 연간 변동성과 샤프 비율을 계산합니다.

    :param df: 월간 수익률이 포함된 데이터프레임. 인덱스는 날짜, 컬럼은 'returns'.
    :param risk_free_rate: 연간 무위험 수익률 (기본값: 0.02)
    :return: 연간 변동성과 샤프 비율
    """
    # 연간 수익률 계산
    cumulative_returns = (1 + df['returns']).prod() ** (12 / len(df)) - 1

    # 연간 변동성 계산
    annual_volatility = df['returns'].std() * np.sqrt(12)

    # 샤프 비율 계산
    sharpe_ratio = (cumulative_returns - risk_free_rate) / annual_volatility

    return annual_volatility, sharpe_ratio

# %%
# %% Set Up
db = wrds.Connection()
start_time = time.time()
# Out:
# WRDS recommends setting up a .pgpass file.
# pgpass file created at C:\Users\Hoyoung_Park\AppData\Roaming\postgresql\pgpass.conf
# Created .pgpass file successfully.
# You can create this file yourself at any time with the create_pgpass_file() function.
# Loading library list...
# Done

# %%
from datetime import date
# from crsp import crsp_sf  # 가상의 함수, 실제 코드에 맞게 수정 필요

print('Stock monthly calculation started.')

# 필요한 변수 목록
varlist = ['dlret', 'dlretx', 'exchcd', 'naics', 'permco', 'prc', 'ret', 'shrcd', 'shrout', 'siccd', 'ticker', 'cusip']

start_date = '2000-01-01'
end_date = date.today().strftime("%Y-%m-%d")
# end_date = '2023-12-31'
freq = 'monthly'
permno_list = None  # 필요에 따라 특정 permno 리스트를 지정할 수 있습니다.
shrcd_list = [10, 11]
exchcd_list = [1, 2, 3]

# crsp_sf 함수 호출 (가상의 함수, 실제 코드에 맞게 수정 필요)
crspm = crsp_sf(varlist,
                start_date,
                end_date,
                freq=freq,
                permno_list=permno_list,
                shrcd_list=shrcd_list,
                exchcd_list=exchcd_list,
                db=db)
# Out:
# Stock monthly calculation started.
# CRSP data was successfully downloaded in 330.1948812007904 seconds.

# %%
start_time = time.time()
if db is None:
    db = wrds.Connection() # make sure to configure wrds connector before hand.

assert freq in ['daily', 'monthly'], "freq must be either 'daily' or 'monthly'."

if freq == 'daily' and len(varlist) > 1:
    warnings.warn('''Querying multiple variables from daily tables may take a long time if limited RAM is available (16GB or less).
                     WRDS connection may time out causing an error.''')

prefix = 'd' if freq == 'daily' else 'm'

sfvars = ['permno', 'date']
sfvars += [i for i in varlist if TABLE[i] in ['{}sf'.format(prefix), 'sf']]
sfvars += [i + ' AS {}_sf'.format(i) for i in varlist if TABLE[i] == 'all']

seallvars = ['permno', 'date']

if ('divamt' in set(varlist)) & ('facpr' not in set(varlist)):
    seallvars += ['facpr']
if ('divamt' in set(varlist)) & ('distcd' not in set(varlist)):
    seallvars += ['distcd']

seallvars += [i for i in varlist if TABLE[i] in ['{}seall'.format(prefix), 'seall']]
seallvars += [i + ' AS {}_seall'.format(i) for i in varlist if TABLE[i] == 'all']

permnos = 'AND permno IN ({})'.format(", ".join(map(str, permno_list))) if permno_list else ''

# WRDS 데이터베이스 연결
db = wrds.Connection()

# SQL 쿼리 문자열
sql = '''
      SELECT {}
      FROM crsp.{}sf
      WHERE date >= DATE '{}'
      AND date <= DATE '{}'
      {}
      '''.format(', '.join(sfvars), prefix, start_date, end_date, permnos)

# SQL 쿼리 실행
df = db.raw_sql(sql, date_cols=['date'])
# Out:
# WRDS recommends setting up a .pgpass file.
# pgpass file created at C:\Users\Hoyoung_Park\AppData\Roaming\postgresql\pgpass.conf
# Created .pgpass file successfully.
# You can create this file yourself at any time with the create_pgpass_file() function.
# Loading library list...
# Done

# %%
crspm['rankyear'] = crspm.date.dt.year
crspm.loc[crspm.date.dt.month <= 6, 'rankyear'] = crspm.loc[crspm.date.dt.month <= 6, 'rankyear'] - 1

# Returns adjusted for delisting
crspm['retadj'] = ((1 + crspm['ret'].fillna(0)) * (1 + crspm['dlret'].fillna(0)) - 1)
crspm.loc[crspm[['ret', 'dlret']].isnull().all(axis=1), 'retadj'] = np.nan

crspm['me'] = abs(crspm['prc']) * (crspm['shrout'] / 1000)

# Adjust for delisting
crspm.loc[crspm.dlret.notnull(), 'me'] = np.nan

start_time1 = time.time()

crspm['edate'] = crspm['date'] + MonthEnd(0)
crspm.sort_values(['permno', 'edate'], inplace=True)
pk_integrity(crspm, ['permno', 'edate'])
crspm.set_index('edate', inplace=True)

# Resample to take care of missing months
scrspm = crspm[['permno', 'me', 'dlret']].groupby('permno').resample('M').mean().drop(columns='permno')  # mean maintains nan
scrspm = scrspm.groupby('permno').shift(1)
scrspm.columns = ['lag_' + i for i in scrspm.columns]

crspm.reset_index(inplace=True)
crspm.set_index(['permno', 'edate'], inplace=True)

crspm_full = crspm.join(scrspm, how='outer')

crspm_full.reset_index(inplace=True)

# Delete rows that were not in the original data set
crspm_full.dropna(subset=['date'], inplace=True)
crspm_full.drop(columns=['edate'], inplace=True)

print("Finish resampling. Time to resample data: %s minutes" % str((time.time() - start_time1)/60))

# Create MElag
crspm_full.set_index(['permno', 'date'], inplace=True)
crspm_full['melag_weights'] = calculate_melag_weight(crspm_full)
crspm_full.drop(columns=[x for x in crspm.columns if 'lag_' in x], inplace=True)

crspm_full.reset_index(inplace=True)
crspm_full.sort_values(['permno', 'date'], inplace=True)

print("Time to create CRSP monthly: %s seconds" % str(time.time() - start_time))

stock_monthly = crspm_full

print("Time to create CRSP monthly: %s minutes" % str(np.round((time.time() - start_time)/60, 2)))
# Out:
# C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\265808269.py:21: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   scrspm = crspm[['permno', 'me', 'dlret']].groupby('permno').resample('M').mean().drop(columns='permno')  # mean maintains nan
# Finish resampling. Time to resample data: 0.3506136178970337 minutes
# C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2045336624.py:294: FutureWarning: SeriesGroupBy.fillna is deprecated and will be removed in a future version. Use obj.ffill() or obj.bfill() for forward or backward filling instead. If you want to fill with a single value, use Series.fillna instead
#   df['melag'] = df.groupby('permno').lag_me.fillna(method='pad')
# C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2045336624.py:294: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['melag'] = df.groupby('permno').lag_me.fillna(method='pad')
# Time to create CRSP monthly: 214.2046513557434 seconds
# Time to create CRSP monthly: 3.57 minutes

# %%
# SQL 쿼리 작성 (Compustat 데이터베이스에서 필요한 데이터 추출)
query = """
    SELECT a.gvkey, a.datadate, c.tic, c.cusip, a.at, a.lt, a.sale, a.cogs, a.xsga, a.xrd, a.ebitda, a.ebit, a.xint, a.pi, a.txt, a.xido, a.ib, a.ni, a.dvc, a.dvt, a.capx, a.oancf, a.prstkc, a.sstk,  a.dltis, a.dlcch, a.fincf, a.act, a.rect, a.che, a.invt, a.intan, a.ivao, a.ppegt, a.ppent, a.lct,  a.ap, a.dlc, a.txp, a.dltt, a.txditc, a.pstkrv, a.seq, a.ceq, a.icapt, a.mib, a.ivst, a.ao, a.lo, a.dp
    FROM comp.funda as a
    LEFT JOIN comp.names as c
    ON a.gvkey = c.gvkey
    WHERE a.indfmt = 'INDL' AND a.datafmt = 'STD' AND a.popsrc = 'D' AND a.consol = 'C'
    AND a.datadate >= '2020-01-01'
"""

# 쿼리 실행 및 데이터프레임으로 변환
funda_df = db.raw_sql(query)

# %%
# SQL 쿼리 작성
query = """
    SELECT q.gvkey, q.datadate, c.tic, c.cusip,  q.actq, q.aoq, q.apq, q.atq, q.ceqq, q.cheq, q.cogsq, q.dlcq, q.dpq, q.epspiq, q.ibq, q.icaptq, q.intanq, q.invtq, q.ivaoq, q.ivstq, q.lctq, q.loq, q.ltq, q.mibtq, q.niq, q.piq, q.ppegtq, q.ppentq, q.pstkrq, q.recdq, q.rectq, q.rectrq, q.saleq, q.seqq, q.txdiq, q.txpq, q.txtq, q.xidoq, q.xintq,q.xrdq, q.xsgaq, q.capxy, q.chechy, q.dlcchy, q.dltisy, q.fincfy, q.oancfy, q.prstkcy, q.sstky
    FROM comp.fundq as q
    LEFT JOIN comp.names as c
    ON q.gvkey = c.gvkey
    WHERE q.indfmt = 'INDL' AND q.datafmt = 'STD' AND q.popsrc = 'D' AND q.consol = 'C'
    AND q.datadate >= '2000-01-01'
"""

# 쿼리 실행 및 데이터프레임으로 변환
fundq_df = db.raw_sql(query)

# 데이터프레임 출력
print(fundq_df.head())
# Out:
#     gvkey    datadate     tic      cusip      actq      aoq      apq  \
# 0  001013  2000-01-31  ADCT.1  000886309  1137.412   333.83  103.291
# 1  001082  2000-01-31  SERV.1  81765M106    39.941    8.971   13.077
# 2  001173  2000-01-31   AIM.1  008015307    17.435    0.877    1.968
# 3  001183  2000-01-31   IDAI.  45169P106      <NA>    8.982    0.632
# 4  001189  2000-01-31   AGR.7  008489502   454.479  125.407     <NA>
#
#         atq      ceqq     cheq  ...   xrdq  xsgaq   capxy  chechy  dlcchy  \
# 0  1814.519  1396.005  364.315  ...   75.2  205.6  46.785  21.138    <NA>
# 1   110.675     21.27     4.44  ...   <NA>  2.169   9.597  -2.956  -7.367
# 2    22.774    12.644    0.964  ...  0.801  1.839   0.558  -0.754   0.174
# 3   103.962    83.879   54.333  ...   <NA>   <NA>   1.091  22.224     0.0
# 4    839.17   363.297     <NA>  ...   <NA>   <NA>  17.181  -12.63    <NA>
#
#    dltisy  fincfy  oancfy  prstkcy   sstky
# 0    <NA>  16.289  41.582      0.0  42.657
# 1   9.503  -4.911   5.032      0.0     0.0
# 2   1.974   0.528  -0.724    0.542     0.0
# 3     0.0  -2.582 -18.925    2.582    <NA>
# 4  38.728  32.244  -21.55      0.0     0.0
#
# [5 rows x 49 columns]

# %%
# cusip의 마지막 자리수를 제거하는 함수 정의
def remove_last_digit(cusip):
    if pd.isnull(cusip):  # NaN 처리
        return cusip
    return cusip[:-1]

# apply 함수를 사용하여 cusip 열에 적용
funda_df['cusip'] = funda_df['cusip'].apply(remove_last_digit)
fundq_df['cusip'] = fundq_df['cusip'].apply(remove_last_digit)


funda_df.rename(columns={'datadate': 'edate'}, inplace=True)
funda_df['edate'] = pd.to_datetime(funda_df['edate'], format='%Y-%m-%d')
crspm_re = crspm.reset_index()
# adata = pd.merge(crspm_re, funda_df, on=['cusip', 'edate'], how='left')
# adata.to_csv(r'C:\Users\82108\PycharmProjects\Factor_Model\US\data\adata_2024_2q.csv')

# %%
# fundq_df[fundq_df['tic'] == 'AAPL'][['tic', 'edate', 'aoq', 'saleq', 'cogsq', 'epspiq']].head(10)

# %%
# save_path = r"C:\Users\MetaM\Downloads\fundq_2025-05-22.csv"
# fundq_df.to_csv(save_path, index=False)

# %%
# qdata.tail(12)

# %%
# fundaq_2024 = fundq_df[fundq_df['edate'] >= '2024-06-01']
# qticker_2024 = fundaq_2024['tic'].unique().tolist()
# qticker_2024 = [ticker for ticker in qticker_2024 if ticker is not None and len(ticker) != 5 and not any(char.isdigit() for char in ticker)]
# len(qticker_2024)

# %%
end_date = date.today().strftime('%Y-%m-%d')

# %%
import FinanceDataReader as fdr
import requests
from io import StringIO

# %%
# ===== S&P 500 데이터 가져오기 (헤더 추가 방식) =====
print("S&P 500 데이터 가져오는 중...")

# User-Agent 헤더 추가하여 Wikipedia 접근
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
}

try:
    url = 'https://en.wikipedia.org/wiki/List_of_S&P_500_companies'
    response = requests.get(url, headers=headers)

    if response.status_code == 200:
        tables = pd.read_html(StringIO(response.text))
        sp = tables[0]

        # 컬럼명 정리
        if 'Security' in sp.columns:
            sp = sp.rename(columns={'Security': 'Name'})
        if 'GICS Sector' in sp.columns:
            sp = sp.rename(columns={'GICS Sector': 'Sector'})
        if 'GICS Sub Industry' in sp.columns:
            sp = sp.rename(columns={'GICS Sub Industry': 'Industry'})

        print(f"S&P 500 데이터 로드 성공: {len(sp)}개 종목")
    else:
        print(f"S&P 500 데이터 로드 실패: HTTP {response.status_code}")
        # 샘플 데이터로 대체
        sp = pd.DataFrame({
            'Symbol': ['AAPL', 'MSFT', 'GOOGL', 'AMZN', 'TSLA', 'META', 'NVDA'],
            'Name': ['Apple Inc.', 'Microsoft Corporation', 'Alphabet Inc.', 'Amazon.com Inc.',
                     'Tesla Inc.', 'Meta Platforms Inc.', 'NVIDIA Corporation'],
            'Sector': ['Technology', 'Technology', 'Technology', 'Consumer Discretionary',
                       'Consumer Discretionary', 'Technology', 'Technology']
        })
        print("샘플 S&P 500 데이터 사용")

except Exception as e:
    print(f"S&P 500 데이터 오류: {e}")
    # 샘플 데이터로 대체
    sp = pd.DataFrame({
        'Symbol': ['AAPL', 'MSFT', 'GOOGL', 'AMZN', 'TSLA', 'META', 'NVDA'],
        'Name': ['Apple Inc.', 'Microsoft Corporation', 'Alphabet Inc.', 'Amazon.com Inc.',
                 'Tesla Inc.', 'Meta Platforms Inc.', 'NVIDIA Corporation'],
        'Sector': ['Technology', 'Technology', 'Technology', 'Consumer Discretionary',
                   'Consumer Discretionary', 'Technology', 'Technology']
    })
    print("샘플 S&P 500 데이터 사용")

# ===== 다른 거래소 데이터 가져오기 (재시도 로직 포함) =====
exchanges = ['AMEX', 'NYSE', 'NASDAQ']
exchange_data = {}

for exchange in exchanges:
    print(f"{exchange} 데이터 가져오는 중...")
    success = False

    for attempt in range(3):  # 최대 3회 시도
        try:
            data = fdr.StockListing(exchange)
            exchange_data[exchange] = data
            print(f"{exchange} 데이터 로드 성공: {len(data)}개 종목")
            success = True
            break

        except Exception as e:
            print(f"{exchange} 시도 {attempt + 1}/3 실패: {str(e)[:100]}...")
            if attempt < 2:  # 마지막 시도가 아니면 잠시 대기
                time.sleep(2)

    if not success:
        print(f"{exchange} 데이터 로드 최종 실패 - 빈 DataFrame 사용")
        exchange_data[exchange] = pd.DataFrame(columns=['Symbol', 'Name', 'Sector', 'Industry'])

# 각 거래소별 DataFrame 할당
amex = exchange_data['AMEX']
nyse = exchange_data['NYSE']
nasdaq = exchange_data['NASDAQ']

# ===== 데이터프레임 생성 =====
print("\n데이터 처리 중...")
sp500 = pd.DataFrame(sp)
amx = pd.DataFrame(amex)
nys = pd.DataFrame(nyse)
nsq = pd.DataFrame(nasdaq)

print(f"원본 데이터 크기:")
print(f"- S&P 500: {len(sp500)}")
print(f"- AMEX: {len(amx)}")
print(f"- NYSE: {len(nys)}")
print(f"- NASDAQ: {len(nsq)}")

# ===== 섹터/업종 필터링 =====
# S&P 500에서 제외할 섹터
excluded_sectors = ['Utilities', 'Financials', 'Real Estate']
if 'Sector' in sp500.columns:
    sp500_ex_fin = sp500[~sp500['Sector'].isin(excluded_sectors)].copy()
else:
    sp500_ex_fin = sp500.copy()

# 다른 거래소에서 제외할 업종
ex_industry = [
    '금융, 상품 시장 운영 및 서비스 제공', '폐쇄형 펀드', '은행', '투자 지주 회사',
    '부동산 임대, 개발 및 운영', '투자 관리 및 펀드 운영', '상업용 REITs',
    '전력 유틸리티', '특수 REITs', '주거용 REITs', '소비자 대출',
    '복합보험 및 중개인', '기업 금융 서비스', ''
]

# 업종별 필터링 (Industry 컬럼이 있는 경우만)
if 'Industry' in amx.columns:
    amx_ex_fin = amx[~amx['Industry'].isin(ex_industry)].copy()
else:
    amx_ex_fin = amx.copy()

if 'Industry' in nys.columns:
    nys_ex_fin = nys[~nys['Industry'].isin(ex_industry)].copy()
else:
    nys_ex_fin = nys.copy()

if 'Industry' in nsq.columns:
    nsq_ex_fin = nsq[~nsq['Industry'].isin(ex_industry)].copy()
else:
    nsq_ex_fin = nsq.copy()

print(f"\n필터링 후 데이터 크기:")
print(f"- S&P 500: {len(sp500_ex_fin)}")
print(f"- AMEX: {len(amx_ex_fin)}")
print(f"- NYSE: {len(nys_ex_fin)}")
print(f"- NASDAQ: {len(nsq_ex_fin)}")

# ===== 거래소 정보 추가 =====
sp500_ex_fin.loc[:, 'exchange'] = 'SP500'
amx_ex_fin.loc[:, 'exchange'] = 'AMEX'
nys_ex_fin.loc[:, 'exchange'] = 'NYSE'
nsq_ex_fin.loc[:, 'exchange'] = 'NASDAQ'

# ===== 데이터 결합 =====
# 공통 컬럼만 남기기 위해 inner join 사용
dfs_to_concat = []

# 빈 DataFrame이 아닌 것만 추가
if len(sp500_ex_fin) > 0:
    dfs_to_concat.append(sp500_ex_fin)
if len(amx_ex_fin) > 0:
    dfs_to_concat.append(amx_ex_fin)
if len(nys_ex_fin) > 0:
    dfs_to_concat.append(nys_ex_fin)
if len(nsq_ex_fin) > 0:
    dfs_to_concat.append(nsq_ex_fin)

if len(dfs_to_concat) > 0:
    try:
        filterd_df = pd.concat(dfs_to_concat, join='inner', ignore_index=True)
    except:
        # join='inner'가 실패하면 outer로 시도
        filterd_df = pd.concat(dfs_to_concat, join='outer', ignore_index=True)
else:
    filterd_df = pd.DataFrame()

print(f"최종 결합된 데이터: {len(filterd_df)}개 종목")

# ===== 티커 리스트 생성 =====
if 'Symbol' in filterd_df.columns:
    ticker_list = filterd_df['Symbol'].unique().tolist()
    # .이나 ' '을 포함하지 않은 값을 필터링
    filtered_list = [item for item in ticker_list
                    if isinstance(item, str) and '.' not in item and ' ' not in item and item.strip()]
else:
    filtered_list = []

print(f"최종 필터링된 티커 개수: {len(filtered_list)}")

# ===== 결과 확인 =====
print(f"\n처음 20개 티커: {filtered_list[:20]}")

# 데이터 샘플 확인
if len(filterd_df) > 0:
    print(f"\n결합된 데이터 샘플:")
    print(filterd_df.head())
    print(f"\n컬럼 정보:")
    print(filterd_df.columns.tolist())
else:
    print("결합된 데이터가 비어있습니다.")
# Out:
# S&P 500 데이터 가져오는 중...
# S&P 500 데이터 로드 성공: 504개 종목
# AMEX 데이터 가져오는 중...
# 100%|██████████| 294/294 [00:01<00:00, 199.82it/s]
# AMEX 데이터 로드 성공: 294개 종목
# NYSE 데이터 가져오는 중...
# 2725it [00:12, 211.90it/s]
# NYSE 데이터 로드 성공: 2725개 종목
# NASDAQ 데이터 가져오는 중...
# 100%|██████████| 3701/3701 [00:17<00:00, 217.12it/s]
# NASDAQ 데이터 로드 성공: 3701개 종목
#
# 데이터 처리 중...
# 원본 데이터 크기:
# - S&P 500: 504
# - AMEX: 294
# - NYSE: 2725
# - NASDAQ: 3701
#
# 필터링 후 데이터 크기:
# - S&P 500: 367
# - AMEX: 206
# - NYSE: 1633
# - NASDAQ: 2829
# 최종 결합된 데이터: 5035개 종목
# 최종 필터링된 티커 개수: 4542
#
# 처음 20개 티커: ['MMM', 'AOS', 'ABT', 'ABBV', 'ACN', 'ADBE', 'AMD', 'A', 'APD', 'ABNB', 'AKAM', 'ALB', 'ALGN', 'ALLE', 'GOOGL', 'GOOG', 'MO', 'AMZN', 'AMCR', 'AME']
#
# 결합된 데이터 샘플:
#   Symbol                 Name exchange
# 0    MMM                   3M    SP500
# 1    AOS          A. O. Smith    SP500
# 2    ABT  Abbott Laboratories    SP500
# 3   ABBV               AbbVie    SP500
# 4    ACN            Accenture    SP500
#
# 컬럼 정보:
# ['Symbol', 'Name', 'exchange']

# %%
prc = []
error_list = []
for ticker in tqdm(filtered_list):
    try:
        df = fdr.DataReader(ticker, '2000-01-01', '2025-07-31')
        monthly_df = df[['Close', 'Adj Close']].resample('M').last()
        # print(monthly_df.head(5))
        monthly_df['ret'] = monthly_df['Adj Close'].pct_change(1)  
        monthly_df['ticker'] = ticker
        prc.append(monthly_df)
    except: error_list.append(ticker)

prc_df = pd.concat(prc)
# Out:
#   0%|          | 0/4542 [00:00<?, ?it/s]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   0%|          | 1/4542 [00:01<1:46:54,  1.41s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   0%|          | 2/4542 [00:02<1:49:40,  1.45s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   0%|          | 3/4542 [00:04<1:50:53,  1.47s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   0%|          | 4/4542 [00:05<1:36:59,  1.28s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   0%|          | 5/4542 [00:06<1:39:48,  1.32s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   0%|          | 6/4542 [00:08<1:39:42,  1.32s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   0%|          | 7/4542 [00:09<1:36:58,  1.28s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   0%|          | 8/4542 [00:10<1:36:02,  1.27s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   0%|          | 9/4542 [00:12<1:46:13,  1.41s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   0%|          | 10/4542 [00:13<1:36:15,  1.27s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   0%|          | 11/4542 [00:14<1:40:43,  1.33s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   0%|          | 12/4542 [00:16<1:45:44,  1.40s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   0%|          | 13/4542 [00:17<1:48:46,  1.44s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   0%|          | 14/4542 [00:19<1:45:19,  1.40s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   0%|          | 15/4542 [00:20<1:48:29,  1.44s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   0%|          | 16/4542 [00:22<1:48:19,  1.44s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   0%|          | 17/4542 [00:23<1:49:42,  1.45s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   0%|          | 18/4542 [00:24<1:47:33,  1.43s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   0%|          | 19/4542 [00:26<1:42:00,  1.35s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   0%|          | 20/4542 [00:27<1:43:48,  1.38s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   0%|          | 21/4542 [00:28<1:43:01,  1.37s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   0%|          | 22/4542 [00:30<1:47:31,  1.43s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   1%|          | 23/4542 [00:31<1:49:15,  1.45s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   1%|          | 24/4542 [00:33<1:55:14,  1.53s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   1%|          | 25/4542 [00:35<1:55:11,  1.53s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   1%|          | 26/4542 [00:36<1:53:24,  1.51s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   1%|          | 27/4542 [00:37<1:43:04,  1.37s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   1%|          | 28/4542 [00:39<1:43:19,  1.37s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   1%|          | 29/4542 [00:40<1:36:30,  1.28s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   1%|          | 30/4542 [00:41<1:40:44,  1.34s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   1%|          | 31/4542 [00:42<1:40:28,  1.34s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   1%|          | 32/4542 [00:44<1:46:15,  1.41s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   1%|          | 33/4542 [00:45<1:47:11,  1.43s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   1%|          | 34/4542 [00:47<1:46:12,  1.41s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   1%|          | 35/4542 [00:48<1:43:47,  1.38s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   1%|          | 36/4542 [00:49<1:42:29,  1.36s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   1%|          | 37/4542 [00:51<1:43:53,  1.38s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   1%|          | 38/4542 [00:52<1:46:36,  1.42s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   1%|          | 39/4542 [00:54<1:47:19,  1.43s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   1%|          | 40/4542 [00:55<1:49:06,  1.45s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   1%|          | 41/4542 [00:57<1:48:15,  1.44s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   1%|          | 42/4542 [00:58<1:46:55,  1.43s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   1%|          | 43/4542 [01:00<1:47:52,  1.44s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   1%|          | 44/4542 [01:01<1:51:55,  1.49s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   1%|          | 45/4542 [01:03<1:47:57,  1.44s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   1%|          | 46/4542 [01:04<1:53:34,  1.52s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   1%|          | 47/4542 [01:06<1:52:42,  1.50s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   1%|          | 48/4542 [01:07<1:51:26,  1.49s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   1%|          | 49/4542 [01:09<1:50:09,  1.47s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   1%|          | 50/4542 [01:10<1:53:58,  1.52s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   1%|          | 51/4542 [01:12<1:49:08,  1.46s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   1%|          | 52/4542 [01:13<1:45:04,  1.40s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   1%|          | 53/4542 [01:14<1:37:04,  1.30s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   1%|          | 54/4542 [01:15<1:40:11,  1.34s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   1%|          | 55/4542 [01:17<1:45:00,  1.40s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   1%|          | 56/4542 [01:18<1:48:29,  1.45s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   1%|▏         | 57/4542 [01:20<1:47:15,  1.43s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   1%|▏         | 58/4542 [01:21<1:35:28,  1.28s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   1%|▏         | 59/4542 [01:22<1:38:34,  1.32s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   1%|▏         | 60/4542 [01:23<1:34:19,  1.26s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   1%|▏         | 61/4542 [01:25<1:37:02,  1.30s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   1%|▏         | 62/4542 [01:26<1:38:35,  1.32s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   1%|▏         | 63/4542 [01:27<1:37:30,  1.31s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   1%|▏         | 64/4542 [01:29<1:34:19,  1.26s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   1%|▏         | 65/4542 [01:30<1:32:57,  1.25s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   1%|▏         | 66/4542 [01:31<1:37:03,  1.30s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   1%|▏         | 67/4542 [01:32<1:35:02,  1.27s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   1%|▏         | 68/4542 [01:34<1:39:44,  1.34s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   2%|▏         | 69/4542 [01:35<1:41:26,  1.36s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   2%|▏         | 70/4542 [01:37<1:43:31,  1.39s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   2%|▏         | 71/4542 [01:38<1:40:48,  1.35s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   2%|▏         | 72/4542 [01:39<1:40:37,  1.35s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   2%|▏         | 73/4542 [01:41<1:46:58,  1.44s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   2%|▏         | 74/4542 [01:42<1:44:17,  1.40s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   2%|▏         | 75/4542 [01:44<1:45:33,  1.42s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   2%|▏         | 76/4542 [01:45<1:45:28,  1.42s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   2%|▏         | 77/4542 [01:47<1:44:00,  1.40s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   2%|▏         | 78/4542 [01:48<1:43:53,  1.40s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   2%|▏         | 79/4542 [01:49<1:42:45,  1.38s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   2%|▏         | 80/4542 [01:51<1:45:37,  1.42s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   2%|▏         | 81/4542 [01:52<1:45:18,  1.42s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   2%|▏         | 82/4542 [01:54<1:45:06,  1.41s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   2%|▏         | 83/4542 [01:55<1:34:26,  1.27s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   2%|▏         | 84/4542 [01:56<1:33:45,  1.26s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   2%|▏         | 85/4542 [01:57<1:38:15,  1.32s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   2%|▏         | 86/4542 [01:58<1:32:20,  1.24s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   2%|▏         | 87/4542 [02:00<1:37:53,  1.32s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   2%|▏         | 88/4542 [02:01<1:45:12,  1.42s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   2%|▏         | 89/4542 [02:03<1:46:26,  1.43s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   2%|▏         | 90/4542 [02:05<1:56:01,  1.56s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   2%|▏         | 91/4542 [02:06<1:55:58,  1.56s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   2%|▏         | 92/4542 [02:07<1:44:15,  1.41s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   2%|▏         | 93/4542 [02:09<1:43:42,  1.40s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   2%|▏         | 94/4542 [02:10<1:34:28,  1.27s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   2%|▏         | 95/4542 [02:11<1:36:51,  1.31s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   2%|▏         | 96/4542 [02:12<1:38:08,  1.32s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   2%|▏         | 97/4542 [02:14<1:36:39,  1.30s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   2%|▏         | 98/4542 [02:15<1:36:09,  1.30s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   2%|▏         | 99/4542 [02:17<1:42:28,  1.38s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   2%|▏         | 100/4542 [02:18<1:40:50,  1.36s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   2%|▏         | 101/4542 [02:19<1:35:35,  1.29s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   2%|▏         | 102/4542 [02:20<1:34:31,  1.28s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   2%|▏         | 103/4542 [02:22<1:33:54,  1.27s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   2%|▏         | 104/4542 [02:23<1:37:05,  1.31s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   2%|▏         | 105/4542 [02:24<1:28:06,  1.19s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   2%|▏         | 106/4542 [02:25<1:35:54,  1.30s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   2%|▏         | 107/4542 [02:26<1:28:12,  1.19s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   2%|▏         | 108/4542 [02:28<1:30:29,  1.22s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   2%|▏         | 109/4542 [02:30<1:44:52,  1.42s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   2%|▏         | 110/4542 [02:31<1:44:13,  1.41s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   2%|▏         | 111/4542 [02:32<1:44:59,  1.42s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   2%|▏         | 112/4542 [02:34<1:44:17,  1.41s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   2%|▏         | 113/4542 [02:35<1:44:32,  1.42s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   3%|▎         | 114/4542 [02:37<1:45:55,  1.44s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   3%|▎         | 115/4542 [02:38<1:44:53,  1.42s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   3%|▎         | 116/4542 [02:39<1:45:12,  1.43s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   3%|▎         | 117/4542 [02:41<1:46:41,  1.45s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   3%|▎         | 118/4542 [02:42<1:39:46,  1.35s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   3%|▎         | 119/4542 [02:43<1:37:21,  1.32s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   3%|▎         | 120/4542 [02:44<1:30:18,  1.23s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   3%|▎         | 121/4542 [02:46<1:35:58,  1.30s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   3%|▎         | 122/4542 [02:47<1:39:07,  1.35s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   3%|▎         | 123/4542 [02:49<1:38:26,  1.34s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   3%|▎         | 124/4542 [02:50<1:32:01,  1.25s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   3%|▎         | 125/4542 [02:51<1:33:17,  1.27s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   3%|▎         | 126/4542 [02:52<1:35:16,  1.29s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   3%|▎         | 127/4542 [02:54<1:37:43,  1.33s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   3%|▎         | 128/4542 [02:55<1:37:40,  1.33s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   3%|▎         | 129/4542 [02:56<1:39:00,  1.35s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   3%|▎         | 130/4542 [02:58<1:40:48,  1.37s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   3%|▎         | 131/4542 [02:59<1:40:10,  1.36s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   3%|▎         | 132/4542 [03:00<1:35:32,  1.30s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   3%|▎         | 133/4542 [03:02<1:39:43,  1.36s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   3%|▎         | 134/4542 [03:03<1:38:40,  1.34s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   3%|▎         | 135/4542 [03:04<1:36:16,  1.31s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   3%|▎         | 136/4542 [03:05<1:26:22,  1.18s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   3%|▎         | 137/4542 [03:06<1:19:14,  1.08s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   3%|▎         | 138/4542 [03:08<1:45:11,  1.43s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   3%|▎         | 139/4542 [03:10<1:42:20,  1.39s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   3%|▎         | 140/4542 [03:11<1:41:33,  1.38s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   3%|▎         | 141/4542 [03:13<1:48:28,  1.48s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   3%|▎         | 142/4542 [03:14<1:37:00,  1.32s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   3%|▎         | 143/4542 [03:15<1:27:46,  1.20s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   3%|▎         | 144/4542 [03:16<1:36:48,  1.32s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   3%|▎         | 145/4542 [03:17<1:34:19,  1.29s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   3%|▎         | 146/4542 [03:19<1:42:30,  1.40s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   3%|▎         | 147/4542 [03:21<1:43:40,  1.42s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   3%|▎         | 148/4542 [03:22<1:42:22,  1.40s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   3%|▎         | 149/4542 [03:23<1:45:47,  1.44s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   3%|▎         | 150/4542 [03:25<1:46:36,  1.46s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   3%|▎         | 151/4542 [03:26<1:43:11,  1.41s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   3%|▎         | 152/4542 [03:28<1:46:16,  1.45s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   3%|▎         | 153/4542 [03:29<1:45:51,  1.45s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   3%|▎         | 154/4542 [03:30<1:39:04,  1.35s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   3%|▎         | 155/4542 [03:32<1:40:34,  1.38s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   3%|▎         | 156/4542 [03:33<1:47:48,  1.47s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   3%|▎         | 157/4542 [03:35<1:42:39,  1.40s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   3%|▎         | 158/4542 [03:36<1:40:10,  1.37s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   4%|▎         | 159/4542 [03:38<1:42:58,  1.41s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   4%|▎         | 160/4542 [03:39<1:45:29,  1.44s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   4%|▎         | 161/4542 [03:41<1:50:57,  1.52s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   4%|▎         | 162/4542 [03:42<1:52:01,  1.53s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   4%|▎         | 163/4542 [03:44<1:49:51,  1.51s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   4%|▎         | 164/4542 [03:45<1:53:14,  1.55s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   4%|▎         | 165/4542 [03:47<1:53:46,  1.56s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#   4%|▎         | 166/4542 [03:49<1:54:43,  1.57s/it]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
# ...
#  99%|█████████▊| 4478/4542 [1:35:59<00:35,  1.80it/s]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#  99%|█████████▊| 4479/4542 [1:35:59<00:34,  1.82it/s]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#  99%|█████████▊| 4480/4542 [1:36:00<00:34,  1.81it/s]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#  99%|█████████▊| 4481/4542 [1:36:00<00:35,  1.74it/s]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#  99%|█████████▊| 4482/4542 [1:36:01<00:33,  1.80it/s]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#  99%|█████████▊| 4483/4542 [1:36:01<00:32,  1.81it/s]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#  99%|█████████▊| 4484/4542 [1:36:02<00:30,  1.91it/s]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#  99%|█████████▊| 4485/4542 [1:36:02<00:32,  1.74it/s]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#  99%|█████████▉| 4486/4542 [1:36:03<00:31,  1.75it/s]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#  99%|█████████▉| 4487/4542 [1:36:04<00:32,  1.70it/s]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#  99%|█████████▉| 4488/4542 [1:36:04<00:33,  1.60it/s]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#  99%|█████████▉| 4489/4542 [1:36:05<00:34,  1.54it/s]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#  99%|█████████▉| 4490/4542 [1:36:06<00:34,  1.52it/s]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#  99%|█████████▉| 4491/4542 [1:36:06<00:34,  1.49it/s]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#  99%|█████████▉| 4492/4542 [1:36:07<00:33,  1.50it/s]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#  99%|█████████▉| 4493/4542 [1:36:08<00:31,  1.54it/s]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#  99%|█████████▉| 4494/4542 [1:36:08<00:30,  1.58it/s]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#  99%|█████████▉| 4495/4542 [1:36:09<00:32,  1.47it/s]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#  99%|█████████▉| 4496/4542 [1:36:10<00:28,  1.59it/s]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#  99%|█████████▉| 4497/4542 [1:36:11<00:35,  1.28it/s]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#  99%|█████████▉| 4498/4542 [1:36:11<00:31,  1.42it/s]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#  99%|█████████▉| 4499/4542 [1:36:12<00:29,  1.46it/s]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#  99%|█████████▉| 4500/4542 [1:36:12<00:25,  1.62it/s]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#  99%|█████████▉| 4501/4542 [1:36:13<00:25,  1.63it/s]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#  99%|█████████▉| 4502/4542 [1:36:14<00:24,  1.65it/s]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#  99%|█████████▉| 4503/4542 [1:36:14<00:24,  1.59it/s]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#  99%|█████████▉| 4504/4542 [1:36:15<00:22,  1.66it/s]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#  99%|█████████▉| 4505/4542 [1:36:15<00:23,  1.59it/s]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#  99%|█████████▉| 4506/4542 [1:36:16<00:21,  1.66it/s]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#  99%|█████████▉| 4507/4542 [1:36:16<00:19,  1.77it/s]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#  99%|█████████▉| 4508/4542 [1:36:17<00:20,  1.68it/s]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#  99%|█████████▉| 4509/4542 [1:36:18<00:18,  1.76it/s]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#  99%|█████████▉| 4510/4542 [1:36:18<00:19,  1.68it/s]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#  99%|█████████▉| 4511/4542 [1:36:19<00:18,  1.72it/s]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#  99%|█████████▉| 4512/4542 [1:36:19<00:15,  1.88it/s]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#  99%|█████████▉| 4513/4542 [1:36:20<00:14,  1.96it/s]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#  99%|█████████▉| 4514/4542 [1:36:20<00:14,  1.94it/s]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#  99%|█████████▉| 4515/4542 [1:36:21<00:13,  2.02it/s]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#  99%|█████████▉| 4516/4542 [1:36:21<00:13,  1.90it/s]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#  99%|█████████▉| 4517/4542 [1:36:22<00:13,  1.79it/s]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#  99%|█████████▉| 4518/4542 [1:36:23<00:14,  1.62it/s]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
#  99%|█████████▉| 4519/4542 [1:36:24<00:20,  1.12it/s]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
# 100%|█████████▉| 4520/4542 [1:36:25<00:17,  1.28it/s]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
# 100%|█████████▉| 4521/4542 [1:36:26<00:16,  1.24it/s]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
# 100%|█████████▉| 4522/4542 [1:36:26<00:15,  1.32it/s]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
# 100%|█████████▉| 4527/4542 [1:36:29<00:07,  2.00it/s]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
# 100%|█████████▉| 4528/4542 [1:36:30<00:09,  1.41it/s]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
# 100%|█████████▉| 4529/4542 [1:36:30<00:08,  1.50it/s]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
# 100%|█████████▉| 4530/4542 [1:36:31<00:07,  1.58it/s]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
# 100%|█████████▉| 4531/4542 [1:36:32<00:06,  1.65it/s]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
# 100%|█████████▉| 4532/4542 [1:36:32<00:05,  1.72it/s]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
# 100%|█████████▉| 4533/4542 [1:36:33<00:05,  1.64it/s]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
# 100%|█████████▉| 4534/4542 [1:36:33<00:04,  1.73it/s]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
# 100%|█████████▉| 4535/4542 [1:36:34<00:03,  1.78it/s]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
# 100%|█████████▉| 4536/4542 [1:36:34<00:03,  1.90it/s]C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\2265710721.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_df = df[['Close', 'Adj Close']].resample('M').last()
# 100%|██████████| 4542/4542 [1:36:37<00:00,  1.28s/it]

# %%
prc_df['edate'] = prc_df.index
data_after_specific_date = prc_df.loc[prc_df.index >= '2000-01-01'].copy()
data_after_specific_date = data_after_specific_date.rename(columns={'Close': 'prc'})
data_after_specific_date.index.name = 'date'
prc_df_re = data_after_specific_date.reset_index()
prc_df_re['rankyear'] = prc_df_re['date'].dt.year
concated_crspm = pd.concat([crspm_re, prc_df_re])
crspm_df = concated_crspm.groupby('ticker').apply(lambda group: group.ffill().infer_objects(copy=False)) 
# 데이터 프레임의 형식 일치 

fundq_df.rename(columns={'datadate': 'edate'}, inplace=True)

# 날짜 형식 일치화
crspm_df['edate'] = pd.to_datetime(crspm_df['edate'])
fundq_df['edate'] = pd.to_datetime(fundq_df['edate'])

fundq_df['cusip'] = fundq_df['cusip'].apply(lambda x: str(x)[:7] if len(str(x)) > 7 else x)
crspm_df['cusip'] = crspm_df['cusip'].apply(lambda x: str(x)[:7] if len(str(x)) > 7 else x)
qdata = pd.merge(crspm_df, fundq_df, on=['cusip', 'edate'], how='left')
adata = pd.merge(crspm_df, funda_df, on=['cusip', 'edate'], how='left')
mdata = crspm_df
mdata['me'] = (mdata['prc'] * mdata['shrout'])/1000
# common_list = sorted(list(set(crspm_re['ticker']) & set(prc_df['ticker'])))
# Out:
# C:\Users\Hoyoung_Park\AppData\Local\Temp\ipykernel_24296\176480716.py:8: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   crspm_df = concated_crspm.groupby('ticker').apply(lambda group: group.ffill().infer_objects(copy=False))

# %%
mdata = mdata[~mdata['permno'].isna()].copy()
qdata = qdata[~qdata['permno'].isna()].copy()

mdata['permno'] = mdata['permno'].astype('int')
qdata['permno'] = qdata['permno'].astype('int')

qdata['siccd'] = qdata['siccd'].apply(lambda x: np.nan if np.isnan(x) else int(x))

# 한국, 미국데이터 공통 전처리

util_and_fin = list(range(4900, 4950)) + list(range(6000, 7000)) # 유틸리티, 금융업 제외 (한국은 금융업만 제외)
qdata = qdata[~qdata['siccd'].isin(util_and_fin)]

permno_list = sorted(list(set(mdata['permno']) & set(qdata['permno'])))
print(len(permno_list))

mdata = mdata[mdata['permno'].isin(permno_list)].copy()
qdata = qdata[qdata['permno'].isin(permno_list)].copy()

# naics	코드에서 상업은행 제외 14943
mdata = mdata[mdata['naics'] != 522110]
qdata = qdata[qdata['naics'] != 522110]

dates = pd.to_datetime(mdata['date'].sort_values().unique())

qdata = qdata[~np.isnan(qdata['date'])]
# Out:
# 10687

# %%
# 주요 데이터
# ret은 수정주가 수익률
# Set option to opt into future behavior
# pd.set_option('future.no_silent_downcasting', True)

ret = mdata.pivot_table(index='date', columns='permno', values='ret').astype('float')
shrout = mdata.pivot_table(index='date', columns='permno', values='shrout').astype('float')

prc = abs(mdata.pivot_table(index='date', columns='permno', values='prc').astype('float'))
prc_jun = prc.loc[[x for x in prc.index if x.month % 3 == 0]].reindex(prc.index).ffill(limit=2).dropna(how='all')

me = prc * shrout / 1000
me = me[me > 0]

me_jun = me.loc[[x for x in me.index if x.month % 3 == 0]].reindex(me.index).ffill(limit=2).dropna(how='all')
# me_dec = me.shift(6).loc[[x for x in me.index if x.month == 6]].reindex(me.index).fillna(method='ffill', limit=11).dropna(how='all')

adata['be'] = adata['at'] - adata['lt']
be = adata.pivot_table(index='date', columns='permno', values='be').astype('float')
be_jun = be.loc[[x for x in be.index if x.month % 3 == 0]].reindex(be.index).ffill(limit=2).dropna(how='all')

market = mdata.pivot_table(index='date', columns='permno', values='exchcd', aggfunc=lambda x: x)
market_jun = market.loc[[x for x in be.index if x.month % 3 == 0]].reindex(be.index).ffill(limit=2).dropna(how='all')

# 예시: 데이터프레임이 혼합된 타입을 가지고 있을 경우
market = market.apply(pd.to_numeric, errors='coerce')
# NaN 값을 유지하면서 Int64 타입으로 변환
market = market.astype('Int64')

# 주가 수익률의 정확한 계산을 위한 수정주가 import and 수익률 계산

prc_bool = prc_jun > 5 # 미국 주식의 경우 prc_jun > 5
nyse_bool = (market == 1) |( market == 2) | (market == 3)
be_bool = be_jun > 0

me_nyse_criteria = me_jun[nyse_bool].apply(lambda x: np.nanpercentile(x, 5), axis=1)
me_bool = me_jun.ge(me_nyse_criteria, axis=0)
universe_bool = prc_bool & be_bool & me_bool

ret.replace([np.inf, -np.inf], np.nan, inplace=True)
ri = (1 + ret).cumprod()

qdata_fill = qdata.ffill(limit=2)

# %%
qdata_fill = qdata_fill.ffill(limit=1)
qdata_fill.tail(12)
# Out:
#          permno      edate       date     dlret    dlretx  exchcd   naics  \
# 3498696   91205 2012-04-30 2012-04-30      <NA>      <NA>       1  337910
# 3498697   91205 2012-05-31 2012-05-31      <NA>      <NA>       1  337910
# 3498698   91205 2012-06-30 2012-06-29      <NA>      <NA>       1  337910
# 3498699   91205 2012-07-31 2012-07-31      <NA>      <NA>       1  337910
# 3498700   91205 2012-08-31 2012-08-31      <NA>      <NA>       1  337910
# 3498701   91205 2012-09-30 2012-09-28      <NA>      <NA>       1  337910
# 3498702   91205 2012-10-31 2012-10-31      <NA>      <NA>       1  337910
# 3498703   91205 2012-11-30 2012-11-30      <NA>      <NA>       1  337910
# 3498704   91205 2012-12-31 2012-12-31      <NA>      <NA>       1  337910
# 3498705   91205 2013-01-31 2013-01-31      <NA>      <NA>       1  337910
# 3498706   91205 2013-02-28 2013-02-28      <NA>      <NA>       1  337910
# 3498707   91205 2013-03-31 2013-03-28  0.009174  0.009174       1  337910
#
#          permco   prc       ret  ...  xrdq    xsgaq   capxy  chechy dlcchy  \
# 3498696   50616  2.06  0.019802  ...  <NA>  100.124   3.822 -10.051   <NA>
# 3498697   50616  1.68 -0.184466  ...  <NA>  106.498   6.641 -26.774   <NA>
# 3498698   50616  1.85  0.101191  ...  <NA>  106.498   6.641 -26.774   <NA>
# 3498699   50616  1.67 -0.097297  ...  <NA>  106.498   6.641 -26.774   <NA>
# 3498700   50616   1.6 -0.041916  ...  <NA>  120.369  10.011 -19.142   <NA>
# 3498701   50616  2.18    0.3625  ...  <NA>  120.369  10.011 -19.142   <NA>
# 3498702   50616  2.23  0.022936  ...  <NA>  120.369  10.011 -19.142   <NA>
# 3498703   50616  2.17 -0.026906  ...  <NA>  124.358  15.914  20.179   <NA>
# 3498704   50616  2.17       0.0  ...  <NA>  124.358  15.914  20.179   <NA>
# 3498705   50616  2.16 -0.004608  ...  <NA>  124.358  15.914  20.179   <NA>
# 3498706   50616  2.18  0.009259  ...  <NA>  124.358  15.914  20.179   <NA>
# 3498707   50616  2.18  0.009259  ...  <NA>     <NA>    <NA>    <NA>   <NA>
#
#          dltisy  fincfy  oancfy  prstkcy  sstky
# 3498696   0.702 -10.537   1.372     0.01    0.0
# 3498697   1.525 -37.635  13.857    0.188  0.046
# 3498698   1.525 -37.635  13.857    0.188  0.046
# 3498699   1.525 -37.635  13.857    0.188  0.046
# 3498700   1.269 -47.753  31.402    2.905  0.062
# 3498701   1.269 -47.753  31.402    2.905  0.062
# 3498702   1.269 -47.753  31.402    2.905  0.062
# 3498703   5.236 -46.123  82.108    3.059  0.104
# 3498704   5.236 -46.123  82.108    3.059  0.104
# 3498705   5.236 -46.123  82.108    3.059  0.104
# 3498706   5.236 -46.123  82.108    3.059  0.104
# 3498707    <NA>    <NA>    <NA>     <NA>   <NA>
#
# [12 rows x 66 columns]

# %%
qdata_fill[qdata_fill['ticker'] == 'NSC'][['date','saleq', 'niq']].head(12)
# Out:
#               date   saleq    niq
# 2187792 2004-06-30  1813.0  213.0
# 2187793 2004-07-30  1813.0  213.0
# 2187794 2004-08-31  1813.0  213.0
# 2187795 2004-09-30  1857.0  288.0
# 2187796 2004-10-29  1857.0  288.0
# 2187797 2004-11-30  1857.0  288.0
# 2187798 2004-12-31  1949.0  264.0
# 2187799 2005-01-31  1949.0  264.0
# 2187800 2005-02-28  1949.0  264.0
# 2187801 2005-03-31  1961.0  194.0
# 2187802 2005-04-29  1961.0  194.0
# 2187803 2005-05-31  1961.0  194.0

# %%
# 저장 경로
save_path = fr"C:\Users\Hoyoung_Park\PyCharmMiscProject\stock_forecast\DATA"
os.makedirs(save_path, exist_ok=True)

# 파일 저장
# adata : 년간 데이터 
# mdata : 월간 데이터 
# qdata_fill : 분기 데이터 (월간 주기)
# fundq_df :  분기 데이터 (분기 주기) 
# adata.to_csv(os.path.join(save_path, f"adata_{end_date}.csv"), index=False)
# mdata.to_csv(os.path.join(save_path, f"mdata_{end_date}.csv"), index=False)
qdata_fill.to_csv(os.path.join(save_path, f"qdata_{end_date}.csv"), index=False)
fundq_df.to_csv(os.path.join(save_path, f"fundq_{end_date}.csv"), index=False)

# %%
fundq_df
# Out:
#          gvkey      edate     tic    cusip      actq       aoq       apq  \
# 0       001013 2000-01-31  ADCT.1  0008863  1137.412   333.830   103.291
# 1       001082 2000-01-31  SERV.1  81765M1    39.941     8.971    13.077
# 2       001173 2000-01-31   AIM.1  0080153    17.435     0.877     1.968
# 3       001183 2000-01-31   IDAI.  45169P1       NaN     8.982     0.632
# 4       001189 2000-01-31   AGR.7  0084895   454.479   125.407       NaN
# ...        ...        ...     ...      ...       ...       ...       ...
# 166436  260849 2025-04-30     UTG  7561581       NaN       NaN       NaN
# 166437  260850 2025-04-30     SCD  50208A1       NaN       NaN       NaN
# 166438  264645 2025-04-30     CSQ  1281251       NaN       NaN       NaN
# 166439  339965 2025-04-30    SNOW  8334451  4785.974  2819.130   155.263
# 166440  023809 2025-05-31     AZO  0533321  7985.711       NaN  7887.417
#
#               atq      ceqq      cheq  ...     xrdq     xsgaq   capxy  \
# 0        1814.519  1396.005   364.315  ...   75.200   205.600  46.785
# 1         110.675    21.270     4.440  ...      NaN     2.169   9.597
# 2          22.774    12.644     0.964  ...    0.801     1.839   0.558
# 3         103.962    83.879    54.333  ...      NaN       NaN   1.091
# 4         839.170   363.297       NaN  ...      NaN       NaN  17.181
# ...           ...       ...       ...  ...      ...       ...     ...
# 166436        NaN       NaN       NaN  ...      NaN       NaN     NaN
# 166437        NaN       NaN       NaN  ...      NaN       NaN     NaN
# 166438        NaN       NaN       NaN  ...      NaN       NaN     NaN
# 166439   8157.407  2408.000  3910.684  ...  472.404  1024.073  44.989
# 166440  18621.983 -3974.405       NaN  ...    0.000  1487.349     NaN
#
#          chechy  dlcchy  dltisy   fincfy    oancfy  prstkcy   sstky
# 0        21.138     NaN     NaN   16.289    41.582    0.000  42.657
# 1        -2.956  -7.367   9.503   -4.911     5.032    0.000   0.000
# 2        -0.754   0.174   1.974    0.528    -0.724    0.542   0.000
# 3        22.224   0.000   0.000   -2.582   -18.925    2.582     NaN
# 4       -12.630     NaN  38.728   32.244   -21.550    0.000   0.000
# ...         ...     ...     ...      ...       ...      ...     ...
# 166436      NaN     NaN     NaN      NaN       NaN      NaN     NaN
# 166437      NaN     NaN     NaN      NaN       NaN      NaN     NaN
# 166438      NaN     NaN     NaN      NaN       NaN      NaN     NaN
# 166439 -379.270   0.000   0.000 -564.057   228.373  623.136  59.453
# 166440      NaN     NaN     NaN      NaN  2164.582      NaN     NaN
#
# [1166441 rows x 49 columns]

# %%
#Accounting variables

#Income statement
sale = get_adata_quarter(qdata_fill, 'saleq')
cogs = get_adata_quarter(qdata_fill, 'cogsq')
gp = sale - cogs
xsga = get_adata_quarter(qdata_fill, 'xsgaq')
# xad = get_adata_annual(adata, 'XAD')
xrd = get_adata_quarter(qdata_fill, 'xrdq')
# xlr = get_adata_annual(adata, 'XLR')
# opex = get_adata_annual(adata, 'XOPR')
# ebitda = get_adata_quarter(adata, 'ebitda')
# ebit = get_adata_quarter(adata, 'ebit')
xint = get_adata_quarter(qdata_fill, 'xintq')
op = get_adata_quarter(qdata_fill, 'xintq')
# ope = ebitda - xint.replace(np.nan, 0)
pi = get_adata_quarter(qdata_fill, 'piq')   # pretax income
tax = get_adata_quarter(qdata_fill, 'txtq')  # income tax
xido = get_adata_quarter(qdata_fill, 'xidoq')# extraordinary item and discontinue
ni = get_adata_quarter(qdata_fill, 'ibq')
nix = get_adata_quarter(qdata_fill, 'niq')
fi = nix + xint.replace(np.nan, 0)
# dvc = get_adata_quarter(adata, 'dvc')
# div = get_adata_annual(adata, 'dvt')


#Cash flow statement
capx = get_adata_quarter(qdata_fill, 'capxy') # capex
capex_sale = capx.divide(sale.replace(0, np.nan), axis=0)
ocf = get_adata_quarter(qdata_fill, 'oancfy')
fcf = ocf - capx
eqbb = get_adata_quarter(qdata_fill, 'prstkcy') # 자사주 매입
eqis = get_adata_quarter(qdata_fill, 'sstky')   # 자사주 매각
eqnetis = eqis.replace(np.nan, 0) - eqbb.replace(np.nan, 0)
# eqpo = div.replace(np.nan, 0) + eqbb.replace(np.nan, 0)
# eqnpo = div - eqnetis

dltnetis = get_adata_quarter(qdata_fill, 'dltisy') # 장기채권 발행
dstnetis = get_adata_quarter(qdata_fill, 'dlcchy') # 유동채권 변화
dbnetis = dltnetis - dstnetis
netis = eqnetis.replace(np.nan, 0) + dbnetis.replace(np.nan, 0)
# fincf = get_adata_annual(adata, 'fincf')


# Balance Sheet - Assets
at = get_adata_quarter(qdata_fill, 'atq') # 분기 자산
at = at[at > 0]
ca = get_adata_quarter(qdata_fill, 'actq')  # 분기 유동자산
rec = get_adata_quarter(qdata_fill, 'rectq') # receivables
cash = get_adata_quarter(qdata_fill, 'cheq') # 현금
inv = get_adata_quarter(qdata_fill, 'invtq') # inventory
nca = at - ca
intan = get_adata_quarter(qdata_fill, 'intanq') #무형자산
ivao = get_adata_quarter(qdata_fill, 'ivaoq') # investment
ppeg = get_adata_quarter(qdata_fill, 'ppegtq') # porperty plant and Equipment total
ppen = get_adata_quarter(qdata_fill, 'ppentq') # porperty plant and Equipment net

# #Balance Sheet - Liabilities
lt = get_adata_quarter(qdata_fill, 'ltq')  # 총부채
cl = get_adata_quarter(qdata_fill, 'lctq') # 유동부채
ap = get_adata_quarter(qdata_fill, 'atq')  # asset total
debtst = get_adata_quarter(qdata_fill, 'dlcq') # Debt in current liability
txp = get_adata_quarter(qdata_fill, 'txpq')    # Income taxes payable
ncl = lt - cl
debtlt = get_adata_quarter(qdata_fill, 'dltisy')  # long term debt total
txditc = get_adata_quarter(qdata_fill, 'txdiq') #  Income Taxes - Deferred (txdiq)

# #Balance Sheet - Financing
pstk = get_adata_quarter(qdata_fill, 'pstkrq') # 상환우선주
debt = (debtst.replace(np.nan, 0) + debtlt.replace(np.nan, 0)).replace(0, np.nan)
netdebt = debt - cash.replace(np.nan, 0)

seq = get_adata_quarter(qdata_fill, 'seqq')  # share holder equity
ceq = get_adata_quarter(qdata_fill, 'ceqq')  # common equit

# be = ceq + txditc.replace(np.nan, 0)
# be = be[be > 0]
icapt = get_adata_quarter(qdata_fill, 'icaptq') # invested capital
mib = get_adata_quarter(qdata_fill, 'mibtq')      # Noncontrolling Interests - Total - Balance Sheet (mibtq)
bev = icapt + debtst.replace(np.nan, 0) - cash.replace(np.nan, 0)
bev = bev[bev > 0]
# 
#Balance Sheet - Summary
nwc = ca - cl
coa = ca - cash
col = cl - debtst.replace(np.nan, 0)
cowc = coa - col
ncoa = at - ca - ivao
ncol = lt - cl - debtlt
nncoa = ncoa - ncol

# ivst = get_data(adata, 'IVST')

# fna = ivst.replace(np.nan, 0) + ivao.replace(np.nan, 0)
# fnl = debt + pstk.replace(np.nan, 0)
# nfna = fna - fnl
oa = coa + ncoa
ol = col + ncol
ao = get_adata_quarter(qdata_fill, 'aoq')# asset other
lo = get_adata_quarter(qdata_fill, 'loq')  # liabilities other
dp = get_adata_quarter(qdata_fill, 'dpq')
noa = oa - ol
lnoa = ppen + intan + ao - lo + dp
# invt = get_adata_annual(adata, 'invt')
# caliq = ca - invt
# ppeinv = ppen + invt
aliq = cash + 0.75*coa + 0.5*(at - ca - intan.replace(np.nan, 0))

be = at - lt
be = be[be > 0]

roeq = ni.divide(be.replace(0, np.nan), axis=0)
roaq = ni.divide(at.replace(0, np.nan), axis=0)

#Market based
oacc = ni - ocf
# tacc = oacc + nfna.diff(12)
# ocf_qtr = get_adata_annual(adata, 'oancfq')
# cop = ebitda + xrd.replace(np.nan, 0) - oacc
# emp = get_adata_annual(adata, 'emp')

mev = me + netdebt
mev = mev[mev > 0]
mev_jun = mev.loc[[x for x in mev.index if x.month == 6]].reindex(mev.index).ffill(limit=11).dropna(how='all')

#Accounting Characteristics

##Accounting based size measures
assets = at
sales = sale
book_equity = be
net_income = ni
enterprise_value = mev
mat = at + be + me
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 4
#       1 #Accounting variables
#       2
#       3 #Income statement
# ----> 4 sale = get_adata_quarter(qdata_fill, 'saleq')
#       5 cogs = get_adata_quarter(qdata_fill, 'cogsq')
#       6 gp = sale - cogs
#
# NameError: name 'get_adata_quarter' is not defined

# %%
me_quantile =  me_jun.iloc[1:].apply(lambda x: get_quantile(x, universe_bool, 10), axis=1)
roeq_quantile = roeq.iloc[1:].apply(lambda x: get_quantile(x, universe_bool, 5), axis=1)
roaq_quantile = roaq.iloc[1:].apply(lambda x: get_quantile(x, universe_bool, 5), axis=1)

start_year = '2001'
# eq_data = me.applymap(lambda x: np.nan if np.isnan(x) else 1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 me_quantile =  me_jun.iloc[1:].apply(lambda x: get_quantile(x, universe_bool, 10), axis=1)
#       2 roeq_quantile = roeq.iloc[1:].apply(lambda x: get_quantile(x, universe_bool, 5), axis=1)
#       3 roaq_quantile = roaq.iloc[1:].apply(lambda x: get_quantile(x, universe_bool, 5), axis=1)
#
# NameError: name 'me_jun' is not defined

# %%
me_quantile.head(3)
# Out:
# permno      10026  10028  10032  10044  10051  10066  10104  10107  10145  \
# date
# 2020-04-30   10.0   10.0   10.0   10.0   10.0    NaN   10.0   10.0   10.0
# 2020-05-29   10.0   10.0   10.0   10.0   10.0    NaN   10.0   10.0   10.0
# 2020-06-30   10.0   10.0   10.0   10.0   10.0    NaN   10.0   10.0   10.0
#
# permno      10158  ...  93384  93393  93397  93401  93420  93422  93423  \
# date               ...
# 2020-04-30   10.0  ...   10.0   10.0   10.0   10.0   10.0   10.0   10.0
# 2020-05-29   10.0  ...   10.0   10.0   10.0   10.0   10.0   10.0   10.0
# 2020-06-30   10.0  ...    NaN   10.0   10.0   10.0   10.0   10.0   10.0
#
# permno      93426  93434  93436
# date
# 2020-04-30   10.0   10.0   10.0
# 2020-05-29   10.0   10.0   10.0
# 2020-06-30   10.0   10.0   10.0
#
# [3 rows x 4318 columns]

# %%
me_jun
# Out:
# permno            10026       10028        10032      10044      10051  \
# date
# 2020-03-31  2285.448000   67.848480  1601.608800  29.112000  583.14382
# 2020-04-30  2285.448000   67.848480  1601.608800  29.112000  583.14382
# 2020-05-29  2285.448000   67.848480  1601.608800  29.112000  583.14382
# 2020-06-30  2401.231440  164.236400  2059.364160  25.776250  625.85208
# 2020-07-31  2401.231440  164.236400  2059.364160  25.776250  625.85208
# 2020-08-31  2401.231440  164.236400  2059.364160  25.776250  625.85208
# 2020-09-30  2466.326850  115.503960  2065.644980  16.259560  602.75782
# 2020-10-30  2466.326850  115.503960  2065.644980  16.259560  602.75782
# 2020-11-30  2466.326850  115.503960  2065.644980  16.259560  602.75782
# 2020-12-31  2945.193720  140.010000  2249.788860  24.587550  838.01691
# 2021-01-29  2945.193720  140.010000  2249.788860  24.587550  838.01691
# 2021-02-26  2945.193720  140.010000  2249.788860  24.587550  838.01691
# 2021-03-31  2988.909020  135.163500  2646.736960  32.273480  870.53736
# 2021-04-30  2988.909020  135.163500  2646.736960  32.273480  870.53736
# 2021-05-28  2988.909020  135.163500  2646.736960  32.273480  870.53736
# 2021-06-30  3324.429010  129.240000  2613.777540  46.726120  974.31648
# 2021-07-30  3324.429010  129.240000  2613.777540  46.726120  974.31648
# 2021-08-31  3324.429010  129.240000  2613.777540  46.726120  974.31648
# 2021-09-30  2916.417071  112.008000  2525.832500  45.317600  849.63240
# 2021-10-29  2916.417071  112.008000  2525.832500  45.317600  849.63240
# 2021-11-30  2916.417071  112.008000  2525.832500  45.317600  849.63240
# 2021-12-31  3015.298631  109.584750  2684.632330  48.489450  701.79417
# 2022-01-31  3015.298631  109.584750  2684.632330  48.489450  701.79417
# 2022-02-28  3015.298631  109.584750  2684.632330  48.489450  701.79417
# 2022-03-31  2973.732492  125.470500  2298.615570  46.938350  709.66428
# 2022-04-29  2973.732492  125.470500  2298.615570  46.938350  709.66428
# 2022-05-31  2973.732492  125.470500  2298.615570  46.938350  709.66428
# 2022-06-30  2679.237440  191.975250  2176.255500  42.835130  558.89528
# 2022-07-29  2679.237440  191.975250  2176.255500  42.835130  558.89528
# 2022-08-31  2679.237440  191.975250  2176.255500  42.835130  558.89528
# 2022-09-30  2488.283930  136.240500  2423.573240  37.400230  732.38256
# 2022-10-31  2488.283930  136.240500  2423.573240  37.400230  732.38256
# 2022-11-30  2488.283930  136.240500  2423.573240  37.400230  732.38256
# 2022-12-30  2878.773782  141.625500  2851.366860  35.562300        NaN
# 2023-01-31  2878.773782  141.625500  2851.366860  35.562300        NaN
# 2023-02-28  2878.773782  141.625500  2851.366860  35.562300        NaN
# 2023-03-31  2853.531440  175.012500  2697.517790  33.162100        NaN
# 2023-04-28  2853.531440  175.012500  2697.517790  33.162100        NaN
# 2023-05-31  2853.531440  175.012500  2697.517790  33.162100        NaN
# 2023-06-30  3051.597200  198.168000  2701.403520  33.715700        NaN
# 2023-07-31  3051.597200  198.168000  2701.403520  33.715700        NaN
# 2023-08-31  3051.597200  198.168000  2701.403520  33.715700        NaN
# 2023-09-29  3163.681607  127.491780  2553.788680  29.988000        NaN
# 2023-10-31  3163.681607  127.491780  2553.788680  29.988000        NaN
# 2023-11-30  3163.681607  127.491780  2553.788680  29.988000        NaN
# 2023-12-29  3232.821880  129.762000  2974.007520  28.989200        NaN
# 2024-01-31  3232.821880  129.762000  2974.007520  28.989200        NaN
# 2024-02-29  3232.821880  129.762000  2974.007520  28.989200        NaN
# 2024-03-31  2796.079473  123.353997  2607.929272  22.813239        NaN
# 2024-04-30  2796.079473  123.353997  2607.929272  22.813239        NaN
# 2024-05-31  2796.079473  123.353997  2607.929272  22.813239        NaN
# 2024-06-30  3140.560446  119.882994  2837.862728  13.864400        NaN
# 2024-07-31  3140.560446  119.882994  2837.862728  13.864400        NaN
# 2024-08-31  3140.560446  119.882994  2837.862728  13.864400        NaN
# 2024-09-30  3329.144946  146.316001  3760.072025  12.604000        NaN
#
# permno           10066          10104         10107          10145  \
# date
# 2020-03-31         NaN  152412.714720  1.197019e+06   94627.920657
# 2020-04-30         NaN  152412.714720  1.197019e+06   94627.920657
# 2020-05-29         NaN  152412.714720  1.197019e+06   94627.920657
# 2020-06-30         NaN  169606.054140  1.540774e+06  101480.202320
# 2020-07-31         NaN  169606.054140  1.540774e+06  101480.202320
# 2020-08-31         NaN  169606.054140  1.540774e+06  101480.202320
# 2020-09-30         NaN  179750.013600  1.590936e+06  115520.499630
# 2020-10-30         NaN  179750.013600  1.590936e+06  115520.499630
# 2020-11-30         NaN  179750.013600  1.590936e+06  115520.499630
# 2020-12-31         NaN  190449.559460  1.678381e+06  149248.612200
# 2021-01-29         NaN  190449.559460  1.678381e+06  149248.612200
# 2021-02-26         NaN  190449.559460  1.678381e+06  149248.612200
# 2021-03-31  251.503000  202337.650950  1.776291e+06  150972.409025
# 2021-04-30  251.503000  202337.650950  1.776291e+06  150972.409025
# 2021-05-28  251.503000  202337.650950  1.776291e+06  150972.409025
# 2021-06-30  106.280300  217329.280000  2.036897e+06  151439.027554
# 2021-07-30  106.280300  217329.280000  2.036897e+06  151439.027554
# 2021-08-31  106.280300  217329.280000  2.036897e+06  151439.027554
# 2021-09-30   84.172440  238186.061180  2.116626e+06  146138.434440
# 2021-10-29   84.172440  238186.061180  2.116626e+06  146138.434440
# 2021-11-30   84.172440  238186.061180  2.116626e+06  146138.434440
# 2021-12-31   50.665780  232889.682870  2.525084e+06  143000.112832
# 2022-01-31   50.665780  232889.682870  2.525084e+06  143000.112832
# 2022-02-28   50.665780  232889.682870  2.525084e+06  143000.112832
# 2022-03-31   46.202090  220736.628610  2.307084e+06  132457.027140
# 2022-04-29   46.202090  220736.628610  2.307084e+06  132457.027140
# 2022-05-31   46.202090  220736.628610  2.307084e+06  132457.027140
# 2022-06-30   37.069827  186198.379620  1.916979e+06  117094.406520
# 2022-07-29   37.069827  186198.379620  1.916979e+06  117094.406520
# 2022-08-31   37.069827  186198.379620  1.916979e+06  117094.406520
# 2022-09-30   34.117280  164623.528710  1.736735e+06  112257.604340
# 2022-10-31   34.117280  164623.528710  1.736735e+06  112257.604340
# 2022-11-30   34.117280  164623.528710  1.736735e+06  112257.604340
# 2022-12-30   52.556640  220391.720220  1.785940e+06  143066.680000
# 2023-01-31   52.556640  220391.720220  1.785940e+06  143066.680000
# 2023-02-28   52.556640  220391.720220  1.785940e+06  143066.680000
# 2023-03-31   58.684320  250865.601840  2.144087e+06  127224.188240
# 2023-04-28   58.684320  250865.601840  2.144087e+06  127224.188240
# 2023-05-31   58.684320  250865.601840  2.144087e+06  127224.188240
# 2023-06-30   43.954320  323241.104310  2.530893e+06  137771.907500
# 2023-07-31   43.954320  323241.104310  2.530893e+06  137771.907500
# 2023-08-31   43.954320  323241.104310  2.530893e+06  137771.907500
# 2023-09-29   37.708800  290154.705920  2.345717e+06  121790.036333
# 2023-10-31   37.708800  290154.705920  2.345717e+06  121790.036333
# 2023-11-30   37.708800  290154.705920  2.345717e+06  121790.036333
# 2023-12-29   39.947760  289818.846460  2.794828e+06  138251.533803
# 2024-01-31   39.947760  289818.846460  2.794828e+06  138251.533803
# 2024-02-29   39.947760  289818.846460  2.794828e+06  138251.533803
# 2024-03-31   35.234160  345292.094098  3.126901e+06  135311.267750
# 2024-04-30   35.234160  345292.094098  3.126901e+06  135311.267750
# 2024-05-31   35.234160  345292.094098  3.126901e+06  135311.267750
# 2024-06-30   42.775921  388147.778011  3.321850e+06  140776.454114
# 2024-07-31   42.775921  388147.778011  3.321850e+06  140776.454114
# 2024-08-31   42.775921  388147.778011  3.321850e+06  140776.454114
# 2024-09-30   53.970719  468416.292022  3.198102e+06  136273.778636
#
# permno            10158  ...     93384       93393      93397      93401  \
# date                     ...
# 2020-03-31   500.341400  ...  96.62715   252.69196  233.93980  204.27984
# 2020-04-30   500.341400  ...  96.62715   252.69196  233.93980  204.27984
# 2020-05-29   500.341400  ...  96.62715   252.69196  233.93980  204.27984
# 2020-06-30   819.787800  ...       NaN  1039.89403  258.76242  260.90127
# 2020-07-31   819.787800  ...       NaN  1039.89403  258.76242  260.90127
# 2020-08-31   819.787800  ...       NaN  1039.89403  258.76242  260.90127
# 2020-09-30   992.881800  ...       NaN  1012.26120  254.76880  171.08280
# 2020-10-30   992.881800  ...       NaN  1012.26120  254.76880  171.08280
# 2020-11-30   992.881800  ...       NaN  1012.26120  254.76880  171.08280
# 2020-12-31  1560.199840  ...       NaN  1050.61600  293.95575  225.60000
# 2021-01-29  1560.199840  ...       NaN  1050.61600  293.95575  225.60000
# 2021-02-26  1560.199840  ...       NaN  1050.61600  293.95575  225.60000
# 2021-03-31  1471.203390  ...       NaN  1746.75540  309.48750        NaN
# 2021-04-30  1471.203390  ...       NaN  1746.75540  309.48750        NaN
# 2021-05-28  1471.203390  ...       NaN  1746.75540  309.48750        NaN
# 2021-06-30  2086.694400  ...       NaN         NaN  310.37175        NaN
# 2021-07-30  2086.694400  ...       NaN         NaN  310.37175        NaN
# 2021-08-31  2086.694400  ...       NaN         NaN  310.37175        NaN
# 2021-09-30  1950.919270  ...       NaN         NaN  285.96645        NaN
# 2021-10-29  1950.919270  ...       NaN         NaN  285.96645        NaN
# 2021-11-30  1950.919270  ...       NaN         NaN  285.96645        NaN
# 2021-12-31  2733.044960  ...       NaN         NaN  265.50000        NaN
# 2022-01-31  2733.044960  ...       NaN         NaN  265.50000        NaN
# 2022-02-28  2733.044960  ...       NaN         NaN  265.50000        NaN
# 2022-03-31  2681.058000  ...       NaN         NaN  259.42496        NaN
# 2022-04-29  2681.058000  ...       NaN         NaN  259.42496        NaN
# 2022-05-31  2681.058000  ...       NaN         NaN  259.42496        NaN
# 2022-06-30  1540.338040  ...       NaN         NaN  249.70298        NaN
# 2022-07-29  1540.338040  ...       NaN         NaN  249.70298        NaN
# 2022-08-31  1540.338040  ...       NaN         NaN  249.70298        NaN
# 2022-09-30  2249.284320  ...       NaN         NaN  233.57596        NaN
# 2022-10-31  2249.284320  ...       NaN         NaN  233.57596        NaN
# 2022-11-30  2249.284320  ...       NaN         NaN  233.57596        NaN
# 2022-12-30  1937.845960  ...       NaN         NaN  215.92164        NaN
# 2023-01-31  1937.845960  ...       NaN         NaN  215.92164        NaN
# 2023-02-28  1937.845960  ...       NaN         NaN  215.92164        NaN
# 2023-03-31  1670.920560  ...       NaN         NaN  297.06446        NaN
# 2023-04-28  1670.920560  ...       NaN         NaN  297.06446        NaN
# 2023-05-31  1670.920560  ...       NaN         NaN  297.06446        NaN
# 2023-06-30  1659.304230  ...       NaN         NaN  279.75324        NaN
# 2023-07-31  1659.304230  ...       NaN         NaN  279.75324        NaN
# 2023-08-31  1659.304230  ...       NaN         NaN  279.75324        NaN
# 2023-09-29  1318.790560  ...       NaN         NaN  275.43828        NaN
# 2023-10-31  1318.790560  ...       NaN         NaN  275.43828        NaN
# 2023-11-30  1318.790560  ...       NaN         NaN  275.43828        NaN
# 2023-12-29  1084.222450  ...       NaN         NaN  371.21622        NaN
# 2024-01-31  1084.222450  ...       NaN         NaN  371.21622        NaN
# 2024-02-29  1084.222450  ...       NaN         NaN  371.21622        NaN
# 2024-03-31   826.090521  ...       NaN         NaN  351.96263        NaN
# 2024-04-30   826.090521  ...       NaN         NaN  351.96263        NaN
# 2024-05-31   826.090521  ...       NaN         NaN  351.96263        NaN
# 2024-06-30   986.310332  ...       NaN         NaN  374.45513        NaN
# 2024-07-31   986.310332  ...       NaN         NaN  374.45513        NaN
# 2024-08-31   986.310332  ...       NaN         NaN  374.45513        NaN
# 2024-09-30  1298.875853  ...       NaN         NaN  476.84100        NaN
#
# permno          93420       93422       93423       93426       93434  \
# date
# 2020-03-31  113.44375   81.009879  1061.59878  251.220880   68.465900
# 2020-04-30  113.44375   81.009879  1061.59878  251.220880   68.465900
# 2020-05-29  113.44375   81.009879  1061.59878  251.220880   68.465900
# 2020-06-30  240.73800  312.414780  1626.83727  308.331520   76.227240
# 2020-07-31  240.73800  312.414780  1626.83727  308.331520   76.227240
# 2020-08-31  240.73800  312.414780  1626.83727  308.331520   76.227240
# 2020-09-30   89.87300  218.771010  1720.66860  317.816640   82.958480
# 2020-10-30   89.87300  218.771010  1720.66860  317.816640   82.958480
# 2020-11-30   89.87300  218.771010  1720.66860  317.816640   82.958480
# 2020-12-31        NaN  580.617040  2897.71570  395.136960  100.103450
# 2021-01-29        NaN  580.617040  2897.71570  395.136960  100.103450
# 2021-02-26        NaN  580.617040  2897.71570  395.136960  100.103450
# 2021-03-31        NaN  834.427040  3965.79627  387.805470  128.368240
# 2021-04-30        NaN  834.427040  3965.79627  387.805470  128.368240
# 2021-05-28        NaN  834.427040  3965.79627  387.805470  128.368240
# 2021-06-30        NaN         NaN  3695.76576  428.461480  133.762720
# 2021-07-30        NaN         NaN  3695.76576  428.461480  133.762720
# 2021-08-31        NaN         NaN  3695.76576  428.461480  133.762720
# 2021-09-30        NaN         NaN  3649.60250  438.206310   95.252430
# 2021-10-29        NaN         NaN  3649.60250  438.206310   95.252430
# 2021-11-30        NaN         NaN  3649.60250  438.206310   95.252430
# 2021-12-31        NaN         NaN  3661.15614  467.823360  106.169700
# 2022-01-31        NaN         NaN  3661.15614  467.823360  106.169700
# 2022-02-28        NaN         NaN  3661.15614  467.823360  106.169700
# 2022-03-31        NaN         NaN  3751.65750  405.475800   88.482330
# 2022-04-29        NaN         NaN  3751.65750  405.475800   88.482330
# 2022-05-31        NaN         NaN  3751.65750  405.475800   88.482330
# 2022-06-30        NaN         NaN  1875.81310  367.649730   42.584000
# 2022-07-29        NaN         NaN  1875.81310  367.649730   42.584000
# 2022-08-31        NaN         NaN  1875.81310  367.649730   42.584000
# 2022-09-30        NaN         NaN  1471.02930  373.780880   31.103840
# 2022-10-31        NaN         NaN  1471.02930  373.780880   31.103840
# 2022-11-30        NaN         NaN  1471.02930  373.780880   31.103840
# 2022-12-30        NaN         NaN  1933.40025  485.096150   63.716870
# 2023-01-31        NaN         NaN  1933.40025  485.096150   63.716870
# 2023-02-28        NaN         NaN  1933.40025  485.096150   63.716870
# 2023-03-31        NaN         NaN  2221.25702  524.296800   61.974605
# 2023-04-28        NaN         NaN  2221.25702  524.296800   61.974605
# 2023-05-31        NaN         NaN  2221.25702  524.296800   61.974605
# 2023-06-30        NaN         NaN  2163.71832  467.235550   52.434380
# 2023-07-31        NaN         NaN  2163.71832  467.235550   52.434380
# 2023-08-31        NaN         NaN  2163.71832  467.235550   52.434380
# 2023-09-29        NaN         NaN  1963.55520  422.469980   48.136480
# 2023-10-31        NaN         NaN  1963.55520  422.469980   48.136480
# 2023-11-30        NaN         NaN  1963.55520  422.469980   48.136480
# 2023-12-29        NaN         NaN  2095.10796  426.215700   30.127300
# 2024-01-31        NaN         NaN  2095.10796  426.215700   30.127300
# 2024-02-29        NaN         NaN  2095.10796  426.215700   30.127300
# 2024-03-31        NaN         NaN         NaN  441.978323   20.658720
# 2024-04-30        NaN         NaN         NaN  441.978323   20.658720
# 2024-05-31        NaN         NaN         NaN  441.978323   20.658720
# 2024-06-30        NaN         NaN         NaN  380.804407   15.494041
# 2024-07-31        NaN         NaN         NaN  380.804407   15.494041
# 2024-08-31        NaN         NaN         NaN  380.804407   15.494041
# 2024-09-30        NaN         NaN         NaN  324.008995    8.177410
#
# permno             93436
# date
# 2020-03-31  9.694000e+04
# 2020-04-30  9.694000e+04
# 2020-05-29  9.694000e+04
# 2020-06-30  2.008447e+05
# 2020-07-31  2.008447e+05
# 2020-08-31  2.008447e+05
# 2020-09-30  4.067015e+05
# 2020-10-30  4.067015e+05
# 2020-11-30  4.067015e+05
# 2020-12-31  6.773402e+05
# 2021-01-29  6.773402e+05
# 2021-02-26  6.773402e+05
# 2021-03-31  6.432166e+05
# 2021-04-30  6.432166e+05
# 2021-05-28  6.432166e+05
# 2021-06-30  6.688268e+05
# 2021-07-30  6.688268e+05
# 2021-08-31  6.688268e+05
# 2021-09-30  7.785819e+05
# 2021-10-29  7.785819e+05
# 2021-11-30  7.785819e+05
# 2021-12-31  1.092191e+06
# 2022-01-31  1.092191e+06
# 2022-02-28  1.092191e+06
# 2022-03-31  1.116368e+06
# 2022-04-29  1.116368e+06
# 2022-05-31  1.116368e+06
# 2022-06-30  7.010302e+05
# 2022-07-29  7.010302e+05
# 2022-08-31  7.010302e+05
# 2022-09-30  8.376595e+05
# 2022-10-31  8.376595e+05
# 2022-11-30  8.376595e+05
# 2022-12-30  3.897415e+05
# 2023-01-31  3.897415e+05
# 2023-02-28  3.897415e+05
# 2023-03-31  6.575059e+05
# 2023-04-28  6.575059e+05
# 2023-05-31  6.575059e+05
# 2023-06-30  8.308579e+05
# 2023-07-31  8.308579e+05
# 2023-08-31  8.308579e+05
# 2023-09-29  7.954494e+05
# 2023-10-31  7.954494e+05
# 2023-11-30  7.954494e+05
# 2023-12-29  7.898983e+05
# 2024-01-31  7.898983e+05
# 2024-02-29  7.898983e+05
# 2024-03-31  5.588225e+05
# 2024-04-30  5.588225e+05
# 2024-05-31  5.588225e+05
# 2024-06-30  6.290449e+05
# 2024-07-31  6.290449e+05
# 2024-08-31  6.290449e+05
# 2024-09-30  8.317011e+05
#
# [55 rows x 4343 columns]

# %%
universe_bool
# Out:
# permno      10026  10028  10032  10044  10051  10066  10104  10107  10145  \
# date
# 2020-03-31  False  False  False  False  False  False  False  False  False
# 2020-04-30  False  False  False  False  False  False  False  False  False
# 2020-05-29  False  False  False  False  False  False  False  False  False
# 2020-06-30  False  False  False  False  False  False  False  False  False
# 2020-07-31  False  False  False  False  False  False  False  False  False
# 2020-08-31  False  False  False  False  False  False  False  False  False
# 2020-09-30  False  False  False  False  False  False  False  False  False
# 2020-10-30  False  False  False  False  False  False  False  False  False
# 2020-11-30  False  False  False  False  False  False  False  False  False
# 2020-12-31  False  False  False  False  False  False  False  False  False
# 2021-01-29  False  False  False  False  False  False  False  False  False
# 2021-02-26  False  False  False  False  False  False  False  False  False
# 2021-03-31  False  False  False  False  False  False  False  False  False
# 2021-04-30  False  False  False  False  False  False  False  False  False
# 2021-05-28  False  False  False  False  False  False  False  False  False
# 2021-06-30  False  False  False  False  False  False  False  False  False
# 2021-07-30  False  False  False  False  False  False  False  False  False
# 2021-08-31  False  False  False  False  False  False  False  False  False
# 2021-09-30  False  False  False  False  False  False  False  False  False
# 2021-10-29  False  False  False  False  False  False  False  False  False
# 2021-11-30  False  False  False  False  False  False  False  False  False
# 2021-12-31  False  False  False  False  False  False  False  False  False
# 2022-01-31  False  False  False  False  False  False  False  False  False
# 2022-02-28  False  False  False  False  False  False  False  False  False
# 2022-03-31  False  False  False  False  False  False  False  False  False
# 2022-04-29  False  False  False  False  False  False  False  False  False
# 2022-05-31  False  False  False  False  False  False  False  False  False
# 2022-06-30  False  False  False  False  False  False  False  False  False
# 2022-07-29  False  False  False  False  False  False  False  False  False
# 2022-08-31  False  False  False  False  False  False  False  False  False
# 2022-09-30  False  False  False  False  False  False  False  False  False
# 2022-10-31  False  False  False  False  False  False  False  False  False
# 2022-11-30  False  False  False  False  False  False  False  False  False
# 2022-12-30  False  False  False  False  False  False  False  False  False
# 2023-01-31  False  False  False  False  False  False  False  False  False
# 2023-02-28  False  False  False  False  False  False  False  False  False
# 2023-03-31  False  False  False  False  False  False  False  False  False
# 2023-04-28  False  False  False  False  False  False  False  False  False
# 2023-05-31  False  False  False  False  False  False  False  False  False
# 2023-06-30  False  False  False  False  False  False  False  False  False
# 2023-07-31  False  False  False  False  False  False  False  False  False
# 2023-08-31  False  False  False  False  False  False  False  False  False
# 2023-09-29  False  False  False  False  False  False  False  False  False
# 2023-10-31  False  False  False  False  False  False  False  False  False
# 2023-11-30  False  False  False  False  False  False  False  False  False
# 2023-12-29  False  False  False  False  False  False  False  False  False
# 2024-01-31  False  False  False  False  False  False  False  False  False
# 2024-02-29  False  False  False  False  False  False  False  False  False
# 2024-03-31  False  False  False  False  False  False  False  False  False
# 2024-04-30  False  False  False  False  False  False  False  False  False
# 2024-05-31  False  False  False  False  False  False  False  False  False
# 2024-06-30  False  False  False  False  False  False  False  False  False
# 2024-07-31  False  False  False  False  False  False  False  False  False
# 2024-08-31  False  False  False  False  False  False  False  False  False
# 2024-09-30  False  False  False  False  False  False  False  False  False
#
# permno      10158  ...  93384  93393  93397  93401  93420  93422  93423  \
# date               ...
# 2020-03-31  False  ...  False  False  False  False  False  False  False
# 2020-04-30  False  ...  False  False  False  False  False  False  False
# 2020-05-29  False  ...  False  False  False  False  False  False  False
# 2020-06-30  False  ...  False  False  False  False  False  False  False
# 2020-07-31  False  ...  False  False  False  False  False  False  False
# 2020-08-31  False  ...  False  False  False  False  False  False  False
# 2020-09-30  False  ...  False  False  False  False  False  False  False
# 2020-10-30  False  ...  False  False  False  False  False  False  False
# 2020-11-30  False  ...  False  False  False  False  False  False  False
# 2020-12-31  False  ...  False  False  False  False  False  False  False
# 2021-01-29  False  ...  False  False  False  False  False  False  False
# 2021-02-26  False  ...  False  False  False  False  False  False  False
# 2021-03-31  False  ...  False  False  False  False  False  False  False
# 2021-04-30  False  ...  False  False  False  False  False  False  False
# 2021-05-28  False  ...  False  False  False  False  False  False  False
# 2021-06-30  False  ...  False  False  False  False  False  False  False
# 2021-07-30  False  ...  False  False  False  False  False  False  False
# 2021-08-31  False  ...  False  False  False  False  False  False  False
# 2021-09-30  False  ...  False  False  False  False  False  False  False
# 2021-10-29  False  ...  False  False  False  False  False  False  False
# 2021-11-30  False  ...  False  False  False  False  False  False  False
# 2021-12-31  False  ...  False  False  False  False  False  False  False
# 2022-01-31  False  ...  False  False  False  False  False  False  False
# 2022-02-28  False  ...  False  False  False  False  False  False  False
# 2022-03-31  False  ...  False  False  False  False  False  False  False
# 2022-04-29  False  ...  False  False  False  False  False  False  False
# 2022-05-31  False  ...  False  False  False  False  False  False  False
# 2022-06-30  False  ...  False  False  False  False  False  False  False
# 2022-07-29  False  ...  False  False  False  False  False  False  False
# 2022-08-31  False  ...  False  False  False  False  False  False  False
# 2022-09-30  False  ...  False  False  False  False  False  False  False
# 2022-10-31  False  ...  False  False  False  False  False  False  False
# 2022-11-30  False  ...  False  False  False  False  False  False  False
# 2022-12-30  False  ...  False  False  False  False  False  False  False
# 2023-01-31  False  ...  False  False  False  False  False  False  False
# 2023-02-28  False  ...  False  False  False  False  False  False  False
# 2023-03-31  False  ...  False  False  False  False  False  False  False
# 2023-04-28  False  ...  False  False  False  False  False  False  False
# 2023-05-31  False  ...  False  False  False  False  False  False  False
# 2023-06-30  False  ...  False  False  False  False  False  False  False
# 2023-07-31  False  ...  False  False  False  False  False  False  False
# 2023-08-31  False  ...  False  False  False  False  False  False  False
# 2023-09-29  False  ...  False  False  False  False  False  False  False
# 2023-10-31  False  ...  False  False  False  False  False  False  False
# 2023-11-30  False  ...  False  False  False  False  False  False  False
# 2023-12-29  False  ...  False  False  False  False  False  False  False
# 2024-01-31  False  ...  False  False  False  False  False  False  False
# 2024-02-29  False  ...  False  False  False  False  False  False  False
# 2024-03-31  False  ...  False  False  False  False  False  False  False
# 2024-04-30  False  ...  False  False  False  False  False  False  False
# 2024-05-31  False  ...  False  False  False  False  False  False  False
# 2024-06-30  False  ...  False  False  False  False  False  False  False
# 2024-07-31  False  ...  False  False  False  False  False  False  False
# 2024-08-31  False  ...  False  False  False  False  False  False  False
# 2024-09-30  False  ...  False  False  False  False  False  False  False
#
# permno      93426  93434  93436
# date
# 2020-03-31  False  False  False
# 2020-04-30  False  False  False
# 2020-05-29  False  False  False
# 2020-06-30  False  False  False
# 2020-07-31  False  False  False
# 2020-08-31  False  False  False
# 2020-09-30  False  False  False
# 2020-10-30  False  False  False
# 2020-11-30  False  False  False
# 2020-12-31  False  False  False
# 2021-01-29  False  False  False
# 2021-02-26  False  False  False
# 2021-03-31  False  False  False
# 2021-04-30  False  False  False
# 2021-05-28  False  False  False
# 2021-06-30  False  False  False
# 2021-07-30  False  False  False
# 2021-08-31  False  False  False
# 2021-09-30  False  False  False
# 2021-10-29  False  False  False
# 2021-11-30  False  False  False
# 2021-12-31  False  False  False
# 2022-01-31  False  False  False
# 2022-02-28  False  False  False
# 2022-03-31  False  False  False
# 2022-04-29  False  False  False
# 2022-05-31  False  False  False
# 2022-06-30  False  False  False
# 2022-07-29  False  False  False
# 2022-08-31  False  False  False
# 2022-09-30  False  False  False
# 2022-10-31  False  False  False
# 2022-11-30  False  False  False
# 2022-12-30  False  False  False
# 2023-01-31  False  False  False
# 2023-02-28  False  False  False
# 2023-03-31  False  False  False
# 2023-04-28  False  False  False
# 2023-05-31  False  False  False
# 2023-06-30  False  False  False
# 2023-07-31  False  False  False
# 2023-08-31  False  False  False
# 2023-09-29  False  False  False
# 2023-10-31  False  False  False
# 2023-11-30  False  False  False
# 2023-12-29  False  False  False
# 2024-01-31  False  False  False
# 2024-02-29  False  False  False
# 2024-03-31  False  False  False
# 2024-04-30  False  False  False
# 2024-05-31  False  False  False
# 2024-06-30  False  False  False
# 2024-07-31  False  False  False
# 2024-08-31  False  False  False
# 2024-09-30  False  False  False
#
# [55 rows x 4343 columns]
