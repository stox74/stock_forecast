# %% [markdown]
# # 1. 단일 기업 재무제표 받기

# %%
import sys
import pandas as pd
import time
# ---------------------------------------------------------
# 0) 프로젝트 경로 추가
# ---------------------------------------------------------
sys.path.append(r"C:\Users\82108\OneDrive\바탕 화면\investment\investment_strategy\US_Market\collect")

# ---------------------------------------------------------
# 1) 필요한 모듈 import
# ---------------------------------------------------------
from sec_data_pipeline.collectors.get_us_ticker import get_filtered_us_tickers
from sec_data_pipeline.collectors.sec_utils import fetch_company_facts
from sec_data_pipeline.parsers.company_facts_parser import CompanyFactsParser
from sec_data_pipeline.parsers.financial_normalizer import FinancialNormalizer
from sec_data_pipeline.validators.wrds_data_validator_mysql_integrated import WRDSDataValidator
from sec_data_pipeline.valuation.financial_data_integrator import integrate_financial_ratios

# ✅ Rate Limiter (이미 프로젝트에 있는 구현 사용)
from sec_data_pipeline.collectors.rate_limiter import AdaptiveRateLimiter

# 통합 분석 클래스 (수정본)
from sec_data_pipeline.valuation.integrated_financial_analyzer_mysql_fixed import IntegratedFinancialAnalyzer

# DB 저장용
from sec_data_pipeline.storage.db_manager import DBManager
from DATA.stock_invest_function import get_db_host


# ---------------------------------------------------------
# 2) DB 설정
# ---------------------------------------------------------
db_info = {
    "host": get_db_host(),
    "port": 3307,
    "user": "stox7412",
    "password": "Apt106503!~",
    "database": "investar",
}

# DBManager 생성 및 테이블 생성 (최초 1회만)
db_manager = DBManager(db_info)
db_manager.create_tables()   # sec_financial_data, fmp_financial_data 등 생성


# ---------------------------------------------------------
# 3) WRDS 접속 문자열
# ---------------------------------------------------------
wrds_conn_str = "postgresql://YOUR_WRDS_ID:YOUR_WRDS_PW@wrds.wharton.upenn.edu:9737/wrds"


# ---------------------------------------------------------
# 4) SEC User-Agent 헤더 설정 (반드시 이메일 포함)
# ---------------------------------------------------------
headers = {
    "User-Agent": "Hoyoung Research <stox1224@gmail.com>"
}


# ---------------------------------------------------------
# 5) 티커 리스트 생성
# ---------------------------------------------------------
# 전체 티커 리스트
TICKER_LIST = get_filtered_us_tickers()

# 테스트 / 안전을 위해 500개까지만
TICKER_LIST = TICKER_LIST[1000:2000]
# 완전 테스트용:
# TICKER_LIST = ["AAPL", "MSFT"]

# ---------------------------------------------------------
# 6) Rate Limiter 설정
#    - max_calls=8, time_window=1 → 초당 최대 8회
#    - AdaptiveRateLimiter: 429 발생 시 자동으로 max_calls 줄임
# ---------------------------------------------------------
rate_limiter = AdaptiveRateLimiter(
    max_calls=8,
    time_window=1.0,
    min_calls=3,
    backoff_factor=0.8,
)

# 통합 분석기
analyzer = IntegratedFinancialAnalyzer(db_info=db_info, wrds_conn_str=wrds_conn_str)


# ---------------------------------------------------------
# 7) 메인 루프: 티커별 EDGAR+WRDS+비율 → DB 저장
# ---------------------------------------------------------
for i, ticker in enumerate(TICKER_LIST, start=1):
    print(f"\n=== [{i}/{len(TICKER_LIST)}] {ticker} 처리 시작 ===")

    # ✅ ❶ 티커마다 호출 전 rate limit 체크
    rate_limiter.wait_if_needed()

    try:
        result = analyzer.analyze(ticker, headers=headers, table_name="us_fundq")
        if result is None:
            print(f"⚠ {ticker}: 분석 결과 없음, 스킵")
            continue

        final_df, cik, entity_name = result

        # date 인덱스 정리 (DB 저장을 위해)
        if final_df.index.name != "date":
            final_df = final_df.copy()
            # 만약 date가 컬럼으로 있다면:
            if "date" in final_df.columns:
                final_df = final_df.set_index("date")
            else:
                final_df.index.name = "date"

        # DB 저장 (LONG FORMAT sec_financial_data)
        db_manager.save_normalized_data(
            ticker=ticker,
            cik=cik,
            df=final_df,
            item_mapping=None  # 컬럼명을 그대로 item_name으로 사용
        )

        print(f"✓ {ticker} ({entity_name}) 저장 완료")

        # ✅ ❷ 여유를 더 두고 싶으면 티커 사이에 약간의 sleep 추가 (선택)
        # time.sleep(0.2)

    except Exception as e:
        msg = str(e)

        # ✅ ❸ SEC 429 / rate limit 의심 시 백오프 처리
        if "Company Facts 요청 실패" in msg and "429" in msg:
            print(f"⚠ {ticker}: SEC 429 Too Many Requests 감지 → rate 낮추고 60초 대기")
            # AdaptiveRateLimiter에 "rateLimit 발생" 알리기
            rate_limiter.on_rate_limit_error()
            # 잠시 쉬었다가 다음 티커로
            time.sleep(60)
            continue

        print(f"✗ {ticker} 처리 중 기타 오류: {e}")
        # (여기서 바로 continue 해서 다음 티커 진행)
        continue

print("\n=== 전체 작업 완료 ===")
# Out:
# ✓ DB connected: 192.168.0.230:3307/investar
# ✓ Tables created
# 100%|██████████| 3773/3773 [00:03<00:00, 1101.07it/s]
# 100%|██████████| 2745/2745 [00:02<00:00, 1172.91it/s]
# 100%|██████████| 294/294 [00:00<00:00, 1100.77it/s]
# 제외된 기업 수: 1812
# 남은 기업 수: 5000
# 티커 수: 5000
#
# === [1/1000] DCBO 처리 시작 ===
# ================================================================================
# [DCBO] 통합 재무분석 시작
# ✓ Entity: DOCEBO INC. (CIK: 1829959)
# ⚠ EDGAR 정규화 DF가 비어 있습니다 (DCBO)
# ✓ EDGAR 정규화 DF: 0 rows × 0 cols
# ⚠ EDGAR 입력 DF가 비어있습니다. WRDS만으로 구성합니다.
# ✓ MySQL 연결 성공: 192.168.0.230:3307/investar
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ⚠ WRDS 보완 후에도 DF가 비어 있습니다 (DCBO)
# ⚠ DCBO: 분석 결과 없음, 스킵
#
# === [2/1000] KRUS 처리 시작 ===
# ================================================================================
# [KRUS] 통합 재무분석 시작
# ✓ Entity: KURA SUSHI USA, INC. (CIK: 1772177)
# ✓ EDGAR 정규화 DF: 30 rows × 22 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 30 rows × 22 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 30 rows × 35 cols
# [KRUS] 통합 재무분석 종료
# ================================================================================
# ✓ Saved KRUS data: 30 dates x 35 items
# ✓ KRUS (KURA SUSHI USA, INC.) 저장 완료
#
# === [3/1000] CEPF 처리 시작 ===
# ================================================================================
# [CEPF] 통합 재무분석 시작
# ✓ Entity: CANTOR EQUITY PARTNERS IV, INC. (CIK: 0002034267)
# ✓ EDGAR 정규화 DF: 8 rows × 10 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 8 rows × 10 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 8 rows × 20 cols
# [CEPF] 통합 재무분석 종료
# ================================================================================
# ✓ Saved CEPF data: 8 dates x 20 items
# ✓ CEPF (CANTOR EQUITY PARTNERS IV, INC.) 저장 완료
#
# === [4/1000] ASMB 처리 시작 ===
# ================================================================================
# [ASMB] 통합 재무분석 시작
# ✓ Entity: ASSEMBLY BIOSCIENCES, INC. (CIK: 1426800)
# ✓ EDGAR 정규화 DF: 67 rows × 28 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 67 rows × 28 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 67 rows × 40 cols
# [ASMB] 통합 재무분석 종료
# ================================================================================
# ✓ Saved ASMB data: 67 dates x 40 items
# ✓ ASMB (ASSEMBLY BIOSCIENCES, INC.) 저장 완료
#
# === [5/1000] MNPR 처리 시작 ===
# ================================================================================
# [MNPR] 통합 재무분석 시작
# ✓ Entity: MONOPAR THERAPEUTICS INC. (CIK: 1645469)
# ✓ EDGAR 정규화 DF: 37 rows × 15 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 37 rows × 15 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 37 rows × 25 cols
# [MNPR] 통합 재무분석 종료
# ================================================================================
# ✓ Saved MNPR data: 37 dates x 25 items
# ✓ MNPR (MONOPAR THERAPEUTICS INC.) 저장 완료
#
# === [6/1000] OPT 처리 시작 ===
# ================================================================================
# [OPT] 통합 재무분석 시작
# ✗ EDGAR Company Facts 로딩 실패 (OPT): 티커를 찾을 수 없습니다: OPT
# ⚠ OPT: 분석 결과 없음, 스킵
#
# === [7/1000] SPT 처리 시작 ===
# ================================================================================
# [SPT] 통합 재무분석 시작
# ✓ Entity: SPROUT SOCIAL, INC. (CIK: 1517375)
# ✓ EDGAR 정규화 DF: 29 rows × 29 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 29 rows × 29 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 29 rows × 42 cols
# [SPT] 통합 재무분석 종료
# ================================================================================
# ✓ Saved SPT data: 29 dates x 42 items
# ✓ SPT (SPROUT SOCIAL, INC.) 저장 완료
#
# === [8/1000] TCMD 처리 시작 ===
# ================================================================================
# [TCMD] 통합 재무분석 시작
# ✓ Entity: Tactile Systems Technology, Inc. (CIK: 1027838)
# ✓ EDGAR 정규화 DF: 46 rows × 29 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 46 rows × 29 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 46 rows × 45 cols
# [TCMD] 통합 재무분석 종료
# ================================================================================
# ✓ Saved TCMD data: 46 dates x 45 items
# ✓ TCMD (Tactile Systems Technology, Inc.) 저장 완료
#
# === [9/1000] LWLG 처리 시작 ===
# ================================================================================
# [LWLG] 통합 재무분석 시작
# ✓ Entity: Lightwave Logic, Inc. (CIK: 1325964)
# ✓ EDGAR 정규화 DF: 71 rows × 27 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 71 rows × 27 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 71 rows × 43 cols
# [LWLG] 통합 재무분석 종료
# ================================================================================
# ✓ Saved LWLG data: 71 dates x 43 items
# ✓ LWLG (Lightwave Logic, Inc.) 저장 완료
#
# === [10/1000] IHRT 처리 시작 ===
# ================================================================================
# [IHRT] 통합 재무분석 시작
# ✓ Entity: IHEARTMEDIA, INC. (CIK: 1400891)
# ✓ EDGAR 정규화 DF: 65 rows × 27 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 65 rows × 27 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 65 rows × 40 cols
# [IHRT] 통합 재무분석 종료
# ================================================================================
# ✓ Saved IHRT data: 65 dates x 40 items
# ✓ IHRT (IHEARTMEDIA, INC.) 저장 완료
#
# === [11/1000] ICHR 처리 시작 ===
# ================================================================================
# [ICHR] 통합 재무분석 시작
# ✓ Entity: ICHOR HOLDINGS, LTD. (CIK: 1652535)
# ✓ EDGAR 정규화 DF: 44 rows × 30 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 44 rows × 30 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 44 rows × 46 cols
# [ICHR] 통합 재무분석 종료
# ================================================================================
# ✓ Saved ICHR data: 44 dates x 46 items
# ✓ ICHR (ICHOR HOLDINGS, LTD.) 저장 완료
#
# === [12/1000] JBIO 처리 시작 ===
# ================================================================================
# [JBIO] 통합 재무분석 시작
# ✓ Entity: Jade Biosciences, Inc. (CIK: 1798749)
# ✓ EDGAR 정규화 DF: 24 rows × 21 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 24 rows × 21 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 24 rows × 31 cols
# [JBIO] 통합 재무분석 종료
# ================================================================================
# ✓ Saved JBIO data: 24 dates x 31 items
# ✓ JBIO (Jade Biosciences, Inc.) 저장 완료
#
# === [13/1000] MNRO 처리 시작 ===
# ================================================================================
# [MNRO] 통합 재무분석 시작
# ✓ Entity: MONRO, INC. (CIK: 876427)
# ✓ EDGAR 정규화 DF: 64 rows × 28 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 64 rows × 28 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 64 rows × 40 cols
# [MNRO] 통합 재무분석 종료
# ================================================================================
# ✓ Saved MNRO data: 64 dates x 40 items
# ✓ MNRO (MONRO, INC.) 저장 완료
#
# === [14/1000] CCD 처리 시작 ===
# ================================================================================
# [CCD] 통합 재무분석 시작
# ✗ EDGAR Company Facts 로딩 실패 (CCD): Company Facts 요청 실패: 404 https://data.sec.gov/api/xbrl/companyfacts/CIK0001602584.json
# ⚠ CCD: 분석 결과 없음, 스킵
#
# === [15/1000] LYTS 처리 시작 ===
# ================================================================================
# [LYTS] 통합 재무분석 시작
# ✓ Entity: LSI Industries Inc. (CIK: 763532)
# ✓ EDGAR 정규화 DF: 64 rows × 30 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 64 rows × 30 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 64 rows × 46 cols
# [LYTS] 통합 재무분석 종료
# ================================================================================
# ✓ Saved LYTS data: 64 dates x 46 items
# ✓ LYTS (LSI Industries Inc.) 저장 완료
#
# === [16/1000] SFIX 처리 시작 ===
# ================================================================================
# [SFIX] 통합 재무분석 시작
# ✓ Entity: STITCH FIX, INC. (CIK: 1576942)
# ✓ EDGAR 정규화 DF: 38 rows × 23 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 38 rows × 23 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 38 rows × 37 cols
# [SFIX] 통합 재무분석 종료
# ================================================================================
# ✓ Saved SFIX data: 38 dates x 37 items
# ✓ SFIX (STITCH FIX, INC.) 저장 완료
#
# === [17/1000] MPLT 처리 시작 ===
# ================================================================================
# [MPLT] 통합 재무분석 시작
# ✗ EDGAR Company Facts 로딩 실패 (MPLT): Company Facts 요청 실패: 404 https://data.sec.gov/api/xbrl/companyfacts/CIK0001770069.json
# ⚠ MPLT: 분석 결과 없음, 스킵
#
# === [18/1000] CHSCO 처리 시작 ===
# ================================================================================
# [CHSCO] 통합 재무분석 시작
# ✓ Entity: CHS Inc. (CIK: 823277)
# ✓ EDGAR 정규화 DF: 63 rows × 30 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 63 rows × 30 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 63 rows × 46 cols
# [CHSCO] 통합 재무분석 종료
# ================================================================================
# ✓ Saved CHSCO data: 63 dates x 46 items
# ✓ CHSCO (CHS Inc.) 저장 완료
#
# === [19/1000] TALK 처리 시작 ===
# ================================================================================
# [TALK] 통합 재무분석 시작
# ✓ Entity: TALKSPACE, INC. (CIK: 1803901)
# ✓ EDGAR 정규화 DF: 25 rows × 29 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 25 rows × 29 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 25 rows × 42 cols
# [TALK] 통합 재무분석 종료
# ================================================================================
# ✓ Saved TALK data: 25 dates x 42 items
# ✓ TALK (TALKSPACE, INC.) 저장 완료
#
# === [20/1000] PRTA 처리 시작 ===
# ================================================================================
# [PRTA] 통합 재무분석 시작
# ✓ Entity: PROTHENA CORPORATION PUBLIC LIMITED COMPANY (CIK: 1559053)
# ✓ EDGAR 정규화 DF: 57 rows × 25 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 57 rows × 25 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 57 rows × 37 cols
# [PRTA] 통합 재무분석 종료
# ================================================================================
# ✓ Saved PRTA data: 57 dates x 37 items
# ✓ PRTA (PROTHENA CORPORATION PUBLIC LIMITED COMPANY) 저장 완료
#
# === [21/1000] CEVA 처리 시작 ===
# ================================================================================
# [CEVA] 통합 재무분석 시작
# ✓ Entity: Ceva, Inc. (CIK: 1173489)
# ✓ EDGAR 정규화 DF: 64 rows × 28 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 64 rows × 28 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 64 rows × 44 cols
# [CEVA] 통합 재무분석 종료
# ================================================================================
# ✓ Saved CEVA data: 64 dates x 44 items
# ✓ CEVA (Ceva, Inc.) 저장 완료
#
# === [22/1000] MBUU 처리 시작 ===
# ================================================================================
# [MBUU] 통합 재무분석 시작
# ✓ Entity: MALIBU BOATS, INC. (CIK: 1590976)
# ✓ EDGAR 정규화 DF: 57 rows × 28 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 57 rows × 28 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 57 rows × 44 cols
# [MBUU] 통합 재무분석 종료
# ================================================================================
# ✓ Saved MBUU data: 57 dates x 44 items
# ✓ MBUU (MALIBU BOATS, INC.) 저장 완료
#
# === [23/1000] GAIN 처리 시작 ===
# ================================================================================
# [GAIN] 통합 재무분석 시작
# ✓ Entity: GLADSTONE INVESTMENT CORPORATION\DE (CIK: 0001321741)
# ✓ EDGAR 정규화 DF: 20 rows × 6 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 20 rows × 6 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 20 rows × 15 cols
# [GAIN] 통합 재무분석 종료
# ================================================================================
# ✓ Saved GAIN data: 20 dates x 15 items
# ✓ GAIN (GLADSTONE INVESTMENT CORPORATION\DE) 저장 완료
#
# === [24/1000] LAB 처리 시작 ===
# ================================================================================
# [LAB] 통합 재무분석 시작
# ✓ Entity: STANDARD BIOTOOLS INC. (CIK: 1162194)
# ✓ EDGAR 정규화 DF: 65 rows × 29 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 65 rows × 29 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 65 rows × 43 cols
# [LAB] 통합 재무분석 종료
# ================================================================================
# ✓ Saved LAB data: 65 dates x 43 items
# ✓ LAB (STANDARD BIOTOOLS INC.) 저장 완료
#
# === [25/1000] NAGE 처리 시작 ===
# ================================================================================
# [NAGE] 통합 재무분석 시작
# ✓ Entity: NIAGEN BIOSCIENCE, INC. (CIK: 1386570)
# ✓ EDGAR 정규화 DF: 65 rows × 29 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 65 rows × 29 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 65 rows × 45 cols
# [NAGE] 통합 재무분석 종료
# ================================================================================
# ✓ Saved NAGE data: 65 dates x 45 items
# ✓ NAGE (NIAGEN BIOSCIENCE, INC.) 저장 완료
#
# === [26/1000] CASS 처리 시작 ===
# ================================================================================
# [CASS] 통합 재무분석 시작
# ✓ Entity: CASS INFORMATION SYSTEMS, INC. (CIK: 708781)
# ✓ EDGAR 정규화 DF: 65 rows × 19 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 65 rows × 19 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 65 rows × 29 cols
# [CASS] 통합 재무분석 종료
# ================================================================================
# ✓ Saved CASS data: 65 dates x 29 items
# ✓ CASS (CASS INFORMATION SYSTEMS, INC.) 저장 완료
#
# === [27/1000] NPCE 처리 시작 ===
# ================================================================================
# [NPCE] 통합 재무분석 시작
# ✓ Entity: NEUROPACE, INC. (CIK: 1528287)
# ✓ EDGAR 정규화 DF: 24 rows × 29 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 24 rows × 29 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 24 rows × 45 cols
# [NPCE] 통합 재무분석 종료
# ================================================================================
# ✓ Saved NPCE data: 24 dates x 45 items
# ✓ NPCE (NEUROPACE, INC.) 저장 완료
#
# === [28/1000] ALT 처리 시작 ===
# ================================================================================
# [ALT] 통합 재무분석 시작
# ✓ Entity: ALTIMMUNE, INC. (CIK: 1326190)
# ✓ EDGAR 정규화 DF: 63 rows × 30 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 63 rows × 30 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 63 rows × 42 cols
# [ALT] 통합 재무분석 종료
# ================================================================================
# ✓ Saved ALT data: 63 dates x 42 items
# ✓ ALT (ALTIMMUNE, INC.) 저장 완료
#
# === [29/1000] DSGN 처리 시작 ===
# ================================================================================
# [DSGN] 통합 재무분석 시작
# ✓ Entity: Design Therapeutics, Inc. (CIK: 1807120)
# ✓ EDGAR 정규화 DF: 24 rows × 18 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 24 rows × 18 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 24 rows × 28 cols
# [DSGN] 통합 재무분석 종료
# ================================================================================
# ✓ Saved DSGN data: 24 dates x 28 items
# ✓ DSGN (Design Therapeutics, Inc.) 저장 완료
#
# === [30/1000] APPS 처리 시작 ===
# ================================================================================
# [APPS] 통합 재무분석 시작
# ✓ Entity: DIGITAL TURBINE, INC. (CIK: 317788)
# ✓ EDGAR 정규화 DF: 63 rows × 30 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 63 rows × 30 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 63 rows × 43 cols
# [APPS] 통합 재무분석 종료
# ================================================================================
# ✓ Saved APPS data: 63 dates x 43 items
# ✓ APPS (DIGITAL TURBINE, INC.) 저장 완료
#
# === [31/1000] IRWD 처리 시작 ===
# ================================================================================
# [IRWD] 통합 재무분석 시작
# ✓ Entity: IRONWOOD PHARMACEUTICALS, INC. (CIK: 1446847)
# ✓ EDGAR 정규화 DF: 65 rows × 29 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 65 rows × 29 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 65 rows × 44 cols
# [IRWD] 통합 재무분석 종료
# ================================================================================
# ✓ Saved IRWD data: 65 dates x 44 items
# ✓ IRWD (IRONWOOD PHARMACEUTICALS, INC.) 저장 완료
#
# === [32/1000] THH 처리 시작 ===
# ================================================================================
# [THH] 통합 재무분석 시작
# ✗ EDGAR Company Facts 로딩 실패 (THH): Company Facts 요청 실패: 404 https://data.sec.gov/api/xbrl/companyfacts/CIK0002044241.json
# ⚠ THH: 분석 결과 없음, 스킵
#
# === [33/1000] UXIN 처리 시작 ===
# ================================================================================
# [UXIN] 통합 재무분석 시작
# ✓ Entity: Uxin Limited (CIK: 1729173)
# ✓ EDGAR 정규화 DF: 10 rows × 31 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 10 rows × 31 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 10 rows × 47 cols
# [UXIN] 통합 재무분석 종료
# ================================================================================
# ✓ Saved UXIN data: 10 dates x 47 items
# ✓ UXIN (Uxin Limited) 저장 완료
#
# === [34/1000] KROS 처리 시작 ===
# ================================================================================
# [KROS] 통합 재무분석 시작
# ✓ Entity: KEROS THERAPEUTICS, INC. (CIK: 1664710)
# ✓ EDGAR 정규화 DF: 28 rows × 24 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 28 rows × 24 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 28 rows × 36 cols
# [KROS] 통합 재무분석 종료
# ================================================================================
# ✓ Saved KROS data: 28 dates x 36 items
# ✓ KROS (KEROS THERAPEUTICS, INC.) 저장 완료
#
# === [35/1000] ENGN 처리 시작 ===
# ================================================================================
# [ENGN] 통합 재무분석 시작
# ✓ Entity: enGene Holdings Inc. (CIK: 0001980845)
# ✓ EDGAR 정규화 DF: 13 rows × 21 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 13 rows × 21 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 13 rows × 31 cols
# [ENGN] 통합 재무분석 종료
# ================================================================================
# ✓ Saved ENGN data: 13 dates x 31 items
# ✓ ENGN (enGene Holdings Inc.) 저장 완료
#
# === [36/1000] ARKO 처리 시작 ===
# ================================================================================
# [ARKO] 통합 재무분석 시작
# ✓ Entity: ARKO Corp. (CIK: 1823794)
# ✓ EDGAR 정규화 DF: 25 rows × 25 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 25 rows × 25 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 25 rows × 38 cols
# [ARKO] 통합 재무분석 종료
# ================================================================================
# ✓ Saved ARKO data: 25 dates x 38 items
# ✓ ARKO (ARKO Corp.) 저장 완료
#
# === [37/1000] CHSCL 처리 시작 ===
# ================================================================================
# [CHSCL] 통합 재무분석 시작
# ✓ Entity: CHS Inc. (CIK: 823277)
# ✓ EDGAR 정규화 DF: 63 rows × 30 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 63 rows × 30 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 63 rows × 46 cols
# [CHSCL] 통합 재무분석 종료
# ================================================================================
# ✓ Saved CHSCL data: 63 dates x 46 items
# ✓ CHSCL (CHS Inc.) 저장 완료
#
# === [38/1000] CCAP 처리 시작 ===
# ================================================================================
# [CCAP] 통합 재무분석 시작
# ✓ Entity: Crescent Capital BDC, Inc. (CIK: 0001633336)
# ✓ EDGAR 정규화 DF: 20 rows × 11 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 20 rows × 11 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 20 rows × 21 cols
# [CCAP] 통합 재무분석 종료
# ================================================================================
# ✓ Saved CCAP data: 20 dates x 21 items
# ✓ CCAP (Crescent Capital BDC, Inc.) 저장 완료
#
# === [39/1000] TRNS 처리 시작 ===
# ================================================================================
# [TRNS] 통합 재무분석 시작
# ✓ Entity: TRANSCAT INC (CIK: 99302)
# ✓ EDGAR 정규화 DF: 65 rows × 29 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 65 rows × 29 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 65 rows × 43 cols
# [TRNS] 통합 재무분석 종료
# ================================================================================
# ✓ Saved TRNS data: 65 dates x 43 items
# ✓ TRNS (TRANSCAT INC) 저장 완료
#
# === [40/1000] LXRX 처리 시작 ===
# ================================================================================
# [LXRX] 통합 재무분석 시작
# ✓ Entity: Lexicon Pharmaceuticals, Inc. (CIK: 1062822)
# ✓ EDGAR 정규화 DF: 65 rows × 31 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 65 rows × 31 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 65 rows × 46 cols
# [LXRX] 통합 재무분석 종료
# ================================================================================
# ✓ Saved LXRX data: 65 dates x 46 items
# ✓ LXRX (Lexicon Pharmaceuticals, Inc.) 저장 완료
#
# === [41/1000] LYEL 처리 시작 ===
# ================================================================================
# [LYEL] 통합 재무분석 시작
# ✓ Entity: Lyell Immunopharma, Inc. (CIK: 1806952)
# ✓ EDGAR 정규화 DF: 25 rows × 19 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 25 rows × 19 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 25 rows × 29 cols
# [LYEL] 통합 재무분석 종료
# ================================================================================
# ✓ Saved LYEL data: 25 dates x 29 items
# ✓ LYEL (Lyell Immunopharma, Inc.) 저장 완료
#
# === [42/1000] DRUG 처리 시작 ===
# ================================================================================
# [DRUG] 통합 재무분석 시작
# ✓ Entity: BRIGHT MINDS BIOSCIENCES INC. (CIK: 0001827401)
# ⚠ EDGAR 정규화 DF가 비어 있습니다 (DRUG)
# ✓ EDGAR 정규화 DF: 0 rows × 0 cols
# ⚠ EDGAR 입력 DF가 비어있습니다. WRDS만으로 구성합니다.
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ⚠ WRDS 보완 후에도 DF가 비어 있습니다 (DRUG)
# ⚠ DRUG: 분석 결과 없음, 스킵
#
# === [43/1000] VLGEA 처리 시작 ===
# ================================================================================
# [VLGEA] 통합 재무분석 시작
# ✓ Entity: VILLAGE SUPER MARKET, INC. (CIK: 103595)
# ✓ EDGAR 정규화 DF: 64 rows × 28 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 64 rows × 28 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 64 rows × 42 cols
# [VLGEA] 통합 재무분석 종료
# ================================================================================
# ✓ Saved VLGEA data: 64 dates x 42 items
# ✓ VLGEA (VILLAGE SUPER MARKET, INC.) 저장 완료
#
# === [44/1000] BCYC 처리 시작 ===
# ================================================================================
# [BCYC] 통합 재무분석 시작
# ✓ Entity: Bicycle Therapeutics plc (CIK: 1761612)
# ✓ EDGAR 정규화 DF: 33 rows × 26 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 33 rows × 26 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 33 rows × 38 cols
# [BCYC] 통합 재무분석 종료
# ================================================================================
# ✓ Saved BCYC data: 33 dates x 38 items
# ✓ BCYC (Bicycle Therapeutics plc) 저장 완료
#
# === [45/1000] ANGO 처리 시작 ===
# ================================================================================
# [ANGO] 통합 재무분석 시작
# ✓ Entity: AngioDynamics, Inc. (CIK: 1275187)
# ✓ EDGAR 정규화 DF: 64 rows × 31 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 64 rows × 31 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 64 rows × 47 cols
# [ANGO] 통합 재무분석 종료
# ================================================================================
# ✓ Saved ANGO data: 64 dates x 47 items
# ✓ ANGO (AngioDynamics, Inc.) 저장 완료
#
# === [46/1000] GEVO 처리 시작 ===
# ================================================================================
# [GEVO] 통합 재무분석 시작
# ✓ Entity: GEVO, INC. (CIK: 1392380)
# ✓ EDGAR 정규화 DF: 67 rows × 32 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 67 rows × 32 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 67 rows × 48 cols
# [GEVO] 통합 재무분석 종료
# ================================================================================
# ✓ Saved GEVO data: 67 dates x 48 items
# ✓ GEVO (GEVO, INC.) 저장 완료
#
# === [47/1000] UROY 처리 시작 ===
# ================================================================================
# [UROY] 통합 재무분석 시작
# ✓ Entity: Uranium Royalty Corp. (CIK: 1711570)
# ⚠ EDGAR 정규화 DF가 비어 있습니다 (UROY)
# ✓ EDGAR 정규화 DF: 0 rows × 0 cols
# ⚠ EDGAR 입력 DF가 비어있습니다. WRDS만으로 구성합니다.
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ⚠ WRDS 보완 후에도 DF가 비어 있습니다 (UROY)
# ⚠ UROY: 분석 결과 없음, 스킵
#
# === [48/1000] CMPS 처리 시작 ===
# ================================================================================
# [CMPS] 통합 재무분석 시작
# ✓ Entity: COMPASS Pathways plc (CIK: 1816590)
# ✓ EDGAR 정규화 DF: 25 rows × 25 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 25 rows × 25 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 25 rows × 35 cols
# [CMPS] 통합 재무분석 종료
# ================================================================================
# ✓ Saved CMPS data: 25 dates x 35 items
# ✓ CMPS (COMPASS Pathways plc) 저장 완료
#
# === [49/1000] EU 처리 시작 ===
# ================================================================================
# [EU] 통합 재무분석 시작
# ✓ Entity: ENCORE ENERGY CORP. (CIK: 0001500881)
# ✓ EDGAR 정규화 DF: 8 rows × 25 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 8 rows × 25 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 8 rows × 39 cols
# [EU] 통합 재무분석 종료
# ================================================================================
# ✓ Saved EU data: 8 dates x 39 items
# ✓ EU (ENCORE ENERGY CORP.) 저장 완료
#
# === [50/1000] RBBN 처리 시작 ===
# ================================================================================
# [RBBN] 통합 재무분석 시작
# ✓ Entity: RIBBON COMMUNICATIONS INC. (CIK: 1708055)
# ✓ EDGAR 정규화 DF: 41 rows × 31 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 41 rows × 31 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 41 rows × 47 cols
# [RBBN] 통합 재무분석 종료
# ================================================================================
# ✓ Saved RBBN data: 41 dates x 47 items
# ✓ RBBN (RIBBON COMMUNICATIONS INC.) 저장 완료
#
# === [51/1000] HCKT 처리 시작 ===
# ================================================================================
# [HCKT] 통합 재무분석 시작
# ✓ Entity: Hackett Group, Inc. (CIK: 1057379)
# ✓ EDGAR 정규화 DF: 65 rows × 30 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 65 rows × 30 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 65 rows × 43 cols
# [HCKT] 통합 재무분석 종료
# ================================================================================
# ✓ Saved HCKT data: 65 dates x 43 items
# ✓ HCKT (Hackett Group, Inc.) 저장 완료
#
# === [52/1000] MCTA 처리 시작 ===
# ================================================================================
# [MCTA] 통합 재무분석 시작
# ✗ EDGAR Company Facts 로딩 실패 (MCTA): Company Facts 요청 실패: 404 https://data.sec.gov/api/xbrl/companyfacts/CIK0002035992.json
# ⚠ MCTA: 분석 결과 없음, 스킵
#
# === [53/1000] TATT 처리 시작 ===
# ================================================================================
# [TATT] 통합 재무분석 시작
# ✓ Entity: TAT TECHNOLOGIES LTD. (CIK: 808439)
# ✓ EDGAR 정규화 DF: 20 rows × 27 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 20 rows × 27 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 20 rows × 43 cols
# [TATT] 통합 재무분석 종료
# ================================================================================
# ✓ Saved TATT data: 20 dates x 43 items
# ✓ TATT (TAT TECHNOLOGIES LTD.) 저장 완료
#
# === [54/1000] CHSCM 처리 시작 ===
# ================================================================================
# [CHSCM] 통합 재무분석 시작
# ✓ Entity: CHS Inc. (CIK: 823277)
# ✓ EDGAR 정규화 DF: 63 rows × 30 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 63 rows × 30 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 63 rows × 46 cols
# [CHSCM] 통합 재무분석 종료
# ================================================================================
# ✓ Saved CHSCM data: 63 dates x 46 items
# ✓ CHSCM (CHS Inc.) 저장 완료
#
# === [55/1000] LTBR 처리 시작 ===
# ================================================================================
# [LTBR] 통합 재무분석 시작
# ✓ Entity: LIGHTBRIDGE CORPORATION (CIK: 1084554)
# ✓ EDGAR 정규화 DF: 63 rows × 26 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 63 rows × 26 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 63 rows × 39 cols
# [LTBR] 통합 재무분석 종료
# ================================================================================
# ✓ Saved LTBR data: 63 dates x 39 items
# ✓ LTBR (LIGHTBRIDGE CORPORATION) 저장 완료
#
# === [56/1000] RSVR 처리 시작 ===
# ================================================================================
# [RSVR] 통합 재무분석 시작
# ✓ Entity: RESERVOIR MEDIA, INC. (CIK: 1824403)
# ✓ EDGAR 정규화 DF: 24 rows × 27 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 24 rows × 27 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 24 rows × 39 cols
# [RSVR] 통합 재무분석 종료
# ================================================================================
# ✓ Saved RSVR data: 24 dates x 39 items
# ✓ RSVR (RESERVOIR MEDIA, INC.) 저장 완료
#
# === [57/1000] ANGI 처리 시작 ===
# ================================================================================
# [ANGI] 통합 재무분석 시작
# ✓ Entity: Angi Inc. (CIK: 1705110)
# ✓ EDGAR 정규화 DF: 41 rows × 28 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 41 rows × 28 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 41 rows × 41 cols
# [ANGI] 통합 재무분석 종료
# ================================================================================
# ✓ Saved ANGI data: 41 dates x 41 items
# ✓ ANGI (Angi Inc.) 저장 완료
#
# === [58/1000] MGPI 처리 시작 ===
# ================================================================================
# [MGPI] 통합 재무분석 시작
# ✓ Entity: MGP INGREDIENTS, INC. (CIK: 835011)
# ✓ EDGAR 정규화 DF: 64 rows × 30 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 64 rows × 30 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 64 rows × 46 cols
# [MGPI] 통합 재무분석 종료
# ================================================================================
# ✓ Saved MGPI data: 64 dates x 46 items
# ✓ MGPI (MGP INGREDIENTS, INC.) 저장 완료
#
# === [59/1000] LE 처리 시작 ===
# ================================================================================
# [LE] 통합 재무분석 시작
# ✓ Entity: Lands’ End, Inc. (CIK: 799288)
# ✓ EDGAR 정규화 DF: 53 rows × 30 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 53 rows × 30 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 53 rows × 46 cols
# [LE] 통합 재무분석 종료
# ================================================================================
# ✓ Saved LE data: 53 dates x 46 items
# ✓ LE (Lands’ End, Inc.) 저장 완료
#
# === [60/1000] IMRX 처리 시작 ===
# ================================================================================
# [IMRX] 통합 재무분석 시작
# ✓ Entity: Immuneering Corporation (CIK: 1790340)
# ✓ EDGAR 정규화 DF: 24 rows × 25 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 24 rows × 25 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 24 rows × 38 cols
# [IMRX] 통합 재무분석 종료
# ================================================================================
# ✓ Saved IMRX data: 24 dates x 38 items
# ✓ IMRX (Immuneering Corporation) 저장 완료
#
# === [61/1000] ZVRA 처리 시작 ===
# ================================================================================
# [ZVRA] 통합 재무분석 시작
# ✓ Entity: Zevra Therapeutics, Inc. (CIK: 1434647)
# ✓ EDGAR 정규화 DF: 49 rows × 28 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 49 rows × 28 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 49 rows × 43 cols
# [ZVRA] 통합 재무분석 종료
# ================================================================================
# ✓ Saved ZVRA data: 49 dates x 43 items
# ✓ ZVRA (Zevra Therapeutics, Inc.) 저장 완료
#
# === [62/1000] LEGH 처리 시작 ===
# ================================================================================
# [LEGH] 통합 재무분석 시작
# ✓ Entity: Legacy Housing Corporation (CIK: 1436208)
# ✓ EDGAR 정규화 DF: 32 rows × 24 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 32 rows × 24 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 32 rows × 39 cols
# [LEGH] 통합 재무분석 종료
# ================================================================================
# ✓ Saved LEGH data: 32 dates x 39 items
# ✓ LEGH (Legacy Housing Corporation) 저장 완료
#
# === [63/1000] VREX 처리 시작 ===
# ================================================================================
# [VREX] 통합 재무분석 시작
# ✓ Entity: VAREX IMAGING CORPORATION (CIK: 1681622)
# ✓ EDGAR 정규화 DF: 43 rows × 31 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 43 rows × 31 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 43 rows × 47 cols
# [VREX] 통합 재무분석 종료
# ================================================================================
# ✓ Saved VREX data: 43 dates x 47 items
# ✓ VREX (VAREX IMAGING CORPORATION) 저장 완료
#
# === [64/1000] CYRX 처리 시작 ===
# ================================================================================
# [CYRX] 통합 재무분석 시작
# ✓ Entity: CRYOPORT, INC. (CIK: 1124524)
# ✓ EDGAR 정규화 DF: 63 rows × 31 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 63 rows × 31 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 63 rows × 47 cols
# [CYRX] 통합 재무분석 종료
# ================================================================================
# ✓ Saved CYRX data: 63 dates x 47 items
# ✓ CYRX (CRYOPORT, INC.) 저장 완료
#
# === [65/1000] GLAD 처리 시작 ===
# ================================================================================
# [GLAD] 통합 재무분석 시작
# ✓ Entity: GLADSTONE CAPITAL CORP (CIK: 0001143513)
# ✓ EDGAR 정규화 DF: 18 rows × 5 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 18 rows × 5 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 18 rows × 14 cols
# [GLAD] 통합 재무분석 종료
# ================================================================================
# ✓ Saved GLAD data: 18 dates x 14 items
# ✓ GLAD (GLADSTONE CAPITAL CORP) 저장 완료
#
# === [66/1000] FIP 처리 시작 ===
# ================================================================================
# [FIP] 통합 재무분석 시작
# ✓ Entity: FTAI INFRASTRUCTURE INC. (CIK: 0001899883)
# ✓ EDGAR 정규화 DF: 19 rows × 25 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 19 rows × 25 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 19 rows × 37 cols
# [FIP] 통합 재무분석 종료
# ================================================================================
# ✓ Saved FIP data: 19 dates x 37 items
# ✓ FIP (FTAI INFRASTRUCTURE INC.) 저장 완료
#
# === [67/1000] DMAC 처리 시작 ===
# ================================================================================
# [DMAC] 통합 재무분석 시작
# ✓ Entity: DIAMEDICA THERAPEUTICS INC. (CIK: 1401040)
# ✓ EDGAR 정규화 DF: 33 rows × 21 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 33 rows × 21 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 33 rows × 33 cols
# [DMAC] 통합 재무분석 종료
# ================================================================================
# ✓ Saved DMAC data: 33 dates x 33 items
# ✓ DMAC (DIAMEDICA THERAPEUTICS INC.) 저장 완료
#
# === [68/1000] IBEX 처리 시작 ===
# ================================================================================
# [IBEX] 통합 재무분석 시작
# ✓ Entity: IBEX LIMITED (CIK: 1720420)
# ✓ EDGAR 정규화 DF: 16 rows × 27 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 16 rows × 27 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 16 rows × 39 cols
# [IBEX] 통합 재무분석 종료
# ================================================================================
# ✓ Saved IBEX data: 16 dates x 39 items
# ✓ IBEX (IBEX LIMITED) 저장 완료
#
# === [69/1000] CLNE 처리 시작 ===
# ================================================================================
# [CLNE] 통합 재무분석 시작
# ✓ Entity: CLEAN ENERGY FUELS CORP. (CIK: 1368265)
# ✓ EDGAR 정규화 DF: 64 rows × 25 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 64 rows × 25 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 64 rows × 38 cols
# [CLNE] 통합 재무분석 종료
# ================================================================================
# ✓ Saved CLNE data: 64 dates x 38 items
# ✓ CLNE (CLEAN ENERGY FUELS CORP.) 저장 완료
#
# === [70/1000] DOMO 처리 시작 ===
# ================================================================================
# [DOMO] 통합 재무분석 시작
# ✓ Entity: DOMO, INC. (CIK: 1505952)
# ✓ EDGAR 정규화 DF: 35 rows × 25 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 35 rows × 25 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 35 rows × 38 cols
# [DOMO] 통합 재무분석 종료
# ================================================================================
# ✓ Saved DOMO data: 35 dates x 38 items
# ✓ DOMO (DOMO, INC.) 저장 완료
#
# === [71/1000] KIDS 처리 시작 ===
# ================================================================================
# [KIDS] 통합 재무분석 시작
# ✓ Entity: OrthoPediatrics Corp (CIK: 1425450)
# ✓ EDGAR 정규화 DF: 41 rows × 31 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 41 rows × 31 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 41 rows × 47 cols
# [KIDS] 통합 재무분석 종료
# ================================================================================
# ✓ Saved KIDS data: 41 dates x 47 items
# ✓ KIDS (OrthoPediatrics Corp) 저장 완료
#
# === [72/1000] POM 처리 시작 ===
# ================================================================================
# [POM] 통합 재무분석 시작
# ✗ EDGAR Company Facts 로딩 실패 (POM): Company Facts 요청 실패: 404 https://data.sec.gov/api/xbrl/companyfacts/CIK0001877971.json
# ⚠ POM: 분석 결과 없음, 스킵
#
# === [73/1000] CLMB 처리 시작 ===
# ================================================================================
# [CLMB] 통합 재무분석 시작
# ✓ Entity: Climb Global Solutions, Inc. (CIK: 945983)
# ✓ EDGAR 정규화 DF: 64 rows × 26 cols
# ...
# ✓ EDGAR 정규화 DF: 5 rows × 11 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 5 rows × 11 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 5 rows × 21 cols
# [IPODU] 통합 재무분석 종료
# ================================================================================
# ✓ Saved IPODU data: 5 dates x 21 items
# ✓ IPODU (DUNE ACQUISITION CORPORATION II) 저장 완료
#
# === [708/1000] CGEN 처리 시작 ===
# ================================================================================
# [CGEN] 통합 재무분석 시작
# ✓ Entity: COMPUGEN LTD. (CIK: 1119774)
# ✓ EDGAR 정규화 DF: 32 rows × 23 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 32 rows × 23 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 32 rows × 36 cols
# [CGEN] 통합 재무분석 종료
# ================================================================================
# ✓ Saved CGEN data: 32 dates x 36 items
# ✓ CGEN (COMPUGEN LTD.) 저장 완료
#
# === [709/1000] HAVAU 처리 시작 ===
# ================================================================================
# [HAVAU] 통합 재무분석 시작
# ✓ Entity: Harvard Ave Acquisition Corporation (CIK: 0002042460)
# ✓ EDGAR 정규화 DF: 5 rows × 8 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 5 rows × 8 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 5 rows × 17 cols
# [HAVAU] 통합 재무분석 종료
# ================================================================================
# ✓ Saved HAVAU data: 5 dates x 17 items
# ✓ HAVAU (Harvard Ave Acquisition Corporation) 저장 완료
#
# === [710/1000] NXXT 처리 시작 ===
# ================================================================================
# [NXXT] 통합 재무분석 시작
# ✓ Entity: NextNRG, Inc. (CIK: 1817004)
# ✓ EDGAR 정규화 DF: 24 rows × 27 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 24 rows × 27 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 24 rows × 42 cols
# [NXXT] 통합 재무분석 종료
# ================================================================================
# ✓ Saved NXXT data: 24 dates x 42 items
# ✓ NXXT (NextNRG, Inc.) 저장 완료
#
# === [711/1000] INAC 처리 시작 ===
# ================================================================================
# [INAC] 통합 재무분석 시작
# ✓ Entity: INDIGO ACQUISITION CORP. (CIK: 0002063816)
# ✓ EDGAR 정규화 DF: 6 rows × 10 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 6 rows × 10 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 6 rows × 20 cols
# [INAC] 통합 재무분석 종료
# ================================================================================
# ✓ Saved INAC data: 6 dates x 20 items
# ✓ INAC (INDIGO ACQUISITION CORP.) 저장 완료
#
# === [712/1000] ESOA 처리 시작 ===
# ================================================================================
# [ESOA] 통합 재무분석 시작
# ✓ Entity: Energy Services of America CORP (CIK: 1357971)
# ✓ EDGAR 정규화 DF: 62 rows × 29 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 62 rows × 29 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 62 rows × 42 cols
# [ESOA] 통합 재무분석 종료
# ================================================================================
# ✓ Saved ESOA data: 62 dates x 42 items
# ✓ ESOA (Energy Services of America CORP) 저장 완료
#
# === [713/1000] LBTYB 처리 시작 ===
# ================================================================================
# [LBTYB] 통합 재무분석 시작
# ✓ Entity: Liberty Global Ltd. (CIK: 1570585)
# ✓ EDGAR 정규화 DF: 57 rows × 27 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 57 rows × 27 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 57 rows × 39 cols
# [LBTYB] 통합 재무분석 종료
# ================================================================================
# ✓ Saved LBTYB data: 57 dates x 39 items
# ✓ LBTYB (Liberty Global Ltd.) 저장 완료
#
# === [714/1000] RCMT 처리 시작 ===
# ================================================================================
# [RCMT] 통합 재무분석 시작
# ✓ Entity: RCM TECHNOLOGIES, INC. (CIK: 700841)
# ✓ EDGAR 정규화 DF: 66 rows × 26 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 66 rows × 26 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 66 rows × 39 cols
# [RCMT] 통합 재무분석 종료
# ================================================================================
# ✓ Saved RCMT data: 66 dates x 39 items
# ✓ RCMT (RCM TECHNOLOGIES, INC.) 저장 완료
#
# === [715/1000] SPWR 처리 시작 ===
# ================================================================================
# [SPWR] 통합 재무분석 시작
# ✓ Entity: COMPLETE SOLARIA, INC. (CIK: 1838987)
# ✓ EDGAR 정규화 DF: 21 rows × 31 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 21 rows × 31 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 21 rows × 47 cols
# [SPWR] 통합 재무분석 종료
# ================================================================================
# ✓ Saved SPWR data: 21 dates x 47 items
# ✓ SPWR (COMPLETE SOLARIA, INC.) 저장 완료
#
# === [716/1000] LAKE 처리 시작 ===
# ================================================================================
# [LAKE] 통합 재무분석 시작
# ✓ Entity: LAKELAND INDUSTRIES, INC. (CIK: 798081)
# ✓ EDGAR 정규화 DF: 63 rows × 29 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 63 rows × 29 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 63 rows × 45 cols
# [LAKE] 통합 재무분석 종료
# ================================================================================
# ✓ Saved LAKE data: 63 dates x 45 items
# ✓ LAKE (LAKELAND INDUSTRIES, INC.) 저장 완료
#
# === [717/1000] EMPG 처리 시작 ===
# ================================================================================
# [EMPG] 통합 재무분석 시작
# ✓ Entity:  (CIK: 0002005569)
# ⚠ EDGAR 정규화 DF가 비어 있습니다 (EMPG)
# ✓ EDGAR 정규화 DF: 0 rows × 0 cols
# ⚠ EDGAR 입력 DF가 비어있습니다. WRDS만으로 구성합니다.
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ⚠ WRDS 보완 후에도 DF가 비어 있습니다 (EMPG)
# ⚠ EMPG: 분석 결과 없음, 스킵
#
# === [718/1000] IMMX 처리 시작 ===
# ================================================================================
# [IMMX] 통합 재무분석 시작
# ✓ Entity: IMMIX BIOPHARMA, INC. (CIK: 0001873835)
# ✓ EDGAR 정규화 DF: 22 rows × 23 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 22 rows × 23 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 22 rows × 33 cols
# [IMMX] 통합 재무분석 종료
# ================================================================================
# ✓ Saved IMMX data: 22 dates x 33 items
# ✓ IMMX (IMMIX BIOPHARMA, INC.) 저장 완료
#
# === [719/1000] GEOS 처리 시작 ===
# ================================================================================
# [GEOS] 통합 재무분석 시작
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[29], line 97
#      94 rate_limiter.wait_if_needed()
#      96 try:
# ---> 97     result = analyzer.analyze(ticker, headers=headers, table_name="us_fundq")
#      98     if result is None:
#      99         print(f"⚠ {ticker}: 분석 결과 없음, 스킵")
#
# File ~\OneDrive\바탕 화면\investment\investment_strategy\US_Market\collect\sec_data_pipeline\valuation\integrated_financial_analyzer_mysql_fixed.py:52, in IntegratedFinancialAnalyzer.analyze(self, ticker, headers, table_name)
#      48 # ------------------------------------------------------------------
#      49 # STEP 1: EDGAR Company Facts 로딩
#      50 # ------------------------------------------------------------------
#      51 try:
# ---> 52     facts = fetch_company_facts(ticker, headers=headers)
#      53 except Exception as e:
#      54     print(f"✗ EDGAR Company Facts 로딩 실패 ({ticker}): {e}")
#
# File ~\OneDrive\바탕 화면\investment\investment_strategy\US_Market\collect\sec_data_pipeline\collectors\sec_utils.py:66, in fetch_company_facts(ticker_or_cik, headers)
#      65 def fetch_company_facts(ticker_or_cik: str, headers: dict) -> dict:
# ---> 66     cik = resolve_cik(ticker_or_cik, headers=headers)
#      67     url = f"https://data.sec.gov/api/xbrl/companyfacts/CIK{cik}.json"
#      68     # 간단 retry
#
# File ~\OneDrive\바탕 화면\investment\investment_strategy\US_Market\collect\sec_data_pipeline\collectors\sec_utils.py:42, in resolve_cik(ticker_or_cik, headers, cache)
#      40 for url_map in url_candidates:
#      41     for attempt in range(3):
# ---> 42         r = requests.get(url_map, headers=headers, timeout=15)
#      43         last_status = r.status_code
#      44         if r.status_code == 200:
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\requests\adapters.py:644, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     641     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     643 try:
# --> 644     resp = conn.urlopen(
#     645         method=request.method,
#     646         url=url,
#     647         body=request.body,
#     648         headers=request.headers,
#     649         redirect=False,
#     650         assert_same_host=False,
#     651         preload_content=False,
#     652         decode_content=False,
#     653         retries=self.max_retries,
#     654         timeout=timeout,
#     655         chunked=chunked,
#     656     )
#     658 except (ProtocolError, OSError) as err:
#     659     raise ConnectionError(err, request=request)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\urllib3\connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\urllib3\connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     532 # Receive the response from the server
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#     536     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\urllib3\connection.py:565, in HTTPConnection.getresponse(self)
#     562 _shutdown = getattr(self.sock, "shutdown", None)
#     564 # Get the response from http.client.HTTPConnection
# --> 565 httplib_response = super().getresponse()
#     567 try:
#     568     assert_header_parsing(httplib_response.msg)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\http\client.py:1377, in HTTPConnection.getresponse(self)
#    1375 try:
#    1376     try:
# -> 1377         response.begin()
#    1378     except ConnectionError:
#    1379         self.close()
#
# File ~\AppData\Local\Programs\Python\Python39\lib\http\client.py:320, in HTTPResponse.begin(self)
#     318 # read until we get a non-100 response
#     319 while True:
# --> 320     version, status, reason = self._read_status()
#     321     if status != CONTINUE:
#     322         break
#
# File ~\AppData\Local\Programs\Python\Python39\lib\http\client.py:281, in HTTPResponse._read_status(self)
#     280 def _read_status(self):
# --> 281     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     282     if len(line) > _MAXLINE:
#     283         raise LineTooLong("status line")
#
# File ~\AppData\Local\Programs\Python\Python39\lib\socket.py:704, in SocketIO.readinto(self, b)
#     702 while True:
#     703     try:
# --> 704         return self._sock.recv_into(b)
#     705     except timeout:
#     706         self._timeout_occurred = True
#
# File ~\AppData\Local\Programs\Python\Python39\lib\ssl.py:1241, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1237     if flags != 0:
#    1238         raise ValueError(
#    1239           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240           self.__class__)
# -> 1241     return self.read(nbytes, buffer)
#    1242 else:
#    1243     return super().recv_into(buffer, nbytes, flags)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\ssl.py:1099, in SSLSocket.read(self, len, buffer)
#    1097 try:
#    1098     if buffer is not None:
# -> 1099         return self._sslobj.read(len, buffer)
#    1100     else:
#    1101         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
import pandas as pd
import pymysql
from typing import Dict, Optional, List


def quarter_end_from_report_date(report_date: pd.Timestamp) -> pd.Timestamp:
    y = report_date.year
    m = report_date.month

    if m in [1, 2, 3]:
        return pd.Timestamp(f"{y}-03-31")
    elif m in [4, 5, 6]:
        return pd.Timestamp(f"{y}-06-30")
    elif m in [7, 8, 9]:
        return pd.Timestamp(f"{y}-09-30")
    else:
        return pd.Timestamp(f"{y}-12-31")


def fetch_sec_financial_pivot_fixed(
    db_info: Dict[str, any],
    ticker: str,
    table_name: str = "sec_financial_data",
    start_date: Optional[str] = None,
    end_date: Optional[str] = None,
    item_list: Optional[List[str]] = None,
) -> pd.DataFrame:

    conn = pymysql.connect(
        host=db_info["host"], port=db_info.get("port", 3306),
        user=db_info["user"], password=db_info["password"],
        database=db_info["database"], charset="utf8mb4"
    )

    # -----------------------------
    # 1) 데이터 로드
    # -----------------------------
    try:
        where_clause = ["ticker=%s"]
        params = [ticker]

        if start_date:
            where_clause.append("date >= %s")
            params.append(start_date)
        if end_date:
            where_clause.append("date <= %s")
            params.append(end_date)
        if item_list:
            placeholders = ",".join(["%s"] * len(item_list))
            where_clause.append(f"item_name IN ({placeholders})")
            params.extend(item_list)

        where_sql = " AND ".join(where_clause)

        sql = f"""
            SELECT date, ticker, item_name, value
            FROM {table_name}
            WHERE {where_sql}
            ORDER BY date, item_name
        """

        df = pd.read_sql(sql, conn, params=params)
    finally:
        conn.close()

    if df.empty:
        print(f"[INFO] {ticker} 데이터 없음")
        return df

    # -----------------------------
    # 2) 기존 date → report_date로 이름 변경
    # -----------------------------
    df = df.rename(columns={"date": "report_date"})
    df["report_date"] = pd.to_datetime(df["report_date"])

    # -----------------------------
    # 3) report_date → 분기말 날짜(date)
    # -----------------------------
    df["date"] = df["report_date"].apply(quarter_end_from_report_date)

    # (중복 가능성 대비) 각 분기(date, ticker)별 대표 report_date 하나 선택
    # 여기서는 가장 늦은 날짜(max) 사용
    rep_dates = (
        df[["date", "ticker", "report_date"]]
        .drop_duplicates()
        .groupby(["date", "ticker"], as_index=False)["report_date"]
        .max()
    )

    # -----------------------------
    # 4) pivot 변환 (분기말 기준 wide)
    # -----------------------------
    df_pivot = df.pivot_table(
        index=["date", "ticker"],
        columns="item_name",
        values="value",
        aggfunc="last"
    ).sort_index()

    df_pivot = df_pivot.reset_index()

    # -----------------------------
    # 5) 대표 report_date 다시 붙이기
    # -----------------------------
    df_pivot = df_pivot.merge(rep_dates, how="left", on=["date", "ticker"])

    # 보기 편하게 컬럼 순서 조정: date, report_date, ticker, 나머지 item 들
    cols = ["date", "report_date", "ticker"] + [
        c for c in df_pivot.columns if c not in ("date", "report_date", "ticker")
    ]
    df_pivot = df_pivot[cols]

    return df_pivot

# %%
# 1) AAPL 전체 기간, 모든 item_name
fs_df = fetch_sec_financial_pivot_fixed(db_info, "NVDA")
fs_df

# 2) 기간 제한 + 특정 항목만
# item_list = ["revenue", "net_income", "total_assets", "ROE", "OPM"]
# aapl_subset = fetch_sec_financial_pivot(
#     db_info,
#     "AAPL",
#     start_date="2015-01-01",
#     end_date="2024-12-31",
#     item_list=item_list
# )
# print(aapl_subset.tail())
# Out:
#          date report_date ticker  accounts_payable  accounts_receivable  \
# 0  2007-03-31  2007-01-28   NVDA               NaN                  NaN
# 1  2008-03-31  2008-01-27   NVDA               NaN                  NaN
# 2  2008-09-30  2008-07-27   NVDA               NaN                  NaN
# 3  2008-12-31  2008-10-26   NVDA               NaN                  NaN
# 4  2009-03-31  2009-01-25   NVDA      2.188640e+08         3.184350e+08
# ..        ...         ...    ...               ...                  ...
# 67 2024-12-31  2024-10-27   NVDA      5.353000e+09         1.769300e+10
# 68 2025-03-31  2025-01-26   NVDA      6.310000e+09         2.306500e+10
# 69 2025-06-30  2025-04-27   NVDA      7.331000e+09         2.213200e+10
# 70 2025-09-30  2025-07-27   NVDA      9.064000e+09         2.780800e+10
# 71 2025-12-31  2025-10-26   NVDA      8.624000e+09         3.339100e+10
#
#     accrued_liabilities  accumulated_depreciation  asset_turnover  \
# 0                   NaN                       NaN             NaN
# 1                   NaN                       NaN             NaN
# 2                   NaN                       NaN             NaN
# 3                   NaN                       NaN             NaN
# 4          5.597270e+08                       NaN             NaN
# ..                  ...                       ...             ...
# 67         1.112600e+10              3.509000e+09        0.041356
# 68         1.173700e+10              4.401000e+09        0.035020
# 69         1.921100e+10              4.401000e+09        0.030693
# 70         1.519300e+10              4.401000e+09        0.027482
# 71         1.645200e+10              4.401000e+09        0.024148
#
#     capital_expenditures          cash  ...  receivables_turnover  \
# 0                    NaN  5.444140e+08  ...                   NaN
# 1                    NaN  7.269690e+08  ...                   NaN
# 2                    NaN  7.191430e+08  ...                   NaN
# 3                    NaN  4.612530e+08  ...                   NaN
# 4                    NaN  4.176880e+08  ...                   NaN
# ..                   ...           ...  ...                   ...
# 67           155000000.0  9.107000e+09  ...              0.238828
# 68           155000000.0  8.589000e+09  ...              0.187818
# 69           155000000.0  1.523400e+10  ...              0.180016
# 70           155000000.0  1.163900e+10  ...              0.148069
# 71           155000000.0  1.148600e+10  ...              0.121564
#
#     research_development       revenue       roa       roe      roic  \
# 0                    NaN           NaN       NaN       NaN       NaN
# 1                    NaN           NaN       NaN       NaN       NaN
# 2           2.129100e+08           NaN       NaN  -4.61929       NaN
# 3           2.123600e+08           NaN       NaN   2.67028       NaN
# 4           2.123600e+08           NaN   1.84282   2.80573   1.77199
# ..                   ...           ...       ...       ...       ...
# 67          3.390000e+09  3.105000e+09  25.71770  38.94360  38.75680
# 68          3.390000e+09  3.105000e+09  21.77760  31.57520  31.53000
# 69          3.989000e+09  3.105000e+09  18.55920  28.23630  29.14320
# 70          4.291000e+09  3.105000e+09  23.38570  33.38470  32.16330
# 71          4.705000e+09  3.105000e+09  24.81710  34.53540  35.33220
#
#     short_term_debt  stockholders_equity  total_assets  total_liabilities
# 0               NaN         2.006920e+09           NaN                NaN
# 1               NaN         2.617910e+09           NaN                NaN
# 2               NaN         2.617910e+09           NaN                NaN
# 3               NaN         2.617910e+09           NaN                NaN
# 4               NaN         2.394650e+09  3.350730e+09                NaN
# ..              ...                  ...           ...                ...
# 67              0.0         6.589900e+10  9.601300e+10       3.011400e+10
# 68              0.0         7.932700e+10  1.116010e+11       3.227400e+10
# 69              0.0         8.384300e+10  1.252540e+11       4.141100e+10
# 70              0.0         1.001310e+11  1.407400e+11       4.060900e+10
# 71      999000000.0         1.188970e+11  1.611480e+11       4.225100e+10
#
# [72 rows x 51 columns]

# %%
aapl_df.columns.tolist()
# Out:
# ['date',
#  'ticker',
#  'accounts_payable',
#  'accounts_receivable',
#  'accrued_liabilities',
#  'accumulated_depreciation',
#  'asset_turnover',
#  'capital_expenditures',
#  'cash',
#  'cost_of_revenue',
#  'current_assets',
#  'current_liabilities',
#  'current_ratio',
#  'days_inventory',
#  'days_receivables',
#  'debt_to_assets',
#  'debt_to_equity',
#  'deferred_revenue',
#  'depreciation_amortization',
#  'equity_multiplier',
#  'goodwill',
#  'gross_margin',
#  'gross_profit',
#  'income_tax_expense',
#  'intangible_assets',
#  'interest_expense',
#  'interest_income',
#  'inventory',
#  'inventory_turnover',
#  'long_term_debt',
#  'long_term_debt_current',
#  'net_income',
#  'net_margin',
#  'net_ppe',
#  'operating_expenses',
#  'operating_income',
#  'operating_margin',
#  'other_noncurrent_assets',
#  'pretax_income',
#  'quick_ratio',
#  'receivables_turnover',
#  'research_development',
#  'revenue',
#  'roa',
#  'roe',
#  'roic',
#  'short_term_debt',
#  'stockholders_equity',
#  'total_assets',
#  'total_liabilities']

# %%
# 1) EDGAR 수집/정규화
headers = {"User-Agent": "HoyoungPark Research <stox1224@email.com>"}
facts   = fetch_company_facts( TICKER, headers=headers)
parser  = CompanyFactsParser(facts)
normal  = FinancialNormalizer(parser)
edgar_df = normal.create_normalized_dataframe(period_type="quarterly")

# 2) WRDS Validator
db_info = {
    "host": get_db_host(),
    "port": 3307,
    "user": "stox7412",
    "password": "Apt106503!~",
    "database": "investar",
}
validator = WRDSDataValidator(db_info)

import sqlalchemy as sa

# ① EDGAR 분기 DF 준비 (이미 갖고 계신 df: edgar_df)
#    edgar_df.index = 분기 날짜, 컬럼에 'revenue' 포함

# ② WRDS(us_fundq)에서 AAPL의 edate, ticker, saleq 로드
db_info = {
    "host": "192.168.0.230",
    "port": 3307,
    "user": "stox7412",
    "password": "Apt106503!~",
    "database": "investar",
}

# %%
tickers = get_filtered_us_tickers()
# Out:
# 100%|██████████| 3774/3774 [00:04<00:00, 840.90it/s]
# 100%|██████████| 2745/2745 [00:02<00:00, 1050.06it/s]
# 100%|██████████| 294/294 [00:00<00:00, 1034.88it/s]
# 제외된 기업 수: 1812
# 남은 기업 수: 5001
# 티커 수: 5001

# %%
ticker_list = tickers[:10]
# Out:
# ['NVDA',
#  'AAPL',
#  'MSFT',
#  'AMZN',
#  'GOOGL',
#  'AVGO',
#  'GOOG',
#  'META',
#  'TSLA',
#  'NFLX']

# %%
import pandas as pd

# 1. 클라이언트 및 다운로더 설정
user_agent = "PersonalResearch stox1224@email.com"
client = SECAPIClient(user_agent, RateLimiter(10, 1.0))
downloader = BulkDownloader(client, output_dir="./sec_data", max_workers=3)

# 2. 다운로드할 기업 리스트
# tickers = ['AAPL', 'MSFT', 'GOOGL', 'AMZN', 'TSLA', 'NVDA', 'META']

# 3. 배치 다운로드 (자동으로 JSON 파일 저장)
results = downloader.download_company_facts_batch(ticker_list)

# 4. 각 기업별 데이터 처리
all_financials = {}

for ticker, company_facts in results.items():
    headers = {"User-Agent": "HoyoungPark Research <stox1224@email.com>"}
    facts   = fetch_company_facts(ticker, headers=headers)
    parser  = CompanyFactsParser(facts)
    normal  = FinancialNormalizer(parser)
    edgar_df = normal.create_normalized_dataframe(period_type="quarterly")


    parser = CompanyFactsParser(company_facts)
    normalizer = FinancialNormalizer(parser)

    # 재무데이터 정규화
    df = normalizer.create_normalized_dataframe(period_type='quarterly')
    df_billions = normalizer.convert_to_billions(df)

    all_financials[ticker] = df_billions

    # 개별 CSV 저장
    # normalizer.export_to_csv(df_billions, f'{ticker}_financials.csv')

print(f"총 {len(all_financials)}개 기업 데이터 수집 완료")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 5
#       3 # 1. 클라이언트 및 다운로더 설정
#       4 user_agent = "PersonalResearch stox1224@email.com"
# ----> 5 client = SECAPIClient(user_agent, RateLimiter(10, 1.0))
#       6 downloader = BulkDownloader(client, output_dir="./sec_data", max_workers=3)
#       8 # 2. 다운로드할 기업 리스트
#       9 # tickers = ['AAPL', 'MSFT', 'GOOGL', 'AMZN', 'TSLA', 'NVDA', 'META']
#      10
#      11 # 3. 배치 다운로드 (자동으로 JSON 파일 저장)
#
# NameError: name 'SECAPIClient' is not defined

# %%
TICKER = "GLW"   # ← 여기만 바꾸면 전체가 따라옵니

# 1) EDGAR 수집/정규화
headers = {"User-Agent": "HoyoungPark Research <stox1224@email.com>"}
facts   = fetch_company_facts( TICKER, headers=headers)
parser  = CompanyFactsParser(facts)
normal  = FinancialNormalizer(parser)
edgar_df = normal.create_normalized_dataframe(period_type="quarterly")

# 2) WRDS Validator
db_info = {
    "host": get_db_host(),
    "port": 3307,
    "user": "stox7412",
    "password": "Apt106503!~",
    "database": "investar",
}
validator = WRDSDataValidator(db_info)

# 3) 결합/보완 실행 (핵심: table_name='us_fundq', date_col='edate')
result_df = validator.validate_and_fill_improved(
    edgar_df=edgar_df,
    ticker= TICKER,
    table_name="us_fundq",   # 당신 DB 테이블
    days_tolerance=15,
    verbose=True,
    ticker_col="ticker",     # 당신 DB 컬럼
    date_col="edate"         # 당신 DB 컬럼
)

import sqlalchemy as sa

# ① EDGAR 분기 DF 준비 (이미 갖고 계신 df: edgar_df)
#    edgar_df.index = 분기 날짜, 컬럼에 'revenue' 포함

# ② WRDS(us_fundq)에서 AAPL의 edate, ticker, saleq 로드
db_info = {
    "host": "192.168.0.230",
    "port": 3307,
    "user": "stox7412",
    "password": "Apt106503!~",
    "database": "investar",
}
df_wrds = fetch_wrds_fundq_sample(
    db_info, ticker=TICKER , columns=["edate", "ticker", "saleq"], table_name="US_fundq"
)

# ③ 결측 보완 + 단위 정합
filled_df = fill_revenue_with_wrds(
    edgar_df=edgar_df,
    wrds_df=df_wrds,
    wrds_value_col="saleq",     # WRDS의 분기 매출 컬럼명
    days_tolerance=20,          # 분기말 근접 허용일
    verbose=True
)

print("\n[CHECK] revenue NaN:")
print("  before:", edgar_df["revenue"].isna().sum())
print("  after :", filled_df["revenue"].isna().sum())

if filled_df.empty:
    print("⚠ filled_df가 비어 있습니다 → result_df를 target_df로 대체합니다.")
    target_df = result_df.copy()
else:
    print("✓ filled_df가 유효합니다 → target_df에 filled_df를 사용합니다.")
    target_df = filled_df.copy()

from sec_data_pipeline.parsers.financial_normalizer import FinancialNormalizer


# parser는 EDGAR 데이터를 읽어온 CompanyFactsParser 등의 인스턴스
normalizer = FinancialNormalizer(parser=None)  # parser가 필요 없으면 None으로 두세요


# 1) 기본 추정: income_tax_expense / pretax_income
est = (filled_df.get('income_tax_expense') / filled_df.get('pretax_income'))

# 2) 이상치/음수/무한대 정리
est = est.replace([np.inf, -np.inf], np.nan)
# 적자 구간(pretax_income <= 0)은 추정치 제거
est = est.mask((filled_df.get('pretax_income') <= 0), np.nan)
# 0~0.5로 클리핑(50% 이상은 보통 이상치)
est = est.clip(lower=0.0, upper=0.3)

# 3) 결측 보강: 최근 값으로 보간 + 기본값 대체
# est = est.ffill().fillna(0.21)

# filled_df['tax_rate'] = 0.21
ratio = normal.calculate_financial_ratios(target_df)
# Out:
# ['NVDA',
#  'AAPL',
#  'MSFT',
#  'AMZN',
#  'GOOGL',
#  'AVGO',
#  'GOOG',
#  'META',
#  'TSLA',
#  'NFLX',
#  'COST',
#  'PLTR',
#  'ASML',
#  'AMD',
#  'CSCO',
#  'AZN',
#  'MU',
#  'TMUS',
#  'ISRG',
#  'SHOP',
#  'PEP',
#  'AMAT',
#  'LRCX',
#  'LIN',
#  'APP',
#  'AMGN',
#  'QCOM',
#  'INTC',
#  'PDD',
#  'BKNG',
#  'GILD',
#  'KLAC',
#  'TXN',
#  'ARM',
#  'ADBE',
#  'PANW',
#  'CRWD',
#  'ADI',
#  'SNY',
#  'HON',
#  'VRTX',
#  'MELI',
#  'ADP',
#  'SBUX',
#  'CMCSA',
#  'NTES',
#  'ORLY',
#  'DASH',
#  'REGN',
#  'CDNS',
#  'MAR',
#  'SNPS',
#  'CTAS',
#  'MNST',
#  'MDLZ',
#  'MRVL',
#  'ABNB',
#  'CSX',
#  'ADSK',
#  'WDAY',
#  'IDXX',
#  'FTNT',
#  'TRI',
#  'ROST',
#  'PYPL',
#  'STX',
#  'WBD',
#  'ALNY',
#  'ARGX',
#  'DDOG',
#  'PCAR',
#  'WDC',
#  'EA',
#  'MSTR',
#  'BKR',
#  'NXPI',
#  'ROP',
#  'FER',
#  'JD',
#  'ZS',
#  'FAST',
#  'TCOM',
#  'SYM',
#  'TTWO',
#  'INSM',
#  'MPWR',
#  'FANG',
#  'AXON',
#  'CCEP',
#  'BIDU',
#  'PAYX',
#  'TEAM',
#  'CPRT',
#  'EBAY',
#  'CTSH',
#  'ONC',
#  'KDP',
#  'GEHC',
#  'CRWV',
#  'RYAAY',
#  'KMB',
#  'FISV',
#  'NTRA',
#  'SNDK',
#  'UAL',
#  'EXPE',
#  'VRSK',
#  'KHC',
#  'CSGP',
#  'ERIC',
#  'VOD',
#  'TSCO',
#  'ODFL',
#  'MCHP',
#  'FSLR',
#  'EXE',
#  'MDB',
#  'BIIB',
#  'CRDO',
#  'TER',
#  'CHTR',
#  'ZM',
#  'ALAB',
#  'DXCM',
#  'BNTX',
#  'VRSN',
#  'ULTA',
#  'PODD',
#  'RPRX',
#  'RKLB',
#  'CYBR',
#  'NBIS',
#  'NTAP',
#  'ESLT',
#  'DLTR',
#  'GRAB',
#  'FLEX',
#  'FWONK',
#  'LULU',
#  'CASY',
#  'SSNC',
#  'UTHR',
#  'INCY',
#  'PTC',
#  'LITE',
#  'SATS',
#  'CHKP',
#  'ASTS',
#  'ILMN',
#  'LI',
#  'ON',
#  'SMCI',
#  'GMAB',
#  'TRMB',
#  'GFS',
#  'EXAS',
#  'RIVN',
#  'TTD',
#  'CDW',
#  'CHRW',
#  'LOGI',
#  'WWD',
#  'MEDP',
#  'FTAI',
#  'PSKY',
#  'HOLX',
#  'GEN',
#  'JBHT',
#  'NTNX',
#  'DKNG',
#  'COO',
#  'WMG',
#  'RVMD',
#  'ROIV',
#  'NBIX',
#  'OKTA',
#  'HTHT',
#  'DPZ',
#  'GH',
#  'ROKU',
#  'FFIV',
#  'AVAV',
#  'TEM',
#  'DOCU',
#  'FOX',
#  'BBIO',
#  'FOXA',
#  'MDGL',
#  'NDSN',
#  'NXT',
#  'ICLR',
#  'WYNN',
#  'SMMT',
#  'IONS',
#  'LECO',
#  'AKAM',
#  'VNOM',
#  'ASND',
#  'KTOS',
#  'ZBRA',
#  'JKHY',
#  'BSY',
#  'MTSI',
#  'PAA',
#  'VTRS',
#  'TXRH',
#  'EXEL',
#  'HAS',
#  'BILI',
#  'ENTG',
#  'CART',
#  'TSEM',
#  'JAZZ',
#  'ENSG',
#  'BMRN',
#  'COKE',
#  'RNA',
#  'MANH',
#  'ALGN',
#  'SAIL',
#  'BZ',
#  'CELH',
#  'TECH',
#  'STRL',
#  'MKSI',
#  'RMBS',
#  'MRNA',
#  'RGEN',
#  'NWSA',
#  'FYBR',
#  'SWKS',
#  'ABVX',
#  'LSCC',
#  'PEGA',
#  'IDCC',
#  'MBLY',
#  'POOL',
#  'HQY',
#  'CPB',
#  'FIVE',
#  'DRS',
#  'TIGO',
#  'NVMI',
#  'TTEK',
#  'HSIC',
#  'PPC',
#  'AAL',
#  'MORN',
#  'RGTI',
#  'HALO',
#  'APA',
#  'OTEX',
#  'NUVL',
#  'CORT',
#  'SANM',
#  'DOX',
#  'SFD',
#  'AMKR',
#  'TTAN',
#  'CYTK',
#  'APPF',
#  'DUOL',
#  'IESC',
#  'PCTY',
#  'SFM',
#  'MTCH',
#  'MASI',
#  'LYFT',
#  'QRVO',
#  'AEIS',
#  'GSAT',
#  'DBX',
#  'AAON',
#  'CFLT',
#  'MNDY',
#  'LKQ',
#  'AUR',
#  'AXSM',
#  'OLLI',
#  'CHDN',
#  'BRKR',
#  'SITM',
#  'VFS',
#  'SAIA',
#  'SOLS',
#  'FROG',
#  'WING',
#  'MRUS',
#  'RYTM',
#  'FIGR',
#  'CAI',
#  'NTSK',
#  'TTMI',
#  'DSGX',
#  'WAY',
#  'SIRI',
#  'LNW',
#  'COGT',
#  'MMYT',
#  'CDTX',
#  'GTLB',
#  'QMMM',
#  'GDS',
#  'GLBE',
#  'PTCT',
#  'SMTC',
#  'PCVX',
#  'BTSG',
#  'SRAD',
#  'MAT',
#  'RDNT',
#  'NICE',
#  'ARWR',
#  'CGNX',
#  'EXLS',
#  'LFUS',
#  'KRYS',
#  'LIF',
#  'CWST',
#  'RRR',
#  'URBN',
#  'IRTC',
#  'CRUS',
#  'ROAD',
#  'MIDD',
#  'BLLN',
#  'LBRDK',
#  'NXST',
#  'PTGX',
#  'RGC',
#  'OLED',
#  'CVLT',
#  'NWS',
#  'UFPI',
#  'TGTX',
#  'WFRD',
#  'CHRD',
#  'LEGN',
#  'MMSI',
#  'WIX',
#  'REYN',
#  'ATAT',
#  'CRSP',
#  'DOOO',
#  'QLYS',
#  'OS',
#  'BCPC',
#  'LLYVK',
#  'SOUN',
#  'TMDX',
#  'PI',
#  'GNTX',
#  'OPCH',
#  'SHC',
#  'APGE',
#  'WGS',
#  'ALKS',
#  'ALGM',
#  'KYMR',
#  'LGN',
#  'CAMT',
#  'CAR',
#  'IEP',
#  'PONY',
#  'CVCO',
#  'CCC',
#  'MZTI',
#  'PRAX',
#  'NAMS',
#  'CELC',
#  'ADMA',
#  'OSIS',
#  'OMAB',
#  'CZR',
#  'LSTR',
#  'AKRO',
#  'VSAT',
#  'BLTE',
#  'LAUR',
#  'ITRI',
#  'PLBL',
#  'LOPE',
#  'RUN',
#  'CROX',
#  'COMM',
#  'VSEC',
#  'LCID',
#  'EOSE',
#  'CRNX',
#  'FELE',
#  'SRRK',
#  'CNTA',
#  'ACLX',
#  'GRAL',
#  'IMVT',
#  'MRCY',
#  'DORM',
#  'INDV',
#  'ACAD',
#  'FORM',
#  'CLBT',
#  'CALM',
#  'SLAB',
#  'VKTX',
#  'LGND',
#  'NOVT',
#  'SKYW',
#  'SAIC',
#  'VICR',
#  'KC',
#  'LNTH',
#  'AMRX',
#  'VCYT',
#  'VIAV',
#  'FTDR',
#  'AMBA',
#  'PSMT',
#  'AVT',
#  'ALHC',
#  'VRNS',
#  'PLXS',
#  'DLO',
#  'CRVL',
#  'POWL',
#  'ARQT',
#  'ICUI',
#  'GLNG',
#  'NAVN',
#  'MIRM',
#  'VEON',
#  'CGON',
#  'PAGP',
#  'ENPH',
#  'EXPO',
#  'PATK',
#  'AGYS',
#  'WSHP',
#  'IRON',
#  'MLCO',
#  'FRSH',
#  'LIVN',
#  'VRRM',
#  'CARG',
#  'BL',
#  'INTA',
#  'XENE',
#  'MYRG',
#  'KYIV',
#  'TARS',
#  'MLYS',
#  'JOYY',
#  'IPGP',
#  'TLX',
#  'ATEC',
#  'KNSA',
#  'RARE',
#  'TVTX',
#  'GTX',
#  'FIZZ',
#  'TENB',
#  'VERX',
#  'BRZE',
#  'RUSHA',
#  'SPSC',
#  'APPN',
#  'IDYA',
#  'ONDS',
#  'ASO',
#  'ADPT',
#  'ARLP',
#  'FLNC',
#  'EEFT',
#  'FOLD',
#  'AAPG',
#  'PRVA',
#  'COCO',
#  'SHOO',
#  'DJT',
#  'VRDN',
#  'GTM',
#  'CSQ',
#  'DYN',
#  'XMTR',
#  'COLM',
#  'CPRX',
#  'SIMO',
#  'NCNO',
#  'HURN',
#  'PTON',
#  'VC',
#  'LQDA',
#  'DNLI',
#  'AVPT',
#  'HTFL',
#  'FLY',
#  'FRPT',
#  'PLUG',
#  'HWKN',
#  'MEOH',
#  'RELY',
#  'BLKB',
#  'STRC',
#  'SLNO',
#  'IAC',
#  'APLS',
#  'HSAI',
#  'TERN',
#  'SUPN',
#  'NSIT',
#  'WDFC',
#  'ALRM',
#  'CHA',
#  'PTRN',
#  'QUBT',
#  'SYNA',
#  'OCUL',
#  'LFST',
#  'IPAR',
#  'UPWK',
#  'MGRC',
#  'ACLS',
#  'EWTX',
#  'CHEF',
#  'WRD',
#  'BEAM',
#  'HCM',
#  'WB',
#  'FA',
#  'TXG',
#  'SPNS',
#  'GT',
#  'VNET',
#  'PLUS',
#  'DRVN',
#  'ODD',
#  'HUBG',
#  'CAKE',
#  'PINC',
#  'EXTR',
#  'MENS',
#  'PGNY',
#  'FORTY',
#  'RUM',
#  'KLIC',
#  'RXRX',
#  'SBLK',
#  'SYRE',
#  'ALKT',
#  'EYE',
#  'AVDL',
#  'GRFS',
#  'CSGS',
#  'ZLAB',
#  'ADUS',
#  'CNXC',
#  'SONO',
#  'XRAY',
#  'DBVT',
#  'SGRY',
#  'PTEN',
#  'TRMD',
#  'VCEL',
#  'ACMR',
#  'AUPH',
#  'ZBIO',
#  'IQ',
#  'MGNI',
#  'OSW',
#  'DIOD',
#  'DGNX',
#  'SEDG',
#  'JANX',
#  'GPCR',
#  'MESO',
#  'FWONA',
#  'GLPG',
#  'OLMA',
#  'IBRX',
#  'HRMY',
#  'PAYO',
#  'SRPT',
#  'IMCR',
#  'BATRK',
#  'ESTA',
#  'SMPL',
#  'SION',
#  'LBTYA',
#  'ZYME',
#  'SBET',
#  'LLYVA',
#  'NTCT',
#  'PENN',
#  'AVAH',
#  'SEZL',
#  'HBNB',
#  'ATRC',
#  'QDEL',
#  'WBTN',
#  'TWST',
#  'LMAT',
#  'DNTH',
#  'VERA',
#  'ANIP',
#  'NN',
#  'POWI',
#  'IOSP',
#  'NVTS',
#  'CECO',
#  'STRA',
#  'PRCT',
#  'PRDO',
#  'PAHC',
#  'PRGS',
#  'MCRI',
#  'TRIP',
#  'INOD',
#  'UFPT',
#  'JJSF',
#  'MAZE',
#  'VECO',
#  'CLDX',
#  'AZTA',
#  'QURE',
#  'CMPR',
#  'MCW',
#  'FBYD',
#  'HLMN',
#  'ANDE',
#  'NRIX',
#  'IRDM',
#  'IAS',
#  'JAMF',
#  'STOK',
#  'LBTYK',
#  'LUNR',
#  'SNDX',
#  'REAL',
#  'LASR',
#  'FLYW',
#  'IMNM',
#  'CSIQ',
#  'ALVO',
#  'OMCL',
#  'AGIO',
#  'LZ',
#  'CLMT',
#  'MNKD',
#  'BLBD',
#  'HTZ',
#  'AMLX',
#  'ENVX',
#  'NEGG',
#  'PHVS',
#  'TILE',
#  'INVA',
#  'ATRO',
#  'WEN',
#  'NEO',
#  'CENTA',
#  'BELFB',
#  'JBLU',
#  'UPB',
#  'DGII',
#  'AAOI',
#  'EVCM',
#  'NEXT',
#  'ACHC',
#  'FIVN',
#  'HROW',
#  'PLTK',
#  'PCT',
#  'WERN',
#  'MCHPP',
#  'WINA',
#  'UNIT',
#  'TNDM',
#  'ORKA',
#  'CNXN',
#  'WLDN',
#  'DXPE',
#  'IMKTA',
#  'ROCK',
#  'TRVI',
#  'NWL',
#  'CERT',
#  'ARCB',
#  'NESR',
#  'ICFI',
#  'NSSC',
#  'BCRX',
#  'COLL',
#  'MREO',
#  'TNGX',
#  'MBX',
#  'NVCR',
#  'MOMO',
#  'VITL',
#  'KMTS',
#  'ARHS',
#  'RLAY',
#  'ARDX',
#  'AMSC',
#  'LILAK',
#  'BBNX',
#  'OXLC',
#  'AFYA',
#  'STGW',
#  'KARO',
#  'AMPL',
#  'ATAI',
#  'GCT',
#  'RAPP',
#  'SHLS',
#  'ADEA',
#  'TRS',
#  'PZZA',
#  'MXL',
#  'DVAX',
#  'QQQX',
#  'PLAB',
#  'PSNY',
#  'IMTX',
#  'HCSG',
#  'ALGT',
#  'XPEL',
#  'TSAT',
#  'AHCO',
#  'OUST',
#  'AXGN',
#  'NEOG',
#  'STAA',
#  'BLFS',
#  'PGEN',
#  'BGM',
#  'URGN',
#  'ZD',
#  'ELVN',
#  'DSGR',
#  'SDGR',
#  'HIMX',
#  'AMPH',
#  'STRF',
#  'TSHA',
#  'SEPN',
#  'PSIX',
#  'CLOV',
#  'GIII',
#  'VRNT',
#  'WVE',
#  'PSEC',
#  'XNCR',
#  'NKTR',
#  'HSII',
#  'EYPT',
#  'KOD',
#  'PRCH',
#  'INBX',
#  'OCSL',
#  'OPRA',
#  'HDL',
#  'CVAC',
#  'LGIH',
#  'FTRE',
#  'XERS',
#  'CCEC',
#  'SSII',
#  'IRMD',
#  'MNMD',
#  'TBLA',
#  'TYRA',
#  'PHAR',
#  'CSTL',
#  'ASTH',
#  'CRAI',
#  'ANAB',
#  'EVO',
#  'ARRY',
#  'ORIC',
#  'UCTT',
#  'PVLA',
#  'MVST',
#  'OCS',
#  'MGIC',
#  'TLRY',
#  'COHU',
#  'THRM',
#  'SBGI',
#  'FWRG',
#  'STRK',
#  'MLKN',
#  'KDK',
#  'NVAX',
#  'ABCL',
#  'EVLV',
#  'GO',
#  'PDFS',
#  'HLIT',
#  'PHAT',
#  'DMLP',
#  'UPBD',
#  'OMDA',
#  'SVRA',
#  'BRKRP',
#  'GLUE',
#  'CRTO',
#  'OPK',
#  'IART',
#  'MDXG',
#  'CRCT',
#  'NBTX',
#  'TASK',
#  'BCAX',
#  'KURA',
#  'ASTE',
#  'PENG',
#  'RPD',
#  'PLPC',
#  'PCRX',
#  'PSNL',
#  'NTLA',
#  'BBOT',
#  'IOVA',
#  'NMFC',
#  'RDWR',
#  'MLTX',
#  'IMOS',
#  'SLDP',
#  'PNTG',
#  'RZLV',
#  'DAWN',
#  'EH',
#  'BTSGU',
#  'MRVI',
#  'BTQ',
#  'TBPH',
#  'ULCC',
#  'NNNN',
#  'GDRX',
#  'FLGT',
#  'GOGO',
#  'TDUP',
#  'WOOF',
#  'CRON',
#  'AVBP',
#  'SANA',
#  'LENZ',
#  'EVER',
#  'LQDT',
#  'DAKT',
#  'GHRS',
#  'CDNA',
#  'SPRY',
#  'AEBI',
#  'BBSI',
#  'ALNT',
#  'PLSE',
#  'SCSC',
#  'STRD',
#  'RIGL',
#  'GLIBK',
#  'VIR',
#  'CHY',
#  'IMSR',
#  'INMD',
#  'CMPX',
#  'RZLT',
#  'ESPR',
#  'CCOI',
#  'VERB',
#  'LOT',
#  'ERAS',
#  'RCAT',
#  'RUSHB',
#  'SLRC',
#  'SIBN',
#  'LBRDA',
#  'NUTX',
#  'JBSS',
#  'ODP',
#  'GLDD',
#  'AHG',
#  'AVO',
#  'ABUS',
#  'RAPT',
#  'CHI',
#  'SWIM',
#  'MRTN',
#  'WLFC',
#  'HPK',
#  'ITRN',
#  'BLDP',
#  'BJRI',
#  'LMB',
#  'QNST',
#  'AMWD',
#  'EMBC',
#  'PACB',
#  'VSTM',
#  'SIFY',
#  'ARVN',
#  'MATW',
#  'APOG',
#  'GDEN',
#  'RDVT',
#  'ALMS',
#  'INDI',
#  'LAES',
#  'HSTM',
#  'GOSS',
#  'ERII',
#  'VALN',
#  'TH',
#  'SCHL',
#  'REPL',
#  'VTYX',
#  'CTKB',
#  'AQST',
#  'GDYN',
#  'UDMY',
#  'CRMD',
#  'GERN',
#  'MYGN',
#  'OLPX',
#  'GLOO',
#  'SSYS',
#  'FWDI',
#  'GILT',
#  'NTGR',
#  'SERV',
#  'INNV',
#  'CRESY',
#  'SKYT',
#  'CCCX',
#  'FDUS',
#  'RR',
#  'ADSE',
#  'LXEO',
#  'GPRE',
#  'TIPT',
#  'ATXS',
#  'CTMX',
#  'GYRE',
#  'CGEM',
#  'SNCY',
#  'KE',
#  'SUPX',
#  'FWRD',
#  'WYFI',
#  'DNUT',
#  'RGNX',
#  'SENEA',
#  'GRPN',
#  'PRME',
#  'KALV',
#  'LIND',
#  'ORGO',
#  'OMER',
#  'ASPI',
#  'CRVS',
#  'HEPS',
#  'DMIIU',
#  'CRSR',
#  'YDES',
#  'NOVTU',
#  'DSP',
#  'LINC',
#  'DJCO',
#  'AEHR',
#  'BVS',
#  'SABR',
#  'CBLL',
#  'ANNX',
#  'OFIX',
#  'CCCXU',
#  'TBLD',
#  'PROK',
#  'APEI',
#  'DVLT',
#  'AIOT',
#  'IVVD',
#  'AEVA',
#  'CBRL',
#  'FULC',
#  'AOSL',
#  'ADTN',
#  'ECX',
#  'POET',
#  'IVA',
#  'FOXF',
#  'DCBO',
#  'FDMT',
#  'MGTX',
#  'ACDC',
#  'BWMN',
#  'SHEN',
#  'HTLD',
#  'CGNT',
#  'LWLG',
#  'AIP',
#  'KRNT',
#  ...]

# %% [markdown]
# ### Billions 단위로 변환

# %%
df_billions = normalizer.convert_to_billions(df)
print(df_billions[['revenue', 'net_income']].tail(8))

# %% [markdown]
# ### TTM (Trailing Twelve Months) 계산

# %%
df_ttm = normalizer.calculate_ttm(df_billions, columns=['revenue', 'net_income'])
print(df_ttm[['revenue', 'revenue_ttm']].tail(8))

# %% [markdown]
# # 2. 다수 기업 재무제표 받기

# %%
from collectors import SECAPIClient, RateLimiter, BulkDownloader
from parsers import CompanyFactsParser, FinancialNormalizer
import pandas as pd

# 1. 클라이언트 및 다운로더 설정
user_agent = "PersonalResearch stox1224@email.com"
client = SECAPIClient(user_agent, RateLimiter(10, 1.0))
downloader = BulkDownloader(client, output_dir="./sec_data", max_workers=3)

# 2. 다운로드할 기업 리스트
tickers = ['AAPL', 'MSFT', 'GOOGL', 'AMZN', 'TSLA', 'NVDA', 'META']

# 3. 배치 다운로드 (자동으로 JSON 파일 저장)
results = downloader.download_company_facts_batch(tickers)

# 4. 각 기업별 데이터 처리
all_financials = {}

for ticker, company_facts in results.items():
    parser = CompanyFactsParser(company_facts)
    normalizer = FinancialNormalizer(parser)

    # 재무데이터 정규화
    df = normalizer.create_normalized_dataframe(period_type='quarterly')
    df_billions = normalizer.convert_to_billions(df)

    all_financials[ticker] = df_billions

    # 개별 CSV 저장
    normalizer.export_to_csv(df_billions, f'{ticker}_financials.csv')

print(f"총 {len(all_financials)}개 기업 데이터 수집 완료")

# %% [markdown]
# # 3. 특정 재무항목만 추출

# %%
revenue_comparison = {}

for ticker, company_facts in results.items():
    parser = CompanyFactsParser(company_facts)
    normalizer = FinancialNormalizer(parser)

    # Revenue만 추출
    revenue_series = normalizer.normalize_single_item('revenue', period_type='quarterly')

    if revenue_series is not None:
        revenue_comparison[ticker] = revenue_series / 1_000_000_000  # Billions

# DataFrame으로 변환
revenue_df = pd.DataFrame(revenue_comparison)
print("\n최근 8분기 매출 비교 (Billions):")
print(revenue_df.tail(8))

# YoY 성장률
growth_df = revenue_df.pct_change(periods=4) * 100
print("\nYoY 매출 성장률 (%):")
print(growth_df.tail(4))

# %% [markdown]
# # 4. 사용 가능한 재무 항목

# %%
# 추출 가능한 표준 재무 항목들
available_items = [
    'revenue',              # 매출
    'net_income',           # 순이익
    'operating_income',     # 영업이익
    'gross_profit',         # 매출총이익
    'total_assets',         # 총자산
    'current_assets',       # 유동자산
    'total_liabilities',    # 총부채
    'current_liabilities',  # 유동부채
    'stockholders_equity',  # 자본
    'cash',                 # 현금
    'long_term_debt',       # 장기부채
    'cost_of_revenue',      # 매출원가
    'operating_expenses',   # 영업비용
    'research_development', # 연구개발비
    'earnings_per_share',   # 주당순이익
]

# 특정 항목만 추출
for item in ['revenue', 'net_income', 'total_assets']:
    series = normalizer.normalize_single_item(item, period_type='quarterly')
    print(f"\n{item}:")
    print(series.tail(4))

# %% [markdown]
# # 5. 재무비율 계산

# %%
# 데이터 준비
df = normalizer.create_normalized_dataframe(period_type='quarterly')

# 재무비율 자동 계산
df_ratios = normalizer.calculate_financial_ratios(df)

# 계산되는 비율들:
# - profit_margin: 순이익률
# - operating_margin: 영업이익률
# - current_ratio: 유동비율
# - debt_to_equity: 부채비율
# - roe: 자기자본이익률
# - roa: 총자산이익률

print(df_ratios[['revenue', 'net_income', 'profit_margin']].tail(8))

# %% [markdown]
# # 6. 성장률 분석

# %%
df_billions = normalizer.convert_to_billions(df)

# YoY 성장률 계산
df_growth = normalizer.calculate_growth_rates(
    df_billions,
    columns=['revenue', 'net_income'],
    periods=4  # 4분기 = YoY
)

print(df_growth[['revenue', 'revenue_yoy_growth']].tail(8))

# %% [markdown]
# # 7. 진행상황 모니터링

# %%
# 콜백 함수 정의
def on_download_complete(ticker, data, index, total):
    if data:
        entity_name = data.get('entityName', 'Unknown')
        print(f"[{index}/{total}] {ticker}: {entity_name} - 완료")
    else:
        print(f"[{index}/{total}] {ticker}: 실패")

# 콜백과 함께 다운로드
results = downloader.download_company_facts_batch(
    tickers=['AAPL', 'MSFT', 'GOOGL'],
    callback=on_download_complete
)

# %% [markdown]
# # 8. 중단된 다운로드 재개

# %%
# 이미 다운로드된 파일은 건너뛰기
remaining_results = downloader.resume_download(tickers)

# %% [markdown]
# # 9. 다운로드 리포트 생성

# %%
# 다운로드 후 리포트 생성
downloader.create_download_report(results, "download_report.json")

# %% [markdown]
# # 10. 실전 예제: S&P 500 상위 기업 분석

# %%
# Tech Giants
tech_giants = ['AAPL', 'MSFT', 'GOOGL', 'AMZN', 'META', 'NVDA', 'TSLA']

# 다운로드
downloader = BulkDownloader(client, output_dir="./tech_giants", max_workers=5)
results = downloader.download_company_facts_batch(tech_giants)

# Revenue 비교 분석
revenue_data = {}
for ticker, facts in results.items():
    parser = CompanyFactsParser(facts)
    normalizer = FinancialNormalizer(parser)
    revenue = normalizer.normalize_single_item('revenue', period_type='quarterly')
    if revenue is not None:
        revenue_data[ticker] = revenue / 1e9  # Billions

# 비교 DataFrame
comparison = pd.DataFrame(revenue_data)
print("\nTech Giants 최근 매출 비교 (Billions):")
print(comparison.tail(8))

# 시각화 (선택사항)
import matplotlib.pyplot as plt
comparison.tail(12).plot(figsize=(12, 6))
plt.title('Tech Giants Revenue Comparison (Last 12 Quarters)')
plt.ylabel('Revenue (Billions USD)')
plt.legend(loc='best')
plt.grid(True)
plt.savefig('tech_giants_revenue.png')
