# %% [markdown]
# # 1. 단일 기업 재무제표 받기

# %%
import sys
import pandas as pd
import time
# ---------------------------------------------------------
# 0) 프로젝트 경로 추가
# ---------------------------------------------------------
sys.path.append(r"C:\Users\82108\OneDrive\바탕 화면\investment\investment_strategy\US_Market\collect")

# ---------------------------------------------------------
# 1) 필요한 모듈 import
# ---------------------------------------------------------
from sec_data_pipeline.collectors.get_us_ticker import get_filtered_us_tickers
from sec_data_pipeline.collectors.sec_utils import fetch_company_facts
from sec_data_pipeline.parsers.company_facts_parser import CompanyFactsParser
from sec_data_pipeline.parsers.financial_normalizer import FinancialNormalizer
from sec_data_pipeline.validators.wrds_data_validator_mysql_integrated import WRDSDataValidator
from sec_data_pipeline.valuation.financial_data_integrator import integrate_financial_ratios

# ✅ Rate Limiter (이미 프로젝트에 있는 구현 사용)
from sec_data_pipeline.collectors.rate_limiter import AdaptiveRateLimiter

# 통합 분석 클래스 (수정본)
from sec_data_pipeline.valuation.integrated_financial_analyzer_mysql_fixed import IntegratedFinancialAnalyzer

# DB 저장용
from sec_data_pipeline.storage.db_manager import DBManager
from DATA.stock_invest_function import get_db_host


# ---------------------------------------------------------
# 2) DB 설정
# ---------------------------------------------------------
db_info = {
    "host": get_db_host(),
    "port": 3307,
    "user": "stox7412",
    "password": "Apt106503!~",
    "database": "investar",
}

# DBManager 생성 및 테이블 생성 (최초 1회만)
db_manager = DBManager(db_info)
db_manager.create_tables()   # sec_financial_data, fmp_financial_data 등 생성


# ---------------------------------------------------------
# 3) WRDS 접속 문자열
# ---------------------------------------------------------
wrds_conn_str = "postgresql://YOUR_WRDS_ID:YOUR_WRDS_PW@wrds.wharton.upenn.edu:9737/wrds"


# ---------------------------------------------------------
# 4) SEC User-Agent 헤더 설정 (반드시 이메일 포함)
# ---------------------------------------------------------
headers = {
    "User-Agent": "Hoyoung Research <stox1224@gmail.com>"
}


# ---------------------------------------------------------
# 5) 티커 리스트 생성
# ---------------------------------------------------------
# 전체 티커 리스트
TICKER_LIST = get_filtered_us_tickers()

# 테스트 / 안전을 위해 500개까지만
TICKER_LIST = TICKER_LIST[2000:3000]
# 완전 테스트용:
# TICKER_LIST = ["APH", "INVX", "MU", "ON", "GLW", "ANET", "SMCI"]

# ---------------------------------------------------------
# 6) Rate Limiter 설정
#    - max_calls=8, time_window=1 → 초당 최대 8회
#    - AdaptiveRateLimiter: 429 발생 시 자동으로 max_calls 줄임
# ---------------------------------------------------------
rate_limiter = AdaptiveRateLimiter(
    max_calls=8,
    time_window=1.0,
    min_calls=3,
    backoff_factor=0.8,
)

# 통합 분석기
analyzer = IntegratedFinancialAnalyzer(db_info=db_info, wrds_conn_str=wrds_conn_str)

# ---------------------------------------------------------
# 7) 메인 루프: 티커별 EDGAR+WRDS+비율 → DB 저장
# ---------------------------------------------------------
for i, ticker in enumerate(TICKER_LIST, start=1):
    print(f"\n=== [{i}/{len(TICKER_LIST)}] {ticker} 처리 시작 ===")

    # ✅ ❶ 티커마다 호출 전 rate limit 체크
    rate_limiter.wait_if_needed()

    try:
        result = analyzer.analyze(ticker, headers=headers, table_name="us_fundq")
        if result is None:
            print(f"⚠ {ticker}: 분석 결과 없음, 스킵")
            continue

        final_df, cik, entity_name = result

        # date 인덱스 정리 (DB 저장을 위해)
        if final_df.index.name != "date":
            final_df = final_df.copy()
            # 만약 date가 컬럼으로 있다면:
            if "date" in final_df.columns:
                final_df = final_df.set_index("date")
            else:
                final_df.index.name = "date"

        # DB 저장 (LONG FORMAT sec_financial_data)
        db_manager.save_normalized_data(
            ticker=ticker,
            cik=cik,
            df=final_df,
            item_mapping=None  # 컬럼명을 그대로 item_name으로 사용
        )

        print(f"✓ {ticker} ({entity_name}) 저장 완료")

        # ✅ ❷ 여유를 더 두고 싶으면 티커 사이에 약간의 sleep 추가 (선택)
        # time.sleep(0.2)

    except Exception as e:
        msg = str(e)

        # ✅ ❸ SEC 429 / rate limit 의심 시 백오프 처리
        if "Company Facts 요청 실패" in msg and "429" in msg:
            print(f"⚠ {ticker}: SEC 429 Too Many Requests 감지 → rate 낮추고 60초 대기")
            # AdaptiveRateLimiter에 "rateLimit 발생" 알리기
            rate_limiter.on_rate_limit_error()
            # 잠시 쉬었다가 다음 티커로
            time.sleep(60)
            continue

        print(f"✗ {ticker} 처리 중 기타 오류: {e}")
        # (여기서 바로 continue 해서 다음 티커 진행)
        continue

print("\n=== 전체 작업 완료 ===")
# Out:
# WARNING:tensorflow:From C:\Users\82108\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# ✓ DB connected: 192.168.0.230:3307/investar
# ✓ Tables created
# 100%|██████████| 3772/3772 [00:03<00:00, 1022.58it/s]
# 100%|██████████| 2738/2738 [00:02<00:00, 1011.18it/s]
# 100%|██████████| 299/299 [00:00<00:00, 860.05it/s]
# 제외된 기업 수: 1816
# 남은 기업 수: 4993
# 티커 수: 4993
#
# === [1/1000] UHG 처리 시작 ===
# ================================================================================
# [UHG] 통합 재무분석 시작
# ✓ Entity: United Homes Group, Inc. (CIK: 1830188)
# ✓ EDGAR 정규화 DF: 20 rows × 25 cols
# ✓ MySQL 연결 성공: 192.168.0.230:3307/investar
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 20 rows × 25 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 20 rows × 40 cols
# [UHG] 통합 재무분석 종료
# ================================================================================
# ✓ Saved UHG data: 20 dates x 40 items
# ✓ UHG (United Homes Group, Inc.) 저장 완료
#
# === [2/1000] BWEN 처리 시작 ===
# ================================================================================
# [BWEN] 통합 재무분석 시작
# ✓ Entity: BROADWIND, INC. (CIK: 1120370)
# ✓ EDGAR 정규화 DF: 64 rows × 28 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 64 rows × 28 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 64 rows × 45 cols
# [BWEN] 통합 재무분석 종료
# ================================================================================
# ✓ Saved BWEN data: 64 dates x 45 items
# ✓ BWEN (BROADWIND, INC.) 저장 완료
#
# === [3/1000] PLRX 처리 시작 ===
# ================================================================================
# [PLRX] 통합 재무분석 시작
# ✓ Entity: PLIANT THERAPEUTICS, INC. (CIK: 1746473)
# ✓ EDGAR 정규화 DF: 28 rows × 23 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 28 rows × 23 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 28 rows × 36 cols
# [PLRX] 통합 재무분석 종료
# ================================================================================
# ✓ Saved PLRX data: 28 dates x 36 items
# ✓ PLRX (PLIANT THERAPEUTICS, INC.) 저장 완료
#
# === [4/1000] ATOM 처리 시작 ===
# ================================================================================
# [ATOM] 통합 재무분석 시작
# ✓ Entity: ATOMERA INCORPORATED (CIK: 1420520)
# ✓ EDGAR 정규화 DF: 43 rows × 26 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 43 rows × 26 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 43 rows × 40 cols
# [ATOM] 통합 재무분석 종료
# ================================================================================
# ✓ Saved ATOM data: 43 dates x 40 items
# ✓ ATOM (ATOMERA INCORPORATED) 저장 완료
#
# === [5/1000] HOVR 처리 시작 ===
# ================================================================================
# [HOVR] 통합 재무분석 시작
# ✓ Entity: NEW HORIZON AIRCRAFT LTD. (CIK: 0001930021)
# ✓ EDGAR 정규화 DF: 13 rows × 24 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 13 rows × 24 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 13 rows × 37 cols
# [HOVR] 통합 재무분석 종료
# ================================================================================
# ✓ Saved HOVR data: 13 dates x 37 items
# ✓ HOVR (NEW HORIZON AIRCRAFT LTD.) 저장 완료
#
# === [6/1000] LVRO 처리 시작 ===
# ================================================================================
# [LVRO] 통합 재무분석 시작
# ✓ Entity: Lavoro Limited (CIK: 0001945711)
# ⚠ EDGAR 정규화 DF가 비어 있습니다 (LVRO)
# ✓ EDGAR 정규화 DF: 0 rows × 0 cols
# ⚠ EDGAR 입력 DF가 비어있습니다. WRDS만으로 구성합니다.
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ⚠ WRDS 보완 후에도 DF가 비어 있습니다 (LVRO)
# ⚠ LVRO: 분석 결과 없음, 스킵
#
# === [7/1000] DXLG 처리 시작 ===
# ================================================================================
# [DXLG] 통합 재무분석 시작
# ✓ Entity: DESTINATION XL GROUP, INC. (CIK: 813298)
# ✓ EDGAR 정규화 DF: 66 rows × 26 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 66 rows × 26 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 66 rows × 41 cols
# [DXLG] 통합 재무분석 종료
# ================================================================================
# ✓ Saved DXLG data: 66 dates x 41 items
# ✓ DXLG (DESTINATION XL GROUP, INC.) 저장 완료
#
# === [8/1000] MTC 처리 시작 ===
# ================================================================================
# [MTC] 통합 재무분석 시작
# ✓ Entity: MMTEC, INC. (CIK: 1742518)
# ✓ EDGAR 정규화 DF: 11 rows × 23 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 11 rows × 23 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 11 rows × 37 cols
# [MTC] 통합 재무분석 종료
# ================================================================================
# ✓ Saved MTC data: 11 dates x 37 items
# ✓ MTC (MMTEC, INC.) 저장 완료
#
# === [9/1000] ARTV 처리 시작 ===
# ================================================================================
# [ARTV] 통합 재무분석 시작
# ✓ Entity: Artiva Biotherapeutics, Inc. (CIK: 0001817241)
# ✓ EDGAR 정규화 DF: 12 rows × 20 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 12 rows × 20 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 12 rows × 33 cols
# [ARTV] 통합 재무분석 종료
# ================================================================================
# ✓ Saved ARTV data: 12 dates x 33 items
# ✓ ARTV (Artiva Biotherapeutics, Inc.) 저장 완료
#
# === [10/1000] FVN 처리 시작 ===
# ================================================================================
# [FVN] 통합 재무분석 시작
# ✓ Entity: FUTURE VISION II ACQUISITION CORP. (CIK: 0002010653)
# ✓ EDGAR 정규화 DF: 7 rows × 13 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 7 rows × 13 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 7 rows × 24 cols
# [FVN] 통합 재무분석 종료
# ================================================================================
# ✓ Saved FVN data: 7 dates x 24 items
# ✓ FVN (FUTURE VISION II ACQUISITION CORP.) 저장 완료
#
# === [11/1000] APAC 처리 시작 ===
# ================================================================================
# [APAC] 통합 재무분석 시작
# ✓ Entity: STONEBRIDGE ACQUISITION II CORPORATION (CIK: 0002043630)
# ✓ EDGAR 정규화 DF: 3 rows × 9 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 3 rows × 9 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 3 rows × 19 cols
# [APAC] 통합 재무분석 종료
# ================================================================================
# ✓ Saved APAC data: 3 dates x 19 items
# ✓ APAC (STONEBRIDGE ACQUISITION II CORPORATION) 저장 완료
#
# === [12/1000] BEAT 처리 시작 ===
# ================================================================================
# [BEAT] 통합 재무분석 시작
# ✓ Entity: HEARTBEAM, INC. (CIK: 1779372)
# ✓ EDGAR 정규화 DF: 23 rows × 20 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 23 rows × 20 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 23 rows × 31 cols
# [BEAT] 통합 재무분석 종료
# ================================================================================
# ✓ Saved BEAT data: 23 dates x 31 items
# ✓ BEAT (HEARTBEAM, INC.) 저장 완료
#
# === [13/1000] CBAT 처리 시작 ===
# ================================================================================
# [CBAT] 통합 재무분석 시작
# ✓ Entity: CBAK ENERGY TECHNOLOGY, INC. (CIK: 1117171)
# ✓ EDGAR 정규화 DF: 65 rows × 33 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 65 rows × 33 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 65 rows × 50 cols
# [CBAT] 통합 재무분석 종료
# ================================================================================
# ✓ Saved CBAT data: 65 dates x 50 items
# ✓ CBAT (CBAK ENERGY TECHNOLOGY, INC.) 저장 완료
#
# === [14/1000] UYSC 처리 시작 ===
# ================================================================================
# [UYSC] 통합 재무분석 시작
# ✓ Entity: UY Scuti Acquisition Corp. (CIK: 0002036973)
# ✓ EDGAR 정규화 DF: 7 rows × 13 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 7 rows × 13 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 7 rows × 24 cols
# [UYSC] 통합 재무분석 종료
# ================================================================================
# ✓ Saved UYSC data: 7 dates x 24 items
# ✓ UYSC (UY Scuti Acquisition Corp.) 저장 완료
#
# === [15/1000] CRVO 처리 시작 ===
# ================================================================================
# [CRVO] 통합 재무분석 시작
# ✓ Entity: CervoMed Inc. (CIK: 1053691)
# ✓ EDGAR 정규화 DF: 62 rows × 30 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 62 rows × 30 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 62 rows × 44 cols
# [CRVO] 통합 재무분석 종료
# ================================================================================
# ✓ Saved CRVO data: 62 dates x 44 items
# ✓ CRVO (CervoMed Inc.) 저장 완료
#
# === [16/1000] TZOO 처리 시작 ===
# ================================================================================
# [TZOO] 통합 재무분석 시작
# ✓ Entity: Travelzoo (CIK: 1133311)
# ✓ EDGAR 정규화 DF: 64 rows × 26 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 64 rows × 26 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 64 rows × 40 cols
# [TZOO] 통합 재무분석 종료
# ================================================================================
# ✓ Saved TZOO data: 64 dates x 40 items
# ✓ TZOO (Travelzoo) 저장 완료
#
# === [17/1000] SSEAU 처리 시작 ===
# ================================================================================
# [SSEAU] 통합 재무분석 시작
# ✓ Entity: STARRY SEA ACQUISITION CORP (CIK: 0002059165)
# ✓ EDGAR 정규화 DF: 3 rows × 10 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 3 rows × 10 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 3 rows × 21 cols
# [SSEAU] 통합 재무분석 종료
# ================================================================================
# ✓ Saved SSEAU data: 3 dates x 21 items
# ✓ SSEAU (STARRY SEA ACQUISITION CORP) 저장 완료
#
# === [18/1000] CPHC 처리 시작 ===
# ================================================================================
# [CPHC] 통합 재무분석 시작
# ✓ Entity: Canterbury Park Holding Corp (CIK: 1672909)
# ✓ EDGAR 정규화 DF: 45 rows × 21 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 45 rows × 21 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 45 rows × 35 cols
# [CPHC] 통합 재무분석 종료
# ================================================================================
# ✓ Saved CPHC data: 45 dates x 35 items
# ✓ CPHC (Canterbury Park Holding Corp) 저장 완료
#
# === [19/1000] KRRO 처리 시작 ===
# ================================================================================
# [KRRO] 통합 재무분석 시작
# ✓ Entity: Korro Bio, Inc. (CIK: 1703647)
# ✓ EDGAR 정규화 DF: 33 rows × 26 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 33 rows × 26 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 33 rows × 37 cols
# [KRRO] 통합 재무분석 종료
# ================================================================================
# ✓ Saved KRRO data: 33 dates x 37 items
# ✓ KRRO (Korro Bio, Inc.) 저장 완료
#
# === [20/1000] MIND 처리 시작 ===
# ================================================================================
# [MIND] 통합 재무분석 시작
# ✓ Entity: MIND TECHNOLOGY, INC (CIK: 926423)
# ✓ EDGAR 정규화 DF: 64 rows × 30 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 64 rows × 30 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 64 rows × 47 cols
# [MIND] 통합 재무분석 종료
# ================================================================================
# ✓ Saved MIND data: 64 dates x 47 items
# ✓ MIND (MIND TECHNOLOGY, INC) 저장 완료
#
# === [21/1000] RVPH 처리 시작 ===
# ================================================================================
# [RVPH] 통합 재무분석 시작
# ✓ Entity: Reviva Pharmaceuticals Holdings, Inc. (CIK: 1742927)
# ✓ EDGAR 정규화 DF: 38 rows × 20 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 38 rows × 20 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 38 rows × 31 cols
# [RVPH] 통합 재무분석 종료
# ================================================================================
# ✓ Saved RVPH data: 38 dates x 31 items
# ✓ RVPH (Reviva Pharmaceuticals Holdings, Inc.) 저장 완료
#
# === [22/1000] SSEA 처리 시작 ===
# ================================================================================
# [SSEA] 통합 재무분석 시작
# ✓ Entity: STARRY SEA ACQUISITION CORP (CIK: 0002059165)
# ✓ EDGAR 정규화 DF: 3 rows × 10 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 3 rows × 10 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 3 rows × 21 cols
# [SSEA] 통합 재무분석 종료
# ================================================================================
# ✓ Saved SSEA data: 3 dates x 21 items
# ✓ SSEA (STARRY SEA ACQUISITION CORP) 저장 완료
#
# === [23/1000] ACET 처리 시작 ===
# ================================================================================
# [ACET] 통합 재무분석 시작
# ✓ Entity: Adicet Bio, Inc. (CIK: 1720580)
# ✓ EDGAR 정규화 DF: 37 rows × 23 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 37 rows × 23 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 37 rows × 34 cols
# [ACET] 통합 재무분석 종료
# ================================================================================
# ✓ Saved ACET data: 37 dates x 34 items
# ✓ ACET (Adicet Bio, Inc.) 저장 완료
#
# === [24/1000] GENK 처리 시작 ===
# ================================================================================
# [GENK] 통합 재무분석 시작
# ✓ Entity: GEN Restaurant Group, Inc. (CIK: 0001891856)
# ✓ EDGAR 정규화 DF: 16 rows × 25 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 16 rows × 25 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 16 rows × 39 cols
# [GENK] 통합 재무분석 종료
# ================================================================================
# ✓ Saved GENK data: 16 dates x 39 items
# ✓ GENK (GEN Restaurant Group, Inc.) 저장 완료
#
# === [25/1000] CHPGU 처리 시작 ===
# ================================================================================
# [CHPGU] 통합 재무분석 시작
# ✓ Entity: ChampionsGate Acquisition Corporation (CIK: 0002024460)
# ✓ EDGAR 정규화 DF: 7 rows × 11 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 7 rows × 11 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 7 rows × 22 cols
# [CHPGU] 통합 재무분석 종료
# ================================================================================
# ✓ Saved CHPGU data: 7 dates x 22 items
# ✓ CHPGU (ChampionsGate Acquisition Corporation) 저장 완료
#
# === [26/1000] ZBAI 처리 시작 ===
# ================================================================================
# [ZBAI] 통합 재무분석 시작
# ✓ Entity: ATIF HOLDINGS LIMITED (CIK: 1755058)
# ✓ EDGAR 정규화 DF: 22 rows × 27 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 22 rows × 27 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 22 rows × 41 cols
# [ZBAI] 통합 재무분석 종료
# ================================================================================
# ✓ Saved ZBAI data: 22 dates x 41 items
# ✓ ZBAI (ATIF HOLDINGS LIMITED) 저장 완료
#
# === [27/1000] ATYR 처리 시작 ===
# ================================================================================
# [ATYR] 통합 재무분석 시작
# ✓ Entity: ATYR PHARMA, INC. (CIK: 1339970)
# ✓ EDGAR 정규화 DF: 49 rows × 20 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 49 rows × 20 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 49 rows × 31 cols
# [ATYR] 통합 재무분석 종료
# ================================================================================
# ✓ Saved ATYR data: 49 dates x 31 items
# ✓ ATYR (ATYR PHARMA, INC.) 저장 완료
#
# === [28/1000] OM 처리 시작 ===
# ================================================================================
# [OM] 통합 재무분석 시작
# ✓ Entity: Outset Medical, Inc. (CIK: 1484612)
# ✓ EDGAR 정규화 DF: 29 rows × 29 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 29 rows × 29 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 29 rows × 46 cols
# [OM] 통합 재무분석 종료
# ================================================================================
# ✓ Saved OM data: 29 dates x 46 items
# ✓ OM (Outset Medical, Inc.) 저장 완료
#
# === [29/1000] STSS 처리 시작 ===
# ================================================================================
# [STSS] 통합 재무분석 시작
# ✓ Entity: Sharps Technology, Inc. (CIK: 0001737995)
# ✓ EDGAR 정규화 DF: 20 rows × 25 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 20 rows × 25 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 20 rows × 42 cols
# [STSS] 통합 재무분석 종료
# ================================================================================
# ✓ Saved STSS data: 20 dates x 42 items
# ✓ STSS (Sharps Technology, Inc.) 저장 완료
#
# === [30/1000] MNOV 처리 시작 ===
# ================================================================================
# [MNOV] 통합 재무분석 시작
# ✓ Entity: MEDICINOVA, INC. (CIK: 1226616)
# ✓ EDGAR 정규화 DF: 75 rows × 28 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 75 rows × 28 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 75 rows × 41 cols
# [MNOV] 통합 재무분석 종료
# ================================================================================
# ✓ Saved MNOV data: 75 dates x 41 items
# ✓ MNOV (MEDICINOVA, INC.) 저장 완료
#
# === [31/1000] WTGUU 처리 시작 ===
# ================================================================================
# [WTGUU] 통합 재무분석 시작
# ✓ Entity: WINTERGREEN ACQUISITION CORP. (CIK: 0002053927)
# ✓ EDGAR 정규화 DF: 5 rows × 11 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 5 rows × 11 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 5 rows × 22 cols
# [WTGUU] 통합 재무분석 종료
# ================================================================================
# ✓ Saved WTGUU data: 5 dates x 22 items
# ✓ WTGUU (WINTERGREEN ACQUISITION CORP.) 저장 완료
#
# === [32/1000] SGA 처리 시작 ===
# ================================================================================
# [SGA] 통합 재무분석 시작
# ✓ Entity: Saga Communications, Inc (CIK: 886136)
# ✓ EDGAR 정규화 DF: 64 rows × 26 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 64 rows × 26 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 64 rows × 39 cols
# [SGA] 통합 재무분석 종료
# ================================================================================
# ✓ Saved SGA data: 64 dates x 39 items
# ✓ SGA (Saga Communications, Inc) 저장 완료
#
# === [33/1000] ZTEK 처리 시작 ===
# ================================================================================
# [ZTEK] 통합 재무분석 시작
# ✓ Entity: Zentek Ltd. (CIK: 0001904501)
# ⚠ EDGAR 정규화 DF가 비어 있습니다 (ZTEK)
# ✓ EDGAR 정규화 DF: 0 rows × 0 cols
# ⚠ EDGAR 입력 DF가 비어있습니다. WRDS만으로 구성합니다.
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ⚠ WRDS 보완 후에도 DF가 비어 있습니다 (ZTEK)
# ⚠ ZTEK: 분석 결과 없음, 스킵
#
# === [34/1000] PCTTU 처리 시작 ===
# ================================================================================
# [PCTTU] 통합 재무분석 시작
# ✓ Entity: PureCycle Technologies, Inc. (CIK: 1830033)
# ✓ EDGAR 정규화 DF: 24 rows × 26 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 24 rows × 26 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 24 rows × 40 cols
# [PCTTU] 통합 재무분석 종료
# ================================================================================
# ✓ Saved PCTTU data: 24 dates x 40 items
# ✓ PCTTU (PureCycle Technologies, Inc.) 저장 완료
#
# === [35/1000] BSAA 처리 시작 ===
# ================================================================================
# [BSAA] 통합 재무분석 시작
# ✓ Entity: BEST SPAC I ACQUISITION CORP. (CIK: 0002051587)
# ✓ EDGAR 정규화 DF: 4 rows × 11 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 4 rows × 11 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 4 rows × 22 cols
# [BSAA] 통합 재무분석 종료
# ================================================================================
# ✓ Saved BSAA data: 4 dates x 22 items
# ✓ BSAA (BEST SPAC I ACQUISITION CORP.) 저장 완료
#
# === [36/1000] THCH 처리 시작 ===
# ================================================================================
# [THCH] 통합 재무분석 시작
# ✓ Entity: TH International Limited (CIK: 0001877333)
# ⚠ EDGAR 정규화 DF가 비어 있습니다 (THCH)
# ✓ EDGAR 정규화 DF: 0 rows × 0 cols
# ⚠ EDGAR 입력 DF가 비어있습니다. WRDS만으로 구성합니다.
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ⚠ WRDS 보완 후에도 DF가 비어 있습니다 (THCH)
# ⚠ THCH: 분석 결과 없음, 스킵
#
# === [37/1000] HTCO 처리 시작 ===
# ================================================================================
# [HTCO] 통합 재무분석 시작
# ✓ Entity: HIGH-TREND INTERNATIONAL GROUP (CIK: 0001928948)
# ✓ EDGAR 정규화 DF: 8 rows × 25 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 8 rows × 25 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 8 rows × 39 cols
# [HTCO] 통합 재무분석 종료
# ================================================================================
# ✓ Saved HTCO data: 8 dates x 39 items
# ✓ HTCO (HIGH-TREND INTERNATIONAL GROUP) 저장 완료
#
# === [38/1000] IMUX 처리 시작 ===
# ================================================================================
# [IMUX] 통합 재무분석 시작
# ✓ Entity: Immunic, Inc. (CIK: 1280776)
# ✓ EDGAR 정규화 DF: 53 rows × 24 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 53 rows × 24 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 53 rows × 36 cols
# [IMUX] 통합 재무분석 종료
# ================================================================================
# ✓ Saved IMUX data: 53 dates x 36 items
# ✓ IMUX (Immunic, Inc.) 저장 완료
#
# === [39/1000] RCT 처리 시작 ===
# ================================================================================
# [RCT] 통합 재무분석 시작
# ✓ Entity: RedCloud Holdings plc (CIK: 0002027360)
# ✓ EDGAR 정규화 DF: 3 rows × 14 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 3 rows × 14 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 3 rows × 26 cols
# [RCT] 통합 재무분석 종료
# ================================================================================
# ✓ Saved RCT data: 3 dates x 26 items
# ✓ RCT (RedCloud Holdings plc) 저장 완료
#
# === [40/1000] UCL 처리 시작 ===
# ================================================================================
# [UCL] 통합 재무분석 시작
# ✓ Entity: UCLOUDLINK GROUP INC. (CIK: 1775898)
# ✓ EDGAR 정규화 DF: 11 rows × 28 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 11 rows × 28 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 11 rows × 43 cols
# [UCL] 통합 재무분석 종료
# ================================================================================
# ✓ Saved UCL data: 11 dates x 43 items
# ✓ UCL (UCLOUDLINK GROUP INC.) 저장 완료
#
# === [41/1000] SNT 처리 시작 ===
# ================================================================================
# [SNT] 통합 재무분석 시작
# ✓ Entity: SENSTAR TECHNOLOGIES CORPORATION (CIK: 0001993727)
# ✓ EDGAR 정규화 DF: 4 rows × 14 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 4 rows × 14 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 4 rows × 27 cols
# [SNT] 통합 재무분석 종료
# ================================================================================
# ✓ Saved SNT data: 4 dates x 27 items
# ✓ SNT (SENSTAR TECHNOLOGIES CORPORATION) 저장 완료
#
# === [42/1000] WTG 처리 시작 ===
# ================================================================================
# [WTG] 통합 재무분석 시작
# ✓ Entity: WINTERGREEN ACQUISITION CORP. (CIK: 0002053927)
# ✓ EDGAR 정규화 DF: 5 rows × 11 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 5 rows × 11 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 5 rows × 22 cols
# [WTG] 통합 재무분석 종료
# ================================================================================
# ✓ Saved WTG data: 5 dates x 22 items
# ✓ WTG (WINTERGREEN ACQUISITION CORP.) 저장 완료
#
# === [43/1000] TIL 처리 시작 ===
# ================================================================================
# [TIL] 통합 재무분석 시작
# ✓ Entity: Instil Bio, Inc. (CIK: 1789769)
# ✓ EDGAR 정규화 DF: 25 rows × 25 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 25 rows × 25 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 25 rows × 36 cols
# [TIL] 통합 재무분석 종료
# ================================================================================
# ✓ Saved TIL data: 25 dates x 36 items
# ✓ TIL (Instil Bio, Inc.) 저장 완료
#
# === [44/1000] BRID 처리 시작 ===
# ================================================================================
# [BRID] 통합 재무분석 시작
# ✓ Entity: BRIDGFORD FOODS CORPORATION (CIK: 14177)
# ✓ EDGAR 정규화 DF: 65 rows × 27 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 65 rows × 27 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 65 rows × 44 cols
# [BRID] 통합 재무분석 종료
# ================================================================================
# ✓ Saved BRID data: 65 dates x 44 items
# ✓ BRID (BRIDGFORD FOODS CORPORATION) 저장 완료
#
# === [45/1000] ASRT 처리 시작 ===
# ================================================================================
# [ASRT] 통합 재무분석 시작
# ✓ Entity: ASSERTIO HOLDINGS, INC. (CIK: 1808665)
# ✓ EDGAR 정규화 DF: 28 rows × 30 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 28 rows × 30 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 28 rows × 44 cols
# [ASRT] 통합 재무분석 종료
# ================================================================================
# ✓ Saved ASRT data: 28 dates x 44 items
# ✓ ASRT (ASSERTIO HOLDINGS, INC.) 저장 완료
#
# === [46/1000] XBIT 처리 시작 ===
# ================================================================================
# [XBIT] 통합 재무분석 시작
# ✓ Entity: XBIOTECH INC. (CIK: 1626878)
# ✓ EDGAR 정규화 DF: 49 rows × 23 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 49 rows × 23 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 49 rows × 37 cols
# [XBIT] 통합 재무분석 종료
# ================================================================================
# ✓ Saved XBIT data: 49 dates x 37 items
# ✓ XBIT (XBIOTECH INC.) 저장 완료
#
# === [47/1000] IMA 처리 시작 ===
# ================================================================================
# [IMA] 통합 재무분석 시작
# ✓ Entity: ImageneBio, Inc. (CIK: 1835579)
# ✓ EDGAR 정규화 DF: 24 rows × 24 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 24 rows × 24 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 24 rows × 35 cols
# [IMA] 통합 재무분석 종료
# ================================================================================
# ✓ Saved IMA data: 24 dates x 35 items
# ✓ IMA (ImageneBio, Inc.) 저장 완료
#
# === [48/1000] RRGB 처리 시작 ===
# ================================================================================
# [RRGB] 통합 재무분석 시작
# ✓ Entity: RED ROBIN GOURMET BURGERS, INC. (CIK: 1171759)
# ✓ EDGAR 정규화 DF: 65 rows × 28 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 65 rows × 28 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 65 rows × 42 cols
# [RRGB] 통합 재무분석 종료
# ================================================================================
# ✓ Saved RRGB data: 65 dates x 42 items
# ✓ RRGB (RED ROBIN GOURMET BURGERS, INC.) 저장 완료
#
# === [49/1000] MCHX 처리 시작 ===
# ================================================================================
# [MCHX] 통합 재무분석 시작
# ✓ Entity: Marchex, Inc. (CIK: 1224133)
# ✓ EDGAR 정규화 DF: 64 rows × 27 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 64 rows × 27 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 64 rows × 40 cols
# [MCHX] 통합 재무분석 종료
# ================================================================================
# ✓ Saved MCHX data: 64 dates x 40 items
# ✓ MCHX (Marchex, Inc.) 저장 완료
#
# === [50/1000] LAZR 처리 시작 ===
# ================================================================================
# [LAZR] 통합 재무분석 시작
# ✓ Entity: Luminar Technologies, Inc./DE (CIK: 1758057)
# ✓ EDGAR 정규화 DF: 29 rows × 31 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 29 rows × 31 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 29 rows × 48 cols
# [LAZR] 통합 재무분석 종료
# ================================================================================
# ✓ Saved LAZR data: 29 dates x 48 items
# ✓ LAZR (Luminar Technologies, Inc./DE) 저장 완료
#
# === [51/1000] HOUR 처리 시작 ===
# ================================================================================
# [HOUR] 통합 재무분석 시작
# ✓ Entity: Hour Loop, Inc. (CIK: 0001874875)
# ✓ EDGAR 정규화 DF: 21 rows × 26 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 21 rows × 26 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 21 rows × 43 cols
# [HOUR] 통합 재무분석 종료
# ================================================================================
# ✓ Saved HOUR data: 21 dates x 43 items
# ✓ HOUR (Hour Loop, Inc.) 저장 완료
#
# === [52/1000] RDAC 처리 시작 ===
# ================================================================================
# [RDAC] 통합 재무분석 시작
# ✓ Entity: RISING DRAGON ACQUISITION CORP. (CIK: 0002018145)
# ✓ EDGAR 정규화 DF: 7 rows × 11 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 7 rows × 11 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 7 rows × 21 cols
# [RDAC] 통합 재무분석 종료
# ================================================================================
# ✓ Saved RDAC data: 7 dates x 21 items
# ✓ RDAC (RISING DRAGON ACQUISITION CORP.) 저장 완료
#
# === [53/1000] TEAD 처리 시작 ===
# ================================================================================
# [TEAD] 통합 재무분석 시작
# ✓ Entity: Teads Holding Co. (CIK: 1454938)
# ✓ EDGAR 정규화 DF: 25 rows × 29 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 25 rows × 29 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 25 rows × 43 cols
# [TEAD] 통합 재무분석 종료
# ================================================================================
# ✓ Saved TEAD data: 25 dates x 43 items
# ✓ TEAD (Teads Holding Co.) 저장 완료
#
# === [54/1000] ALGS 처리 시작 ===
# ================================================================================
# [ALGS] 통합 재무분석 시작
# ✓ Entity: Aligos Therapeutics, Inc. (CIK: 1799448)
# ✓ EDGAR 정규화 DF: 27 rows × 21 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 27 rows × 21 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 27 rows × 32 cols
# [ALGS] 통합 재무분석 종료
# ================================================================================
# ✓ Saved ALGS data: 27 dates x 32 items
# ✓ ALGS (Aligos Therapeutics, Inc.) 저장 완료
#
# === [55/1000] INCR 처리 시작 ===
# ================================================================================
# [INCR] 통합 재무분석 시작
# ✓ Entity: INTERCURE LTD. (CIK: 0001857030)
# ⚠ EDGAR 정규화 DF가 비어 있습니다 (INCR)
# ✓ EDGAR 정규화 DF: 0 rows × 0 cols
# ⚠ EDGAR 입력 DF가 비어있습니다. WRDS만으로 구성합니다.
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ⚠ WRDS 보완 후에도 DF가 비어 있습니다 (INCR)
# ⚠ INCR: 분석 결과 없음, 스킵
#
# === [56/1000] RGS 처리 시작 ===
# ================================================================================
# [RGS] 통합 재무분석 시작
# ✓ Entity: Regis Corp (CIK: 716643)
# ✓ EDGAR 정규화 DF: 67 rows × 29 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 67 rows × 29 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 67 rows × 44 cols
# [RGS] 통합 재무분석 종료
# ================================================================================
# ✓ Saved RGS data: 67 dates x 44 items
# ✓ RGS (Regis Corp) 저장 완료
#
# === [57/1000] IFRX 처리 시작 ===
# ================================================================================
# [IFRX] 통합 재무분석 시작
# ✓ Entity: InflaRx N.V. (CIK: 1708688)
# ⚠ EDGAR 정규화 DF가 비어 있습니다 (IFRX)
# ✓ EDGAR 정규화 DF: 0 rows × 0 cols
# ⚠ EDGAR 입력 DF가 비어있습니다. WRDS만으로 구성합니다.
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ⚠ WRDS 보완 후에도 DF가 비어 있습니다 (IFRX)
# ⚠ IFRX: 분석 결과 없음, 스킵
#
# === [58/1000] HCHL 처리 시작 ===
# ================================================================================
# [HCHL] 통합 재무분석 시작
# ✗ EDGAR Company Facts 로딩 실패 (HCHL): Company Facts 요청 실패: 404 https://data.sec.gov/api/xbrl/companyfacts/CIK0002046656.json
# ⚠ HCHL: 분석 결과 없음, 스킵
#
# === [59/1000] NTIC 처리 시작 ===
# ================================================================================
# [NTIC] 통합 재무분석 시작
# ✓ Entity: NORTHERN TECHNOLOGIES INTERNATIONAL CORPORATION (CIK: 875582)
# ✓ EDGAR 정규화 DF: 61 rows × 26 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 61 rows × 26 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 61 rows × 41 cols
# [NTIC] 통합 재무분석 종료
# ================================================================================
# ✓ Saved NTIC data: 61 dates x 41 items
# ✓ NTIC (NORTHERN TECHNOLOGIES INTERNATIONAL CORPORATION) 저장 완료
#
# === [60/1000] CLNN 처리 시작 ===
# ================================================================================
# [CLNN] 통합 재무분석 시작
# ✓ Entity: Clene Inc. (CIK: 1822791)
# ✓ EDGAR 정규화 DF: 25 rows × 28 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 25 rows × 28 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 25 rows × 44 cols
# [CLNN] 통합 재무분석 종료
# ================================================================================
# ✓ Saved CLNN data: 25 dates x 44 items
# ✓ CLNN (Clene Inc.) 저장 완료
#
# === [61/1000] FTAIM 처리 시작 ===
# ================================================================================
# [FTAIM] 통합 재무분석 시작
# ✓ Entity: FTAI AVIATION LTD. (CIK: 1590364)
# ✓ EDGAR 정규화 DF: 49 rows × 29 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 49 rows × 29 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 49 rows × 45 cols
# [FTAIM] 통합 재무분석 종료
# ================================================================================
# ✓ Saved FTAIM data: 49 dates x 45 items
# ✓ FTAIM (FTAI AVIATION LTD.) 저장 완료
#
# === [62/1000] YIBO 처리 시작 ===
# ================================================================================
# [YIBO] 통합 재무분석 시작
# ✓ Entity: Planet Image International Limited (CIK: 0001868395)
# ✓ EDGAR 정규화 DF: 7 rows × 26 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 7 rows × 26 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 7 rows × 43 cols
# [YIBO] 통합 재무분석 종료
# ================================================================================
# ✓ Saved YIBO data: 7 dates x 43 items
# ✓ YIBO (Planet Image International Limited) 저장 완료
#
# === [63/1000] OFS 처리 시작 ===
# ================================================================================
# [OFS] 통합 재무분석 시작
# ✓ Entity: OFS CAPITAL CORPORATION (CIK: 0001487918)
# ✓ EDGAR 정규화 DF: 21 rows × 9 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 21 rows × 9 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 21 rows × 19 cols
# [OFS] 통합 재무분석 종료
# ================================================================================
# ✓ Saved OFS data: 21 dates x 19 items
# ✓ OFS (OFS CAPITAL CORPORATION) 저장 완료
#
# === [64/1000] RITR 처리 시작 ===
# ================================================================================
# [RITR] 통합 재무분석 시작
# ✓ Entity: Reitar Logtech Holdings Limited (CIK: 0001951229)
# ✓ EDGAR 정규화 DF: 3 rows × 14 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 3 rows × 14 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 3 rows × 26 cols
# [RITR] 통합 재무분석 종료
# ================================================================================
# ✓ Saved RITR data: 3 dates x 26 items
# ✓ RITR (Reitar Logtech Holdings Limited) 저장 완료
#
# === [65/1000] EURKU 처리 시작 ===
# ================================================================================
# [EURKU] 통합 재무분석 시작
# ✓ Entity: Eureka Acquisition Corp (CIK: 0002000410)
# ✓ EDGAR 정규화 DF: 9 rows × 13 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 9 rows × 13 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 9 rows × 24 cols
# [EURKU] 통합 재무분석 종료
# ================================================================================
# ✓ Saved EURKU data: 9 dates x 24 items
# ✓ EURKU (Eureka Acquisition Corp) 저장 완료
#
# === [66/1000] SFWL 처리 시작 ===
# ================================================================================
# [SFWL] 통합 재무분석 시작
# ✓ Entity: Shengfeng Development Limited (CIK: 0001863218)
# ✓ EDGAR 정규화 DF: 9 rows × 32 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 9 rows × 32 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 9 rows × 49 cols
# [SFWL] 통합 재무분석 종료
# ================================================================================
# ✓ Saved SFWL data: 9 dates x 49 items
# ✓ SFWL (Shengfeng Development Limited) 저장 완료
#
# === [67/1000] FLNT 처리 시작 ===
# ================================================================================
# [FLNT] 통합 재무분석 시작
# ✓ Entity: Fluent, Inc. (CIK: 1460329)
# ✓ EDGAR 정규화 DF: 51 rows × 32 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 51 rows × 32 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 51 rows × 46 cols
# [FLNT] 통합 재무분석 종료
# ================================================================================
# ✓ Saved FLNT data: 51 dates x 46 items
# ✓ FLNT (Fluent, Inc.) 저장 완료
#
# === [68/1000] LASE 처리 시작 ===
# ================================================================================
# [LASE] 통합 재무분석 시작
# ✓ Entity: Laser     Photonics Corporation (CIK: 1807887)
# ✓ EDGAR 정규화 DF: 25 rows × 29 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 25 rows × 29 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 25 rows × 46 cols
# [LASE] 통합 재무분석 종료
# ================================================================================
# ✓ Saved LASE data: 25 dates x 46 items
# ✓ LASE (Laser     Photonics Corporation) 저장 완료
#
# === [69/1000] ZENV 처리 시작 ===
# ================================================================================
# [ZENV] 통합 재무분석 시작
# ✓ Entity: Zenvia Inc. (CIK: 0001836934)
# ⚠ EDGAR 정규화 DF가 비어 있습니다 (ZENV)
# ✓ EDGAR 정규화 DF: 0 rows × 0 cols
# ⚠ EDGAR 입력 DF가 비어있습니다. WRDS만으로 구성합니다.
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ⚠ WRDS 보완 후에도 DF가 비어 있습니다 (ZENV)
# ⚠ ZENV: 분석 결과 없음, 스킵
#
# === [70/1000] FORA 처리 시작 ===
# ================================================================================
# [FORA] 통합 재무분석 시작
# ✓ Entity: FORIAN INC. (CIK: 1829280)
# ✓ EDGAR 정규화 DF: 25 rows × 25 cols
# ...
# [DMAAR] 통합 재무분석 종료
# ================================================================================
# ✓ Saved DMAAR data: 6 dates x 22 items
# ✓ DMAAR (DRUGS MADE IN AMERICA ACQUISITION CORP.) 저장 완료
#
# === [978/1000] RIBBR 처리 시작 ===
# ================================================================================
# [RIBBR] 통합 재무분석 시작
# ✓ Entity: Ribbon Acquisition Corporation (CIK: 0002035016)
# ✓ EDGAR 정규화 DF: 5 rows × 12 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql: SELECT * FROM us_fundq WHERE tic=%s
# (0, '')
# unable to rollback
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 5 rows × 12 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 5 rows × 23 cols
# [RIBBR] 통합 재무분석 종료
# ================================================================================
# ✓ Saved RIBBR data: 5 dates x 23 items
# ✓ RIBBR (Ribbon Acquisition Corporation) 저장 완료
#
# === [979/1000] KFIIR 처리 시작 ===
# ================================================================================
# [KFIIR] 통합 재무분석 시작
# ✓ Entity: K&F GROWTH ACQUISITION CORP. II (CIK: 0002029976)
# ✓ EDGAR 정규화 DF: 5 rows × 13 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql: SELECT * FROM us_fundq WHERE tic=%s
# (0, '')
# unable to rollback
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 5 rows × 13 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 5 rows × 24 cols
# [KFIIR] 통합 재무분석 종료
# ================================================================================
# ✓ Saved KFIIR data: 5 dates x 24 items
# ✓ KFIIR (K&F GROWTH ACQUISITION CORP. II) 저장 완료
#
# === [980/1000] COLAR 처리 시작 ===
# ================================================================================
# [COLAR] 통합 재무분석 시작
# ✓ Entity: Columbus Acquisition Corp/Cayman Islands (CIK: 0002028201)
# ✓ EDGAR 정규화 DF: 7 rows × 12 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql: SELECT * FROM us_fundq WHERE tic=%s
# (0, '')
# unable to rollback
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 7 rows × 12 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 7 rows × 23 cols
# [COLAR] 통합 재무분석 종료
# ================================================================================
# ✓ Saved COLAR data: 7 dates x 23 items
# ✓ COLAR (Columbus Acquisition Corp/Cayman Islands) 저장 완료
#
# === [981/1000] AACBR 처리 시작 ===
# ================================================================================
# [AACBR] 통합 재무분석 시작
# ✓ Entity: ARTIUS II ACQUISITION INC. (CIK: 0002034334)
# ✓ EDGAR 정규화 DF: 6 rows × 10 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql: SELECT * FROM us_fundq WHERE tic=%s
# (0, '')
# unable to rollback
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 6 rows × 10 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 6 rows × 21 cols
# [AACBR] 통합 재무분석 종료
# ================================================================================
# ✓ Saved AACBR data: 6 dates x 21 items
# ✓ AACBR (ARTIUS II ACQUISITION INC.) 저장 완료
#
# === [982/1000] GENVR 처리 시작 ===
# ================================================================================
# [GENVR] 통합 재무분석 시작
# ✓ Entity: Gen Digital Inc. (CIK: 849399)
# ✓ EDGAR 정규화 DF: 73 rows × 32 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql: SELECT * FROM us_fundq WHERE tic=%s
# (0, '')
# unable to rollback
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 73 rows × 32 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 73 rows × 49 cols
# [GENVR] 통합 재무분석 종료
# ================================================================================
# ✓ Saved GENVR data: 73 dates x 49 items
# ✓ GENVR (Gen Digital Inc.) 저장 완료
#
# === [983/1000] FERAR 처리 시작 ===
# ================================================================================
# [FERAR] 통합 재무분석 시작
# ✓ Entity: FIFTH ERA ACQUISITION CORP I (CIK: 0002025401)
# ✓ EDGAR 정규화 DF: 6 rows × 13 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql: SELECT * FROM us_fundq WHERE tic=%s
# (0, '')
# unable to rollback
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 6 rows × 13 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 6 rows × 24 cols
# [FERAR] 통합 재무분석 종료
# ================================================================================
# ✓ Saved FERAR data: 6 dates x 24 items
# ✓ FERAR (FIFTH ERA ACQUISITION CORP I) 저장 완료
#
# === [984/1000] QSEAR 처리 시작 ===
# ================================================================================
# [QSEAR] 통합 재무분석 시작
# ✓ Entity: Quartzsea Acquisition Corporation (CIK: 0002047455)
# ✓ EDGAR 정규화 DF: 4 rows × 11 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql: SELECT * FROM us_fundq WHERE tic=%s
# (0, '')
# unable to rollback
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 4 rows × 11 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 4 rows × 22 cols
# [QSEAR] 통합 재무분석 종료
# ================================================================================
# ✓ Saved QSEAR data: 4 dates x 22 items
# ✓ QSEAR (Quartzsea Acquisition Corporation) 저장 완료
#
# === [985/1000] CHACR 처리 시작 ===
# ================================================================================
# [CHACR] 통합 재무분석 시작
# ✓ Entity: CRANE HARBOR ACQUISITION CORP. (CIK: 0002054174)
# ✓ EDGAR 정규화 DF: 3 rows × 9 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql: SELECT * FROM us_fundq WHERE tic=%s
# (0, '')
# unable to rollback
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 3 rows × 9 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 3 rows × 20 cols
# [CHACR] 통합 재무분석 종료
# ================================================================================
# ✓ Saved CHACR data: 3 dates x 20 items
# ✓ CHACR (CRANE HARBOR ACQUISITION CORP.) 저장 완료
#
# === [986/1000] SZZLR 처리 시작 ===
# ================================================================================
# [SZZLR] 통합 재무분석 시작
# ✓ Entity: Sizzle Acquisition Corp. II (CIK: 0002030663)
# ✓ EDGAR 정규화 DF: 5 rows × 11 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql: SELECT * FROM us_fundq WHERE tic=%s
# (0, '')
# unable to rollback
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 5 rows × 11 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 5 rows × 22 cols
# [SZZLR] 통합 재무분석 종료
# ================================================================================
# ✓ Saved SZZLR data: 5 dates x 22 items
# ✓ SZZLR (Sizzle Acquisition Corp. II) 저장 완료
#
# === [987/1000] UYSCR 처리 시작 ===
# ================================================================================
# [UYSCR] 통합 재무분석 시작
# ✓ Entity: UY Scuti Acquisition Corp. (CIK: 0002036973)
# ✓ EDGAR 정규화 DF: 7 rows × 13 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql: SELECT * FROM us_fundq WHERE tic=%s
# (0, '')
# unable to rollback
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 7 rows × 13 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 7 rows × 24 cols
# [UYSCR] 통합 재무분석 종료
# ================================================================================
# ✓ Saved UYSCR data: 7 dates x 24 items
# ✓ UYSCR (UY Scuti Acquisition Corp.) 저장 완료
#
# === [988/1000] SDHIR 처리 시작 ===
# ================================================================================
# [SDHIR] 통합 재무분석 시작
# ✓ Entity: SIDDHI ACQUISITION CORP (CIK: 0002034037)
# ✓ EDGAR 정규화 DF: 6 rows × 10 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql: SELECT * FROM us_fundq WHERE tic=%s
# (0, '')
# unable to rollback
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 6 rows × 10 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 6 rows × 21 cols
# [SDHIR] 통합 재무분석 종료
# ================================================================================
# ✓ Saved SDHIR data: 6 dates x 21 items
# ✓ SDHIR (SIDDHI ACQUISITION CORP) 저장 완료
#
# === [989/1000] PELIR 처리 시작 ===
# ================================================================================
# [PELIR] 통합 재무분석 시작
# ✓ Entity: Pelican Acquisition Corporation (CIK: 0002037431)
# ✓ EDGAR 정규화 DF: 3 rows × 11 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql: SELECT * FROM us_fundq WHERE tic=%s
# (0, '')
# unable to rollback
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 3 rows × 11 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 3 rows × 22 cols
# [PELIR] 통합 재무분석 종료
# ================================================================================
# ✓ Saved PELIR data: 3 dates x 22 items
# ✓ PELIR (Pelican Acquisition Corporation) 저장 완료
#
# === [990/1000] IPCXR 처리 시작 ===
# ================================================================================
# [IPCXR] 통합 재무분석 시작
# ✓ Entity: INFLECTION POINT ACQUISITION CORP. III (CIK: 0002012318)
# ✓ EDGAR 정규화 DF: 7 rows × 10 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql: SELECT * FROM us_fundq WHERE tic=%s
# (0, '')
# unable to rollback
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 7 rows × 10 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 7 rows × 21 cols
# [IPCXR] 통합 재무분석 종료
# ================================================================================
# ✓ Saved IPCXR data: 7 dates x 21 items
# ✓ IPCXR (INFLECTION POINT ACQUISITION CORP. III) 저장 완료
#
# === [991/1000] CHPGR 처리 시작 ===
# ================================================================================
# [CHPGR] 통합 재무분석 시작
# ✓ Entity: ChampionsGate Acquisition Corporation (CIK: 0002024460)
# ✓ EDGAR 정규화 DF: 7 rows × 11 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql: SELECT * FROM us_fundq WHERE tic=%s
# (0, '')
# unable to rollback
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 7 rows × 11 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 7 rows × 22 cols
# [CHPGR] 통합 재무분석 종료
# ================================================================================
# ✓ Saved CHPGR data: 7 dates x 22 items
# ✓ CHPGR (ChampionsGate Acquisition Corporation) 저장 완료
#
# === [992/1000] CRAQR 처리 시작 ===
# ================================================================================
# [CRAQR] 통합 재무분석 시작
# ✓ Entity: Cal Redwood Acquisition Corp. (CIK: 0002058359)
# ✓ EDGAR 정규화 DF: 3 rows × 13 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql: SELECT * FROM us_fundq WHERE tic=%s
# (0, '')
# unable to rollback
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 3 rows × 13 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 3 rows × 24 cols
# [CRAQR] 통합 재무분석 종료
# ================================================================================
# ✓ Saved CRAQR data: 3 dates x 24 items
# ✓ CRAQR (Cal Redwood Acquisition Corp.) 저장 완료
#
# === [993/1000] LCCCR 처리 시작 ===
# ================================================================================
# [LCCCR] 통합 재무분석 시작
# ✓ Entity: Lakeshore Acquisition III Corp. (CIK: 0002049248)
# ✓ EDGAR 정규화 DF: 4 rows × 8 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql: SELECT * FROM us_fundq WHERE tic=%s
# (0, '')
# unable to rollback
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 4 rows × 8 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 4 rows × 19 cols
# [LCCCR] 통합 재무분석 종료
# ================================================================================
# ✓ Saved LCCCR data: 4 dates x 19 items
# ✓ LCCCR (Lakeshore Acquisition III Corp.) 저장 완료
#
# === [994/1000] EGHAR 처리 시작 ===
# ================================================================================
# [EGHAR] 통합 재무분석 시작
# ✓ Entity: EGH ACQUISITION CORP. (CIK: 0002052547)
# ✓ EDGAR 정규화 DF: 4 rows × 11 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql: SELECT * FROM us_fundq WHERE tic=%s
# (0, '')
# unable to rollback
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 4 rows × 11 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 4 rows × 22 cols
# [EGHAR] 통합 재무분석 종료
# ================================================================================
# ✓ Saved EGHAR data: 4 dates x 22 items
# ✓ EGHAR (EGH ACQUISITION CORP.) 저장 완료
#
# === [995/1000] RNBW 처리 시작 ===
# ================================================================================
# [RNBW] 통합 재무분석 시작
# ✗ EDGAR Company Facts 로딩 실패 (RNBW): Company Facts 요청 실패: 404 https://data.sec.gov/api/xbrl/companyfacts/CIK0002046919.json
# ⚠ RNBW: 분석 결과 없음, 스킵
#
# === [996/1000] TVAIR 처리 시작 ===
# ================================================================================
# [TVAIR] 통합 재무분석 시작
# ✓ Entity: THAYER VENTURES ACQUISITION CORPORATION II (CIK: 0001872228)
# ✓ EDGAR 정규화 DF: 7 rows × 12 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql: SELECT * FROM us_fundq WHERE tic=%s
# (0, '')
# unable to rollback
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 7 rows × 12 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 7 rows × 23 cols
# [TVAIR] 통합 재무분석 종료
# ================================================================================
# ✓ Saved TVAIR data: 7 dates x 23 items
# ✓ TVAIR (THAYER VENTURES ACQUISITION CORPORATION II) 저장 완료
#
# === [997/1000] OYSER 처리 시작 ===
# ================================================================================
# [OYSER] 통합 재무분석 시작
# ✓ Entity: OYSTER ENTERPRISES II ACQUISITION CORP (CIK: 0002042182)
# ✓ EDGAR 정규화 DF: 4 rows × 12 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql: SELECT * FROM us_fundq WHERE tic=%s
# (0, '')
# unable to rollback
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 4 rows × 12 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 4 rows × 23 cols
# [OYSER] 통합 재무분석 종료
# ================================================================================
# ✓ Saved OYSER data: 4 dates x 23 items
# ✓ OYSER (OYSTER ENTERPRISES II ACQUISITION CORP) 저장 완료
#
# === [998/1000] KCHVR 처리 시작 ===
# ================================================================================
# [KCHVR] 통합 재무분석 시작
# ✓ Entity: Kochav Defense Acquisition Corp. (CIK: 0002053799)
# ✓ EDGAR 정규화 DF: 3 rows × 12 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql: SELECT * FROM us_fundq WHERE tic=%s
# (0, '')
# unable to rollback
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 3 rows × 12 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 3 rows × 23 cols
# [KCHVR] 통합 재무분석 종료
# ================================================================================
# ✓ Saved KCHVR data: 3 dates x 23 items
# ✓ KCHVR (Kochav Defense Acquisition Corp.) 저장 완료
#
# === [999/1000] WTGUR 처리 시작 ===
# ================================================================================
# [WTGUR] 통합 재무분석 시작
# ✓ Entity: WINTERGREEN ACQUISITION CORP. (CIK: 0002053927)
# ✓ EDGAR 정규화 DF: 5 rows × 11 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql: SELECT * FROM us_fundq WHERE tic=%s
# (0, '')
# unable to rollback
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 5 rows × 11 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 5 rows × 22 cols
# [WTGUR] 통합 재무분석 종료
# ================================================================================
# ✓ Saved WTGUR data: 5 dates x 22 items
# ✓ WTGUR (WINTERGREEN ACQUISITION CORP.) 저장 완료
#
# === [1000/1000] GTERR 처리 시작 ===
# ================================================================================
# [GTERR] 통합 재무분석 시작
# ✓ Entity: GLOBA TERRA ACQUISITION CORPORATION (CIK: 0002043766)
# ✓ EDGAR 정규화 DF: 4 rows × 11 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql: SELECT * FROM us_fundq WHERE tic=%s
# (0, '')
# unable to rollback
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 4 rows × 11 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 4 rows × 21 cols
# [GTERR] 통합 재무분석 종료
# ================================================================================
# ✓ Saved GTERR data: 4 dates x 21 items
# ✓ GTERR (GLOBA TERRA ACQUISITION CORPORATION) 저장 완료
#
# === 전체 작업 완료 ===

# %%
import pandas as pd
import pymysql
from typing import Dict, Optional, List


def quarter_end_from_report_date(report_date: pd.Timestamp) -> pd.Timestamp:
    y = report_date.year
    m = report_date.month

    if m in [1, 2, 3]:
        return pd.Timestamp(f"{y}-03-31")
    elif m in [4, 5, 6]:
        return pd.Timestamp(f"{y}-06-30")
    elif m in [7, 8, 9]:
        return pd.Timestamp(f"{y}-09-30")
    else:
        return pd.Timestamp(f"{y}-12-31")


def fetch_sec_financial_pivot_fixed(
    db_info: Dict[str, any],
    ticker: str,
    table_name: str = "sec_financial_data",
    start_date: Optional[str] = None,
    end_date: Optional[str] = None,
    item_list: Optional[List[str]] = None,
) -> pd.DataFrame:

    conn = pymysql.connect(
        host=db_info["host"], port=db_info.get("port", 3306),
        user=db_info["user"], password=db_info["password"],
        database=db_info["database"], charset="utf8mb4"
    )

    # -----------------------------
    # 1) 데이터 로드
    # -----------------------------
    try:
        where_clause = ["ticker=%s"]
        params = [ticker]

        if start_date:
            where_clause.append("date >= %s")
            params.append(start_date)
        if end_date:
            where_clause.append("date <= %s")
            params.append(end_date)
        if item_list:
            placeholders = ",".join(["%s"] * len(item_list))
            where_clause.append(f"item_name IN ({placeholders})")
            params.extend(item_list)

        where_sql = " AND ".join(where_clause)

        sql = f"""
            SELECT date, ticker, item_name, value
            FROM {table_name}
            WHERE {where_sql}
            ORDER BY date, item_name
        """

        df = pd.read_sql(sql, conn, params=params)
    finally:
        conn.close()

    if df.empty:
        print(f"[INFO] {ticker} 데이터 없음")
        return df

    # -----------------------------
    # 2) 기존 date → report_date로 이름 변경
    # -----------------------------
    df = df.rename(columns={"date": "report_date"})
    df["report_date"] = pd.to_datetime(df["report_date"])

    # -----------------------------
    # 3) report_date → 분기말 날짜(date)
    # -----------------------------
    df["date"] = df["report_date"].apply(quarter_end_from_report_date)

    # (중복 가능성 대비) 각 분기(date, ticker)별 대표 report_date 하나 선택
    # 여기서는 가장 늦은 날짜(max) 사용
    rep_dates = (
        df[["date", "ticker", "report_date"]]
        .drop_duplicates()
        .groupby(["date", "ticker"], as_index=False)["report_date"]
        .max()
    )

    # -----------------------------
    # 4) pivot 변환 (분기말 기준 wide)
    # -----------------------------
    df_pivot = df.pivot_table(
        index=["date", "ticker"],
        columns="item_name",
        values="value",
        aggfunc="last"
    ).sort_index()

    df_pivot = df_pivot.reset_index()

    # -----------------------------
    # 5) 대표 report_date 다시 붙이기
    # -----------------------------
    df_pivot = df_pivot.merge(rep_dates, how="left", on=["date", "ticker"])

    # 보기 편하게 컬럼 순서 조정: date, report_date, ticker, 나머지 item 들
    cols = ["date", "report_date", "ticker"] + [
        c for c in df_pivot.columns if c not in ("date", "report_date", "ticker")
    ]
    df_pivot = df_pivot[cols]

    return df_pivot

# %%
# 1) AAPL 전체 기간, 모든 item_name
fs_df = fetch_sec_financial_pivot_fixed(db_info, "INVX")
fs_df

# 2) 기간 제한 + 특정 항목만
# item_list = ["revenue", "net_income", "total_assets", "ROE", "OPM"]
# aapl_subset = fetch_sec_financial_pivot(
#     db_info,
#     "AAPL",
#     start_date="2015-01-01",
#     end_date="2024-12-31",
#     item_list=item_list
# )
# print(aapl_subset.tail())
# Out:
#          date report_date ticker  accounts_payable  accounts_receivable  \
# 0  2007-12-31  2007-12-31   INVX               NaN                  NaN
# 1  2008-12-31  2008-12-31   INVX               NaN                  NaN
# 2  2009-06-30  2009-06-30   INVX               NaN                  NaN
# 3  2009-09-30  2009-09-30   INVX               NaN                  NaN
# 4  2009-12-31  2009-12-31   INVX        24828000.0          130816000.0
# ..        ...         ...    ...               ...                  ...
# 63 2024-09-30  2024-09-30   INVX        83613000.0          225067000.0
# 64 2024-12-31  2024-12-31   INVX        65201000.0          239506000.0
# 65 2025-03-31  2025-03-31   INVX        76391000.0          236020000.0
# 66 2025-06-30  2025-06-30   INVX        65321000.0          220966000.0
# 67 2025-09-30  2025-09-30   INVX        66633000.0          220408000.0
#
#     accrued_liabilities  accumulated_depreciation  asset_turnover  \
# 0                   NaN                       NaN             NaN
# 1                   NaN                       NaN             NaN
# 2                   NaN                       NaN             NaN
# 3                   NaN                       NaN             NaN
# 4                   NaN                       NaN             NaN
# ..                  ...                       ...             ...
# 63           55884000.0                64540000.0        0.141862
# 64           60593000.0                73365000.0        0.181514
# 65           37116000.0                82051000.0        0.216880
# 66           48556000.0                87740000.0        0.200635
# 67           45680000.0                94284000.0        0.201115
#
#     capital_expenditures         cash  ...  quick_ratio  receivables_turnover  \
# 0                    NaN  201732000.0  ...          NaN                   NaN
# 1                    NaN   95952000.0  ...          NaN                   NaN
# 2                    NaN  115988000.0  ...          NaN                   NaN
# 3                    NaN  139018000.0  ...          NaN                   NaN
# 4                    NaN  197792000.0  ...      3.49041                   NaN
# ..                   ...          ...  ...          ...                   ...
# 63             4757000.0  185629000.0  ...      2.17278              0.847184
# 64             4757000.0  185629000.0  ...      2.27605              0.848457
# 65             4757000.0  185629000.0  ...      2.49204              1.288550
# 66             4757000.0  185629000.0  ...      2.68695              1.195440
# 67             4757000.0  185629000.0  ...      2.92620              1.077500
#
#         revenue       roa       roe     roic  stockholders_equity  \
# 0           NaN       NaN       NaN      NaN         5.924950e+08
# 1           NaN       NaN       NaN      NaN         5.594500e+08
# 2           NaN       NaN   4.77380      NaN         5.594500e+08
# 3           NaN       NaN   9.25749      NaN         5.594500e+08
# 4           NaN   9.40659  11.84900  3.84579         7.050850e+08
# ..          ...       ...       ...      ...                  ...
# 63  151817000.0  11.57780  20.44100 -1.63137         9.043510e+08
# 64  151817000.0  22.85090  29.69880 -2.41076         9.581560e+08
# 65  240415000.0  17.09160  28.64830  1.83705         9.783760e+08
# 66  224234000.0  17.47230  28.97130  1.89230         9.955530e+08
# 67  240000000.0  12.73030  15.63480  5.26193         1.038950e+09
#
#     total_assets  total_debt  total_liabilities
# 0            NaN         NaN                NaN
# 1            NaN         NaN                NaN
# 2            NaN         NaN                NaN
# 3            NaN         NaN                NaN
# 4   8.172460e+08         NaN        112161000.0
# ..           ...         ...                ...
# 63  1.132780e+09  12351000.0        228432000.0
# 64  1.197480e+09  24901000.0        239327000.0
# 65  1.196000e+09  19679000.0        217627000.0
# 66  1.227080e+09  34780000.0        231528000.0
# 67  1.253910e+09  20090000.0        214956000.0
#
# [68 rows x 51 columns]

# %%
def count_unique_tickers_sec_financial(db_info: dict,
                                       table_name: str = "sec_financial_data") -> int:
    """
    sec_financial_data 테이블에서 unique ticker 개수를 조회하여 반환하는 함수.
    """
    conn = pymysql.connect(
        host=db_info["host"],
        port=db_info["port"],
        user=db_info["user"],
        password=db_info["password"],
        database=db_info["database"],
        charset="utf8mb4"
    )

    try:
        query = f"SELECT DISTINCT ticker FROM {table_name};"
        df = pd.read_sql(query, conn)

        unique_ticker_count = df["ticker"].nunique()

        print(f"[INFO] Unique tickers in {table_name}: {unique_ticker_count}")
        return unique_ticker_count

    finally:
        conn.close()

# %%
import pymysql

count_unique_tickers_sec_financial(db_info)
# Out:
# [INFO] Unique tickers in sec_financial_data: 1571
# 1571

# %%
aapl_df.columns.tolist()
# Out:
# ['date',
#  'ticker',
#  'accounts_payable',
#  'accounts_receivable',
#  'accrued_liabilities',
#  'accumulated_depreciation',
#  'asset_turnover',
#  'capital_expenditures',
#  'cash',
#  'cost_of_revenue',
#  'current_assets',
#  'current_liabilities',
#  'current_ratio',
#  'days_inventory',
#  'days_receivables',
#  'debt_to_assets',
#  'debt_to_equity',
#  'deferred_revenue',
#  'depreciation_amortization',
#  'equity_multiplier',
#  'goodwill',
#  'gross_margin',
#  'gross_profit',
#  'income_tax_expense',
#  'intangible_assets',
#  'interest_expense',
#  'interest_income',
#  'inventory',
#  'inventory_turnover',
#  'long_term_debt',
#  'long_term_debt_current',
#  'net_income',
#  'net_margin',
#  'net_ppe',
#  'operating_expenses',
#  'operating_income',
#  'operating_margin',
#  'other_noncurrent_assets',
#  'pretax_income',
#  'quick_ratio',
#  'receivables_turnover',
#  'research_development',
#  'revenue',
#  'roa',
#  'roe',
#  'roic',
#  'short_term_debt',
#  'stockholders_equity',
#  'total_assets',
#  'total_liabilities']

# %%
# # 1) EDGAR 수집/정규화
# headers = {"User-Agent": "HoyoungPark Research <stox1224@email.com>"}
# facts   = fetch_company_facts( TICKER, headers=headers)
# parser  = CompanyFactsParser(facts)
# normal  = FinancialNormalizer(parser)
# edgar_df = normal.create_normalized_dataframe(period_type="quarterly")
#
# # 2) WRDS Validator
# db_info = {
#     "host": get_db_host(),
#     "port": 3307,
#     "user": "stox7412",
#     "password": "Apt106503!~",
#     "database": "investar",
# }
# validator = WRDSDataValidator(db_info)
#
# import sqlalchemy as sa
#
# # ① EDGAR 분기 DF 준비 (이미 갖고 계신 df: edgar_df)
# #    edgar_df.index = 분기 날짜, 컬럼에 'revenue' 포함
#
# # ② WRDS(us_fundq)에서 AAPL의 edate, ticker, saleq 로드
# db_info = {
#     "host": "192.168.0.230",
#     "port": 3307,
#     "user": "stox7412",
#     "password": "Apt106503!~",
#     "database": "investar",
# }

# %%
tickers = get_filtered_us_tickers()
# Out:
# 100%|██████████| 3774/3774 [00:04<00:00, 840.90it/s]
# 100%|██████████| 2745/2745 [00:02<00:00, 1050.06it/s]
# 100%|██████████| 294/294 [00:00<00:00, 1034.88it/s]
# 제외된 기업 수: 1812
# 남은 기업 수: 5001
# 티커 수: 5001

# %%
ticker_list = tickers[:10]
# Out:
# ['NVDA',
#  'AAPL',
#  'MSFT',
#  'AMZN',
#  'GOOGL',
#  'AVGO',
#  'GOOG',
#  'META',
#  'TSLA',
#  'NFLX']

# %%
# import pandas as pd
#
# # 1. 클라이언트 및 다운로더 설정
# user_agent = "PersonalResearch stox1224@email.com"
# client = SECAPIClient(user_agent, RateLimiter(10, 1.0))
# downloader = BulkDownloader(client, output_dir="./sec_data", max_workers=3)
#
# # 2. 다운로드할 기업 리스트
# # tickers = ['AAPL', 'MSFT', 'GOOGL', 'AMZN', 'TSLA', 'NVDA', 'META']
#
# # 3. 배치 다운로드 (자동으로 JSON 파일 저장)
# results = downloader.download_company_facts_batch(ticker_list)
#
# # 4. 각 기업별 데이터 처리
# all_financials = {}
#
# for ticker, company_facts in results.items():
#     headers = {"User-Agent": "HoyoungPark Research <stox1224@email.com>"}
#     facts   = fetch_company_facts(ticker, headers=headers)
#     parser  = CompanyFactsParser(facts)
#     normal  = FinancialNormalizer(parser)
#     edgar_df = normal.create_normalized_dataframe(period_type="quarterly")
#
#
#     parser = CompanyFactsParser(company_facts)
#     normalizer = FinancialNormalizer(parser)
#
#     # 재무데이터 정규화
#     df = normalizer.create_normalized_dataframe(period_type='quarterly')
#     df_billions = normalizer.convert_to_billions(df)
#
#     all_financials[ticker] = df_billions
#
#     # 개별 CSV 저장
#     # normalizer.export_to_csv(df_billions, f'{ticker}_financials.csv')
#
# print(f"총 {len(all_financials)}개 기업 데이터 수집 완료")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 5
#       3 # 1. 클라이언트 및 다운로더 설정
#       4 user_agent = "PersonalResearch stox1224@email.com"
# ----> 5 client = SECAPIClient(user_agent, RateLimiter(10, 1.0))
#       6 downloader = BulkDownloader(client, output_dir="./sec_data", max_workers=3)
#       8 # 2. 다운로드할 기업 리스트
#       9 # tickers = ['AAPL', 'MSFT', 'GOOGL', 'AMZN', 'TSLA', 'NVDA', 'META']
#      10
#      11 # 3. 배치 다운로드 (자동으로 JSON 파일 저장)
#
# NameError: name 'SECAPIClient' is not defined

# %%
TICKER = "GLW"   # ← 여기만 바꾸면 전체가 따라옵니

# 1) EDGAR 수집/정규화
headers = {"User-Agent": "HoyoungPark Research <stox1224@email.com>"}
facts   = fetch_company_facts( TICKER, headers=headers)
parser  = CompanyFactsParser(facts)
normal  = FinancialNormalizer(parser)
edgar_df = normal.create_normalized_dataframe(period_type="quarterly")

# 2) WRDS Validator
db_info = {
    "host": get_db_host(),
    "port": 3307,
    "user": "stox7412",
    "password": "Apt106503!~",
    "database": "investar",
}
validator = WRDSDataValidator(db_info)

# 3) 결합/보완 실행 (핵심: table_name='us_fundq', date_col='edate')
result_df = validator.validate_and_fill_improved(
    edgar_df=edgar_df,
    ticker= TICKER,
    table_name="us_fundq",   # 당신 DB 테이블
    days_tolerance=15,
    verbose=True,
    ticker_col="ticker",     # 당신 DB 컬럼
    date_col="edate"         # 당신 DB 컬럼
)

import sqlalchemy as sa

# ① EDGAR 분기 DF 준비 (이미 갖고 계신 df: edgar_df)
#    edgar_df.index = 분기 날짜, 컬럼에 'revenue' 포함

# ② WRDS(us_fundq)에서 AAPL의 edate, ticker, saleq 로드
db_info = {
    "host": "192.168.0.230",
    "port": 3307,
    "user": "stox7412",
    "password": "Apt106503!~",
    "database": "investar",
}
df_wrds = fetch_wrds_fundq_sample(
    db_info, ticker=TICKER , columns=["edate", "ticker", "saleq"], table_name="US_fundq"
)

# ③ 결측 보완 + 단위 정합
filled_df = fill_revenue_with_wrds(
    edgar_df=edgar_df,
    wrds_df=df_wrds,
    wrds_value_col="saleq",     # WRDS의 분기 매출 컬럼명
    days_tolerance=20,          # 분기말 근접 허용일
    verbose=True
)

print("\n[CHECK] revenue NaN:")
print("  before:", edgar_df["revenue"].isna().sum())
print("  after :", filled_df["revenue"].isna().sum())

if filled_df.empty:
    print("⚠ filled_df가 비어 있습니다 → result_df를 target_df로 대체합니다.")
    target_df = result_df.copy()
else:
    print("✓ filled_df가 유효합니다 → target_df에 filled_df를 사용합니다.")
    target_df = filled_df.copy()

from sec_data_pipeline.parsers.financial_normalizer import FinancialNormalizer


# parser는 EDGAR 데이터를 읽어온 CompanyFactsParser 등의 인스턴스
normalizer = FinancialNormalizer(parser=None)  # parser가 필요 없으면 None으로 두세요


# 1) 기본 추정: income_tax_expense / pretax_income
est = (filled_df.get('income_tax_expense') / filled_df.get('pretax_income'))

# 2) 이상치/음수/무한대 정리
est = est.replace([np.inf, -np.inf], np.nan)
# 적자 구간(pretax_income <= 0)은 추정치 제거
est = est.mask((filled_df.get('pretax_income') <= 0), np.nan)
# 0~0.5로 클리핑(50% 이상은 보통 이상치)
est = est.clip(lower=0.0, upper=0.3)

# 3) 결측 보강: 최근 값으로 보간 + 기본값 대체
# est = est.ffill().fillna(0.21)

# filled_df['tax_rate'] = 0.21
ratio = normal.calculate_financial_ratios(target_df)
# Out:
# ['NVDA',
#  'AAPL',
#  'MSFT',
#  'AMZN',
#  'GOOGL',
#  'AVGO',
#  'GOOG',
#  'META',
#  'TSLA',
#  'NFLX',
#  'COST',
#  'PLTR',
#  'ASML',
#  'AMD',
#  'CSCO',
#  'AZN',
#  'MU',
#  'TMUS',
#  'ISRG',
#  'SHOP',
#  'PEP',
#  'AMAT',
#  'LRCX',
#  'LIN',
#  'APP',
#  'AMGN',
#  'QCOM',
#  'INTC',
#  'PDD',
#  'BKNG',
#  'GILD',
#  'KLAC',
#  'TXN',
#  'ARM',
#  'ADBE',
#  'PANW',
#  'CRWD',
#  'ADI',
#  'SNY',
#  'HON',
#  'VRTX',
#  'MELI',
#  'ADP',
#  'SBUX',
#  'CMCSA',
#  'NTES',
#  'ORLY',
#  'DASH',
#  'REGN',
#  'CDNS',
#  'MAR',
#  'SNPS',
#  'CTAS',
#  'MNST',
#  'MDLZ',
#  'MRVL',
#  'ABNB',
#  'CSX',
#  'ADSK',
#  'WDAY',
#  'IDXX',
#  'FTNT',
#  'TRI',
#  'ROST',
#  'PYPL',
#  'STX',
#  'WBD',
#  'ALNY',
#  'ARGX',
#  'DDOG',
#  'PCAR',
#  'WDC',
#  'EA',
#  'MSTR',
#  'BKR',
#  'NXPI',
#  'ROP',
#  'FER',
#  'JD',
#  'ZS',
#  'FAST',
#  'TCOM',
#  'SYM',
#  'TTWO',
#  'INSM',
#  'MPWR',
#  'FANG',
#  'AXON',
#  'CCEP',
#  'BIDU',
#  'PAYX',
#  'TEAM',
#  'CPRT',
#  'EBAY',
#  'CTSH',
#  'ONC',
#  'KDP',
#  'GEHC',
#  'CRWV',
#  'RYAAY',
#  'KMB',
#  'FISV',
#  'NTRA',
#  'SNDK',
#  'UAL',
#  'EXPE',
#  'VRSK',
#  'KHC',
#  'CSGP',
#  'ERIC',
#  'VOD',
#  'TSCO',
#  'ODFL',
#  'MCHP',
#  'FSLR',
#  'EXE',
#  'MDB',
#  'BIIB',
#  'CRDO',
#  'TER',
#  'CHTR',
#  'ZM',
#  'ALAB',
#  'DXCM',
#  'BNTX',
#  'VRSN',
#  'ULTA',
#  'PODD',
#  'RPRX',
#  'RKLB',
#  'CYBR',
#  'NBIS',
#  'NTAP',
#  'ESLT',
#  'DLTR',
#  'GRAB',
#  'FLEX',
#  'FWONK',
#  'LULU',
#  'CASY',
#  'SSNC',
#  'UTHR',
#  'INCY',
#  'PTC',
#  'LITE',
#  'SATS',
#  'CHKP',
#  'ASTS',
#  'ILMN',
#  'LI',
#  'ON',
#  'SMCI',
#  'GMAB',
#  'TRMB',
#  'GFS',
#  'EXAS',
#  'RIVN',
#  'TTD',
#  'CDW',
#  'CHRW',
#  'LOGI',
#  'WWD',
#  'MEDP',
#  'FTAI',
#  'PSKY',
#  'HOLX',
#  'GEN',
#  'JBHT',
#  'NTNX',
#  'DKNG',
#  'COO',
#  'WMG',
#  'RVMD',
#  'ROIV',
#  'NBIX',
#  'OKTA',
#  'HTHT',
#  'DPZ',
#  'GH',
#  'ROKU',
#  'FFIV',
#  'AVAV',
#  'TEM',
#  'DOCU',
#  'FOX',
#  'BBIO',
#  'FOXA',
#  'MDGL',
#  'NDSN',
#  'NXT',
#  'ICLR',
#  'WYNN',
#  'SMMT',
#  'IONS',
#  'LECO',
#  'AKAM',
#  'VNOM',
#  'ASND',
#  'KTOS',
#  'ZBRA',
#  'JKHY',
#  'BSY',
#  'MTSI',
#  'PAA',
#  'VTRS',
#  'TXRH',
#  'EXEL',
#  'HAS',
#  'BILI',
#  'ENTG',
#  'CART',
#  'TSEM',
#  'JAZZ',
#  'ENSG',
#  'BMRN',
#  'COKE',
#  'RNA',
#  'MANH',
#  'ALGN',
#  'SAIL',
#  'BZ',
#  'CELH',
#  'TECH',
#  'STRL',
#  'MKSI',
#  'RMBS',
#  'MRNA',
#  'RGEN',
#  'NWSA',
#  'FYBR',
#  'SWKS',
#  'ABVX',
#  'LSCC',
#  'PEGA',
#  'IDCC',
#  'MBLY',
#  'POOL',
#  'HQY',
#  'CPB',
#  'FIVE',
#  'DRS',
#  'TIGO',
#  'NVMI',
#  'TTEK',
#  'HSIC',
#  'PPC',
#  'AAL',
#  'MORN',
#  'RGTI',
#  'HALO',
#  'APA',
#  'OTEX',
#  'NUVL',
#  'CORT',
#  'SANM',
#  'DOX',
#  'SFD',
#  'AMKR',
#  'TTAN',
#  'CYTK',
#  'APPF',
#  'DUOL',
#  'IESC',
#  'PCTY',
#  'SFM',
#  'MTCH',
#  'MASI',
#  'LYFT',
#  'QRVO',
#  'AEIS',
#  'GSAT',
#  'DBX',
#  'AAON',
#  'CFLT',
#  'MNDY',
#  'LKQ',
#  'AUR',
#  'AXSM',
#  'OLLI',
#  'CHDN',
#  'BRKR',
#  'SITM',
#  'VFS',
#  'SAIA',
#  'SOLS',
#  'FROG',
#  'WING',
#  'MRUS',
#  'RYTM',
#  'FIGR',
#  'CAI',
#  'NTSK',
#  'TTMI',
#  'DSGX',
#  'WAY',
#  'SIRI',
#  'LNW',
#  'COGT',
#  'MMYT',
#  'CDTX',
#  'GTLB',
#  'QMMM',
#  'GDS',
#  'GLBE',
#  'PTCT',
#  'SMTC',
#  'PCVX',
#  'BTSG',
#  'SRAD',
#  'MAT',
#  'RDNT',
#  'NICE',
#  'ARWR',
#  'CGNX',
#  'EXLS',
#  'LFUS',
#  'KRYS',
#  'LIF',
#  'CWST',
#  'RRR',
#  'URBN',
#  'IRTC',
#  'CRUS',
#  'ROAD',
#  'MIDD',
#  'BLLN',
#  'LBRDK',
#  'NXST',
#  'PTGX',
#  'RGC',
#  'OLED',
#  'CVLT',
#  'NWS',
#  'UFPI',
#  'TGTX',
#  'WFRD',
#  'CHRD',
#  'LEGN',
#  'MMSI',
#  'WIX',
#  'REYN',
#  'ATAT',
#  'CRSP',
#  'DOOO',
#  'QLYS',
#  'OS',
#  'BCPC',
#  'LLYVK',
#  'SOUN',
#  'TMDX',
#  'PI',
#  'GNTX',
#  'OPCH',
#  'SHC',
#  'APGE',
#  'WGS',
#  'ALKS',
#  'ALGM',
#  'KYMR',
#  'LGN',
#  'CAMT',
#  'CAR',
#  'IEP',
#  'PONY',
#  'CVCO',
#  'CCC',
#  'MZTI',
#  'PRAX',
#  'NAMS',
#  'CELC',
#  'ADMA',
#  'OSIS',
#  'OMAB',
#  'CZR',
#  'LSTR',
#  'AKRO',
#  'VSAT',
#  'BLTE',
#  'LAUR',
#  'ITRI',
#  'PLBL',
#  'LOPE',
#  'RUN',
#  'CROX',
#  'COMM',
#  'VSEC',
#  'LCID',
#  'EOSE',
#  'CRNX',
#  'FELE',
#  'SRRK',
#  'CNTA',
#  'ACLX',
#  'GRAL',
#  'IMVT',
#  'MRCY',
#  'DORM',
#  'INDV',
#  'ACAD',
#  'FORM',
#  'CLBT',
#  'CALM',
#  'SLAB',
#  'VKTX',
#  'LGND',
#  'NOVT',
#  'SKYW',
#  'SAIC',
#  'VICR',
#  'KC',
#  'LNTH',
#  'AMRX',
#  'VCYT',
#  'VIAV',
#  'FTDR',
#  'AMBA',
#  'PSMT',
#  'AVT',
#  'ALHC',
#  'VRNS',
#  'PLXS',
#  'DLO',
#  'CRVL',
#  'POWL',
#  'ARQT',
#  'ICUI',
#  'GLNG',
#  'NAVN',
#  'MIRM',
#  'VEON',
#  'CGON',
#  'PAGP',
#  'ENPH',
#  'EXPO',
#  'PATK',
#  'AGYS',
#  'WSHP',
#  'IRON',
#  'MLCO',
#  'FRSH',
#  'LIVN',
#  'VRRM',
#  'CARG',
#  'BL',
#  'INTA',
#  'XENE',
#  'MYRG',
#  'KYIV',
#  'TARS',
#  'MLYS',
#  'JOYY',
#  'IPGP',
#  'TLX',
#  'ATEC',
#  'KNSA',
#  'RARE',
#  'TVTX',
#  'GTX',
#  'FIZZ',
#  'TENB',
#  'VERX',
#  'BRZE',
#  'RUSHA',
#  'SPSC',
#  'APPN',
#  'IDYA',
#  'ONDS',
#  'ASO',
#  'ADPT',
#  'ARLP',
#  'FLNC',
#  'EEFT',
#  'FOLD',
#  'AAPG',
#  'PRVA',
#  'COCO',
#  'SHOO',
#  'DJT',
#  'VRDN',
#  'GTM',
#  'CSQ',
#  'DYN',
#  'XMTR',
#  'COLM',
#  'CPRX',
#  'SIMO',
#  'NCNO',
#  'HURN',
#  'PTON',
#  'VC',
#  'LQDA',
#  'DNLI',
#  'AVPT',
#  'HTFL',
#  'FLY',
#  'FRPT',
#  'PLUG',
#  'HWKN',
#  'MEOH',
#  'RELY',
#  'BLKB',
#  'STRC',
#  'SLNO',
#  'IAC',
#  'APLS',
#  'HSAI',
#  'TERN',
#  'SUPN',
#  'NSIT',
#  'WDFC',
#  'ALRM',
#  'CHA',
#  'PTRN',
#  'QUBT',
#  'SYNA',
#  'OCUL',
#  'LFST',
#  'IPAR',
#  'UPWK',
#  'MGRC',
#  'ACLS',
#  'EWTX',
#  'CHEF',
#  'WRD',
#  'BEAM',
#  'HCM',
#  'WB',
#  'FA',
#  'TXG',
#  'SPNS',
#  'GT',
#  'VNET',
#  'PLUS',
#  'DRVN',
#  'ODD',
#  'HUBG',
#  'CAKE',
#  'PINC',
#  'EXTR',
#  'MENS',
#  'PGNY',
#  'FORTY',
#  'RUM',
#  'KLIC',
#  'RXRX',
#  'SBLK',
#  'SYRE',
#  'ALKT',
#  'EYE',
#  'AVDL',
#  'GRFS',
#  'CSGS',
#  'ZLAB',
#  'ADUS',
#  'CNXC',
#  'SONO',
#  'XRAY',
#  'DBVT',
#  'SGRY',
#  'PTEN',
#  'TRMD',
#  'VCEL',
#  'ACMR',
#  'AUPH',
#  'ZBIO',
#  'IQ',
#  'MGNI',
#  'OSW',
#  'DIOD',
#  'DGNX',
#  'SEDG',
#  'JANX',
#  'GPCR',
#  'MESO',
#  'FWONA',
#  'GLPG',
#  'OLMA',
#  'IBRX',
#  'HRMY',
#  'PAYO',
#  'SRPT',
#  'IMCR',
#  'BATRK',
#  'ESTA',
#  'SMPL',
#  'SION',
#  'LBTYA',
#  'ZYME',
#  'SBET',
#  'LLYVA',
#  'NTCT',
#  'PENN',
#  'AVAH',
#  'SEZL',
#  'HBNB',
#  'ATRC',
#  'QDEL',
#  'WBTN',
#  'TWST',
#  'LMAT',
#  'DNTH',
#  'VERA',
#  'ANIP',
#  'NN',
#  'POWI',
#  'IOSP',
#  'NVTS',
#  'CECO',
#  'STRA',
#  'PRCT',
#  'PRDO',
#  'PAHC',
#  'PRGS',
#  'MCRI',
#  'TRIP',
#  'INOD',
#  'UFPT',
#  'JJSF',
#  'MAZE',
#  'VECO',
#  'CLDX',
#  'AZTA',
#  'QURE',
#  'CMPR',
#  'MCW',
#  'FBYD',
#  'HLMN',
#  'ANDE',
#  'NRIX',
#  'IRDM',
#  'IAS',
#  'JAMF',
#  'STOK',
#  'LBTYK',
#  'LUNR',
#  'SNDX',
#  'REAL',
#  'LASR',
#  'FLYW',
#  'IMNM',
#  'CSIQ',
#  'ALVO',
#  'OMCL',
#  'AGIO',
#  'LZ',
#  'CLMT',
#  'MNKD',
#  'BLBD',
#  'HTZ',
#  'AMLX',
#  'ENVX',
#  'NEGG',
#  'PHVS',
#  'TILE',
#  'INVA',
#  'ATRO',
#  'WEN',
#  'NEO',
#  'CENTA',
#  'BELFB',
#  'JBLU',
#  'UPB',
#  'DGII',
#  'AAOI',
#  'EVCM',
#  'NEXT',
#  'ACHC',
#  'FIVN',
#  'HROW',
#  'PLTK',
#  'PCT',
#  'WERN',
#  'MCHPP',
#  'WINA',
#  'UNIT',
#  'TNDM',
#  'ORKA',
#  'CNXN',
#  'WLDN',
#  'DXPE',
#  'IMKTA',
#  'ROCK',
#  'TRVI',
#  'NWL',
#  'CERT',
#  'ARCB',
#  'NESR',
#  'ICFI',
#  'NSSC',
#  'BCRX',
#  'COLL',
#  'MREO',
#  'TNGX',
#  'MBX',
#  'NVCR',
#  'MOMO',
#  'VITL',
#  'KMTS',
#  'ARHS',
#  'RLAY',
#  'ARDX',
#  'AMSC',
#  'LILAK',
#  'BBNX',
#  'OXLC',
#  'AFYA',
#  'STGW',
#  'KARO',
#  'AMPL',
#  'ATAI',
#  'GCT',
#  'RAPP',
#  'SHLS',
#  'ADEA',
#  'TRS',
#  'PZZA',
#  'MXL',
#  'DVAX',
#  'QQQX',
#  'PLAB',
#  'PSNY',
#  'IMTX',
#  'HCSG',
#  'ALGT',
#  'XPEL',
#  'TSAT',
#  'AHCO',
#  'OUST',
#  'AXGN',
#  'NEOG',
#  'STAA',
#  'BLFS',
#  'PGEN',
#  'BGM',
#  'URGN',
#  'ZD',
#  'ELVN',
#  'DSGR',
#  'SDGR',
#  'HIMX',
#  'AMPH',
#  'STRF',
#  'TSHA',
#  'SEPN',
#  'PSIX',
#  'CLOV',
#  'GIII',
#  'VRNT',
#  'WVE',
#  'PSEC',
#  'XNCR',
#  'NKTR',
#  'HSII',
#  'EYPT',
#  'KOD',
#  'PRCH',
#  'INBX',
#  'OCSL',
#  'OPRA',
#  'HDL',
#  'CVAC',
#  'LGIH',
#  'FTRE',
#  'XERS',
#  'CCEC',
#  'SSII',
#  'IRMD',
#  'MNMD',
#  'TBLA',
#  'TYRA',
#  'PHAR',
#  'CSTL',
#  'ASTH',
#  'CRAI',
#  'ANAB',
#  'EVO',
#  'ARRY',
#  'ORIC',
#  'UCTT',
#  'PVLA',
#  'MVST',
#  'OCS',
#  'MGIC',
#  'TLRY',
#  'COHU',
#  'THRM',
#  'SBGI',
#  'FWRG',
#  'STRK',
#  'MLKN',
#  'KDK',
#  'NVAX',
#  'ABCL',
#  'EVLV',
#  'GO',
#  'PDFS',
#  'HLIT',
#  'PHAT',
#  'DMLP',
#  'UPBD',
#  'OMDA',
#  'SVRA',
#  'BRKRP',
#  'GLUE',
#  'CRTO',
#  'OPK',
#  'IART',
#  'MDXG',
#  'CRCT',
#  'NBTX',
#  'TASK',
#  'BCAX',
#  'KURA',
#  'ASTE',
#  'PENG',
#  'RPD',
#  'PLPC',
#  'PCRX',
#  'PSNL',
#  'NTLA',
#  'BBOT',
#  'IOVA',
#  'NMFC',
#  'RDWR',
#  'MLTX',
#  'IMOS',
#  'SLDP',
#  'PNTG',
#  'RZLV',
#  'DAWN',
#  'EH',
#  'BTSGU',
#  'MRVI',
#  'BTQ',
#  'TBPH',
#  'ULCC',
#  'NNNN',
#  'GDRX',
#  'FLGT',
#  'GOGO',
#  'TDUP',
#  'WOOF',
#  'CRON',
#  'AVBP',
#  'SANA',
#  'LENZ',
#  'EVER',
#  'LQDT',
#  'DAKT',
#  'GHRS',
#  'CDNA',
#  'SPRY',
#  'AEBI',
#  'BBSI',
#  'ALNT',
#  'PLSE',
#  'SCSC',
#  'STRD',
#  'RIGL',
#  'GLIBK',
#  'VIR',
#  'CHY',
#  'IMSR',
#  'INMD',
#  'CMPX',
#  'RZLT',
#  'ESPR',
#  'CCOI',
#  'VERB',
#  'LOT',
#  'ERAS',
#  'RCAT',
#  'RUSHB',
#  'SLRC',
#  'SIBN',
#  'LBRDA',
#  'NUTX',
#  'JBSS',
#  'ODP',
#  'GLDD',
#  'AHG',
#  'AVO',
#  'ABUS',
#  'RAPT',
#  'CHI',
#  'SWIM',
#  'MRTN',
#  'WLFC',
#  'HPK',
#  'ITRN',
#  'BLDP',
#  'BJRI',
#  'LMB',
#  'QNST',
#  'AMWD',
#  'EMBC',
#  'PACB',
#  'VSTM',
#  'SIFY',
#  'ARVN',
#  'MATW',
#  'APOG',
#  'GDEN',
#  'RDVT',
#  'ALMS',
#  'INDI',
#  'LAES',
#  'HSTM',
#  'GOSS',
#  'ERII',
#  'VALN',
#  'TH',
#  'SCHL',
#  'REPL',
#  'VTYX',
#  'CTKB',
#  'AQST',
#  'GDYN',
#  'UDMY',
#  'CRMD',
#  'GERN',
#  'MYGN',
#  'OLPX',
#  'GLOO',
#  'SSYS',
#  'FWDI',
#  'GILT',
#  'NTGR',
#  'SERV',
#  'INNV',
#  'CRESY',
#  'SKYT',
#  'CCCX',
#  'FDUS',
#  'RR',
#  'ADSE',
#  'LXEO',
#  'GPRE',
#  'TIPT',
#  'ATXS',
#  'CTMX',
#  'GYRE',
#  'CGEM',
#  'SNCY',
#  'KE',
#  'SUPX',
#  'FWRD',
#  'WYFI',
#  'DNUT',
#  'RGNX',
#  'SENEA',
#  'GRPN',
#  'PRME',
#  'KALV',
#  'LIND',
#  'ORGO',
#  'OMER',
#  'ASPI',
#  'CRVS',
#  'HEPS',
#  'DMIIU',
#  'CRSR',
#  'YDES',
#  'NOVTU',
#  'DSP',
#  'LINC',
#  'DJCO',
#  'AEHR',
#  'BVS',
#  'SABR',
#  'CBLL',
#  'ANNX',
#  'OFIX',
#  'CCCXU',
#  'TBLD',
#  'PROK',
#  'APEI',
#  'DVLT',
#  'AIOT',
#  'IVVD',
#  'AEVA',
#  'CBRL',
#  'FULC',
#  'AOSL',
#  'ADTN',
#  'ECX',
#  'POET',
#  'IVA',
#  'FOXF',
#  'DCBO',
#  'FDMT',
#  'MGTX',
#  'ACDC',
#  'BWMN',
#  'SHEN',
#  'HTLD',
#  'CGNT',
#  'LWLG',
#  'AIP',
#  'KRNT',
#  ...]

# %% [markdown]
# ### Billions 단위로 변환

# %%
df_billions = normalizer.convert_to_billions(df)
print(df_billions[['revenue', 'net_income']].tail(8))

# %% [markdown]
# ### TTM (Trailing Twelve Months) 계산

# %%
df_ttm = normalizer.calculate_ttm(df_billions, columns=['revenue', 'net_income'])
print(df_ttm[['revenue', 'revenue_ttm']].tail(8))

# %% [markdown]
# # 2. 다수 기업 재무제표 받기

# %%
from collectors import SECAPIClient, RateLimiter, BulkDownloader
from parsers import CompanyFactsParser, FinancialNormalizer
import pandas as pd

# 1. 클라이언트 및 다운로더 설정
user_agent = "PersonalResearch stox1224@email.com"
client = SECAPIClient(user_agent, RateLimiter(10, 1.0))
downloader = BulkDownloader(client, output_dir="./sec_data", max_workers=3)

# 2. 다운로드할 기업 리스트
tickers = ['AAPL', 'MSFT', 'GOOGL', 'AMZN', 'TSLA', 'NVDA', 'META']

# 3. 배치 다운로드 (자동으로 JSON 파일 저장)
results = downloader.download_company_facts_batch(tickers)

# 4. 각 기업별 데이터 처리
all_financials = {}

for ticker, company_facts in results.items():
    parser = CompanyFactsParser(company_facts)
    normalizer = FinancialNormalizer(parser)

    # 재무데이터 정규화
    df = normalizer.create_normalized_dataframe(period_type='quarterly')
    df_billions = normalizer.convert_to_billions(df)

    all_financials[ticker] = df_billions

    # 개별 CSV 저장
    normalizer.export_to_csv(df_billions, f'{ticker}_financials.csv')

print(f"총 {len(all_financials)}개 기업 데이터 수집 완료")

# %% [markdown]
# # 3. 특정 재무항목만 추출

# %%
revenue_comparison = {}

for ticker, company_facts in results.items():
    parser = CompanyFactsParser(company_facts)
    normalizer = FinancialNormalizer(parser)

    # Revenue만 추출
    revenue_series = normalizer.normalize_single_item('revenue', period_type='quarterly')

    if revenue_series is not None:
        revenue_comparison[ticker] = revenue_series / 1_000_000_000  # Billions

# DataFrame으로 변환
revenue_df = pd.DataFrame(revenue_comparison)
print("\n최근 8분기 매출 비교 (Billions):")
print(revenue_df.tail(8))

# YoY 성장률
growth_df = revenue_df.pct_change(periods=4) * 100
print("\nYoY 매출 성장률 (%):")
print(growth_df.tail(4))

# %% [markdown]
# # 4. 사용 가능한 재무 항목

# %%
# 추출 가능한 표준 재무 항목들
available_items = [
    'revenue',              # 매출
    'net_income',           # 순이익
    'operating_income',     # 영업이익
    'gross_profit',         # 매출총이익
    'total_assets',         # 총자산
    'current_assets',       # 유동자산
    'total_liabilities',    # 총부채
    'current_liabilities',  # 유동부채
    'stockholders_equity',  # 자본
    'cash',                 # 현금
    'long_term_debt',       # 장기부채
    'cost_of_revenue',      # 매출원가
    'operating_expenses',   # 영업비용
    'research_development', # 연구개발비
    'earnings_per_share',   # 주당순이익
]

# 특정 항목만 추출
for item in ['revenue', 'net_income', 'total_assets']:
    series = normalizer.normalize_single_item(item, period_type='quarterly')
    print(f"\n{item}:")
    print(series.tail(4))

# %% [markdown]
# # 5. 재무비율 계산

# %%
# 데이터 준비
df = normalizer.create_normalized_dataframe(period_type='quarterly')

# 재무비율 자동 계산
df_ratios = normalizer.calculate_financial_ratios(df)

# 계산되는 비율들:
# - profit_margin: 순이익률
# - operating_margin: 영업이익률
# - current_ratio: 유동비율
# - debt_to_equity: 부채비율
# - roe: 자기자본이익률
# - roa: 총자산이익률

print(df_ratios[['revenue', 'net_income', 'profit_margin']].tail(8))

# %% [markdown]
# # 6. 성장률 분석

# %%
df_billions = normalizer.convert_to_billions(df)

# YoY 성장률 계산
df_growth = normalizer.calculate_growth_rates(
    df_billions,
    columns=['revenue', 'net_income'],
    periods=4  # 4분기 = YoY
)

print(df_growth[['revenue', 'revenue_yoy_growth']].tail(8))

# %% [markdown]
# # 7. 진행상황 모니터링

# %%
# 콜백 함수 정의
def on_download_complete(ticker, data, index, total):
    if data:
        entity_name = data.get('entityName', 'Unknown')
        print(f"[{index}/{total}] {ticker}: {entity_name} - 완료")
    else:
        print(f"[{index}/{total}] {ticker}: 실패")

# 콜백과 함께 다운로드
results = downloader.download_company_facts_batch(
    tickers=['AAPL', 'MSFT', 'GOOGL'],
    callback=on_download_complete
)

# %% [markdown]
# # 8. 중단된 다운로드 재개

# %%
# 이미 다운로드된 파일은 건너뛰기
remaining_results = downloader.resume_download(tickers)

# %% [markdown]
# # 9. 다운로드 리포트 생성

# %%
# 다운로드 후 리포트 생성
downloader.create_download_report(results, "download_report.json")

# %% [markdown]
# # 10. 실전 예제: S&P 500 상위 기업 분석

# %%
# Tech Giants
tech_giants = ['AAPL', 'MSFT', 'GOOGL', 'AMZN', 'META', 'NVDA', 'TSLA']

# 다운로드
downloader = BulkDownloader(client, output_dir="./tech_giants", max_workers=5)
results = downloader.download_company_facts_batch(tech_giants)

# Revenue 비교 분석
revenue_data = {}
for ticker, facts in results.items():
    parser = CompanyFactsParser(facts)
    normalizer = FinancialNormalizer(parser)
    revenue = normalizer.normalize_single_item('revenue', period_type='quarterly')
    if revenue is not None:
        revenue_data[ticker] = revenue / 1e9  # Billions

# 비교 DataFrame
comparison = pd.DataFrame(revenue_data)
print("\nTech Giants 최근 매출 비교 (Billions):")
print(comparison.tail(8))

# 시각화 (선택사항)
import matplotlib.pyplot as plt
comparison.tail(12).plot(figsize=(12, 6))
plt.title('Tech Giants Revenue Comparison (Last 12 Quarters)')
plt.ylabel('Revenue (Billions USD)')
plt.legend(loc='best')
plt.grid(True)
plt.savefig('tech_giants_revenue.png')
