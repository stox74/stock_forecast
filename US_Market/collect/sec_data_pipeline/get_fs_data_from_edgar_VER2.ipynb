# %% [markdown]
# # 1. 단일 기업 재무제표 받기

# %%
import sys
import pandas as pd
import time
# ---------------------------------------------------------
# 0) 프로젝트 경로 추가
# ---------------------------------------------------------
sys.path.append(r"C:\Users\82108\OneDrive\바탕 화면\investment\investment_strategy\US_Market\collect")

# ---------------------------------------------------------
# 1) 필요한 모듈 import
# ---------------------------------------------------------
from sec_data_pipeline.collectors.get_us_ticker import get_filtered_us_tickers
from sec_data_pipeline.collectors.sec_utils import fetch_company_facts
from sec_data_pipeline.parsers.company_facts_parser import CompanyFactsParser
from sec_data_pipeline.parsers.financial_normalizer import FinancialNormalizer
from sec_data_pipeline.validators.wrds_data_validator_mysql_integrated import WRDSDataValidator
from sec_data_pipeline.valuation.financial_data_integrator import integrate_financial_ratios

# ✅ Rate Limiter (이미 프로젝트에 있는 구현 사용)
from sec_data_pipeline.collectors.rate_limiter import AdaptiveRateLimiter

# 통합 분석 클래스 (수정본)
from sec_data_pipeline.valuation.integrated_financial_analyzer_mysql_fixed import IntegratedFinancialAnalyzer

# DB 저장용
from sec_data_pipeline.storage.db_manager import DBManager
from DATA.stock_invest_function import get_db_host


# ---------------------------------------------------------
# 2) DB 설정
# ---------------------------------------------------------
db_info = {
    "host": get_db_host(),
    "port": 3307,
    "user": "stox7412",
    "password": "Apt106503!~",
    "database": "investar",
}

# DBManager 생성 및 테이블 생성 (최초 1회만)
db_manager = DBManager(db_info)
db_manager.create_tables()   # sec_financial_data, fmp_financial_data 등 생성


# ---------------------------------------------------------
# 3) WRDS 접속 문자열
# ---------------------------------------------------------
wrds_conn_str = "postgresql://YOUR_WRDS_ID:YOUR_WRDS_PW@wrds.wharton.upenn.edu:9737/wrds"


# ---------------------------------------------------------
# 4) SEC User-Agent 헤더 설정 (반드시 이메일 포함)
# ---------------------------------------------------------
headers = {
    "User-Agent": "Hoyoung Research <stox1224@gmail.com>"
}


# ---------------------------------------------------------
# 5) 티커 리스트 생성
# ---------------------------------------------------------
# 전체 티커 리스트
TICKER_LIST = get_filtered_us_tickers()

# 테스트 / 안전을 위해 500개까지만
TICKER_LIST = TICKER_LIST[4000:4990]
# 완전 테스트용:
# TICKER_LIST = ["MU"]

# ---------------------------------------------------------
# 6) Rate Limiter 설정
#    - max_calls=8, time_window=1 → 초당 최대 8회
#    - AdaptiveRateLimiter: 429 발생 시 자동으로 max_calls 줄임
# ---------------------------------------------------------
rate_limiter = AdaptiveRateLimiter(
    max_calls=8,
    time_window=1.0,
    min_calls=3,
    backoff_factor=0.8,
)

# 통합 분석기
analyzer = IntegratedFinancialAnalyzer(db_info=db_info, wrds_conn_str=wrds_conn_str)

# ---------------------------------------------------------
# 7) 메인 루프: 티커별 EDGAR+WRDS+비율 → DB 저장
# ---------------------------------------------------------
for i, ticker in enumerate(TICKER_LIST, start=1):
    print(f"\n=== [{i}/{len(TICKER_LIST)}] {ticker} 처리 시작 ===")

    # ✅ ❶ 티커마다 호출 전 rate limit 체크
    rate_limiter.wait_if_needed()

    try:
        result = analyzer.analyze(ticker, headers=headers, table_name="us_fundq")
        if result is None:
            print(f"⚠ {ticker}: 분석 결과 없음, 스킵")
            continue

        final_df, cik, entity_name = result

        # date 인덱스 정리 (DB 저장을 위해)
        if final_df.index.name != "date":
            final_df = final_df.copy()
            # 만약 date가 컬럼으로 있다면:
            if "date" in final_df.columns:
                final_df = final_df.set_index("date")
            else:
                final_df.index.name = "date"

        # DB 저장 (LONG FORMAT sec_financial_data)
        db_manager.save_normalized_data(
            ticker=ticker,
            cik=cik,
            df=final_df,
            item_mapping=None  # 컬럼명을 그대로 item_name으로 사용
        )

        print(f"✓ {ticker} ({entity_name}) 저장 완료")

        # ✅ ❷ 여유를 더 두고 싶으면 티커 사이에 약간의 sleep 추가 (선택)
        # time.sleep(0.2)

    except Exception as e:
        msg = str(e)

        # ✅ ❸ SEC 429 / rate limit 의심 시 백오프 처리
        if "Company Facts 요청 실패" in msg and "429" in msg:
            print(f"⚠ {ticker}: SEC 429 Too Many Requests 감지 → rate 낮추고 60초 대기")
            # AdaptiveRateLimiter에 "rateLimit 발생" 알리기
            rate_limiter.on_rate_limit_error()
            # 잠시 쉬었다가 다음 티커로
            time.sleep(60)
            continue

        print(f"✗ {ticker} 처리 중 기타 오류: {e}")
        # (여기서 바로 continue 해서 다음 티커 진행)
        continue

print("\n=== 전체 작업 완료 ===")
# Out:
# ✓ DB connected: 192.168.0.230:3307/investar
# ✓ Tables created
# 100%|██████████| 3775/3775 [00:10<00:00, 359.45it/s]
# 100%|██████████| 2730/2730 [00:08<00:00, 331.11it/s]
# 100%|██████████| 299/299 [00:00<00:00, 321.79it/s]
# 제외된 기업 수: 1814
# 남은 기업 수: 4990
# 티커 수: 4990
#
# === [1/990] TDOC 처리 시작 ===
# ================================================================================
# [TDOC] 통합 재무분석 시작
# ✓ Entity: TELADOC HEALTH, INC. (CIK: 1477449)
# ✓ EDGAR 정규화 DF: 48 rows × 31 cols
# ✓ MySQL 연결 성공: 192.168.0.230:3307/investar
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 48 rows × 31 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 48 rows × 48 cols
# [TDOC] 통합 재무분석 종료
# ================================================================================
# ✓ Saved TDOC data: 48 dates x 48 items
# ✓ TDOC (TELADOC HEALTH, INC.) 저장 완료
#
# === [2/990] ARDT 처리 시작 ===
# ================================================================================
# [ARDT] 통합 재무분석 시작
# ✓ Entity: Ardent Health, Inc. (CIK: 0001756655)
# ✓ EDGAR 정규화 DF: 12 rows × 23 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 12 rows × 23 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 12 rows × 37 cols
# [ARDT] 통합 재무분석 종료
# ================================================================================
# ✓ Saved ARDT data: 12 dates x 37 items
# ✓ ARDT (Ardent Health, Inc.) 저장 완료
#
# === [3/990] PRLB 처리 시작 ===
# ================================================================================
# [PRLB] 통합 재무분석 시작
# ✓ Entity: Proto Labs, Inc. (CIK: 1443669)
# ✓ EDGAR 정규화 DF: 61 rows × 30 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 61 rows × 30 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 61 rows × 47 cols
# [PRLB] 통합 재무분석 종료
# ================================================================================
# ✓ Saved PRLB data: 61 dates x 47 items
# ✓ PRLB (Proto Labs, Inc.) 저장 완료
#
# === [4/990] LNN 처리 시작 ===
# ================================================================================
# [LNN] 통합 재무분석 시작
# ✓ Entity: Lindsay Corporation (CIK: 836157)
# ✓ EDGAR 정규화 DF: 62 rows × 33 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 62 rows × 33 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 62 rows × 50 cols
# [LNN] 통합 재무분석 종료
# ================================================================================
# ✓ Saved LNN data: 62 dates x 50 items
# ✓ LNN (Lindsay Corporation) 저장 완료
#
# === [5/990] COUR 처리 시작 ===
# ================================================================================
# [COUR] 통합 재무분석 시작
# ✓ Entity: COURSERA, INC. (CIK: 1651562)
# ✓ EDGAR 정규화 DF: 25 rows × 27 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 25 rows × 27 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 25 rows × 41 cols
# [COUR] 통합 재무분석 종료
# ================================================================================
# ✓ Saved COUR data: 25 dates x 41 items
# ✓ COUR (COURSERA, INC.) 저장 완료
#
# === [6/990] JFR 처리 시작 ===
# ================================================================================
# [JFR] 통합 재무분석 시작
# ✗ EDGAR Company Facts 로딩 실패 (JFR): Company Facts 요청 실패: 404 https://data.sec.gov/api/xbrl/companyfacts/CIK0001276533.json
# ⚠ JFR: 분석 결과 없음, 스킵
#
# === [7/990] TTI 처리 시작 ===
# ================================================================================
# [TTI] 통합 재무분석 시작
# ✓ Entity: TETRA Technologies, Inc. (CIK: 844965)
# ✓ EDGAR 정규화 DF: 68 rows × 26 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 68 rows × 26 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 68 rows × 43 cols
# [TTI] 통합 재무분석 종료
# ================================================================================
# ✓ Saved TTI data: 68 dates x 43 items
# ✓ TTI (TETRA Technologies, Inc.) 저장 완료
#
# === [8/990] THR 처리 시작 ===
# ================================================================================
# [THR] 통합 재무분석 시작
# ✓ Entity: THERMON GROUP HOLDINGS, INC. (CIK: 1489096)
# ✓ EDGAR 정규화 DF: 63 rows × 28 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 63 rows × 28 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 63 rows × 45 cols
# [THR] 통합 재무분석 종료
# ================================================================================
# ✓ Saved THR data: 63 dates x 45 items
# ✓ THR (THERMON GROUP HOLDINGS, INC.) 저장 완료
#
# === [9/990] LUCK 처리 시작 ===
# ================================================================================
# [LUCK] 통합 재무분석 시작
# ✓ Entity: LUCKY STRIKE ENTERTAINMENT CORPORATION (CIK: 1840572)
# ✓ EDGAR 정규화 DF: 27 rows × 30 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 27 rows × 30 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 27 rows × 47 cols
# [LUCK] 통합 재무분석 종료
# ================================================================================
# ✓ Saved LUCK data: 27 dates x 47 items
# ✓ LUCK (LUCKY STRIKE ENTERTAINMENT CORPORATION) 저장 완료
#
# === [10/990] FOR 처리 시작 ===
# ================================================================================
# [FOR] 통합 재무분석 시작
# ✓ Entity: Forestar Group Inc. (CIK: 1406587)
# ✓ EDGAR 정규화 DF: 65 rows × 21 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 65 rows × 21 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 65 rows × 33 cols
# [FOR] 통합 재무분석 종료
# ================================================================================
# ✓ Saved FOR data: 65 dates x 33 items
# ✓ FOR (Forestar Group Inc.) 저장 완료
#
# === [11/990] KRP 처리 시작 ===
# ================================================================================
# [KRP] 통합 재무분석 시작
# ✓ Entity: Kimbell Royalty Partners, LP (CIK: 1657788)
# ✓ EDGAR 정규화 DF: 36 rows × 21 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 36 rows × 21 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 36 rows × 32 cols
# [KRP] 통합 재무분석 종료
# ================================================================================
# ✓ Saved KRP data: 36 dates x 32 items
# ✓ KRP (Kimbell Royalty Partners, LP) 저장 완료
#
# === [12/990] CNMD 처리 시작 ===
# ================================================================================
# [CNMD] 통합 재무분석 시작
# ✓ Entity: CONMED CORPORATION (CIK: 816956)
# ✓ EDGAR 정규화 DF: 65 rows × 31 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql 'SELECT * FROM us_fundq WHERE tic=%s': (1146, "Table 'investar.us_fundq' doesn't exist")
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 65 rows × 31 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 65 rows × 48 cols
# [CNMD] 통합 재무분석 종료
# ================================================================================
# ✗ Error saving CNMD: (pymysql.err.OperationalError) (2013, 'Lost connection to MySQL server during query')
# [SQL: SELECT sec_financial_data.id AS sec_financial_data_id, sec_financial_data.ticker AS sec_financial_data_ticker, sec_financial_data.cik AS sec_financial_data_cik, sec_financial_data.date AS sec_financial_data_date, sec_financial_data.fiscal_year AS sec_financial_data_fiscal_year, sec_financial_data.fiscal_period AS sec_financial_data_fiscal_period, sec_financial_data.item_name AS sec_financial_data_item_name, sec_financial_data.value AS sec_financial_data_value, sec_financial_data.unit AS sec_financial_data_unit, sec_financial_data.data_source AS sec_financial_data_data_source, sec_financial_data.created_at AS sec_financial_data_created_at, sec_financial_data.updated_at AS sec_financial_data_updated_at
# FROM sec_financial_data
# WHERE sec_financial_data.ticker = %(ticker_1)s AND sec_financial_data.date = %(date_1)s AND sec_financial_data.item_name = %(item_name_1)s
#  LIMIT %(param_1)s]
# [parameters: {'ticker_1': 'CNMD', 'date_1': Timestamp('2021-03-31 00:00:00'), 'item_name_1': 'net_ppe', 'param_1': 1}]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# ✗ CNMD 처리 중 기타 오류: (pymysql.err.OperationalError) (2013, 'Lost connection to MySQL server during query')
# [SQL: SELECT sec_financial_data.id AS sec_financial_data_id, sec_financial_data.ticker AS sec_financial_data_ticker, sec_financial_data.cik AS sec_financial_data_cik, sec_financial_data.date AS sec_financial_data_date, sec_financial_data.fiscal_year AS sec_financial_data_fiscal_year, sec_financial_data.fiscal_period AS sec_financial_data_fiscal_period, sec_financial_data.item_name AS sec_financial_data_item_name, sec_financial_data.value AS sec_financial_data_value, sec_financial_data.unit AS sec_financial_data_unit, sec_financial_data.data_source AS sec_financial_data_data_source, sec_financial_data.created_at AS sec_financial_data_created_at, sec_financial_data.updated_at AS sec_financial_data_updated_at
# FROM sec_financial_data
# WHERE sec_financial_data.ticker = %(ticker_1)s AND sec_financial_data.date = %(date_1)s AND sec_financial_data.item_name = %(item_name_1)s
#  LIMIT %(param_1)s]
# [parameters: {'ticker_1': 'CNMD', 'date_1': Timestamp('2021-03-31 00:00:00'), 'item_name_1': 'net_ppe', 'param_1': 1}]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
#
# === [13/990] NGL 처리 시작 ===
# ================================================================================
# [NGL] 통합 재무분석 시작
# ✓ Entity: NGL Energy Partners LP (CIK: 1504461)
# ✓ EDGAR 정규화 DF: 61 rows × 29 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql: SELECT * FROM us_fundq WHERE tic=%s
# (2013, 'Lost connection to MySQL server during query')
# unable to rollback
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 61 rows × 29 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 61 rows × 46 cols
# [NGL] 통합 재무분석 종료
# ================================================================================
# ✗ Error saving NGL: (pymysql.err.OperationalError) (2003, "Can't connect to MySQL server on '192.168.0.230' ([WinError 10061] 대상 컴퓨터에서 연결을 거부했으므로 연결하지 못했습니다)")
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# ✗ NGL 처리 중 기타 오류: (pymysql.err.OperationalError) (2003, "Can't connect to MySQL server on '192.168.0.230' ([WinError 10061] 대상 컴퓨터에서 연결을 거부했으므로 연결하지 못했습니다)")
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
#
# === [14/990] SPH 처리 시작 ===
# ================================================================================
# [SPH] 통합 재무분석 시작
# ✓ Entity: SUBURBAN PROPANE PARTNERS LP (CIK: 1005210)
# ✓ EDGAR 정규화 DF: 68 rows × 27 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql: SELECT * FROM us_fundq WHERE tic=%s
# (0, '')
# unable to rollback
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 68 rows × 27 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 68 rows × 43 cols
# [SPH] 통합 재무분석 종료
# ================================================================================
# ✗ Error saving SPH: (pymysql.err.OperationalError) (2003, "Can't connect to MySQL server on '192.168.0.230' ([WinError 10061] 대상 컴퓨터에서 연결을 거부했으므로 연결하지 못했습니다)")
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# ✗ SPH 처리 중 기타 오류: (pymysql.err.OperationalError) (2003, "Can't connect to MySQL server on '192.168.0.230' ([WinError 10061] 대상 컴퓨터에서 연결을 거부했으므로 연결하지 못했습니다)")
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
#
# === [15/990] GOOS 처리 시작 ===
# ================================================================================
# [GOOS] 통합 재무분석 시작
# ✓ Entity: CANADA GOOSE HOLDINGS INC. (CIK: 1690511)
# ⚠ EDGAR 정규화 DF가 비어 있습니다 (GOOS)
# ✓ EDGAR 정규화 DF: 0 rows × 0 cols
# ⚠ EDGAR 입력 DF가 비어있습니다. WRDS만으로 구성합니다.
# ⚠ WRDS 쿼리 실패: Execution failed on sql: SELECT * FROM us_fundq WHERE tic=%s
# (0, '')
# unable to rollback
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ⚠ WRDS 보완 후에도 DF가 비어 있습니다 (GOOS)
# ⚠ GOOS: 분석 결과 없음, 스킵
#
# === [16/990] GSL 처리 시작 ===
# ================================================================================
# [GSL] 통합 재무분석 시작
# ✓ Entity: Global Ship Lease, Inc. (CIK: 1430725)
# ✓ EDGAR 정규화 DF: 33 rows × 27 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql: SELECT * FROM us_fundq WHERE tic=%s
# (0, '')
# unable to rollback
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 33 rows × 27 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 33 rows × 41 cols
# [GSL] 통합 재무분석 종료
# ================================================================================
# ✗ Error saving GSL: (pymysql.err.OperationalError) (2003, "Can't connect to MySQL server on '192.168.0.230' ([WinError 10061] 대상 컴퓨터에서 연결을 거부했으므로 연결하지 못했습니다)")
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# ✗ GSL 처리 중 기타 오류: (pymysql.err.OperationalError) (2003, "Can't connect to MySQL server on '192.168.0.230' ([WinError 10061] 대상 컴퓨터에서 연결을 거부했으므로 연결하지 못했습니다)")
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
#
# === [17/990] EOS 처리 시작 ===
# ================================================================================
# [EOS] 통합 재무분석 시작
# ✓ Entity:  (CIK: 0001308335)
# ⚠ EDGAR 정규화 DF가 비어 있습니다 (EOS)
# ✓ EDGAR 정규화 DF: 0 rows × 0 cols
# ⚠ EDGAR 입력 DF가 비어있습니다. WRDS만으로 구성합니다.
# ⚠ WRDS 쿼리 실패: Execution failed on sql: SELECT * FROM us_fundq WHERE tic=%s
# (0, '')
# unable to rollback
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ⚠ WRDS 보완 후에도 DF가 비어 있습니다 (EOS)
# ⚠ EOS: 분석 결과 없음, 스킵
#
# === [18/990] DFIN 처리 시작 ===
# ================================================================================
# [DFIN] 통합 재무분석 시작
# ✓ Entity: Donnelley Financial Solutions, Inc. (CIK: 1669811)
# ✓ EDGAR 정규화 DF: 43 rows × 28 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql: SELECT * FROM us_fundq WHERE tic=%s
# (0, '')
# unable to rollback
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 43 rows × 28 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 43 rows × 42 cols
# [DFIN] 통합 재무분석 종료
# ================================================================================
# ✗ Error saving DFIN: (pymysql.err.OperationalError) (2003, "Can't connect to MySQL server on '192.168.0.230' ([WinError 10061] 대상 컴퓨터에서 연결을 거부했으므로 연결하지 못했습니다)")
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# ✗ DFIN 처리 중 기타 오류: (pymysql.err.OperationalError) (2003, "Can't connect to MySQL server on '192.168.0.230' ([WinError 10061] 대상 컴퓨터에서 연결을 거부했으므로 연결하지 못했습니다)")
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
#
# === [19/990] BV 처리 시작 ===
# ================================================================================
# [BV] 통합 재무분석 시작
# ✓ Entity: BrightView Holdings, Inc. (CIK: 1734713)
# ✓ EDGAR 정규화 DF: 37 rows × 28 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql: SELECT * FROM us_fundq WHERE tic=%s
# (0, '')
# unable to rollback
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 37 rows × 28 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 37 rows × 45 cols
# [BV] 통합 재무분석 종료
# ================================================================================
# ✗ Error saving BV: (pymysql.err.OperationalError) (2003, "Can't connect to MySQL server on '192.168.0.230' ([WinError 10061] 대상 컴퓨터에서 연결을 거부했으므로 연결하지 못했습니다)")
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# ✗ BV 처리 중 기타 오류: (pymysql.err.OperationalError) (2003, "Can't connect to MySQL server on '192.168.0.230' ([WinError 10061] 대상 컴퓨터에서 연결을 거부했으므로 연결하지 못했습니다)")
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
#
# === [20/990] USPH 처리 시작 ===
# ================================================================================
# [USPH] 통합 재무분석 시작
# ✓ Entity: U S PHYSICAL THERAPY INC /NV (CIK: 885978)
# ✓ EDGAR 정규화 DF: 62 rows × 24 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql: SELECT * FROM us_fundq WHERE tic=%s
# (0, '')
# unable to rollback
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 62 rows × 24 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 62 rows × 38 cols
# [USPH] 통합 재무분석 종료
# ================================================================================
# ✗ Error saving USPH: (pymysql.err.OperationalError) (2003, "Can't connect to MySQL server on '192.168.0.230' ([WinError 10061] 대상 컴퓨터에서 연결을 거부했으므로 연결하지 못했습니다)")
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# ✗ USPH 처리 중 기타 오류: (pymysql.err.OperationalError) (2003, "Can't connect to MySQL server on '192.168.0.230' ([WinError 10061] 대상 컴퓨터에서 연결을 거부했으므로 연결하지 못했습니다)")
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
#
# === [21/990] NFJ 처리 시작 ===
# ================================================================================
# [NFJ] 통합 재무분석 시작
# ✗ EDGAR Company Facts 로딩 실패 (NFJ): Company Facts 요청 실패: 404 https://data.sec.gov/api/xbrl/companyfacts/CIK0001260563.json
# ⚠ NFJ: 분석 결과 없음, 스킵
#
# === [22/990] RES 처리 시작 ===
# ================================================================================
# [RES] 통합 재무분석 시작
# ✓ Entity: RPC, INC. (CIK: 742278)
# ✓ EDGAR 정규화 DF: 64 rows × 25 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql: SELECT * FROM us_fundq WHERE tic=%s
# (0, '')
# unable to rollback
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 64 rows × 25 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 64 rows × 41 cols
# [RES] 통합 재무분석 종료
# ================================================================================
# ✗ Error saving RES: (pymysql.err.OperationalError) (2003, "Can't connect to MySQL server on '192.168.0.230' ([WinError 10061] 대상 컴퓨터에서 연결을 거부했으므로 연결하지 못했습니다)")
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# ✗ RES 처리 중 기타 오류: (pymysql.err.OperationalError) (2003, "Can't connect to MySQL server on '192.168.0.230' ([WinError 10061] 대상 컴퓨터에서 연결을 거부했으므로 연결하지 못했습니다)")
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
#
# === [23/990] FSCO 처리 시작 ===
# ================================================================================
# [FSCO] 통합 재무분석 시작
# ✗ EDGAR Company Facts 로딩 실패 (FSCO): Company Facts 요청 실패: 404 https://data.sec.gov/api/xbrl/companyfacts/CIK0001568194.json
# ⚠ FSCO: 분석 결과 없음, 스킵
#
# === [24/990] WGO 처리 시작 ===
# ================================================================================
# [WGO] 통합 재무분석 시작
# ✓ Entity: WINNEBAGO INDUSTRIES, INC. (CIK: 107687)
# ✓ EDGAR 정규화 DF: 63 rows × 29 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql: SELECT * FROM us_fundq WHERE tic=%s
# (0, '')
# unable to rollback
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 63 rows × 29 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 63 rows × 46 cols
# [WGO] 통합 재무분석 종료
# ================================================================================
# ✗ Error saving WGO: (pymysql.err.OperationalError) (2003, "Can't connect to MySQL server on '192.168.0.230' ([WinError 10061] 대상 컴퓨터에서 연결을 거부했으므로 연결하지 못했습니다)")
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# ✗ WGO 처리 중 기타 오류: (pymysql.err.OperationalError) (2003, "Can't connect to MySQL server on '192.168.0.230' ([WinError 10061] 대상 컴퓨터에서 연결을 거부했으므로 연결하지 못했습니다)")
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
#
# === [25/990] THS 처리 시작 ===
# ================================================================================
# [THS] 통합 재무분석 시작
# ✓ Entity: TreeHouse Foods, Inc. (CIK: 1320695)
# ✓ EDGAR 정규화 DF: 68 rows × 32 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql: SELECT * FROM us_fundq WHERE tic=%s
# (0, '')
# unable to rollback
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 68 rows × 32 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 68 rows × 49 cols
# [THS] 통합 재무분석 종료
# ================================================================================
# ✗ Error saving THS: (pymysql.err.OperationalError) (2003, "Can't connect to MySQL server on '192.168.0.230' ([WinError 10061] 대상 컴퓨터에서 연결을 거부했으므로 연결하지 못했습니다)")
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# ✗ THS 처리 중 기타 오류: (pymysql.err.OperationalError) (2003, "Can't connect to MySQL server on '192.168.0.230' ([WinError 10061] 대상 컴퓨터에서 연결을 거부했으므로 연결하지 못했습니다)")
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
#
# === [26/990] PD 처리 시작 ===
# ================================================================================
# [PD] 통합 재무분석 시작
# ✓ Entity: PAGERDUTY, INC. (CIK: 1568100)
# ✓ EDGAR 정규화 DF: 33 rows × 29 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql: SELECT * FROM us_fundq WHERE tic=%s
# (0, '')
# unable to rollback
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 33 rows × 29 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 33 rows × 43 cols
# [PD] 통합 재무분석 종료
# ================================================================================
# ✗ Error saving PD: (pymysql.err.OperationalError) (2003, "Can't connect to MySQL server on '192.168.0.230' ([WinError 10061] 대상 컴퓨터에서 연결을 거부했으므로 연결하지 못했습니다)")
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# ✗ PD 처리 중 기타 오류: (pymysql.err.OperationalError) (2003, "Can't connect to MySQL server on '192.168.0.230' ([WinError 10061] 대상 컴퓨터에서 연결을 거부했으므로 연결하지 못했습니다)")
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
#
# === [27/990] ECO 처리 시작 ===
# ================================================================================
# [ECO] 통합 재무분석 시작
# ✓ Entity: Okeanis Eco Tankers Corp. (CIK: 0001964954)
# ⚠ EDGAR 정규화 DF가 비어 있습니다 (ECO)
# ✓ EDGAR 정규화 DF: 0 rows × 0 cols
# ⚠ EDGAR 입력 DF가 비어있습니다. WRDS만으로 구성합니다.
# ⚠ WRDS 쿼리 실패: Execution failed on sql: SELECT * FROM us_fundq WHERE tic=%s
# (0, '')
# unable to rollback
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ⚠ WRDS 보완 후에도 DF가 비어 있습니다 (ECO)
# ⚠ ECO: 분석 결과 없음, 스킵
#
# === [28/990] LUXE 처리 시작 ===
# ================================================================================
# [LUXE] 통합 재무분석 시작
# ✓ Entity: LuxExperience B.V. (CIK: 1831907)
# ⚠ EDGAR 정규화 DF가 비어 있습니다 (LUXE)
# ✓ EDGAR 정규화 DF: 0 rows × 0 cols
# ⚠ EDGAR 입력 DF가 비어있습니다. WRDS만으로 구성합니다.
# ⚠ WRDS 쿼리 실패: Execution failed on sql: SELECT * FROM us_fundq WHERE tic=%s
# (0, '')
# unable to rollback
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ⚠ WRDS 보완 후에도 DF가 비어 있습니다 (LUXE)
# ⚠ LUXE: 분석 결과 없음, 스킵
#
# === [29/990] NMZ 처리 시작 ===
# ================================================================================
# [NMZ] 통합 재무분석 시작
# ✗ EDGAR Company Facts 로딩 실패 (NMZ): Company Facts 요청 실패: 404 https://data.sec.gov/api/xbrl/companyfacts/CIK0001266585.json
# ⚠ NMZ: 분석 결과 없음, 스킵
#
# === [30/990] DEC 처리 시작 ===
# ================================================================================
# [DEC] 통합 재무분석 시작
# ✓ Entity: Diversified Energy Company PLC (CIK: 0001922446)
# ⚠ EDGAR 정규화 DF가 비어 있습니다 (DEC)
# ✓ EDGAR 정규화 DF: 0 rows × 0 cols
# ⚠ EDGAR 입력 DF가 비어있습니다. WRDS만으로 구성합니다.
# ⚠ WRDS 쿼리 실패: Execution failed on sql: SELECT * FROM us_fundq WHERE tic=%s
# (0, '')
# unable to rollback
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ⚠ WRDS 보완 후에도 DF가 비어 있습니다 (DEC)
# ⚠ DEC: 분석 결과 없음, 스킵
#
# === [31/990] RERE 처리 시작 ===
# ================================================================================
# [RERE] 통합 재무분석 시작
# ✓ Entity: ATRenew Inc. (CIK: 0001838957)
# ✓ EDGAR 정규화 DF: 4 rows × 14 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql: SELECT * FROM us_fundq WHERE tic=%s
# (0, '')
# unable to rollback
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 4 rows × 14 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 4 rows × 25 cols
# [RERE] 통합 재무분석 종료
# ================================================================================
# ✗ Error saving RERE: (pymysql.err.OperationalError) (2003, "Can't connect to MySQL server on '192.168.0.230' ([WinError 10061] 대상 컴퓨터에서 연결을 거부했으므로 연결하지 못했습니다)")
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# ✗ RERE 처리 중 기타 오류: (pymysql.err.OperationalError) (2003, "Can't connect to MySQL server on '192.168.0.230' ([WinError 10061] 대상 컴퓨터에서 연결을 거부했으므로 연결하지 못했습니다)")
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
#
# === [32/990] ASA 처리 시작 ===
# ================================================================================
# [ASA] 통합 재무분석 시작
# ✓ Entity:  (CIK: 0001230869)
# ⚠ EDGAR 정규화 DF가 비어 있습니다 (ASA)
# ✓ EDGAR 정규화 DF: 0 rows × 0 cols
# ⚠ EDGAR 입력 DF가 비어있습니다. WRDS만으로 구성합니다.
# ⚠ WRDS 쿼리 실패: Execution failed on sql: SELECT * FROM us_fundq WHERE tic=%s
# (0, '')
# unable to rollback
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ⚠ WRDS 보완 후에도 DF가 비어 있습니다 (ASA)
# ⚠ ASA: 분석 결과 없음, 스킵
#
# === [33/990] CRI 처리 시작 ===
# ================================================================================
# [CRI] 통합 재무분석 시작
# ✓ Entity: CARTER’S, INC. (CIK: 1060822)
# ✓ EDGAR 정규화 DF: 68 rows × 31 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql: SELECT * FROM us_fundq WHERE tic=%s
# (0, '')
# unable to rollback
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 68 rows × 31 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 68 rows × 48 cols
# [CRI] 통합 재무분석 종료
# ================================================================================
# ✗ Error saving CRI: (pymysql.err.OperationalError) (2003, "Can't connect to MySQL server on '192.168.0.230' ([WinError 10061] 대상 컴퓨터에서 연결을 거부했으므로 연결하지 못했습니다)")
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# ✗ CRI 처리 중 기타 오류: (pymysql.err.OperationalError) (2003, "Can't connect to MySQL server on '192.168.0.230' ([WinError 10061] 대상 컴퓨터에서 연결을 거부했으므로 연결하지 못했습니다)")
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
#
# === [34/990] GIC 처리 시작 ===
# ================================================================================
# [GIC] 통합 재무분석 시작
# ✓ Entity: Global Industrial Company (CIK: 945114)
# ✓ EDGAR 정규화 DF: 62 rows × 30 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql: SELECT * FROM us_fundq WHERE tic=%s
# (0, '')
# unable to rollback
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 62 rows × 30 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 62 rows × 47 cols
# [GIC] 통합 재무분석 종료
# ================================================================================
# ✗ Error saving GIC: (pymysql.err.OperationalError) (2003, "Can't connect to MySQL server on '192.168.0.230' ([WinError 10061] 대상 컴퓨터에서 연결을 거부했으므로 연결하지 못했습니다)")
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# ✗ GIC 처리 중 기타 오류: (pymysql.err.OperationalError) (2003, "Can't connect to MySQL server on '192.168.0.230' ([WinError 10061] 대상 컴퓨터에서 연결을 거부했으므로 연결하지 못했습니다)")
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
#
# === [35/990] PXED 처리 시작 ===
# ================================================================================
# [PXED] 통합 재무분석 시작
# ✗ EDGAR Company Facts 로딩 실패 (PXED): Company Facts 요청 실패: 404 https://data.sec.gov/api/xbrl/companyfacts/CIK0001600222.json
# ⚠ PXED: 분석 결과 없음, 스킵
#
# === [36/990] BORR 처리 시작 ===
# ================================================================================
# [BORR] 통합 재무분석 시작
# ✓ Entity: Borr Drilling Limited (CIK: 1715497)
# ✓ EDGAR 정규화 DF: 13 rows × 25 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql: SELECT * FROM us_fundq WHERE tic=%s
# (0, '')
# unable to rollback
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 13 rows × 25 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 13 rows × 38 cols
# [BORR] 통합 재무분석 종료
# ================================================================================
# ✗ Error saving BORR: (pymysql.err.OperationalError) (2003, "Can't connect to MySQL server on '192.168.0.230' ([WinError 10061] 대상 컴퓨터에서 연결을 거부했으므로 연결하지 못했습니다)")
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# ✗ BORR 처리 중 기타 오류: (pymysql.err.OperationalError) (2003, "Can't connect to MySQL server on '192.168.0.230' ([WinError 10061] 대상 컴퓨터에서 연결을 거부했으므로 연결하지 못했습니다)")
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
#
# === [37/990] KUKE 처리 시작 ===
# ================================================================================
# [KUKE] 통합 재무분석 시작
# ✓ Entity: Kuke Music Holding Limited (CIK: 1809158)
# ⚠ EDGAR 정규화 DF가 비어 있습니다 (KUKE)
# ✓ EDGAR 정규화 DF: 0 rows × 0 cols
# ⚠ EDGAR 입력 DF가 비어있습니다. WRDS만으로 구성합니다.
# ⚠ WRDS 쿼리 실패: Execution failed on sql: SELECT * FROM us_fundq WHERE tic=%s
# (0, '')
# unable to rollback
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ⚠ WRDS 보완 후에도 DF가 비어 있습니다 (KUKE)
# ⚠ KUKE: 분석 결과 없음, 스킵
#
# === [38/990] NMAX 처리 시작 ===
# ================================================================================
# [NMAX] 통합 재무분석 시작
# ✓ Entity: NEWSMAX INC. (CIK: 0002026478)
# ✓ EDGAR 정규화 DF: 8 rows × 23 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql: SELECT * FROM us_fundq WHERE tic=%s
# (0, '')
# unable to rollback
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 8 rows × 23 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 8 rows × 38 cols
# [NMAX] 통합 재무분석 종료
# ================================================================================
# ✗ Error saving NMAX: (pymysql.err.OperationalError) (2003, "Can't connect to MySQL server on '192.168.0.230' ([WinError 10061] 대상 컴퓨터에서 연결을 거부했으므로 연결하지 못했습니다)")
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# ✗ NMAX 처리 중 기타 오류: (pymysql.err.OperationalError) (2003, "Can't connect to MySQL server on '192.168.0.230' ([WinError 10061] 대상 컴퓨터에서 연결을 거부했으므로 연결하지 못했습니다)")
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
#
# === [39/990] NBXG 처리 시작 ===
# ================================================================================
# [NBXG] 통합 재무분석 시작
# ✓ Entity:  (CIK: 0001843181)
# ⚠ EDGAR 정규화 DF가 비어 있습니다 (NBXG)
# ✓ EDGAR 정규화 DF: 0 rows × 0 cols
# ⚠ EDGAR 입력 DF가 비어있습니다. WRDS만으로 구성합니다.
# ⚠ WRDS 쿼리 실패: Execution failed on sql: SELECT * FROM us_fundq WHERE tic=%s
# (0, '')
# unable to rollback
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ⚠ WRDS 보완 후에도 DF가 비어 있습니다 (NBXG)
# ⚠ NBXG: 분석 결과 없음, 스킵
#
# === [40/990] FPF 처리 시작 ===
# ================================================================================
# [FPF] 통합 재무분석 시작
# ✗ EDGAR Company Facts 로딩 실패 (FPF): Company Facts 요청 실패: 404 https://data.sec.gov/api/xbrl/companyfacts/CIK0001567569.json
# ⚠ FPF: 분석 결과 없음, 스킵
#
# === [41/990] NVGS 처리 시작 ===
# ================================================================================
# [NVGS] 통합 재무분석 시작
# ✓ Entity: NAVIGATOR HOLDINGS LTD (CIK: 1581804)
# ✓ EDGAR 정규화 DF: 34 rows × 24 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql: SELECT * FROM us_fundq WHERE tic=%s
# (0, '')
# unable to rollback
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 34 rows × 24 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 34 rows × 38 cols
# [NVGS] 통합 재무분석 종료
# ================================================================================
# ✗ Error saving NVGS: (pymysql.err.OperationalError) (2003, "Can't connect to MySQL server on '192.168.0.230' ([WinError 10061] 대상 컴퓨터에서 연결을 거부했으므로 연결하지 못했습니다)")
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# ✗ NVGS 처리 중 기타 오류: (pymysql.err.OperationalError) (2003, "Can't connect to MySQL server on '192.168.0.230' ([WinError 10061] 대상 컴퓨터에서 연결을 거부했으므로 연결하지 못했습니다)")
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
#
# === [42/990] YALA 처리 시작 ===
# ================================================================================
# [YALA] 통합 재무분석 시작
# ✓ Entity: YALLA GROUP LIMITED (CIK: 1794350)
# ✓ EDGAR 정규화 DF: 8 rows × 13 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql: SELECT * FROM us_fundq WHERE tic=%s
# (0, '')
# unable to rollback
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 8 rows × 13 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 8 rows × 23 cols
# [YALA] 통합 재무분석 종료
# ================================================================================
# ✗ Error saving YALA: (pymysql.err.OperationalError) (2003, "Can't connect to MySQL server on '192.168.0.230' ([WinError 10061] 대상 컴퓨터에서 연결을 거부했으므로 연결하지 못했습니다)")
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# ✗ YALA 처리 중 기타 오류: (pymysql.err.OperationalError) (2003, "Can't connect to MySQL server on '192.168.0.230' ([WinError 10061] 대상 컴퓨터에서 연결을 거부했으므로 연결하지 못했습니다)")
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
#
# === [43/990] REX 처리 시작 ===
# ================================================================================
# [REX] 통합 재무분석 시작
# ✓ Entity: REX AMERICAN RESOURCES CORPORATION (CIK: 744187)
# ✓ EDGAR 정규화 DF: 64 rows × 28 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql: SELECT * FROM us_fundq WHERE tic=%s
# (0, '')
# unable to rollback
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 64 rows × 28 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 64 rows × 45 cols
# [REX] 통합 재무분석 종료
# ================================================================================
# ✗ Error saving REX: (pymysql.err.OperationalError) (2003, "Can't connect to MySQL server on '192.168.0.230' ([WinError 10061] 대상 컴퓨터에서 연결을 거부했으므로 연결하지 못했습니다)")
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# ✗ REX 처리 중 기타 오류: (pymysql.err.OperationalError) (2003, "Can't connect to MySQL server on '192.168.0.230' ([WinError 10061] 대상 컴퓨터에서 연결을 거부했으므로 연결하지 못했습니다)")
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
#
# === [44/990] AGRO 처리 시작 ===
# ================================================================================
# [AGRO] 통합 재무분석 시작
# ✓ Entity: Adecoagro S.A. (CIK: 1499505)
# ⚠ EDGAR 정규화 DF가 비어 있습니다 (AGRO)
# ✓ EDGAR 정규화 DF: 0 rows × 0 cols
# ⚠ EDGAR 입력 DF가 비어있습니다. WRDS만으로 구성합니다.
# ⚠ WRDS 쿼리 실패: Execution failed on sql: SELECT * FROM us_fundq WHERE tic=%s
# (0, '')
# unable to rollback
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ⚠ WRDS 보완 후에도 DF가 비어 있습니다 (AGRO)
# ⚠ AGRO: 분석 결과 없음, 스킵
#
# === [45/990] PRO 처리 시작 ===
# ================================================================================
# [PRO] 통합 재무분석 시작
# ✗ EDGAR Company Facts 로딩 실패 (PRO): 티커를 찾을 수 없습니다: PRO
# ⚠ PRO: 분석 결과 없음, 스킵
#
# === [46/990] ECVT 처리 시작 ===
# ================================================================================
# [ECVT] 통합 재무분석 시작
# ✓ Entity: Ecovyst Inc. (CIK: 1708035)
# ✓ EDGAR 정규화 DF: 41 rows × 28 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql: SELECT * FROM us_fundq WHERE tic=%s
# (0, '')
# unable to rollback
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 41 rows × 28 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 41 rows × 45 cols
# [ECVT] 통합 재무분석 종료
# ================================================================================
# ✗ Error saving ECVT: (pymysql.err.OperationalError) (2003, "Can't connect to MySQL server on '192.168.0.230' ([WinError 10061] 대상 컴퓨터에서 연결을 거부했으므로 연결하지 못했습니다)")
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# ✗ ECVT 처리 중 기타 오류: (pymysql.err.OperationalError) (2003, "Can't connect to MySQL server on '192.168.0.230' ([WinError 10061] 대상 컴퓨터에서 연결을 거부했으므로 연결하지 못했습니다)")
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
#
# === [47/990] CCO 처리 시작 ===
# ================================================================================
# [CCO] 통합 재무분석 시작
# ✓ Entity: CLEAR CHANNEL OUTDOOR HOLDINGS, INC. (CIK: 1334978)
# ✓ EDGAR 정규화 DF: 64 rows × 27 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql: SELECT * FROM us_fundq WHERE tic=%s
# (0, '')
# unable to rollback
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 64 rows × 27 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 64 rows × 41 cols
# [CCO] 통합 재무분석 종료
# ================================================================================
# ✗ Error saving CCO: (pymysql.err.OperationalError) (2003, "Can't connect to MySQL server on '192.168.0.230' ([WinError 10061] 대상 컴퓨터에서 연결을 거부했으므로 연결하지 못했습니다)")
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# ✗ CCO 처리 중 기타 오류: (pymysql.err.OperationalError) (2003, "Can't connect to MySQL server on '192.168.0.230' ([WinError 10061] 대상 컴퓨터에서 연결을 거부했으므로 연결하지 못했습니다)")
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
#
# === [48/990] SFL 처리 시작 ===
# ================================================================================
# [SFL] 통합 재무분석 시작
# ✓ Entity: SFL Corporation Ltd. (CIK: 1289877)
# ✓ EDGAR 정규화 DF: 37 rows × 24 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql: SELECT * FROM us_fundq WHERE tic=%s
# (0, '')
# unable to rollback
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 37 rows × 24 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 37 rows × 38 cols
# [SFL] 통합 재무분석 종료
# ================================================================================
# ✗ Error saving SFL: (pymysql.err.OperationalError) (2003, "Can't connect to MySQL server on '192.168.0.230' ([WinError 10061] 대상 컴퓨터에서 연결을 거부했으므로 연결하지 못했습니다)")
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# ✗ SFL 처리 중 기타 오류: (pymysql.err.OperationalError) (2003, "Can't connect to MySQL server on '192.168.0.230' ([WinError 10061] 대상 컴퓨터에서 연결을 거부했으므로 연결하지 못했습니다)")
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
#
# === [49/990] AMPX 처리 시작 ===
# ================================================================================
# [AMPX] 통합 재무분석 시작
# ✓ Entity: AMPRIUS TECHNOLOGIES, INC. (CIK: 0001899287)
# ✓ EDGAR 정규화 DF: 21 rows × 23 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql: SELECT * FROM us_fundq WHERE tic=%s
# (0, '')
# unable to rollback
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 21 rows × 23 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 21 rows × 40 cols
# [AMPX] 통합 재무분석 종료
# ================================================================================
# ✗ Error saving AMPX: (pymysql.err.OperationalError) (2003, "Can't connect to MySQL server on '192.168.0.230' ([WinError 10061] 대상 컴퓨터에서 연결을 거부했으므로 연결하지 못했습니다)")
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# ✗ AMPX 처리 중 기타 오류: (pymysql.err.OperationalError) (2003, "Can't connect to MySQL server on '192.168.0.230' ([WinError 10061] 대상 컴퓨터에서 연결을 거부했으므로 연결하지 못했습니다)")
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
#
# === [50/990] DAO 처리 시작 ===
# ================================================================================
# [DAO] 통합 재무분석 시작
# ✓ Entity: Youdao, Inc. (CIK: 1781753)
# ✓ EDGAR 정규화 DF: 7 rows × 23 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql: SELECT * FROM us_fundq WHERE tic=%s
# (0, '')
# unable to rollback
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 7 rows × 23 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 7 rows × 40 cols
# [DAO] 통합 재무분석 종료
# ================================================================================
# ✗ Error saving DAO: (pymysql.err.OperationalError) (2003, "Can't connect to MySQL server on '192.168.0.230' ([WinError 10061] 대상 컴퓨터에서 연결을 거부했으므로 연결하지 못했습니다)")
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# ✗ DAO 처리 중 기타 오류: (pymysql.err.OperationalError) (2003, "Can't connect to MySQL server on '192.168.0.230' ([WinError 10061] 대상 컴퓨터에서 연결을 거부했으므로 연결하지 못했습니다)")
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
#
# === [51/990] VLRS 처리 시작 ===
# ================================================================================
# [VLRS] 통합 재무분석 시작
# ✓ Entity: Controladora Vuela Compania de Aviacion, S.A.B. de C.V. (CIK: 1520504)
# ⚠ EDGAR 정규화 DF가 비어 있습니다 (VLRS)
# ✓ EDGAR 정규화 DF: 0 rows × 0 cols
# ⚠ EDGAR 입력 DF가 비어있습니다. WRDS만으로 구성합니다.
# ⚠ WRDS 쿼리 실패: Execution failed on sql: SELECT * FROM us_fundq WHERE tic=%s
# (0, '')
# unable to rollback
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ⚠ WRDS 보완 후에도 DF가 비어 있습니다 (VLRS)
# ⚠ VLRS: 분석 결과 없음, 스킵
#
# === [52/990] HQH 처리 시작 ===
# ================================================================================
# [HQH] 통합 재무분석 시작
# ✗ EDGAR Company Facts 로딩 실패 (HQH): Company Facts 요청 실패: 404 https://data.sec.gov/api/xbrl/companyfacts/CIK0000805267.json
# ⚠ HQH: 분석 결과 없음, 스킵
#
# === [53/990] PTA 처리 시작 ===
# ================================================================================
# [PTA] 통합 재무분석 시작
# ✗ EDGAR Company Facts 로딩 실패 (PTA): Company Facts 요청 실패: 404 https://data.sec.gov/api/xbrl/companyfacts/CIK0001793882.json
# ⚠ PTA: 분석 결과 없음, 스킵
#
# === [54/990] SCL 처리 시작 ===
# ================================================================================
# [SCL] 통합 재무분석 시작
# ✓ Entity: STEPAN COMPANY (CIK: 94049)
# ✓ EDGAR 정규화 DF: 64 rows × 27 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql: SELECT * FROM us_fundq WHERE tic=%s
# (0, '')
# unable to rollback
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 64 rows × 27 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 64 rows × 44 cols
# [SCL] 통합 재무분석 종료
# ================================================================================
# ✗ Error saving SCL: (pymysql.err.OperationalError) (2003, "Can't connect to MySQL server on '192.168.0.230' ([WinError 10061] 대상 컴퓨터에서 연결을 거부했으므로 연결하지 못했습니다)")
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# ✗ SCL 처리 중 기타 오류: (pymysql.err.OperationalError) (2003, "Can't connect to MySQL server on '192.168.0.230' ([WinError 10061] 대상 컴퓨터에서 연결을 거부했으므로 연결하지 못했습니다)")
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
#
# === [55/990] AOD 처리 시작 ===
# ================================================================================
# [AOD] 통합 재무분석 시작
# ✓ Entity:  (CIK: 0001379400)
# ⚠ EDGAR 정규화 DF가 비어 있습니다 (AOD)
# ✓ EDGAR 정규화 DF: 0 rows × 0 cols
# ⚠ EDGAR 입력 DF가 비어있습니다. WRDS만으로 구성합니다.
# ⚠ WRDS 쿼리 실패: Execution failed on sql: SELECT * FROM us_fundq WHERE tic=%s
# (0, '')
# unable to rollback
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ⚠ WRDS 보완 후에도 DF가 비어 있습니다 (AOD)
# ⚠ AOD: 분석 결과 없음, 스킵
#
# === [56/990] VTOL 처리 시작 ===
# ================================================================================
# [VTOL] 통합 재무분석 시작
# ✓ Entity: Bristow Group Inc. (CIK: 1525221)
# ✓ EDGAR 정규화 DF: 59 rows × 30 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql: SELECT * FROM us_fundq WHERE tic=%s
# (0, '')
# unable to rollback
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 59 rows × 30 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 59 rows × 44 cols
# [VTOL] 통합 재무분석 종료
# ================================================================================
# ✗ Error saving VTOL: (pymysql.err.OperationalError) (2003, "Can't connect to MySQL server on '192.168.0.230' ([WinError 10061] 대상 컴퓨터에서 연결을 거부했으므로 연결하지 못했습니다)")
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# ✗ VTOL 처리 중 기타 오류: (pymysql.err.OperationalError) (2003, "Can't connect to MySQL server on '192.168.0.230' ([WinError 10061] 대상 컴퓨터에서 연결을 거부했으므로 연결하지 못했습니다)")
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
#
# === [57/990] ALIT 처리 시작 ===
# ================================================================================
# [ALIT] 통합 재무분석 시작
# ✓ Entity: Alight, Inc. / Delaware (CIK: 1809104)
# ✓ EDGAR 정규화 DF: 23 rows × 29 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql: SELECT * FROM us_fundq WHERE tic=%s
# (0, '')
# unable to rollback
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 23 rows × 29 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 23 rows × 43 cols
# [ALIT] 통합 재무분석 종료
# ================================================================================
# ✗ Error saving ALIT: (pymysql.err.OperationalError) (2003, "Can't connect to MySQL server on '192.168.0.230' ([WinError 10061] 대상 컴퓨터에서 연결을 거부했으므로 연결하지 못했습니다)")
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# ✗ ALIT 처리 중 기타 오류: (pymysql.err.OperationalError) (2003, "Can't connect to MySQL server on '192.168.0.230' ([WinError 10061] 대상 컴퓨터에서 연결을 거부했으므로 연결하지 못했습니다)")
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
#
# === [58/990] CWH 처리 시작 ===
# ================================================================================
# [CWH] 통합 재무분석 시작
# ✓ Entity: CAMPING WORLD HOLDINGS, INC. (CIK: 1669779)
# ✓ EDGAR 정규화 DF: 45 rows × 28 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql: SELECT * FROM us_fundq WHERE tic=%s
# (0, '')
# unable to rollback
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 45 rows × 28 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 45 rows × 44 cols
# [CWH] 통합 재무분석 종료
# ================================================================================
# ✗ Error saving CWH: (pymysql.err.OperationalError) (2003, "Can't connect to MySQL server on '192.168.0.230' ([WinError 10061] 대상 컴퓨터에서 연결을 거부했으므로 연결하지 못했습니다)")
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# ✗ CWH 처리 중 기타 오류: (pymysql.err.OperationalError) (2003, "Can't connect to MySQL server on '192.168.0.230' ([WinError 10061] 대상 컴퓨터에서 연결을 거부했으므로 연결하지 못했습니다)")
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
#
# === [59/990] BBN 처리 시작 ===
# ================================================================================
# [BBN] 통합 재무분석 시작
# ✗ EDGAR Company Facts 로딩 실패 (BBN): Company Facts 요청 실패: 404 https://data.sec.gov/api/xbrl/companyfacts/CIK0001493683.json
# ⚠ BBN: 분석 결과 없음, 스킵
#
# === [60/990] MKC.V 처리 시작 ===
# ================================================================================
# [MKC.V] 통합 재무분석 시작
# ✗ EDGAR Company Facts 로딩 실패 (MKC.V): 티커를 찾을 수 없습니다: MKC.V
# ⚠ MKC.V: 분석 결과 없음, 스킵
#
# === [61/990] LPG 처리 시작 ===
# ================================================================================
# [LPG] 통합 재무분석 시작
# ✓ Entity: DORIAN LPG LTD. (CIK: 1596993)
# ✓ EDGAR 정규화 DF: 50 rows × 23 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql: SELECT * FROM us_fundq WHERE tic=%s
# (0, '')
# unable to rollback
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 50 rows × 23 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 50 rows × 37 cols
# [LPG] 통합 재무분석 종료
# ================================================================================
# ✗ Error saving LPG: (pymysql.err.OperationalError) (2003, "Can't connect to MySQL server on '192.168.0.230' ([WinError 10061] 대상 컴퓨터에서 연결을 거부했으므로 연결하지 못했습니다)")
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# ✗ LPG 처리 중 기타 오류: (pymysql.err.OperationalError) (2003, "Can't connect to MySQL server on '192.168.0.230' ([WinError 10061] 대상 컴퓨터에서 연결을 거부했으므로 연결하지 못했습니다)")
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
#
# === [62/990] UAA 처리 시작 ===
# ================================================================================
# [UAA] 통합 재무분석 시작
# ✓ Entity: UNDER ARMOUR, INC. (CIK: 1336917)
# ✓ EDGAR 정규화 DF: 68 rows × 28 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql: SELECT * FROM us_fundq WHERE tic=%s
# (0, '')
# unable to rollback
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 68 rows × 28 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 68 rows × 45 cols
# [UAA] 통합 재무분석 종료
# ...
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 66 rows × 49 cols
# [DSS] 통합 재무분석 종료
# ================================================================================
# ✓ Saved DSS data: 66 dates x 49 items
# ✓ DSS (DSS,     INC.) 저장 완료
#
# === [967/990] MSN 처리 시작 ===
# ================================================================================
# [MSN] 통합 재무분석 시작
# ✓ Entity: EMERSON RADIO CORP (CIK: 32621)
# ✓ EDGAR 정규화 DF: 63 rows × 26 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql: SELECT * FROM us_fundq WHERE tic=%s
# (0, '')
# unable to rollback
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 63 rows × 26 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 63 rows × 42 cols
# [MSN] 통합 재무분석 종료
# ================================================================================
# ✓ Saved MSN data: 63 dates x 42 items
# ✓ MSN (EMERSON RADIO CORP) 저장 완료
#
# === [968/990] AMBO 처리 시작 ===
# ================================================================================
# [AMBO] 통합 재무분석 시작
# ✓ Entity: Ambow Education Holding Ltd. (CIK: 1494558)
# ✓ EDGAR 정규화 DF: 23 rows × 26 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql: SELECT * FROM us_fundq WHERE tic=%s
# (0, '')
# unable to rollback
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 23 rows × 26 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 23 rows × 43 cols
# [AMBO] 통합 재무분석 종료
# ================================================================================
# ✓ Saved AMBO data: 23 dates x 43 items
# ✓ AMBO (Ambow Education Holding Ltd.) 저장 완료
#
# === [969/990] SOAR 처리 시작 ===
# ================================================================================
# [SOAR] 통합 재무분석 시작
# ✓ Entity: VOLATO GROUP, INC. (CIK: 0001853070)
# ✓ EDGAR 정규화 DF: 19 rows × 24 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql: SELECT * FROM us_fundq WHERE tic=%s
# (0, '')
# unable to rollback
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 19 rows × 24 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 19 rows × 37 cols
# [SOAR] 통합 재무분석 종료
# ================================================================================
# ✓ Saved SOAR data: 19 dates x 37 items
# ✓ SOAR (VOLATO GROUP, INC.) 저장 완료
#
# === [970/990] BQ 처리 시작 ===
# ================================================================================
# [BQ] 통합 재무분석 시작
# ✓ Entity: BOQII HOLDING LIMITED (CIK: 1815021)
# ✓ EDGAR 정규화 DF: 5 rows × 17 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql: SELECT * FROM us_fundq WHERE tic=%s
# (0, '')
# unable to rollback
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 5 rows × 17 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 5 rows × 30 cols
# [BQ] 통합 재무분석 종료
# ================================================================================
# ✓ Saved BQ data: 5 dates x 30 items
# ✓ BQ (BOQII HOLDING LIMITED) 저장 완료
#
# === [971/990] SRXH 처리 시작 ===
# ================================================================================
# [SRXH] 통합 재무분석 시작
# ✓ Entity: SRx Health Solutions Inc. (CIK: 1471727)
# ✓ EDGAR 정규화 DF: 78 rows × 32 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql: SELECT * FROM us_fundq WHERE tic=%s
# (0, '')
# unable to rollback
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 78 rows × 32 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 78 rows × 49 cols
# [SRXH] 통합 재무분석 종료
# ================================================================================
# ✓ Saved SRXH data: 78 dates x 49 items
# ✓ SRXH (SRx Health Solutions Inc.) 저장 완료
#
# === [972/990] MITQ 처리 시작 ===
# ================================================================================
# [MITQ] 통합 재무분석 시작
# ✓ Entity: MOVING iMAGE TECHNOLOGIES INC. (CIK: 1770236)
# ✓ EDGAR 정규화 DF: 23 rows × 28 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql: SELECT * FROM us_fundq WHERE tic=%s
# (0, '')
# unable to rollback
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 23 rows × 28 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 23 rows × 45 cols
# [MITQ] 통합 재무분석 종료
# ================================================================================
# ✓ Saved MITQ data: 23 dates x 45 items
# ✓ MITQ (MOVING iMAGE TECHNOLOGIES INC.) 저장 완료
#
# === [973/990] AMZE 처리 시작 ===
# ================================================================================
# [AMZE] 통합 재무분석 시작
# ✓ Entity: Amaze Holdings, Inc. (CIK: 0001880343)
# ✓ EDGAR 정규화 DF: 20 rows × 23 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql: SELECT * FROM us_fundq WHERE tic=%s
# (0, '')
# unable to rollback
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 20 rows × 23 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 20 rows × 40 cols
# [AMZE] 통합 재무분석 종료
# ================================================================================
# ✓ Saved AMZE data: 20 dates x 40 items
# ✓ AMZE (Amaze Holdings, Inc.) 저장 완료
#
# === [974/990] TPET 처리 시작 ===
# ================================================================================
# [TPET] 통합 재무분석 시작
# ✓ Entity: TRIO PETROLEUM CORP (CIK: 0001898766)
# ✓ EDGAR 정규화 DF: 15 rows × 18 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql: SELECT * FROM us_fundq WHERE tic=%s
# (0, '')
# unable to rollback
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 15 rows × 18 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 15 rows × 32 cols
# [TPET] 통합 재무분석 종료
# ================================================================================
# ✓ Saved TPET data: 15 dates x 32 items
# ✓ TPET (TRIO PETROLEUM CORP) 저장 완료
#
# === [975/990] CPHI 처리 시작 ===
# ================================================================================
# [CPHI] 통합 재무분석 시작
# ✓ Entity: CHINA PHARMA HOLDINGS, INC. (CIK: 1106644)
# ✓ EDGAR 정규화 DF: 63 rows × 30 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql: SELECT * FROM us_fundq WHERE tic=%s
# (0, '')
# unable to rollback
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 63 rows × 30 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 63 rows × 47 cols
# [CPHI] 통합 재무분석 종료
# ================================================================================
# ✓ Saved CPHI data: 63 dates x 47 items
# ✓ CPHI (CHINA PHARMA HOLDINGS, INC.) 저장 완료
#
# === [976/990] TOVX 처리 시작 ===
# ================================================================================
# [TOVX] 통합 재무분석 시작
# ✓ Entity: THERIVA BIOLOGICS, INC. (CIK: 894158)
# ✓ EDGAR 정규화 DF: 64 rows × 26 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql: SELECT * FROM us_fundq WHERE tic=%s
# (0, '')
# unable to rollback
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 64 rows × 26 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 64 rows × 39 cols
# [TOVX] 통합 재무분석 종료
# ================================================================================
# ✓ Saved TOVX data: 64 dates x 39 items
# ✓ TOVX (THERIVA BIOLOGICS, INC.) 저장 완료
#
# === [977/990] SYNX 처리 시작 ===
# ================================================================================
# [SYNX] 통합 재무분석 시작
# ✓ Entity: Silynxcom Ltd. (CIK: 0001976443)
# ⚠ EDGAR 정규화 DF가 비어 있습니다 (SYNX)
# ✓ EDGAR 정규화 DF: 0 rows × 0 cols
# ⚠ EDGAR 입력 DF가 비어있습니다. WRDS만으로 구성합니다.
# ⚠ WRDS 쿼리 실패: Execution failed on sql: SELECT * FROM us_fundq WHERE tic=%s
# (0, '')
# unable to rollback
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ⚠ WRDS 보완 후에도 DF가 비어 있습니다 (SYNX)
# ⚠ SYNX: 분석 결과 없음, 스킵
#
# === [978/990] NCL 처리 시작 ===
# ================================================================================
# [NCL] 통합 재무분석 시작
# ✓ Entity: NORTHANN CORP. (CIK: 0001923780)
# ✓ EDGAR 정규화 DF: 15 rows × 23 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql: SELECT * FROM us_fundq WHERE tic=%s
# (0, '')
# unable to rollback
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 15 rows × 23 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 15 rows × 40 cols
# [NCL] 통합 재무분석 종료
# ================================================================================
# ✓ Saved NCL data: 15 dates x 40 items
# ✓ NCL (NORTHANN CORP.) 저장 완료
#
# === [979/990] CANF 처리 시작 ===
# ================================================================================
# [CANF] 통합 재무분석 시작
# ✓ Entity: CAN-FITE BIOPHARMA LTD. (CIK: 1536196)
# ✓ EDGAR 정규화 DF: 16 rows × 17 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql: SELECT * FROM us_fundq WHERE tic=%s
# (0, '')
# unable to rollback
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 16 rows × 17 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 16 rows × 30 cols
# [CANF] 통합 재무분석 종료
# ================================================================================
# ✓ Saved CANF data: 16 dates x 30 items
# ✓ CANF (CAN-FITE BIOPHARMA LTD.) 저장 완료
#
# === [980/990] HCWC 처리 시작 ===
# ================================================================================
# [HCWC] 통합 재무분석 시작
# ✓ Entity: HEALTHY CHOICE WELLNESS CORP. (CIK: 0001948864)
# ✓ EDGAR 정규화 DF: 11 rows × 27 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql: SELECT * FROM us_fundq WHERE tic=%s
# (0, '')
# unable to rollback
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 11 rows × 27 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 11 rows × 44 cols
# [HCWC] 통합 재무분석 종료
# ================================================================================
# ✓ Saved HCWC data: 11 dates x 44 items
# ✓ HCWC (HEALTHY CHOICE WELLNESS CORP.) 저장 완료
#
# === [981/990] MTNB 처리 시작 ===
# ================================================================================
# [MTNB] 통합 재무분석 시작
# ✓ Entity: MATINAS BIOPHARMA HOLDINGS, INC. (CIK: 1582554)
# ✓ EDGAR 정규화 DF: 53 rows × 22 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql: SELECT * FROM us_fundq WHERE tic=%s
# (0, '')
# unable to rollback
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 53 rows × 22 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 53 rows × 35 cols
# [MTNB] 통합 재무분석 종료
# ================================================================================
# ✓ Saved MTNB data: 53 dates x 35 items
# ✓ MTNB (MATINAS BIOPHARMA HOLDINGS, INC.) 저장 완료
#
# === [982/990] SGN 처리 시작 ===
# ================================================================================
# [SGN] 통합 재무분석 시작
# ✓ Entity: SIGNING DAY SPORTS, INC. (CIK: 0001898474)
# ✓ EDGAR 정규화 DF: 16 rows × 27 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql: SELECT * FROM us_fundq WHERE tic=%s
# (0, '')
# unable to rollback
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 16 rows × 27 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 16 rows × 41 cols
# [SGN] 통합 재무분석 종료
# ================================================================================
# ✓ Saved SGN data: 16 dates x 41 items
# ✓ SGN (SIGNING DAY SPORTS, INC.) 저장 완료
#
# === [983/990] ITP 처리 시작 ===
# ================================================================================
# [ITP] 통합 재무분석 시작
# ✓ Entity: IT TECH PACKAGING, INC. (CIK: 1358190)
# ✓ EDGAR 정규화 DF: 65 rows × 30 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql: SELECT * FROM us_fundq WHERE tic=%s
# (0, '')
# unable to rollback
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 65 rows × 30 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 65 rows × 47 cols
# [ITP] 통합 재무분석 종료
# ================================================================================
# ✓ Saved ITP data: 65 dates x 47 items
# ✓ ITP (IT TECH PACKAGING, INC.) 저장 완료
#
# === [984/990] AIM 처리 시작 ===
# ================================================================================
# [AIM] 통합 재무분석 시작
# ✓ Entity: AIM IMMUNOTECH INC. (CIK: 946644)
# ✓ EDGAR 정규화 DF: 64 rows × 24 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql: SELECT * FROM us_fundq WHERE tic=%s
# (0, '')
# unable to rollback
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 64 rows × 24 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 64 rows × 37 cols
# [AIM] 통합 재무분석 종료
# ================================================================================
# ✓ Saved AIM data: 64 dates x 37 items
# ✓ AIM (AIM IMMUNOTECH INC.) 저장 완료
#
# === [985/990] OGEN 처리 시작 ===
# ================================================================================
# [OGEN] 통합 재무분석 시작
# ✓ Entity: ORAGENICS, INC. (CIK: 1174940)
# ✓ EDGAR 정규화 DF: 63 rows × 26 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql: SELECT * FROM us_fundq WHERE tic=%s
# (0, '')
# unable to rollback
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 63 rows × 26 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 63 rows × 41 cols
# [OGEN] 통합 재무분석 종료
# ================================================================================
# ✓ Saved OGEN data: 63 dates x 41 items
# ✓ OGEN (ORAGENICS, INC.) 저장 완료
#
# === [986/990] AZTR 처리 시작 ===
# ================================================================================
# [AZTR] 통합 재무분석 시작
# ✓ Entity: Azitra, Inc. (CIK: 0001701478)
# ✓ EDGAR 정규화 DF: 16 rows × 25 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql: SELECT * FROM us_fundq WHERE tic=%s
# (0, '')
# unable to rollback
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 16 rows × 25 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 16 rows × 38 cols
# [AZTR] 통합 재무분석 종료
# ================================================================================
# ✓ Saved AZTR data: 16 dates x 38 items
# ✓ AZTR (Azitra, Inc.) 저장 완료
#
# === [987/990] PHGE 처리 시작 ===
# ================================================================================
# [PHGE] 통합 재무분석 시작
# ✓ Entity: BiomX Inc. (CIK: 1739174)
# ✓ EDGAR 정규화 DF: 33 rows × 28 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql: SELECT * FROM us_fundq WHERE tic=%s
# (0, '')
# unable to rollback
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 33 rows × 28 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 33 rows × 39 cols
# [PHGE] 통합 재무분석 종료
# ================================================================================
# ✓ Saved PHGE data: 33 dates x 39 items
# ✓ PHGE (BiomX Inc.) 저장 완료
#
# === [988/990] VTAK 처리 시작 ===
# ================================================================================
# [VTAK] 통합 재무분석 시작
# ✓ Entity: Catheter Precision, Inc. (CIK: 1716621)
# ✓ EDGAR 정규화 DF: 34 rows × 31 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql: SELECT * FROM us_fundq WHERE tic=%s
# (0, '')
# unable to rollback
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 34 rows × 31 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 34 rows × 48 cols
# [VTAK] 통합 재무분석 종료
# ================================================================================
# ✓ Saved VTAK data: 34 dates x 48 items
# ✓ VTAK (Catheter Precision, Inc.) 저장 완료
#
# === [989/990] SBEV 처리 시작 ===
# ================================================================================
# [SBEV] 통합 재무분석 시작
# ✓ Entity: SPLASH BEVERAGE GROUP, INC. (CIK: 1553788)
# ✓ EDGAR 정규화 DF: 58 rows × 29 cols
# ⚠ WRDS 쿼리 실패: Execution failed on sql: SELECT * FROM us_fundq WHERE tic=%s
# (0, '')
# unable to rollback
# WRDS 데이터 없음 → EDGAR 그대로 반환
# ✓ EDGAR+WRDS 병합 DF: 58 rows × 29 cols
# 재무비율 계산 중...
#   - 수익성 비율 계산...
#   - 레버리지 비율 계산...
#   - 유동성 비율 계산...
#   - 효율성 비율 계산...
# 재무비율 계산 완료!
# ✓ 최종 DF (비율 포함): 58 rows × 46 cols
# [SBEV] 통합 재무분석 종료
# ================================================================================
# ✓ Saved SBEV data: 58 dates x 46 items
# ✓ SBEV (SPLASH BEVERAGE GROUP, INC.) 저장 완료
#
# === [990/990] GLU PR A 처리 시작 ===
# ================================================================================
# [GLU PR A] 통합 재무분석 시작
# ✗ EDGAR Company Facts 로딩 실패 (GLU PR A): 티커를 찾을 수 없습니다: GLU PR A
# ⚠ GLU PR A: 분석 결과 없음, 스킵
#
# === 전체 작업 완료 ===

# %%
import pandas as pd
import pymysql
from typing import Dict, Optional, List


def quarter_end_from_report_date(report_date: pd.Timestamp) -> pd.Timestamp:
    y = report_date.year
    m = report_date.month

    if m in [1, 2, 3]:
        return pd.Timestamp(f"{y}-03-31")
    elif m in [4, 5, 6]:
        return pd.Timestamp(f"{y}-06-30")
    elif m in [7, 8, 9]:
        return pd.Timestamp(f"{y}-09-30")
    else:
        return pd.Timestamp(f"{y}-12-31")


def fetch_sec_financial_pivot_fixed(
    db_info: Dict[str, any],
    ticker: str,
    table_name: str = "sec_financial_data",
    start_date: Optional[str] = None,
    end_date: Optional[str] = None,
    item_list: Optional[List[str]] = None,
) -> pd.DataFrame:

    conn = pymysql.connect(
        host=db_info["host"], port=db_info.get("port", 3306),
        user=db_info["user"], password=db_info["password"],
        database=db_info["database"], charset="utf8mb4"
    )

    # -----------------------------
    # 1) 데이터 로드
    # -----------------------------
    try:
        where_clause = ["ticker=%s"]
        params = [ticker]

        if start_date:
            where_clause.append("date >= %s")
            params.append(start_date)
        if end_date:
            where_clause.append("date <= %s")
            params.append(end_date)
        if item_list:
            placeholders = ",".join(["%s"] * len(item_list))
            where_clause.append(f"item_name IN ({placeholders})")
            params.extend(item_list)

        where_sql = " AND ".join(where_clause)

        sql = f"""
            SELECT date, ticker, item_name, value
            FROM {table_name}
            WHERE {where_sql}
            ORDER BY date, item_name
        """

        df = pd.read_sql(sql, conn, params=params)
    finally:
        conn.close()

    if df.empty:
        print(f"[INFO] {ticker} 데이터 없음")
        return df

    # -----------------------------
    # 2) 기존 date → report_date로 이름 변경
    # -----------------------------
    df = df.rename(columns={"date": "report_date"})
    df["report_date"] = pd.to_datetime(df["report_date"])

    # -----------------------------
    # 3) report_date → 분기말 날짜(date)
    # -----------------------------
    df["date"] = df["report_date"].apply(quarter_end_from_report_date)

    # (중복 가능성 대비) 각 분기(date, ticker)별 대표 report_date 하나 선택
    # 여기서는 가장 늦은 날짜(max) 사용
    rep_dates = (
        df[["date", "ticker", "report_date"]]
        .drop_duplicates()
        .groupby(["date", "ticker"], as_index=False)["report_date"]
        .max()
    )

    # -----------------------------
    # 4) pivot 변환 (분기말 기준 wide)
    # -----------------------------
    df_pivot = df.pivot_table(
        index=["date", "ticker"],
        columns="item_name",
        values="value",
        aggfunc="last"
    ).sort_index()

    df_pivot = df_pivot.reset_index()

    # -----------------------------
    # 5) 대표 report_date 다시 붙이기
    # -----------------------------
    df_pivot = df_pivot.merge(rep_dates, how="left", on=["date", "ticker"])

    # 보기 편하게 컬럼 순서 조정: date, report_date, ticker, 나머지 item 들
    cols = ["date", "report_date", "ticker"] + [
        c for c in df_pivot.columns if c not in ("date", "report_date", "ticker")
    ]
    df_pivot = df_pivot[cols]

    return df_pivot

# %%
# 1) AAPL 전체 기간, 모든 item_name
fs_df = fetch_sec_financial_pivot_fixed(db_info, "MU")
fs_df

# 2) 기간 제한 + 특정 항목만
# item_list = ["revenue", "net_income", "total_assets", "ROE", "OPM"]
# aapl_subset = fetch_sec_financial_pivot(
#     db_info,
#     "AAPL",
#     start_date="2015-01-01",
#     end_date="2024-12-31",
#     item_list=item_list
# )
# print(aapl_subset.tail())
# Out:
#          date report_date ticker  accounts_payable  accounts_receivable  \
# 0  2008-09-30  2008-08-28     MU               NaN                  NaN
# 1  2008-12-31  2008-12-04     MU               NaN                  NaN
# 2  2009-09-30  2009-09-03     MU      1.037000e+09                  NaN
# 3  2009-12-31  2009-12-03     MU      1.059000e+09                  NaN
# 4  2010-03-31  2010-03-04     MU      1.059000e+09                  NaN
# ..        ...         ...    ...               ...                  ...
# 62 2024-09-30  2024-08-29     MU      7.299000e+09         5.419000e+09
# 63 2024-12-31  2024-11-28     MU      7.126000e+09         6.250000e+09
# 64 2025-03-31  2025-02-27     MU      6.176000e+09         5.092000e+09
# 65 2025-06-30  2025-05-29     MU      8.761000e+09         5.492000e+09
# 66 2025-09-30  2025-08-28     MU      9.649000e+09         7.163000e+09
#
#     accrued_liabilities  accumulated_depreciation  asset_turnover  \
# 0                   NaN                       NaN             NaN
# 1                   NaN                       NaN             NaN
# 2                   NaN                       NaN             NaN
# 3                   NaN                       NaN             NaN
# 4                   NaN                       NaN             NaN
# ..                  ...                       ...             ...
# 62         1.117000e+09              3.319000e+10        0.101908
# 63         1.054000e+09              3.319000e+10        0.128796
# 64         6.140000e+08              3.319000e+10        0.116062
# 65         9.500000e+08              3.319000e+10        0.128598
# 66         1.116000e+09              3.319000e+10        0.122210
#
#     capital_expenditures          cash  ...  research_development  \
# 0                    NaN  1.243000e+09  ...                   NaN
# 1           2.700000e+08  1.025000e+09  ...           178000000.0
# 2           2.700000e+08  1.485000e+09  ...           178000000.0
# 3           6.200000e+07  1.565000e+09  ...           137000000.0
# 4           6.200000e+07  1.870000e+09  ...           148000000.0
# ..                   ...           ...  ...                   ...
# 62          1.796000e+09  7.041000e+09  ...           850000000.0
# 63          3.206000e+09  6.693000e+09  ...           888000000.0
# 64          3.206000e+09  7.552000e+09  ...           898000000.0
# 65          3.206000e+09  1.016300e+10  ...           965000000.0
# 66          3.206000e+09  9.642000e+09  ...           965000000.0
#
#          revenue        roa        roe      roic  short_term_debt  \
# 0            NaN        NaN        NaN       NaN              NaN
# 1            NaN        NaN        NaN       NaN              NaN
# 2            NaN -12.531600 -28.992500 -7.218820              NaN
# 3            NaN -10.506600 -23.715100  2.148580              NaN
# 4            NaN  -7.393830 -16.689100  4.388170              NaN
# ..           ...        ...        ...       ...              ...
# 62  6.811000e+09   0.333658   0.499714  0.746563      431000000.0
# 63  8.709000e+09   4.920250   7.419550  3.932490      533000000.0
# 64  8.053000e+09   5.933520   8.901330  3.226110      504000000.0
# 65  9.301000e+09   7.839500  11.940200  3.886090      538000000.0
# 66  9.301000e+09   9.490590  14.548400  3.952500      560000000.0
#
#     stockholders_equity  total_assets    total_debt  total_liabilities
# 0                   NaN           NaN           NaN                NaN
# 1                   NaN           NaN           NaN                NaN
# 2          4.953000e+09  1.145900e+10           NaN       4.520000e+09
# 3          5.195000e+09  1.172600e+10           NaN       4.635000e+09
# 4          5.195000e+09  1.172600e+10           NaN       4.635000e+09
# ..                  ...           ...           ...                ...
# 62         4.513100e+10  6.941600e+10  1.339700e+10       2.428500e+10
# 63         4.679700e+10  7.146100e+10  1.378500e+10       2.466400e+10
# 64         4.863300e+10  7.305300e+10  1.435500e+10       2.442000e+10
# 65         5.074800e+10  7.839700e+10  1.554100e+10       2.764900e+10
# 66         5.416500e+10  8.279800e+10  1.457700e+10       2.863300e+10
#
# [67 rows x 53 columns]

# %%
def count_unique_tickers_sec_financial(db_info: dict,
                                       table_name: str = "sec_financial_data") -> int:
    """
    sec_financial_data 테이블에서 unique ticker 개수를 조회하여 반환하는 함수.
    """
    conn = pymysql.connect(
        host=db_info["host"],
        port=db_info["port"],
        user=db_info["user"],
        password=db_info["password"],
        database=db_info["database"],
        charset="utf8mb4"
    )

    try:
        query = f"SELECT DISTINCT ticker FROM {table_name};"
        df = pd.read_sql(query, conn)

        unique_ticker_count = df["ticker"].nunique()

        print(f"[INFO] Unique tickers in {table_name}: {unique_ticker_count}")
        return unique_ticker_count

    finally:
        conn.close()

# %%
import pymysql

count_unique_tickers_sec_financial(db_info)
# Out:
# [INFO] Unique tickers in sec_financial_data: 1571
# 1571

# %%
aapl_df.columns.tolist()
# Out:
# ['date',
#  'ticker',
#  'accounts_payable',
#  'accounts_receivable',
#  'accrued_liabilities',
#  'accumulated_depreciation',
#  'asset_turnover',
#  'capital_expenditures',
#  'cash',
#  'cost_of_revenue',
#  'current_assets',
#  'current_liabilities',
#  'current_ratio',
#  'days_inventory',
#  'days_receivables',
#  'debt_to_assets',
#  'debt_to_equity',
#  'deferred_revenue',
#  'depreciation_amortization',
#  'equity_multiplier',
#  'goodwill',
#  'gross_margin',
#  'gross_profit',
#  'income_tax_expense',
#  'intangible_assets',
#  'interest_expense',
#  'interest_income',
#  'inventory',
#  'inventory_turnover',
#  'long_term_debt',
#  'long_term_debt_current',
#  'net_income',
#  'net_margin',
#  'net_ppe',
#  'operating_expenses',
#  'operating_income',
#  'operating_margin',
#  'other_noncurrent_assets',
#  'pretax_income',
#  'quick_ratio',
#  'receivables_turnover',
#  'research_development',
#  'revenue',
#  'roa',
#  'roe',
#  'roic',
#  'short_term_debt',
#  'stockholders_equity',
#  'total_assets',
#  'total_liabilities']

# %%
# # 1) EDGAR 수집/정규화
# headers = {"User-Agent": "HoyoungPark Research <stox1224@email.com>"}
# facts   = fetch_company_facts( TICKER, headers=headers)
# parser  = CompanyFactsParser(facts)
# normal  = FinancialNormalizer(parser)
# edgar_df = normal.create_normalized_dataframe(period_type="quarterly")
#
# # 2) WRDS Validator
# db_info = {
#     "host": get_db_host(),
#     "port": 3307,
#     "user": "stox7412",
#     "password": "Apt106503!~",
#     "database": "investar",
# }
# validator = WRDSDataValidator(db_info)
#
# import sqlalchemy as sa
#
# # ① EDGAR 분기 DF 준비 (이미 갖고 계신 df: edgar_df)
# #    edgar_df.index = 분기 날짜, 컬럼에 'revenue' 포함
#
# # ② WRDS(us_fundq)에서 AAPL의 edate, ticker, saleq 로드
# db_info = {
#     "host": "192.168.0.230",
#     "port": 3307,
#     "user": "stox7412",
#     "password": "Apt106503!~",
#     "database": "investar",
# }

# %%
tickers = get_filtered_us_tickers()
# Out:
# 100%|██████████| 3774/3774 [00:04<00:00, 840.90it/s]
# 100%|██████████| 2745/2745 [00:02<00:00, 1050.06it/s]
# 100%|██████████| 294/294 [00:00<00:00, 1034.88it/s]
# 제외된 기업 수: 1812
# 남은 기업 수: 5001
# 티커 수: 5001

# %%
ticker_list = tickers[:10]
# Out:
# ['NVDA',
#  'AAPL',
#  'MSFT',
#  'AMZN',
#  'GOOGL',
#  'AVGO',
#  'GOOG',
#  'META',
#  'TSLA',
#  'NFLX']

# %%
# import pandas as pd
#
# # 1. 클라이언트 및 다운로더 설정
# user_agent = "PersonalResearch stox1224@email.com"
# client = SECAPIClient(user_agent, RateLimiter(10, 1.0))
# downloader = BulkDownloader(client, output_dir="./sec_data", max_workers=3)
#
# # 2. 다운로드할 기업 리스트
# # tickers = ['AAPL', 'MSFT', 'GOOGL', 'AMZN', 'TSLA', 'NVDA', 'META']
#
# # 3. 배치 다운로드 (자동으로 JSON 파일 저장)
# results = downloader.download_company_facts_batch(ticker_list)
#
# # 4. 각 기업별 데이터 처리
# all_financials = {}
#
# for ticker, company_facts in results.items():
#     headers = {"User-Agent": "HoyoungPark Research <stox1224@email.com>"}
#     facts   = fetch_company_facts(ticker, headers=headers)
#     parser  = CompanyFactsParser(facts)
#     normal  = FinancialNormalizer(parser)
#     edgar_df = normal.create_normalized_dataframe(period_type="quarterly")
#
#
#     parser = CompanyFactsParser(company_facts)
#     normalizer = FinancialNormalizer(parser)
#
#     # 재무데이터 정규화
#     df = normalizer.create_normalized_dataframe(period_type='quarterly')
#     df_billions = normalizer.convert_to_billions(df)
#
#     all_financials[ticker] = df_billions
#
#     # 개별 CSV 저장
#     # normalizer.export_to_csv(df_billions, f'{ticker}_financials.csv')
#
# print(f"총 {len(all_financials)}개 기업 데이터 수집 완료")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 5
#       3 # 1. 클라이언트 및 다운로더 설정
#       4 user_agent = "PersonalResearch stox1224@email.com"
# ----> 5 client = SECAPIClient(user_agent, RateLimiter(10, 1.0))
#       6 downloader = BulkDownloader(client, output_dir="./sec_data", max_workers=3)
#       8 # 2. 다운로드할 기업 리스트
#       9 # tickers = ['AAPL', 'MSFT', 'GOOGL', 'AMZN', 'TSLA', 'NVDA', 'META']
#      10
#      11 # 3. 배치 다운로드 (자동으로 JSON 파일 저장)
#
# NameError: name 'SECAPIClient' is not defined

# %%
TICKER = "GLW"   # ← 여기만 바꾸면 전체가 따라옵니

# 1) EDGAR 수집/정규화
headers = {"User-Agent": "HoyoungPark Research <stox1224@email.com>"}
facts   = fetch_company_facts( TICKER, headers=headers)
parser  = CompanyFactsParser(facts)
normal  = FinancialNormalizer(parser)
edgar_df = normal.create_normalized_dataframe(period_type="quarterly")

# 2) WRDS Validator
db_info = {
    "host": get_db_host(),
    "port": 3307,
    "user": "stox7412",
    "password": "Apt106503!~",
    "database": "investar",
}
validator = WRDSDataValidator(db_info)

# 3) 결합/보완 실행 (핵심: table_name='us_fundq', date_col='edate')
result_df = validator.validate_and_fill_improved(
    edgar_df=edgar_df,
    ticker= TICKER,
    table_name="us_fundq",   # 당신 DB 테이블
    days_tolerance=15,
    verbose=True,
    ticker_col="ticker",     # 당신 DB 컬럼
    date_col="edate"         # 당신 DB 컬럼
)

import sqlalchemy as sa

# ① EDGAR 분기 DF 준비 (이미 갖고 계신 df: edgar_df)
#    edgar_df.index = 분기 날짜, 컬럼에 'revenue' 포함

# ② WRDS(us_fundq)에서 AAPL의 edate, ticker, saleq 로드
db_info = {
    "host": "192.168.0.230",
    "port": 3307,
    "user": "stox7412",
    "password": "Apt106503!~",
    "database": "investar",
}
df_wrds = fetch_wrds_fundq_sample(
    db_info, ticker=TICKER , columns=["edate", "ticker", "saleq"], table_name="US_fundq"
)

# ③ 결측 보완 + 단위 정합
filled_df = fill_revenue_with_wrds(
    edgar_df=edgar_df,
    wrds_df=df_wrds,
    wrds_value_col="saleq",     # WRDS의 분기 매출 컬럼명
    days_tolerance=20,          # 분기말 근접 허용일
    verbose=True
)

print("\n[CHECK] revenue NaN:")
print("  before:", edgar_df["revenue"].isna().sum())
print("  after :", filled_df["revenue"].isna().sum())

if filled_df.empty:
    print("⚠ filled_df가 비어 있습니다 → result_df를 target_df로 대체합니다.")
    target_df = result_df.copy()
else:
    print("✓ filled_df가 유효합니다 → target_df에 filled_df를 사용합니다.")
    target_df = filled_df.copy()

from sec_data_pipeline.parsers.financial_normalizer import FinancialNormalizer


# parser는 EDGAR 데이터를 읽어온 CompanyFactsParser 등의 인스턴스
normalizer = FinancialNormalizer(parser=None)  # parser가 필요 없으면 None으로 두세요


# 1) 기본 추정: income_tax_expense / pretax_income
est = (filled_df.get('income_tax_expense') / filled_df.get('pretax_income'))

# 2) 이상치/음수/무한대 정리
est = est.replace([np.inf, -np.inf], np.nan)
# 적자 구간(pretax_income <= 0)은 추정치 제거
est = est.mask((filled_df.get('pretax_income') <= 0), np.nan)
# 0~0.5로 클리핑(50% 이상은 보통 이상치)
est = est.clip(lower=0.0, upper=0.3)

# 3) 결측 보강: 최근 값으로 보간 + 기본값 대체
# est = est.ffill().fillna(0.21)

# filled_df['tax_rate'] = 0.21
ratio = normal.calculate_financial_ratios(target_df)
# Out:
# ['NVDA',
#  'AAPL',
#  'MSFT',
#  'AMZN',
#  'GOOGL',
#  'AVGO',
#  'GOOG',
#  'META',
#  'TSLA',
#  'NFLX',
#  'COST',
#  'PLTR',
#  'ASML',
#  'AMD',
#  'CSCO',
#  'AZN',
#  'MU',
#  'TMUS',
#  'ISRG',
#  'SHOP',
#  'PEP',
#  'AMAT',
#  'LRCX',
#  'LIN',
#  'APP',
#  'AMGN',
#  'QCOM',
#  'INTC',
#  'PDD',
#  'BKNG',
#  'GILD',
#  'KLAC',
#  'TXN',
#  'ARM',
#  'ADBE',
#  'PANW',
#  'CRWD',
#  'ADI',
#  'SNY',
#  'HON',
#  'VRTX',
#  'MELI',
#  'ADP',
#  'SBUX',
#  'CMCSA',
#  'NTES',
#  'ORLY',
#  'DASH',
#  'REGN',
#  'CDNS',
#  'MAR',
#  'SNPS',
#  'CTAS',
#  'MNST',
#  'MDLZ',
#  'MRVL',
#  'ABNB',
#  'CSX',
#  'ADSK',
#  'WDAY',
#  'IDXX',
#  'FTNT',
#  'TRI',
#  'ROST',
#  'PYPL',
#  'STX',
#  'WBD',
#  'ALNY',
#  'ARGX',
#  'DDOG',
#  'PCAR',
#  'WDC',
#  'EA',
#  'MSTR',
#  'BKR',
#  'NXPI',
#  'ROP',
#  'FER',
#  'JD',
#  'ZS',
#  'FAST',
#  'TCOM',
#  'SYM',
#  'TTWO',
#  'INSM',
#  'MPWR',
#  'FANG',
#  'AXON',
#  'CCEP',
#  'BIDU',
#  'PAYX',
#  'TEAM',
#  'CPRT',
#  'EBAY',
#  'CTSH',
#  'ONC',
#  'KDP',
#  'GEHC',
#  'CRWV',
#  'RYAAY',
#  'KMB',
#  'FISV',
#  'NTRA',
#  'SNDK',
#  'UAL',
#  'EXPE',
#  'VRSK',
#  'KHC',
#  'CSGP',
#  'ERIC',
#  'VOD',
#  'TSCO',
#  'ODFL',
#  'MCHP',
#  'FSLR',
#  'EXE',
#  'MDB',
#  'BIIB',
#  'CRDO',
#  'TER',
#  'CHTR',
#  'ZM',
#  'ALAB',
#  'DXCM',
#  'BNTX',
#  'VRSN',
#  'ULTA',
#  'PODD',
#  'RPRX',
#  'RKLB',
#  'CYBR',
#  'NBIS',
#  'NTAP',
#  'ESLT',
#  'DLTR',
#  'GRAB',
#  'FLEX',
#  'FWONK',
#  'LULU',
#  'CASY',
#  'SSNC',
#  'UTHR',
#  'INCY',
#  'PTC',
#  'LITE',
#  'SATS',
#  'CHKP',
#  'ASTS',
#  'ILMN',
#  'LI',
#  'ON',
#  'SMCI',
#  'GMAB',
#  'TRMB',
#  'GFS',
#  'EXAS',
#  'RIVN',
#  'TTD',
#  'CDW',
#  'CHRW',
#  'LOGI',
#  'WWD',
#  'MEDP',
#  'FTAI',
#  'PSKY',
#  'HOLX',
#  'GEN',
#  'JBHT',
#  'NTNX',
#  'DKNG',
#  'COO',
#  'WMG',
#  'RVMD',
#  'ROIV',
#  'NBIX',
#  'OKTA',
#  'HTHT',
#  'DPZ',
#  'GH',
#  'ROKU',
#  'FFIV',
#  'AVAV',
#  'TEM',
#  'DOCU',
#  'FOX',
#  'BBIO',
#  'FOXA',
#  'MDGL',
#  'NDSN',
#  'NXT',
#  'ICLR',
#  'WYNN',
#  'SMMT',
#  'IONS',
#  'LECO',
#  'AKAM',
#  'VNOM',
#  'ASND',
#  'KTOS',
#  'ZBRA',
#  'JKHY',
#  'BSY',
#  'MTSI',
#  'PAA',
#  'VTRS',
#  'TXRH',
#  'EXEL',
#  'HAS',
#  'BILI',
#  'ENTG',
#  'CART',
#  'TSEM',
#  'JAZZ',
#  'ENSG',
#  'BMRN',
#  'COKE',
#  'RNA',
#  'MANH',
#  'ALGN',
#  'SAIL',
#  'BZ',
#  'CELH',
#  'TECH',
#  'STRL',
#  'MKSI',
#  'RMBS',
#  'MRNA',
#  'RGEN',
#  'NWSA',
#  'FYBR',
#  'SWKS',
#  'ABVX',
#  'LSCC',
#  'PEGA',
#  'IDCC',
#  'MBLY',
#  'POOL',
#  'HQY',
#  'CPB',
#  'FIVE',
#  'DRS',
#  'TIGO',
#  'NVMI',
#  'TTEK',
#  'HSIC',
#  'PPC',
#  'AAL',
#  'MORN',
#  'RGTI',
#  'HALO',
#  'APA',
#  'OTEX',
#  'NUVL',
#  'CORT',
#  'SANM',
#  'DOX',
#  'SFD',
#  'AMKR',
#  'TTAN',
#  'CYTK',
#  'APPF',
#  'DUOL',
#  'IESC',
#  'PCTY',
#  'SFM',
#  'MTCH',
#  'MASI',
#  'LYFT',
#  'QRVO',
#  'AEIS',
#  'GSAT',
#  'DBX',
#  'AAON',
#  'CFLT',
#  'MNDY',
#  'LKQ',
#  'AUR',
#  'AXSM',
#  'OLLI',
#  'CHDN',
#  'BRKR',
#  'SITM',
#  'VFS',
#  'SAIA',
#  'SOLS',
#  'FROG',
#  'WING',
#  'MRUS',
#  'RYTM',
#  'FIGR',
#  'CAI',
#  'NTSK',
#  'TTMI',
#  'DSGX',
#  'WAY',
#  'SIRI',
#  'LNW',
#  'COGT',
#  'MMYT',
#  'CDTX',
#  'GTLB',
#  'QMMM',
#  'GDS',
#  'GLBE',
#  'PTCT',
#  'SMTC',
#  'PCVX',
#  'BTSG',
#  'SRAD',
#  'MAT',
#  'RDNT',
#  'NICE',
#  'ARWR',
#  'CGNX',
#  'EXLS',
#  'LFUS',
#  'KRYS',
#  'LIF',
#  'CWST',
#  'RRR',
#  'URBN',
#  'IRTC',
#  'CRUS',
#  'ROAD',
#  'MIDD',
#  'BLLN',
#  'LBRDK',
#  'NXST',
#  'PTGX',
#  'RGC',
#  'OLED',
#  'CVLT',
#  'NWS',
#  'UFPI',
#  'TGTX',
#  'WFRD',
#  'CHRD',
#  'LEGN',
#  'MMSI',
#  'WIX',
#  'REYN',
#  'ATAT',
#  'CRSP',
#  'DOOO',
#  'QLYS',
#  'OS',
#  'BCPC',
#  'LLYVK',
#  'SOUN',
#  'TMDX',
#  'PI',
#  'GNTX',
#  'OPCH',
#  'SHC',
#  'APGE',
#  'WGS',
#  'ALKS',
#  'ALGM',
#  'KYMR',
#  'LGN',
#  'CAMT',
#  'CAR',
#  'IEP',
#  'PONY',
#  'CVCO',
#  'CCC',
#  'MZTI',
#  'PRAX',
#  'NAMS',
#  'CELC',
#  'ADMA',
#  'OSIS',
#  'OMAB',
#  'CZR',
#  'LSTR',
#  'AKRO',
#  'VSAT',
#  'BLTE',
#  'LAUR',
#  'ITRI',
#  'PLBL',
#  'LOPE',
#  'RUN',
#  'CROX',
#  'COMM',
#  'VSEC',
#  'LCID',
#  'EOSE',
#  'CRNX',
#  'FELE',
#  'SRRK',
#  'CNTA',
#  'ACLX',
#  'GRAL',
#  'IMVT',
#  'MRCY',
#  'DORM',
#  'INDV',
#  'ACAD',
#  'FORM',
#  'CLBT',
#  'CALM',
#  'SLAB',
#  'VKTX',
#  'LGND',
#  'NOVT',
#  'SKYW',
#  'SAIC',
#  'VICR',
#  'KC',
#  'LNTH',
#  'AMRX',
#  'VCYT',
#  'VIAV',
#  'FTDR',
#  'AMBA',
#  'PSMT',
#  'AVT',
#  'ALHC',
#  'VRNS',
#  'PLXS',
#  'DLO',
#  'CRVL',
#  'POWL',
#  'ARQT',
#  'ICUI',
#  'GLNG',
#  'NAVN',
#  'MIRM',
#  'VEON',
#  'CGON',
#  'PAGP',
#  'ENPH',
#  'EXPO',
#  'PATK',
#  'AGYS',
#  'WSHP',
#  'IRON',
#  'MLCO',
#  'FRSH',
#  'LIVN',
#  'VRRM',
#  'CARG',
#  'BL',
#  'INTA',
#  'XENE',
#  'MYRG',
#  'KYIV',
#  'TARS',
#  'MLYS',
#  'JOYY',
#  'IPGP',
#  'TLX',
#  'ATEC',
#  'KNSA',
#  'RARE',
#  'TVTX',
#  'GTX',
#  'FIZZ',
#  'TENB',
#  'VERX',
#  'BRZE',
#  'RUSHA',
#  'SPSC',
#  'APPN',
#  'IDYA',
#  'ONDS',
#  'ASO',
#  'ADPT',
#  'ARLP',
#  'FLNC',
#  'EEFT',
#  'FOLD',
#  'AAPG',
#  'PRVA',
#  'COCO',
#  'SHOO',
#  'DJT',
#  'VRDN',
#  'GTM',
#  'CSQ',
#  'DYN',
#  'XMTR',
#  'COLM',
#  'CPRX',
#  'SIMO',
#  'NCNO',
#  'HURN',
#  'PTON',
#  'VC',
#  'LQDA',
#  'DNLI',
#  'AVPT',
#  'HTFL',
#  'FLY',
#  'FRPT',
#  'PLUG',
#  'HWKN',
#  'MEOH',
#  'RELY',
#  'BLKB',
#  'STRC',
#  'SLNO',
#  'IAC',
#  'APLS',
#  'HSAI',
#  'TERN',
#  'SUPN',
#  'NSIT',
#  'WDFC',
#  'ALRM',
#  'CHA',
#  'PTRN',
#  'QUBT',
#  'SYNA',
#  'OCUL',
#  'LFST',
#  'IPAR',
#  'UPWK',
#  'MGRC',
#  'ACLS',
#  'EWTX',
#  'CHEF',
#  'WRD',
#  'BEAM',
#  'HCM',
#  'WB',
#  'FA',
#  'TXG',
#  'SPNS',
#  'GT',
#  'VNET',
#  'PLUS',
#  'DRVN',
#  'ODD',
#  'HUBG',
#  'CAKE',
#  'PINC',
#  'EXTR',
#  'MENS',
#  'PGNY',
#  'FORTY',
#  'RUM',
#  'KLIC',
#  'RXRX',
#  'SBLK',
#  'SYRE',
#  'ALKT',
#  'EYE',
#  'AVDL',
#  'GRFS',
#  'CSGS',
#  'ZLAB',
#  'ADUS',
#  'CNXC',
#  'SONO',
#  'XRAY',
#  'DBVT',
#  'SGRY',
#  'PTEN',
#  'TRMD',
#  'VCEL',
#  'ACMR',
#  'AUPH',
#  'ZBIO',
#  'IQ',
#  'MGNI',
#  'OSW',
#  'DIOD',
#  'DGNX',
#  'SEDG',
#  'JANX',
#  'GPCR',
#  'MESO',
#  'FWONA',
#  'GLPG',
#  'OLMA',
#  'IBRX',
#  'HRMY',
#  'PAYO',
#  'SRPT',
#  'IMCR',
#  'BATRK',
#  'ESTA',
#  'SMPL',
#  'SION',
#  'LBTYA',
#  'ZYME',
#  'SBET',
#  'LLYVA',
#  'NTCT',
#  'PENN',
#  'AVAH',
#  'SEZL',
#  'HBNB',
#  'ATRC',
#  'QDEL',
#  'WBTN',
#  'TWST',
#  'LMAT',
#  'DNTH',
#  'VERA',
#  'ANIP',
#  'NN',
#  'POWI',
#  'IOSP',
#  'NVTS',
#  'CECO',
#  'STRA',
#  'PRCT',
#  'PRDO',
#  'PAHC',
#  'PRGS',
#  'MCRI',
#  'TRIP',
#  'INOD',
#  'UFPT',
#  'JJSF',
#  'MAZE',
#  'VECO',
#  'CLDX',
#  'AZTA',
#  'QURE',
#  'CMPR',
#  'MCW',
#  'FBYD',
#  'HLMN',
#  'ANDE',
#  'NRIX',
#  'IRDM',
#  'IAS',
#  'JAMF',
#  'STOK',
#  'LBTYK',
#  'LUNR',
#  'SNDX',
#  'REAL',
#  'LASR',
#  'FLYW',
#  'IMNM',
#  'CSIQ',
#  'ALVO',
#  'OMCL',
#  'AGIO',
#  'LZ',
#  'CLMT',
#  'MNKD',
#  'BLBD',
#  'HTZ',
#  'AMLX',
#  'ENVX',
#  'NEGG',
#  'PHVS',
#  'TILE',
#  'INVA',
#  'ATRO',
#  'WEN',
#  'NEO',
#  'CENTA',
#  'BELFB',
#  'JBLU',
#  'UPB',
#  'DGII',
#  'AAOI',
#  'EVCM',
#  'NEXT',
#  'ACHC',
#  'FIVN',
#  'HROW',
#  'PLTK',
#  'PCT',
#  'WERN',
#  'MCHPP',
#  'WINA',
#  'UNIT',
#  'TNDM',
#  'ORKA',
#  'CNXN',
#  'WLDN',
#  'DXPE',
#  'IMKTA',
#  'ROCK',
#  'TRVI',
#  'NWL',
#  'CERT',
#  'ARCB',
#  'NESR',
#  'ICFI',
#  'NSSC',
#  'BCRX',
#  'COLL',
#  'MREO',
#  'TNGX',
#  'MBX',
#  'NVCR',
#  'MOMO',
#  'VITL',
#  'KMTS',
#  'ARHS',
#  'RLAY',
#  'ARDX',
#  'AMSC',
#  'LILAK',
#  'BBNX',
#  'OXLC',
#  'AFYA',
#  'STGW',
#  'KARO',
#  'AMPL',
#  'ATAI',
#  'GCT',
#  'RAPP',
#  'SHLS',
#  'ADEA',
#  'TRS',
#  'PZZA',
#  'MXL',
#  'DVAX',
#  'QQQX',
#  'PLAB',
#  'PSNY',
#  'IMTX',
#  'HCSG',
#  'ALGT',
#  'XPEL',
#  'TSAT',
#  'AHCO',
#  'OUST',
#  'AXGN',
#  'NEOG',
#  'STAA',
#  'BLFS',
#  'PGEN',
#  'BGM',
#  'URGN',
#  'ZD',
#  'ELVN',
#  'DSGR',
#  'SDGR',
#  'HIMX',
#  'AMPH',
#  'STRF',
#  'TSHA',
#  'SEPN',
#  'PSIX',
#  'CLOV',
#  'GIII',
#  'VRNT',
#  'WVE',
#  'PSEC',
#  'XNCR',
#  'NKTR',
#  'HSII',
#  'EYPT',
#  'KOD',
#  'PRCH',
#  'INBX',
#  'OCSL',
#  'OPRA',
#  'HDL',
#  'CVAC',
#  'LGIH',
#  'FTRE',
#  'XERS',
#  'CCEC',
#  'SSII',
#  'IRMD',
#  'MNMD',
#  'TBLA',
#  'TYRA',
#  'PHAR',
#  'CSTL',
#  'ASTH',
#  'CRAI',
#  'ANAB',
#  'EVO',
#  'ARRY',
#  'ORIC',
#  'UCTT',
#  'PVLA',
#  'MVST',
#  'OCS',
#  'MGIC',
#  'TLRY',
#  'COHU',
#  'THRM',
#  'SBGI',
#  'FWRG',
#  'STRK',
#  'MLKN',
#  'KDK',
#  'NVAX',
#  'ABCL',
#  'EVLV',
#  'GO',
#  'PDFS',
#  'HLIT',
#  'PHAT',
#  'DMLP',
#  'UPBD',
#  'OMDA',
#  'SVRA',
#  'BRKRP',
#  'GLUE',
#  'CRTO',
#  'OPK',
#  'IART',
#  'MDXG',
#  'CRCT',
#  'NBTX',
#  'TASK',
#  'BCAX',
#  'KURA',
#  'ASTE',
#  'PENG',
#  'RPD',
#  'PLPC',
#  'PCRX',
#  'PSNL',
#  'NTLA',
#  'BBOT',
#  'IOVA',
#  'NMFC',
#  'RDWR',
#  'MLTX',
#  'IMOS',
#  'SLDP',
#  'PNTG',
#  'RZLV',
#  'DAWN',
#  'EH',
#  'BTSGU',
#  'MRVI',
#  'BTQ',
#  'TBPH',
#  'ULCC',
#  'NNNN',
#  'GDRX',
#  'FLGT',
#  'GOGO',
#  'TDUP',
#  'WOOF',
#  'CRON',
#  'AVBP',
#  'SANA',
#  'LENZ',
#  'EVER',
#  'LQDT',
#  'DAKT',
#  'GHRS',
#  'CDNA',
#  'SPRY',
#  'AEBI',
#  'BBSI',
#  'ALNT',
#  'PLSE',
#  'SCSC',
#  'STRD',
#  'RIGL',
#  'GLIBK',
#  'VIR',
#  'CHY',
#  'IMSR',
#  'INMD',
#  'CMPX',
#  'RZLT',
#  'ESPR',
#  'CCOI',
#  'VERB',
#  'LOT',
#  'ERAS',
#  'RCAT',
#  'RUSHB',
#  'SLRC',
#  'SIBN',
#  'LBRDA',
#  'NUTX',
#  'JBSS',
#  'ODP',
#  'GLDD',
#  'AHG',
#  'AVO',
#  'ABUS',
#  'RAPT',
#  'CHI',
#  'SWIM',
#  'MRTN',
#  'WLFC',
#  'HPK',
#  'ITRN',
#  'BLDP',
#  'BJRI',
#  'LMB',
#  'QNST',
#  'AMWD',
#  'EMBC',
#  'PACB',
#  'VSTM',
#  'SIFY',
#  'ARVN',
#  'MATW',
#  'APOG',
#  'GDEN',
#  'RDVT',
#  'ALMS',
#  'INDI',
#  'LAES',
#  'HSTM',
#  'GOSS',
#  'ERII',
#  'VALN',
#  'TH',
#  'SCHL',
#  'REPL',
#  'VTYX',
#  'CTKB',
#  'AQST',
#  'GDYN',
#  'UDMY',
#  'CRMD',
#  'GERN',
#  'MYGN',
#  'OLPX',
#  'GLOO',
#  'SSYS',
#  'FWDI',
#  'GILT',
#  'NTGR',
#  'SERV',
#  'INNV',
#  'CRESY',
#  'SKYT',
#  'CCCX',
#  'FDUS',
#  'RR',
#  'ADSE',
#  'LXEO',
#  'GPRE',
#  'TIPT',
#  'ATXS',
#  'CTMX',
#  'GYRE',
#  'CGEM',
#  'SNCY',
#  'KE',
#  'SUPX',
#  'FWRD',
#  'WYFI',
#  'DNUT',
#  'RGNX',
#  'SENEA',
#  'GRPN',
#  'PRME',
#  'KALV',
#  'LIND',
#  'ORGO',
#  'OMER',
#  'ASPI',
#  'CRVS',
#  'HEPS',
#  'DMIIU',
#  'CRSR',
#  'YDES',
#  'NOVTU',
#  'DSP',
#  'LINC',
#  'DJCO',
#  'AEHR',
#  'BVS',
#  'SABR',
#  'CBLL',
#  'ANNX',
#  'OFIX',
#  'CCCXU',
#  'TBLD',
#  'PROK',
#  'APEI',
#  'DVLT',
#  'AIOT',
#  'IVVD',
#  'AEVA',
#  'CBRL',
#  'FULC',
#  'AOSL',
#  'ADTN',
#  'ECX',
#  'POET',
#  'IVA',
#  'FOXF',
#  'DCBO',
#  'FDMT',
#  'MGTX',
#  'ACDC',
#  'BWMN',
#  'SHEN',
#  'HTLD',
#  'CGNT',
#  'LWLG',
#  'AIP',
#  'KRNT',
#  ...]

# %% [markdown]
# ### Billions 단위로 변환

# %%
df_billions = normalizer.convert_to_billions(df)
print(df_billions[['revenue', 'net_income']].tail(8))

# %% [markdown]
# ### TTM (Trailing Twelve Months) 계산

# %%
df_ttm = normalizer.calculate_ttm(df_billions, columns=['revenue', 'net_income'])
print(df_ttm[['revenue', 'revenue_ttm']].tail(8))

# %% [markdown]
# # 2. 다수 기업 재무제표 받기

# %%
from collectors import SECAPIClient, RateLimiter, BulkDownloader
from parsers import CompanyFactsParser, FinancialNormalizer
import pandas as pd

# 1. 클라이언트 및 다운로더 설정
user_agent = "PersonalResearch stox1224@email.com"
client = SECAPIClient(user_agent, RateLimiter(10, 1.0))
downloader = BulkDownloader(client, output_dir="./sec_data", max_workers=3)

# 2. 다운로드할 기업 리스트
tickers = ['AAPL', 'MSFT', 'GOOGL', 'AMZN', 'TSLA', 'NVDA', 'META']

# 3. 배치 다운로드 (자동으로 JSON 파일 저장)
results = downloader.download_company_facts_batch(tickers)

# 4. 각 기업별 데이터 처리
all_financials = {}

for ticker, company_facts in results.items():
    parser = CompanyFactsParser(company_facts)
    normalizer = FinancialNormalizer(parser)

    # 재무데이터 정규화
    df = normalizer.create_normalized_dataframe(period_type='quarterly')
    df_billions = normalizer.convert_to_billions(df)

    all_financials[ticker] = df_billions

    # 개별 CSV 저장
    normalizer.export_to_csv(df_billions, f'{ticker}_financials.csv')

print(f"총 {len(all_financials)}개 기업 데이터 수집 완료")

# %% [markdown]
# # 3. 특정 재무항목만 추출

# %%
revenue_comparison = {}

for ticker, company_facts in results.items():
    parser = CompanyFactsParser(company_facts)
    normalizer = FinancialNormalizer(parser)

    # Revenue만 추출
    revenue_series = normalizer.normalize_single_item('revenue', period_type='quarterly')

    if revenue_series is not None:
        revenue_comparison[ticker] = revenue_series / 1_000_000_000  # Billions

# DataFrame으로 변환
revenue_df = pd.DataFrame(revenue_comparison)
print("\n최근 8분기 매출 비교 (Billions):")
print(revenue_df.tail(8))

# YoY 성장률
growth_df = revenue_df.pct_change(periods=4) * 100
print("\nYoY 매출 성장률 (%):")
print(growth_df.tail(4))

# %% [markdown]
# # 4. 사용 가능한 재무 항목

# %%
# 추출 가능한 표준 재무 항목들
available_items = [
    'revenue',              # 매출
    'net_income',           # 순이익
    'operating_income',     # 영업이익
    'gross_profit',         # 매출총이익
    'total_assets',         # 총자산
    'current_assets',       # 유동자산
    'total_liabilities',    # 총부채
    'current_liabilities',  # 유동부채
    'stockholders_equity',  # 자본
    'cash',                 # 현금
    'long_term_debt',       # 장기부채
    'cost_of_revenue',      # 매출원가
    'operating_expenses',   # 영업비용
    'research_development', # 연구개발비
    'earnings_per_share',   # 주당순이익
]

# 특정 항목만 추출
for item in ['revenue', 'net_income', 'total_assets']:
    series = normalizer.normalize_single_item(item, period_type='quarterly')
    print(f"\n{item}:")
    print(series.tail(4))

# %% [markdown]
# # 5. 재무비율 계산

# %%
# 데이터 준비
df = normalizer.create_normalized_dataframe(period_type='quarterly')

# 재무비율 자동 계산
df_ratios = normalizer.calculate_financial_ratios(df)

# 계산되는 비율들:
# - profit_margin: 순이익률
# - operating_margin: 영업이익률
# - current_ratio: 유동비율
# - debt_to_equity: 부채비율
# - roe: 자기자본이익률
# - roa: 총자산이익률

print(df_ratios[['revenue', 'net_income', 'profit_margin']].tail(8))

# %% [markdown]
# # 6. 성장률 분석

# %%
df_billions = normalizer.convert_to_billions(df)

# YoY 성장률 계산
df_growth = normalizer.calculate_growth_rates(
    df_billions,
    columns=['revenue', 'net_income'],
    periods=4  # 4분기 = YoY
)

print(df_growth[['revenue', 'revenue_yoy_growth']].tail(8))

# %% [markdown]
# # 7. 진행상황 모니터링

# %%
# 콜백 함수 정의
def on_download_complete(ticker, data, index, total):
    if data:
        entity_name = data.get('entityName', 'Unknown')
        print(f"[{index}/{total}] {ticker}: {entity_name} - 완료")
    else:
        print(f"[{index}/{total}] {ticker}: 실패")

# 콜백과 함께 다운로드
results = downloader.download_company_facts_batch(
    tickers=['AAPL', 'MSFT', 'GOOGL'],
    callback=on_download_complete
)

# %% [markdown]
# # 8. 중단된 다운로드 재개

# %%
# 이미 다운로드된 파일은 건너뛰기
remaining_results = downloader.resume_download(tickers)

# %% [markdown]
# # 9. 다운로드 리포트 생성

# %%
# 다운로드 후 리포트 생성
downloader.create_download_report(results, "download_report.json")

# %% [markdown]
# # 10. 실전 예제: S&P 500 상위 기업 분석

# %%
# Tech Giants
tech_giants = ['AAPL', 'MSFT', 'GOOGL', 'AMZN', 'META', 'NVDA', 'TSLA']

# 다운로드
downloader = BulkDownloader(client, output_dir="./tech_giants", max_workers=5)
results = downloader.download_company_facts_batch(tech_giants)

# Revenue 비교 분석
revenue_data = {}
for ticker, facts in results.items():
    parser = CompanyFactsParser(facts)
    normalizer = FinancialNormalizer(parser)
    revenue = normalizer.normalize_single_item('revenue', period_type='quarterly')
    if revenue is not None:
        revenue_data[ticker] = revenue / 1e9  # Billions

# 비교 DataFrame
comparison = pd.DataFrame(revenue_data)
print("\nTech Giants 최근 매출 비교 (Billions):")
print(comparison.tail(8))

# 시각화 (선택사항)
import matplotlib.pyplot as plt
comparison.tail(12).plot(figsize=(12, 6))
plt.title('Tech Giants Revenue Comparison (Last 12 Quarters)')
plt.ylabel('Revenue (Billions USD)')
plt.legend(loc='best')
plt.grid(True)
plt.savefig('tech_giants_revenue.png')
