# %%
import pandas as pd
from sqlalchemy import create_engine
from statsmodels.tsa.statespace.sarimax import SARIMAX
import matplotlib.pyplot as plt
import numpy as np
from sqlalchemy import create_engine

import warnings
warnings.filterwarnings("ignore")

# %%
def forecast_yoy_growth_auto(df, col, forecast_steps=12, seasonal=True):
    """
    최적 SARIMAX 파라미터를 자동 탐색하여 수출입 증가율 예측.
    월별 데이터가 72개월 미만일 경우 예측을 수행하지 않습니다.

    Parameters:
        df (pd.DataFrame): 'period' (datetime), 예측 대상 컬럼 포함
        col (str): 예측 컬럼 (예: 'expDlr_yoy')
        forecast_steps (int): 예측 기간 (월 기준 12, 분기 기준 4)
        seasonal (bool): 계절성 사용 여부
    """
    df = df[['period', col]].dropna().copy()
    df = df.set_index('period').sort_index()
    ts = df[col]

    # ✅ 데이터 길이 검사
    if forecast_steps > 4 and len(ts) < 72:
        print("⚠️ 월 데이터가 6년치(72개월) 미만입니다. 충분한 데이터 기간 기준에 미달합니다.")
        return None
    elif forecast_steps <= 4 and len(ts) < 16:
        print("⚠️ 분기 데이터가 4년치(16분기) 미만입니다. 충분한 데이터 기간 기준에 미달합니다.")
        return None

    # SARIMA 파라미터 범위
    p = d = q = range(0, 2)
    pdq = [(x, y, z) for x in p for y in d for z in q]
    seasonal_pdq = [(x, y, z) for x in p for y in d for z in q]
    seasonal_period = 12 if forecast_steps > 4 else 4

    best_model, best_order, best_seasonal_order = sarimax_grid_search(ts, pdq, seasonal_pdq, seasonal_period)

    # 예측
    future_index = pd.date_range(
        start=ts.index[-1] + pd.offsets.DateOffset(months=1 if seasonal_period == 12 else 3),
        periods=forecast_steps,
        freq='M' if seasonal_period == 12 else 'Q'
    )

    forecast = best_model.forecast(steps=forecast_steps)
    forecast.index = future_index

    # 시각화
    plt.figure(figsize=(12, 6))
    plt.plot(ts.index, ts, label='Actual')
    plt.plot(forecast.index, forecast, label='Forecast', linestyle='--', color='red')
    plt.title(f"{col} 예측 (Auto SARIMAX)")
    plt.ylabel('YoY Growth')
    plt.xticks(rotation=45)
    plt.legend()
    plt.tight_layout()
    plt.show()

# %%
def load_monthly_trade_data_from_db():
    # host = '192.168.0.230'
    host = 'hystox74.synology.me'
    port = 3307
    user = 'stox7412'
    password = 'Apt106503!~'
    database = 'investar'
    engine = create_engine(f'mysql+pymysql://{user}:{password}@{host}:{port}/{database}')
    query = "SELECT * FROM trade_data_monthly"
    return pd.read_sql(query, con=engine)


def forecast_yoy_growth_auto_with_ci(df, col, hs_code, forecast_steps=12):
    warnings.filterwarnings("ignore")
    df = df[df['root_hs_code'] == hs_code].copy()

      # ✅ period 컬럼 자동 대체
    if 'period' not in df.columns:
        if 'date' in df.columns:
            df = df.rename(columns={'date': 'period'})
        elif 'year_month' in df.columns:
            df = df.rename(columns={'year_month': 'period'})
        elif df.index.name == 'period':
            df = df.reset_index()
        else:
            print(f"❌ {hs_code} | 누락된 컬럼: ['period'] 대체 불가")
            return None, None

    required_cols = ['period', col, 'expDlr', 'impDlr']
    missing_cols = [c for c in required_cols if c not in df.columns]
    if missing_cols:
        print(f"❌ {hs_code} | 누락된 컬럼: {missing_cols}")
        return None, None

    df = df[required_cols].dropna()
    df['period'] = pd.to_datetime(df['period'])
    df = df.set_index('period').sort_index()

    ts = df[col].astype(float)
    if forecast_steps > 4 and len(ts) < 72:
        print(f"⚠️ {hs_code}: 월 데이터가 6년치 미만입니다.")
        return None, None

    best_aic = np.inf
    best_order = None
    best_seasonal_order = None
    best_model = None

    p = d = q = range(0, 2)
    P = D = Q = range(0, 2)
    m = 12

    for order in [(p_, d_, q_) for p_ in p for d_ in d for q_ in q]:
        for seasonal_order in [(P_, D_, Q_, m) for P_ in P for D_ in D for Q_ in Q]:
            try:
                model = SARIMAX(ts,
                                order=order,
                                seasonal_order=seasonal_order,
                                enforce_stationarity=False,
                                enforce_invertibility=False)
                result = model.fit(disp=False)
                if result.aic < best_aic:
                    best_aic = result.aic
                    best_order = order
                    best_seasonal_order = seasonal_order
                    best_model = result
            except:
                continue

    if best_model is None:
        print(f"❌ {hs_code}: SARIMAX 모델 최적화 실패")
        return None, None

    forecast_result = best_model.get_forecast(steps=forecast_steps)
    pred_mean = forecast_result.predicted_mean
    conf_int = forecast_result.conf_int()

    future_index = pd.date_range(start=ts.index[-1] + pd.DateOffset(months=1), periods=forecast_steps, freq='M')

    forecast_df = pd.DataFrame({
        col + '_forecast': pred_mean.values,
        col + '_lower': conf_int.iloc[:, 0].values,
        col + '_upper': conf_int.iloc[:, 1].values
    }, index=future_index)

    print(f"✅ {hs_code}: 최적 모델 order={best_order}, seasonal_order={best_seasonal_order}, AIC={best_aic:.2f}")
    return forecast_df, df


def build_forecasted_series(base_df, forecast_df, col_name):
    full_df = pd.concat([base_df[[col_name]], forecast_df[[col_name + '_forecast']]], axis=0)

    full_df[col_name + '_forecast'] = pd.to_numeric(full_df[col_name + '_forecast'], errors='coerce')
    full_df[col_name + '_forecast'] = full_df[col_name + '_forecast'].replace([np.inf, -np.inf], np.nan)

    full_df[col_name + '_estimated'] = full_df[col_name + '_forecast'].shift(1) * (1 + full_df[col_name + '_forecast'])
    return full_df


def run_forecasting_pipeline(hs_code_list, max_hs_count=3):
    export_m_with_yoy = load_monthly_trade_data_from_db()
    hs_code_list = hs_code_list[:max_hs_count]
    result_list = []

    for hs_code in hs_code_list:
        print(f"📈 {hs_code} 예측 중...")
        for target_col in ['expDlr_yoy', 'impDlr_yoy']:
            forecast_df, base_df = forecast_yoy_growth_auto_with_ci(export_m_with_yoy, target_col, hs_code)

            if forecast_df is None or forecast_df.empty:
                print(f"⚠️ 예측 실패 또는 결과 없음 | hs_code={hs_code}, col={target_col}")
                continue

            full_df = build_forecasted_series(base_df, forecast_df, target_col)
            forecast_only = forecast_df.copy()
            forecast_only['hs_code'] = hs_code
            forecast_only['target_col'] = target_col
            forecast_only['date'] = forecast_only.index
            forecast_only = forecast_only.reset_index(drop=True)

            result_list.append(forecast_only)

    if not result_list:
        print("❌ 모든 예측이 실패하여 결과가 없습니다.")
        return pd.DataFrame()

    final_df = pd.concat(result_list, ignore_index=True)
    return final_df

def merge_forecast_with_actuals(forecast_df, trade_data_df):
    import pandas as pd

    # 복사 및 컬럼명 통일
    forecast_df = forecast_df.copy()
    forecast_df = forecast_df.rename(columns={'hs_code': 'root_hs_code'})

    forecast_df['period'] = pd.to_datetime(forecast_df['period'])

    # 예측 컬럼 존재 여부 확인
    forecast_cols = ['expDlr_yoy_forecast', 'impDlr_yoy_forecast']
    present_forecast_cols = [col for col in forecast_cols if col in forecast_df.columns]

    if not present_forecast_cols:
        raise KeyError("❌ forecast_df에 'expDlr_yoy_forecast' 또는 'impDlr_yoy_forecast' 컬럼이 없습니다.")

    # 📌 1. 예측 데이터 요약 (pivot 필요 없음)
    forecast_pivot = forecast_df[['period', 'root_hs_code'] + present_forecast_cols].drop_duplicates()

    # 📌 2. 무역 데이터 처리
    trade_data_df = trade_data_df.copy()
    trade_data_df['period'] = pd.to_datetime(
        trade_data_df['new_year'].astype(str) + '-' + trade_data_df['new_month'].astype(str) + '-01'
    )

    filtered_trade_data = trade_data_df[['period', 'root_hs_code', 'expDlr_yoy', 'impDlr_yoy', 'expDlr', 'impDlr']]

    # 📌 3. 예측과 실적 결합
    combined_df = pd.merge(
        filtered_trade_data,
        forecast_pivot,
        on=['period', 'root_hs_code'],
        how='outer'
    ).sort_values(['root_hs_code', 'period']).reset_index(drop=True)

    # 📌 4. 최종 YoY 생성
    combined_df['final_expDlr_yoy'] = combined_df['expDlr_yoy']
    if 'expDlr_yoy_forecast' in combined_df.columns:
        combined_df.loc[combined_df['final_expDlr_yoy'].isna(), 'final_expDlr_yoy'] = combined_df['expDlr_yoy_forecast']

    combined_df['final_impDlr_yoy'] = combined_df['impDlr_yoy']
    if 'impDlr_yoy_forecast' in combined_df.columns:
        combined_df.loc[combined_df['final_impDlr_yoy'].isna(), 'final_impDlr_yoy'] = combined_df['impDlr_yoy_forecast']

    # 📌 5. 자료형 정리
    combined_df['final_expDlr_yoy'] = pd.to_numeric(combined_df['final_expDlr_yoy'], errors='coerce')
    combined_df['final_impDlr_yoy'] = pd.to_numeric(combined_df['final_impDlr_yoy'], errors='coerce')

    # 📌 6. 12개월 전 실적 추출
    combined_df['expDlr_lag12'] = combined_df.groupby('root_hs_code')['expDlr'].shift(12)
    combined_df['impDlr_lag12'] = combined_df.groupby('root_hs_code')['impDlr'].shift(12)

    # 📌 7. 12개월 후 예측값 계산
    combined_df['expDlr_forecast_12m'] = combined_df['expDlr_lag12'] * (1 + combined_df['final_expDlr_yoy'])
    combined_df['impDlr_forecast_12m'] = combined_df['impDlr_lag12'] * (1 + combined_df['final_impDlr_yoy'])

    return combined_df

def pivot_forecast_df(forecast_df):
    # 피벗하여 target_col 기준으로 예측값을 컬럼화
    forecast_df = forecast_df.rename(columns={'hs_code': 'root_hs_code'})
    forecast_df['period'] = pd.to_datetime(forecast_df['period'])

    forecast_pivot = forecast_df.pivot_table(index=['period', 'root_hs_code'],
                                             columns='target_col',
                                             values='yoy_forecast').reset_index()

    # 컬럼 이름 정리
    forecast_pivot.columns.name = None
    forecast_pivot = forecast_pivot.rename(columns={
        'expDlr_yoy': 'expDlr_yoy_forecast',
        'impDlr_yoy': 'impDlr_yoy_forecast'
    })
    return forecast_pivot

def upload_forecast_to_db(df, db_info, table_name='trade_forecast_by_month'):
    """
    예측 결과 데이터를 MySQL(MariaDB)에 업로드하는 함수 (중복 시 대체)

    Parameters:
    - df (pd.DataFrame): 업로드할 데이터프레임
    - db_info (dict): DB 연결 정보. keys = ['host', 'port', 'user', 'password', 'database']
    - table_name (str): 업로드할 테이블 이름
    """
    try:
        # ✅ SQLAlchemy 엔진 생성
        engine = create_engine(
            f"mysql+pymysql://{db_info['user']}:{db_info['password']}@{db_info['host']}:{db_info['port']}/{db_info['database']}"
        )
        conn = engine.raw_connection()
        cursor = conn.cursor()

        # ✅ 테이블 생성 (없을 경우)
        create_table_query = f"""
        CREATE TABLE IF NOT EXISTS {table_name} (
            period DATE,
            root_hs_code VARCHAR(20),
            final_expDlr_yoy FLOAT,
            expDlr_forecast_12m FLOAT,
            PRIMARY KEY (period, root_hs_code)
        );
        """
        cursor.execute(create_table_query)

        # ✅ NaN 및 NaT, inf → None 변환 (모든 타입 안전하게 처리)
        df = df.astype(object).where(pd.notnull(df), None)

        # ✅ REPLACE INTO
        insert_query = f"""
        REPLACE INTO {table_name} (period, root_hs_code, final_expDlr_yoy, expDlr_forecast_12m)
        VALUES (%s, %s, %s, %s)
        """
        data = df[['period', 'root_hs_code', 'final_expDlr_yoy', 'expDlr_forecast_12m']].values.tolist()
        cursor.executemany(insert_query, data)

        conn.commit()
        cursor.close()
        conn.close()

        print(f"✅ 데이터가 {table_name} 테이블에 성공적으로 업로드되었습니다. (중복 시 자동 갱신)")

    except Exception as e:
        print(f"❌ 업로드 실패: {e}")

# %%
trade_data_df =  load_monthly_trade_data_from_db()

hs_cd_list = trade_data_df['root_hs_code'].unique().tolist()
# hs_cd_list = ['854232']
forecast_by_month = run_forecasting_pipeline(hs_code_list=hs_cd_list, max_hs_count=len(hs_cd_list))
# Out:
# 📈 190230 예측 중...
# ✅ 190230: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=-236.68
# ✅ 190230: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=131.55
# 📈 190590 예측 중...
# ✅ 190590: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-273.41
# ✅ 190590: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-226.39
# 📈 200899 예측 중...
# ✅ 200899: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 1, 1, 12), AIC=723.54
# ✅ 200899: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-157.40
# 📈 210390 예측 중...
# ✅ 210390: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-198.43
# ✅ 210390: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=-304.58
# 📈 210690 예측 중...
# ✅ 210690: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-232.69
# ✅ 210690: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-300.15
# 📈 220299 예측 중...
# ✅ 220299: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=-81.24
# ✅ 220299: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-57.10
# 📈 240220 예측 중...
# ✅ 240220: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=136.23
# ✅ 240220: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=716.00
# 📈 260300 예측 중...
# ✅ 260300: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 1, 1, 12), AIC=2292.93
# ✅ 260300: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=229.61
# 📈 270730 예측 중...
# ✅ 270730: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=484.99
# ✅ 270730: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 0, 12), AIC=141.88
# 📈 270750 예측 중...
# ✅ 270750: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 0, 12), AIC=213.93
# ✅ 270750: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=3267.28
# 📈 271012 예측 중...
# ✅ 271012: 최적 모델 order=(1, 0, 0), seasonal_order=(0, 0, 1, 12), AIC=87.78
# ✅ 271012: 최적 모델 order=(1, 0, 0), seasonal_order=(0, 0, 1, 12), AIC=32.58
# 📈 271019 예측 중...
# ✅ 271019: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-47.96
# ✅ 271019: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=298.78
# 📈 271320 예측 중...
# ✅ 271320: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=171.13
# ✅ 271320: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=2064.74
# 📈 280300 예측 중...
# ✅ 280300: 최적 모델 order=(1, 0, 0), seasonal_order=(0, 0, 1, 12), AIC=-56.95
# ✅ 280300: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-103.18
# 📈 283324 예측 중...
# ✅ 283324: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=1328.97
# ✅ 283324: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=815.47
# 📈 284190 예측 중...
# ✅ 284190: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=275.77
# ✅ 284190: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=221.93
# 📈 290121 예측 중...
# ✅ 290121: 최적 모델 order=(1, 0, 0), seasonal_order=(0, 0, 1, 12), AIC=153.89
# ✅ 290121: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=3532.47
# 📈 290122 예측 중...
# ✅ 290122: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=126.25
# ✅ 290122: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=1313.10
# 📈 290124 예측 중...
# ✅ 290124: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 0, 12), AIC=469.73
# ✅ 290124: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=656.71
# 📈 290220 예측 중...
# ✅ 290220: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=145.35
# ✅ 290220: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=3611.03
# 📈 290230 예측 중...
# ✅ 290230: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=648.10
# ✅ 290230: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=607.91
# 📈 290243 예측 중...
# ✅ 290243: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=55.48
# ✅ 290243: 최적 모델 order=(0, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=4217.34
# 📈 290250 예측 중...
# ✅ 290250: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=304.83
# ✅ 290250: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=451.40
# 📈 290723 예측 중...
# ✅ 290723: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=132.67
# ✅ 290723: 최적 모델 order=(1, 0, 0), seasonal_order=(1, 1, 1, 12), AIC=376.26
# 📈 291736 예측 중...
# ✅ 291736: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=39.41
# ✅ 291736: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 1, 1, 12), AIC=1656.98
# 📈 291739 예측 중...
# ✅ 291739: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=17.42
# ✅ 291739: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=43.54
# 📈 292910 예측 중...
# ✅ 292910: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=56.23
# ✅ 292910: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-50.88
# 📈 293499 예측 중...
# ✅ 293499: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=511.62
# ✅ 293499: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=36.32
# 📈 300212 예측 중...
# ✅ 300212: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 0, 0, 12), AIC=126.62
# ✅ 300212: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=3.44
# 📈 300214 예측 중...
# ✅ 300214: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=137.31
# ✅ 300214: 최적 모델 order=(0, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=416.29
# 📈 300215 예측 중...
# ✅ 300215: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=212.05
# ✅ 300215: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=52.55
# 📈 300249 예측 중...
# ⚠️ 300249: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=300249, col=expDlr_yoy
# ⚠️ 300249: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=300249, col=impDlr_yoy
# 📈 300490 예측 중...
# ✅ 300490: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-83.02
# ✅ 300490: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 0, 12), AIC=-45.97
# 📈 320730 예측 중...
# ✅ 320730: 최적 모델 order=(1, 0, 0), seasonal_order=(1, 0, 0, 12), AIC=382.76
# ✅ 320730: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=49.15
# 📈 320890 예측 중...
# ✅ 320890: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-174.67
# ✅ 320890: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-293.78
# 📈 330410 예측 중...
# ✅ 330410: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=190.72
# ✅ 330410: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-105.69
# 📈 330499 예측 중...
# ✅ 330499: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=169.70
# ✅ 330499: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-313.22
# 📈 330790 예측 중...
# ✅ 330790: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=112.97
# ✅ 330790: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=109.52
# 📈 340130 예측 중...
# ✅ 340130: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=340.41
# ✅ 340130: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 1, 1, 12), AIC=314.42
# 📈 350610 예측 중...
# ✅ 350610: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-186.22
# ✅ 350610: 최적 모델 order=(1, 0, 0), seasonal_order=(0, 0, 1, 12), AIC=-107.81
# 📈 350691 예측 중...
# ✅ 350691: 최적 모델 order=(1, 0, 0), seasonal_order=(1, 0, 0, 12), AIC=90.87
# ✅ 350691: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-70.43
# 📈 370790 예측 중...
# ✅ 370790: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-236.23
# ✅ 370790: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-237.64
# 📈 381800 예측 중...
# ✅ 381800: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 0, 0, 12), AIC=-103.42
# ✅ 381800: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-220.76
# 📈 382219 예측 중...
# ⚠️ 382219: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=382219, col=expDlr_yoy
# ⚠️ 382219: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=382219, col=impDlr_yoy
# 📈 382499 예측 중...
# ✅ 382499: 최적 모델 order=(1, 1, 0), seasonal_order=(1, 0, 1, 12), AIC=-13.46
# ✅ 382499: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 0, 12), AIC=-160.82
# 📈 382600 예측 중...
# ✅ 382600: 최적 모델 order=(0, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=2156.44
# ✅ 382600: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 1, 1, 12), AIC=2219.92
# 📈 390110 예측 중...
# ✅ 390110: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-195.73
# ✅ 390110: 최적 모델 order=(1, 1, 0), seasonal_order=(0, 0, 1, 12), AIC=11.52
# 📈 390120 예측 중...
# ✅ 390120: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-217.71
# ✅ 390120: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=152.32
# 📈 390130 예측 중...
# ✅ 390130: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-67.92
# ✅ 390130: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=243.03
# 📈 390140 예측 중...
# ✅ 390140: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=23.36
# ✅ 390140: 최적 모델 order=(0, 0, 0), seasonal_order=(0, 0, 1, 12), AIC=3.65
# 📈 390210 예측 중...
# ✅ 390210: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-269.34
# ✅ 390210: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=161.74
# 📈 390230 예측 중...
# ✅ 390230: 최적 모델 order=(1, 0, 0), seasonal_order=(0, 0, 1, 12), AIC=-191.51
# ✅ 390230: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=119.44
# 📈 390330 예측 중...
# ✅ 390330: 최적 모델 order=(1, 0, 0), seasonal_order=(0, 0, 1, 12), AIC=-247.08
# ✅ 390330: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 0, 12), AIC=151.58
# 📈 390390 예측 중...
# ✅ 390390: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-129.27
# ✅ 390390: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=38.75
# 📈 390410 예측 중...
# ✅ 390410: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-24.64
# ✅ 390410: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=381.86
# 📈 390690 예측 중...
# ✅ 390690: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-274.45
# ✅ 390690: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-266.07
# 📈 390710 예측 중...
# ✅ 390710: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-89.15
# ✅ 390710: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=131.85
# 📈 390729 예측 중...
# ⚠️ 390729: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=390729, col=expDlr_yoy
# ⚠️ 390729: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=390729, col=impDlr_yoy
# 📈 390730 예측 중...
# ✅ 390730: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-43.96
# ✅ 390730: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-92.44
# 📈 390740 예측 중...
# ✅ 390740: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-29.17
# ✅ 390740: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-36.30
# 📈 390761 예측 중...
# ✅ 390761: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 0, 12), AIC=-48.67
# ✅ 390761: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=93.54
# 📈 390769 예측 중...
# ✅ 390769: 최적 모델 order=(1, 0, 0), seasonal_order=(0, 0, 1, 12), AIC=-62.60
# ✅ 390769: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=75.91
# 📈 390799 예측 중...
# ✅ 390799: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-222.90
# ✅ 390799: 최적 모델 order=(1, 0, 0), seasonal_order=(1, 0, 1, 12), AIC=-104.41
# 📈 390810 예측 중...
# ✅ 390810: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=18.10
# ✅ 390810: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 0, 12), AIC=16.58
# 📈 390931 예측 중...
# ✅ 390931: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=34.08
# ✅ 390931: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=66.45
# 📈 390950 예측 중...
# ✅ 390950: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-148.34
# ✅ 390950: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-106.09
# 📈 391110 예측 중...
# ✅ 391110: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-209.08
# ✅ 391110: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-65.51
# 📈 391190 예측 중...
# ✅ 391190: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=106.73
# ✅ 391190: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-116.13
# 📈 391239 예측 중...
# ✅ 391239: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=-236.04
# ✅ 391239: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=0.96
# 📈 391810 예측 중...
# ✅ 391810: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-244.75
# ✅ 391810: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=220.01
# 📈 391990 예측 중...
# ✅ 391990: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-233.32
# ✅ 391990: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-226.23
# 📈 392062 예측 중...
# ✅ 392062: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-330.51
# ✅ 392062: 최적 모델 order=(1, 0, 0), seasonal_order=(1, 0, 1, 12), AIC=-135.52
# 📈 392099 예측 중...
# ✅ 392099: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 0, 0, 12), AIC=37.69
# ✅ 392099: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-171.11
# 📈 392119 예측 중...
# ✅ 392119: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-94.28
# ✅ 392119: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-30.24
# 📈 392190 예측 중...
# ✅ 392190: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-266.66
# ✅ 392190: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 0, 12), AIC=-305.18
# 📈 392310 예측 중...
# ✅ 392310: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-320.79
# ✅ 392310: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-329.18
# 📈 392690 예측 중...
# ✅ 392690: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-299.36
# ✅ 392690: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-296.59
# 📈 400219 예측 중...
# ✅ 400219: 최적 모델 order=(1, 0, 0), seasonal_order=(1, 0, 1, 12), AIC=-162.69
# ✅ 400219: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=243.72
# 📈 400220 예측 중...
# ✅ 400220: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 0, 12), AIC=-62.44
# ✅ 400220: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=324.33
# 📈 400251 예측 중...
# ✅ 400251: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=745.26
# ✅ 400251: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=3460.31
# 📈 400270 예측 중...
# ✅ 400270: 최적 모델 order=(1, 0, 0), seasonal_order=(0, 0, 1, 12), AIC=13.45
# ✅ 400270: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=92.15
# 📈 401110 예측 중...
# ✅ 401110: 최적 모델 order=(1, 0, 0), seasonal_order=(0, 0, 1, 12), AIC=-154.81
# ✅ 401110: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-186.06
# 📈 401120 예측 중...
# ✅ 401120: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 0, 12), AIC=-144.80
# ✅ 401120: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=175.63
# 📈 481019 예측 중...
# ✅ 481019: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-317.80
# ✅ 481019: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 0, 12), AIC=214.88
# 📈 481092 예측 중...
# ✅ 481092: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=258.99
# ✅ 481092: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=1520.38
# 📈 540761 예측 중...
# ✅ 540761: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-182.54
# ✅ 540761: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-17.77
# 📈 550320 예측 중...
# ✅ 550320: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-207.41
# ✅ 550320: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=215.04
# 📈 590320 예측 중...
# ✅ 590320: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-242.07
# ✅ 590320: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-101.05
# 📈 600410 예측 중...
# ✅ 600410: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-138.11
# ✅ 600410: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=136.77
# 📈 600632 예측 중...
# ✅ 600632: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-229.78
# ✅ 600632: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 0, 12), AIC=264.24
# 📈 621790 예측 중...
# ✅ 621790: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-54.61
# ✅ 621790: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=366.98
# 📈 630900 예측 중...
# ✅ 630900: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-105.78
# ✅ 630900: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-90.88
# 📈 700490 예측 중...
# ✅ 700490: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 1, 1, 12), AIC=2071.34
# ✅ 700490: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=679.86
# 📈 700600 예측 중...
# ✅ 700600: 최적 모델 order=(1, 0, 0), seasonal_order=(0, 0, 1, 12), AIC=277.96
# ✅ 700600: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=56.78
# 📈 710691 예측 중...
# ✅ 710691: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=1998.21
# 📈 710813 예측 중...
# ✅ 710691: 최적 모델 order=(1, 1, 0), seasonal_order=(1, 0, 1, 12), AIC=37.07
# ✅ 710813: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=466.32
# ✅ 710813: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=1045.83
# 📈 711292 예측 중...
# ✅ 711292: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=1417.49
# ✅ 711292: 최적 모델 order=(0, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=952.66
# 📈 711319 예측 중...
# ✅ 711319: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=383.38
# ✅ 711319: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=144.22
# 📈 720270 예측 중...
# ✅ 720270: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=642.68
# ✅ 720270: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 1, 1, 12), AIC=2620.82
# 📈 720826 예측 중...
# ✅ 720826: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=66.33
# ✅ 720826: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=1133.69
# 📈 720827 예측 중...
# ✅ 720827: 최적 모델 order=(1, 0, 0), seasonal_order=(0, 0, 1, 12), AIC=-43.86
# ✅ 720827: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=1239.12
# 📈 720836 예측 중...
# ✅ 720836: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=436.84
# ✅ 720836: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=1477.37
# 📈 720837 예측 중...
# ✅ 720837: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=333.51
# ✅ 720837: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=486.94
# 📈 720838 예측 중...
# ✅ 720838: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 0, 12), AIC=299.80
# ✅ 720838: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 0, 12), AIC=236.56
# 📈 720839 예측 중...
# ✅ 720839: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=75.74
# ✅ 720839: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 0, 12), AIC=102.28
# 📈 720851 예측 중...
# ✅ 720851: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-20.82
# ✅ 720851: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=266.17
# 📈 720916 예측 중...
# ✅ 720916: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-121.80
# ✅ 720916: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=753.11
# 📈 720917 예측 중...
# ✅ 720917: 최적 모델 order=(1, 0, 0), seasonal_order=(0, 0, 1, 12), AIC=-181.02
# ✅ 720917: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=627.92
# 📈 721012 예측 중...
# ✅ 721012: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-121.94
# ✅ 721012: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 1, 1, 12), AIC=1276.97
# 📈 721030 예측 중...
# ✅ 721030: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 0, 12), AIC=-67.46
# ✅ 721030: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=344.08
# 📈 721049 예측 중...
# ✅ 721049: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-177.57
# ✅ 721049: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=287.97
# 📈 721061 예측 중...
# ✅ 721061: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-45.84
# ✅ 721061: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=2455.96
# 📈 721070 예측 중...
# ✅ 721070: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-230.03
# ✅ 721070: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=942.26
# 📈 721391 예측 중...
# ✅ 721391: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 0, 12), AIC=259.23
# ✅ 721391: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=274.81
# 📈 721633 예측 중...
# ✅ 721633: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 0, 12), AIC=208.15
# ✅ 721633: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=371.46
# 📈 721913 예측 중...
# ✅ 721913: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=74.59
# ✅ 721913: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=335.45
# 📈 721933 예측 중...
# ✅ 721933: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=314.09
# ✅ 721933: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=353.73
# 📈 721934 예측 중...
# ✅ 721934: 최적 모델 order=(1, 0, 0), seasonal_order=(0, 0, 1, 12), AIC=-52.37
# ✅ 721934: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=148.10
# 📈 722519 예측 중...
# ✅ 722519: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=347.67
# ✅ 722519: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=720.43
# 📈 722530 예측 중...
# ✅ 722530: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=2352.27
# ✅ 722530: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=1561.00
# 📈 722550 예측 중...
# ✅ 722550: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 1, 1, 12), AIC=1219.65
# ✅ 722550: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=996.66
# 📈 722592 예측 중...
# ✅ 722592: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=500.88
# ✅ 722592: 최적 모델 order=(0, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=2032.72
# 📈 730511 예측 중...
# ✅ 730511: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=567.16
# ✅ 730511: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 1, 1, 12), AIC=849.96
# 📈 730629 예측 중...
# ✅ 730629: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=2444.15
# ✅ 730629: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=2482.45
# 📈 730890 예측 중...
# ✅ 730890: 최적 모델 order=(0, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=796.25
# ✅ 730890: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=273.91
# 📈 731210 예측 중...
# ✅ 731210: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-277.32
# ✅ 731210: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-135.29
# 📈 731815 예측 중...
# ✅ 731815: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-160.80
# ✅ 731815: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 0, 12), AIC=252.74
# 📈 732690 예측 중...
# ✅ 732690: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-222.88
# ✅ 732690: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-118.21
# 📈 740311 예측 중...
# ✅ 740311: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=289.39
# ✅ 740311: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-4.91
# 📈 741011 예측 중...
# ✅ 741011: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=88.08
# ✅ 741011: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-109.62
# 📈 741021 예측 중...
# ✅ 741021: 최적 모델 order=(1, 0, 0), seasonal_order=(1, 0, 1, 12), AIC=12.39
# ✅ 741021: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 0, 12), AIC=-191.36
# 📈 741110 예측 중...
# ✅ 741110: 최적 모델 order=(1, 1, 0), seasonal_order=(0, 0, 1, 12), AIC=-80.66
# ✅ 741110: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=226.34
# 📈 760120 예측 중...
# ✅ 760120: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=166.32
# ✅ 760120: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=21.23
# 📈 760612 예측 중...
# ✅ 760612: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-138.00
# ✅ 760612: 최적 모델 order=(1, 1, 0), seasonal_order=(1, 0, 1, 12), AIC=-189.12
# 📈 761699 예측 중...
# ✅ 761699: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-110.06
# ✅ 761699: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-149.22
# 📈 780110 예측 중...
# ✅ 780110: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=395.25
# ✅ 780110: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=198.11
# 📈 790111 예측 중...
# ✅ 790111: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=102.23
# ✅ 790111: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=397.74
# 📈 790120 예측 중...
# ✅ 790120: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=107.81
# ✅ 790120: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 1, 1, 12), AIC=2327.13
# 📈 820730 예측 중...
# ✅ 820730: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=133.02
# ✅ 820730: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=527.44
# 📈 820900 예측 중...
# ✅ 820900: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-173.26
# ✅ 820900: 최적 모델 order=(1, 1, 0), seasonal_order=(1, 0, 1, 12), AIC=-267.85
# 📈 830230 예측 중...
# ✅ 830230: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=260.19
# ✅ 830230: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=189.75
# 📈 840130 예측 중...
# ⚠️ 840130: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=840130, col=expDlr_yoy
# ⚠️ 840130: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=840130, col=impDlr_yoy
# 📈 840733 예측 중...
# ✅ 840733: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=930.08
# ✅ 840733: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=1874.34
# 📈 840734 예측 중...
# ✅ 840734: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=334.15
# ✅ 840734: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 1, 1, 12), AIC=651.75
# 📈 840810 예측 중...
# ✅ 840810: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=330.58
# ✅ 840810: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=699.22
# 📈 840890 예측 중...
# ✅ 840890: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=95.36
# ✅ 840890: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=69.75
# 📈 840991 예측 중...
# ✅ 840991: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 0, 0, 12), AIC=65.25
# ✅ 840991: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=-212.21
# 📈 840999 예측 중...
# ✅ 840999: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-255.24
# ✅ 840999: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-207.29
# 📈 841112 예측 중...
# ✅ 841112: 최적 모델 order=(0, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=3453.59
# ✅ 841112: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=3230.04
# 📈 841191 예측 중...
# ✅ 841191: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=113.92
# ✅ 841191: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=267.85
# 📈 841221 예측 중...
# ✅ 841221: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=141.90
# ✅ 841221: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=537.47
# 📈 841330 예측 중...
# ✅ 841330: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=20.91
# ✅ 841330: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-116.80
# 📈 841370 예측 중...
# ✅ 841370: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=313.64
# ✅ 841370: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=326.16
# 📈 841391 예측 중...
# ✅ 841391: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-168.84
# ✅ 841391: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=41.21
# 📈 841410 예측 중...
# ✅ 841410: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=281.81
# ✅ 841410: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-12.11
# 📈 841430 예측 중...
# ✅ 841430: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=-102.57
# ✅ 841430: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-189.87
# 📈 841459 예측 중...
# ✅ 841459: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=95.04
# ✅ 841459: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=137.48
# 📈 841480 예측 중...
# ✅ 841480: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=112.84
# ✅ 841480: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=219.48
# 📈 841490 예측 중...
# ✅ 841490: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=-98.76
# ✅ 841490: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-95.10
# 📈 841510 예측 중...
# ✅ 841510: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=48.66
# ✅ 841510: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=307.59
# 📈 841590 예측 중...
# ✅ 841590: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-114.18
# ✅ 841590: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=24.28
# 📈 841810 예측 중...
# ✅ 841810: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-145.01
# ✅ 841810: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=90.58
# 📈 841869 예측 중...
# ✅ 841869: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=27.13
# ✅ 841869: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=368.47
# 📈 841899 예측 중...
# ✅ 841899: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-29.88
# ✅ 841899: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 1, 1, 12), AIC=109.96
# 📈 841950 예측 중...
# ✅ 841950: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=237.60
# ✅ 841950: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=409.13
# 📈 841989 예측 중...
# ✅ 841989: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=401.02
# ✅ 841989: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=174.06
# 📈 841990 예측 중...
# ✅ 841990: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=473.81
# ✅ 841990: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=252.32
# 📈 842121 예측 중...
# ✅ 842121: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=146.38
# ✅ 842121: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=228.86
# 📈 842139 예측 중...
# ✅ 842139: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=355.72
# ✅ 842139: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=144.38
# 📈 842199 예측 중...
# ✅ 842199: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=7.29
# ✅ 842199: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-104.44
# 📈 842489 예측 중...
# ✅ 842489: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=477.36
# ✅ 842489: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=431.94
# 📈 842710 예측 중...
# ✅ 842710: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=82.39
# ✅ 842710: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=258.39
# 📈 842720 예측 중...
# ✅ 842720: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=22.58
# ✅ 842720: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=283.10
# 📈 842833 예측 중...
# ✅ 842833: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=322.18
# ✅ 842833: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=655.43
# 📈 842839 예측 중...
# ✅ 842839: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=624.99
# ✅ 842839: 최적 모델 order=(0, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=765.76
# 📈 842890 예측 중...
# ✅ 842890: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=344.12
# ✅ 842890: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=302.93
# 📈 842951 예측 중...
# ✅ 842951: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=89.65
# ✅ 842951: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 1, 1, 12), AIC=610.57
# 📈 842952 예측 중...
# ✅ 842952: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-44.64
# ✅ 842952: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=356.47
# 📈 843149 예측 중...
# ✅ 843149: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-169.85
# ✅ 843149: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 0, 12), AIC=136.95
# 📈 845020 예측 중...
# ✅ 845020: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=140.87
# ✅ 845020: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 1, 1, 12), AIC=727.92
# 📈 845129 예측 중...
# ✅ 845129: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=93.31
# ✅ 845129: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 1, 1, 12), AIC=888.90
# 📈 845611 예측 중...
# ✅ 845611: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=147.90
# ✅ 845611: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=40.49
# 📈 845710 예측 중...
# ✅ 845710: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=149.56
# ✅ 845710: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=246.26
# 📈 845811 예측 중...
# ✅ 845811: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=38.15
# ✅ 845811: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=487.77
# 📈 846262 예측 중...
# ⚠️ 846262: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=846262, col=expDlr_yoy
# ⚠️ 846262: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=846262, col=impDlr_yoy
# 📈 847290 예측 중...
# ✅ 847290: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=62.07
# ✅ 847290: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=191.65
# 📈 847330 예측 중...
# ✅ 847330: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=53.08
# ✅ 847330: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=62.85
# 📈 847950 예측 중...
# ✅ 847950: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=601.79
# ✅ 847950: 최적 모델 order=(1, 0, 0), seasonal_order=(0, 1, 1, 12), AIC=659.92
# 📈 847982 예측 중...
# ✅ 847982: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=557.27
# ✅ 847982: 최적 모델 order=(0, 0, 0), seasonal_order=(1, 1, 1, 12), AIC=255.01
# 📈 847989 예측 중...
# ✅ 847989: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=63.88
# ✅ 847989: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=60.39
# 📈 847990 예측 중...
# ✅ 847990: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-144.55
# ✅ 847990: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=21.44
# 📈 848071 예측 중...
# ✅ 848071: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-34.12
# ✅ 848071: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=287.91
# 📈 848180 예측 중...
# ✅ 848180: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-73.47
# ✅ 848180: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-274.53
# 📈 848190 예측 중...
# ✅ 848190: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-116.20
# ✅ 848190: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-205.43
# 📈 848210 예측 중...
# ✅ 848210: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 0, 12), AIC=-193.91
# ✅ 848210: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-285.40
# 📈 848310 예측 중...
# ✅ 848310: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-128.96
# ✅ 848310: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-85.96
# 📈 848340 예측 중...
# ✅ 848340: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-146.02
# ✅ 848340: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-181.65
# 📈 848390 예측 중...
# ✅ 848390: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-139.94
# ✅ 848390: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=282.69
# 📈 848620 예측 중...
# ✅ 848620: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=567.58
# ✅ 848620: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=698.76
# 📈 848630 예측 중...
# ✅ 848630: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=661.06
# ✅ 848630: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=1800.70
# 📈 848640 예측 중...
# ✅ 848640: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=402.94
# ✅ 848640: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 0, 12), AIC=337.57
# 📈 848690 예측 중...
# ✅ 848690: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=56.27
# ✅ 848690: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-9.82
# 📈 850110 예측 중...
# ✅ 850110: 최적 모델 order=(0, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=282.32
# ✅ 850110: 최적 모델 order=(1, 0, 0), seasonal_order=(0, 0, 1, 12), AIC=-4.01
# 📈 850131 예측 중...
# ✅ 850131: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-27.71
# ✅ 850131: 최적 모델 order=(1, 1, 0), seasonal_order=(0, 0, 1, 12), AIC=-210.11
# 📈 850213 예측 중...
# ✅ 850213: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=1169.43
# ✅ 850213: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=808.90
# 📈 850300 예측 중...
# ✅ 850300: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 0, 12), AIC=72.42
# ✅ 850300: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=218.87
# 📈 850421 예측 중...
# ✅ 850421: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=612.07
# ✅ 850421: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=949.37
# 📈 850422 예측 중...
# ✅ 850422: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=615.60
# ✅ 850422: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=2738.05
# 📈 850423 예측 중...
# ✅ 850423: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=411.51
# ✅ 850423: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=2988.10
# 📈 850440 예측 중...
# ✅ 850440: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-138.48
# ✅ 850440: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-258.22
# 📈 850450 예측 중...
# ✅ 850450: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=91.98
# ✅ 850450: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-258.03
# 📈 850490 예측 중...
# ✅ 850490: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-213.37
# ✅ 850490: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-108.98
# 📈 850710 예측 중...
# ✅ 850710: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-251.96
# ✅ 850710: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=432.81
# 📈 850760 예측 중...
# ✅ 850760: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-149.95
# ✅ 850760: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=63.94
# 📈 850790 예측 중...
# ✅ 850790: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-113.11
# ✅ 850790: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 0, 12), AIC=266.17
# 📈 851140 예측 중...
# ✅ 851140: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=415.60
# ✅ 851140: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=185.13
# 📈 851220 예측 중...
# ✅ 851220: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=47.83
# ✅ 851220: 최적 모델 order=(1, 1, 0), seasonal_order=(1, 0, 1, 12), AIC=-52.79
# 📈 851290 예측 중...
# ✅ 851290: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 0, 12), AIC=-8.08
# ✅ 851290: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-138.00
# 📈 851419 예측 중...
# ⚠️ 851419: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=851419, col=expDlr_yoy
# ⚠️ 851419: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=851419, col=impDlr_yoy
# 📈 851580 예측 중...
# ✅ 851580: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=496.18
# ✅ 851580: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=517.99
# 📈 851660 예측 중...
# ✅ 851660: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=98.45
# ✅ 851660: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-71.92
# 📈 851713 예측 중...
# ⚠️ 851713: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=851713, col=expDlr_yoy
# ⚠️ 851713: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=851713, col=impDlr_yoy
# 📈 851762 예측 중...
# ✅ 851762: 최적 모델 order=(1, 0, 0), seasonal_order=(0, 0, 1, 12), AIC=-70.59
# ✅ 851762: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-57.40
# 📈 851779 예측 중...
# ⚠️ 851779: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=851779, col=expDlr_yoy
# ⚠️ 851779: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=851779, col=impDlr_yoy
# 📈 852349 예측 중...
# ✅ 852349: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=287.14
# ✅ 852349: 최적 모델 order=(0, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=270.51
# 📈 852351 예측 중...
# ✅ 852351: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=613.86
# ✅ 852351: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=375.57
# 📈 852411 예측 중...
# ⚠️ 852411: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=852411, col=expDlr_yoy
# ⚠️ 852411: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=852411, col=impDlr_yoy
# 📈 852412 예측 중...
# ⚠️ 852412: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=852412, col=expDlr_yoy
# ⚠️ 852412: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=852412, col=impDlr_yoy
# 📈 852491 예측 중...
# ⚠️ 852491: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=852491, col=expDlr_yoy
# ⚠️ 852491: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=852491, col=impDlr_yoy
# 📈 852492 예측 중...
# ⚠️ 852492: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=852492, col=expDlr_yoy
# ⚠️ 852492: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=852492, col=impDlr_yoy
# 📈 852589 예측 중...
# ⚠️ 852589: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=852589, col=expDlr_yoy
# ⚠️ 852589: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=852589, col=impDlr_yoy
# 📈 852721 예측 중...
# ✅ 852721: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=343.07
# ✅ 852721: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 0, 12), AIC=88.42
# 📈 852859 예측 중...
# ✅ 852859: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=18.82
# ✅ 852859: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=213.48
# 📈 852990 예측 중...
# ✅ 852990: 최적 모델 order=(1, 0, 0), seasonal_order=(0, 0, 1, 12), AIC=62.04
# ✅ 852990: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=58.08
# 📈 853224 예측 중...
# ✅ 853224: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=-121.56
# ✅ 853224: 최적 모델 order=(1, 0, 0), seasonal_order=(1, 0, 1, 12), AIC=-233.32
# 📈 853400 예측 중...
# ✅ 853400: 최적 모델 order=(1, 0, 0), seasonal_order=(0, 0, 1, 12), AIC=-350.80
# ✅ 853400: 최적 모델 order=(1, 0, 0), seasonal_order=(0, 0, 1, 12), AIC=-307.99
# 📈 853529 예측 중...
# ✅ 853529: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=1129.05
# ✅ 853529: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=2626.95
# 📈 853650 예측 중...
# ✅ 853650: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-184.26
# ✅ 853650: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-270.01
# 📈 853669 예측 중...
# ✅ 853669: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-247.79
# ✅ 853669: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-392.58
# 📈 853690 예측 중...
# ✅ 853690: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-163.97
# ✅ 853690: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=-167.59
# 📈 853710 예측 중...
# ✅ 853710: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=-1.57
# ✅ 853710: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=37.23
# 📈 853720 예측 중...
# ✅ 853720: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=668.50
# ✅ 853720: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=730.06
# 📈 853890 예측 중...
# ✅ 853890: 최적 모델 order=(1, 0, 0), seasonal_order=(0, 0, 1, 12), AIC=-50.34
# ✅ 853890: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-248.49
# 📈 854110 예측 중...
# ✅ 854110: 최적 모델 order=(1, 0, 0), seasonal_order=(0, 0, 1, 12), AIC=-224.75
# ✅ 854110: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-341.96
# 📈 854129 예측 중...
# ✅ 854129: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=-101.60
# ✅ 854129: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-77.98
# 📈 854141 예측 중...
# ⚠️ 854141: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=854141, col=expDlr_yoy
# ⚠️ 854141: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=854141, col=impDlr_yoy
# 📈 854149 예측 중...
# ⚠️ 854149: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=854149, col=expDlr_yoy
# ⚠️ 854149: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=854149, col=impDlr_yoy
# 📈 854231 예측 중...
# ✅ 854231: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-277.08
# ✅ 854231: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-314.98
# 📈 854232 예측 중...
# ✅ 854232: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-219.27
# ✅ 854232: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-119.85
# 📈 854239 예측 중...
# ✅ 854239: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=-98.95
# ✅ 854239: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-73.63
# 📈 854290 예측 중...
# ✅ 854290: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-187.29
# ✅ 854290: 최적 모델 order=(0, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=739.87
# 📈 854370 예측 중...
# ✅ 854370: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=43.75
# ✅ 854370: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-149.75
# 📈 854430 예측 중...
# ✅ 854430: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-76.89
# ✅ 854430: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 0, 12), AIC=-186.90
# 📈 854442 예측 중...
# ✅ 854442: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-194.57
# ✅ 854442: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-325.54
# 📈 854449 예측 중...
# ✅ 854449: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=-166.67
# ✅ 854449: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-78.58
# 📈 854460 예측 중...
# ✅ 854460: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 0, 0, 12), AIC=319.43
# ✅ 854460: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=600.12
# 📈 870192 예측 중...
# ✅ 870192: 최적 모델 order=(1, 0, 0), seasonal_order=(1, 0, 1, 12), AIC=7.31
# ✅ 870192: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=337.80
# 📈 870210 예측 중...
# ✅ 870210: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=16.66
# ✅ 870210: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=1883.68
# 📈 870321 예측 중...
# ✅ 870321: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 0, 12), AIC=131.94
# ✅ 870321: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=498.02
# 📈 870322 예측 중...
# ✅ 870322: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=2.83
# ✅ 870322: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=938.77
# 📈 870323 예측 중...
# ✅ 870323: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 0, 12), AIC=-76.72
# ✅ 870323: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=183.70
# 📈 870324 예측 중...
# ✅ 870324: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=123.22
# ✅ 870324: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=226.21
# 📈 870332 예측 중...
# ✅ 870332: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=101.67
# ✅ 870332: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=356.48
# 📈 870340 예측 중...
# ✅ 870340: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 0, 0, 12), AIC=54.98
# ✅ 870340: 최적 모델 order=(0, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=298.51
# 📈 870360 예측 중...
# ✅ 870360: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 0, 0, 12), AIC=115.70
# ✅ 870360: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 1, 1, 12), AIC=385.55
# 📈 870380 예측 중...
# ✅ 870380: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=84.58
# ✅ 870380: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=459.09
# 📈 870421 예측 중...
# ✅ 870421: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 0, 12), AIC=102.63
# ✅ 870421: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=2124.06
# 📈 870829 예측 중...
# ✅ 870829: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=-34.25
# ✅ 870829: 최적 모델 order=(1, 1, 0), seasonal_order=(1, 0, 1, 12), AIC=-208.02
# 📈 870830 예측 중...
# ✅ 870830: 최적 모델 order=(1, 0, 0), seasonal_order=(1, 0, 0, 12), AIC=-111.10
# ✅ 870830: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-145.10
# 📈 870840 예측 중...
# ✅ 870840: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=261.82
# ✅ 870840: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-101.44
# 📈 870850 예측 중...
# ✅ 870850: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 0, 12), AIC=225.91
# ✅ 870850: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=312.74
# 📈 870880 예측 중...
# ✅ 870880: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 0, 12), AIC=-42.78
# ✅ 870880: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=12.33
# 📈 870893 예측 중...
# ✅ 870893: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-146.12
# ✅ 870893: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-4.96
# 📈 870894 예측 중...
# ✅ 870894: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=76.65
# ✅ 870894: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-50.76
# 📈 870899 예측 중...
# ✅ 870899: 최적 모델 order=(1, 0, 0), seasonal_order=(1, 0, 1, 12), AIC=-125.75
# ✅ 870899: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-288.26
# 📈 871000 예측 중...
# ✅ 871000: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=2205.28
# ✅ 871000: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=683.27
# 📈 880240 예측 중...
# ✅ 880240: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=1718.83
# ✅ 880240: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=2299.05
# 📈 880730 예측 중...
# ⚠️ 880730: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=880730, col=expDlr_yoy
# ⚠️ 880730: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=880730, col=impDlr_yoy
# 📈 890120 예측 중...
# ✅ 890120: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=271.03
# ✅ 890120: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=3178.52
# 📈 890190 예측 중...
# ✅ 890190: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=855.72
# ✅ 890190: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 1, 1, 12), AIC=1860.02
# 📈 890590 예측 중...
# ✅ 890590: 최적 모델 order=(0, 0, 0), seasonal_order=(0, 1, 1, 12), AIC=3571.49
# ✅ 890590: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 1, 1, 12), AIC=2294.40
# 📈 900120 예측 중...
# ✅ 900120: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-160.89
# ✅ 900120: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-109.91
# 📈 900130 예측 중...
# ✅ 900130: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-127.44
# ✅ 900130: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=87.29
# 📈 900190 예측 중...
# ✅ 900190: 최적 모델 order=(1, 0, 0), seasonal_order=(1, 0, 1, 12), AIC=-170.03
# ✅ 900190: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-117.14
# 📈 901320 예측 중...
# ✅ 901320: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=717.38
# ✅ 901320: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=31.94
# 📈 901812 예측 중...
# ✅ 901812: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 0, 12), AIC=-147.53
# ✅ 901812: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=232.93
# 📈 901849 예측 중...
# ✅ 901849: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 0, 0, 12), AIC=156.04
# ✅ 901849: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-63.08
# 📈 901890 예측 중...
# ✅ 901890: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-87.53
# ✅ 901890: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-303.18
# 📈 902129 예측 중...
# ✅ 902129: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=102.70
# ✅ 902129: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=65.64
# 📈 902214 예측 중...
# ...
# 📈 730900 예측 중...
# ✅ 730900: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=479.77
# ✅ 730900: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=772.96
# 📈 731100 예측 중...
# ✅ 731100: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=53.64
# ✅ 731100: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=88.84
# 📈 731816 예측 중...
# ✅ 731816: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-117.72
# ✅ 731816: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-197.65
# 📈 740200 예측 중...
# ✅ 740200: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=2417.09
# ✅ 740200: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=2260.33
# 📈 740321 예측 중...
# ✅ 740321: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=227.78
# ✅ 740321: 최적 모델 order=(0, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=3859.85
# 📈 740400 예측 중...
# ✅ 740400: 최적 모델 order=(1, 0, 0), seasonal_order=(0, 1, 1, 12), AIC=465.78
# ✅ 740400: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=60.50
# 📈 740721 예측 중...
# ✅ 740721: 최적 모델 order=(1, 0, 0), seasonal_order=(1, 0, 0, 12), AIC=183.69
# ✅ 740721: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=897.53
# 📈 740811 예측 중...
# ✅ 740811: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=114.15
# ✅ 740811: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=773.05
# 📈 740819 예측 중...
# ✅ 740819: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=103.30
# ✅ 740819: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=731.14
# 📈 740911 예측 중...
# ✅ 740911: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=129.35
# ✅ 740911: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=306.59
# 📈 740921 예측 중...
# ✅ 740921: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=14.40
# ✅ 740921: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=531.76
# 📈 741980 예측 중...
# ⚠️ 741980: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=741980, col=expDlr_yoy
# ⚠️ 741980: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=741980, col=impDlr_yoy
# 📈 760711 예측 중...
# ✅ 760711: 최적 모델 order=(1, 1, 0), seasonal_order=(0, 0, 1, 12), AIC=-339.30
# ✅ 760711: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=-78.57
# 📈 761090 예측 중...
# ✅ 761090: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=212.63
# ✅ 761090: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 0, 0, 12), AIC=352.33
# 📈 780199 예측 중...
# ✅ 780199: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=200.08
# ✅ 780199: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=730.54
# 📈 790112 예측 중...
# ✅ 790112: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=266.71
# ✅ 790112: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=2944.33
# 📈 820770 예측 중...
# ✅ 820770: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-187.58
# ✅ 820770: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-109.98
# 📈 831120 예측 중...
# ✅ 831120: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-167.26
# ✅ 831120: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=139.79
# 📈 840310 예측 중...
# ✅ 840310: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=208.58
# ✅ 840310: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=747.72
# 📈 840410 예측 중...
# ✅ 840410: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=1252.82
# ✅ 840410: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=1730.92
# 📈 840690 예측 중...
# ✅ 840690: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=954.60
# ✅ 840690: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=882.11
# 📈 841229 예측 중...
# ✅ 841229: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=231.68
# ✅ 841229: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=215.36
# 📈 841360 예측 중...
# ✅ 841360: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=1006.24
# ✅ 841360: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=37.65
# 📈 841940 예측 중...
# ✅ 841940: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=2157.00
# ✅ 841940: 최적 모델 order=(0, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=978.56
# 📈 842211 예측 중...
# ✅ 842211: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=206.63
# ✅ 842211: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=914.41
# 📈 842611 예측 중...
# ✅ 842611: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 1, 1, 12), AIC=2064.83
# ✅ 842611: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=2796.29
# 📈 842691 예측 중...
# ✅ 842691: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 1, 1, 12), AIC=633.01
# ✅ 842691: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=1565.57
# 📈 842810 예측 중...
# ✅ 842810: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=369.66
# ✅ 842810: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=373.30
# 📈 843041 예측 중...
# ✅ 843041: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=604.96
# ✅ 843041: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=1528.99
# 📈 843069 예측 중...
# ✅ 843069: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=1305.73
# ✅ 843069: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=2018.22
# 📈 843120 예측 중...
# ✅ 843120: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-1.29
# ✅ 843120: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-91.79
# 📈 843139 예측 중...
# ✅ 843139: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=283.84
# ✅ 843139: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=256.69
# 📈 844332 예측 중...
# ✅ 844332: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=350.64
# ✅ 844332: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-163.40
# 📈 845090 예측 중...
# ✅ 845090: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-25.21
# ✅ 845090: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=54.89
# 📈 845521 예측 중...
# ✅ 845521: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 1, 1, 12), AIC=2471.69
# ✅ 845521: 최적 모델 order=(0, 0, 0), seasonal_order=(1, 1, 1, 12), AIC=1695.64
# 📈 845730 예측 중...
# ✅ 845730: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=1897.20
# ✅ 845730: 최적 모델 order=(0, 0, 0), seasonal_order=(0, 1, 1, 12), AIC=2188.89
# 📈 845891 예측 중...
# ✅ 845891: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=434.93
# ✅ 845891: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 1, 1, 12), AIC=888.99
# 📈 845899 예측 중...
# ✅ 845899: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=1623.78
# ✅ 845899: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 1, 1, 12), AIC=837.34
# 📈 846242 예측 중...
# ⚠️ 846242: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=846242, col=expDlr_yoy
# ⚠️ 846242: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=846242, col=impDlr_yoy
# 📈 846290 예측 중...
# ⚠️ 846290: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=846290, col=expDlr_yoy
# ⚠️ 846290: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=846290, col=impDlr_yoy
# 📈 846693 예측 중...
# ✅ 846693: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-31.08
# ✅ 846693: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=28.18
# 📈 847130 예측 중...
# ✅ 847130: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=478.77
# ✅ 847130: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-33.57
# 📈 847150 예측 중...
# ✅ 847150: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=427.80
# ✅ 847150: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=57.04
# 📈 847160 예측 중...
# ✅ 847160: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=528.68
# ✅ 847160: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=231.21
# 📈 847521 예측 중...
# ⚠️ 847521: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=847521, col=expDlr_yoy
# ⚠️ 847521: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=847521, col=impDlr_yoy
# 📈 847710 예측 중...
# ✅ 847710: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=104.59
# ✅ 847710: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 0, 12), AIC=338.40
# 📈 848110 예측 중...
# ✅ 848110: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 1, 1, 12), AIC=912.87
# ✅ 848110: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=20.32
# 📈 848120 예측 중...
# ✅ 848120: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=220.60
# ✅ 848120: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-49.16
# 📈 848220 예측 중...
# ✅ 848220: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=120.73
# ✅ 848220: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-26.37
# 📈 848299 예측 중...
# ✅ 848299: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=13.72
# ✅ 848299: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-180.14
# 📈 848350 예측 중...
# ✅ 848350: 최적 모델 order=(1, 0, 0), seasonal_order=(0, 0, 0, 12), AIC=-74.94
# ✅ 848350: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=180.76
# 📈 848610 예측 중...
# ✅ 848610: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=821.42
# ✅ 848610: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=1509.89
# 📈 848790 예측 중...
# ✅ 848790: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-61.32
# ✅ 848790: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=107.27
# 📈 850153 예측 중...
# ✅ 850153: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=216.11
# ✅ 850153: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=535.34
# 📈 850434 예측 중...
# ✅ 850434: 최적 모델 order=(0, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=686.72
# ✅ 850434: 최적 모델 order=(0, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=1155.64
# 📈 850650 예측 중...
# ✅ 850650: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=223.67
# ✅ 850650: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=121.69
# 📈 851590 예측 중...
# ✅ 851590: 최적 모델 order=(0, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=609.86
# ✅ 851590: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=14.42
# 📈 852190 예측 중...
# ✅ 852190: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=-111.80
# ✅ 852190: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=72.76
# 📈 852610 예측 중...
# ✅ 852610: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=885.13
# ✅ 852610: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=649.44
# 📈 852852 예측 중...
# ✅ 852852: 최적 모델 order=(1, 0, 0), seasonal_order=(0, 0, 1, 12), AIC=25.21
# ✅ 852852: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 0, 12), AIC=22.61
# 📈 852910 예측 중...
# ✅ 852910: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=21.99
# ✅ 852910: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 1, 1, 12), AIC=507.74
# 📈 853530 예측 중...
# ✅ 853530: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=700.71
# ✅ 853530: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=888.14
# 📈 853620 예측 중...
# ✅ 853620: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-122.26
# ✅ 853620: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=116.01
# 📈 854121 예측 중...
# ✅ 854121: 최적 모델 order=(1, 0, 0), seasonal_order=(1, 0, 1, 12), AIC=-41.10
# ✅ 854121: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-285.74
# 📈 854142 예측 중...
# ⚠️ 854142: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=854142, col=expDlr_yoy
# ⚠️ 854142: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=854142, col=impDlr_yoy
# 📈 854143 예측 중...
# ⚠️ 854143: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=854143, col=expDlr_yoy
# ⚠️ 854143: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=854143, col=impDlr_yoy
# 📈 854159 예측 중...
# ⚠️ 854159: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=854159, col=expDlr_yoy
# ⚠️ 854159: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=854159, col=impDlr_yoy
# 📈 854233 예측 중...
# ✅ 854233: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=426.79
# ✅ 854233: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=196.99
# 📈 854390 예측 중...
# ✅ 854390: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=35.38
# ✅ 854390: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=171.49
# 📈 854411 예측 중...
# ✅ 854411: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-169.80
# ✅ 854411: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 0, 0, 12), AIC=124.29
# 📈 854720 예측 중...
# ✅ 854720: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-152.26
# ✅ 854720: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=-44.13
# 📈 860310 예측 중...
# ✅ 860310: 최적 모델 order=(0, 0, 0), seasonal_order=(1, 1, 1, 12), AIC=2542.76
# ✅ 860310: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=1197.00
# 📈 860500 예측 중...
# ⚠️ 860500: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=860500, col=expDlr_yoy
# ⚠️ 860500: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=860500, col=impDlr_yoy
# 📈 860900 예측 중...
# ✅ 860900: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=466.63
# ✅ 860900: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=75.82
# 📈 870191 예측 중...
# ✅ 870191: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=58.67
# ✅ 870191: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=604.63
# 📈 870193 예측 중...
# ✅ 870193: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=44.59
# ✅ 870193: 최적 모델 order=(0, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=165.08
# 📈 870333 예측 중...
# ✅ 870333: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 1, 1, 12), AIC=917.74
# ✅ 870333: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=604.11
# 📈 870422 예측 중...
# ✅ 870422: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=467.96
# ✅ 870422: 최적 모델 order=(0, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=1612.72
# 📈 870870 예측 중...
# ✅ 870870: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=8.51
# ✅ 870870: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=37.82
# 📈 870895 예측 중...
# ✅ 870895: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=6.00
# ✅ 870895: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-216.75
# 📈 890110 예측 중...
# ✅ 890110: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=2084.75
# ✅ 890110: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=1358.87
# 📈 900211 예측 중...
# ✅ 900211: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-14.51
# ✅ 900211: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-35.40
# 📈 900290 예측 중...
# ✅ 900290: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=536.03
# ✅ 900290: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=435.49
# 📈 901210 예측 중...
# ✅ 901210: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=545.52
# ✅ 901210: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=601.59
# 📈 901819 예측 중...
# ✅ 901819: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-143.44
# ✅ 901819: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-144.27
# 📈 901832 예측 중...
# ✅ 901832: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-144.95
# ✅ 901832: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=0.21
# 📈 902190 예측 중...
# ✅ 902190: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-46.52
# ✅ 902190: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-237.09
# 📈 902213 예측 중...
# ✅ 902213: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=344.18
# ✅ 902213: 최적 모델 order=(0, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=766.79
# 📈 902219 예측 중...
# ✅ 902219: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=544.51
# ✅ 902219: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=371.36
# 📈 902620 예측 중...
# ✅ 902620: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=232.47
# ✅ 902620: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-49.19
# 📈 902710 예측 중...
# ✅ 902710: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=413.03
# ✅ 902710: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=20.58
# 📈 902789 예측 중...
# ⚠️ 902789: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=902789, col=expDlr_yoy
# ⚠️ 902789: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=902789, col=impDlr_yoy
# 📈 902790 예측 중...
# ✅ 902790: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-22.48
# ✅ 902790: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-248.21
# 📈 903082 예측 중...
# ✅ 903082: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=669.97
# ✅ 903082: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 0, 12), AIC=424.34
# 📈 903141 예측 중...
# ✅ 903141: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=905.83
# ✅ 903141: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=1004.28
# 📈 970191 예측 중...
# ⚠️ 970191: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=970191, col=expDlr_yoy
# ⚠️ 970191: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=970191, col=impDlr_yoy

# %%
trade_data_df[trade_data_df['root_hs_code'] == '854232'].tail(12)
# Out:
#       root_hs_code  new_year  new_quarter  new_month  balPayments      expDlr  \
# 48808       854232      2024            2          5   4039343143  5714466095
# 48809       854232      2024            2          6   5533943589  7055050042
# 48810       854232      2024            3          7   4165965445  5804491763
# 48811       854232      2024            3          8   4355896714  6034933835
# 48812       854232      2024            3          9   5369305976  6926348924
# 48813       854232      2024            4         10   4486588889  6220656370
# 48814       854232      2024            4         11   4602695325  6443621669
# 48815       854232      2024            4         12   5625206052  7444169908
# 48816       854232      2025            1          1   3410142992  4766192111
# 48817       854232      2025            1          2   3303553240  4725936715
# 48818       854232      2025            1          3   5105005804  6694279385
# 48819       854232      2025            2          4   4313954323  5761090961
#
#            impDlr region year_month            expDlr_yoy  \
# 48808  1675122952     전국 2024-05-01     0.889404168048076
# 48809  1521106453     전국 2024-06-01    0.7489819124548467
# 48810  1638526318     전국 2024-07-01    0.9018399133481385
# 48811  1679037121     전국 2024-08-01    0.6192220431597901
# 48812  1557042948     전국 2024-09-01    0.6238338591825219
# 48813  1734067481     전국 2024-10-01    0.6585918439683798
# 48814  1840926344     전국 2024-11-01    0.5122735527851219
# 48815  1818963856     전국 2024-12-01    0.4006450483649675
# 48816  1356049119     전국 2025-01-01  0.050511313104259825
# 48817  1422383475     전국 2025-02-01  -0.08706481567204005
# 48818  1589273581     전국 2025-03-01   0.16107396174551503
# 48819  1447136638     전국 2025-04-01    0.1765224438893085
#
#                   impDlr_yoy
# 48808    0.13850403967384062
# 48809     0.1854118028747822
# 48810     0.4005168537892949
# 48811     0.4832809460804437
# 48812    0.40637841714910805
# 48813    0.36745004594587405
# 48814     0.6366506258975317
# 48815    0.39298385792244783
# 48816  -0.015376937446084704
# 48817    -0.1329578299772447
# 48818   -0.09637654839977527
# 48819   -0.14658863781675946

# %%
forecast_by_month['period'] =  forecast_by_month['date']

# %%
# 예측 실행 결과 (from run_forecasting_pipeline)
forecast_df = forecast_by_month

# 'expDlr_yoy_forecast' → 'yoy_forecast'로 정리
if 'expDlr_yoy_forecast' in forecast_df.columns:
    forecast_df = forecast_df.rename(columns={'expDlr_yoy_forecast': 'yoy_forecast'})
elif 'impDlr_yoy_forecast' in forecast_df.columns:
    forecast_df = forecast_df.rename(columns={'impDlr_yoy_forecast': 'yoy_forecast'})

# DB에서 데이터 불러오기
trade_data_df = load_monthly_trade_data_from_db()

# 🧩 Step 1: forecast_df 피벗
forecast_df_pivoted = pivot_forecast_df(forecast_df)

# 🧩 Step 2: merge 실행'
final_combined_df = merge_forecast_with_actuals(forecast_df_pivoted, trade_data_df)

# hs_code_list = ['854232', '854231']
# hs_code_list
forecast_result_df = final_combined_df[final_combined_df['root_hs_code'].isin(hs_cd_list)]
forecast_result_data = forecast_result_df[['period', 'root_hs_code', 'final_expDlr_yoy', 'expDlr_forecast_12m']]

# %%
db_info = {
    # 'host' : '192.168.0.230',
    'host' : 'hystox74.synology.me',
    'port' : 3307,
    'user' : 'stox7412',
    'password' : 'Apt106503!~',
    'database' : 'investar'
}

upload_forecast_to_db(forecast_result_data, db_info)
# Out:
# ✅ 데이터가 trade_forecast_by_month 테이블에 성공적으로 업로드되었습니다. (중복 시 자동 갱신)

# %%
forecast_result_data[forecast_result_data['root_hs_code'] == '854232']
# Out:
#           period root_hs_code  final_expDlr_yoy  expDlr_forecast_12m
# 90153 2007-01-01       854232               NaN                  NaN
# 90154 2007-02-01       854232               NaN                  NaN
# 90155 2007-03-01       854232               NaN                  NaN
# 90156 2007-04-01       854232               NaN                  NaN
# 90157 2007-05-01       854232               NaN                  NaN
# ...          ...          ...               ...                  ...
# 90380 2025-12-31       854232         -0.103563         6.673226e+09
# 90381 2026-01-31       854232          0.042921         4.970762e+09
# 90382 2026-02-28       854232          0.045941         4.943051e+09
# 90383 2026-03-31       854232          0.057529         7.079393e+09
# 90384 2026-04-30       854232         -0.013138         5.685402e+09
#
# [232 rows x 4 columns]

# %%
forecast_by_month.tail(12)
# Out:
#        expDlr_yoy_forecast  expDlr_yoy_lower  expDlr_yoy_upper hs_code  \
# 11184                  NaN               NaN               NaN  903141
# 11185                  NaN               NaN               NaN  903141
# 11186                  NaN               NaN               NaN  903141
# 11187                  NaN               NaN               NaN  903141
# 11188                  NaN               NaN               NaN  903141
# 11189                  NaN               NaN               NaN  903141
# 11190                  NaN               NaN               NaN  903141
# 11191                  NaN               NaN               NaN  903141
# 11192                  NaN               NaN               NaN  903141
# 11193                  NaN               NaN               NaN  903141
# 11194                  NaN               NaN               NaN  903141
# 11195                  NaN               NaN               NaN  903141
#
#        target_col       date  impDlr_yoy_forecast  impDlr_yoy_lower  \
# 11184  impDlr_yoy 2025-05-31            -0.188990         -7.329021
# 11185  impDlr_yoy 2025-06-30            -0.315262         -8.511709
# 11186  impDlr_yoy 2025-07-31            -0.086996         -8.607744
# 11187  impDlr_yoy 2025-08-31            -0.696890         -9.332265
# 11188  impDlr_yoy 2025-09-30            -0.858857         -9.540459
# 11189  impDlr_yoy 2025-10-31            -0.898969         -9.602278
# 11190  impDlr_yoy 2025-11-30            -0.646873         -9.362221
# 11191  impDlr_yoy 2025-12-31            -0.652430         -9.375633
# 11192  impDlr_yoy 2026-01-31             1.699072         -7.030028
# 11193  impDlr_yoy 2026-02-28             0.525139         -8.210229
# 11194  impDlr_yoy 2026-03-31             1.202382         -7.539081
# 11195  impDlr_yoy 2026-04-30            -0.222264         -8.969070
#
#        impDlr_yoy_upper     period
# 11184          6.951041 2025-05-31
# 11185          7.881185 2025-06-30
# 11186          8.433751 2025-07-31
# 11187          7.938484 2025-08-31
# 11188          7.822745 2025-09-30
# 11189          7.804340 2025-10-31
# 11190          8.068474 2025-11-30
# 11191          8.070773 2025-12-31
# 11192         10.428171 2026-01-31
# 11193          9.260507 2026-02-28
# 11194          9.943845 2026-03-31
# 11195          8.524541 2026-04-30
