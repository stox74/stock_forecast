# %%
import pandas as pd
from sqlalchemy import create_engine
from statsmodels.tsa.statespace.sarimax import SARIMAX
import matplotlib.pyplot as plt
import numpy as np
from sqlalchemy import create_engine

import warnings
warnings.filterwarnings("ignore")

# %%
def forecast_yoy_growth_auto(df, col, forecast_steps=12, seasonal=True):
    """
    최적 SARIMAX 파라미터를 자동 탐색하여 수출입 증가율 예측.
    월별 데이터가 72개월 미만일 경우 예측을 수행하지 않습니다.

    Parameters:
        df (pd.DataFrame): 'period' (datetime), 예측 대상 컬럼 포함
        col (str): 예측 컬럼 (예: 'expDlr_yoy')
        forecast_steps (int): 예측 기간 (월 기준 12, 분기 기준 4)
        seasonal (bool): 계절성 사용 여부
    """
    df = df[['period', col]].dropna().copy()
    df = df.set_index('period').sort_index()
    ts = df[col]

    # ✅ 데이터 길이 검사
    if forecast_steps > 4 and len(ts) < 72:
        print("⚠️ 월 데이터가 6년치(72개월) 미만입니다. 충분한 데이터 기간 기준에 미달합니다.")
        return None
    elif forecast_steps <= 4 and len(ts) < 16:
        print("⚠️ 분기 데이터가 4년치(16분기) 미만입니다. 충분한 데이터 기간 기준에 미달합니다.")
        return None

    # SARIMA 파라미터 범위
    p = d = q = range(0, 2)
    pdq = [(x, y, z) for x in p for y in d for z in q]
    seasonal_pdq = [(x, y, z) for x in p for y in d for z in q]
    seasonal_period = 12 if forecast_steps > 4 else 4

    best_model, best_order, best_seasonal_order = sarimax_grid_search(ts, pdq, seasonal_pdq, seasonal_period)

    # 예측
    future_index = pd.date_range(
        start=ts.index[-1] + pd.offsets.DateOffset(months=1 if seasonal_period == 12 else 3),
        periods=forecast_steps,
        freq='M' if seasonal_period == 12 else 'Q'
    )

    forecast = best_model.forecast(steps=forecast_steps)
    forecast.index = future_index

    # 시각화
    plt.figure(figsize=(12, 6))
    plt.plot(ts.index, ts, label='Actual')
    plt.plot(forecast.index, forecast, label='Forecast', linestyle='--', color='red')
    plt.title(f"{col} 예측 (Auto SARIMAX)")
    plt.ylabel('YoY Growth')
    plt.xticks(rotation=45)
    plt.legend()
    plt.tight_layout()
    plt.show()

# %%
# ✅ 수정된 DB 구조에 맞춘 데이터 로딩 함수
def load_monthly_trade_data_from_db():
    # host = 'hystox74.synology.me'
    host = '192.168.0.230'
    port = 3307
    user = 'stox7412'
    password = 'Apt106503!~'
    database = 'investar'
    engine = create_engine(f'mysql+pymysql://{user}:{password}@{host}:{port}/{database}')
    query = "SELECT * FROM korea_monthly_trade_data"
    df = pd.read_sql(query, con=engine)
    return df


# ✅ 수정된 long format 기반 SARIMA 예측 함수
def forecast_yoy_growth_auto_with_ci(df, col, hs_code, forecast_steps):
    warnings.filterwarnings("ignore")
    df_hs = df[(df['root_hs_code'] == hs_code) & (df['indicator'] == col)].copy()

    if df_hs.empty:
        print(f"❌ {hs_code} | '{col}'에 해당하는 데이터가 없습니다.")
        return None, None

    df_hs['date'] = pd.to_datetime(df_hs['date'])
    df_hs = df_hs.set_index('date').sort_index()
    ts = df_hs['value'].astype(float).dropna()

    if forecast_steps > 4 and len(ts) < 72:
        print(f"⚠️ {hs_code}: 월 데이터가 6년치 미만입니다.")
        return None, None

    best_aic = np.inf
    best_order = None
    best_seasonal_order = None
    best_model = None

    p = d = q = range(0, 2)
    P = D = Q = range(0, 2)
    m = 12

    for order in [(p_, d_, q_) for p_ in p for d_ in d for q_ in q]:
        for seasonal_order in [(P_, D_, Q_, m) for P_ in P for D_ in D for Q_ in Q]:
            try:
                model = SARIMAX(ts,
                                order=order,
                                seasonal_order=seasonal_order,
                                enforce_stationarity=False,
                                enforce_invertibility=False)
                result = model.fit(disp=False)
                if result.aic < best_aic:
                    best_aic = result.aic
                    best_order = order
                    best_seasonal_order = seasonal_order
                    best_model = result
            except:
                continue

    if best_model is None:
        print(f"❌ {hs_code}: SARIMAX 모델 최적화 실패")
        return None, None

    forecast_result = best_model.get_forecast(steps=forecast_steps)
    pred_mean = forecast_result.predicted_mean
    conf_int = forecast_result.conf_int()
    future_index = pd.date_range(start=ts.index[-1] + pd.DateOffset(months=1), periods=forecast_steps, freq='M')

    forecast_df = pd.DataFrame({
        col + '_forecast': pred_mean.values,
        col + '_lower': conf_int.iloc[:, 0].values,
        col + '_upper': conf_int.iloc[:, 1].values
    }, index=future_index)

    print(f"✅ {hs_code}: 최적 모델 order={best_order}, seasonal_order={best_seasonal_order}, AIC={best_aic:.2f}")
    return forecast_df, df_hs

# ✅ forecast 시계열 결합 함수 (기존과 동일)
def build_forecasted_series(base_df, forecast_df, col_name):
    full_df = pd.concat([base_df[['value']], forecast_df[[col_name + '_forecast']]], axis=0)
    full_df[col_name + '_forecast'] = pd.to_numeric(full_df[col_name + '_forecast'], errors='coerce')
    full_df[col_name + '_forecast'] = full_df[col_name + '_forecast'].replace([np.inf, -np.inf], np.nan)
    full_df[col_name + '_estimated'] = full_df[col_name + '_forecast'].shift(1) * (1 + full_df[col_name + '_forecast'])
    return full_df

# ✅ 전체 파이프라인 실행 함수
def run_forecasting_pipeline(hs_code_list, max_hs_count=3, forecast_steps = 12):
    export_m_with_yoy = load_monthly_trade_data_from_db()
    hs_code_list = hs_code_list[:max_hs_count]
    result_list = []

    for hs_code in hs_code_list:
        print(f"📈 {hs_code} 예측 중...")
        for target_col in ['expDlr_yoy', 'impDlr_yoy']:
            forecast_df, base_df = forecast_yoy_growth_auto_with_ci(export_m_with_yoy, target_col, hs_code, forecast_steps)

            if forecast_df is None or forecast_df.empty:
                print(f"⚠️ 예측 실패 또는 결과 없음 | hs_code={hs_code}, col={target_col}")
                continue

            full_df = build_forecasted_series(base_df, forecast_df, target_col)
            forecast_only = forecast_df.copy()
            forecast_only['hs_code'] = hs_code
            forecast_only['target_col'] = target_col
            forecast_only['date'] = forecast_only.index
            forecast_only = forecast_only.reset_index(drop=True)

            result_list.append(forecast_only)

    if not result_list:
        print("❌ 모든 예측이 실패하여 결과가 없습니다.")
        return pd.DataFrame()

    final_df = pd.concat(result_list, ignore_index=True)
    return final_df

def merge_forecast_with_actuals(forecast_df, trade_data_df):
    import pandas as pd

    # 📌 1. 복사 및 컬럼명 정리
    forecast_df = forecast_df.copy()
    forecast_df = forecast_df.rename(columns={'hs_code': 'root_hs_code'})  # 혹시 모를 컬럼명 정리

    # 'period' → 'date'로 통일
    if 'period' in forecast_df.columns:
        forecast_df = forecast_df.rename(columns={'period': 'date'})

    forecast_df['date'] = pd.to_datetime(forecast_df['date'])
    trade_data_df['date'] = pd.to_datetime(trade_data_df['date'])

    # 예측 컬럼 확인
    forecast_cols = ['expDlr_yoy_forecast', 'impDlr_yoy_forecast']
    present_forecast_cols = [col for col in forecast_cols if col in forecast_df.columns]
    if not present_forecast_cols:
        raise KeyError("❌ forecast_df에 'expDlr_yoy_forecast' 또는 'impDlr_yoy_forecast' 컬럼이 없습니다.")

    # 📌 2. 무역 데이터 → wide 포맷으로 변환
    trade_pivot = trade_data_df.pivot_table(
        index=['date', 'root_hs_code'],
        columns='indicator',
        values='value',
        aggfunc='last'
    ).reset_index()

    # 📌 3. 예측 데이터 선택
    forecast_selected = forecast_df[['date', 'root_hs_code'] + present_forecast_cols].drop_duplicates()

    # 📌 4. 병합
    combined_df = pd.merge(
        trade_pivot,
        forecast_selected,
        on=['date', 'root_hs_code'],
        how='outer'
    ).sort_values(['root_hs_code', 'date']).reset_index(drop=True)

    # 📌 5. YoY 보정
    combined_df['final_expDlr_yoy'] = combined_df['expDlr_yoy']
    if 'expDlr_yoy_forecast' in combined_df.columns:
        combined_df.loc[combined_df['final_expDlr_yoy'].isna(), 'final_expDlr_yoy'] = combined_df['expDlr_yoy_forecast']

    combined_df['final_impDlr_yoy'] = combined_df['impDlr_yoy']
    if 'impDlr_yoy_forecast' in combined_df.columns:
        combined_df.loc[combined_df['final_impDlr_yoy'].isna(), 'final_impDlr_yoy'] = combined_df['impDlr_yoy_forecast']

    # 📌 6. 자료형 정리
    combined_df['final_expDlr_yoy'] = pd.to_numeric(combined_df['final_expDlr_yoy'], errors='coerce')
    combined_df['final_impDlr_yoy'] = pd.to_numeric(combined_df['final_impDlr_yoy'], errors='coerce')

    # 📌 7. 12개월 전 실적
    combined_df['expDlr_lag12'] = combined_df.groupby('root_hs_code')['expDlr'].shift(12)
    combined_df['impDlr_lag12'] = combined_df.groupby('root_hs_code')['impDlr'].shift(12)

    # 📌 8. 12개월 후 예측
    combined_df['expDlr_forecast_12m'] = combined_df['expDlr_lag12'] * (1 + combined_df['final_expDlr_yoy'])
    combined_df['impDlr_forecast_12m'] = combined_df['impDlr_lag12'] * (1 + combined_df['final_impDlr_yoy'])

    return combined_df

def pivot_forecast_df(forecast_df):
    # 피벗하여 target_col 기준으로 예측값을 컬럼화
    forecast_df = forecast_df.rename(columns={'hs_code': 'root_hs_code'})
    forecast_df['period'] = pd.to_datetime(forecast_df['period'])

    forecast_pivot = forecast_df.pivot_table(index=['period', 'root_hs_code'],
                                             columns='target_col',
                                             values='yoy_forecast').reset_index()

    # 컬럼 이름 정리
    forecast_pivot.columns.name = None
    forecast_pivot = forecast_pivot.rename(columns={
        'expDlr_yoy': 'expDlr_yoy_forecast',
        'impDlr_yoy': 'impDlr_yoy_forecast'
    })
    return forecast_pivot

def upload_forecast_to_db(df, db_info, table_name='korea_trade_forecast_by_month'):
    """
    예측 결과 데이터를 MySQL(MariaDB)에 업로드하는 함수 (중복 시 대체)

    Parameters:
    - df (pd.DataFrame): 업로드할 데이터프레임
    - db_info (dict): DB 연결 정보. keys = ['host', 'port', 'user', 'password', 'database']
    - table_name (str): 업로드할 테이블 이름
    """
    try:
        # ✅ SQLAlchemy 엔진 생성
        engine = create_engine(
            f"mysql+pymysql://{db_info['user']}:{db_info['password']}@{db_info['host']}:{db_info['port']}/{db_info['database']}"
        )
        conn = engine.raw_connection()
        cursor = conn.cursor()

        # ✅ 테이블 생성 (없을 경우)
        create_table_query = f"""
        CREATE TABLE IF NOT EXISTS {table_name} (
            date DATE,
            root_hs_code VARCHAR(20),
            final_expDlr_yoy FLOAT,
            expDlr_forecast_12m FLOAT,
            PRIMARY KEY (date, root_hs_code)
        );
        """
        cursor.execute(create_table_query)

        # ✅ NaN 및 NaT, inf → None 변환 (모든 타입 안전하게 처리)
        df = df.astype(object).where(pd.notnull(df), None)

        # ✅ REPLACE INTO
        insert_query = f"""
        REPLACE INTO {table_name} (date, root_hs_code, final_expDlr_yoy, expDlr_forecast_12m)
        VALUES (%s, %s, %s, %s)
        """
        data = df[['date', 'root_hs_code', 'final_expDlr_yoy', 'expDlr_forecast_12m']].values.tolist()
        cursor.executemany(insert_query, data)

        conn.commit()
        cursor.close()
        conn.close()

        print(f"✅ 데이터가 {table_name} 테이블에 성공적으로 업로드되었습니다. (중복 시 자동 갱신)")

    except Exception as e:
        print(f"❌ 업로드 실패: {e}")

# %%
trade_data_df =  load_monthly_trade_data_from_db()
hs_cd_list = trade_data_df['root_hs_code'].unique().tolist()
# hs_cd_list = ['854232']
forecast_by_month = run_forecasting_pipeline(hs_code_list=hs_cd_list, max_hs_count=len(hs_cd_list), forecast_steps=13)
# Out:
# 📈 121120 예측 중...
# ✅ 121120: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=386.29
# ✅ 121120: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=2154.31
# 📈 151550 예측 중...
# ✅ 151550: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=1247.31
# ✅ 151550: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 1, 1, 12), AIC=1279.98
# 📈 151590 예측 중...
# ✅ 151590: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=639.47
# ✅ 151590: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=5.70
# 📈 170199 예측 중...
# ✅ 170199: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-2.57
# ✅ 170199: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=548.22
# 📈 190230 예측 중...
# ✅ 190230: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=-238.99
# ✅ 190230: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=131.45
# 📈 190590 예측 중...
# ✅ 190590: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-275.23
# ✅ 190590: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-228.60
# 📈 200599 예측 중...
# ✅ 200599: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-237.76
# ✅ 200599: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-153.53
# 📈 200830 예측 중...
# ✅ 200830: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-47.10
# ✅ 200830: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=485.90
# 📈 200899 예측 중...
# ✅ 200899: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 1, 1, 12), AIC=726.40
# ✅ 200899: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-158.57
# 📈 210111 예측 중...
# ✅ 210111: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=131.47
# ✅ 210111: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=505.12
# 📈 210390 예측 중...
# ✅ 210390: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-200.53
# ✅ 210390: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=-307.12
# 📈 210690 예측 중...
# ✅ 210690: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-234.78
# ✅ 210690: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-302.79
# 📈 220890 예측 중...
# ✅ 220890: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-88.70
# ✅ 220890: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=70.24
# 📈 230910 예측 중...
# ✅ 230910: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=95.06
# ✅ 230910: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-192.60
# 📈 240220 예측 중...
# ✅ 240220: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=135.88
# ✅ 240220: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=718.81
# 📈 260300 예측 중...
# ✅ 260300: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 1, 1, 12), AIC=2306.02
# ✅ 260300: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=230.72
# 📈 270730 예측 중...
# ✅ 270730: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=486.72
# ✅ 270730: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 0, 12), AIC=143.44
# 📈 270750 예측 중...
# ✅ 270750: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 0, 12), AIC=214.79
# ✅ 270750: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=3284.68
# 📈 270799 예측 중...
# ✅ 270799: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=946.88
# ✅ 270799: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=621.54
# 📈 271019 예측 중...
# ✅ 271019: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-49.25
# ✅ 271019: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=301.20
# 📈 271113 예측 중...
# ✅ 271113: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-8.72
# ✅ 271113: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=175.12
# 📈 271119 예측 중...
# ✅ 271119: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=2848.23
# ✅ 271119: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=776.99
# 📈 271320 예측 중...
# ✅ 271320: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=172.22
# ✅ 271320: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=2064.74
# 📈 280300 예측 중...
# ✅ 280300: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=-57.51
# ✅ 280300: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-97.61
# 📈 280700 예측 중...
# ✅ 280700: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=502.58
# ✅ 280700: 최적 모델 order=(0, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=868.14
# 📈 281512 예측 중...
# ✅ 281512: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=673.08
# ✅ 281512: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=1290.72
# 📈 281520 예측 중...
# ✅ 281520: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=-78.96
# ✅ 281520: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=767.48
# 📈 282110 예측 중...
# ✅ 282110: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 0, 12), AIC=112.63
# ✅ 282110: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=45.12
# 📈 282520 예측 중...
# ✅ 282520: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=2074.95
# ✅ 282520: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=576.20
# 📈 283324 예측 중...
# ✅ 283324: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=1335.23
# ✅ 283324: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=819.38
# 📈 283691 예측 중...
# ✅ 283691: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=2661.05
# ✅ 283691: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=539.27
# 📈 283711 예측 중...
# ✅ 283711: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=90.03
# ✅ 283711: 최적 모델 order=(0, 0, 0), seasonal_order=(0, 1, 1, 12), AIC=2986.57
# 📈 284190 예측 중...
# ✅ 284190: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=276.21
# ✅ 284190: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=222.03
# 📈 290121 예측 중...
# ✅ 290121: 최적 모델 order=(1, 0, 0), seasonal_order=(0, 0, 1, 12), AIC=153.73
# ✅ 290121: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=3551.11
# 📈 290122 예측 중...
# ✅ 290122: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=126.02
# ✅ 290122: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=1319.87
# 📈 290124 예측 중...
# ✅ 290124: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 0, 12), AIC=471.24
# ✅ 290124: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=659.85
# 📈 290220 예측 중...
# ✅ 290220: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=145.98
# ✅ 290220: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=3630.02
# 📈 290230 예측 중...
# ✅ 290230: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=650.50
# ✅ 290230: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=610.10
# 📈 290241 예측 중...
# ✅ 290241: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=4519.14
# ✅ 290241: 최적 모델 order=(0, 0, 0), seasonal_order=(1, 1, 1, 12), AIC=3867.50
# 📈 290243 예측 중...
# ✅ 290243: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=55.28
# ✅ 290243: 최적 모델 order=(0, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=4239.50
# 📈 290250 예측 중...
# ✅ 290250: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 0, 12), AIC=309.43
# ✅ 290250: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=453.51
# 📈 290315 예측 중...
# ✅ 290315: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=588.44
# ✅ 290315: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 1, 1, 12), AIC=3254.04
# 📈 290516 예측 중...
# ✅ 290516: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=1369.98
# ✅ 290516: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=817.28
# 📈 290531 예측 중...
# ✅ 290531: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=1200.34
# ✅ 290531: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=92.21
# 📈 290539 예측 중...
# ✅ 290539: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=79.59
# ✅ 290539: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=255.52
# 📈 290723 예측 중...
# ✅ 290723: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=132.52
# ✅ 290723: 최적 모델 order=(1, 0, 0), seasonal_order=(1, 1, 1, 12), AIC=379.49
# 📈 291736 예측 중...
# ✅ 291736: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=39.10
# ✅ 291736: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 1, 1, 12), AIC=1665.11
# 📈 291739 예측 중...
# ✅ 291739: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=16.47
# ✅ 291739: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=43.25
# 📈 292610 예측 중...
# ✅ 292610: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=511.52
# ✅ 292610: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=447.53
# 📈 292910 예측 중...
# ✅ 292910: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=55.47
# ✅ 292910: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-49.24
# 📈 293299 예측 중...
# ✅ 293299: 최적 모델 order=(0, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=780.69
# ✅ 293299: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=233.52
# 📈 293399 예측 중...
# ✅ 293399: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=226.26
# ✅ 293399: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-40.81
# 📈 293499 예측 중...
# ✅ 293499: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=513.29
# ✅ 293499: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=35.50
# 📈 294130 예측 중...
# ✅ 294130: 최적 모델 order=(0, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=3092.91
# ✅ 294130: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=589.02
# 📈 294190 예측 중...
# ✅ 294190: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-8.45
# ✅ 294190: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-57.03
# 📈 300490 예측 중...
# ✅ 300490: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-198.02
# ✅ 300490: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-82.05
# 📈 300640 예측 중...
# ✅ 300640: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-55.20
# ✅ 300640: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=-176.24
# 📈 310520 예측 중...
# ✅ 310520: 최적 모델 order=(0, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=664.03
# ✅ 310520: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=419.25
# 📈 320417 예측 중...
# ✅ 320417: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-134.93
# ✅ 320417: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-190.28
# 📈 320490 예측 중...
# ✅ 320490: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=558.61
# ✅ 320490: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=360.66
# 📈 320730 예측 중...
# ✅ 320730: 최적 모델 order=(1, 0, 0), seasonal_order=(1, 0, 0, 12), AIC=383.71
# ✅ 320730: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=48.41
# 📈 320890 예측 중...
# ✅ 320890: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-176.61
# ✅ 320890: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-296.36
# 📈 321410 예측 중...
# ✅ 321410: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=-118.52
# ✅ 321410: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-237.80
# 📈 321519 예측 중...
# ✅ 321519: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-180.28
# ✅ 321519: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=20.39
# 📈 330410 예측 중...
# ✅ 330410: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=490.02
# ✅ 330410: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-20.17
# 📈 330420 예측 중...
# ✅ 330420: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-87.88
# ✅ 330420: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-19.57
# 📈 330499 예측 중...
# ✅ 330499: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=169.55
# ✅ 330499: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-315.95
# 📈 330510 예측 중...
# ✅ 330510: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=83.09
# ✅ 330510: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-29.44
# 📈 330590 예측 중...
# ✅ 330590: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-36.02
# ✅ 330590: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-166.52
# 📈 330610 예측 중...
# ✅ 330610: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=246.48
# ✅ 330610: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=196.16
# 📈 330790 예측 중...
# ✅ 330790: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=112.53
# ✅ 330790: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=109.02
# 📈 340130 예측 중...
# ✅ 340130: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=341.48
# ✅ 340130: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 1, 1, 12), AIC=315.11
# 📈 340290 예측 중...
# ✅ 340290: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-147.74
# ✅ 340290: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-174.42
# 📈 340420 예측 중...
# ✅ 340420: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=622.01
# ✅ 340420: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=521.43
# 📈 350610 예측 중...
# ✅ 350610: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-188.05
# ✅ 350610: 최적 모델 order=(1, 0, 0), seasonal_order=(0, 0, 1, 12), AIC=-109.17
# 📈 350691 예측 중...
# ✅ 350691: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-85.43
# ✅ 350691: 최적 모델 order=(1, 1, 0), seasonal_order=(0, 0, 1, 12), AIC=-154.70
# 📈 350790 예측 중...
# ✅ 350790: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=389.06
# ✅ 350790: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-52.82
# 📈 360610 예측 중...
# ✅ 360610: 최적 모델 order=(0, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=715.41
# ✅ 360610: 최적 모델 order=(0, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=3307.59
# 📈 370199 예측 중...
# ✅ 370199: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=144.02
# ✅ 370199: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-155.75
# 📈 370790 예측 중...
# ✅ 370790: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-238.41
# ✅ 370790: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-238.37
# 📈 380891 예측 중...
# ✅ 380891: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=542.00
# ✅ 380891: 최적 모델 order=(0, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=571.36
# 📈 380892 예측 중...
# ✅ 380892: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 1, 1, 12), AIC=705.90
# ✅ 380892: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=438.28
# 📈 381400 예측 중...
# ✅ 381400: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-91.82
# ✅ 381400: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=41.97
# 📈 381800 예측 중...
# ✅ 381800: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 0, 0, 12), AIC=-104.85
# ✅ 381800: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-222.87
# 📈 382490 예측 중...
# ✅ 382490: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-10.71
# ✅ 382490: 최적 모델 order=(1, 1, 0), seasonal_order=(1, 0, 0, 12), AIC=-57.14
# 📈 390110 예측 중...
# ✅ 390110: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-197.18
# ✅ 390110: 최적 모델 order=(1, 1, 0), seasonal_order=(0, 0, 1, 12), AIC=10.90
# 📈 390120 예측 중...
# ✅ 390120: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-219.55
# ✅ 390120: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=152.18
# 📈 390130 예측 중...
# ✅ 390130: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-69.08
# ✅ 390130: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=243.36
# 📈 390190 예측 중...
# ✅ 390190: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=24.72
# ✅ 390190: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-200.03
# 📈 390210 예측 중...
# ✅ 390210: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-269.00
# ✅ 390210: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=161.59
# 📈 390220 예측 중...
# ✅ 390220: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=2299.83
# ✅ 390220: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=438.46
# 📈 390230 예측 중...
# ✅ 390230: 최적 모델 order=(1, 0, 0), seasonal_order=(0, 0, 1, 12), AIC=-193.50
# ✅ 390230: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=119.72
# 📈 390290 예측 중...
# ✅ 390290: 최적 모델 order=(1, 1, 0), seasonal_order=(1, 0, 0, 12), AIC=-1.56
# ✅ 390290: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-35.55
# 📈 390319 예측 중...
# ✅ 390319: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-122.13
# ✅ 390319: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=187.57
# 📈 390320 예측 중...
# ✅ 390320: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-107.47
# ✅ 390320: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=505.22
# 📈 390330 예측 중...
# ✅ 390330: 최적 모델 order=(1, 0, 0), seasonal_order=(0, 0, 1, 12), AIC=-246.96
# ✅ 390330: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 0, 12), AIC=151.42
# 📈 390390 예측 중...
# ✅ 390390: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-117.06
# ✅ 390390: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=18.82
# 📈 390410 예측 중...
# ✅ 390410: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-25.61
# ✅ 390410: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=383.37
# 📈 390610 예측 중...
# ✅ 390610: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-47.14
# ✅ 390610: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 0, 12), AIC=199.41
# 📈 390690 예측 중...
# ✅ 390690: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-276.24
# ✅ 390690: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-268.54
# 📈 390710 예측 중...
# ✅ 390710: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-90.09
# ✅ 390710: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=131.53
# 📈 390730 예측 중...
# ✅ 390730: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-45.23
# ✅ 390730: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-93.02
# 📈 390740 예측 중...
# ✅ 390740: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-30.26
# ✅ 390740: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-37.46
# 📈 390799 예측 중...
# ✅ 390799: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-223.46
# ✅ 390799: 최적 모델 order=(1, 0, 0), seasonal_order=(1, 0, 1, 12), AIC=-105.76
# 📈 390810 예측 중...
# ✅ 390810: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=17.08
# ✅ 390810: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 0, 12), AIC=16.01
# 📈 390950 예측 중...
# ✅ 390950: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=-121.35
# ✅ 390950: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-76.79
# 📈 391000 예측 중...
# ✅ 391000: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-166.52
# ✅ 391000: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-166.96
# 📈 391110 예측 중...
# ✅ 391110: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-210.12
# ✅ 391110: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-54.04
# 📈 391190 예측 중...
# ✅ 391190: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=173.31
# ✅ 391190: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-80.92
# 📈 391239 예측 중...
# ✅ 391239: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=-20.29
# ✅ 391239: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=52.31
# 📈 391810 예측 중...
# ✅ 391810: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-247.11
# ✅ 391810: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=220.22
# 📈 391910 예측 중...
# ✅ 391910: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-205.69
# ✅ 391910: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-215.48
# 📈 391990 예측 중...
# ✅ 391990: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-235.07
# ✅ 391990: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-228.21
# 📈 392010 예측 중...
# ✅ 392010: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-247.99
# ✅ 392010: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-250.24
# 📈 392020 예측 중...
# ✅ 392020: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-346.40
# ✅ 392020: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-103.47
# 📈 392049 예측 중...
# ✅ 392049: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-135.81
# ✅ 392049: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-30.04
# 📈 392051 예측 중...
# ✅ 392051: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-96.60
# ✅ 392051: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=147.79
# 📈 392062 예측 중...
# ✅ 392062: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-333.15
# ✅ 392062: 최적 모델 order=(1, 0, 0), seasonal_order=(1, 0, 1, 12), AIC=-137.33
# 📈 392099 예측 중...
# ✅ 392099: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 0, 0, 12), AIC=38.00
# ✅ 392099: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-172.35
# 📈 392119 예측 중...
# ✅ 392119: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-95.85
# ✅ 392119: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-31.38
# 📈 392190 예측 중...
# ✅ 392190: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-266.49
# ✅ 392190: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 0, 12), AIC=-307.74
# 📈 392310 예측 중...
# ✅ 392310: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-322.98
# ✅ 392310: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-331.87
# 📈 392321 예측 중...
# ✅ 392321: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-193.97
# ✅ 392321: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=12.07
# 📈 392330 예측 중...
# ✅ 392330: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-210.85
# ✅ 392330: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-149.72
# 📈 392390 예측 중...
# ✅ 392390: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 0, 12), AIC=-118.70
# ✅ 392390: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=-174.88
# 📈 392630 예측 중...
# ✅ 392630: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=1140.03
# ✅ 392630: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=316.90
# 📈 392690 예측 중...
# ✅ 392690: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-302.00
# ✅ 392690: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-299.04
# 📈 400219 예측 중...
# ✅ 400219: 최적 모델 order=(1, 0, 0), seasonal_order=(1, 0, 1, 12), AIC=-164.54
# ✅ 400219: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=244.10
# 📈 400220 예측 중...
# ✅ 400220: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 0, 12), AIC=-63.13
# ✅ 400220: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=326.90
# 📈 400251 예측 중...
# ✅ 400251: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=750.46
# ✅ 400251: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 1, 1, 12), AIC=3484.51
# 📈 400259 예측 중...
# ✅ 400259: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=7.59
# ✅ 400259: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=238.66
# 📈 400270 예측 중...
# ✅ 400270: 최적 모델 order=(1, 0, 0), seasonal_order=(0, 0, 1, 12), AIC=177.91
# ✅ 400270: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=139.65
# 📈 401110 예측 중...
# ✅ 401110: 최적 모델 order=(1, 0, 0), seasonal_order=(0, 0, 1, 12), AIC=-156.42
# ✅ 401110: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-188.08
# 📈 401120 예측 중...
# ✅ 401120: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-220.19
# ✅ 401120: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=-8.93
# 📈 401693 예측 중...
# ✅ 401693: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-134.59
# ✅ 401693: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 0, 12), AIC=-166.00
# 📈 401699 예측 중...
# ✅ 401699: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-195.93
# ✅ 401699: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-210.49
# 📈 410792 예측 중...
# ✅ 410792: 최적 모델 order=(1, 0, 0), seasonal_order=(0, 0, 1, 12), AIC=-20.40
# ✅ 410792: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=290.23
# 📈 470329 예측 중...
# ✅ 470329: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=2135.56
# ✅ 470329: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-11.44
# 📈 470710 예측 중...
# ✅ 470710: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=673.93
# ✅ 470710: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=57.40
# 📈 480511 예측 중...
# ✅ 480511: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=464.74
# ✅ 480511: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=567.90
# 📈 480990 예측 중...
# ✅ 480990: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-2.07
# ✅ 480990: 최적 모델 order=(1, 1, 0), seasonal_order=(0, 0, 1, 12), AIC=169.27
# 📈 481019 예측 중...
# ✅ 481019: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-320.24
# ✅ 481019: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 0, 12), AIC=214.96
# 📈 481092 예측 중...
# ✅ 481092: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=259.40
# ✅ 481092: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=1527.80
# 📈 481190 예측 중...
# ✅ 481190: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=121.75
# ✅ 481190: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 0, 12), AIC=-23.71
# 📈 490199 예측 중...
# ✅ 490199: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=89.13
# ✅ 490199: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-229.89
# 📈 540211 예측 중...
# ✅ 540211: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=470.32
# ✅ 540211: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=686.13
# 📈 540247 예측 중...
# ✅ 540247: 최적 모델 order=(1, 0, 0), seasonal_order=(1, 0, 0, 12), AIC=-166.52
# ✅ 540247: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=51.85
# 📈 540249 예측 중...
# ✅ 540249: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-28.58
# ✅ 540249: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=398.74
# 📈 540752 예측 중...
# ✅ 540752: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-173.47
# ✅ 540752: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=9.18
# 📈 540761 예측 중...
# ✅ 540761: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-184.11
# ✅ 540761: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-17.06
# 📈 540792 예측 중...
# ✅ 540792: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=-72.46
# ✅ 540792: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=303.16
# 📈 550320 예측 중...
# ✅ 550320: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-209.46
# ✅ 550320: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=216.04
# 📈 560122 예측 중...
# ✅ 560122: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=277.98
# ✅ 560122: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=125.05
# 📈 560394 예측 중...
# ✅ 560394: 최적 모델 order=(1, 0, 0), seasonal_order=(0, 0, 1, 12), AIC=-167.95
# ✅ 560394: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-125.72
# 📈 560749 예측 중...
# ✅ 560749: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-120.71
# ✅ 560749: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=263.70
# 📈 590320 예측 중...
# ✅ 590320: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-243.98
# ✅ 590320: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-102.44
# 📈 590390 예측 중...
# ✅ 590390: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-192.68
# ✅ 590390: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-40.52
# 📈 591110 예측 중...
# ✅ 591110: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=437.02
# ✅ 591110: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=966.18
# 📈 600410 예측 중...
# ✅ 600410: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-196.48
# ✅ 600410: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=127.03
# 📈 600622 예측 중...
# ✅ 600622: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-159.64
# ✅ 600622: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=344.11
# 📈 600632 예측 중...
# ✅ 600632: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-231.09
# ✅ 600632: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 0, 12), AIC=264.68
# 📈 610910 예측 중...
# ✅ 610910: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-126.83
# ✅ 610910: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-217.14
# 📈 621710 예측 중...
# ✅ 621710: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-115.58
# ✅ 621710: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-107.83
# 📈 621790 예측 중...
# ✅ 621790: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=108.99
# ✅ 621790: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=405.07
# 📈 630293 예측 중...
# ✅ 630293: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=285.61
# ✅ 630293: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=343.17
# 📈 630710 예측 중...
# ✅ 630710: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-215.05
# ✅ 630710: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=263.85
# 📈 630900 예측 중...
# ✅ 630900: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-107.27
# ✅ 630900: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-91.72
# 📈 680421 예측 중...
# ✅ 680421: 최적 모델 order=(1, 1, 0), seasonal_order=(0, 0, 1, 12), AIC=-249.47
# ✅ 680421: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-124.17
# 📈 690919 예측 중...
# ✅ 690919: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=207.19
# ✅ 690919: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-114.47
# 📈 691490 예측 중...
# ✅ 691490: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-39.67
# ✅ 691490: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=34.57
# 📈 700319 예측 중...
# ✅ 700319: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=2569.53
# ✅ 700319: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=526.10
# 📈 700490 예측 중...
# ✅ 700490: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 1, 1, 12), AIC=2089.50
# ✅ 700490: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=692.52
# 📈 700529 예측 중...
# ✅ 700529: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=295.39
# ✅ 700529: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=80.48
# 📈 700600 예측 중...
# ✅ 700600: 최적 모델 order=(1, 0, 0), seasonal_order=(0, 0, 1, 12), AIC=278.50
# ✅ 700600: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=56.11
# 📈 701349 예측 중...
# ✅ 701349: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=566.40
# ✅ 701349: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-23.96
# 📈 702000 예측 중...
# ✅ 702000: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=14.11
# ✅ 702000: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-206.96
# 📈 710510 예측 중...
# ✅ 710510: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=38.03
# ✅ 710510: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=52.16
# 📈 710610 예측 중...
# ✅ 710610: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=419.92
# ✅ 710610: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=215.01
# 📈 710691 예측 중...
# ✅ 710691: 최적 모델 order=(1, 1, 0), seasonal_order=(1, 0, 1, 12), AIC=36.31
# ✅ 710691: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=2008.17
# 📈 710812 예측 중...
# ✅ 710812: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=957.96
# ✅ 710812: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=501.40
# 📈 710813 예측 중...
# ✅ 710813: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=467.85
# ✅ 710813: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=1050.73
# 📈 711021 예측 중...
# ✅ 711021: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 1, 1, 12), AIC=1727.23
# ✅ 711021: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=279.16
# 📈 711292 예측 중...
# ✅ 711292: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=1424.25
# ✅ 711292: 최적 모델 order=(0, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=956.81
# 📈 711319 예측 중...
# ✅ 711319: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=387.52
# ✅ 711319: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=143.93
# 📈 711890 예측 중...
# ✅ 711890: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=2490.06
# ✅ 711890: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 1, 1, 12), AIC=951.86
# 📈 720270 예측 중...
# ✅ 720270: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=644.87
# ✅ 720270: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 1, 1, 12), AIC=2639.36
# 📈 720712 예측 중...
# ✅ 720712: 최적 모델 order=(0, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=2647.91
# ✅ 720712: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=542.89
# 📈 720826 예측 중...
# ✅ 720826: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=65.62
# ✅ 720826: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=1139.00
# 📈 720827 예측 중...
# ✅ 720827: 최적 모델 order=(1, 0, 0), seasonal_order=(0, 0, 1, 12), AIC=-45.09
# ✅ 720827: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=1245.26
# 📈 720836 예측 중...
# ✅ 720836: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=438.46
# ✅ 720836: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=1485.28
# 📈 720837 예측 중...
# ✅ 720837: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=305.29
# ✅ 720837: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=543.48
# 📈 720838 예측 중...
# ✅ 720838: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 0, 12), AIC=300.34
# ✅ 720838: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 0, 12), AIC=236.74
# 📈 720839 예측 중...
# ✅ 720839: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=75.25
# ✅ 720839: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 0, 12), AIC=101.81
# 📈 720851 예측 중...
# ✅ 720851: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-22.01
# ✅ 720851: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=266.50
# 📈 720852 예측 중...
# ✅ 720852: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=404.04
# ✅ 720852: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 1, 1, 12), AIC=1184.64
# 📈 720916 예측 중...
# ✅ 720916: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-123.23
# ✅ 720916: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=756.19
# 📈 720917 예측 중...
# ✅ 720917: 최적 모델 order=(1, 0, 0), seasonal_order=(0, 0, 1, 12), AIC=-182.75
# ✅ 720917: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=630.34
# 📈 720918 예측 중...
# ✅ 720918: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-38.42
# ✅ 720918: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 1, 1, 12), AIC=725.24
# 📈 721012 예측 중...
# ✅ 721012: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=-91.20
# ✅ 721012: 최적 모델 order=(0, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=1343.22
# 📈 721030 예측 중...
# ✅ 721030: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 0, 12), AIC=-68.27
# ✅ 721030: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=344.68
# 📈 721049 예측 중...
# ✅ 721049: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-176.84
# ✅ 721049: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=288.38
# 📈 721061 예측 중...
# ✅ 721061: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 0, 12), AIC=-55.17
# ✅ 721061: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=2618.62
# 📈 721069 예측 중...
# ✅ 721069: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 0, 12), AIC=158.77
# ✅ 721069: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=2461.61
# 📈 721070 예측 중...
# ✅ 721070: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-231.72
# ✅ 721070: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=946.37
# 📈 721240 예측 중...
# ✅ 721240: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-47.81
# ✅ 721240: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=403.36
# 📈 721391 예측 중...
# ✅ 721391: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 0, 12), AIC=259.82
# ✅ 721391: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=275.60
# 📈 721633 예측 중...
# ✅ 721633: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 0, 12), AIC=200.82
# ✅ 721633: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 0, 12), AIC=372.15
# 📈 721710 예측 중...
# ✅ 721710: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-197.51
# ✅ 721710: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 1, 1, 12), AIC=403.95
# 📈 721730 예측 중...
# ✅ 721730: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-89.28
# ✅ 721730: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=298.12
# 📈 721912 예측 중...
# ✅ 721912: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=554.31
# ✅ 721912: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=305.01
# 📈 721913 예측 중...
# ✅ 721913: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=377.95
# ✅ 721913: 최적 모델 order=(1, 0, 0), seasonal_order=(0, 1, 1, 12), AIC=510.65
# 📈 721933 예측 중...
# ✅ 721933: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=323.37
# ✅ 721933: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=371.96
# 📈 721934 예측 중...
# ✅ 721934: 최적 모델 order=(1, 0, 0), seasonal_order=(0, 0, 1, 12), AIC=-53.72
# ✅ 721934: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=148.18
# 📈 722020 예측 중...
# ✅ 722020: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=30.55
# ✅ 722020: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=103.41
# 📈 722300 예측 중...
# ✅ 722300: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-232.12
# ✅ 722300: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-31.81
# 📈 722519 예측 중...
# ✅ 722519: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=348.54
# ✅ 722519: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=723.49
# 📈 722530 예측 중...
# ✅ 722530: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=1378.92
# ✅ 722530: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=2110.60
# 📈 722550 예측 중...
# ✅ 722550: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 1, 1, 12), AIC=1226.33
# ✅ 722550: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=1001.11
# 📈 722592 예측 중...
# ✅ 722592: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=502.56
# ✅ 722592: 최적 모델 order=(0, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=2043.74
# 📈 722599 예측 중...
# ✅ 722599: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 1, 1, 12), AIC=1290.88
# ✅ 722599: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=791.87
# 📈 722790 예측 중...
# ✅ 722790: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=290.25
# ✅ 722790: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=208.34
# 📈 722830 예측 중...
# ✅ 722830: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=128.71
# ✅ 722830: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=399.89
# 📈 722990 예측 중...
# ✅ 722990: 최적 모델 order=(1, 1, 0), seasonal_order=(0, 0, 1, 12), AIC=-168.18
# ✅ 722990: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=187.59
# 📈 730511 예측 중...
# ✅ 730511: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=569.17
# ✅ 730511: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 1, 1, 12), AIC=849.96
# 📈 730512 예측 중...
# ✅ 730512: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=799.72
# ⚠️ 730512: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=730512, col=impDlr_yoy
# 📈 730531 예측 중...
# ✅ 730531: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=501.76
# ✅ 730531: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=1480.89
# 📈 730629 예측 중...
# ✅ 730629: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=2456.55
# ✅ 730629: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=2496.57
# 📈 730630 예측 중...
# ✅ 730630: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=-35.70
# ✅ 730630: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=275.93
# 📈 730640 예측 중...
# ✅ 730640: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=114.85
# ✅ 730640: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=413.10
# 📈 730729 예측 중...
# ✅ 730729: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-121.47
# ✅ 730729: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=128.91
# 📈 730791 예측 중...
# ✅ 730791: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-17.61
# ✅ 730791: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=94.99
# 📈 730793 예측 중...
# ✅ 730793: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-16.73
# ✅ 730793: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=493.82
# 📈 730799 예측 중...
# ✅ 730799: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-73.47
# ✅ 730799: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=135.35
# 📈 730840 예측 중...
# ✅ 730840: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=343.64
# ✅ 730840: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=977.86
# 📈 730890 예측 중...
# ✅ 730890: 최적 모델 order=(0, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=799.61
# ✅ 730890: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=276.91
# 📈 730900 예측 중...
# ✅ 730900: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=481.85
# ✅ 730900: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=776.72
# 📈 731100 예측 중...
# ✅ 731100: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=52.87
# ✅ 731100: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=88.36
# 📈 731210 예측 중...
# ✅ 731210: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-207.11
# ✅ 731210: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-116.27
# 📈 731815 예측 중...
# ✅ 731815: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-162.65
# ✅ 731815: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 0, 12), AIC=253.02
# 📈 731816 예측 중...
# ✅ 731816: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-119.04
# ✅ 731816: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-199.60
# 📈 732182 예측 중...
# ✅ 732182: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=1408.70
# ✅ 732182: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=1687.30
# 📈 732290 예측 중...
# ✅ 732290: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=882.86
# ✅ 732290: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=647.99
# 📈 732690 예측 중...
# ✅ 732690: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-225.07
# ✅ 732690: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-119.74
# 📈 740200 예측 중...
# ✅ 740200: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=2429.31
# ✅ 740200: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=2271.68
# 📈 740311 예측 중...
# ✅ 740311: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=294.88
# ✅ 740311: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-5.94
# 📈 740321 예측 중...
# ✅ 740321: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=227.96
# ✅ 740321: 최적 모델 order=(0, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=3880.54
# 📈 740400 예측 중...
# ✅ 740400: 최적 모델 order=(1, 0, 0), seasonal_order=(0, 1, 1, 12), AIC=467.35
# ✅ 740400: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=60.17
# 📈 740721 예측 중...
# ✅ 740721: 최적 모델 order=(1, 0, 0), seasonal_order=(1, 0, 0, 12), AIC=183.79
# ✅ 740721: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=901.45
# 📈 740811 예측 중...
# ✅ 740811: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=114.59
# ✅ 740811: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=776.22
# 📈 740819 예측 중...
# ✅ 740819: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=103.30
# ✅ 740819: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=735.12
# 📈 740911 예측 중...
# ✅ 740911: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=128.97
# ✅ 740911: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=308.15
# 📈 740921 예측 중...
# ✅ 740921: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=13.53
# ✅ 740921: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=534.15
# 📈 740990 예측 중...
# ✅ 740990: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=294.63
# ✅ 740990: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-11.64
# 📈 741011 예측 중...
# ✅ 741011: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=87.75
# ✅ 741011: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-106.66
# 📈 741021 예측 중...
# ✅ 741021: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=-73.43
# ✅ 741021: 최적 모델 order=(1, 0, 0), seasonal_order=(1, 0, 1, 12), AIC=-232.94
# 📈 741110 예측 중...
# ✅ 741110: 최적 모델 order=(1, 1, 0), seasonal_order=(0, 0, 1, 12), AIC=-81.40
# ✅ 741110: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=226.56
# 📈 741999 예측 중...
# ✅ 741999: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=293.09
# ✅ 741999: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=36.25
# 📈 760120 예측 중...
# ✅ 760120: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=167.23
# ✅ 760120: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=20.37
# 📈 760612 예측 중...
# ✅ 760612: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-137.02
# ✅ 760612: 최적 모델 order=(1, 1, 0), seasonal_order=(1, 0, 1, 12), AIC=-191.17
# 📈 760711 예측 중...
# ✅ 760711: 최적 모델 order=(1, 1, 0), seasonal_order=(0, 0, 1, 12), AIC=-341.03
# ✅ 760711: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=-80.11
# 📈 761090 예측 중...
# ✅ 761090: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=213.11
# ✅ 761090: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 0, 0, 12), AIC=353.29
# 📈 761699 예측 중...
# ✅ 761699: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-111.31
# ✅ 761699: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-151.02
# 📈 780110 예측 중...
# ✅ 780110: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=396.83
# ✅ 780110: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=198.10
# 📈 780199 예측 중...
# ✅ 780199: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=200.22
# ✅ 780199: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=733.91
# 📈 790111 예측 중...
# ✅ 790111: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=102.53
# ✅ 790111: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=399.99
# 📈 790112 예측 중...
# ✅ 790112: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=268.74
# ✅ 790112: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=2973.21
# 📈 790120 예측 중...
# ✅ 790120: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=224.76
# ✅ 790120: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=2419.52
# 📈 820730 예측 중...
# ✅ 820730: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=134.18
# ✅ 820730: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=529.13
# 📈 820740 예측 중...
# ✅ 820740: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-85.06
# ✅ 820740: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=74.37
# 📈 820750 예측 중...
# ✅ 820750: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=-61.07
# ✅ 820750: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-315.04
# 📈 820770 예측 중...
# ✅ 820770: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-189.61
# ✅ 820770: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-111.63
# 📈 820900 예측 중...
# ✅ 820900: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-168.80
# ✅ 820900: 최적 모델 order=(1, 1, 0), seasonal_order=(1, 0, 1, 12), AIC=-268.89
# 📈 830230 예측 중...
# ✅ 830230: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=260.53
# ✅ 830230: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=189.67
# 📈 831120 예측 중...
# ✅ 831120: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-169.22
# ✅ 831120: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=139.61
# 📈 840310 예측 중...
# ✅ 840310: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=208.69
# ✅ 840310: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=750.66
# 📈 840410 예측 중...
# ✅ 840410: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=1258.61
# ✅ 840410: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=1755.22
# 📈 840510 예측 중...
# ✅ 840510: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=1253.54
# ✅ 840510: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=569.14
# 📈 840690 예측 중...
# ✅ 840690: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=958.70
# ✅ 840690: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=888.33
# 📈 840733 예측 중...
# ✅ 840733: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=934.15
# ✅ 840733: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=1883.87
# 📈 840734 예측 중...
# ✅ 840734: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=334.83
# ✅ 840734: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 1, 1, 12), AIC=654.85
# 📈 840810 예측 중...
# ✅ 840810: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=331.96
# ✅ 840810: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=703.72
# 📈 840890 예측 중...
# ✅ 840890: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=121.68
# ✅ 840890: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=92.07
# 📈 840991 예측 중...
# ✅ 840991: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 0, 0, 12), AIC=64.96
# ✅ 840991: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=-214.16
# 📈 840999 예측 중...
# ✅ 840999: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-257.57
# ✅ 840999: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-204.63
# 📈 841112 예측 중...
# ✅ 841112: 최적 모델 order=(0, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=3474.17
# ✅ 841112: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 1, 1, 12), AIC=3248.50
# 📈 841191 예측 중...
# ✅ 841191: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=113.49
# ✅ 841191: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=268.33
# 📈 841221 예측 중...
# ✅ 841221: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=141.75
# ✅ 841221: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=539.34
# 📈 841229 예측 중...
# ✅ 841229: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=231.87
# ✅ 841229: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=215.98
# 📈 841330 예측 중...
# ✅ 841330: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=20.24
# ✅ 841330: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-117.04
# 📈 841360 예측 중...
# ✅ 841360: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=1010.80
# ✅ 841360: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=37.01
# ...
# 📈 890190 예측 중...
# ✅ 890190: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=859.42
# ✅ 890190: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 1, 1, 12), AIC=1871.25
# 📈 890590 예측 중...
# ✅ 890590: 최적 모델 order=(0, 0, 0), seasonal_order=(0, 1, 1, 12), AIC=3595.22
# ✅ 890590: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 1, 1, 12), AIC=2311.65
# 📈 900120 예측 중...
# ✅ 900120: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-162.75
# ✅ 900120: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-111.43
# 📈 900130 예측 중...
# ✅ 900130: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-129.10
# ✅ 900130: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=87.37
# 📈 900190 예측 중...
# ✅ 900190: 최적 모델 order=(1, 0, 0), seasonal_order=(1, 0, 1, 12), AIC=-171.71
# ✅ 900190: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-118.77
# 📈 900211 예측 중...
# ✅ 900211: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-15.59
# ✅ 900211: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-36.57
# 📈 900290 예측 중...
# ✅ 900290: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=538.56
# ✅ 900290: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=444.03
# 📈 900691 예측 중...
# ✅ 900691: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=558.21
# ✅ 900691: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=141.66
# 📈 901210 예측 중...
# ✅ 901210: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=548.08
# ✅ 901210: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=605.65
# 📈 901320 예측 중...
# ✅ 901320: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=720.20
# ✅ 901320: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=31.08
# 📈 901390 예측 중...
# ✅ 901390: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=66.04
# ✅ 901390: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=32.97
# 📈 901812 예측 중...
# ✅ 901812: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 0, 12), AIC=-147.51
# ✅ 901812: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=233.06
# 📈 901819 예측 중...
# ✅ 901819: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-145.27
# ✅ 901819: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-143.53
# 📈 901832 예측 중...
# ✅ 901832: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-146.78
# ✅ 901832: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-0.88
# 📈 901849 예측 중...
# ✅ 901849: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=157.52
# ✅ 901849: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-62.72
# 📈 901890 예측 중...
# ✅ 901890: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-88.89
# ✅ 901890: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-305.83
# 📈 902129 예측 중...
# ✅ 902129: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=102.52
# ✅ 902129: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=65.56
# 📈 902190 예측 중...
# ✅ 902190: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-47.30
# ✅ 902190: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-239.30
# 📈 902213 예측 중...
# ✅ 902213: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=344.92
# ✅ 902213: 최적 모델 order=(0, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=771.19
# 📈 902214 예측 중...
# ✅ 902214: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=64.75
# ✅ 902214: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=364.92
# 📈 902219 예측 중...
# ✅ 902219: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=546.97
# ✅ 902219: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=372.39
# 📈 902290 예측 중...
# ✅ 902290: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=-205.81
# ✅ 902290: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-232.66
# 📈 902610 예측 중...
# ✅ 902610: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=444.38
# ✅ 902610: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-126.39
# 📈 902620 예측 중...
# ✅ 902620: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=232.97
# ✅ 902620: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-50.49
# 📈 902710 예측 중...
# ✅ 902710: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=414.11
# ✅ 902710: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=19.72
# 📈 902750 예측 중...
# ✅ 902750: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=387.91
# ✅ 902750: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=224.58
# 📈 902790 예측 중...
# ✅ 902790: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-16.45
# ✅ 902790: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-250.35
# 📈 902920 예측 중...
# ✅ 902920: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=412.48
# ✅ 902920: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=276.33
# 📈 903040 예측 중...
# ✅ 903040: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=383.64
# ✅ 903040: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 0, 12), AIC=229.45
# 📈 903082 예측 중...
# ✅ 903082: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=672.98
# ✅ 903082: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 0, 12), AIC=425.73
# 📈 903090 예측 중...
# ✅ 903090: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=81.00
# ✅ 903090: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-56.52
# 📈 903141 예측 중...
# ✅ 903141: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=909.76
# ✅ 903141: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=1008.81
# 📈 903149 예측 중...
# ✅ 903149: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=412.51
# ✅ 903149: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 0, 12), AIC=122.62
# 📈 903180 예측 중...
# ✅ 903180: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-2.23
# ✅ 903180: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 0, 12), AIC=-27.26
# 📈 903190 예측 중...
# ✅ 903190: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=133.58
# ✅ 903190: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-57.72
# 📈 903289 예측 중...
# ✅ 903289: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=64.50
# ✅ 903289: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-119.32
# 📈 940130 예측 중...
# ✅ 940130: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=49.14
# ✅ 940130: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=295.32
# 📈 940330 예측 중...
# ✅ 940330: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 0, 12), AIC=429.26
# ✅ 940330: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-154.44
# 📈 940540 예측 중...
# ✅ 940540: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=306.52
# ✅ 940540: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=12.36
# 📈 950300 예측 중...
# ✅ 950300: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-42.37
# ✅ 950300: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-169.03
# 📈 840130 예측 중...
# ⚠️ 840130: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=840130, col=expDlr_yoy
# ⚠️ 840130: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=840130, col=impDlr_yoy
# 📈 860500 예측 중...
# ⚠️ 860500: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=860500, col=expDlr_yoy
# ⚠️ 860500: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=860500, col=impDlr_yoy
# 📈 847521 예측 중...
# ⚠️ 847521: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=847521, col=expDlr_yoy
# ⚠️ 847521: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=847521, col=impDlr_yoy
# 📈 121221 예측 중...
# ✅ 121221: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=43.21
# ✅ 121221: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=328.57
# 📈 271012 예측 중...
# ✅ 271012: 최적 모델 order=(1, 0, 0), seasonal_order=(0, 0, 1, 12), AIC=87.67
# ✅ 271012: 최적 모델 order=(1, 0, 0), seasonal_order=(0, 0, 1, 12), AIC=32.17
# 📈 293190 예측 중...
# ✅ 293190: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-24.54
# ✅ 293190: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-101.81
# 📈 382600 예측 중...
# ✅ 382600: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=2190.33
# ✅ 382600: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 1, 1, 12), AIC=2240.63
# 📈 731940 예측 중...
# ✅ 731940: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-1.24
# ✅ 731940: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=62.45
# 📈 850760 예측 중...
# ✅ 850760: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-147.20
# ✅ 850760: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=64.98
# 📈 852349 예측 중...
# ✅ 852349: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=288.23
# ✅ 852349: 최적 모델 order=(0, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=271.65
# 📈 220299 예측 중...
# ✅ 220299: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=-83.62
# ✅ 220299: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-58.86
# 📈 300212 예측 중...
# ✅ 300212: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=129.15
# ✅ 300212: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=2.74
# 📈 300214 예측 중...
# ✅ 300214: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=138.18
# ✅ 300214: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=425.50
# 📈 300215 예측 중...
# ✅ 300215: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=214.56
# ✅ 300215: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=52.36
# 📈 370500 예측 중...
# ✅ 370500: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-58.75
# ✅ 370500: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-3.64
# 📈 381239 예측 중...
# ✅ 381239: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 0, 12), AIC=-74.55
# ✅ 381239: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-37.52
# 📈 382499 예측 중...
# ✅ 382499: 최적 모델 order=(1, 1, 0), seasonal_order=(0, 0, 1, 12), AIC=-11.49
# ✅ 382499: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 0, 12), AIC=-162.70
# 📈 390140 예측 중...
# ✅ 390140: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=23.09
# ✅ 390140: 최적 모델 order=(0, 0, 0), seasonal_order=(0, 0, 1, 12), AIC=2.57
# 📈 390761 예측 중...
# ✅ 390761: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-33.72
# ✅ 390761: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=87.79
# 📈 390769 예측 중...
# ✅ 390769: 최적 모델 order=(1, 0, 0), seasonal_order=(0, 0, 1, 12), AIC=-63.50
# ✅ 390769: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=75.81
# 📈 390931 예측 중...
# ✅ 390931: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=34.03
# ✅ 390931: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=66.58
# 📈 600537 예측 중...
# ✅ 600537: 최적 모델 order=(1, 0, 0), seasonal_order=(0, 0, 1, 12), AIC=-51.01
# ✅ 600537: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=123.96
# 📈 845611 예측 중...
# ✅ 845611: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=148.85
# ✅ 845611: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=41.85
# 📈 852852 예측 중...
# ✅ 852852: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=25.99
# ✅ 852852: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 0, 12), AIC=21.82
# 📈 870191 예측 중...
# ✅ 870191: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=58.37
# ✅ 870191: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=614.59
# 📈 870192 예측 중...
# ✅ 870192: 최적 모델 order=(1, 0, 0), seasonal_order=(1, 0, 1, 12), AIC=9.64
# ✅ 870192: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=342.92
# 📈 870193 예측 중...
# ✅ 870193: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=44.65
# ✅ 870193: 최적 모델 order=(0, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=167.25
# 📈 870340 예측 중...
# ✅ 870340: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 0, 0, 12), AIC=54.60
# ✅ 870340: 최적 모델 order=(0, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=302.09
# 📈 870360 예측 중...
# ✅ 870360: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=116.56
# ✅ 870360: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 1, 1, 12), AIC=385.57
# 📈 870380 예측 중...
# ✅ 870380: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=84.56
# ✅ 870380: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=465.40
# 📈 300249 예측 중...
# ⚠️ 300249: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=300249, col=expDlr_yoy
# ⚠️ 300249: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=300249, col=impDlr_yoy
# 📈 382219 예측 중...
# ⚠️ 382219: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=382219, col=expDlr_yoy
# ⚠️ 382219: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=382219, col=impDlr_yoy
# 📈 390729 예측 중...
# ⚠️ 390729: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=390729, col=expDlr_yoy
# ⚠️ 390729: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=390729, col=impDlr_yoy
# 📈 620240 예측 중...
# ⚠️ 620240: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=620240, col=expDlr_yoy
# ⚠️ 620240: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=620240, col=impDlr_yoy
# 📈 681511 예측 중...
# ⚠️ 681511: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=681511, col=expDlr_yoy
# ⚠️ 681511: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=681511, col=impDlr_yoy
# 📈 741980 예측 중...
# ⚠️ 741980: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=741980, col=expDlr_yoy
# ⚠️ 741980: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=741980, col=impDlr_yoy
# 📈 846242 예측 중...
# ⚠️ 846242: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=846242, col=expDlr_yoy
# ⚠️ 846242: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=846242, col=impDlr_yoy
# 📈 846262 예측 중...
# ⚠️ 846262: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=846262, col=expDlr_yoy
# ⚠️ 846262: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=846262, col=impDlr_yoy
# 📈 846290 예측 중...
# ⚠️ 846290: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=846290, col=expDlr_yoy
# ⚠️ 846290: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=846290, col=impDlr_yoy
# 📈 851419 예측 중...
# ⚠️ 851419: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=851419, col=expDlr_yoy
# ⚠️ 851419: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=851419, col=impDlr_yoy
# 📈 851713 예측 중...
# ⚠️ 851713: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=851713, col=expDlr_yoy
# ⚠️ 851713: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=851713, col=impDlr_yoy
# 📈 851779 예측 중...
# ⚠️ 851779: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=851779, col=expDlr_yoy
# ⚠️ 851779: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=851779, col=impDlr_yoy
# 📈 852411 예측 중...
# ⚠️ 852411: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=852411, col=expDlr_yoy
# ⚠️ 852411: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=852411, col=impDlr_yoy
# 📈 852412 예측 중...
# ⚠️ 852412: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=852412, col=expDlr_yoy
# ⚠️ 852412: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=852412, col=impDlr_yoy
# 📈 852492 예측 중...
# ⚠️ 852492: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=852492, col=expDlr_yoy
# ⚠️ 852492: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=852492, col=impDlr_yoy
# 📈 852589 예측 중...
# ⚠️ 852589: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=852589, col=expDlr_yoy
# ⚠️ 852589: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=852589, col=impDlr_yoy
# 📈 854141 예측 중...
# ⚠️ 854141: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=854141, col=expDlr_yoy
# ⚠️ 854141: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=854141, col=impDlr_yoy
# 📈 854142 예측 중...
# ⚠️ 854142: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=854142, col=expDlr_yoy
# ⚠️ 854142: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=854142, col=impDlr_yoy
# 📈 854143 예측 중...
# ⚠️ 854143: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=854143, col=expDlr_yoy
# ⚠️ 854143: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=854143, col=impDlr_yoy
# 📈 854149 예측 중...
# ⚠️ 854149: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=854149, col=expDlr_yoy
# ⚠️ 854149: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=854149, col=impDlr_yoy
# 📈 854159 예측 중...
# ⚠️ 854159: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=854159, col=expDlr_yoy
# ⚠️ 854159: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=854159, col=impDlr_yoy
# 📈 880730 예측 중...
# ⚠️ 880730: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=880730, col=expDlr_yoy
# ⚠️ 880730: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=880730, col=impDlr_yoy
# 📈 902789 예측 중...
# ⚠️ 902789: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=902789, col=expDlr_yoy
# ⚠️ 902789: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=902789, col=impDlr_yoy
# 📈 940199 예측 중...
# ⚠️ 940199: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=940199, col=expDlr_yoy
# ⚠️ 940199: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=940199, col=impDlr_yoy
# 📈 970191 예측 중...
# ⚠️ 970191: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=970191, col=expDlr_yoy
# ⚠️ 970191: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=970191, col=impDlr_yoy

# %%
# forecast_by_month[forecast_by_month['target_col'] == 'expDlr_yoy'].tail(20)

# %%
# 예측 실행 결과 (from run_forecasting_pipeline)
forecast_df = forecast_by_month

# 'expDlr_yoy_forecast' → 'yoy_forecast'로 정리
if 'expDlr_yoy_forecast' in forecast_df.columns:
    forecast_df = forecast_df.rename(columns={'expDlr_yoy_forecast': 'yoy_forecast'})
elif 'impDlr_yoy_forecast' in forecast_df.columns:
    forecast_df = forecast_df.rename(columns={'impDlr_yoy_forecast': 'yoy_forecast'})

# DB에서 데이터 불러오기
trade_data_df = load_monthly_trade_data_from_db()

# 🧩 Step 1: forecast_df 피벗
forecast_df_pivoted = pivot_forecast_df(forecast_df)

# 🧩 Step 2: merge 실행'
final_combined_df = merge_forecast_with_actuals(forecast_df_pivoted, trade_data_df)

# hs_code_list = ['854232', '854231']
# hs_code_list
forecast_result_df = final_combined_df[final_combined_df['root_hs_code'].isin(hs_cd_list)]
forecast_result_data = forecast_result_df[['date', 'root_hs_code', 'final_expDlr_yoy', 'expDlr_forecast_12m']]

# %%
db_info = {
    'host' : '192.168.0.230',
    'port' : 3307,
    'user' : 'stox7412',
    'password' : 'Apt106503!~',
    'database' : 'investar'
}

upload_forecast_to_db(forecast_result_data, db_info)
# Out:
# ✅ 데이터가 korea_trade_forecast_by_month 테이블에 성공적으로 업로드되었습니다. (중복 시 자동 갱신)

# %% [markdown]
# ### 예측 정확성 측정을 위해 예측치만 별도로 DB에 보관한다

# %%
from datetime import datetime

# 📌 2. 전처리
today_date = datetime.today().strftime('%Y-%m-%d')

# 'period' 제거
if 'period' in forecast_by_month.columns:
    df = forecast_by_month.drop(columns=['period'])

# 'hs_code' → 'root_hs_code'로 변경
df = forecast_by_month.rename(columns={'hs_code': 'root_hs_code'})

# forecast_date 추가
df['forecast_date'] = today_date

# SQLAlchemy 엔진 생성
engine = create_engine(
    f"mysql+pymysql://{db_info['user']}:{db_info['password']}@{db_info['host']}:{db_info['port']}/{db_info['database']}"
)
# 📌 4. DB 업로드
table_name = 'korea_trade_data_forecast_record'
df.to_sql(name=table_name, con=engine, if_exists='append', index=False)

print(f"✅ {table_name} 테이블에 {len(df)}건 업로드 완료 (날짜: {today_date})")
# Out:
# ✅ korea_trade_data_forecast_record 테이블에 13871건 업로드 완료 (날짜: 2025-06-12)
