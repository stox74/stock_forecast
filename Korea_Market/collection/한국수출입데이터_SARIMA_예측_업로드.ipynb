# %%
import pandas as pd
from sqlalchemy import create_engine
from statsmodels.tsa.statespace.sarimax import SARIMAX
import matplotlib.pyplot as plt
import numpy as np
from DATA.stock_invest_function import *
import warnings
warnings.filterwarnings("ignore")

# %%
def forecast_yoy_growth_auto(df, col, forecast_steps=12, seasonal=True):
    """
    최적 SARIMAX 파라미터를 자동 탐색하여 수출입 증가율 예측.
    월별 데이터가 72개월 미만일 경우 예측을 수행하지 않습니다.

    Parameters:
        df (pd.DataFrame): 'period' (datetime), 예측 대상 컬럼 포함
        col (str): 예측 컬럼 (예: 'expDlr_yoy')
        forecast_steps (int): 예측 기간 (월 기준 12, 분기 기준 4)
        seasonal (bool): 계절성 사용 여부
    """
    df = df[['period', col]].dropna().copy()
    df = df.set_index('period').sort_index()
    ts = df[col]

    # ✅ 데이터 길이 검사
    if forecast_steps > 4 and len(ts) < 72:
        print("⚠️ 월 데이터가 6년치(72개월) 미만입니다. 충분한 데이터 기간 기준에 미달합니다.")
        return None
    elif forecast_steps <= 4 and len(ts) < 16:
        print("⚠️ 분기 데이터가 4년치(16분기) 미만입니다. 충분한 데이터 기간 기준에 미달합니다.")
        return None

    # SARIMA 파라미터 범위
    p = d = q = range(0, 2)
    pdq = [(x, y, z) for x in p for y in d for z in q]
    seasonal_pdq = [(x, y, z) for x in p for y in d for z in q]
    seasonal_period = 12 if forecast_steps > 4 else 4

    best_model, best_order, best_seasonal_order = sarimax_grid_search(ts, pdq, seasonal_pdq, seasonal_period)

    # 예측
    future_index = pd.date_range(
        start=ts.index[-1] + pd.offsets.DateOffset(months=1 if seasonal_period == 12 else 3),
        periods=forecast_steps,
        freq='M' if seasonal_period == 12 else 'Q'
    )

    forecast = best_model.forecast(steps=forecast_steps)
    forecast.index = future_index

    # 시각화
    plt.figure(figsize=(12, 6))
    plt.plot(ts.index, ts, label='Actual')
    plt.plot(forecast.index, forecast, label='Forecast', linestyle='--', color='red')
    plt.title(f"{col} 예측 (Auto SARIMAX)")
    plt.ylabel('YoY Growth')
    plt.xticks(rotation=45)
    plt.legend()
    plt.tight_layout()
    plt.show()

# %%
# ✅ 수정된 DB 구조에 맞춘 데이터 로딩 함수
def load_monthly_trade_data_from_db():
    host : get_db_host()
    # host = '192.168.0.230'
    port = 3307
    user = 'stox7412'
    password = 'Apt106503!~'
    database = 'investar'
    engine = create_engine(f'mysql+pymysql://{user}:{password}@{host}:{port}/{database}')
    query = "SELECT * FROM korea_monthly_trade_data"
    df = pd.read_sql(query, con=engine)
    return df


# ✅ 수정된 long format 기반 SARIMA 예측 함수
def forecast_yoy_growth_auto_with_ci(df, col, hs_code, forecast_steps):
    warnings.filterwarnings("ignore")
    df_hs = df[(df['root_hs_code'] == hs_code) & (df['indicator'] == col)].copy()

    if df_hs.empty:
        print(f"❌ {hs_code} | '{col}'에 해당하는 데이터가 없습니다.")
        return None, None

    df_hs['date'] = pd.to_datetime(df_hs['date'])
    df_hs = df_hs.set_index('date').sort_index()
    ts = df_hs['value'].astype(float).dropna()

    if forecast_steps > 4 and len(ts) < 72:
        print(f"⚠️ {hs_code}: 월 데이터가 6년치 미만입니다.")
        return None, None

    best_aic = np.inf
    best_order = None
    best_seasonal_order = None
    best_model = None

    p = d = q = range(0, 2)
    P = D = Q = range(0, 2)
    m = 12

    for order in [(p_, d_, q_) for p_ in p for d_ in d for q_ in q]:
        for seasonal_order in [(P_, D_, Q_, m) for P_ in P for D_ in D for Q_ in Q]:
            try:
                model = SARIMAX(ts,
                                order=order,
                                seasonal_order=seasonal_order,
                                enforce_stationarity=False,
                                enforce_invertibility=False)
                result = model.fit(disp=False)
                if result.aic < best_aic:
                    best_aic = result.aic
                    best_order = order
                    best_seasonal_order = seasonal_order
                    best_model = result
            except:
                continue

    if best_model is None:
        print(f"❌ {hs_code}: SARIMAX 모델 최적화 실패")
        return None, None

    forecast_result = best_model.get_forecast(steps=forecast_steps)
    pred_mean = forecast_result.predicted_mean
    conf_int = forecast_result.conf_int()
    future_index = pd.date_range(start=ts.index[-1] + pd.DateOffset(months=1), periods=forecast_steps, freq='M')

    forecast_df = pd.DataFrame({
        col + '_forecast': pred_mean.values,
        col + '_lower': conf_int.iloc[:, 0].values,
        col + '_upper': conf_int.iloc[:, 1].values
    }, index=future_index)

    print(f"✅ {hs_code}: 최적 모델 order={best_order}, seasonal_order={best_seasonal_order}, AIC={best_aic:.2f}")
    return forecast_df, df_hs

# ✅ forecast 시계열 결합 함수 (기존과 동일)
def build_forecasted_series(base_df, forecast_df, col_name):
    full_df = pd.concat([base_df[['value']], forecast_df[[col_name + '_forecast']]], axis=0)
    full_df[col_name + '_forecast'] = pd.to_numeric(full_df[col_name + '_forecast'], errors='coerce')
    full_df[col_name + '_forecast'] = full_df[col_name + '_forecast'].replace([np.inf, -np.inf], np.nan)
    full_df[col_name + '_estimated'] = full_df[col_name + '_forecast'].shift(1) * (1 + full_df[col_name + '_forecast'])
    return full_df

# ✅ 전체 파이프라인 실행 함수
def run_forecasting_pipeline(db_info, hs_code_list, max_hs_count=3, forecast_steps = 12):
    export_m_with_yoy = fetch_table_data(db_info, "korea_monthly_trade_data")
    hs_code_list = hs_code_list[:max_hs_count]
    result_list = []

    for hs_code in hs_code_list:
        print(f"📈 {hs_code} 예측 중...")
        for target_col in ['expDlr_yoy', 'impDlr_yoy']:
            forecast_df, base_df = forecast_yoy_growth_auto_with_ci(export_m_with_yoy, target_col, hs_code, forecast_steps)

            if forecast_df is None or forecast_df.empty:
                print(f"⚠️ 예측 실패 또는 결과 없음 | hs_code={hs_code}, col={target_col}")
                continue

            full_df = build_forecasted_series(base_df, forecast_df, target_col)
            forecast_only = forecast_df.copy()
            forecast_only['hs_code'] = hs_code
            forecast_only['target_col'] = target_col
            forecast_only['date'] = forecast_only.index
            forecast_only = forecast_only.reset_index(drop=True)

            result_list.append(forecast_only)

    if not result_list:
        print("❌ 모든 예측이 실패하여 결과가 없습니다.")
        return pd.DataFrame()

    final_df = pd.concat(result_list, ignore_index=True)
    return final_df

def merge_forecast_with_actuals(forecast_df, trade_data_df):
    import pandas as pd

    # 📌 1. 복사 및 컬럼명 정리
    forecast_df = forecast_df.copy()
    forecast_df = forecast_df.rename(columns={'hs_code': 'root_hs_code'})  # 혹시 모를 컬럼명 정리

    # 'period' → 'date'로 통일
    if 'period' in forecast_df.columns:
        forecast_df = forecast_df.rename(columns={'period': 'date'})

    forecast_df['date'] = pd.to_datetime(forecast_df['date'])
    trade_data_df['date'] = pd.to_datetime(trade_data_df['date'])

    # 예측 컬럼 확인
    forecast_cols = ['expDlr_yoy_forecast', 'impDlr_yoy_forecast']
    present_forecast_cols = [col for col in forecast_cols if col in forecast_df.columns]
    if not present_forecast_cols:
        raise KeyError("❌ forecast_df에 'expDlr_yoy_forecast' 또는 'impDlr_yoy_forecast' 컬럼이 없습니다.")

    # 📌 2. 무역 데이터 → wide 포맷으로 변환
    trade_pivot = trade_data_df.pivot_table(
        index=['date', 'root_hs_code'],
        columns='indicator',
        values='value',
        aggfunc='last'
    ).reset_index()

    # 📌 3. 예측 데이터 선택
    forecast_selected = forecast_df[['date', 'root_hs_code'] + present_forecast_cols].drop_duplicates()

    # 📌 4. 병합
    combined_df = pd.merge(
        trade_pivot,
        forecast_selected,
        on=['date', 'root_hs_code'],
        how='outer'
    ).sort_values(['root_hs_code', 'date']).reset_index(drop=True)

    # 📌 5. YoY 보정
    combined_df['final_expDlr_yoy'] = combined_df['expDlr_yoy']
    if 'expDlr_yoy_forecast' in combined_df.columns:
        combined_df.loc[combined_df['final_expDlr_yoy'].isna(), 'final_expDlr_yoy'] = combined_df['expDlr_yoy_forecast']

    combined_df['final_impDlr_yoy'] = combined_df['impDlr_yoy']
    if 'impDlr_yoy_forecast' in combined_df.columns:
        combined_df.loc[combined_df['final_impDlr_yoy'].isna(), 'final_impDlr_yoy'] = combined_df['impDlr_yoy_forecast']

    # 📌 6. 자료형 정리
    combined_df['final_expDlr_yoy'] = pd.to_numeric(combined_df['final_expDlr_yoy'], errors='coerce')
    combined_df['final_impDlr_yoy'] = pd.to_numeric(combined_df['final_impDlr_yoy'], errors='coerce')

    # 📌 7. 12개월 전 실적
    combined_df['expDlr_lag12'] = combined_df.groupby('root_hs_code')['expDlr'].shift(12)
    combined_df['impDlr_lag12'] = combined_df.groupby('root_hs_code')['impDlr'].shift(12)

    # 📌 8. 12개월 후 예측
    combined_df['expDlr_forecast_12m'] = combined_df['expDlr_lag12'] * (1 + combined_df['final_expDlr_yoy'])
    combined_df['impDlr_forecast_12m'] = combined_df['impDlr_lag12'] * (1 + combined_df['final_impDlr_yoy'])

    return combined_df

def pivot_forecast_df(forecast_df):
    # 피벗하여 target_col 기준으로 예측값을 컬럼화
    forecast_df = forecast_df.rename(columns={'hs_code': 'root_hs_code'})
    forecast_df['date'] = pd.to_datetime(forecast_df['date'])

    forecast_pivot = forecast_df.pivot_table(index=['date', 'root_hs_code'],
                                             columns='target_col',
                                             values='yoy_forecast').reset_index()

    # 컬럼 이름 정리
    forecast_pivot.columns.name = None
    forecast_pivot = forecast_pivot.rename(columns={
        'expDlr_yoy': 'expDlr_yoy_forecast',
        'impDlr_yoy': 'impDlr_yoy_forecast'
    })
    return forecast_pivot

def upload_forecast_to_db(df, db_info, table_name='korea_monthly_trade_data_forecast'):
    """
    예측 결과 데이터를 MySQL(MariaDB)에 업로드하는 함수 (중복 시 대체)

    Parameters:
    - df (pd.DataFrame): 업로드할 데이터프레임
    - db_info (dict): DB 연결 정보. keys = ['host', 'port', 'user', 'password', 'database']
    - table_name (str): 업로드할 테이블 이름
    """
    try:
        # ✅ SQLAlchemy 엔진 생성
        engine = create_engine(
            f"mysql+pymysql://{db_info['user']}:{db_info['password']}@{db_info['host']}:{db_info['port']}/{db_info['database']}"
        )
        conn = engine.raw_connection()
        cursor = conn.cursor()

        # ✅ 테이블 생성 (없을 경우)
        create_table_query = f"""
        CREATE TABLE IF NOT EXISTS {table_name} (
            date DATE,
            root_hs_code VARCHAR(20),
            final_expDlr_yoy FLOAT,
            expDlr_forecast_12m FLOAT,
            PRIMARY KEY (date, root_hs_code)
        );
        """
        cursor.execute(create_table_query)

        # ✅ NaN 및 NaT, inf → None 변환 (모든 타입 안전하게 처리)
        df = df.astype(object).where(pd.notnull(df), None)

        # ✅ REPLACE INTO
        insert_query = f"""
        REPLACE INTO {table_name} (date, root_hs_code, final_expDlr_yoy, expDlr_forecast_12m)
        VALUES (%s, %s, %s, %s)
        """
        data = df[['date', 'root_hs_code', 'final_expDlr_yoy', 'expDlr_forecast_12m']].values.tolist()
        cursor.executemany(insert_query, data)

        conn.commit()
        cursor.close()
        conn.close()

        print(f"✅ 데이터가 {table_name} 테이블에 성공적으로 업로드되었습니다. (중복 시 자동 갱신)")

    except Exception as e:
        print(f"❌ 업로드 실패: {e}")

# %%
db_info = {
    'host': get_db_host(),
    'port' : 3307,
    'user' : 'stox7412',
    'password' : 'Apt106503!~',
    'database' : 'investar'
}


trade_data_df =  fetch_table_data(db_info, "korea_monthly_trade_data")

hs_cd_list = trade_data_df['root_hs_code'].unique().tolist()
trade_data_df = fetch_table_data(db_info, "korea_monthly_trade_data")
# hs_cd_list = ['854232']
forecast_by_month = run_forecasting_pipeline(db_info, hs_code_list=hs_cd_list, max_hs_count=len(hs_cd_list), forecast_steps=13)
# Out:
# ✅ 'korea_monthly_trade_data' 테이블에서 788650건의 데이터를 가져왔습니다.
# ✅ 'korea_monthly_trade_data' 테이블에서 788650건의 데이터를 가져왔습니다.
# ✅ 'korea_monthly_trade_data' 테이블에서 788650건의 데이터를 가져왔습니다.
# 📈 121120 예측 중...
# ✅ 121120: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=387.67
# ✅ 121120: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=2165.74
# 📈 151550 예측 중...
# ✅ 151550: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=1247.31
# ✅ 151550: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 1, 1, 12), AIC=1279.98
# 📈 151590 예측 중...
# ✅ 151590: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=639.47
# ✅ 151590: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=5.70
# 📈 170199 예측 중...
# ✅ 170199: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-3.60
# ✅ 170199: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=549.98
# 📈 190230 예측 중...
# ✅ 190230: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=-240.92
# ✅ 190230: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=131.38
# 📈 190590 예측 중...
# ✅ 190590: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-277.71
# ✅ 190590: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-230.21
# 📈 200599 예측 중...
# ✅ 200599: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-240.05
# ✅ 200599: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-155.39
# 📈 200830 예측 중...
# ✅ 200830: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-47.10
# ✅ 200830: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=485.90
# 📈 200899 예측 중...
# ✅ 200899: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 1, 1, 12), AIC=729.22
# ✅ 200899: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-160.46
# 📈 210111 예측 중...
# ✅ 210111: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=131.80
# ✅ 210111: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=513.43
# 📈 210390 예측 중...
# ✅ 210390: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-186.09
# ✅ 210390: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=-308.70
# 📈 210690 예측 중...
# ✅ 210690: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-237.06
# ✅ 210690: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-305.33
# 📈 220890 예측 중...
# ✅ 220890: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-88.70
# ✅ 220890: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=70.24
# 📈 230910 예측 중...
# ✅ 230910: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=94.49
# ✅ 230910: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-194.69
# 📈 240220 예측 중...
# ✅ 240220: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=135.55
# ✅ 240220: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=721.59
# 📈 260300 예측 중...
# ✅ 260300: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 1, 1, 12), AIC=2319.13
# ✅ 260300: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=235.24
# 📈 270730 예측 중...
# ✅ 270730: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=489.32
# ✅ 270730: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 0, 12), AIC=143.57
# 📈 270750 예측 중...
# ✅ 270750: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 0, 12), AIC=215.78
# ✅ 270750: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=3302.08
# 📈 270799 예측 중...
# ✅ 270799: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=950.99
# ✅ 270799: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=623.98
# 📈 271019 예측 중...
# ✅ 271019: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-50.02
# ✅ 271019: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=301.90
# 📈 271113 예측 중...
# ✅ 271113: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-8.69
# ✅ 271113: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=175.28
# 📈 271119 예측 중...
# ✅ 271119: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=2863.21
# ✅ 271119: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=780.34
# 📈 271320 예측 중...
# ✅ 271320: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=172.32
# ✅ 271320: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 1, 1, 12), AIC=2083.84
# 📈 280300 예측 중...
# ✅ 280300: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=-58.92
# ✅ 280300: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-99.15
# 📈 280700 예측 중...
# ✅ 280700: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=502.58
# ✅ 280700: 최적 모델 order=(0, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=868.14
# 📈 281512 예측 중...
# ✅ 281512: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=675.70
# ✅ 281512: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=1296.74
# 📈 281520 예측 중...
# ✅ 281520: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=-79.15
# ✅ 281520: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=770.66
# 📈 282110 예측 중...
# ✅ 282110: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 0, 12), AIC=112.63
# ✅ 282110: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=45.12
# 📈 282520 예측 중...
# ✅ 282520: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=2092.15
# ✅ 282520: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=578.20
# 📈 283324 예측 중...
# ✅ 283324: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=1341.68
# ✅ 283324: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=822.99
# 📈 283691 예측 중...
# ✅ 283691: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=2677.59
# ✅ 283691: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=541.27
# 📈 283711 예측 중...
# ✅ 283711: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=91.61
# ✅ 283711: 최적 모델 order=(0, 0, 0), seasonal_order=(0, 1, 1, 12), AIC=3005.29
# 📈 284190 예측 중...
# ✅ 284190: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=276.56
# ✅ 284190: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=225.94
# 📈 290121 예측 중...
# ✅ 290121: 최적 모델 order=(1, 0, 0), seasonal_order=(0, 0, 1, 12), AIC=153.49
# ✅ 290121: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=3569.74
# 📈 290122 예측 중...
# ✅ 290122: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=126.30
# ✅ 290122: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=1326.00
# 📈 290124 예측 중...
# ✅ 290124: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 0, 12), AIC=473.84
# ✅ 290124: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=662.33
# 📈 290220 예측 중...
# ✅ 290220: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=145.67
# ✅ 290220: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=3642.05
# 📈 290230 예측 중...
# ✅ 290230: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=654.01
# ✅ 290230: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=612.66
# 📈 290241 예측 중...
# ✅ 290241: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=4545.37
# ✅ 290241: 최적 모델 order=(0, 0, 0), seasonal_order=(1, 1, 1, 12), AIC=3888.89
# 📈 290243 예측 중...
# ✅ 290243: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=56.28
# ✅ 290243: 최적 모델 order=(0, 0, 0), seasonal_order=(0, 1, 1, 12), AIC=4261.57
# 📈 290250 예측 중...
# ✅ 290250: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 0, 12), AIC=310.05
# ✅ 290250: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=454.82
# 📈 290315 예측 중...
# ✅ 290315: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=590.58
# ✅ 290315: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 1, 1, 12), AIC=3270.85
# 📈 290516 예측 중...
# ✅ 290516: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=1376.38
# ✅ 290516: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=820.66
# 📈 290531 예측 중...
# ✅ 290531: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=1206.14
# ✅ 290531: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=92.20
# 📈 290539 예측 중...
# ✅ 290539: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=80.53
# ✅ 290539: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=255.82
# 📈 290723 예측 중...
# ✅ 290723: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=132.31
# ✅ 290723: 최적 모델 order=(1, 0, 0), seasonal_order=(1, 1, 1, 12), AIC=380.90
# 📈 291736 예측 중...
# ✅ 291736: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=38.35
# ✅ 291736: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 1, 1, 12), AIC=1674.05
# 📈 291739 예측 중...
# ✅ 291739: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=15.66
# ✅ 291739: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=44.73
# 📈 292610 예측 중...
# ✅ 292610: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=513.43
# ✅ 292610: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=449.03
# 📈 292910 예측 중...
# ✅ 292910: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=54.74
# ✅ 292910: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-49.19
# 📈 293299 예측 중...
# ✅ 293299: 최적 모델 order=(0, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=780.69
# ✅ 293299: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=233.52
# 📈 293399 예측 중...
# ✅ 293399: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=226.46
# ✅ 293399: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-42.10
# 📈 293499 예측 중...
# ✅ 293499: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=514.93
# ✅ 293499: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=45.10
# 📈 294130 예측 중...
# ✅ 294130: 최적 모델 order=(0, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=3092.91
# ✅ 294130: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=589.02
# 📈 294190 예측 중...
# ✅ 294190: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-9.56
# ✅ 294190: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-58.36
# 📈 300490 예측 중...
# ✅ 300490: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-200.13
# ✅ 300490: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-83.56
# 📈 300640 예측 중...
# ✅ 300640: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-55.20
# ✅ 300640: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=-176.24
# 📈 310520 예측 중...
# ✅ 310520: 최적 모델 order=(0, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=666.52
# ✅ 310520: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=420.60
# 📈 320417 예측 중...
# ✅ 320417: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-135.52
# ✅ 320417: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-188.09
# 📈 320490 예측 중...
# ✅ 320490: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=560.46
# ✅ 320490: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=364.53
# 📈 320730 예측 중...
# ✅ 320730: 최적 모델 order=(1, 0, 0), seasonal_order=(1, 0, 0, 12), AIC=384.76
# ✅ 320730: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=47.50
# 📈 320890 예측 중...
# ✅ 320890: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-178.65
# ✅ 320890: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-298.16
# 📈 321410 예측 중...
# ✅ 321410: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=-120.13
# ✅ 321410: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-239.37
# 📈 321519 예측 중...
# ✅ 321519: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-182.15
# ✅ 321519: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=19.48
# 📈 330410 예측 중...
# ✅ 330410: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=491.45
# ✅ 330410: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 0, 12), AIC=-20.83
# 📈 330420 예측 중...
# ✅ 330420: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-88.39
# ✅ 330420: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-20.13
# 📈 330499 예측 중...
# ✅ 330499: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=169.30
# ✅ 330499: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-316.90
# 📈 330510 예측 중...
# ✅ 330510: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=83.16
# ✅ 330510: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-30.62
# 📈 330590 예측 중...
# ✅ 330590: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-36.24
# ✅ 330590: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-168.16
# 📈 330610 예측 중...
# ✅ 330610: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=246.48
# ✅ 330610: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=196.16
# 📈 330790 예측 중...
# ✅ 330790: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=112.06
# ✅ 330790: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=108.93
# 📈 340130 예측 중...
# ✅ 340130: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=342.27
# ✅ 340130: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 1, 1, 12), AIC=316.06
# 📈 340290 예측 중...
# ✅ 340290: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-149.57
# ✅ 340290: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-176.22
# 📈 340420 예측 중...
# ✅ 340420: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=624.17
# ✅ 340420: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=523.81
# 📈 350610 예측 중...
# ✅ 350610: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-190.05
# ✅ 350610: 최적 모델 order=(1, 0, 0), seasonal_order=(0, 0, 1, 12), AIC=-105.62
# 📈 350691 예측 중...
# ✅ 350691: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-86.62
# ✅ 350691: 최적 모델 order=(1, 1, 0), seasonal_order=(0, 0, 1, 12), AIC=-155.09
# 📈 350790 예측 중...
# ✅ 350790: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=389.06
# ✅ 350790: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-52.82
# 📈 360610 예측 중...
# ✅ 360610: 최적 모델 order=(0, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=715.41
# ✅ 360610: 최적 모델 order=(0, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=3307.59
# 📈 370199 예측 중...
# ✅ 370199: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=144.02
# ✅ 370199: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-155.75
# 📈 370790 예측 중...
# ✅ 370790: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-240.60
# ✅ 370790: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-240.43
# 📈 380891 예측 중...
# ✅ 380891: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=544.08
# ✅ 380891: 최적 모델 order=(0, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=573.34
# 📈 380892 예측 중...
# ✅ 380892: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 1, 1, 12), AIC=708.62
# ✅ 380892: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=439.61
# 📈 381400 예측 중...
# ✅ 381400: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-93.22
# ✅ 381400: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=41.15
# 📈 381800 예측 중...
# ✅ 381800: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 0, 0, 12), AIC=-106.33
# ✅ 381800: 최적 모델 order=(1, 1, 0), seasonal_order=(1, 0, 1, 12), AIC=-222.71
# 📈 382490 예측 중...
# ✅ 382490: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-10.71
# ✅ 382490: 최적 모델 order=(1, 1, 0), seasonal_order=(1, 0, 0, 12), AIC=-57.14
# 📈 390110 예측 중...
# ✅ 390110: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-199.26
# ✅ 390110: 최적 모델 order=(1, 1, 0), seasonal_order=(0, 0, 1, 12), AIC=9.97
# 📈 390120 예측 중...
# ✅ 390120: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-221.69
# ✅ 390120: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=152.27
# 📈 390130 예측 중...
# ✅ 390130: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-70.49
# ✅ 390130: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=243.50
# 📈 390190 예측 중...
# ✅ 390190: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=23.89
# ✅ 390190: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-200.29
# 📈 390210 예측 중...
# ✅ 390210: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-271.45
# ✅ 390210: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=161.52
# 📈 390220 예측 중...
# ✅ 390220: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=2311.45
# ✅ 390220: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=440.14
# 📈 390230 예측 중...
# ✅ 390230: 최적 모델 order=(1, 0, 0), seasonal_order=(0, 0, 1, 12), AIC=-195.55
# ✅ 390230: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=119.62
# 📈 390290 예측 중...
# ✅ 390290: 최적 모델 order=(1, 1, 0), seasonal_order=(1, 0, 0, 12), AIC=-2.52
# ✅ 390290: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-36.83
# 📈 390319 예측 중...
# ✅ 390319: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-123.81
# ✅ 390319: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=187.66
# 📈 390320 예측 중...
# ✅ 390320: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-109.11
# ✅ 390320: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=507.21
# 📈 390330 예측 중...
# ✅ 390330: 최적 모델 order=(1, 0, 0), seasonal_order=(0, 0, 1, 12), AIC=-248.95
# ✅ 390330: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 0, 12), AIC=151.28
# 📈 390390 예측 중...
# ✅ 390390: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-118.67
# ✅ 390390: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=18.30
# 📈 390410 예측 중...
# ✅ 390410: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-26.15
# ✅ 390410: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=390.88
# 📈 390610 예측 중...
# ✅ 390610: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-48.39
# ✅ 390610: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 0, 12), AIC=202.58
# 📈 390690 예측 중...
# ✅ 390690: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-278.68
# ✅ 390690: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-270.69
# 📈 390710 예측 중...
# ✅ 390710: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-91.07
# ✅ 390710: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=131.26
# 📈 390730 예측 중...
# ✅ 390730: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-46.50
# ✅ 390730: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-93.54
# 📈 390740 예측 중...
# ✅ 390740: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-26.12
# ✅ 390740: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-38.44
# 📈 390799 예측 중...
# ✅ 390799: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-224.66
# ✅ 390799: 최적 모델 order=(1, 0, 0), seasonal_order=(1, 0, 1, 12), AIC=-106.80
# 📈 390810 예측 중...
# ✅ 390810: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=16.06
# ✅ 390810: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 0, 12), AIC=15.45
# 📈 390950 예측 중...
# ✅ 390950: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=-123.10
# ✅ 390950: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-78.20
# 📈 391000 예측 중...
# ✅ 391000: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-168.44
# ✅ 391000: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-168.63
# 📈 391110 예측 중...
# ✅ 391110: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-211.98
# ✅ 391110: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-52.44
# 📈 391190 예측 중...
# ✅ 391190: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=173.27
# ✅ 391190: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-82.37
# 📈 391239 예측 중...
# ✅ 391239: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=-21.44
# ✅ 391239: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=52.44
# 📈 391810 예측 중...
# ✅ 391810: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-247.26
# ✅ 391810: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=220.55
# 📈 391910 예측 중...
# ✅ 391910: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-207.59
# ✅ 391910: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-217.66
# 📈 391990 예측 중...
# ✅ 391990: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-237.06
# ✅ 391990: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-229.23
# 📈 392010 예측 중...
# ✅ 392010: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-250.12
# ✅ 392010: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-252.30
# 📈 392020 예측 중...
# ✅ 392020: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-349.12
# ✅ 392020: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-105.02
# 📈 392049 예측 중...
# ✅ 392049: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-137.38
# ✅ 392049: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-31.17
# 📈 392051 예측 중...
# ✅ 392051: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-98.03
# ✅ 392051: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=147.99
# 📈 392062 예측 중...
# ✅ 392062: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-334.10
# ✅ 392062: 최적 모델 order=(1, 0, 0), seasonal_order=(1, 0, 1, 12), AIC=-138.78
# 📈 392099 예측 중...
# ✅ 392099: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 0, 0, 12), AIC=37.57
# ✅ 392099: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-174.31
# 📈 392119 예측 중...
# ✅ 392119: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-97.36
# ✅ 392119: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-30.69
# 📈 392190 예측 중...
# ✅ 392190: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-268.92
# ✅ 392190: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 0, 12), AIC=-309.81
# 📈 392310 예측 중...
# ✅ 392310: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-325.68
# ✅ 392310: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-334.72
# 📈 392321 예측 중...
# ✅ 392321: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-195.40
# ✅ 392321: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=11.18
# 📈 392330 예측 중...
# ✅ 392330: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-213.03
# ✅ 392330: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-150.64
# 📈 392390 예측 중...
# ✅ 392390: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 0, 12), AIC=-120.20
# ✅ 392390: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=-176.90
# 📈 392630 예측 중...
# ✅ 392630: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=1145.17
# ✅ 392630: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=317.49
# 📈 392690 예측 중...
# ✅ 392690: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-304.64
# ✅ 392690: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-301.47
# 📈 400219 예측 중...
# ✅ 400219: 최적 모델 order=(1, 0, 0), seasonal_order=(1, 0, 1, 12), AIC=-166.35
# ✅ 400219: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=244.41
# 📈 400220 예측 중...
# ✅ 400220: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 0, 12), AIC=-64.45
# ✅ 400220: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=327.56
# 📈 400251 예측 중...
# ✅ 400251: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=751.78
# ✅ 400251: 최적 모델 order=(0, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=3512.62
# 📈 400259 예측 중...
# ✅ 400259: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=6.62
# ✅ 400259: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=239.01
# 📈 400270 예측 중...
# ✅ 400270: 최적 모델 order=(1, 0, 0), seasonal_order=(0, 0, 1, 12), AIC=177.85
# ✅ 400270: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=140.23
# 📈 401110 예측 중...
# ✅ 401110: 최적 모델 order=(1, 0, 0), seasonal_order=(0, 0, 1, 12), AIC=-158.09
# ✅ 401110: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-188.42
# 📈 401120 예측 중...
# ✅ 401120: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-221.85
# ✅ 401120: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=-9.26
# 📈 401693 예측 중...
# ✅ 401693: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-136.34
# ✅ 401693: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 0, 12), AIC=-167.78
# 📈 401699 예측 중...
# ✅ 401699: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-198.01
# ✅ 401699: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-211.29
# 📈 410792 예측 중...
# ✅ 410792: 최적 모델 order=(1, 0, 0), seasonal_order=(0, 0, 1, 12), AIC=-21.55
# ✅ 410792: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=290.80
# 📈 470329 예측 중...
# ✅ 470329: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=2135.56
# ✅ 470329: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-11.44
# 📈 470710 예측 중...
# ✅ 470710: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=673.93
# ✅ 470710: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=57.40
# 📈 480511 예측 중...
# ✅ 480511: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=466.21
# ✅ 480511: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=569.84
# 📈 480990 예측 중...
# ✅ 480990: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-3.00
# ✅ 480990: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=185.01
# 📈 481019 예측 중...
# ✅ 481019: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-322.76
# ✅ 481019: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 0, 12), AIC=215.04
# 📈 481092 예측 중...
# ✅ 481092: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=259.84
# ✅ 481092: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=1535.22
# 📈 481190 예측 중...
# ✅ 481190: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=121.42
# ✅ 481190: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 0, 12), AIC=-24.70
# 📈 490199 예측 중...
# ✅ 490199: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=89.08
# ✅ 490199: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-231.92
# 📈 540211 예측 중...
# ✅ 540211: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=471.73
# ✅ 540211: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=688.93
# 📈 540247 예측 중...
# ✅ 540247: 최적 모델 order=(1, 0, 0), seasonal_order=(1, 0, 0, 12), AIC=-168.37
# ✅ 540247: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=51.07
# 📈 540249 예측 중...
# ✅ 540249: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-28.58
# ✅ 540249: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=398.74
# 📈 540752 예측 중...
# ✅ 540752: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-175.26
# ✅ 540752: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=8.36
# 📈 540761 예측 중...
# ✅ 540761: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-185.37
# ✅ 540761: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-17.88
# 📈 540792 예측 중...
# ✅ 540792: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=-70.89
# ✅ 540792: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=303.67
# 📈 550320 예측 중...
# ✅ 550320: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-209.80
# ✅ 550320: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=216.08
# 📈 560122 예측 중...
# ✅ 560122: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=278.39
# ✅ 560122: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=124.88
# 📈 560394 예측 중...
# ✅ 560394: 최적 모델 order=(1, 0, 0), seasonal_order=(0, 0, 1, 12), AIC=-167.95
# ✅ 560394: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-125.72
# 📈 560749 예측 중...
# ✅ 560749: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-120.71
# ✅ 560749: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=263.70
# 📈 590320 예측 중...
# ✅ 590320: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-246.23
# ✅ 590320: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-96.43
# 📈 590390 예측 중...
# ✅ 590390: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-194.64
# ✅ 590390: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-41.85
# 📈 591110 예측 중...
# ✅ 591110: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=437.02
# ✅ 591110: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=966.18
# 📈 600410 예측 중...
# ✅ 600410: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-198.57
# ✅ 600410: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=127.42
# 📈 600622 예측 중...
# ✅ 600622: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-160.32
# ✅ 600622: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=344.89
# 📈 600632 예측 중...
# ✅ 600632: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-231.66
# ✅ 600632: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 0, 12), AIC=265.05
# 📈 610910 예측 중...
# ✅ 610910: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-128.52
# ✅ 610910: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-219.26
# 📈 621710 예측 중...
# ✅ 621710: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-117.22
# ✅ 621710: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-109.40
# 📈 621790 예측 중...
# ✅ 621790: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=108.41
# ✅ 621790: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=406.58
# 📈 630293 예측 중...
# ✅ 630293: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=285.61
# ✅ 630293: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=343.17
# 📈 630710 예측 중...
# ✅ 630710: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-215.05
# ✅ 630710: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=263.85
# 📈 630900 예측 중...
# ✅ 630900: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-108.21
# ✅ 630900: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-93.26
# 📈 680421 예측 중...
# ✅ 680421: 최적 모델 order=(1, 1, 0), seasonal_order=(0, 0, 1, 12), AIC=-251.22
# ✅ 680421: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-125.75
# 📈 690919 예측 중...
# ✅ 690919: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=207.14
# ✅ 690919: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-116.19
# 📈 691490 예측 중...
# ✅ 691490: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-39.67
# ✅ 691490: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=34.57
# 📈 700319 예측 중...
# ✅ 700319: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=2582.84
# ✅ 700319: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=528.63
# 📈 700490 예측 중...
# ✅ 700490: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=2100.24
# ✅ 700490: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=695.35
# 📈 700529 예측 중...
# ✅ 700529: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=296.23
# ✅ 700529: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=80.86
# 📈 700600 예측 중...
# ✅ 700600: 최적 모델 order=(1, 0, 0), seasonal_order=(0, 0, 1, 12), AIC=279.02
# ✅ 700600: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=55.34
# 📈 701349 예측 중...
# ✅ 701349: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=566.40
# ✅ 701349: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-23.96
# 📈 702000 예측 중...
# ✅ 702000: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=13.03
# ✅ 702000: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-208.34
# 📈 710510 예측 중...
# ✅ 710510: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=38.03
# ✅ 710510: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=52.16
# 📈 710610 예측 중...
# ✅ 710610: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=419.92
# ✅ 710610: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=215.01
# 📈 710691 예측 중...
# ✅ 710691: 최적 모델 order=(1, 1, 0), seasonal_order=(1, 0, 1, 12), AIC=35.55
# ✅ 710691: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=2069.46
# 📈 710812 예측 중...
# ✅ 710812: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=962.19
# ✅ 710812: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=503.46
# 📈 710813 예측 중...
# ✅ 710813: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=473.64
# ✅ 710813: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=1064.78
# 📈 711021 예측 중...
# ✅ 711021: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 1, 1, 12), AIC=1738.00
# ✅ 711021: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=279.99
# 📈 711292 예측 중...
# ✅ 711292: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=1431.12
# ✅ 711292: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=983.31
# 📈 711319 예측 중...
# ✅ 711319: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=389.24
# ✅ 711319: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=143.95
# 📈 711890 예측 중...
# ✅ 711890: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=2502.67
# ✅ 711890: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=957.81
# 📈 720270 예측 중...
# ✅ 720270: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=647.05
# ✅ 720270: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 1, 1, 12), AIC=2657.94
# 📈 720712 예측 중...
# ✅ 720712: 최적 모델 order=(0, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=2661.87
# ✅ 720712: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=545.68
# 📈 720826 예측 중...
# ✅ 720826: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=65.27
# ✅ 720826: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=1144.40
# 📈 720827 예측 중...
# ✅ 720827: 최적 모델 order=(1, 0, 0), seasonal_order=(0, 0, 1, 12), AIC=-46.37
# ✅ 720827: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=1251.24
# 📈 720836 예측 중...
# ✅ 720836: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=439.95
# ✅ 720836: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=1492.32
# 📈 720837 예측 중...
# ✅ 720837: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=305.82
# ✅ 720837: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=545.51
# 📈 720838 예측 중...
# ✅ 720838: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 0, 12), AIC=300.93
# ✅ 720838: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 0, 12), AIC=237.61
# 📈 720839 예측 중...
# ✅ 720839: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=75.06
# ✅ 720839: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 0, 12), AIC=102.14
# 📈 720851 예측 중...
# ✅ 720851: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-23.08
# ✅ 720851: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=267.54
# 📈 720852 예측 중...
# ✅ 720852: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=405.24
# ✅ 720852: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 1, 1, 12), AIC=1189.98
# 📈 720916 예측 중...
# ✅ 720916: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-124.23
# ✅ 720916: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=759.28
# 📈 720917 예측 중...
# ✅ 720917: 최적 모델 order=(1, 0, 0), seasonal_order=(0, 0, 1, 12), AIC=-182.80
# ✅ 720917: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=632.76
# 📈 720918 예측 중...
# ✅ 720918: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-38.55
# ✅ 720918: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 1, 1, 12), AIC=728.23
# 📈 721012 예측 중...
# ✅ 721012: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=-91.75
# ✅ 721012: 최적 모델 order=(0, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=1349.87
# 📈 721030 예측 중...
# ✅ 721030: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 0, 12), AIC=-65.69
# ✅ 721030: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=345.48
# 📈 721049 예측 중...
# ✅ 721049: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-177.57
# ✅ 721049: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=288.84
# 📈 721061 예측 중...
# ✅ 721061: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 0, 12), AIC=-54.19
# ✅ 721061: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=2632.13
# 📈 721069 예측 중...
# ✅ 721069: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 0, 12), AIC=158.58
# ✅ 721069: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=2474.91
# 📈 721070 예측 중...
# ✅ 721070: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-233.56
# ✅ 721070: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=950.53
# 📈 721240 예측 중...
# ✅ 721240: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-47.81
# ✅ 721240: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=403.36
# 📈 721391 예측 중...
# ✅ 721391: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 0, 12), AIC=260.13
# ✅ 721391: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=276.27
# 📈 721633 예측 중...
# ✅ 721633: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=201.98
# ✅ 721633: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 0, 12), AIC=373.22
# 📈 721710 예측 중...
# ✅ 721710: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-198.09
# ✅ 721710: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 1, 1, 12), AIC=405.91
# 📈 721730 예측 중...
# ✅ 721730: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-89.28
# ✅ 721730: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=298.12
# 📈 721912 예측 중...
# ✅ 721912: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=556.65
# ✅ 721912: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=305.52
# 📈 721913 예측 중...
# ✅ 721913: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=381.80
# ✅ 721913: 최적 모델 order=(1, 0, 0), seasonal_order=(0, 1, 1, 12), AIC=512.38
# 📈 721933 예측 중...
# ✅ 721933: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=324.01
# ✅ 721933: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=372.93
# 📈 721934 예측 중...
# ✅ 721934: 최적 모델 order=(1, 0, 0), seasonal_order=(0, 0, 1, 12), AIC=-54.84
# ✅ 721934: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=148.28
# 📈 722020 예측 중...
# ✅ 722020: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=29.65
# ✅ 722020: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=106.29
# 📈 722300 예측 중...
# ✅ 722300: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-234.35
# ✅ 722300: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-32.02
# 📈 722519 예측 중...
# ✅ 722519: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=349.35
# ✅ 722519: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=726.31
# 📈 722530 예측 중...
# ✅ 722530: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=1385.46
# ✅ 722530: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=2121.08
# 📈 722550 예측 중...
# ✅ 722550: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 1, 1, 12), AIC=1240.06
# ✅ 722550: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=1005.56
# 📈 722592 예측 중...
# ✅ 722592: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=504.21
# ✅ 722592: 최적 모델 order=(0, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=2054.48
# 📈 722599 예측 중...
# ✅ 722599: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 1, 1, 12), AIC=1296.82
# ✅ 722599: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=794.79
# 📈 722790 예측 중...
# ✅ 722790: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=290.79
# ✅ 722790: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=208.43
# 📈 722830 예측 중...
# ✅ 722830: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=128.32
# ✅ 722830: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=401.27
# 📈 722990 예측 중...
# ✅ 722990: 최적 모델 order=(1, 1, 0), seasonal_order=(0, 0, 1, 12), AIC=-169.17
# ✅ 722990: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=189.16
# 📈 730511 예측 중...
# ✅ 730511: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=571.05
# ✅ 730511: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 1, 1, 12), AIC=849.96
# 📈 730512 예측 중...
# ✅ 730512: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=803.02
# ⚠️ 730512: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=730512, col=impDlr_yoy
# 📈 730531 예측 중...
# ✅ 730531: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=503.31
# ✅ 730531: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=1493.29
# 📈 730629 예측 중...
# ✅ 730629: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=2469.18
# ✅ 730629: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=2510.66
# 📈 730630 예측 중...
# ✅ 730630: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=-35.18
# ✅ 730630: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=276.35
# 📈 730640 예측 중...
# ✅ 730640: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=115.20
# ✅ 730640: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=414.18
# 📈 730729 예측 중...
# ✅ 730729: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-120.09
# ✅ 730729: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=129.25
# 📈 730791 예측 중...
# ✅ 730791: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-17.61
# ✅ 730791: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=94.99
# 📈 730793 예측 중...
# ✅ 730793: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-17.88
# ✅ 730793: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=495.98
# 📈 730799 예측 중...
# ✅ 730799: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-74.92
# ✅ 730799: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=135.00
# 📈 730840 예측 중...
# ✅ 730840: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=344.55
# ✅ 730840: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=982.10
# 📈 730890 예측 중...
# ✅ 730890: 최적 모델 order=(0, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=803.30
# ✅ 730890: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=278.40
# 📈 730900 예측 중...
# ✅ 730900: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=483.89
# ✅ 730900: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=780.20
# 📈 731100 예측 중...
# ✅ 731100: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=52.09
# ✅ 731100: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=87.86
# 📈 731210 예측 중...
# ✅ 731210: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-208.94
# ✅ 731210: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-117.50
# 📈 731815 예측 중...
# ✅ 731815: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-164.27
# ✅ 731815: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 0, 12), AIC=253.28
# 📈 731816 예측 중...
# ✅ 731816: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-120.69
# ✅ 731816: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-201.73
# 📈 732182 예측 중...
# ✅ 732182: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=1408.70
# ✅ 732182: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=1687.30
# 📈 732290 예측 중...
# ✅ 732290: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=882.86
# ✅ 732290: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=647.99
# 📈 732690 예측 중...
# ✅ 732690: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-227.27
# ✅ 732690: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-121.43
# 📈 740200 예측 중...
# ✅ 740200: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=2441.54
# ✅ 740200: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=2283.03
# 📈 740311 예측 중...
# ✅ 740311: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=295.64
# ✅ 740311: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-6.49
# 📈 740321 예측 중...
# ✅ 740321: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=228.44
# ✅ 740321: 최적 모델 order=(0, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=3901.21
# 📈 740400 예측 중...
# ✅ 740400: 최적 모델 order=(1, 0, 0), seasonal_order=(0, 1, 1, 12), AIC=468.92
# ✅ 740400: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=59.31
# 📈 740721 예측 중...
# ✅ 740721: 최적 모델 order=(1, 0, 0), seasonal_order=(1, 0, 0, 12), AIC=183.73
# ✅ 740721: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=905.32
# 📈 740811 예측 중...
# ✅ 740811: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=114.75
# ✅ 740811: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=779.56
# 📈 740819 예측 중...
# ✅ 740819: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=102.77
# ✅ 740819: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=738.42
# 📈 740911 예측 중...
# ✅ 740911: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=128.64
# ✅ 740911: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=309.46
# 📈 740921 예측 중...
# ✅ 740921: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=12.66
# ✅ 740921: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=535.96
# 📈 740990 예측 중...
# ✅ 740990: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=294.63
# ✅ 740990: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-11.64
# 📈 741011 예측 중...
# ✅ 741011: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=87.35
# ✅ 741011: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-108.09
# 📈 741021 예측 중...
# ✅ 741021: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=-74.94
# ✅ 741021: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-234.48
# 📈 741110 예측 중...
# ✅ 741110: 최적 모델 order=(1, 1, 0), seasonal_order=(0, 0, 1, 12), AIC=-82.79
# ✅ 741110: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=227.01
# 📈 741999 예측 중...
# ✅ 741999: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=293.09
# ✅ 741999: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=36.25
# 📈 760120 예측 중...
# ✅ 760120: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=167.09
# ✅ 760120: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=21.19
# 📈 760612 예측 중...
# ✅ 760612: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-138.73
# ✅ 760612: 최적 모델 order=(1, 1, 0), seasonal_order=(1, 0, 1, 12), AIC=-193.12
# 📈 760711 예측 중...
# ✅ 760711: 최적 모델 order=(1, 1, 0), seasonal_order=(0, 0, 1, 12), AIC=-343.77
# ✅ 760711: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=-80.97
# 📈 761090 예측 중...
# ✅ 761090: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=214.23
# ✅ 761090: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 0, 0, 12), AIC=354.11
# 📈 761699 예측 중...
# ✅ 761699: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-112.86
# ✅ 761699: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-152.64
# 📈 780110 예측 중...
# ✅ 780110: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=400.20
# ✅ 780110: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=198.03
# 📈 780199 예측 중...
# ✅ 780199: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=200.29
# ✅ 780199: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=736.93
# 📈 790111 예측 중...
# ✅ 790111: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=105.21
# ✅ 790111: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=402.17
# 📈 790112 예측 중...
# ✅ 790112: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=270.20
# ✅ 790112: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=3163.95
# 📈 790120 예측 중...
# ✅ 790120: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=224.96
# ✅ 790120: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=2434.77
# 📈 820730 예측 중...
# ✅ 820730: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=133.76
# ✅ 820730: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=530.94
# 📈 820740 예측 중...
# ✅ 820740: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-85.06
# ✅ 820740: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=74.37
# 📈 820750 예측 중...
# ✅ 820750: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=-61.07
# ✅ 820750: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-315.04
# 📈 820770 예측 중...
# ✅ 820770: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-191.66
# ✅ 820770: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-113.14
# 📈 820900 예측 중...
# ✅ 820900: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-169.48
# ✅ 820900: 최적 모델 order=(1, 1, 0), seasonal_order=(1, 0, 1, 12), AIC=-270.95
# 📈 830230 예측 중...
# ✅ 830230: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=260.84
# ✅ 830230: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=189.68
# 📈 831120 예측 중...
# ✅ 831120: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-170.78
# ✅ 831120: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=139.49
# 📈 840310 예측 중...
# ✅ 840310: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=208.86
# ✅ 840310: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=753.84
# 📈 840410 예측 중...
# ✅ 840410: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=1264.40
# ✅ 840410: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=1763.95
# 📈 840510 예측 중...
# ✅ 840510: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=1253.54
# ✅ 840510: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=569.14
# 📈 840690 예측 중...
# ✅ 840690: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=963.03
# ✅ 840690: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=892.07
# 📈 840733 예측 중...
# ✅ 840733: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=938.12
# ✅ 840733: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=1893.39
# 📈 840734 예측 중...
# ✅ 840734: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=335.56
# ✅ 840734: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 1, 1, 12), AIC=657.30
# 📈 840810 예측 중...
# ✅ 840810: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=332.79
# ✅ 840810: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=706.43
# 📈 840890 예측 중...
# ✅ 840890: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=121.36
# ✅ 840890: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=91.41
# 📈 840991 예측 중...
# ✅ 840991: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 0, 0, 12), AIC=64.25
# ✅ 840991: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=-215.05
# 📈 840999 예측 중...
# ✅ 840999: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-259.84
# ✅ 840999: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-206.37
# 📈 841112 예측 중...
# ✅ 841112: 최적 모델 order=(0, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=3494.74
# ✅ 841112: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 1, 1, 12), AIC=3265.37
# 📈 841191 예측 중...
# ✅ 841191: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=113.38
# ✅ 841191: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=268.68
# 📈 841221 예측 중...
# ✅ 841221: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=141.33
# ✅ 841221: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=541.05
# 📈 841229 예측 중...
# ✅ 841229: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=232.16
# ✅ 841229: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=216.14
# 📈 841330 예측 중...
# ✅ 841330: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=19.44
# ...
# ✅ 8507: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-77.57
# 📈 8511 예측 중...
# ✅ 8511: 최적 모델 order=(1, 0, 0), seasonal_order=(0, 0, 1, 12), AIC=18.29
# ✅ 8511: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-23.32
# 📈 8512 예측 중...
# ✅ 8512: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-39.11
# ✅ 8512: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-249.42
# 📈 8514 예측 중...
# ✅ 8514: 최적 모델 order=(0, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=453.27
# ✅ 8514: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=235.48
# 📈 8515 예측 중...
# ✅ 8515: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=312.78
# ✅ 8515: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=106.44
# 📈 8516 예측 중...
# ✅ 8516: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-199.56
# ✅ 8516: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-246.40
# 📈 8517 예측 중...
# ✅ 8517: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-104.15
# ✅ 8517: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=2.95
# 📈 8523 예측 중...
# ✅ 8523: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=339.18
# ✅ 8523: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=216.66
# 📈 8525 예측 중...
# ✅ 8525: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=377.08
# ✅ 8525: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-54.82
# 📈 8526 예측 중...
# ✅ 8526: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-73.13
# ✅ 8526: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=143.56
# 📈 8528 예측 중...
# ✅ 8528: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-249.41
# ✅ 8528: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-165.73
# 📈 8529 예측 중...
# ✅ 8529: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=38.80
# ✅ 8529: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=56.69
# 📈 8532 예측 중...
# ✅ 8532: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-311.26
# ✅ 8532: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-396.73
# 📈 8534 예측 중...
# ✅ 8534: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-399.67
# ✅ 8534: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-355.68
# 📈 8535 예측 중...
# ✅ 8535: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=202.41
# ✅ 8535: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=123.33
# 📈 8536 예측 중...
# ✅ 8536: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-353.71
# ✅ 8536: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-460.66
# 📈 8537 예측 중...
# ✅ 8537: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=30.83
# ✅ 8537: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=11.45
# 📈 8538 예측 중...
# ✅ 8538: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-68.69
# ✅ 8538: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-232.31
# 📈 8541 예측 중...
# ✅ 8541: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-332.09
# ✅ 8541: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-368.64
# 📈 8542 예측 중...
# ✅ 8542: 최적 모델 order=(1, 0, 0), seasonal_order=(0, 0, 1, 12), AIC=-396.76
# ✅ 8542: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-386.03
# 📈 8543 예측 중...
# ✅ 8543: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-22.71
# ✅ 8543: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-182.70
# 📈 8544 예측 중...
# ✅ 8544: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-263.26
# ✅ 8544: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-368.57
# 📈 8701 예측 중...
# ✅ 8701: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=9.69
# ✅ 8701: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=235.07
# 📈 8702 예측 중...
# ✅ 8702: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-5.85
# ✅ 8702: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 1, 1, 12), AIC=760.34
# 📈 8703 예측 중...
# ✅ 8703: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-164.91
# ✅ 8703: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=50.67
# 📈 8704 예측 중...
# ✅ 8704: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=31.41
# ✅ 8704: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=440.83
# 📈 8708 예측 중...
# ✅ 8708: 최적 모델 order=(1, 0, 0), seasonal_order=(1, 0, 1, 12), AIC=-151.60
# ✅ 8708: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-314.97
# 📈 8802 예측 중...
# ✅ 8802: 최적 모델 order=(0, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=3554.67
# ✅ 8802: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 1, 1, 12), AIC=3087.24
# 📈 8901 예측 중...
# ✅ 8901: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=157.03
# ✅ 8901: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=1211.11
# 📈 9001 예측 중...
# ✅ 9001: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-343.12
# ✅ 9001: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-326.39
# 📈 9002 예측 중...
# ✅ 9002: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=103.07
# ✅ 9002: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-29.51
# 📈 9013 예측 중...
# ✅ 9013: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-337.60
# ✅ 9013: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-171.00
# 📈 9018 예측 중...
# ✅ 9018: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-269.26
# ✅ 9018: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-405.81
# 📈 9021 예측 중...
# ✅ 9021: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-56.21
# ✅ 9021: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-295.49
# 📈 9022 예측 중...
# ✅ 9022: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-191.42
# ✅ 9022: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-45.89
# 📈 9027 예측 중...
# ✅ 9027: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=300.83
# ✅ 9027: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-239.69
# 📈 9030 예측 중...
# ✅ 9030: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=14.69
# ✅ 9030: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-52.75
# 📈 9031 예측 중...
# ✅ 9031: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-2.65
# ✅ 9031: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=94.76
# 📈 9032 예측 중...
# ✅ 9032: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-63.78
# ✅ 9032: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-215.73
# 📈 9301 예측 중...
# ✅ 9301: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=3989.28
# ✅ 9301: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=1632.87
# 📈 9306 예측 중...
# ✅ 9306: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 1, 1, 12), AIC=738.08
# ✅ 9306: 최적 모델 order=(0, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=1224.57
# 📈 9401 예측 중...
# ✅ 9401: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-247.22
# ✅ 9401: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-379.85
# 📈 121221 예측 중...
# ✅ 121221: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=42.81
# ✅ 121221: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=329.97
# 📈 271012 예측 중...
# ✅ 271012: 최적 모델 order=(1, 0, 0), seasonal_order=(0, 0, 1, 12), AIC=87.45
# ✅ 271012: 최적 모델 order=(1, 0, 0), seasonal_order=(0, 0, 1, 12), AIC=31.51
# 📈 293190 예측 중...
# ✅ 293190: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-25.18
# ✅ 293190: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-102.69
# 📈 382600 예측 중...
# ✅ 382600: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 1, 1, 12), AIC=2183.73
# ✅ 382600: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 1, 1, 12), AIC=2261.33
# 📈 731940 예측 중...
# ✅ 731940: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-1.24
# ✅ 731940: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=62.45
# 📈 850760 예측 중...
# ✅ 850760: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-149.17
# ✅ 850760: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=64.53
# 📈 852349 예측 중...
# ✅ 852349: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=289.31
# ✅ 852349: 최적 모델 order=(0, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=272.76
# 📈 220299 예측 중...
# ✅ 220299: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=-83.63
# ✅ 220299: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-60.86
# 📈 300212 예측 중...
# ✅ 300212: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=130.05
# ✅ 300212: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=1.52
# 📈 300214 예측 중...
# ✅ 300214: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=139.07
# ✅ 300214: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=431.23
# 📈 300215 예측 중...
# ✅ 300215: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=217.23
# ✅ 300215: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=51.88
# 📈 370500 예측 중...
# ✅ 370500: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-59.54
# ✅ 370500: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-2.46
# 📈 381239 예측 중...
# ✅ 381239: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 0, 12), AIC=-76.48
# ✅ 381239: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-39.19
# 📈 382499 예측 중...
# ✅ 382499: 최적 모델 order=(1, 1, 0), seasonal_order=(0, 0, 1, 12), AIC=-12.41
# ✅ 382499: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 0, 12), AIC=-164.91
# 📈 390140 예측 중...
# ✅ 390140: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=22.70
# ✅ 390140: 최적 모델 order=(0, 0, 0), seasonal_order=(0, 0, 1, 12), AIC=1.66
# 📈 390761 예측 중...
# ✅ 390761: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-35.32
# ✅ 390761: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=88.21
# 📈 390769 예측 중...
# ✅ 390769: 최적 모델 order=(1, 0, 0), seasonal_order=(0, 0, 1, 12), AIC=-65.33
# ✅ 390769: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=75.86
# 📈 390931 예측 중...
# ✅ 390931: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=33.43
# ✅ 390931: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=67.92
# 📈 600537 예측 중...
# ✅ 600537: 최적 모델 order=(1, 0, 0), seasonal_order=(0, 0, 1, 12), AIC=-52.74
# ✅ 600537: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=125.54
# 📈 845611 예측 중...
# ✅ 845611: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=152.69
# ✅ 845611: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=41.63
# 📈 852852 예측 중...
# ✅ 852852: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=25.32
# ✅ 852852: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 0, 12), AIC=21.00
# 📈 870191 예측 중...
# ✅ 870191: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=58.51
# ✅ 870191: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=624.52
# 📈 870192 예측 중...
# ✅ 870192: 최적 모델 order=(1, 0, 0), seasonal_order=(1, 0, 1, 12), AIC=8.55
# ✅ 870192: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=348.10
# 📈 870193 예측 중...
# ✅ 870193: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=44.46
# ✅ 870193: 최적 모델 order=(0, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=168.84
# 📈 870340 예측 중...
# ✅ 870340: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 0, 0, 12), AIC=54.42
# ✅ 870340: 최적 모델 order=(0, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=305.81
# 📈 870360 예측 중...
# ✅ 870360: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=118.67
# ✅ 870360: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 1, 1, 12), AIC=390.61
# 📈 870380 예측 중...
# ✅ 870380: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=85.01
# ✅ 870380: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=472.12
# 📈 2404 예측 중...
# ⚠️ 2404: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=2404, col=expDlr_yoy
# ⚠️ 2404: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=2404, col=impDlr_yoy
# 📈 300249 예측 중...
# ⚠️ 300249: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=300249, col=expDlr_yoy
# ⚠️ 300249: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=300249, col=impDlr_yoy
# 📈 382219 예측 중...
# ⚠️ 382219: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=382219, col=expDlr_yoy
# ⚠️ 382219: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=382219, col=impDlr_yoy
# 📈 390729 예측 중...
# ⚠️ 390729: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=390729, col=expDlr_yoy
# ⚠️ 390729: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=390729, col=impDlr_yoy
# 📈 620240 예측 중...
# ⚠️ 620240: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=620240, col=expDlr_yoy
# ⚠️ 620240: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=620240, col=impDlr_yoy
# 📈 681511 예측 중...
# ⚠️ 681511: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=681511, col=expDlr_yoy
# ⚠️ 681511: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=681511, col=impDlr_yoy
# 📈 741980 예측 중...
# ⚠️ 741980: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=741980, col=expDlr_yoy
# ⚠️ 741980: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=741980, col=impDlr_yoy
# 📈 846242 예측 중...
# ⚠️ 846242: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=846242, col=expDlr_yoy
# ⚠️ 846242: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=846242, col=impDlr_yoy
# 📈 846262 예측 중...
# ⚠️ 846262: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=846262, col=expDlr_yoy
# ⚠️ 846262: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=846262, col=impDlr_yoy
# 📈 846290 예측 중...
# ⚠️ 846290: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=846290, col=expDlr_yoy
# ⚠️ 846290: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=846290, col=impDlr_yoy
# 📈 851419 예측 중...
# ⚠️ 851419: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=851419, col=expDlr_yoy
# ⚠️ 851419: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=851419, col=impDlr_yoy
# 📈 851713 예측 중...
# ⚠️ 851713: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=851713, col=expDlr_yoy
# ⚠️ 851713: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=851713, col=impDlr_yoy
# 📈 851779 예측 중...
# ⚠️ 851779: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=851779, col=expDlr_yoy
# ⚠️ 851779: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=851779, col=impDlr_yoy
# 📈 8524 예측 중...
# ⚠️ 8524: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=8524, col=expDlr_yoy
# ⚠️ 8524: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=8524, col=impDlr_yoy
# 📈 852411 예측 중...
# ⚠️ 852411: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=852411, col=expDlr_yoy
# ⚠️ 852411: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=852411, col=impDlr_yoy
# 📈 852412 예측 중...
# ⚠️ 852412: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=852412, col=expDlr_yoy
# ⚠️ 852412: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=852412, col=impDlr_yoy
# 📈 852492 예측 중...
# ⚠️ 852492: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=852492, col=expDlr_yoy
# ⚠️ 852492: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=852492, col=impDlr_yoy
# 📈 852589 예측 중...
# ⚠️ 852589: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=852589, col=expDlr_yoy
# ⚠️ 852589: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=852589, col=impDlr_yoy
# 📈 854141 예측 중...
# ⚠️ 854141: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=854141, col=expDlr_yoy
# ⚠️ 854141: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=854141, col=impDlr_yoy
# 📈 854142 예측 중...
# ⚠️ 854142: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=854142, col=expDlr_yoy
# ⚠️ 854142: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=854142, col=impDlr_yoy
# 📈 854143 예측 중...
# ⚠️ 854143: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=854143, col=expDlr_yoy
# ⚠️ 854143: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=854143, col=impDlr_yoy
# 📈 854149 예측 중...
# ⚠️ 854149: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=854149, col=expDlr_yoy
# ⚠️ 854149: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=854149, col=impDlr_yoy
# 📈 854159 예측 중...
# ⚠️ 854159: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=854159, col=expDlr_yoy
# ⚠️ 854159: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=854159, col=impDlr_yoy
# 📈 8807 예측 중...
# ⚠️ 8807: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=8807, col=expDlr_yoy
# ⚠️ 8807: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=8807, col=impDlr_yoy
# 📈 880730 예측 중...
# ⚠️ 880730: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=880730, col=expDlr_yoy
# ⚠️ 880730: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=880730, col=impDlr_yoy
# 📈 902789 예측 중...
# ⚠️ 902789: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=902789, col=expDlr_yoy
# ⚠️ 902789: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=902789, col=impDlr_yoy
# 📈 940199 예측 중...
# ⚠️ 940199: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=940199, col=expDlr_yoy
# ⚠️ 940199: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=940199, col=impDlr_yoy
# 📈 970191 예측 중...
# ⚠️ 970191: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=970191, col=expDlr_yoy
# ⚠️ 970191: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=970191, col=impDlr_yoy

# %%
forecast_df = forecast_by_month

# 'expDlr_yoy_forecast' → 'yoy_forecast'로 정리
if 'expDlr_yoy_forecast' in forecast_df.columns:
    forecast_df = forecast_df.rename(columns={'expDlr_yoy_forecast': 'yoy_forecast'})
elif 'impDlr_yoy_forecast' in forecast_df.columns:
    forecast_df = forecast_df.rename(columns={'impDlr_yoy_forecast': 'yoy_forecast'})

# DB에서 데이터 불러오기
# trade_data_df = load_monthly_trade_data_from_db()

# 🧩 Step 1: forecast_df 피벗
forecast_df_pivoted = pivot_forecast_df(forecast_df)

# 🧩 Step 2: merge 실행'
final_combined_df = merge_forecast_with_actuals(forecast_df_pivoted, trade_data_df)

# hs_code_list = ['854232', '854231']
# hs_code_list
forecast_result_df = final_combined_df[final_combined_df['root_hs_code'].isin(hs_cd_list)]
forecast_result_data = forecast_result_df[['date', 'root_hs_code', 'final_expDlr_yoy', 'expDlr_forecast_12m']]

# %%
upload_forecast_to_db(forecast_result_data, db_info)
# Out:
# ✅ 데이터가 korea_monthly_trade_data_forecast 테이블에 성공적으로 업로드되었습니다. (중복 시 자동 갱신)

# %%
from datetime import datetime

# 📌 2. 전처리
today_date = datetime.today().strftime('%Y-%m-%d')

# 'period' 제거
if 'period' in forecast_by_month.columns:
    df = forecast_by_month.drop(columns=['period'])

# 'hs_code' → 'root_hs_code'로 변경
df = forecast_by_month.rename(columns={'hs_code': 'root_hs_code'})

# forecast_date 추가
df['forecast_date'] = today_date

# SQLAlchemy 엔진 생성
engine = create_engine(
    f"mysql+pymysql://{db_info['user']}:{db_info['password']}@{db_info['host']}:{db_info['port']}/{db_info['database']}"
)
# 📌 4. DB 업로드
table_name = 'korea_monthly_trade_data_record'
df.to_sql(name=table_name, con=engine, if_exists='append', index=False)

print(f"✅ {table_name} 테이블에 {len(df)}건 업로드 완료 (날짜: {today_date})")
# Out:
# ✅ korea_monthly_trade_data_record 테이블에 18967건 업로드 완료 (날짜: 2025-07-13)
