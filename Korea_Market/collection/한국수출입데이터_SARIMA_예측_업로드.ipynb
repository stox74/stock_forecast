# %%
import pandas as pd
from sqlalchemy import create_engine
from statsmodels.tsa.statespace.sarimax import SARIMAX
import matplotlib.pyplot as plt
import numpy as np
from DATA.stock_invest_function import *
import warnings
warnings.filterwarnings("ignore")
# Out:
# WARNING:tensorflow:From C:\Users\82108\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
def forecast_yoy_growth_auto(df, col, forecast_steps=12, seasonal=True):
    """
    최적 SARIMAX 파라미터를 자동 탐색하여 수출입 증가율 예측.
    월별 데이터가 72개월 미만일 경우 예측을 수행하지 않습니다.

    Parameters:
        df (pd.DataFrame): 'period' (datetime), 예측 대상 컬럼 포함
        col (str): 예측 컬럼 (예: 'expDlr_yoy')
        forecast_steps (int): 예측 기간 (월 기준 12, 분기 기준 4)
        seasonal (bool): 계절성 사용 여부
    """
    df = df[['period', col]].dropna().copy()
    df = df.set_index('period').sort_index()
    ts = df[col]

    # ✅ 데이터 길이 검사
    if forecast_steps > 4 and len(ts) < 72:
        print("⚠️ 월 데이터가 6년치(72개월) 미만입니다. 충분한 데이터 기간 기준에 미달합니다.")
        return None
    elif forecast_steps <= 4 and len(ts) < 16:
        print("⚠️ 분기 데이터가 4년치(16분기) 미만입니다. 충분한 데이터 기간 기준에 미달합니다.")
        return None

    # SARIMA 파라미터 범위
    p = d = q = range(0, 2)
    pdq = [(x, y, z) for x in p for y in d for z in q]
    seasonal_pdq = [(x, y, z) for x in p for y in d for z in q]
    seasonal_period = 12 if forecast_steps > 4 else 4

    best_model, best_order, best_seasonal_order = sarimax_grid_search(ts, pdq, seasonal_pdq, seasonal_period)

    # 예측
    future_index = pd.date_range(
        start=ts.index[-1] + pd.offsets.DateOffset(months=1 if seasonal_period == 12 else 3),
        periods=forecast_steps,
        freq='M' if seasonal_period == 12 else 'Q'
    )

    forecast = best_model.forecast(steps=forecast_steps)
    forecast.index = future_index

    # 시각화
    plt.figure(figsize=(12, 6))
    plt.plot(ts.index, ts, label='Actual')
    plt.plot(forecast.index, forecast, label='Forecast', linestyle='--', color='red')
    plt.title(f"{col} 예측 (Auto SARIMAX)")
    plt.ylabel('YoY Growth')
    plt.xticks(rotation=45)
    plt.legend()
    plt.tight_layout()
    plt.show()

# %%
# ✅ 수정된 DB 구조에 맞춘 데이터 로딩 함수
def load_monthly_trade_data_from_db():
    host : get_db_host()
    # host = '192.168.0.230'
    port = 3307
    user = 'stox7412'
    password = 'Apt106503!~'
    database = 'investar'
    engine = create_engine(f'mysql+pymysql://{user}:{password}@{host}:{port}/{database}')
    query = "SELECT * FROM korea_monthly_trade_data"
    df = pd.read_sql(query, con=engine)
    return df


# ✅ 수정된 long format 기반 SARIMA 예측 함수
def forecast_yoy_growth_auto_with_ci(df, col, hs_code, forecast_steps):
    warnings.filterwarnings("ignore")
    df_hs = df[(df['root_hs_code'] == hs_code) & (df['indicator'] == col)].copy()

    if df_hs.empty:
        print(f"❌ {hs_code} | '{col}'에 해당하는 데이터가 없습니다.")
        return None, None

    df_hs['date'] = pd.to_datetime(df_hs['date'])
    df_hs = df_hs.set_index('date').sort_index()
    ts = df_hs['value'].astype(float).dropna()

    if forecast_steps > 4 and len(ts) < 72:
        print(f"⚠️ {hs_code}: 월 데이터가 6년치 미만입니다.")
        return None, None

    best_aic = np.inf
    best_order = None
    best_seasonal_order = None
    best_model = None

    p = d = q = range(0, 2)
    P = D = Q = range(0, 2)
    m = 12

    for order in [(p_, d_, q_) for p_ in p for d_ in d for q_ in q]:
        for seasonal_order in [(P_, D_, Q_, m) for P_ in P for D_ in D for Q_ in Q]:
            try:
                model = SARIMAX(ts,
                                order=order,
                                seasonal_order=seasonal_order,
                                enforce_stationarity=False,
                                enforce_invertibility=False)
                result = model.fit(disp=False)
                if result.aic < best_aic:
                    best_aic = result.aic
                    best_order = order
                    best_seasonal_order = seasonal_order
                    best_model = result
            except:
                continue

    if best_model is None:
        print(f"❌ {hs_code}: SARIMAX 모델 최적화 실패")
        return None, None

    forecast_result = best_model.get_forecast(steps=forecast_steps)
    pred_mean = forecast_result.predicted_mean
    conf_int = forecast_result.conf_int()
    future_index = pd.date_range(start=ts.index[-1] + pd.DateOffset(months=1), periods=forecast_steps, freq='M')

    forecast_df = pd.DataFrame({
        col + '_forecast': pred_mean.values,
        col + '_lower': conf_int.iloc[:, 0].values,
        col + '_upper': conf_int.iloc[:, 1].values
    }, index=future_index)

    print(f"✅ {hs_code}: 최적 모델 order={best_order}, seasonal_order={best_seasonal_order}, AIC={best_aic:.2f}")
    return forecast_df, df_hs

# ✅ forecast 시계열 결합 함수 (기존과 동일)
def build_forecasted_series(base_df, forecast_df, col_name):
    full_df = pd.concat([base_df[['value']], forecast_df[[col_name + '_forecast']]], axis=0)
    full_df[col_name + '_forecast'] = pd.to_numeric(full_df[col_name + '_forecast'], errors='coerce')
    full_df[col_name + '_forecast'] = full_df[col_name + '_forecast'].replace([np.inf, -np.inf], np.nan)
    full_df[col_name + '_estimated'] = full_df[col_name + '_forecast'].shift(1) * (1 + full_df[col_name + '_forecast'])
    return full_df

# ✅ 전체 파이프라인 실행 함수
def run_forecasting_pipeline(db_info, hs_code_list, max_hs_count=3, forecast_steps = 12):
    export_m_with_yoy = fetch_table_data(db_info, "korea_monthly_trade_data")
    hs_code_list = hs_code_list[:max_hs_count]
    result_list = []

    for hs_code in hs_code_list:
        print(f"📈 {hs_code} 예측 중...")
        for target_col in ['expDlr_yoy', 'impDlr_yoy']:
            forecast_df, base_df = forecast_yoy_growth_auto_with_ci(export_m_with_yoy, target_col, hs_code, forecast_steps)

            if forecast_df is None or forecast_df.empty:
                print(f"⚠️ 예측 실패 또는 결과 없음 | hs_code={hs_code}, col={target_col}")
                continue

            full_df = build_forecasted_series(base_df, forecast_df, target_col)
            forecast_only = forecast_df.copy()
            forecast_only['hs_code'] = hs_code
            forecast_only['target_col'] = target_col
            forecast_only['date'] = forecast_only.index
            forecast_only = forecast_only.reset_index(drop=True)

            result_list.append(forecast_only)

    if not result_list:
        print("❌ 모든 예측이 실패하여 결과가 없습니다.")
        return pd.DataFrame()

    final_df = pd.concat(result_list, ignore_index=True)
    return final_df

def merge_forecast_with_actuals(forecast_df, trade_data_df):
    import pandas as pd

    # 📌 1. 복사 및 컬럼명 정리
    forecast_df = forecast_df.copy()
    forecast_df = forecast_df.rename(columns={'hs_code': 'root_hs_code'})  # 혹시 모를 컬럼명 정리

    # 'period' → 'date'로 통일
    if 'period' in forecast_df.columns:
        forecast_df = forecast_df.rename(columns={'period': 'date'})

    forecast_df['date'] = pd.to_datetime(forecast_df['date'])
    trade_data_df['date'] = pd.to_datetime(trade_data_df['date'])

    # 예측 컬럼 확인
    forecast_cols = ['expDlr_yoy_forecast', 'impDlr_yoy_forecast']
    present_forecast_cols = [col for col in forecast_cols if col in forecast_df.columns]
    if not present_forecast_cols:
        raise KeyError("❌ forecast_df에 'expDlr_yoy_forecast' 또는 'impDlr_yoy_forecast' 컬럼이 없습니다.")

    # 📌 2. 무역 데이터 → wide 포맷으로 변환
    trade_pivot = trade_data_df.pivot_table(
        index=['date', 'root_hs_code'],
        columns='indicator',
        values='value',
        aggfunc='last'
    ).reset_index()

    # 📌 3. 예측 데이터 선택
    forecast_selected = forecast_df[['date', 'root_hs_code'] + present_forecast_cols].drop_duplicates()

    # 📌 4. 병합
    combined_df = pd.merge(
        trade_pivot,
        forecast_selected,
        on=['date', 'root_hs_code'],
        how='outer'
    ).sort_values(['root_hs_code', 'date']).reset_index(drop=True)

    # 📌 5. YoY 보정
    combined_df['final_expDlr_yoy'] = combined_df['expDlr_yoy']
    if 'expDlr_yoy_forecast' in combined_df.columns:
        combined_df.loc[combined_df['final_expDlr_yoy'].isna(), 'final_expDlr_yoy'] = combined_df['expDlr_yoy_forecast']

    combined_df['final_impDlr_yoy'] = combined_df['impDlr_yoy']
    if 'impDlr_yoy_forecast' in combined_df.columns:
        combined_df.loc[combined_df['final_impDlr_yoy'].isna(), 'final_impDlr_yoy'] = combined_df['impDlr_yoy_forecast']

    # 📌 6. 자료형 정리
    combined_df['final_expDlr_yoy'] = pd.to_numeric(combined_df['final_expDlr_yoy'], errors='coerce')
    combined_df['final_impDlr_yoy'] = pd.to_numeric(combined_df['final_impDlr_yoy'], errors='coerce')

    # 📌 7. 12개월 전 실적
    combined_df['expDlr_lag12'] = combined_df.groupby('root_hs_code')['expDlr'].shift(12)
    combined_df['impDlr_lag12'] = combined_df.groupby('root_hs_code')['impDlr'].shift(12)

    # 📌 8. 12개월 후 예측
    combined_df['expDlr_forecast_12m'] = combined_df['expDlr_lag12'] * (1 + combined_df['final_expDlr_yoy'])
    combined_df['impDlr_forecast_12m'] = combined_df['impDlr_lag12'] * (1 + combined_df['final_impDlr_yoy'])

    return combined_df

def pivot_forecast_df(forecast_df):
    # 피벗하여 target_col 기준으로 예측값을 컬럼화
    forecast_df = forecast_df.rename(columns={'hs_code': 'root_hs_code'})
    forecast_df['date'] = pd.to_datetime(forecast_df['date'])

    forecast_pivot = forecast_df.pivot_table(index=['date', 'root_hs_code'],
                                             columns='target_col',
                                             values='yoy_forecast').reset_index()

    # 컬럼 이름 정리
    forecast_pivot.columns.name = None
    forecast_pivot = forecast_pivot.rename(columns={
        'expDlr_yoy': 'expDlr_yoy_forecast',
        'impDlr_yoy': 'impDlr_yoy_forecast'
    })
    return forecast_pivot

def upload_forecast_to_db(df, db_info, table_name='korea_monthly_trade_data_forecast'):
    """
    예측 결과 데이터를 MySQL(MariaDB)에 업로드하는 함수 (중복 시 대체)

    Parameters:
    - df (pd.DataFrame): 업로드할 데이터프레임
    - db_info (dict): DB 연결 정보. keys = ['host', 'port', 'user', 'password', 'database']
    - table_name (str): 업로드할 테이블 이름
    """
    try:
        # ✅ SQLAlchemy 엔진 생성
        engine = create_engine(
            f"mysql+pymysql://{db_info['user']}:{db_info['password']}@{db_info['host']}:{db_info['port']}/{db_info['database']}"
        )
        conn = engine.raw_connection()
        cursor = conn.cursor()

        # ✅ 테이블 생성 (없을 경우)
        create_table_query = f"""
        CREATE TABLE IF NOT EXISTS {table_name} (
            date DATE,
            root_hs_code VARCHAR(20),
            final_expDlr_yoy FLOAT,
            expDlr_forecast_12m FLOAT,
            PRIMARY KEY (date, root_hs_code)
        );
        """
        cursor.execute(create_table_query)

        # ✅ NaN 및 NaT, inf → None 변환 (모든 타입 안전하게 처리)
        df = df.astype(object).where(pd.notnull(df), None)

        # ✅ REPLACE INTO
        insert_query = f"""
        REPLACE INTO {table_name} (date, root_hs_code, final_expDlr_yoy, expDlr_forecast_12m)
        VALUES (%s, %s, %s, %s)
        """
        data = df[['date', 'root_hs_code', 'final_expDlr_yoy', 'expDlr_forecast_12m']].values.tolist()
        cursor.executemany(insert_query, data)

        conn.commit()
        cursor.close()
        conn.close()

        print(f"✅ 데이터가 {table_name} 테이블에 성공적으로 업로드되었습니다. (중복 시 자동 갱신)")

    except Exception as e:
        print(f"❌ 업로드 실패: {e}")

# %%
db_info = {
    'host': get_db_host(),
    'port' : 3307,
    'user' : 'stox7412',
    'password' : 'Apt106503!~',
    'database' : 'investar'
}


trade_data_df =  fetch_table_data(db_info, "korea_monthly_trade_data")

hs_cd_list = trade_data_df['root_hs_code'].unique().tolist()
trade_data_df = fetch_table_data(db_info, "korea_monthly_trade_data")
# hs_cd_list = ['854232']
forecast_by_month = run_forecasting_pipeline(db_info, hs_code_list=hs_cd_list, max_hs_count=len(hs_cd_list), forecast_steps=13)
# Out:
# ✅ 'korea_monthly_trade_data' 테이블에서 1104097건의 데이터를 가져왔습니다.
# ✅ 'korea_monthly_trade_data' 테이블에서 1104097건의 데이터를 가져왔습니다.
# ✅ 'korea_monthly_trade_data' 테이블에서 1104097건의 데이터를 가져왔습니다.
# 📈 121120 예측 중...
# ✅ 121120: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=388.68
# ✅ 121120: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=2176.45
# 📈 151550 예측 중...
# ✅ 151550: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=1258.88
# ✅ 151550: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=1292.34
# 📈 151590 예측 중...
# ✅ 151590: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=644.32
# ✅ 151590: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=4.05
# 📈 170199 예측 중...
# ✅ 170199: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-4.67
# ✅ 170199: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=551.75
# 📈 190230 예측 중...
# ✅ 190230: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=-244.41
# ✅ 190230: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=130.76
# 📈 190590 예측 중...
# ✅ 190590: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-282.94
# ✅ 190590: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-226.86
# 📈 200599 예측 중...
# ✅ 200599: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-240.70
# ✅ 200599: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-157.19
# 📈 200830 예측 중...
# ✅ 200830: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-49.64
# ✅ 200830: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=489.64
# 📈 200899 예측 중...
# ✅ 200899: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 1, 1, 12), AIC=732.04
# ✅ 200899: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=-161.11
# 📈 210111 예측 중...
# ✅ 210111: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=131.63
# ✅ 210111: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=515.08
# 📈 210390 예측 중...
# ✅ 210390: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-185.11
# ✅ 210390: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=-313.20
# 📈 210690 예측 중...
# ✅ 210690: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-242.34
# ✅ 210690: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-311.35
# 📈 220890 예측 중...
# ✅ 220890: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-92.71
# ✅ 220890: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=68.97
# 📈 230910 예측 중...
# ✅ 230910: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=93.92
# ✅ 230910: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-196.11
# 📈 240220 예측 중...
# ✅ 240220: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=135.98
# ✅ 240220: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=724.73
# 📈 260300 예측 중...
# ✅ 260300: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 1, 1, 12), AIC=2332.22
# ✅ 260300: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=235.45
# 📈 270730 예측 중...
# ✅ 270730: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=491.09
# ✅ 270730: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 0, 12), AIC=143.49
# 📈 270750 예측 중...
# ✅ 270750: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 0, 12), AIC=219.38
# ✅ 270750: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=3319.47
# 📈 270799 예측 중...
# ✅ 270799: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=955.10
# ✅ 270799: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=626.50
# 📈 271019 예측 중...
# ✅ 271019: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-51.33
# ✅ 271019: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=302.46
# 📈 271113 예측 중...
# ✅ 271113: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-11.22
# ✅ 271113: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=174.88
# 📈 271119 예측 중...
# ✅ 271119: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=2878.03
# ✅ 271119: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=783.50
# 📈 271320 예측 중...
# ✅ 271320: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=172.52
# ✅ 271320: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 1, 1, 12), AIC=2105.10
# 📈 280300 예측 중...
# ✅ 280300: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=-59.57
# ✅ 280300: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-99.21
# 📈 280700 예측 중...
# ✅ 280700: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=505.67
# ✅ 280700: 최적 모델 order=(0, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=875.43
# 📈 281512 예측 중...
# ✅ 281512: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=678.42
# ✅ 281512: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=1302.75
# 📈 281520 예측 중...
# ✅ 281520: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=-80.44
# ✅ 281520: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=773.80
# 📈 282110 예측 중...
# ✅ 282110: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 0, 12), AIC=112.11
# ✅ 282110: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=44.35
# 📈 282520 예측 중...
# ✅ 282520: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 1, 1, 12), AIC=2110.48
# ✅ 282520: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=580.19
# 📈 283324 예측 중...
# ✅ 283324: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=1347.93
# ✅ 283324: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=826.40
# 📈 283691 예측 중...
# ✅ 283691: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=2694.13
# ✅ 283691: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=543.00
# 📈 283711 예측 중...
# ✅ 283711: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=92.69
# ✅ 283711: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=2983.02
# 📈 284190 예측 중...
# ✅ 284190: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=277.29
# ✅ 284190: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=226.05
# 📈 290121 예측 중...
# ✅ 290121: 최적 모델 order=(1, 0, 0), seasonal_order=(0, 0, 1, 12), AIC=153.37
# ✅ 290121: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=3588.37
# 📈 290122 예측 중...
# ✅ 290122: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=125.88
# ✅ 290122: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=1332.12
# 📈 290124 예측 중...
# ✅ 290124: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 0, 12), AIC=475.55
# ✅ 290124: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=665.78
# 📈 290220 예측 중...
# ✅ 290220: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=145.59
# ✅ 290220: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=3667.93
# 📈 290230 예측 중...
# ✅ 290230: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=656.84
# ✅ 290230: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=614.89
# 📈 290241 예측 중...
# ✅ 290241: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=4571.59
# ✅ 290241: 최적 모델 order=(0, 0, 0), seasonal_order=(1, 1, 1, 12), AIC=3910.26
# 📈 290243 예측 중...
# ✅ 290243: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=55.62
# ✅ 290243: 최적 모델 order=(0, 0, 0), seasonal_order=(0, 1, 1, 12), AIC=4283.54
# 📈 290250 예측 중...
# ✅ 290250: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 0, 12), AIC=310.59
# ✅ 290250: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=456.19
# 📈 290315 예측 중...
# ✅ 290315: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=592.73
# ✅ 290315: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=3288.61
# 📈 290516 예측 중...
# ✅ 290516: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=1382.78
# ✅ 290516: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=824.08
# 📈 290531 예측 중...
# ✅ 290531: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=1211.65
# ✅ 290531: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=92.05
# 📈 290539 예측 중...
# ✅ 290539: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=80.59
# ✅ 290539: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=256.11
# 📈 290723 예측 중...
# ✅ 290723: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=131.67
# ✅ 290723: 최적 모델 order=(1, 0, 0), seasonal_order=(1, 1, 1, 12), AIC=384.56
# 📈 291736 예측 중...
# ✅ 291736: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=37.88
# ✅ 291736: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 1, 1, 12), AIC=1682.79
# 📈 291739 예측 중...
# ✅ 291739: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=14.67
# ✅ 291739: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=44.45
# 📈 292610 예측 중...
# ✅ 292610: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=515.19
# ✅ 292610: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=450.58
# 📈 292910 예측 중...
# ✅ 292910: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=55.34
# ✅ 292910: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-50.51
# 📈 293299 예측 중...
# ✅ 293299: 최적 모델 order=(0, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=787.12
# ✅ 293299: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=250.87
# 📈 293399 예측 중...
# ✅ 293399: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=229.45
# ✅ 293399: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-43.10
# 📈 293499 예측 중...
# ✅ 293499: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=516.75
# ✅ 293499: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=44.27
# 📈 294130 예측 중...
# ✅ 294130: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=3114.48
# ✅ 294130: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=599.11
# 📈 294190 예측 중...
# ✅ 294190: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-9.32
# ✅ 294190: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-59.73
# 📈 300490 예측 중...
# ✅ 300490: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-202.21
# ✅ 300490: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-84.93
# 📈 300640 예측 중...
# ✅ 300640: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-57.94
# ✅ 300640: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=-179.44
# 📈 310520 예측 중...
# ✅ 310520: 최적 모델 order=(0, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=669.11
# ✅ 310520: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=422.35
# 📈 320417 예측 중...
# ✅ 320417: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-136.32
# ✅ 320417: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-190.12
# 📈 320490 예측 중...
# ✅ 320490: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=562.28
# ✅ 320490: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=366.05
# 📈 320730 예측 중...
# ✅ 320730: 최적 모델 order=(1, 0, 0), seasonal_order=(1, 0, 0, 12), AIC=385.71
# ✅ 320730: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=48.43
# 📈 320890 예측 중...
# ✅ 320890: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-180.71
# ✅ 320890: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-297.20
# 📈 321410 예측 중...
# ✅ 321410: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=-121.65
# ✅ 321410: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-241.26
# 📈 321519 예측 중...
# ✅ 321519: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-184.17
# ✅ 321519: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=18.52
# 📈 330410 예측 중...
# ✅ 330410: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=492.90
# ✅ 330410: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 0, 12), AIC=-21.63
# 📈 330420 예측 중...
# ✅ 330420: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-91.26
# ✅ 330420: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-20.43
# 📈 330499 예측 중...
# ✅ 330499: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=168.66
# ✅ 330499: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-322.80
# 📈 330510 예측 중...
# ✅ 330510: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=82.62
# ✅ 330510: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-31.37
# 📈 330590 예측 중...
# ✅ 330590: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=-36.59
# ✅ 330590: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-171.23
# 📈 330610 예측 중...
# ✅ 330610: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=249.90
# ✅ 330610: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=197.27
# 📈 330790 예측 중...
# ✅ 330790: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=111.31
# ✅ 330790: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=109.31
# 📈 340130 예측 중...
# ✅ 340130: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=342.98
# ✅ 340130: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=317.45
# 📈 340290 예측 중...
# ✅ 340290: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-150.86
# ✅ 340290: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-177.66
# 📈 340420 예측 중...
# ✅ 340420: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=630.64
# ✅ 340420: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=541.62
# 📈 350610 예측 중...
# ✅ 350610: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-191.63
# ✅ 350610: 최적 모델 order=(1, 0, 0), seasonal_order=(0, 0, 1, 12), AIC=-104.46
# 📈 350691 예측 중...
# ✅ 350691: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-90.85
# ✅ 350691: 최적 모델 order=(1, 1, 0), seasonal_order=(0, 0, 1, 12), AIC=-158.79
# 📈 350790 예측 중...
# ✅ 350790: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=390.96
# ✅ 350790: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-53.22
# 📈 360610 예측 중...
# ✅ 360610: 최적 모델 order=(0, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=721.48
# ✅ 360610: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 1, 1, 12), AIC=3333.16
# 📈 370199 예측 중...
# ✅ 370199: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=145.09
# ✅ 370199: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-158.42
# 📈 370790 예측 중...
# ✅ 370790: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-246.21
# ✅ 370790: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-245.70
# 📈 380891 예측 중...
# ✅ 380891: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=546.24
# ✅ 380891: 최적 모델 order=(0, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=575.36
# 📈 380892 예측 중...
# ✅ 380892: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 1, 1, 12), AIC=711.36
# ✅ 380892: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=440.94
# 📈 381400 예측 중...
# ✅ 381400: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-93.81
# ✅ 381400: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=40.28
# 📈 381800 예측 중...
# ✅ 381800: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 0, 0, 12), AIC=-107.58
# ✅ 381800: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-221.14
# 📈 382490 예측 중...
# ✅ 382490: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-10.71
# ✅ 382490: 최적 모델 order=(1, 1, 0), seasonal_order=(1, 0, 0, 12), AIC=-57.14
# 📈 390110 예측 중...
# ✅ 390110: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-199.63
# ✅ 390110: 최적 모델 order=(1, 1, 0), seasonal_order=(0, 0, 1, 12), AIC=12.37
# 📈 390120 예측 중...
# ✅ 390120: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-223.75
# ✅ 390120: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=153.85
# 📈 390130 예측 중...
# ✅ 390130: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-71.52
# ✅ 390130: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=244.02
# 📈 390190 예측 중...
# ✅ 390190: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=22.95
# ✅ 390190: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-193.18
# 📈 390210 예측 중...
# ✅ 390210: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-273.90
# ✅ 390210: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=161.06
# 📈 390220 예측 중...
# ✅ 390220: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=2323.10
# ✅ 390220: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=442.23
# 📈 390230 예측 중...
# ✅ 390230: 최적 모델 order=(1, 0, 0), seasonal_order=(1, 0, 1, 12), AIC=-195.56
# ✅ 390230: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=123.14
# 📈 390290 예측 중...
# ✅ 390290: 최적 모델 order=(1, 1, 0), seasonal_order=(1, 0, 0, 12), AIC=-3.31
# ✅ 390290: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-37.93
# 📈 390319 예측 중...
# ✅ 390319: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-125.49
# ✅ 390319: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 0, 12), AIC=191.87
# 📈 390320 예측 중...
# ✅ 390320: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-110.75
# ✅ 390320: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=508.86
# 📈 390330 예측 중...
# ✅ 390330: 최적 모델 order=(1, 0, 0), seasonal_order=(0, 0, 1, 12), AIC=-251.03
# ✅ 390330: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 0, 12), AIC=151.03
# 📈 390390 예측 중...
# ✅ 390390: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-120.26
# ✅ 390390: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=20.53
# 📈 390410 예측 중...
# ✅ 390410: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-25.54
# ✅ 390410: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=392.99
# 📈 390610 예측 중...
# ✅ 390610: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-49.75
# ✅ 390610: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 0, 12), AIC=203.25
# 📈 390690 예측 중...
# ✅ 390690: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-280.47
# ✅ 390690: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-270.68
# 📈 390710 예측 중...
# ✅ 390710: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-92.65
# ✅ 390710: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=131.95
# 📈 390730 예측 중...
# ✅ 390730: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-46.73
# ✅ 390730: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-94.12
# 📈 390740 예측 중...
# ✅ 390740: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-27.00
# ✅ 390740: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-39.58
# 📈 390799 예측 중...
# ✅ 390799: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-230.50
# ✅ 390799: 최적 모델 order=(1, 0, 0), seasonal_order=(1, 0, 1, 12), AIC=-108.79
# 📈 390810 예측 중...
# ✅ 390810: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=15.13
# ✅ 390810: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 0, 12), AIC=14.67
# 📈 390950 예측 중...
# ✅ 390950: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=-124.56
# ✅ 390950: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-79.41
# 📈 391000 예측 중...
# ✅ 391000: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-170.04
# ✅ 391000: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-170.22
# 📈 391110 예측 중...
# ✅ 391110: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-213.88
# ✅ 391110: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-53.71
# 📈 391190 예측 중...
# ✅ 391190: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=173.13
# ✅ 391190: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-83.77
# 📈 391239 예측 중...
# ✅ 391239: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=-22.72
# ✅ 391239: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=55.29
# 📈 391810 예측 중...
# ✅ 391810: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-248.63
# ✅ 391810: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=221.33
# 📈 391910 예측 중...
# ✅ 391910: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-209.83
# ✅ 391910: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-219.09
# 📈 391990 예측 중...
# ✅ 391990: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-239.23
# ✅ 391990: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-231.47
# 📈 392010 예측 중...
# ✅ 392010: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-248.42
# ✅ 392010: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-254.64
# 📈 392020 예측 중...
# ✅ 392020: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-351.98
# ✅ 392020: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-105.21
# 📈 392049 예측 중...
# ✅ 392049: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-138.39
# ✅ 392049: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-32.07
# 📈 392051 예측 중...
# ✅ 392051: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-102.38
# ✅ 392051: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=155.09
# 📈 392062 예측 중...
# ✅ 392062: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-336.90
# ✅ 392062: 최적 모델 order=(1, 0, 0), seasonal_order=(1, 0, 1, 12), AIC=-139.92
# 📈 392099 예측 중...
# ✅ 392099: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 0, 0, 12), AIC=35.52
# ✅ 392099: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-175.36
# 📈 392119 예측 중...
# ✅ 392119: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-99.33
# ✅ 392119: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-32.15
# 📈 392190 예측 중...
# ✅ 392190: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-270.30
# ✅ 392190: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 0, 12), AIC=-310.29
# 📈 392310 예측 중...
# ✅ 392310: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-327.95
# ✅ 392310: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-337.54
# 📈 392321 예측 중...
# ✅ 392321: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-200.90
# ✅ 392321: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=9.03
# 📈 392330 예측 중...
# ✅ 392330: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-214.83
# ✅ 392330: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-151.67
# 📈 392390 예측 중...
# ✅ 392390: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 0, 12), AIC=-121.44
# ✅ 392390: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=-178.91
# 📈 392630 예측 중...
# ✅ 392630: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=1150.31
# ✅ 392630: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=318.11
# 📈 392690 예측 중...
# ✅ 392690: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-307.29
# ✅ 392690: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-303.95
# 📈 400219 예측 중...
# ✅ 400219: 최적 모델 order=(1, 0, 0), seasonal_order=(1, 0, 1, 12), AIC=-166.80
# ✅ 400219: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=244.98
# 📈 400220 예측 중...
# ✅ 400220: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 0, 12), AIC=-68.00
# ✅ 400220: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=333.48
# 📈 400251 예측 중...
# ✅ 400251: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=761.47
# ✅ 400251: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 1, 1, 12), AIC=3557.79
# 📈 400259 예측 중...
# ✅ 400259: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=6.52
# ✅ 400259: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=249.51
# 📈 400270 예측 중...
# ✅ 400270: 최적 모델 order=(1, 0, 0), seasonal_order=(0, 0, 1, 12), AIC=177.82
# ✅ 400270: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=140.22
# 📈 401110 예측 중...
# ✅ 401110: 최적 모델 order=(1, 0, 0), seasonal_order=(0, 0, 1, 12), AIC=-159.73
# ✅ 401110: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-190.07
# 📈 401120 예측 중...
# ✅ 401120: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-223.94
# ✅ 401120: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=-9.62
# 📈 401693 예측 중...
# ✅ 401693: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-138.03
# ✅ 401693: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 0, 12), AIC=-169.64
# 📈 401699 예측 중...
# ✅ 401699: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-200.05
# ✅ 401699: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-213.46
# 📈 410792 예측 중...
# ✅ 410792: 최적 모델 order=(1, 0, 0), seasonal_order=(0, 0, 1, 12), AIC=-22.36
# ✅ 410792: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=291.44
# 📈 470329 예측 중...
# ✅ 470329: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 1, 1, 12), AIC=2164.80
# ✅ 470329: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-12.97
# 📈 470710 예측 중...
# ✅ 470710: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=679.18
# ✅ 470710: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=57.31
# 📈 480511 예측 중...
# ✅ 480511: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=467.63
# ✅ 480511: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=571.80
# 📈 480990 예측 중...
# ✅ 480990: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-5.61
# ✅ 480990: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=187.13
# 📈 481019 예측 중...
# ✅ 481019: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-323.56
# ✅ 481019: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 0, 12), AIC=215.13
# 📈 481092 예측 중...
# ✅ 481092: 최적 모델 order=(1, 1, 0), seasonal_order=(1, 1, 1, 12), AIC=258.31
# ✅ 481092: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=1540.32
# 📈 481190 예측 중...
# ✅ 481190: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=121.31
# ✅ 481190: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 0, 12), AIC=-24.97
# 📈 490199 예측 중...
# ✅ 490199: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=88.50
# ✅ 490199: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-234.20
# 📈 540211 예측 중...
# ✅ 540211: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=473.09
# ✅ 540211: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=691.74
# 📈 540247 예측 중...
# ✅ 540247: 최적 모델 order=(1, 0, 0), seasonal_order=(1, 0, 0, 12), AIC=-173.50
# ✅ 540247: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=49.04
# 📈 540249 예측 중...
# ✅ 540249: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-30.45
# ✅ 540249: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=400.80
# 📈 540752 예측 중...
# ✅ 540752: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-177.05
# ✅ 540752: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=7.46
# 📈 540761 예측 중...
# ✅ 540761: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-187.23
# ✅ 540761: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-18.90
# 📈 540792 예측 중...
# ✅ 540792: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=-72.32
# ✅ 540792: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=304.23
# 📈 550320 예측 중...
# ✅ 550320: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-211.93
# ✅ 550320: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=216.11
# 📈 560122 예측 중...
# ✅ 560122: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=278.81
# ✅ 560122: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=124.50
# 📈 560394 예측 중...
# ✅ 560394: 최적 모델 order=(1, 0, 0), seasonal_order=(0, 0, 1, 12), AIC=-172.85
# ✅ 560394: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-129.42
# 📈 560749 예측 중...
# ✅ 560749: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-122.25
# ✅ 560749: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=264.40
# 📈 590320 예측 중...
# ✅ 590320: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-251.73
# ✅ 590320: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-94.68
# 📈 590390 예측 중...
# ✅ 590390: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-196.08
# ✅ 590390: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-41.53
# 📈 591110 예측 중...
# ✅ 591110: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=439.45
# ✅ 591110: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=974.93
# 📈 600410 예측 중...
# ✅ 600410: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-200.59
# ✅ 600410: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=129.32
# 📈 600622 예측 중...
# ✅ 600622: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-161.74
# ✅ 600622: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=345.57
# 📈 600632 예측 중...
# ✅ 600632: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-232.91
# ✅ 600632: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 0, 12), AIC=265.36
# 📈 610910 예측 중...
# ✅ 610910: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-130.10
# ✅ 610910: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-221.42
# 📈 621710 예측 중...
# ✅ 621710: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-118.86
# ✅ 621710: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-111.06
# 📈 621790 예측 중...
# ✅ 621790: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=107.92
# ✅ 621790: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=407.85
# 📈 630293 예측 중...
# ✅ 630293: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=291.17
# ✅ 630293: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=346.74
# 📈 630710 예측 중...
# ✅ 630710: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-222.10
# ✅ 630710: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=265.92
# 📈 630900 예측 중...
# ✅ 630900: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-107.42
# ✅ 630900: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-94.82
# 📈 680421 예측 중...
# ✅ 680421: 최적 모델 order=(1, 1, 0), seasonal_order=(0, 0, 1, 12), AIC=-253.44
# ✅ 680421: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-127.49
# 📈 690919 예측 중...
# ✅ 690919: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=207.24
# ✅ 690919: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-115.56
# 📈 691490 예측 중...
# ✅ 691490: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-40.29
# ✅ 691490: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=33.10
# 📈 700319 예측 중...
# ✅ 700319: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=2596.15
# ✅ 700319: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=530.41
# 📈 700490 예측 중...
# ✅ 700490: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=2110.78
# ✅ 700490: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=698.07
# 📈 700529 예측 중...
# ✅ 700529: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=296.76
# ✅ 700529: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=80.22
# 📈 700600 예측 중...
# ✅ 700600: 최적 모델 order=(1, 0, 0), seasonal_order=(0, 0, 1, 12), AIC=279.46
# ✅ 700600: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=54.67
# 📈 701349 예측 중...
# ✅ 701349: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=571.53
# ✅ 701349: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-26.08
# 📈 702000 예측 중...
# ✅ 702000: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=12.37
# ✅ 702000: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-210.34
# 📈 710510 예측 중...
# ✅ 710510: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=36.29
# ✅ 710510: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=52.02
# 📈 710610 예측 중...
# ✅ 710610: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=426.08
# ✅ 710610: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=217.37
# 📈 710691 예측 중...
# ✅ 710691: 최적 모델 order=(1, 1, 0), seasonal_order=(1, 0, 1, 12), AIC=36.66
# ✅ 710691: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=2117.81
# 📈 710812 예측 중...
# ✅ 710812: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=966.32
# ✅ 710812: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=504.98
# 📈 710813 예측 중...
# ✅ 710813: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=475.02
# ✅ 710813: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=1073.50
# 📈 711021 예측 중...
# ✅ 711021: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 1, 1, 12), AIC=1748.75
# ✅ 711021: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=280.30
# 📈 711292 예측 중...
# ✅ 711292: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=1437.82
# ✅ 711292: 최적 모델 order=(0, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=965.11
# 📈 711319 예측 중...
# ✅ 711319: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=390.40
# ✅ 711319: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=144.46
# 📈 711890 예측 중...
# ✅ 711890: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=2515.28
# ✅ 711890: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=962.44
# 📈 720270 예측 중...
# ✅ 720270: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=649.54
# ✅ 720270: 최적 모델 order=(0, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=2687.87
# 📈 720712 예측 중...
# ✅ 720712: 최적 모델 order=(0, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=2675.83
# ✅ 720712: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=549.61
# 📈 720826 예측 중...
# ✅ 720826: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=68.27
# ✅ 720826: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=1149.71
# 📈 720827 예측 중...
# ✅ 720827: 최적 모델 order=(1, 0, 0), seasonal_order=(0, 0, 1, 12), AIC=-47.61
# ✅ 720827: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=1256.94
# 📈 720836 예측 중...
# ✅ 720836: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=441.16
# ✅ 720836: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=1499.35
# 📈 720837 예측 중...
# ✅ 720837: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=306.98
# ✅ 720837: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=547.34
# 📈 720838 예측 중...
# ✅ 720838: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 0, 12), AIC=301.42
# ✅ 720838: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 0, 12), AIC=238.16
# 📈 720839 예측 중...
# ✅ 720839: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=77.93
# ✅ 720839: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 0, 12), AIC=101.97
# 📈 720851 예측 중...
# ✅ 720851: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-24.03
# ✅ 720851: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=267.91
# 📈 720852 예측 중...
# ✅ 720852: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=406.29
# ✅ 720852: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 1, 1, 12), AIC=1195.63
# 📈 720916 예측 중...
# ✅ 720916: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-125.28
# ✅ 720916: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=762.75
# 📈 720917 예측 중...
# ✅ 720917: 최적 모델 order=(1, 0, 0), seasonal_order=(0, 0, 1, 12), AIC=-184.70
# ✅ 720917: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=635.37
# 📈 720918 예측 중...
# ✅ 720918: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-39.82
# ✅ 720918: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 1, 1, 12), AIC=732.62
# 📈 721012 예측 중...
# ✅ 721012: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-94.19
# ✅ 721012: 최적 모델 order=(0, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=1369.82
# 📈 721030 예측 중...
# ✅ 721030: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 0, 12), AIC=-67.01
# ✅ 721030: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=346.36
# 📈 721049 예측 중...
# ✅ 721049: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-179.42
# ✅ 721049: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=289.24
# 📈 721061 예측 중...
# ✅ 721061: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 0, 12), AIC=-55.18
# ✅ 721061: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=2645.63
# 📈 721069 예측 중...
# ✅ 721069: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 0, 12), AIC=158.03
# ✅ 721069: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=2515.73
# 📈 721070 예측 중...
# ✅ 721070: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-234.64
# ✅ 721070: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=954.63
# 📈 721240 예측 중...
# ✅ 721240: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-49.52
# ✅ 721240: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=405.38
# 📈 721391 예측 중...
# ✅ 721391: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 0, 12), AIC=260.61
# ✅ 721391: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=277.89
# 📈 721633 예측 중...
# ✅ 721633: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=212.64
# ✅ 721633: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 0, 12), AIC=376.82
# 📈 721710 예측 중...
# ✅ 721710: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-200.20
# ✅ 721710: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 1, 1, 12), AIC=407.02
# 📈 721730 예측 중...
# ✅ 721730: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-92.27
# ✅ 721730: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=299.18
# 📈 721912 예측 중...
# ✅ 721912: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=558.65
# ✅ 721912: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=306.03
# 📈 721913 예측 중...
# ✅ 721913: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=382.78
# ✅ 721913: 최적 모델 order=(1, 0, 0), seasonal_order=(0, 1, 1, 12), AIC=514.16
# 📈 721933 예측 중...
# ✅ 721933: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=324.64
# ✅ 721933: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=374.67
# 📈 721934 예측 중...
# ✅ 721934: 최적 모델 order=(1, 0, 0), seasonal_order=(0, 0, 1, 12), AIC=-56.04
# ✅ 721934: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 0, 0, 12), AIC=148.60
# 📈 722020 예측 중...
# ✅ 722020: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=28.96
# ✅ 722020: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=106.73
# 📈 722300 예측 중...
# ✅ 722300: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-236.71
# ✅ 722300: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-33.25
# 📈 722519 예측 중...
# ✅ 722519: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=350.09
# ✅ 722519: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=729.16
# 📈 722530 예측 중...
# ✅ 722530: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=1392.00
# ✅ 722530: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=2131.58
# 📈 722550 예측 중...
# ✅ 722550: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 1, 1, 12), AIC=1246.77
# ✅ 722550: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=1010.00
# 📈 722592 예측 중...
# ✅ 722592: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=505.85
# ✅ 722592: 최적 모델 order=(0, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=2065.22
# 📈 722599 예측 중...
# ✅ 722599: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 1, 1, 12), AIC=1302.75
# ✅ 722599: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=797.72
# 📈 722790 예측 중...
# ✅ 722790: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=291.22
# ✅ 722790: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=208.99
# 📈 722830 예측 중...
# ✅ 722830: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=128.18
# ✅ 722830: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=402.35
# 📈 722990 예측 중...
# ✅ 722990: 최적 모델 order=(1, 1, 0), seasonal_order=(0, 0, 1, 12), AIC=-170.79
# ✅ 722990: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=191.69
# 📈 730511 예측 중...
# ✅ 730511: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=573.23
# ✅ 730511: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 1, 1, 12), AIC=849.96
# 📈 730512 예측 중...
# ✅ 730512: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=806.23
# ⚠️ 730512: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=730512, col=impDlr_yoy
# 📈 730531 예측 중...
# ✅ 730531: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=505.60
# ✅ 730531: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=1493.29
# 📈 730629 예측 중...
# ✅ 730629: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=2481.56
# ✅ 730629: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=2525.37
# 📈 730630 예측 중...
# ✅ 730630: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-34.91
# ✅ 730630: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=277.77
# 📈 730640 예측 중...
# ✅ 730640: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=114.70
# ✅ 730640: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=415.28
# 📈 730729 예측 중...
# ✅ 730729: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-121.35
# ✅ 730729: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=129.43
# 📈 730791 예측 중...
# ✅ 730791: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-18.96
# ✅ 730791: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=94.45
# 📈 730793 예측 중...
# ✅ 730793: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-12.81
# ✅ 730793: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=500.64
# 📈 730799 예측 중...
# ✅ 730799: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-75.39
# ✅ 730799: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=134.61
# 📈 730840 예측 중...
# ✅ 730840: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=349.30
# ✅ 730840: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=994.82
# 📈 730890 예측 중...
# ✅ 730890: 최적 모델 order=(0, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=814.32
# ✅ 730890: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=281.21
# 📈 730900 예측 중...
# ✅ 730900: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=485.76
# ✅ 730900: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=783.42
# 📈 731100 예측 중...
# ✅ 731100: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=51.40
# ✅ 731100: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=87.27
# 📈 731210 예측 중...
# ✅ 731210: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-215.17
# ✅ 731210: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-121.46
# 📈 731815 예측 중...
# ✅ 731815: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-166.19
# ✅ 731815: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 0, 12), AIC=253.56
# 📈 731816 예측 중...
# ✅ 731816: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-122.35
# ✅ 731816: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-202.99
# 📈 732182 예측 중...
# ✅ 732182: 최적 모델 order=(0, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=1422.18
# ✅ 732182: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=1703.91
# 📈 732290 예측 중...
# ✅ 732290: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=890.44
# ✅ 732290: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=653.18
# 📈 732690 예측 중...
# ✅ 732690: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-233.64
# ✅ 732690: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-124.31
# 📈 740200 예측 중...
# ✅ 740200: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=2454.33
# ✅ 740200: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=2294.38
# 📈 740311 예측 중...
# ✅ 740311: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=296.52
# ✅ 740311: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-6.77
# 📈 740321 예측 중...
# ✅ 740321: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=228.48
# ✅ 740321: 최적 모델 order=(0, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=3921.88
# 📈 740400 예측 중...
# ✅ 740400: 최적 모델 order=(1, 0, 0), seasonal_order=(0, 1, 1, 12), AIC=470.44
# ✅ 740400: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=58.45
# 📈 740721 예측 중...
# ✅ 740721: 최적 모델 order=(1, 0, 0), seasonal_order=(1, 0, 0, 12), AIC=183.63
# ✅ 740721: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=909.21
# 📈 740811 예측 중...
# ✅ 740811: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=114.28
# ✅ 740811: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=783.04
# 📈 740819 예측 중...
# ✅ 740819: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=102.26
# ✅ 740819: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=742.05
# 📈 740911 예측 중...
# ✅ 740911: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=128.37
# ✅ 740911: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=310.12
# 📈 740921 예측 중...
# ✅ 740921: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=12.14
# ✅ 740921: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=542.94
# 📈 740990 예측 중...
# ✅ 740990: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=296.11
# ✅ 740990: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-13.82
# 📈 741011 예측 중...
# ✅ 741011: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=86.74
# ✅ 741011: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-108.22
# 📈 741021 예측 중...
# ✅ 741021: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=-75.90
# ✅ 741021: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-235.26
# 📈 741110 예측 중...
# ✅ 741110: 최적 모델 order=(1, 1, 0), seasonal_order=(0, 0, 1, 12), AIC=-84.26
# ✅ 741110: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=227.12
# 📈 741999 예측 중...
# ✅ 741999: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=293.09
# ✅ 741999: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=36.25
# 📈 760120 예측 중...
# ✅ 760120: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=166.87
# ✅ 760120: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=20.37
# 📈 760612 예측 중...
# ✅ 760612: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-139.47
# ✅ 760612: 최적 모델 order=(1, 1, 0), seasonal_order=(1, 0, 1, 12), AIC=-195.17
# 📈 760711 예측 중...
# ✅ 760711: 최적 모델 order=(1, 1, 0), seasonal_order=(0, 0, 1, 12), AIC=-338.61
# ✅ 760711: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=-82.13
# 📈 761090 예측 중...
# ✅ 761090: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=215.99
# ✅ 761090: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 0, 0, 12), AIC=354.88
# 📈 761699 예측 중...
# ✅ 761699: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-114.43
# ✅ 761699: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-153.14
# 📈 780110 예측 중...
# ✅ 780110: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=401.30
# ✅ 780110: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=198.65
# 📈 780199 예측 중...
# ✅ 780199: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=200.28
# ✅ 780199: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=739.81
# 📈 790111 예측 중...
# ✅ 790111: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=108.73
# ✅ 790111: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=403.53
# 📈 790112 예측 중...
# ✅ 790112: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=270.99
# ✅ 790112: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=3163.95
# 📈 790120 예측 중...
# ✅ 790120: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=225.10
# ✅ 790120: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=2450.62
# 📈 820730 예측 중...
# ✅ 820730: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=134.79
# ✅ 820730: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=536.33
# 📈 820740 예측 중...
# ✅ 820740: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-87.79
# ✅ 820740: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=76.52
# 📈 820750 예측 중...
# ✅ 820750: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=-63.71
# ✅ 820750: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-312.35
# 📈 820770 예측 중...
# ✅ 820770: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-193.57
# ✅ 820770: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-114.79
# 📈 820900 예측 중...
# ✅ 820900: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-169.19
# ✅ 820900: 최적 모델 order=(1, 1, 0), seasonal_order=(1, 0, 1, 12), AIC=-275.56
# 📈 830230 예측 중...
# ✅ 830230: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=261.08
# ✅ 830230: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=189.62
# 📈 831120 예측 중...
# ✅ 831120: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-172.69
# ✅ 831120: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=139.15
# 📈 840310 예측 중...
# ✅ 840310: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=208.91
# ✅ 840310: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=763.22
# 📈 840410 예측 중...
# ✅ 840410: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=1281.76
# ✅ 840410: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=1789.57
# 📈 840510 예측 중...
# ✅ 840510: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=1265.24
# ✅ 840510: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=588.81
# 📈 840690 예측 중...
# ✅ 840690: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=967.18
# ✅ 840690: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=903.23
# 📈 840733 예측 중...
# ✅ 840733: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=942.12
# ✅ 840733: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=1902.92
# 📈 840734 예측 중...
# ✅ 840734: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=336.49
# ✅ 840734: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 1, 1, 12), AIC=659.74
# 📈 840810 예측 중...
# ✅ 840810: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=333.55
# ✅ 840810: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=709.26
# 📈 840890 예측 중...
# ✅ 840890: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=121.02
# ✅ 840890: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=91.48
# 📈 840991 예측 중...
# ✅ 840991: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 0, 0, 12), AIC=62.19
# ✅ 840991: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=-220.60
# 📈 840999 예측 중...
# ✅ 840999: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-261.89
# ✅ 840999: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-208.51
# 📈 841112 예측 중...
# ✅ 841112: 최적 모델 order=(0, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=3515.30
# ✅ 841112: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 1, 1, 12), AIC=3282.24
# 📈 841191 예측 중...
# ✅ 841191: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=118.99
# ✅ 841191: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=271.60
# 📈 841221 예측 중...
# ✅ 841221: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=140.92
# ✅ 841221: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=542.74
# 📈 841229 예측 중...
# ✅ 841229: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=232.60
# ✅ 841229: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=216.32
# 📈 841330 예측 중...
# ✅ 841330: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=17.16
# ...
# 📈 9031809091 예측 중...
# ✅ 9031809091: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=825.72
# ✅ 9031809091: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=1293.27
# 📈 9032 예측 중...
# ✅ 9032: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-64.80
# ✅ 9032: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-217.85
# 📈 9301 예측 중...
# ✅ 9301: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=4017.40
# ✅ 9301: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=1642.24
# 📈 9306 예측 중...
# ✅ 9306: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 1, 1, 12), AIC=742.40
# ✅ 9306: 최적 모델 order=(0, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=1230.62
# 📈 9401 예측 중...
# ✅ 9401: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-249.65
# ✅ 9401: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-382.63
# 📈 9401309000 예측 중...
# ✅ 9401309000: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=28.89
# ✅ 9401309000: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 0, 12), AIC=254.15
# 📈 940340 예측 중...
# ✅ 940340: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=244.23
# ✅ 940340: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=130.04
# 📈 9405 예측 중...
# ✅ 9405: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=74.04
# ✅ 9405: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-136.15
# 📈 9405409000 예측 중...
# ✅ 9405409000: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=244.46
# ✅ 9405409000: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=20.63
# 📈 961610 예측 중...
# ✅ 961610: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=230.30
# ✅ 961610: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=88.18
# 📈 8905907000 예측 중...
# ✅ 8905907000: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=322.08
# ⚠️ 8905907000: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=8905907000, col=impDlr_yoy
# 📈 8486306020 예측 중...
# ✅ 8486306020: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=420.35
# ⚠️ 8486306020: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=8486306020, col=impDlr_yoy
# 📈 8906100000 예측 중...
# ⚠️ 8906100000: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=8906100000, col=expDlr_yoy
# ⚠️ 8906100000: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=8906100000, col=impDlr_yoy
# 📈 8486304010 예측 중...
# ✅ 8486304010: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 1, 1, 12), AIC=2304.17
# ✅ 8486304010: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=859.95
# 📈 8401100000 예측 중...
# ⚠️ 8401100000: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=8401100000, col=expDlr_yoy
# ⚠️ 8401100000: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=8401100000, col=impDlr_yoy
# 📈 8905201000 예측 중...
# ❌ 8905201000 | 'expDlr_yoy'에 해당하는 데이터가 없습니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=8905201000, col=expDlr_yoy
# ❌ 8905201000 | 'impDlr_yoy'에 해당하는 데이터가 없습니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=8905201000, col=impDlr_yoy
# 📈 5402339000 예측 중...
# ✅ 5402339000: 최적 모델 order=(1, 0, 0), seasonal_order=(0, 0, 1, 12), AIC=40.31
# ✅ 5402339000: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-163.20
# 📈 5402469000 예측 중...
# ✅ 5402469000: 최적 모델 order=(1, 0, 0), seasonal_order=(1, 1, 1, 12), AIC=360.10
# ✅ 5402469000: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=26.15
# 📈 8486208410 예측 중...
# ✅ 8486208410: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=1232.41
# ✅ 8486208410: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=446.27
# 📈 8486208420 예측 중...
# ✅ 8486208420: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=1451.78
# ✅ 8486208420: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=1827.97
# 📈 8542311000 예측 중...
# ✅ 8542311000: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-259.50
# ✅ 8542311000: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-332.78
# 📈 8486303043 예측 중...
# ✅ 8486303043: 최적 모델 order=(0, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=590.14
# ⚠️ 8486303043: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=8486303043, col=impDlr_yoy
# 📈 8486305051 예측 중...
# ✅ 8486305051: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=1399.63
# ⚠️ 8486305051: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=8486305051, col=impDlr_yoy
# 📈 121221 예측 중...
# ✅ 121221: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=43.94
# ✅ 121221: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=331.43
# 📈 271012 예측 중...
# ✅ 271012: 최적 모델 order=(1, 0, 0), seasonal_order=(0, 0, 1, 12), AIC=87.04
# ✅ 271012: 최적 모델 order=(1, 0, 0), seasonal_order=(0, 0, 1, 12), AIC=33.08
# 📈 293190 예측 중...
# ✅ 293190: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-25.09
# ✅ 293190: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-104.52
# 📈 3702983000 예측 중...
# ✅ 3702983000: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-22.83
# ✅ 3702983000: 최적 모델 order=(0, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=686.05
# 📈 382600 예측 중...
# ✅ 382600: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=2228.83
# ✅ 382600: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 1, 1, 12), AIC=2282.02
# 📈 7210702000 예측 중...
# ✅ 7210702000: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 0, 12), AIC=-161.84
# ✅ 7210702000: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=191.93
# 📈 7212402000 예측 중...
# ✅ 7212402000: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-37.66
# ✅ 7212402000: 최적 모델 order=(0, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=388.91
# 📈 731940 예측 중...
# ✅ 731940: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=9.04
# ✅ 731940: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=64.10
# 📈 850760 예측 중...
# ✅ 850760: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-154.56
# ✅ 850760: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=65.78
# 📈 852349 예측 중...
# ✅ 852349: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=290.38
# ✅ 852349: 최적 모델 order=(0, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=273.86
# 📈 961900 예측 중...
# ✅ 961900: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-65.26
# ✅ 961900: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-135.01
# 📈 8429521021 예측 중...
# ✅ 8429521021: 최적 모델 order=(1, 0, 0), seasonal_order=(0, 0, 1, 12), AIC=-74.91
# ✅ 8429521021: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=186.15
# 📈 8529909643 예측 중...
# ✅ 8529909643: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=94.94
# ✅ 8529909643: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=280.75
# 📈 9030901000 예측 중...
# ✅ 9030901000: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 0, 12), AIC=28.17
# ✅ 9030901000: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=25.92
# 📈 9031499000 예측 중...
# ✅ 9031499000: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=199.82
# ✅ 9031499000: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=-18.86
# 📈 220299 예측 중...
# ✅ 220299: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=-85.65
# ✅ 220299: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-62.87
# 📈 300212 예측 중...
# ✅ 300212: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=133.28
# ✅ 300212: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=7.85
# 📈 3002121000 예측 중...
# ⚠️ 3002121000: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=3002121000, col=expDlr_yoy
# ⚠️ 3002121000: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=3002121000, col=impDlr_yoy
# 📈 300214 예측 중...
# ✅ 300214: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=140.16
# ✅ 300214: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=436.96
# 📈 300215 예측 중...
# ✅ 300215: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=219.91
# ✅ 300215: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=53.87
# 📈 370500 예측 중...
# ✅ 370500: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-61.40
# ✅ 370500: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=-3.74
# 📈 381239 예측 중...
# ✅ 381239: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-77.36
# ✅ 381239: 최적 모델 order=(1, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=-40.46
# 📈 382499 예측 중...
# ✅ 382499: 최적 모델 order=(1, 1, 0), seasonal_order=(1, 0, 1, 12), AIC=-10.10
# ✅ 382499: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 0, 12), AIC=-172.12
# 📈 3824997100 예측 중...
# ✅ 3824997100: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=6.16
# ✅ 3824997100: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-88.76
# 📈 390140 예측 중...
# ✅ 390140: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=21.84
# ✅ 390140: 최적 모델 order=(0, 0, 0), seasonal_order=(0, 0, 1, 12), AIC=12.80
# 📈 3901400000 예측 중...
# ✅ 3901400000: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=20.30
# ✅ 3901400000: 최적 모델 order=(0, 0, 0), seasonal_order=(0, 0, 1, 12), AIC=17.32
# 📈 390761 예측 중...
# ✅ 390761: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=-36.32
# ✅ 390761: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=88.33
# 📈 390769 예측 중...
# ✅ 390769: 최적 모델 order=(1, 0, 0), seasonal_order=(0, 0, 1, 12), AIC=-67.19
# ✅ 390769: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=76.08
# 📈 390931 예측 중...
# ✅ 390931: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=32.93
# ✅ 390931: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=68.09
# 📈 600537 예측 중...
# ✅ 600537: 최적 모델 order=(1, 0, 0), seasonal_order=(0, 0, 1, 12), AIC=-54.44
# ✅ 600537: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=127.14
# 📈 845611 예측 중...
# ✅ 845611: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=153.54
# ✅ 845611: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=41.01
# 📈 8507609000 예측 중...
# ✅ 8507609000: 최적 모델 order=(0, 1, 1), seasonal_order=(1, 0, 0, 12), AIC=-66.15
# ✅ 8507609000: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=139.84
# 📈 852852 예측 중...
# ✅ 852852: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=24.61
# ✅ 852852: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 0, 12), AIC=20.17
# 📈 870191 예측 중...
# ✅ 870191: 최적 모델 order=(1, 0, 1), seasonal_order=(0, 0, 1, 12), AIC=58.26
# ✅ 870191: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=634.44
# 📈 870192 예측 중...
# ✅ 870192: 최적 모델 order=(1, 0, 0), seasonal_order=(1, 0, 1, 12), AIC=7.38
# ✅ 870192: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=353.20
# 📈 870193 예측 중...
# ✅ 870193: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 0, 1, 12), AIC=44.13
# ✅ 870193: 최적 모델 order=(0, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=170.35
# 📈 870340 예측 중...
# ✅ 870340: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 0, 0, 12), AIC=54.01
# ✅ 870340: 최적 모델 order=(0, 0, 1), seasonal_order=(0, 1, 1, 12), AIC=309.35
# 📈 870360 예측 중...
# ✅ 870360: 최적 모델 order=(1, 1, 1), seasonal_order=(1, 0, 1, 12), AIC=119.23
# ✅ 870360: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 1, 1, 12), AIC=396.49
# 📈 870380 예측 중...
# ✅ 870380: 최적 모델 order=(1, 0, 1), seasonal_order=(1, 0, 1, 12), AIC=85.00
# ✅ 870380: 최적 모델 order=(0, 1, 1), seasonal_order=(0, 1, 1, 12), AIC=478.51
# 📈 2404 예측 중...
# ⚠️ 2404: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=2404, col=expDlr_yoy
# ⚠️ 2404: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=2404, col=impDlr_yoy
# 📈 300249 예측 중...
# ⚠️ 300249: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=300249, col=expDlr_yoy
# ⚠️ 300249: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=300249, col=impDlr_yoy
# 📈 382219 예측 중...
# ⚠️ 382219: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=382219, col=expDlr_yoy
# ⚠️ 382219: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=382219, col=impDlr_yoy
# 📈 3901200000 예측 중...
# ⚠️ 3901200000: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=3901200000, col=expDlr_yoy
# ⚠️ 3901200000: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=3901200000, col=impDlr_yoy
# 📈 390729 예측 중...
# ⚠️ 390729: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=390729, col=expDlr_yoy
# ⚠️ 390729: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=390729, col=impDlr_yoy
# 📈 620240 예측 중...
# ⚠️ 620240: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=620240, col=expDlr_yoy
# ⚠️ 620240: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=620240, col=impDlr_yoy
# 📈 681511 예측 중...
# ⚠️ 681511: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=681511, col=expDlr_yoy
# ⚠️ 681511: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=681511, col=impDlr_yoy
# 📈 741980 예측 중...
# ⚠️ 741980: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=741980, col=expDlr_yoy
# ⚠️ 741980: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=741980, col=impDlr_yoy
# 📈 846242 예측 중...
# ⚠️ 846242: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=846242, col=expDlr_yoy
# ⚠️ 846242: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=846242, col=impDlr_yoy
# 📈 846262 예측 중...
# ⚠️ 846262: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=846262, col=expDlr_yoy
# ⚠️ 846262: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=846262, col=impDlr_yoy
# 📈 846290 예측 중...
# ⚠️ 846290: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=846290, col=expDlr_yoy
# ⚠️ 846290: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=846290, col=impDlr_yoy
# 📈 851419 예측 중...
# ⚠️ 851419: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=851419, col=expDlr_yoy
# ⚠️ 851419: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=851419, col=impDlr_yoy
# 📈 851713 예측 중...
# ⚠️ 851713: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=851713, col=expDlr_yoy
# ⚠️ 851713: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=851713, col=impDlr_yoy
# 📈 851779 예측 중...
# ⚠️ 851779: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=851779, col=expDlr_yoy
# ⚠️ 851779: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=851779, col=impDlr_yoy
# 📈 8524 예측 중...
# ⚠️ 8524: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=8524, col=expDlr_yoy
# ⚠️ 8524: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=8524, col=impDlr_yoy
# 📈 852411 예측 중...
# ⚠️ 852411: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=852411, col=expDlr_yoy
# ⚠️ 852411: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=852411, col=impDlr_yoy
# 📈 852412 예측 중...
# ⚠️ 852412: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=852412, col=expDlr_yoy
# ⚠️ 852412: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=852412, col=impDlr_yoy
# 📈 852492 예측 중...
# ⚠️ 852492: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=852492, col=expDlr_yoy
# ⚠️ 852492: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=852492, col=impDlr_yoy
# 📈 852589 예측 중...
# ⚠️ 852589: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=852589, col=expDlr_yoy
# ⚠️ 852589: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=852589, col=impDlr_yoy
# 📈 854141 예측 중...
# ⚠️ 854141: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=854141, col=expDlr_yoy
# ⚠️ 854141: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=854141, col=impDlr_yoy
# 📈 854142 예측 중...
# ⚠️ 854142: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=854142, col=expDlr_yoy
# ⚠️ 854142: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=854142, col=impDlr_yoy
# 📈 854143 예측 중...
# ⚠️ 854143: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=854143, col=expDlr_yoy
# ⚠️ 854143: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=854143, col=impDlr_yoy
# 📈 854149 예측 중...
# ⚠️ 854149: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=854149, col=expDlr_yoy
# ⚠️ 854149: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=854149, col=impDlr_yoy
# 📈 854159 예측 중...
# ⚠️ 854159: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=854159, col=expDlr_yoy
# ⚠️ 854159: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=854159, col=impDlr_yoy
# 📈 8807 예측 중...
# ⚠️ 8807: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=8807, col=expDlr_yoy
# ⚠️ 8807: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=8807, col=impDlr_yoy
# 📈 880730 예측 중...
# ⚠️ 880730: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=880730, col=expDlr_yoy
# ⚠️ 880730: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=880730, col=impDlr_yoy
# 📈 9018909000 예측 중...
# ⚠️ 9018909000: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=9018909000, col=expDlr_yoy
# ⚠️ 9018909000: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=9018909000, col=impDlr_yoy
# 📈 902789 예측 중...
# ⚠️ 902789: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=902789, col=expDlr_yoy
# ⚠️ 902789: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=902789, col=impDlr_yoy
# 📈 940199 예측 중...
# ⚠️ 940199: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=940199, col=expDlr_yoy
# ⚠️ 940199: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=940199, col=impDlr_yoy
# 📈 970191 예측 중...
# ⚠️ 970191: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=970191, col=expDlr_yoy
# ⚠️ 970191: 월 데이터가 6년치 미만입니다.
# ⚠️ 예측 실패 또는 결과 없음 | hs_code=970191, col=impDlr_yoy

# %%
forecast_df = forecast_by_month

# 'expDlr_yoy_forecast' → 'yoy_forecast'로 정리
if 'expDlr_yoy_forecast' in forecast_df.columns:
    forecast_df = forecast_df.rename(columns={'expDlr_yoy_forecast': 'yoy_forecast'})
elif 'impDlr_yoy_forecast' in forecast_df.columns:
    forecast_df = forecast_df.rename(columns={'impDlr_yoy_forecast': 'yoy_forecast'})

# DB에서 데이터 불러오기
# trade_data_df = load_monthly_trade_data_from_db()

# 🧩 Step 1: forecast_df 피벗
forecast_df_pivoted = pivot_forecast_df(forecast_df)

# 🧩 Step 2: merge 실행'
final_combined_df = merge_forecast_with_actuals(forecast_df_pivoted, trade_data_df)

# hs_code_list = ['854232', '854231']
# hs_code_list
forecast_result_df = final_combined_df[final_combined_df['root_hs_code'].isin(hs_cd_list)]
forecast_result_data = forecast_result_df[['date', 'root_hs_code', 'final_expDlr_yoy', 'expDlr_forecast_12m']]

# %%
upload_forecast_to_db(forecast_result_data, db_info)
# Out:
# ✅ 데이터가 korea_monthly_trade_data_forecast 테이블에 성공적으로 업로드되었습니다. (중복 시 자동 갱신)

# %%
# from datetime import datetime
#
# # 📌 2. 전처리
# today_date = datetime.today().strftime('%Y-%m-%d')
#
# # 'period' 제거
# if 'period' in forecast_by_month.columns:
#     df = forecast_by_month.drop(columns=['period'])
#
# # 'hs_code' → 'root_hs_code'로 변경
# df = forecast_by_month.rename(columns={'hs_code': 'root_hs_code'})
#
# # forecast_date 추가
# df['forecast_date'] = today_date
#
# # SQLAlchemy 엔진 생성
# engine = create_engine(
#     f"mysql+pymysql://{db_info['user']}:{db_info['password']}@{db_info['host']}:{db_info['port']}/{db_info['database']}"
# )
# # 📌 4. DB 업로드
# table_name = 'korea_monthly_trade_data_record'
# df.to_sql(name=table_name, con=engine, if_exists='append', index=False)
#
# print(f"✅ {table_name} 테이블에 {len(df)}건 업로드 완료 (날짜: {today_date})")
# Out:
# ✅ korea_monthly_trade_data_record 테이블에 18967건 업로드 완료 (날짜: 2025-08-12)
