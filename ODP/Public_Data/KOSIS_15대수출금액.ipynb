# %%
from stock_forecast.ODP.Public_Data.kita_long_term_collector_fixed import collect_long_term_trade_data, analyze_trade_data, save_trade_data

from DATA.KEYS import *

# API 키
SERVICE_KEY = KEYS['ODPD']

# 데이터 수집
df = collect_long_term_trade_data(
    service_key=SERVICE_KEY,
    start_year=2010,
    end_year=2025
)

# 분석
analyze_trade_data(df)

# 저장
save_trade_data(df, 2010, 2025)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from stock_forecast.ODP.Public_Data.kita_long_term_collector_fixed import collect_long_term_trade_data, analyze_trade_data, save_trade_data
#       3 from DATA.KEYS import *
#       5 # API 키
#
# ModuleNotFoundError: No module named 'stock_forecast.ODP'

# %%
from stock_forecast.ODP.Public_Data.motie_15items_from_hs4_itemtrade import run

SERVICE_KEY = '2o6NG3ixxDgGQ9S4dWUgsMac9WlxfX46%2BJvFRsAlsXQ6xVi6CZewvNJvbHd4S7exkWwt3YWoKSdwvUNb46kSTQ%3D%3D'

df = run(SERVICE_KEY, 2020, 2025)
df.tail()
# Out:
# 2026-02-02 11:26:51,415 - INFO - ================================================================================
# 2026-02-02 11:26:51,417 - INFO - [INFO] 수집 대상 HS4 총 66개 (중복 제거)
# 2026-02-02 11:26:51,418 - INFO - ================================================================================
# 2026-02-02 11:26:51,418 - INFO - [HS4] 2710 수집 시작
# 2026-02-02 11:26:52,792 - INFO -   2020: ✅ 12개월
# 2026-02-02 11:26:53,973 - INFO -   2021: ✅ 12개월
# 2026-02-02 11:26:54,991 - INFO -   2022: ✅ 12개월
# 2026-02-02 11:26:56,256 - INFO -   2023: ✅ 12개월
# 2026-02-02 11:26:57,016 - INFO -   2024: ✅ 12개월
# 2026-02-02 11:26:57,661 - INFO -   2025: ✅ 12개월
# 2026-02-02 11:26:57,744 - INFO - [HS4] 2711 수집 시작
# 2026-02-02 11:26:58,922 - INFO -   2020: ✅ 12개월
# 2026-02-02 11:26:59,995 - INFO -   2021: ✅ 12개월
# 2026-02-02 11:27:00,840 - INFO -   2022: ✅ 12개월
# 2026-02-02 11:27:01,547 - INFO -   2023: ✅ 12개월
# 2026-02-02 11:27:02,628 - INFO -   2024: ✅ 12개월
# ...
